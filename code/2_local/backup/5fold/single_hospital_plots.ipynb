# %%
# Data
hospitals = ['Hospital 18', 'Hospital 43', 'Hospital 55']
models = ['vgg 19', 'resnet 50', 'resnet 101', 'densenet161']

# Metrics
metrics = ['Total Acc', 'nff Acc', 'aff Acc', 'AUC', 'MCC', 'F1 Score']

# Values for each hospital and model
values = {
    'Hospital 18': {
        'vgg 19': {'Total Acc': 0.821, 'nff Acc': 0.839, 'aff Acc': 0.749, 'AUC': 0.794, 'MCC': 0.525, 'F1 Score': 0.626},
        'resnet 50': {'Total Acc': 0.865, 'nff Acc': 0.911, 'aff Acc': 0.682, 'AUC': 0.797, 'MCC': 0.585, 'F1 Score': 0.67},
        'resnet 101': {'Total Acc': 0.83, 'nff Acc': 0.856, 'aff Acc': 0.728, 'AUC': 0.792, 'MCC': 0.532, 'F1 Score': 0.632},
        'densenet161': {'Total Acc': 0.844, 'nff Acc': 0.872, 'aff Acc': 0.732, 'AUC': 0.802, 'MCC': 0.559, 'F1 Score': 0.652},
    },
    'Hospital 43': {
        'vgg 19': {'Total Acc': 0.886, 'nff Acc': 0.963, 'aff Acc': 0.577, 'AUC': 0.77, 'MCC': 0.613, 'F1 Score': 0.668},
        'resnet 50': {'Total Acc': 0.924, 'nff Acc': 0.972, 'aff Acc': 0.73, 'AUC': 0.851, 'MCC': 0.751, 'F1 Score': 0.793},
        'resnet 101': {'Total Acc': 0.895, 'nff Acc': 0.974, 'aff Acc': 0.578, 'AUC': 0.776, 'MCC': 0.644, 'F1 Score': 0.688},
        'densenet161': {'Total Acc': 0.892, 'nff Acc': 0.93, 'aff Acc': 0.741, 'AUC': 0.835, 'MCC': 0.666, 'F1 Score': 0.733},
    },
    'Hospital 55': {
        'vgg 19': {'Total Acc': 0.886, 'nff Acc': 0.963, 'aff Acc': 0.577, 'AUC': 0.77, 'MCC': 0.613, 'F1 Score': 0.668},
        'resnet 50': {'Total Acc': 0.924, 'nff Acc': 0.972, 'aff Acc': 0.73, 'AUC': 0.851, 'MCC': 0.751, 'F1 Score': 0.793},
        'resnet 101': {'Total Acc': 0.895, 'nff Acc': 0.974, 'aff Acc': 0.578, 'AUC': 0.776, 'MCC': 0.644, 'F1 Score': 0.688},
        'densenet161': {'Total Acc': 0.892, 'nff Acc': 0.93, 'aff Acc': 0.741, 'AUC': 0.835, 'MCC': 0.666, 'F1 Score': 0.733},
    },
}

# Calculate average values
avg_values = {}
for metric in metrics:
    avg_values[metric] = {}
    for model in models:
        total = sum(values[hospital][model][metric] for hospital in hospitals)
        avg_values[metric][model] = total / len(hospitals)

# Display the average values
for metric, model_values in avg_values.items():
    print(f'{metric} Average:')
    for model, value in model_values.items():
        print(f'{model}: {value:.3f}')
    print('\n')
# Out:
# Total Acc Average:
# vgg 19: 0.864
# resnet 50: 0.904
# resnet 101: 0.873
# densenet161: 0.876
#
#
# nff Acc Average:
# vgg 19: 0.922
# resnet 50: 0.952
# resnet 101: 0.935
# densenet161: 0.911
#
#
# aff Acc Average:
# vgg 19: 0.634
# resnet 50: 0.714
# resnet 101: 0.628
# densenet161: 0.738
#
#
# AUC Average:
# vgg 19: 0.778
# resnet 50: 0.833
# resnet 101: 0.781
# densenet161: 0.824
#
#
# MCC Average:
# vgg 19: 0.584
# resnet 50: 0.696
# resnet 101: 0.607
# densenet161: 0.630
#
#
# F1 Score Average:
# vgg 19: 0.654
# resnet 50: 0.752
# resnet 101: 0.669
# densenet161: 0.706

# %%
import numpy as np

# Data for Hospital 18
hospital_18_data = {
    'vgg19': {'Total Acc': 0.821, 'AUC': 0.794, 'MCC': 0.525, 'F1 Score': 0.626},
    'resnet50': {'Total Acc': 0.865, 'AUC': 0.797, 'MCC': 0.585, 'F1 Score': 0.67},
    'resnet101': {'Total Acc': 0.83, 'AUC': 0.792, 'MCC': 0.532, 'F1 Score': 0.632},
    'densenet161': {'Total Acc': 0.844, 'AUC': 0.802, 'MCC': 0.559, 'F1 Score': 0.652}
}

# Data for Hospital 43
hospital_43_data = {
    'vgg19': {'Total Acc': 0.886, 'AUC': 0.77, 'MCC': 0.613, 'F1 Score': 0.668},
    'resnet50': {'Total Acc': 0.924, 'AUC': 0.851, 'MCC': 0.751, 'F1 Score': 0.793},
    'resnet101': {'Total Acc': 0.895, 'AUC': 0.776, 'MCC': 0.644, 'F1 Score': 0.688},
    'densenet161': {'Total Acc': 0.892, 'AUC': 0.835, 'MCC': 0.666, 'F1 Score': 0.733}
}

# Data for Hospital 55
hospital_55_data = {
    'vgg19': {'Total Acc': 0.8, 'AUC': 0.5, 'MCC': 0.0, 'F1 Score': 0.0},
    'resnet50': {'Total Acc': 0.712, 'AUC': 0.724, 'MCC': 0.368, 'F1 Score': 0.508},
    'resnet101': {'Total Acc': 0.568, 'AUC': 0.643, 'MCC': 0.229, 'F1 Score': 0.415},
    'densenet161': {'Total Acc': 0.713, 'AUC': 0.726, 'MCC': 0.372, 'F1 Score': 0.51}
}

# Combine data from all hospitals
all_data = [hospital_18_data, hospital_43_data, hospital_55_data]

# Calculate averages
avg_values = {}
for hospital_data in all_data:
    for model, metrics in hospital_data.items():
        if model not in avg_values:
            avg_values[model] = {metric: [metrics[metric]] for metric in metrics}
        else:
            for metric, value in metrics.items():
                avg_values[model][metric].append(value)

# Calculate mean values and round to three decimal places
mean_values = {model: {metric: round(np.mean(values), 3) for metric, values in metrics.items()} for model, metrics in avg_values.items()}

print(mean_values)
# Out:
# {'vgg19': {'Total Acc': 0.836, 'AUC': 0.688, 'MCC': 0.379, 'F1 Score': 0.431}, 'resnet50': {'Total Acc': 0.834, 'AUC': 0.791, 'MCC': 0.568, 'F1 Score': 0.657}, 'resnet101': {'Total Acc': 0.764, 'AUC': 0.737, 'MCC': 0.468, 'F1 Score': 0.578}, 'densenet161': {'Total Acc': 0.816, 'AUC': 0.788, 'MCC': 0.532, 'F1 Score': 0.632}}

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
models = ['VGG 19', 'ResNet 50', 'ResNet 101', 'DenseNet 161']

# New mean values
total_acc_mean = [0.836, 0.834, 0.764, 0.816]
auc_mean = [0.688, 0.791, 0.737, 0.788]
mcc_mean = [0.379, 0.568, 0.468, 0.532]
f1_score_mean = [0.431, 0.657, 0.578, 0.632]

# Standard deviation values (you can adjust these as needed)
total_acc_std = [0.007, 0.002, 0.004, 0.007]
auc_std = [0.002, 0.008, 0.009, 0.002]
mcc_std = [0.011, 0.006, 0.0, 0.013]
f1_score_std = [0.008, 0.007, 0.003, 0.008]

# Plotting
bar_width = 0.2
index = np.arange(len(models))

fig, ax = plt.subplots(figsize=(10, 6))

bar1 = ax.bar(index - bar_width, total_acc_mean, bar_width, label='Total Acc', yerr=total_acc_std, color='#d2ecf9')
bar2 = ax.bar(index, auc_mean, bar_width, label='AUC', yerr=auc_std, color='#1891ac')
bar3 = ax.bar(index + bar_width, mcc_mean, bar_width, label='MCC', yerr=mcc_std, color='#1f5f8b')
bar4 = ax.bar(index + 2 * bar_width, f1_score_mean, bar_width, label='F1 Score', yerr=f1_score_std, color='#253b6e')

ax.set_xlabel('Models')
ax.set_ylabel('Scores')
ax.set_xticks(index + bar_width)
ax.set_xticklabels(models)
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
models = ['vgg19', 'resnet50', 'resnet101', 'densenet161']

# Local training data for Hospital 18
hospital_18_local_data = {
    'vgg19': {'Total Acc': 0.821, 'nff Acc': 0.839, 'aff Acc': 0.749, 'AUC': 0.794, 'MCC': 0.525, 'F1 Score': 0.626},
    'resnet50': {'Total Acc': 0.865, 'nff Acc': 0.911, 'aff Acc': 0.682, 'AUC': 0.797, 'MCC': 0.585, 'F1 Score': 0.67},
    'resnet101': {'Total Acc': 0.83, 'nff Acc': 0.856, 'aff Acc': 0.728, 'AUC': 0.792, 'MCC': 0.532, 'F1 Score': 0.632},
    'densenet161': {'Total Acc': 0.844, 'nff Acc': 0.872, 'aff Acc': 0.732, 'AUC': 0.802, 'MCC': 0.559, 'F1 Score': 0.652}
}

# Extracting values
total_acc_mean = [hospital_18_local_data[model]['Total Acc'] for model in models]
nff_acc_mean = [hospital_18_local_data[model]['nff Acc'] for model in models]
aff_acc_mean = [hospital_18_local_data[model]['aff Acc'] for model in models]
auc_mean = [hospital_18_local_data[model]['AUC'] for model in models]
mcc_mean = [hospital_18_local_data[model]['MCC'] for model in models]
f1_score_mean = [hospital_18_local_data[model]['F1 Score'] for model in models]

# Plotting
bar_width = 0.15
index = np.arange(len(models))

fig, ax = plt.subplots(figsize=(12, 6))

bar1 = ax.bar(index - 2*bar_width, total_acc_mean, bar_width, label='Total Acc', color='#d2ecf9')
bar2 = ax.bar(index - bar_width, nff_acc_mean, bar_width, label='nff Acc', color='#1891ac')
bar3 = ax.bar(index, aff_acc_mean, bar_width, label='aff Acc', color='#1f5f8b')
bar4 = ax.bar(index + bar_width, auc_mean, bar_width, label='AUC', color='#253b6e')
bar5 = ax.bar(index + 2*bar_width, mcc_mean, bar_width, label='MCC', color='#8b1f5f')
bar6 = ax.bar(index + 3*bar_width, f1_score_mean, bar_width, label='F1 Score', color='#6e253b')

ax.set_xlabel('Models')
ax.set_ylabel('Scores')
ax.set_xticks(index)
ax.set_xticklabels(models)
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

# Data for Hospital 18
hospital_18_data = {
    'vgg19': {'Total Acc': 0.821, 'AUC': 0.794, 'MCC': 0.525, 'F1 Score': 0.626},
    'resnet50': {'Total Acc': 0.865, 'AUC': 0.797, 'MCC': 0.585, 'F1 Score': 0.67},
    'resnet101': {'Total Acc': 0.83, 'AUC': 0.792, 'MCC': 0.532, 'F1 Score': 0.632},
    'densenet161': {'Total Acc': 0.844, 'AUC': 0.802, 'MCC': 0.559, 'F1 Score': 0.652}
}

# Data for Hospital 43
hospital_43_data = {
    'vgg19': {'Total Acc': 0.886, 'AUC': 0.77, 'MCC': 0.613, 'F1 Score': 0.668},
    'resnet50': {'Total Acc': 0.924, 'AUC': 0.851, 'MCC': 0.751, 'F1 Score': 0.793},
    'resnet101': {'Total Acc': 0.895, 'AUC': 0.776, 'MCC': 0.644, 'F1 Score': 0.688},
    'densenet161': {'Total Acc': 0.892, 'AUC': 0.835, 'MCC': 0.666, 'F1 Score': 0.733}
}

# Data for Hospital 55
hospital_55_data = {
    'vgg19': {'Total Acc': 0.67, 'AUC': 0.657, 'MCC': 0.258, 'F1 Score': 0.435},
    'resnet50': {'Total Acc': 0.712, 'AUC': 0.724, 'MCC': 0.368, 'F1 Score': 0.508},
    'resnet101': {'Total Acc': 0.568, 'AUC': 0.643, 'MCC': 0.229, 'F1 Score': 0.415},
    'densenet161': {'Total Acc': 0.713, 'AUC': 0.726, 'MCC': 0.372, 'F1 Score': 0.51}
}
# Function to plot data
def plot_subplot(ax, data, title):
    models = list(data.keys())
    metrics = list(data[models[0]].keys())

    for metric in metrics:
        values = [data[model][metric] for model in models]
        ax.plot(models, values, marker='o', label=metric)

    ax.set_title(title)
    ax.set_xlabel('Models')
    ax.set_ylabel('Scores')
    ax.legend(loc='lower right')

# Create subplots
fig, axs = plt.subplots(1, 3, figsize=(18, 5))

# 设置Y轴刻度范围为0到1
for ax in axs:
    ax.set_ylim(0, 1)

# Plot for Hospital 18
plot_subplot(axs[0], hospital_18_data, 'Hospital 18')

# Plot for Hospital 43
plot_subplot(axs[1], hospital_43_data, 'Hospital 43')

# Plot for Hospital 55
plot_subplot(axs[2], hospital_55_data, 'Hospital 55')

plt.tight_layout()
plt.show()
