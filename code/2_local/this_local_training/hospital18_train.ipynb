# %% [markdown]
# # Functions

# %% [markdown]
# test on hospital data without 18 22 43 45 55
#
# use CustomDatasetCSV to load test data
#
# use CustomDatasetJson to load train data
#
# with smoothed training curve, weight = 0.8
#
# test data on 4_fedrated, path:
#
# /local/data1/honzh/local_repository/FL/code/4_federated/csv_files/test_data.csv

# %%
from torch.utils.data import Dataset
from PIL import Image
import csv
from torchvision import transforms
import torch
import numpy as np
import matplotlib.pyplot as plt
import json

# # read by csv files 
class CustomDatasetCSV(Dataset):
    def __init__(self, csv_file, transform=None):
        self.data = []
        self.labels = []
        self.patient_ids = []
        self.transform = transform
        
        with open(csv_file, 'r') as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                image_path = row['ImagePath']
                label = row['Label']
                patient_id = row['PatientID']
                
                if label == 'NFF':
                    label = 0
                elif label == 'AFF':
                    label = 1
                else:
                    raise ValueError("Invalid label in CSV file.")
                
                self.data.append((image_path, label))
                self.labels.append(label)
                self.patient_ids.append(patient_id)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image_path, label = self.data[idx]
        image = Image.open(image_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image, label

# read by json files:
# in order to read from json file
class CustomDatasetJson(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]
        image_path = item['ImagePath']
        label = item['Label']

        # Load image
        image = Image.open(image_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        # Convert label to numerical representation
        if label == 'NFF':
            label = 0
        elif label == 'AFF':
            label = 1
        else:
            raise ValueError("Invalid label in JSON data.")

        return image, label

# show image by csvfiles
# def show_image(dataset, num_images=5):
#     random_indices = np.random.choice(len(dataset), num_images, replace=False)
    
#     plt.figure(figsize=(15, 5))
#     for i, idx in enumerate(random_indices):
#         image, label = dataset[idx]
#         filename = dataset.data[idx][0]
#         truncated_filename = filename.split('/')[-1][:15]
        
#         print(f"Image location: {filename}")

#         plt.subplot(1, num_images, i + 1)
#         plt.title(f"Label: {label}")
#         plt.imshow(image[0])
#         plt.axis('off')
#     plt.show()

# show image by json files


# show x ray image
def show_image(dataset, num_images=5):
    random_indices = np.random.choice(len(dataset), num_images, replace=False)
    
    plt.figure(figsize=(15, 5))
    for i, idx in enumerate(random_indices):
        data_point = dataset[idx]
        image_path = data_point["ImagePath"]
        label = data_point["Label"]

        image = Image.open(image_path)
        
        plt.subplot(1, num_images, i + 1)
        plt.title(f"Label: {label}")
        plt.imshow(image)
        plt.axis('off')
    plt.show()


# model parameters number
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# calculate class weight
def get_class_weight(train_dataset):
    train_nff_count = sum(1 for _, label in train_dataset if label == 0)
    train_aff_count = sum(1 for _, label in train_dataset if label == 1)
    class_weight_nff = 1 / (2 * (train_nff_count / (train_nff_count + train_aff_count)))
    class_weight_aff = 1 / (2 * (train_aff_count / (train_nff_count + train_aff_count)))
    
    return [class_weight_nff, class_weight_aff]

# %%
# import pandas as pd
# from sklearn.model_selection import train_test_split

# # Load the original CSV file
# csv_file_path = "/local/data1/honzh/local_repository/FL/code/2_local/hospital18.csv"
# df = pd.read_csv(csv_file_path)

# # Unique patient IDs
# unique_patient_ids = df['PatientID'].unique()

# # Split the patient IDs into training and validation sets
# train_patient_ids, val_patient_ids = train_test_split(unique_patient_ids, test_size=0.3, random_state=1)

# # Create subsets based on patient IDs
# train_data = df[df['PatientID'].isin(train_patient_ids)]
# val_data = df[df['PatientID'].isin(val_patient_ids)]

# # Save the subsets to separate CSV files if needed
# train_data.to_csv("/local/data1/honzh/local_repository/FL/code/2_local/hospital18_train.csv", index=False)
# val_data.to_csv("/local/data1/honzh/local_repository/FL/code/2_local/hospital18_val.csv", index=False)

# %% [markdown]
# # training
# training function and best acc model

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import matthews_corrcoef
import random

# Set random seed
seed = 1
torch.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)

# CUDA seed 
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

def smooth_curve(points, factor=0.8):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points

# train function with early stopping
def train_custom_model(model, train_dataset, val_dataset, num_epochs, batch_size, optimizer):
    # patience = 40  # early stopping
    classweight = get_class_weight(train_dataset)
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    criterion = nn.CrossEntropyLoss(weight=torch.Tensor(classweight).to(device))

    train_loader = DataLoader(train_dataset, batch_size=batch_size,shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    # Create a learning rate scheduler
    lr_scheduler_step = 10  # Adjust this value based on your requirement
    scheduler = lr_scheduler.StepLR(optimizer, step_size=lr_scheduler_step, gamma=0.1)

    best_acc = 0  # Initialize best accuracy value  # Change here
    best_model = None

    # consecutive_no_improvement = 0  # Counter for consecutive epochs without improvement

    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []
    train_mccs = []  # List to store MCC values for each epoch
    val_mccs = []  # List to store MCC values for each epoch

    for epoch in range(num_epochs):
        model.train()
        correct_train = 0
        total_train = 0
        train_loss = 0

        all_train_labels = []  # List to store labels for the entire training set
        all_train_predictions = []  # List to store predictions for the entire training set

        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
            train_loss += loss.item()

            all_train_labels.extend(labels.cpu().numpy())
            all_train_predictions.extend(predicted.cpu().numpy())

        train_accuracy = correct_train / total_train
        train_loss /= len(train_loader)

        # Calculate MCC for training set
        train_mcc = matthews_corrcoef(all_train_labels, all_train_predictions)

        model.eval()
        correct_validation = 0
        total_validation = 0
        validation_loss = 0

        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)

                _, predicted = torch.max(outputs.data, 1)
                total_validation += labels.size(0)
                correct_validation += (predicted == labels).sum().item()
                validation_loss += loss.item()

            validation_accuracy = correct_validation / total_validation
            validation_loss /= len(val_loader)

            # Calculate MCC for validation set
            all_val_labels = []  # List to store labels for the entire validation set
            all_val_predictions = []  # List to store predictions for the entire validation set
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                outputs = model(images)
                _, predicted = torch.max(outputs.data, 1)
                all_val_labels.extend(labels.cpu().numpy())
                all_val_predictions.extend(predicted.cpu().numpy())

            val_mcc = matthews_corrcoef(all_val_labels, all_val_predictions)

            print(f"Epoch {epoch + 1}/{num_epochs}, "
                  f"Train Loss: {train_loss:.4f}, Train ACC: {train_accuracy:.2f}, Train MCC: {train_mcc:.4f}, "
                  f"Val Loss: {validation_loss:.4f}, Val ACC: {validation_accuracy:.2f}, Val MCC: {val_mcc:.4f}")

            # Early stopping check
            if validation_accuracy > best_acc:  # Change here
                best_acc = validation_accuracy  # Change here
                # Save the best model
                best_model = model
                
            # early stopping 
            # if consecutive_no_improvement >= patience:
            #     print(f"No improvement in MCC for {patience} consecutive epochs. Early stopping.")
            #     break

        # Append metrics for plotting
        train_losses.append(train_loss)
        val_losses.append(validation_loss)
        train_accuracies.append(train_accuracy)
        val_accuracies.append(validation_accuracy)
        train_mccs.append(train_mcc)
        val_mccs.append(val_mcc)

        # Step the learning rate scheduler
        scheduler.step()

    # Plotting with smoothing and original curves
    plt.figure(figsize=(15, 5))

    # Plotting Loss
    plt.subplot(1, 3, 1)
    plt.plot(range(1, len(train_losses) + 1), smooth_curve(train_losses), label='Train Loss(smoothed)', color='blue')
    plt.plot(range(1, len(val_losses) + 1), smooth_curve(val_losses), label='Validation Loss (smoothed)', color='orange')
    plt.plot(range(1, len(train_losses) + 1), train_losses, linestyle='dashed', label='Train Loss', color='lightblue')
    plt.plot(range(1, len(val_losses) + 1), val_losses, linestyle='dashed', label='Validation Loss', color='navajowhite')
    plt.xlabel('Epoch', fontsize = 15)
    plt.ylabel('Loss', fontsize = 15)
    plt.ylim(0, 1)  # Set Y-axis limits
    plt.legend()

    # Plotting Accuracy
    plt.subplot(1, 3, 2)
    plt.plot(range(1, len(train_accuracies) + 1), smooth_curve(train_accuracies), label='Train Accuracy (smoothed)', color='green')
    plt.plot(range(1, len(val_accuracies) + 1), smooth_curve(val_accuracies), label='Validation Accuracy (smoothed)', color='red')
    plt.plot(range(1, len(train_accuracies) + 1), train_accuracies, linestyle='dashed', label='Train Accuracy', color='lightgreen')
    plt.plot(range(1, len(val_accuracies) + 1), val_accuracies, linestyle='dashed', label='Validation Accuracy', color='lightcoral')
    plt.xlabel('Epoch', fontsize = 15)
    plt.ylabel('Accuracy', fontsize = 15)
    plt.ylim(0, 1)  # Set Y-axis limits
    plt.legend()

    # Plotting MCC
    plt.subplot(1, 3, 3)
    plt.plot(range(1, len(train_mccs) + 1), smooth_curve(train_mccs), label='Train MCC (smoothed)', color='purple')
    plt.plot(range(1, len(val_mccs) + 1), smooth_curve(val_mccs), label='Validation MCC (smoothed)', color='black')
    plt.plot(range(1, len(train_mccs) + 1), train_mccs, linestyle='dashed', label='Train MCC', color='plum')
    plt.plot(range(1, len(val_mccs) + 1), val_mccs, linestyle='dashed', label='Validation MCC', color='grey')
    plt.xlabel('Epoch', fontsize = 15)
    plt.ylabel('MCC', fontsize = 15)
    plt.ylim(0, 1)  # Set Y-axis limits
    plt.legend()

    plt.tight_layout()
    plt.show()

    return best_model  # Return the model with the best MCC

# %% [markdown]
# # test model performance

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import matthews_corrcoef, f1_score
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, average_precision_score, precision_score, recall_score, accuracy_score
import torchvision.transforms as transforms
import random

def test_model(model, test_dataset):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, pin_memory=True)
    model = model.to(device)

    model.eval()

    correct_test_nff = 0
    correct_test_aff = 0
    total_nff = 0
    total_aff = 0
    total_test = 0
    test_loss = 0

    criterion = nn.CrossEntropyLoss()

    with torch.no_grad():
        all_predictions = []
        all_labels = []
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            _, predicted = torch.max(outputs.data, 1)
            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            total_test += labels.size(0)
            total_nff += (labels == 0).sum().item()
            total_aff += (labels == 1).sum().item()
            correct_test_nff += ((predicted == labels) & (labels == 0)).sum().item()
            correct_test_aff += ((predicted == labels) & (labels == 1)).sum().item()
            test_loss += loss.item()

    # Check if total_aff is zero before performing the division
    test_accuracy_nff = correct_test_nff / total_nff if total_nff != 0 else 0
    test_accuracy_aff = correct_test_aff / total_aff if total_aff != 0 else 0
    test_accuracy_total = (correct_test_nff + correct_test_aff) / total_test
    test_loss /= len(test_loader)

    conf_matrix = confusion_matrix(all_labels, all_predictions)

    # Directly use class labels as strings in target_names
    target_names = ['NFF', 'AFF']

    classification_rep = classification_report(all_labels, all_predictions)

    # Calculate AUC
    auc_score = roc_auc_score(all_labels, all_predictions)

    # Calculate Matthew's correlation coefficient
    mcc_score = matthews_corrcoef(all_labels, all_predictions)

    # Calculate F1 score
    f1_score_value = f1_score(all_labels, all_predictions)

    # Calculate Precision, Recall, Accuracy, ROC-AUC, and PRC-AUC
    precision_value = precision_score(all_labels, all_predictions)
    recall_value = recall_score(all_labels, all_predictions)
    accuracy_value = accuracy_score(all_labels, all_predictions)
    roc_auc_value = roc_auc_score(all_labels, all_predictions)
    prc_auc_value = average_precision_score(all_labels, all_predictions)

    # Store metrics in a dictionary
    metrics = {
        "Total Acc": round(test_accuracy_total, 3),
        "nff Acc": round(test_accuracy_nff, 3),
        "aff Acc": round(test_accuracy_aff, 3),
        "Precision": round(precision_value, 3),
        "Recall": round(recall_value, 3),
        "Accuracy": round(accuracy_value, 3),
        "AUC": round(auc_score, 3),
        "MCC": round(mcc_score, 3),
        "F1 Score": round(f1_score_value, 3),
        "ROC_AUC": round(roc_auc_value, 3),
        "PRC-AUC": round(prc_auc_value, 3)
    }

    # Confusion Matrix
    plt.figure(figsize=(6, 4))
    sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=target_names, yticklabels=target_names)
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()

    # Classification Report
    print("Classification Report:")
    print(classification_rep)

    # Print all metrics
    # for metric_name, metric_value in metrics.items():
    #     print(f"{metric_name}: {metric_value}")

    return metrics

# %%
# Image transformations
train_transforms = transforms.Compose([
    transforms.RandomRotation(degrees=30),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.GaussianBlur(kernel_size=3),
    transforms.RandomEqualize(),
    transforms.RandomAdjustSharpness(sharpness_factor=5),
    transforms.RandomPerspective(distortion_scale=0.6),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

val_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])



# Load by csv data
# train_dataset = CustomDataset('/local/data1/honzh/local_repository/FL/code/2_local/hospital18_train.csv', transform=train_transforms)
# val_dataset = CustomDataset('/local/data1/honzh/local_repository/FL/code/2_local/hospital18_val.csv', transform=val_transforms)
# class_weights = get_class_weight(train_dataset)
# print('Training class weights:', class_weights)

# Load by JSON data
with open('/local/data1/honzh/local_repository/FL/code/2_local/data_files/hospital18_1.json', 'r') as json_file:
    json_data = json.load(json_file)
    train_data = json_data['train']
    val_data = json_data['val']

train_dataset = CustomDatasetJson(train_data, transform=train_transforms)
val_dataset = CustomDatasetJson(val_data, transform=val_transforms)


# Show images
# show_image(train_dataset, 5)

# Calculate numbers
print('-----------------------------------')
train_NFF_count = sum(1 for _, label in train_dataset if label == 0)
train_AFF_count = sum(1 for _, label in train_dataset if label == 1)

print(f"train AFF: {train_AFF_count}, ratio: {train_AFF_count / (train_AFF_count + train_NFF_count):.2f}")
print(f"----- NFF: {train_NFF_count}, ratio: {train_NFF_count / (train_AFF_count + train_NFF_count):.2f}")

print('-----------------------------------')
train_NFF_count = sum(1 for _, label in val_dataset if label == 0)
train_AFF_count = sum(1 for _, label in val_dataset if label == 1)

print(f"val AFF: {train_AFF_count}, ratio: {train_AFF_count / (train_AFF_count + train_NFF_count):.2f}")
print(f"----- NFF: {train_NFF_count}, ratio: {train_NFF_count / (train_AFF_count + train_NFF_count):.2f}")
# Out:
# -----------------------------------
# train AFF: 33, ratio: 0.38
# ----- NFF: 54, ratio: 0.62
# -----------------------------------
# val AFF: 10, ratio: 0.26
# ----- NFF: 29, ratio: 0.74

# %% [markdown]
# # VGG 19

# %%
from torchvision.models import vgg19, VGG19_Weights
from torchvision import transforms, models

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the VGG-19 model
model = models.vgg19(weights=VGG19_Weights.DEFAULT)

# Modify the classifier part of the model
num_features = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_features, 2)

# layer number
total_layers = len(list(model.features.children()))

# freeze 50% layer
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.features.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False
# ---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 200
batch_size = 32
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

vgg19 = train_custom_model(model, train_dataset, val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/200, Train Loss: 0.7540, Train ACC: 0.46, Train MCC: -0.0463, Val Loss: 0.5633, Val ACC: 0.74, Val MCC: 0.0000
# Epoch 2/200, Train Loss: 0.7001, Train ACC: 0.61, Train MCC: 0.0927, Val Loss: 0.5976, Val ACC: 0.72, Val MCC: 0.1844
# Epoch 3/200, Train Loss: 0.6743, Train ACC: 0.63, Train MCC: 0.1760, Val Loss: 0.6104, Val ACC: 0.56, Val MCC: 0.1325
# Epoch 4/200, Train Loss: 0.6386, Train ACC: 0.62, Train MCC: 0.2891, Val Loss: 0.6232, Val ACC: 0.49, Val MCC: 0.0425
# Epoch 5/200, Train Loss: 0.6735, Train ACC: 0.67, Train MCC: 0.3351, Val Loss: 0.5718, Val ACC: 0.51, Val MCC: 0.0151
# Epoch 6/200, Train Loss: 0.6326, Train ACC: 0.57, Train MCC: 0.2066, Val Loss: 0.6872, Val ACC: 0.49, Val MCC: 0.1661
# Epoch 7/200, Train Loss: 0.6435, Train ACC: 0.68, Train MCC: 0.4019, Val Loss: 0.6361, Val ACC: 0.51, Val MCC: 0.1946
# Epoch 8/200, Train Loss: 0.5993, Train ACC: 0.64, Train MCC: 0.2770, Val Loss: 0.6954, Val ACC: 0.46, Val MCC: 0.1370
# Epoch 9/200, Train Loss: 0.5341, Train ACC: 0.72, Train MCC: 0.4296, Val Loss: 0.6994, Val ACC: 0.54, Val MCC: 0.0453
# Epoch 10/200, Train Loss: 0.5686, Train ACC: 0.66, Train MCC: 0.3170, Val Loss: 0.6823, Val ACC: 0.59, Val MCC: 0.0502
# Epoch 11/200, Train Loss: 0.4680, Train ACC: 0.78, Train MCC: 0.5457, Val Loss: 0.6738, Val ACC: 0.56, Val MCC: -0.0415
# Epoch 12/200, Train Loss: 0.5033, Train ACC: 0.79, Train MCC: 0.5664, Val Loss: 0.6657, Val ACC: 0.59, Val MCC: 0.0502
# Epoch 13/200, Train Loss: 0.4429, Train ACC: 0.83, Train MCC: 0.6670, Val Loss: 0.6731, Val ACC: 0.59, Val MCC: 0.1071
# Epoch 14/200, Train Loss: 0.4987, Train ACC: 0.76, Train MCC: 0.5617, Val Loss: 0.6792, Val ACC: 0.62, Val MCC: 0.1943
# Epoch 15/200, Train Loss: 0.4467, Train ACC: 0.72, Train MCC: 0.4484, Val Loss: 0.6588, Val ACC: 0.67, Val MCC: 0.3128
# Epoch 16/200, Train Loss: 0.4266, Train ACC: 0.79, Train MCC: 0.5908, Val Loss: 0.6193, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 17/200, Train Loss: 0.3656, Train ACC: 0.83, Train MCC: 0.6489, Val Loss: 0.6068, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 18/200, Train Loss: 0.4221, Train ACC: 0.80, Train MCC: 0.5827, Val Loss: 0.6094, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 19/200, Train Loss: 0.3396, Train ACC: 0.79, Train MCC: 0.6012, Val Loss: 0.5965, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 20/200, Train Loss: 0.4695, Train ACC: 0.80, Train MCC: 0.5876, Val Loss: 0.5930, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 21/200, Train Loss: 0.4206, Train ACC: 0.84, Train MCC: 0.6550, Val Loss: 0.5971, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 22/200, Train Loss: 0.3736, Train ACC: 0.79, Train MCC: 0.5733, Val Loss: 0.6035, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 23/200, Train Loss: 0.3663, Train ACC: 0.84, Train MCC: 0.6692, Val Loss: 0.6079, Val ACC: 0.67, Val MCC: 0.3128
# Epoch 24/200, Train Loss: 0.3239, Train ACC: 0.87, Train MCC: 0.7444, Val Loss: 0.6114, Val ACC: 0.67, Val MCC: 0.3128
# Epoch 25/200, Train Loss: 0.3446, Train ACC: 0.86, Train MCC: 0.7244, Val Loss: 0.6141, Val ACC: 0.67, Val MCC: 0.3128
# Epoch 26/200, Train Loss: 0.4685, Train ACC: 0.82, Train MCC: 0.6094, Val Loss: 0.6167, Val ACC: 0.67, Val MCC: 0.3128
# Epoch 27/200, Train Loss: 0.3926, Train ACC: 0.82, Train MCC: 0.6291, Val Loss: 0.6181, Val ACC: 0.67, Val MCC: 0.3128
# Epoch 28/200, Train Loss: 0.3901, Train ACC: 0.78, Train MCC: 0.5622, Val Loss: 0.6169, Val ACC: 0.67, Val MCC: 0.3128
# Epoch 29/200, Train Loss: 0.4009, Train ACC: 0.83, Train MCC: 0.6489, Val Loss: 0.6156, Val ACC: 0.67, Val MCC: 0.3128
# Epoch 30/200, Train Loss: 0.3926, Train ACC: 0.79, Train MCC: 0.5908, Val Loss: 0.6123, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 31/200, Train Loss: 0.3418, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.6117, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 32/200, Train Loss: 0.3980, Train ACC: 0.80, Train MCC: 0.6097, Val Loss: 0.6112, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 33/200, Train Loss: 0.3613, Train ACC: 0.83, Train MCC: 0.6573, Val Loss: 0.6105, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 34/200, Train Loss: 0.3561, Train ACC: 0.82, Train MCC: 0.6291, Val Loss: 0.6098, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 35/200, Train Loss: 0.3614, Train ACC: 0.84, Train MCC: 0.6767, Val Loss: 0.6091, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 36/200, Train Loss: 0.3192, Train ACC: 0.89, Train MCC: 0.7720, Val Loss: 0.6087, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 37/200, Train Loss: 0.2774, Train ACC: 0.86, Train MCC: 0.7113, Val Loss: 0.6084, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 38/200, Train Loss: 0.3618, Train ACC: 0.87, Train MCC: 0.7523, Val Loss: 0.6080, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 39/200, Train Loss: 0.4121, Train ACC: 0.79, Train MCC: 0.5664, Val Loss: 0.6077, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 40/200, Train Loss: 0.3720, Train ACC: 0.83, Train MCC: 0.6419, Val Loss: 0.6078, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 41/200, Train Loss: 0.4128, Train ACC: 0.75, Train MCC: 0.5310, Val Loss: 0.6078, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 42/200, Train Loss: 0.3421, Train ACC: 0.83, Train MCC: 0.6419, Val Loss: 0.6077, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 43/200, Train Loss: 0.3632, Train ACC: 0.86, Train MCC: 0.7331, Val Loss: 0.6077, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 44/200, Train Loss: 0.3943, Train ACC: 0.82, Train MCC: 0.6291, Val Loss: 0.6077, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 45/200, Train Loss: 0.4237, Train ACC: 0.77, Train MCC: 0.5433, Val Loss: 0.6077, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 46/200, Train Loss: 0.3018, Train ACC: 0.86, Train MCC: 0.7244, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 47/200, Train Loss: 0.3264, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 48/200, Train Loss: 0.3478, Train ACC: 0.83, Train MCC: 0.6489, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 49/200, Train Loss: 0.3183, Train ACC: 0.83, Train MCC: 0.6489, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 50/200, Train Loss: 0.3758, Train ACC: 0.85, Train MCC: 0.6900, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 51/200, Train Loss: 0.3855, Train ACC: 0.80, Train MCC: 0.6011, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 52/200, Train Loss: 0.3667, Train ACC: 0.87, Train MCC: 0.7444, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 53/200, Train Loss: 0.2983, Train ACC: 0.90, Train MCC: 0.7922, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 54/200, Train Loss: 0.3713, Train ACC: 0.87, Train MCC: 0.7381, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 55/200, Train Loss: 0.3617, Train ACC: 0.84, Train MCC: 0.6630, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 56/200, Train Loss: 0.3703, Train ACC: 0.85, Train MCC: 0.6847, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 57/200, Train Loss: 0.3551, Train ACC: 0.86, Train MCC: 0.7244, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 58/200, Train Loss: 0.3451, Train ACC: 0.80, Train MCC: 0.6011, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 59/200, Train Loss: 0.3588, Train ACC: 0.85, Train MCC: 0.6847, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 60/200, Train Loss: 0.3577, Train ACC: 0.86, Train MCC: 0.7171, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 61/200, Train Loss: 0.3626, Train ACC: 0.86, Train MCC: 0.7113, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 62/200, Train Loss: 0.3712, Train ACC: 0.83, Train MCC: 0.6489, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 63/200, Train Loss: 0.4233, Train ACC: 0.85, Train MCC: 0.7048, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 64/200, Train Loss: 0.4102, Train ACC: 0.80, Train MCC: 0.6011, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 65/200, Train Loss: 0.3311, Train ACC: 0.85, Train MCC: 0.6900, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 66/200, Train Loss: 0.3136, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 67/200, Train Loss: 0.3320, Train ACC: 0.86, Train MCC: 0.7331, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 68/200, Train Loss: 0.2995, Train ACC: 0.92, Train MCC: 0.8399, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 69/200, Train Loss: 0.3358, Train ACC: 0.84, Train MCC: 0.6857, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 70/200, Train Loss: 0.3650, Train ACC: 0.82, Train MCC: 0.6291, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 71/200, Train Loss: 0.3988, Train ACC: 0.80, Train MCC: 0.6011, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 72/200, Train Loss: 0.3309, Train ACC: 0.87, Train MCC: 0.7523, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 73/200, Train Loss: 0.3782, Train ACC: 0.86, Train MCC: 0.7331, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 74/200, Train Loss: 0.4134, Train ACC: 0.79, Train MCC: 0.5664, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 75/200, Train Loss: 0.4426, Train ACC: 0.85, Train MCC: 0.6788, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 76/200, Train Loss: 0.4164, Train ACC: 0.82, Train MCC: 0.6291, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 77/200, Train Loss: 0.4293, Train ACC: 0.82, Train MCC: 0.6291, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 78/200, Train Loss: 0.2889, Train ACC: 0.85, Train MCC: 0.7144, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 79/200, Train Loss: 0.4068, Train ACC: 0.80, Train MCC: 0.5938, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 80/200, Train Loss: 0.3497, Train ACC: 0.89, Train MCC: 0.7720, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 81/200, Train Loss: 0.3864, Train ACC: 0.82, Train MCC: 0.6382, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 82/200, Train Loss: 0.3788, Train ACC: 0.80, Train MCC: 0.6011, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 83/200, Train Loss: 0.3844, Train ACC: 0.77, Train MCC: 0.5338, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 84/200, Train Loss: 0.3756, Train ACC: 0.82, Train MCC: 0.6382, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 85/200, Train Loss: 0.3701, Train ACC: 0.83, Train MCC: 0.6362, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 86/200, Train Loss: 0.3519, Train ACC: 0.86, Train MCC: 0.7113, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 87/200, Train Loss: 0.3305, Train ACC: 0.87, Train MCC: 0.7381, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 88/200, Train Loss: 0.3634, Train ACC: 0.86, Train MCC: 0.7113, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 89/200, Train Loss: 0.3277, Train ACC: 0.87, Train MCC: 0.7523, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 90/200, Train Loss: 0.3470, Train ACC: 0.82, Train MCC: 0.6147, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 91/200, Train Loss: 0.3864, Train ACC: 0.85, Train MCC: 0.6900, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 92/200, Train Loss: 0.4125, Train ACC: 0.82, Train MCC: 0.6291, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 93/200, Train Loss: 0.4178, Train ACC: 0.82, Train MCC: 0.6291, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 94/200, Train Loss: 0.4235, Train ACC: 0.78, Train MCC: 0.5457, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 95/200, Train Loss: 0.4585, Train ACC: 0.76, Train MCC: 0.5147, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 96/200, Train Loss: 0.3066, Train ACC: 0.92, Train MCC: 0.8399, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 97/200, Train Loss: 0.4020, Train ACC: 0.77, Train MCC: 0.5254, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 98/200, Train Loss: 0.3949, Train ACC: 0.83, Train MCC: 0.6319, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 99/200, Train Loss: 0.3954, Train ACC: 0.80, Train MCC: 0.6097, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 100/200, Train Loss: 0.3264, Train ACC: 0.82, Train MCC: 0.6382, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 101/200, Train Loss: 0.4102, Train ACC: 0.79, Train MCC: 0.5815, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 102/200, Train Loss: 0.3925, Train ACC: 0.85, Train MCC: 0.6788, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 103/200, Train Loss: 0.4001, Train ACC: 0.83, Train MCC: 0.6489, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 104/200, Train Loss: 0.3407, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 105/200, Train Loss: 0.3288, Train ACC: 0.86, Train MCC: 0.7244, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 106/200, Train Loss: 0.3286, Train ACC: 0.89, Train MCC: 0.7650, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 107/200, Train Loss: 0.3758, Train ACC: 0.82, Train MCC: 0.6213, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 108/200, Train Loss: 0.3765, Train ACC: 0.84, Train MCC: 0.6767, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 109/200, Train Loss: 0.3911, Train ACC: 0.80, Train MCC: 0.5938, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 110/200, Train Loss: 0.2937, Train ACC: 0.91, Train MCC: 0.8079, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 111/200, Train Loss: 0.3949, Train ACC: 0.80, Train MCC: 0.6097, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 112/200, Train Loss: 0.4030, Train ACC: 0.79, Train MCC: 0.5815, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 113/200, Train Loss: 0.3583, Train ACC: 0.84, Train MCC: 0.6857, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 114/200, Train Loss: 0.3332, Train ACC: 0.91, Train MCC: 0.8079, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 115/200, Train Loss: 0.3768, Train ACC: 0.84, Train MCC: 0.6692, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 116/200, Train Loss: 0.3921, Train ACC: 0.83, Train MCC: 0.6670, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 117/200, Train Loss: 0.3685, Train ACC: 0.83, Train MCC: 0.6489, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 118/200, Train Loss: 0.3286, Train ACC: 0.86, Train MCC: 0.7171, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 119/200, Train Loss: 0.3594, Train ACC: 0.84, Train MCC: 0.6767, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 120/200, Train Loss: 0.3903, Train ACC: 0.83, Train MCC: 0.6362, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 121/200, Train Loss: 0.3659, Train ACC: 0.82, Train MCC: 0.6382, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 122/200, Train Loss: 0.3670, Train ACC: 0.84, Train MCC: 0.6692, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 123/200, Train Loss: 0.3830, Train ACC: 0.82, Train MCC: 0.6213, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 124/200, Train Loss: 0.3702, Train ACC: 0.82, Train MCC: 0.6382, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 125/200, Train Loss: 0.3709, Train ACC: 0.85, Train MCC: 0.7048, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 126/200, Train Loss: 0.3885, Train ACC: 0.87, Train MCC: 0.7333, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 127/200, Train Loss: 0.4045, Train ACC: 0.84, Train MCC: 0.6692, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 128/200, Train Loss: 0.4141, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 129/200, Train Loss: 0.3536, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 130/200, Train Loss: 0.4684, Train ACC: 0.72, Train MCC: 0.4484, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 131/200, Train Loss: 0.3517, Train ACC: 0.85, Train MCC: 0.6847, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 132/200, Train Loss: 0.4086, Train ACC: 0.79, Train MCC: 0.5815, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 133/200, Train Loss: 0.3625, Train ACC: 0.80, Train MCC: 0.6307, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 134/200, Train Loss: 0.3539, Train ACC: 0.83, Train MCC: 0.6489, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 135/200, Train Loss: 0.4087, Train ACC: 0.85, Train MCC: 0.6847, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 136/200, Train Loss: 0.3763, Train ACC: 0.84, Train MCC: 0.6692, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 137/200, Train Loss: 0.3492, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 138/200, Train Loss: 0.3243, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 139/200, Train Loss: 0.3478, Train ACC: 0.84, Train MCC: 0.6630, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 140/200, Train Loss: 0.4037, Train ACC: 0.80, Train MCC: 0.6097, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 141/200, Train Loss: 0.3896, Train ACC: 0.80, Train MCC: 0.5938, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 142/200, Train Loss: 0.4912, Train ACC: 0.76, Train MCC: 0.4976, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 143/200, Train Loss: 0.3703, Train ACC: 0.85, Train MCC: 0.7048, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 144/200, Train Loss: 0.3925, Train ACC: 0.82, Train MCC: 0.6382, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 145/200, Train Loss: 0.3682, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 146/200, Train Loss: 0.3734, Train ACC: 0.80, Train MCC: 0.5938, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 147/200, Train Loss: 0.4025, Train ACC: 0.85, Train MCC: 0.6900, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 148/200, Train Loss: 0.3532, Train ACC: 0.83, Train MCC: 0.6419, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 149/200, Train Loss: 0.3301, Train ACC: 0.84, Train MCC: 0.6857, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 150/200, Train Loss: 0.3515, Train ACC: 0.84, Train MCC: 0.6767, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 151/200, Train Loss: 0.3352, Train ACC: 0.84, Train MCC: 0.6857, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 152/200, Train Loss: 0.3569, Train ACC: 0.84, Train MCC: 0.6960, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 153/200, Train Loss: 0.3163, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 154/200, Train Loss: 0.3753, Train ACC: 0.85, Train MCC: 0.6900, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 155/200, Train Loss: 0.3509, Train ACC: 0.86, Train MCC: 0.7244, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 156/200, Train Loss: 0.3247, Train ACC: 0.85, Train MCC: 0.7144, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 157/200, Train Loss: 0.4212, Train ACC: 0.84, Train MCC: 0.6630, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 158/200, Train Loss: 0.3725, Train ACC: 0.82, Train MCC: 0.6291, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 159/200, Train Loss: 0.3461, Train ACC: 0.86, Train MCC: 0.7331, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 160/200, Train Loss: 0.3857, Train ACC: 0.83, Train MCC: 0.6489, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 161/200, Train Loss: 0.3840, Train ACC: 0.82, Train MCC: 0.6094, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 162/200, Train Loss: 0.3334, Train ACC: 0.90, Train MCC: 0.7818, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 163/200, Train Loss: 0.3128, Train ACC: 0.89, Train MCC: 0.7650, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 164/200, Train Loss: 0.3422, Train ACC: 0.87, Train MCC: 0.7381, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 165/200, Train Loss: 0.3789, Train ACC: 0.83, Train MCC: 0.6419, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 166/200, Train Loss: 0.3792, Train ACC: 0.82, Train MCC: 0.6094, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 167/200, Train Loss: 0.3237, Train ACC: 0.86, Train MCC: 0.7113, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 168/200, Train Loss: 0.3106, Train ACC: 0.89, Train MCC: 0.7650, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 169/200, Train Loss: 0.3664, Train ACC: 0.84, Train MCC: 0.6630, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 170/200, Train Loss: 0.3899, Train ACC: 0.86, Train MCC: 0.7244, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 171/200, Train Loss: 0.3252, Train ACC: 0.89, Train MCC: 0.7720, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 172/200, Train Loss: 0.3851, Train ACC: 0.83, Train MCC: 0.6419, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 173/200, Train Loss: 0.3986, Train ACC: 0.80, Train MCC: 0.6097, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 174/200, Train Loss: 0.3813, Train ACC: 0.82, Train MCC: 0.6291, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 175/200, Train Loss: 0.3461, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 176/200, Train Loss: 0.3528, Train ACC: 0.85, Train MCC: 0.7048, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 177/200, Train Loss: 0.4067, Train ACC: 0.75, Train MCC: 0.4862, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 178/200, Train Loss: 0.3851, Train ACC: 0.87, Train MCC: 0.7444, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 179/200, Train Loss: 0.3756, Train ACC: 0.84, Train MCC: 0.6582, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 180/200, Train Loss: 0.4181, Train ACC: 0.80, Train MCC: 0.6195, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 181/200, Train Loss: 0.3485, Train ACC: 0.83, Train MCC: 0.6670, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 182/200, Train Loss: 0.4213, Train ACC: 0.80, Train MCC: 0.5938, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 183/200, Train Loss: 0.3882, Train ACC: 0.84, Train MCC: 0.6857, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 184/200, Train Loss: 0.3386, Train ACC: 0.84, Train MCC: 0.6582, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 185/200, Train Loss: 0.3590, Train ACC: 0.86, Train MCC: 0.7113, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 186/200, Train Loss: 0.3400, Train ACC: 0.85, Train MCC: 0.6847, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 187/200, Train Loss: 0.3099, Train ACC: 0.89, Train MCC: 0.7720, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 188/200, Train Loss: 0.3137, Train ACC: 0.82, Train MCC: 0.6291, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 189/200, Train Loss: 0.3686, Train ACC: 0.82, Train MCC: 0.6147, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 190/200, Train Loss: 0.3729, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 191/200, Train Loss: 0.3677, Train ACC: 0.84, Train MCC: 0.6692, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 192/200, Train Loss: 0.4215, Train ACC: 0.78, Train MCC: 0.5391, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 193/200, Train Loss: 0.4034, Train ACC: 0.83, Train MCC: 0.6419, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 194/200, Train Loss: 0.3657, Train ACC: 0.84, Train MCC: 0.6960, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 195/200, Train Loss: 0.3589, Train ACC: 0.79, Train MCC: 0.5733, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 196/200, Train Loss: 0.3114, Train ACC: 0.89, Train MCC: 0.7596, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 197/200, Train Loss: 0.3894, Train ACC: 0.79, Train MCC: 0.6130, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 198/200, Train Loss: 0.4369, Train ACC: 0.77, Train MCC: 0.5433, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 199/200, Train Loss: 0.4180, Train ACC: 0.82, Train MCC: 0.6213, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 200/200, Train Loss: 0.3770, Train ACC: 0.84, Train MCC: 0.6857, Val Loss: 0.6076, Val ACC: 0.62, Val MCC: 0.1393

# %%
model = vgg19
model.eval()
# 加载测试数据集
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_csv_file = "/local/data1/honzh/local_repository/FL/code/4_federated/csv_files/test_data.csv"

test_dataset = CustomDatasetCSV(csv_file=test_csv_file, transform=test_transform)

test_model(model, test_dataset)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.73      0.81      2271
#            1       0.34      0.67      0.45       490
#
#     accuracy                           0.71      2761
#    macro avg       0.63      0.70      0.63      2761
# weighted avg       0.81      0.71      0.74      2761
# {'Total Acc': 0.715,
#  'nff Acc': 0.725,
#  'aff Acc': 0.667,
#  'Precision': 0.344,
#  'Recall': 0.667,
#  'Accuracy': 0.715,
#  'AUC': 0.696,
#  'MCC': 0.316,
#  'F1 Score': 0.454,
#  'ROC_AUC': 0.696,
#  'PRC-AUC': 0.289}

# %% [markdown]
# # ResNet50 50% freezed

# %%
from torchvision.models import resnet50, ResNet50_Weights
from torchvision import transforms, models

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

model = models.resnet50(weights=ResNet50_Weights.DEFAULT)

num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)

# layer number
total_layers = len(list(model.children()))

# freeze 50% layer
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False

# modify full connection layer
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)

#---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 200
batch_size = 32
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

res50 = train_custom_model(model, train_dataset,val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/200, Train Loss: 0.6834, Train ACC: 0.55, Train MCC: 0.1859, Val Loss: 0.7011, Val ACC: 0.38, Val MCC: 0.1216
# Epoch 2/200, Train Loss: 0.6651, Train ACC: 0.63, Train MCC: 0.3201, Val Loss: 0.6835, Val ACC: 0.46, Val MCC: 0.1370
# Epoch 3/200, Train Loss: 0.6557, Train ACC: 0.69, Train MCC: 0.3721, Val Loss: 0.6776, Val ACC: 0.44, Val MCC: -0.0186
# Epoch 4/200, Train Loss: 0.6364, Train ACC: 0.67, Train MCC: 0.3464, Val Loss: 0.6710, Val ACC: 0.44, Val MCC: -0.0186
# Epoch 5/200, Train Loss: 0.6641, Train ACC: 0.62, Train MCC: 0.2295, Val Loss: 0.6627, Val ACC: 0.49, Val MCC: 0.0425
# Epoch 6/200, Train Loss: 0.6127, Train ACC: 0.74, Train MCC: 0.4420, Val Loss: 0.6564, Val ACC: 0.49, Val MCC: 0.0425
# Epoch 7/200, Train Loss: 0.5931, Train ACC: 0.72, Train MCC: 0.4296, Val Loss: 0.6710, Val ACC: 0.49, Val MCC: 0.0425
# Epoch 8/200, Train Loss: 0.5772, Train ACC: 0.74, Train MCC: 0.4420, Val Loss: 0.6873, Val ACC: 0.49, Val MCC: 0.0425
# Epoch 9/200, Train Loss: 0.5570, Train ACC: 0.72, Train MCC: 0.4296, Val Loss: 0.6682, Val ACC: 0.49, Val MCC: 0.0425
# Epoch 10/200, Train Loss: 0.4972, Train ACC: 0.76, Train MCC: 0.5056, Val Loss: 0.6583, Val ACC: 0.49, Val MCC: 0.0425
# Epoch 11/200, Train Loss: 0.4627, Train ACC: 0.79, Train MCC: 0.5815, Val Loss: 0.6654, Val ACC: 0.49, Val MCC: 0.0425
# Epoch 12/200, Train Loss: 0.4758, Train ACC: 0.76, Train MCC: 0.5359, Val Loss: 0.6636, Val ACC: 0.49, Val MCC: 0.0425
# Epoch 13/200, Train Loss: 0.5179, Train ACC: 0.78, Train MCC: 0.5391, Val Loss: 0.6617, Val ACC: 0.49, Val MCC: 0.0425
# Epoch 14/200, Train Loss: 0.4612, Train ACC: 0.79, Train MCC: 0.5815, Val Loss: 0.6620, Val ACC: 0.51, Val MCC: 0.0725
# Epoch 15/200, Train Loss: 0.4397, Train ACC: 0.84, Train MCC: 0.6630, Val Loss: 0.6744, Val ACC: 0.51, Val MCC: 0.0725
# Epoch 16/200, Train Loss: 0.5106, Train ACC: 0.75, Train MCC: 0.4958, Val Loss: 0.6753, Val ACC: 0.51, Val MCC: 0.0725
# Epoch 17/200, Train Loss: 0.5163, Train ACC: 0.76, Train MCC: 0.5247, Val Loss: 0.7072, Val ACC: 0.49, Val MCC: 0.0425
# Epoch 18/200, Train Loss: 0.4500, Train ACC: 0.80, Train MCC: 0.5876, Val Loss: 0.7200, Val ACC: 0.49, Val MCC: 0.0425
# Epoch 19/200, Train Loss: 0.4609, Train ACC: 0.83, Train MCC: 0.6489, Val Loss: 0.7309, Val ACC: 0.49, Val MCC: 0.0425
# Epoch 20/200, Train Loss: 0.4696, Train ACC: 0.83, Train MCC: 0.6489, Val Loss: 0.7400, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 21/200, Train Loss: 0.4501, Train ACC: 0.80, Train MCC: 0.6195, Val Loss: 0.7600, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 22/200, Train Loss: 0.4480, Train ACC: 0.79, Train MCC: 0.5606, Val Loss: 0.7634, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 23/200, Train Loss: 0.5034, Train ACC: 0.80, Train MCC: 0.6011, Val Loss: 0.7699, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 24/200, Train Loss: 0.4520, Train ACC: 0.80, Train MCC: 0.6011, Val Loss: 0.7935, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 25/200, Train Loss: 0.4840, Train ACC: 0.79, Train MCC: 0.5664, Val Loss: 0.7912, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 26/200, Train Loss: 0.4543, Train ACC: 0.80, Train MCC: 0.5938, Val Loss: 0.7745, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 27/200, Train Loss: 0.4628, Train ACC: 0.85, Train MCC: 0.6847, Val Loss: 0.7741, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 28/200, Train Loss: 0.4578, Train ACC: 0.83, Train MCC: 0.6319, Val Loss: 0.7897, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 29/200, Train Loss: 0.4249, Train ACC: 0.79, Train MCC: 0.6012, Val Loss: 0.7790, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 30/200, Train Loss: 0.4976, Train ACC: 0.78, Train MCC: 0.5457, Val Loss: 0.7779, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 31/200, Train Loss: 0.4467, Train ACC: 0.78, Train MCC: 0.5457, Val Loss: 0.7766, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 32/200, Train Loss: 0.4422, Train ACC: 0.82, Train MCC: 0.6213, Val Loss: 0.7744, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 33/200, Train Loss: 0.4293, Train ACC: 0.86, Train MCC: 0.7171, Val Loss: 0.7713, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 34/200, Train Loss: 0.4739, Train ACC: 0.78, Train MCC: 0.5534, Val Loss: 0.7739, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 35/200, Train Loss: 0.4157, Train ACC: 0.89, Train MCC: 0.7720, Val Loss: 0.7652, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 36/200, Train Loss: 0.4776, Train ACC: 0.82, Train MCC: 0.6382, Val Loss: 0.7566, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 37/200, Train Loss: 0.4508, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.7410, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 38/200, Train Loss: 0.4219, Train ACC: 0.84, Train MCC: 0.6767, Val Loss: 0.7368, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 39/200, Train Loss: 0.4763, Train ACC: 0.78, Train MCC: 0.5534, Val Loss: 0.7459, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 40/200, Train Loss: 0.4230, Train ACC: 0.83, Train MCC: 0.6489, Val Loss: 0.7514, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 41/200, Train Loss: 0.4355, Train ACC: 0.84, Train MCC: 0.6692, Val Loss: 0.7437, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 42/200, Train Loss: 0.4350, Train ACC: 0.82, Train MCC: 0.6147, Val Loss: 0.7403, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 43/200, Train Loss: 0.4275, Train ACC: 0.83, Train MCC: 0.6419, Val Loss: 0.7283, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 44/200, Train Loss: 0.4566, Train ACC: 0.85, Train MCC: 0.6900, Val Loss: 0.7435, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 45/200, Train Loss: 0.4688, Train ACC: 0.79, Train MCC: 0.5908, Val Loss: 0.7430, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 46/200, Train Loss: 0.4894, Train ACC: 0.83, Train MCC: 0.6489, Val Loss: 0.7506, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 47/200, Train Loss: 0.4949, Train ACC: 0.82, Train MCC: 0.6213, Val Loss: 0.7580, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 48/200, Train Loss: 0.4209, Train ACC: 0.89, Train MCC: 0.7596, Val Loss: 0.7567, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 49/200, Train Loss: 0.4266, Train ACC: 0.86, Train MCC: 0.7171, Val Loss: 0.7478, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 50/200, Train Loss: 0.4356, Train ACC: 0.80, Train MCC: 0.6097, Val Loss: 0.7366, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 51/200, Train Loss: 0.4836, Train ACC: 0.82, Train MCC: 0.6213, Val Loss: 0.7543, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 52/200, Train Loss: 0.4541, Train ACC: 0.79, Train MCC: 0.5664, Val Loss: 0.7606, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 53/200, Train Loss: 0.4450, Train ACC: 0.82, Train MCC: 0.6213, Val Loss: 0.7612, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 54/200, Train Loss: 0.4265, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.7529, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 55/200, Train Loss: 0.4503, Train ACC: 0.80, Train MCC: 0.6097, Val Loss: 0.7592, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 56/200, Train Loss: 0.4534, Train ACC: 0.79, Train MCC: 0.5908, Val Loss: 0.7477, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 57/200, Train Loss: 0.4680, Train ACC: 0.83, Train MCC: 0.6489, Val Loss: 0.7496, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 58/200, Train Loss: 0.4806, Train ACC: 0.82, Train MCC: 0.6291, Val Loss: 0.7486, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 59/200, Train Loss: 0.4658, Train ACC: 0.76, Train MCC: 0.4905, Val Loss: 0.7506, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 60/200, Train Loss: 0.4098, Train ACC: 0.85, Train MCC: 0.6900, Val Loss: 0.7501, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 61/200, Train Loss: 0.4081, Train ACC: 0.89, Train MCC: 0.7559, Val Loss: 0.7536, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 62/200, Train Loss: 0.4221, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.7428, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 63/200, Train Loss: 0.5119, Train ACC: 0.69, Train MCC: 0.3721, Val Loss: 0.7494, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 64/200, Train Loss: 0.4181, Train ACC: 0.83, Train MCC: 0.6489, Val Loss: 0.7410, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 65/200, Train Loss: 0.4699, Train ACC: 0.77, Train MCC: 0.5254, Val Loss: 0.7463, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 66/200, Train Loss: 0.4302, Train ACC: 0.79, Train MCC: 0.5815, Val Loss: 0.7500, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 67/200, Train Loss: 0.4769, Train ACC: 0.80, Train MCC: 0.6097, Val Loss: 0.7475, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 68/200, Train Loss: 0.4790, Train ACC: 0.83, Train MCC: 0.6573, Val Loss: 0.7447, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 69/200, Train Loss: 0.4448, Train ACC: 0.80, Train MCC: 0.5938, Val Loss: 0.7484, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 70/200, Train Loss: 0.4867, Train ACC: 0.80, Train MCC: 0.6097, Val Loss: 0.7493, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 71/200, Train Loss: 0.4393, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.7566, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 72/200, Train Loss: 0.4483, Train ACC: 0.76, Train MCC: 0.4976, Val Loss: 0.7680, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 73/200, Train Loss: 0.4503, Train ACC: 0.85, Train MCC: 0.6847, Val Loss: 0.7611, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 74/200, Train Loss: 0.4434, Train ACC: 0.82, Train MCC: 0.6213, Val Loss: 0.7544, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 75/200, Train Loss: 0.4429, Train ACC: 0.80, Train MCC: 0.5876, Val Loss: 0.7380, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 76/200, Train Loss: 0.5146, Train ACC: 0.75, Train MCC: 0.4958, Val Loss: 0.7354, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 77/200, Train Loss: 0.4768, Train ACC: 0.80, Train MCC: 0.6011, Val Loss: 0.7398, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 78/200, Train Loss: 0.4445, Train ACC: 0.79, Train MCC: 0.5664, Val Loss: 0.7340, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 79/200, Train Loss: 0.4415, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.7399, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 80/200, Train Loss: 0.4589, Train ACC: 0.78, Train MCC: 0.5622, Val Loss: 0.7405, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 81/200, Train Loss: 0.4469, Train ACC: 0.80, Train MCC: 0.5938, Val Loss: 0.7410, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 82/200, Train Loss: 0.4952, Train ACC: 0.78, Train MCC: 0.5534, Val Loss: 0.7454, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 83/200, Train Loss: 0.4119, Train ACC: 0.83, Train MCC: 0.6419, Val Loss: 0.7435, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 84/200, Train Loss: 0.4649, Train ACC: 0.75, Train MCC: 0.4698, Val Loss: 0.7344, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 85/200, Train Loss: 0.4444, Train ACC: 0.80, Train MCC: 0.6097, Val Loss: 0.7361, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 86/200, Train Loss: 0.4146, Train ACC: 0.84, Train MCC: 0.6630, Val Loss: 0.7445, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 87/200, Train Loss: 0.4401, Train ACC: 0.85, Train MCC: 0.7048, Val Loss: 0.7458, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 88/200, Train Loss: 0.4430, Train ACC: 0.76, Train MCC: 0.4976, Val Loss: 0.7473, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 89/200, Train Loss: 0.4850, Train ACC: 0.77, Train MCC: 0.5254, Val Loss: 0.7449, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 90/200, Train Loss: 0.4202, Train ACC: 0.83, Train MCC: 0.6780, Val Loss: 0.7382, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 91/200, Train Loss: 0.4169, Train ACC: 0.85, Train MCC: 0.6847, Val Loss: 0.7359, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 92/200, Train Loss: 0.4221, Train ACC: 0.84, Train MCC: 0.6767, Val Loss: 0.7461, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 93/200, Train Loss: 0.4192, Train ACC: 0.84, Train MCC: 0.6692, Val Loss: 0.7354, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 94/200, Train Loss: 0.5295, Train ACC: 0.75, Train MCC: 0.4698, Val Loss: 0.7363, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 95/200, Train Loss: 0.4143, Train ACC: 0.86, Train MCC: 0.7171, Val Loss: 0.7462, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 96/200, Train Loss: 0.4501, Train ACC: 0.83, Train MCC: 0.6362, Val Loss: 0.7441, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 97/200, Train Loss: 0.4518, Train ACC: 0.83, Train MCC: 0.6489, Val Loss: 0.7402, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 98/200, Train Loss: 0.4789, Train ACC: 0.76, Train MCC: 0.4905, Val Loss: 0.7405, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 99/200, Train Loss: 0.3794, Train ACC: 0.91, Train MCC: 0.8079, Val Loss: 0.7388, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 100/200, Train Loss: 0.4339, Train ACC: 0.82, Train MCC: 0.6291, Val Loss: 0.7295, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 101/200, Train Loss: 0.4617, Train ACC: 0.80, Train MCC: 0.5827, Val Loss: 0.7388, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 102/200, Train Loss: 0.4396, Train ACC: 0.83, Train MCC: 0.6573, Val Loss: 0.7372, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 103/200, Train Loss: 0.4301, Train ACC: 0.86, Train MCC: 0.7244, Val Loss: 0.7433, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 104/200, Train Loss: 0.4490, Train ACC: 0.79, Train MCC: 0.5664, Val Loss: 0.7322, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 105/200, Train Loss: 0.4873, Train ACC: 0.80, Train MCC: 0.5938, Val Loss: 0.7316, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 106/200, Train Loss: 0.4682, Train ACC: 0.78, Train MCC: 0.5622, Val Loss: 0.7336, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 107/200, Train Loss: 0.5324, Train ACC: 0.77, Train MCC: 0.5254, Val Loss: 0.7477, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 108/200, Train Loss: 0.4667, Train ACC: 0.87, Train MCC: 0.7381, Val Loss: 0.7527, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 109/200, Train Loss: 0.4700, Train ACC: 0.77, Train MCC: 0.5433, Val Loss: 0.7520, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 110/200, Train Loss: 0.4447, Train ACC: 0.82, Train MCC: 0.6147, Val Loss: 0.7518, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 111/200, Train Loss: 0.4594, Train ACC: 0.82, Train MCC: 0.6213, Val Loss: 0.7469, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 112/200, Train Loss: 0.4673, Train ACC: 0.77, Train MCC: 0.5433, Val Loss: 0.7358, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 113/200, Train Loss: 0.4239, Train ACC: 0.84, Train MCC: 0.6692, Val Loss: 0.7525, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 114/200, Train Loss: 0.4918, Train ACC: 0.75, Train MCC: 0.4958, Val Loss: 0.7577, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 115/200, Train Loss: 0.4788, Train ACC: 0.77, Train MCC: 0.5539, Val Loss: 0.7531, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 116/200, Train Loss: 0.4458, Train ACC: 0.84, Train MCC: 0.6767, Val Loss: 0.7380, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 117/200, Train Loss: 0.4177, Train ACC: 0.84, Train MCC: 0.6857, Val Loss: 0.7345, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 118/200, Train Loss: 0.4627, Train ACC: 0.75, Train MCC: 0.5065, Val Loss: 0.7407, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 119/200, Train Loss: 0.4290, Train ACC: 0.80, Train MCC: 0.6097, Val Loss: 0.7440, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 120/200, Train Loss: 0.4821, Train ACC: 0.80, Train MCC: 0.6011, Val Loss: 0.7538, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 121/200, Train Loss: 0.4687, Train ACC: 0.77, Train MCC: 0.5254, Val Loss: 0.7559, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 122/200, Train Loss: 0.4716, Train ACC: 0.84, Train MCC: 0.6857, Val Loss: 0.7595, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 123/200, Train Loss: 0.4683, Train ACC: 0.79, Train MCC: 0.5733, Val Loss: 0.7409, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 124/200, Train Loss: 0.4794, Train ACC: 0.78, Train MCC: 0.5622, Val Loss: 0.7367, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 125/200, Train Loss: 0.4486, Train ACC: 0.80, Train MCC: 0.6097, Val Loss: 0.7203, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 126/200, Train Loss: 0.4332, Train ACC: 0.86, Train MCC: 0.7113, Val Loss: 0.7222, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 127/200, Train Loss: 0.4604, Train ACC: 0.84, Train MCC: 0.6767, Val Loss: 0.7249, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 128/200, Train Loss: 0.4776, Train ACC: 0.78, Train MCC: 0.5534, Val Loss: 0.7379, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 129/200, Train Loss: 0.4454, Train ACC: 0.83, Train MCC: 0.6670, Val Loss: 0.7384, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 130/200, Train Loss: 0.4351, Train ACC: 0.84, Train MCC: 0.6630, Val Loss: 0.7382, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 131/200, Train Loss: 0.4332, Train ACC: 0.80, Train MCC: 0.5876, Val Loss: 0.7415, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 132/200, Train Loss: 0.4560, Train ACC: 0.80, Train MCC: 0.6195, Val Loss: 0.7353, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 133/200, Train Loss: 0.4694, Train ACC: 0.78, Train MCC: 0.5457, Val Loss: 0.7427, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 134/200, Train Loss: 0.4519, Train ACC: 0.76, Train MCC: 0.4976, Val Loss: 0.7558, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 135/200, Train Loss: 0.4507, Train ACC: 0.77, Train MCC: 0.5338, Val Loss: 0.7559, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 136/200, Train Loss: 0.4197, Train ACC: 0.86, Train MCC: 0.7171, Val Loss: 0.7465, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 137/200, Train Loss: 0.4800, Train ACC: 0.76, Train MCC: 0.4976, Val Loss: 0.7355, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 138/200, Train Loss: 0.4200, Train ACC: 0.84, Train MCC: 0.6582, Val Loss: 0.7415, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 139/200, Train Loss: 0.4638, Train ACC: 0.77, Train MCC: 0.5254, Val Loss: 0.7535, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 140/200, Train Loss: 0.4711, Train ACC: 0.77, Train MCC: 0.5254, Val Loss: 0.7481, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 141/200, Train Loss: 0.4721, Train ACC: 0.79, Train MCC: 0.5908, Val Loss: 0.7358, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 142/200, Train Loss: 0.4815, Train ACC: 0.79, Train MCC: 0.5606, Val Loss: 0.7397, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 143/200, Train Loss: 0.4630, Train ACC: 0.80, Train MCC: 0.5876, Val Loss: 0.7232, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 144/200, Train Loss: 0.4187, Train ACC: 0.80, Train MCC: 0.6011, Val Loss: 0.7396, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 145/200, Train Loss: 0.4569, Train ACC: 0.76, Train MCC: 0.4976, Val Loss: 0.7332, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 146/200, Train Loss: 0.4459, Train ACC: 0.83, Train MCC: 0.6489, Val Loss: 0.7346, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 147/200, Train Loss: 0.4478, Train ACC: 0.89, Train MCC: 0.7720, Val Loss: 0.7494, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 148/200, Train Loss: 0.4137, Train ACC: 0.85, Train MCC: 0.7048, Val Loss: 0.7526, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 149/200, Train Loss: 0.4307, Train ACC: 0.79, Train MCC: 0.5908, Val Loss: 0.7610, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 150/200, Train Loss: 0.4357, Train ACC: 0.80, Train MCC: 0.5938, Val Loss: 0.7603, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 151/200, Train Loss: 0.4193, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.7635, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 152/200, Train Loss: 0.4737, Train ACC: 0.82, Train MCC: 0.6147, Val Loss: 0.7622, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 153/200, Train Loss: 0.3983, Train ACC: 0.90, Train MCC: 0.7862, Val Loss: 0.7780, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 154/200, Train Loss: 0.4488, Train ACC: 0.78, Train MCC: 0.5534, Val Loss: 0.7716, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 155/200, Train Loss: 0.4650, Train ACC: 0.84, Train MCC: 0.6767, Val Loss: 0.7558, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 156/200, Train Loss: 0.4478, Train ACC: 0.89, Train MCC: 0.7650, Val Loss: 0.7633, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 157/200, Train Loss: 0.4746, Train ACC: 0.77, Train MCC: 0.5433, Val Loss: 0.7631, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 158/200, Train Loss: 0.5013, Train ACC: 0.84, Train MCC: 0.6630, Val Loss: 0.7492, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 159/200, Train Loss: 0.4596, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.7353, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 160/200, Train Loss: 0.4707, Train ACC: 0.79, Train MCC: 0.5664, Val Loss: 0.7404, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 161/200, Train Loss: 0.4692, Train ACC: 0.84, Train MCC: 0.6692, Val Loss: 0.7390, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 162/200, Train Loss: 0.4274, Train ACC: 0.86, Train MCC: 0.7244, Val Loss: 0.7384, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 163/200, Train Loss: 0.4656, Train ACC: 0.79, Train MCC: 0.5733, Val Loss: 0.7494, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 164/200, Train Loss: 0.4775, Train ACC: 0.78, Train MCC: 0.5534, Val Loss: 0.7376, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 165/200, Train Loss: 0.4502, Train ACC: 0.80, Train MCC: 0.6011, Val Loss: 0.7377, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 166/200, Train Loss: 0.4617, Train ACC: 0.78, Train MCC: 0.5457, Val Loss: 0.7313, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 167/200, Train Loss: 0.4726, Train ACC: 0.77, Train MCC: 0.5181, Val Loss: 0.7315, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 168/200, Train Loss: 0.4519, Train ACC: 0.78, Train MCC: 0.5622, Val Loss: 0.7386, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 169/200, Train Loss: 0.4170, Train ACC: 0.86, Train MCC: 0.7434, Val Loss: 0.7346, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 170/200, Train Loss: 0.4457, Train ACC: 0.82, Train MCC: 0.6291, Val Loss: 0.7398, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 171/200, Train Loss: 0.4742, Train ACC: 0.78, Train MCC: 0.5721, Val Loss: 0.7406, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 172/200, Train Loss: 0.5029, Train ACC: 0.78, Train MCC: 0.5534, Val Loss: 0.7329, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 173/200, Train Loss: 0.4589, Train ACC: 0.80, Train MCC: 0.6011, Val Loss: 0.7281, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 174/200, Train Loss: 0.4495, Train ACC: 0.79, Train MCC: 0.5908, Val Loss: 0.7330, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 175/200, Train Loss: 0.4976, Train ACC: 0.78, Train MCC: 0.5534, Val Loss: 0.7299, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 176/200, Train Loss: 0.4387, Train ACC: 0.83, Train MCC: 0.6573, Val Loss: 0.7280, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 177/200, Train Loss: 0.4399, Train ACC: 0.83, Train MCC: 0.6489, Val Loss: 0.7252, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 178/200, Train Loss: 0.4861, Train ACC: 0.78, Train MCC: 0.5391, Val Loss: 0.7266, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 179/200, Train Loss: 0.4184, Train ACC: 0.85, Train MCC: 0.7048, Val Loss: 0.7309, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 180/200, Train Loss: 0.4350, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.7268, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 181/200, Train Loss: 0.4563, Train ACC: 0.79, Train MCC: 0.5908, Val Loss: 0.7366, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 182/200, Train Loss: 0.4678, Train ACC: 0.79, Train MCC: 0.5664, Val Loss: 0.7485, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 183/200, Train Loss: 0.4059, Train ACC: 0.83, Train MCC: 0.6489, Val Loss: 0.7575, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 184/200, Train Loss: 0.4848, Train ACC: 0.79, Train MCC: 0.6012, Val Loss: 0.7488, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 185/200, Train Loss: 0.4301, Train ACC: 0.87, Train MCC: 0.7381, Val Loss: 0.7590, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 186/200, Train Loss: 0.4691, Train ACC: 0.78, Train MCC: 0.5534, Val Loss: 0.7540, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 187/200, Train Loss: 0.4742, Train ACC: 0.83, Train MCC: 0.6573, Val Loss: 0.7453, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 188/200, Train Loss: 0.4328, Train ACC: 0.83, Train MCC: 0.6573, Val Loss: 0.7359, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 189/200, Train Loss: 0.4698, Train ACC: 0.80, Train MCC: 0.5827, Val Loss: 0.7428, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 190/200, Train Loss: 0.4964, Train ACC: 0.76, Train MCC: 0.5056, Val Loss: 0.7521, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 191/200, Train Loss: 0.4508, Train ACC: 0.83, Train MCC: 0.6573, Val Loss: 0.7516, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 192/200, Train Loss: 0.4437, Train ACC: 0.82, Train MCC: 0.6291, Val Loss: 0.7509, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 193/200, Train Loss: 0.4198, Train ACC: 0.80, Train MCC: 0.5938, Val Loss: 0.7443, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 194/200, Train Loss: 0.4246, Train ACC: 0.85, Train MCC: 0.6900, Val Loss: 0.7369, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 195/200, Train Loss: 0.4683, Train ACC: 0.79, Train MCC: 0.5664, Val Loss: 0.7362, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 196/200, Train Loss: 0.4434, Train ACC: 0.77, Train MCC: 0.5338, Val Loss: 0.7191, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 197/200, Train Loss: 0.4414, Train ACC: 0.82, Train MCC: 0.6147, Val Loss: 0.7259, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 198/200, Train Loss: 0.4782, Train ACC: 0.77, Train MCC: 0.5338, Val Loss: 0.7296, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 199/200, Train Loss: 0.4276, Train ACC: 0.82, Train MCC: 0.6213, Val Loss: 0.7331, Val ACC: 0.51, Val MCC: 0.1316
# Epoch 200/200, Train Loss: 0.4352, Train ACC: 0.84, Train MCC: 0.6692, Val Loss: 0.7187, Val ACC: 0.51, Val MCC: 0.1316

# %%
model = res50
model.eval()
# 加载测试数据集
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_csv_file = "/local/data1/honzh/local_repository/FL/code/4_federated/csv_files/test_data.csv"

test_dataset = CustomDatasetCSV(csv_file=test_csv_file, transform=test_transform)

test_model(model, test_dataset)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.50      0.65      2271
#            1       0.26      0.81      0.39       490
#
#     accuracy                           0.55      2761
#    macro avg       0.59      0.65      0.52      2761
# weighted avg       0.81      0.55      0.60      2761
# {'Total Acc': 0.553,
#  'nff Acc': 0.497,
#  'aff Acc': 0.812,
#  'Precision': 0.258,
#  'Recall': 0.812,
#  'Accuracy': 0.553,
#  'AUC': 0.654,
#  'MCC': 0.238,
#  'F1 Score': 0.392,
#  'ROC_AUC': 0.654,
#  'PRC-AUC': 0.243}

# %% [markdown]
# # ResNet 101

# %%
from torchvision.models import resnet101, ResNet101_Weights
from torchvision import transforms, models

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the ResNet-101 model
model = models.resnet101(weights=ResNet101_Weights.DEFAULT)

num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)

# layer number
total_layers = len(list(model.children()))

# freeze 50% layer
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False

# modify full connection layer
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)
#---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 200
batch_size = 32
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

res101 = train_custom_model(model, train_dataset,val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/200, Train Loss: 0.7037, Train ACC: 0.59, Train MCC: -0.0571, Val Loss: 0.6349, Val ACC: 0.69, Val MCC: 0.1931
# Epoch 2/200, Train Loss: 0.6588, Train ACC: 0.71, Train MCC: 0.3611, Val Loss: 0.6057, Val ACC: 0.67, Val MCC: 0.2076
# Epoch 3/200, Train Loss: 0.6643, Train ACC: 0.60, Train MCC: 0.1306, Val Loss: 0.5944, Val ACC: 0.64, Val MCC: 0.1726
# Epoch 4/200, Train Loss: 0.6310, Train ACC: 0.64, Train MCC: 0.3109, Val Loss: 0.5905, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 5/200, Train Loss: 0.6101, Train ACC: 0.72, Train MCC: 0.4296, Val Loss: 0.5734, Val ACC: 0.62, Val MCC: 0.1943
# Epoch 6/200, Train Loss: 0.6070, Train ACC: 0.67, Train MCC: 0.3052, Val Loss: 0.5586, Val ACC: 0.59, Val MCC: 0.1631
# Epoch 7/200, Train Loss: 0.5422, Train ACC: 0.80, Train MCC: 0.6011, Val Loss: 0.5464, Val ACC: 0.59, Val MCC: 0.1631
# Epoch 8/200, Train Loss: 0.4945, Train ACC: 0.83, Train MCC: 0.6670, Val Loss: 0.5297, Val ACC: 0.59, Val MCC: 0.1631
# Epoch 9/200, Train Loss: 0.4572, Train ACC: 0.84, Train MCC: 0.6767, Val Loss: 0.5210, Val ACC: 0.59, Val MCC: 0.1631
# Epoch 10/200, Train Loss: 0.4737, Train ACC: 0.77, Train MCC: 0.5433, Val Loss: 0.5294, Val ACC: 0.59, Val MCC: 0.1631
# Epoch 11/200, Train Loss: 0.4116, Train ACC: 0.76, Train MCC: 0.5147, Val Loss: 0.5172, Val ACC: 0.59, Val MCC: 0.1631
# Epoch 12/200, Train Loss: 0.3880, Train ACC: 0.86, Train MCC: 0.7171, Val Loss: 0.5130, Val ACC: 0.59, Val MCC: 0.1631
# Epoch 13/200, Train Loss: 0.3742, Train ACC: 0.84, Train MCC: 0.6857, Val Loss: 0.5014, Val ACC: 0.59, Val MCC: 0.1631
# Epoch 14/200, Train Loss: 0.3604, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.4959, Val ACC: 0.59, Val MCC: 0.1631
# Epoch 15/200, Train Loss: 0.4055, Train ACC: 0.82, Train MCC: 0.6213, Val Loss: 0.4938, Val ACC: 0.59, Val MCC: 0.1631
# Epoch 16/200, Train Loss: 0.3354, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.4816, Val ACC: 0.59, Val MCC: 0.1631
# Epoch 17/200, Train Loss: 0.3565, Train ACC: 0.83, Train MCC: 0.6489, Val Loss: 0.4659, Val ACC: 0.62, Val MCC: 0.1943
# Epoch 18/200, Train Loss: 0.4086, Train ACC: 0.84, Train MCC: 0.6692, Val Loss: 0.4667, Val ACC: 0.62, Val MCC: 0.1943
# Epoch 19/200, Train Loss: 0.3747, Train ACC: 0.82, Train MCC: 0.6382, Val Loss: 0.4902, Val ACC: 0.62, Val MCC: 0.1943
# Epoch 20/200, Train Loss: 0.3477, Train ACC: 0.89, Train MCC: 0.7720, Val Loss: 0.5029, Val ACC: 0.59, Val MCC: 0.1071
# Epoch 21/200, Train Loss: 0.3674, Train ACC: 0.84, Train MCC: 0.6692, Val Loss: 0.5030, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 22/200, Train Loss: 0.3878, Train ACC: 0.86, Train MCC: 0.7171, Val Loss: 0.5012, Val ACC: 0.59, Val MCC: 0.1071
# Epoch 23/200, Train Loss: 0.3363, Train ACC: 0.87, Train MCC: 0.7444, Val Loss: 0.5087, Val ACC: 0.59, Val MCC: 0.1071
# Epoch 24/200, Train Loss: 0.3640, Train ACC: 0.85, Train MCC: 0.6900, Val Loss: 0.4993, Val ACC: 0.62, Val MCC: 0.1943
# Epoch 25/200, Train Loss: 0.3118, Train ACC: 0.91, Train MCC: 0.8196, Val Loss: 0.4977, Val ACC: 0.62, Val MCC: 0.1943
# Epoch 26/200, Train Loss: 0.4443, Train ACC: 0.79, Train MCC: 0.5908, Val Loss: 0.4918, Val ACC: 0.64, Val MCC: 0.2809
# Epoch 27/200, Train Loss: 0.3572, Train ACC: 0.89, Train MCC: 0.7650, Val Loss: 0.4869, Val ACC: 0.64, Val MCC: 0.2809
# Epoch 28/200, Train Loss: 0.3824, Train ACC: 0.89, Train MCC: 0.7650, Val Loss: 0.4825, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 29/200, Train Loss: 0.4414, Train ACC: 0.78, Train MCC: 0.5622, Val Loss: 0.4797, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 30/200, Train Loss: 0.3248, Train ACC: 0.89, Train MCC: 0.7650, Val Loss: 0.4818, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 31/200, Train Loss: 0.3732, Train ACC: 0.84, Train MCC: 0.6692, Val Loss: 0.4915, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 32/200, Train Loss: 0.3597, Train ACC: 0.86, Train MCC: 0.7113, Val Loss: 0.4993, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 33/200, Train Loss: 0.3308, Train ACC: 0.89, Train MCC: 0.7720, Val Loss: 0.5010, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 34/200, Train Loss: 0.3369, Train ACC: 0.85, Train MCC: 0.6900, Val Loss: 0.4949, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 35/200, Train Loss: 0.3576, Train ACC: 0.84, Train MCC: 0.6692, Val Loss: 0.4982, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 36/200, Train Loss: 0.3239, Train ACC: 0.87, Train MCC: 0.7444, Val Loss: 0.4911, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 37/200, Train Loss: 0.4111, Train ACC: 0.85, Train MCC: 0.7048, Val Loss: 0.4963, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 38/200, Train Loss: 0.3909, Train ACC: 0.85, Train MCC: 0.6810, Val Loss: 0.4980, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 39/200, Train Loss: 0.3656, Train ACC: 0.86, Train MCC: 0.7244, Val Loss: 0.5112, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 40/200, Train Loss: 0.3386, Train ACC: 0.85, Train MCC: 0.7144, Val Loss: 0.5147, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 41/200, Train Loss: 0.4014, Train ACC: 0.84, Train MCC: 0.6630, Val Loss: 0.5125, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 42/200, Train Loss: 0.3411, Train ACC: 0.86, Train MCC: 0.7113, Val Loss: 0.4997, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 43/200, Train Loss: 0.3622, Train ACC: 0.87, Train MCC: 0.7381, Val Loss: 0.5105, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 44/200, Train Loss: 0.3379, Train ACC: 0.86, Train MCC: 0.7171, Val Loss: 0.5065, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 45/200, Train Loss: 0.2706, Train ACC: 0.93, Train MCC: 0.8562, Val Loss: 0.5040, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 46/200, Train Loss: 0.3923, Train ACC: 0.83, Train MCC: 0.6573, Val Loss: 0.5045, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 47/200, Train Loss: 0.4310, Train ACC: 0.82, Train MCC: 0.6291, Val Loss: 0.4947, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 48/200, Train Loss: 0.3732, Train ACC: 0.87, Train MCC: 0.7381, Val Loss: 0.4982, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 49/200, Train Loss: 0.3417, Train ACC: 0.89, Train MCC: 0.7650, Val Loss: 0.4926, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 50/200, Train Loss: 0.3236, Train ACC: 0.91, Train MCC: 0.8129, Val Loss: 0.4911, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 51/200, Train Loss: 0.2795, Train ACC: 0.91, Train MCC: 0.8129, Val Loss: 0.4891, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 52/200, Train Loss: 0.3898, Train ACC: 0.82, Train MCC: 0.6291, Val Loss: 0.4862, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 53/200, Train Loss: 0.3369, Train ACC: 0.86, Train MCC: 0.7244, Val Loss: 0.4938, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 54/200, Train Loss: 0.3491, Train ACC: 0.80, Train MCC: 0.6011, Val Loss: 0.4839, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 55/200, Train Loss: 0.3233, Train ACC: 0.89, Train MCC: 0.7596, Val Loss: 0.4856, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 56/200, Train Loss: 0.3193, Train ACC: 0.92, Train MCC: 0.8399, Val Loss: 0.4884, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 57/200, Train Loss: 0.3347, Train ACC: 0.85, Train MCC: 0.7048, Val Loss: 0.4944, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 58/200, Train Loss: 0.3888, Train ACC: 0.83, Train MCC: 0.6419, Val Loss: 0.4965, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 59/200, Train Loss: 0.3824, Train ACC: 0.87, Train MCC: 0.7381, Val Loss: 0.4874, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 60/200, Train Loss: 0.3788, Train ACC: 0.85, Train MCC: 0.7048, Val Loss: 0.4947, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 61/200, Train Loss: 0.3694, Train ACC: 0.82, Train MCC: 0.6382, Val Loss: 0.5035, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 62/200, Train Loss: 0.3160, Train ACC: 0.87, Train MCC: 0.7523, Val Loss: 0.4984, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 63/200, Train Loss: 0.3476, Train ACC: 0.89, Train MCC: 0.7596, Val Loss: 0.4932, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 64/200, Train Loss: 0.4128, Train ACC: 0.78, Train MCC: 0.5534, Val Loss: 0.4926, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 65/200, Train Loss: 0.3559, Train ACC: 0.85, Train MCC: 0.6900, Val Loss: 0.4992, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 66/200, Train Loss: 0.3004, Train ACC: 0.86, Train MCC: 0.7434, Val Loss: 0.4964, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 67/200, Train Loss: 0.3175, Train ACC: 0.85, Train MCC: 0.7048, Val Loss: 0.4912, Val ACC: 0.67, Val MCC: 0.2600
# Epoch 68/200, Train Loss: 0.3420, Train ACC: 0.85, Train MCC: 0.7144, Val Loss: 0.4931, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 69/200, Train Loss: 0.3276, Train ACC: 0.87, Train MCC: 0.7333, Val Loss: 0.4941, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 70/200, Train Loss: 0.4019, Train ACC: 0.83, Train MCC: 0.6362, Val Loss: 0.5008, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 71/200, Train Loss: 0.3483, Train ACC: 0.82, Train MCC: 0.6291, Val Loss: 0.5013, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 72/200, Train Loss: 0.3920, Train ACC: 0.83, Train MCC: 0.6489, Val Loss: 0.5012, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 73/200, Train Loss: 0.3304, Train ACC: 0.90, Train MCC: 0.7922, Val Loss: 0.5006, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 74/200, Train Loss: 0.3492, Train ACC: 0.86, Train MCC: 0.7244, Val Loss: 0.5048, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 75/200, Train Loss: 0.4810, Train ACC: 0.77, Train MCC: 0.5254, Val Loss: 0.4927, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 76/200, Train Loss: 0.3695, Train ACC: 0.86, Train MCC: 0.7171, Val Loss: 0.4959, Val ACC: 0.64, Val MCC: 0.1726
# Epoch 77/200, Train Loss: 0.3224, Train ACC: 0.86, Train MCC: 0.7171, Val Loss: 0.5045, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 78/200, Train Loss: 0.3280, Train ACC: 0.89, Train MCC: 0.7650, Val Loss: 0.4977, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 79/200, Train Loss: 0.3425, Train ACC: 0.87, Train MCC: 0.7444, Val Loss: 0.4961, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 80/200, Train Loss: 0.3346, Train ACC: 0.91, Train MCC: 0.8280, Val Loss: 0.4971, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 81/200, Train Loss: 0.3393, Train ACC: 0.86, Train MCC: 0.7244, Val Loss: 0.4996, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 82/200, Train Loss: 0.3789, Train ACC: 0.89, Train MCC: 0.7596, Val Loss: 0.4944, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 83/200, Train Loss: 0.3697, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.4945, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 84/200, Train Loss: 0.3392, Train ACC: 0.83, Train MCC: 0.6362, Val Loss: 0.4956, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 85/200, Train Loss: 0.3204, Train ACC: 0.92, Train MCC: 0.8399, Val Loss: 0.4943, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 86/200, Train Loss: 0.3495, Train ACC: 0.82, Train MCC: 0.6382, Val Loss: 0.5002, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 87/200, Train Loss: 0.3403, Train ACC: 0.90, Train MCC: 0.7818, Val Loss: 0.5013, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 88/200, Train Loss: 0.3603, Train ACC: 0.85, Train MCC: 0.6900, Val Loss: 0.5032, Val ACC: 0.67, Val MCC: 0.3128
# Epoch 89/200, Train Loss: 0.4218, Train ACC: 0.86, Train MCC: 0.7113, Val Loss: 0.5041, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 90/200, Train Loss: 0.3617, Train ACC: 0.89, Train MCC: 0.7596, Val Loss: 0.5077, Val ACC: 0.64, Val MCC: 0.2809
# Epoch 91/200, Train Loss: 0.3245, Train ACC: 0.87, Train MCC: 0.7381, Val Loss: 0.4958, Val ACC: 0.62, Val MCC: 0.1943
# Epoch 92/200, Train Loss: 0.3403, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.5025, Val ACC: 0.64, Val MCC: 0.2809
# Epoch 93/200, Train Loss: 0.4110, Train ACC: 0.86, Train MCC: 0.7113, Val Loss: 0.5050, Val ACC: 0.64, Val MCC: 0.2809
# Epoch 94/200, Train Loss: 0.3601, Train ACC: 0.86, Train MCC: 0.7244, Val Loss: 0.5067, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 95/200, Train Loss: 0.3658, Train ACC: 0.89, Train MCC: 0.7596, Val Loss: 0.5052, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 96/200, Train Loss: 0.3323, Train ACC: 0.89, Train MCC: 0.7596, Val Loss: 0.5042, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 97/200, Train Loss: 0.3927, Train ACC: 0.83, Train MCC: 0.6573, Val Loss: 0.4982, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 98/200, Train Loss: 0.3246, Train ACC: 0.86, Train MCC: 0.7244, Val Loss: 0.4950, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 99/200, Train Loss: 0.3271, Train ACC: 0.86, Train MCC: 0.7244, Val Loss: 0.4925, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 100/200, Train Loss: 0.3286, Train ACC: 0.91, Train MCC: 0.8129, Val Loss: 0.4991, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 101/200, Train Loss: 0.3178, Train ACC: 0.87, Train MCC: 0.7444, Val Loss: 0.4973, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 102/200, Train Loss: 0.3760, Train ACC: 0.83, Train MCC: 0.6573, Val Loss: 0.4915, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 103/200, Train Loss: 0.3705, Train ACC: 0.84, Train MCC: 0.6630, Val Loss: 0.4871, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 104/200, Train Loss: 0.3583, Train ACC: 0.87, Train MCC: 0.7444, Val Loss: 0.4917, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 105/200, Train Loss: 0.3421, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.4898, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 106/200, Train Loss: 0.3060, Train ACC: 0.87, Train MCC: 0.7523, Val Loss: 0.4779, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 107/200, Train Loss: 0.3676, Train ACC: 0.86, Train MCC: 0.7331, Val Loss: 0.4812, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 108/200, Train Loss: 0.3536, Train ACC: 0.83, Train MCC: 0.6573, Val Loss: 0.4842, Val ACC: 0.67, Val MCC: 0.3128
# Epoch 109/200, Train Loss: 0.3733, Train ACC: 0.86, Train MCC: 0.7244, Val Loss: 0.4865, Val ACC: 0.67, Val MCC: 0.3128
# Epoch 110/200, Train Loss: 0.3457, Train ACC: 0.85, Train MCC: 0.7048, Val Loss: 0.4905, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 111/200, Train Loss: 0.3915, Train ACC: 0.87, Train MCC: 0.7381, Val Loss: 0.4986, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 112/200, Train Loss: 0.3812, Train ACC: 0.85, Train MCC: 0.6900, Val Loss: 0.5000, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 113/200, Train Loss: 0.3575, Train ACC: 0.85, Train MCC: 0.6900, Val Loss: 0.4972, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 114/200, Train Loss: 0.4142, Train ACC: 0.79, Train MCC: 0.5733, Val Loss: 0.5017, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 115/200, Train Loss: 0.3587, Train ACC: 0.89, Train MCC: 0.7806, Val Loss: 0.5131, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 116/200, Train Loss: 0.3518, Train ACC: 0.89, Train MCC: 0.7650, Val Loss: 0.5131, Val ACC: 0.67, Val MCC: 0.3128
# Epoch 117/200, Train Loss: 0.3868, Train ACC: 0.83, Train MCC: 0.6419, Val Loss: 0.5049, Val ACC: 0.64, Val MCC: 0.2809
# Epoch 118/200, Train Loss: 0.3663, Train ACC: 0.84, Train MCC: 0.6692, Val Loss: 0.5147, Val ACC: 0.62, Val MCC: 0.1943
# Epoch 119/200, Train Loss: 0.3647, Train ACC: 0.84, Train MCC: 0.6767, Val Loss: 0.5109, Val ACC: 0.64, Val MCC: 0.2809
# Epoch 120/200, Train Loss: 0.3624, Train ACC: 0.80, Train MCC: 0.6097, Val Loss: 0.5061, Val ACC: 0.64, Val MCC: 0.2809
# Epoch 121/200, Train Loss: 0.3443, Train ACC: 0.87, Train MCC: 0.7381, Val Loss: 0.4993, Val ACC: 0.64, Val MCC: 0.2809
# Epoch 122/200, Train Loss: 0.4038, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.4999, Val ACC: 0.67, Val MCC: 0.3128
# Epoch 123/200, Train Loss: 0.2930, Train ACC: 0.92, Train MCC: 0.8474, Val Loss: 0.5077, Val ACC: 0.64, Val MCC: 0.2809
# Epoch 124/200, Train Loss: 0.3980, Train ACC: 0.83, Train MCC: 0.6419, Val Loss: 0.5068, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 125/200, Train Loss: 0.3634, Train ACC: 0.84, Train MCC: 0.6692, Val Loss: 0.5023, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 126/200, Train Loss: 0.3932, Train ACC: 0.84, Train MCC: 0.6857, Val Loss: 0.5029, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 127/200, Train Loss: 0.3347, Train ACC: 0.89, Train MCC: 0.7650, Val Loss: 0.4984, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 128/200, Train Loss: 0.3577, Train ACC: 0.84, Train MCC: 0.7078, Val Loss: 0.5055, Val ACC: 0.67, Val MCC: 0.2600
# Epoch 129/200, Train Loss: 0.3587, Train ACC: 0.87, Train MCC: 0.7444, Val Loss: 0.4975, Val ACC: 0.64, Val MCC: 0.1726
# Epoch 130/200, Train Loss: 0.3515, Train ACC: 0.86, Train MCC: 0.7244, Val Loss: 0.4993, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 131/200, Train Loss: 0.4032, Train ACC: 0.84, Train MCC: 0.6857, Val Loss: 0.4918, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 132/200, Train Loss: 0.3707, Train ACC: 0.87, Train MCC: 0.7333, Val Loss: 0.4954, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 133/200, Train Loss: 0.3704, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.4948, Val ACC: 0.64, Val MCC: 0.1726
# Epoch 134/200, Train Loss: 0.3384, Train ACC: 0.86, Train MCC: 0.7434, Val Loss: 0.5002, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 135/200, Train Loss: 0.3562, Train ACC: 0.86, Train MCC: 0.7331, Val Loss: 0.5163, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 136/200, Train Loss: 0.3231, Train ACC: 0.87, Train MCC: 0.7333, Val Loss: 0.5123, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 137/200, Train Loss: 0.3277, Train ACC: 0.86, Train MCC: 0.7331, Val Loss: 0.5110, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 138/200, Train Loss: 0.4201, Train ACC: 0.79, Train MCC: 0.5733, Val Loss: 0.5151, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 139/200, Train Loss: 0.3409, Train ACC: 0.92, Train MCC: 0.8304, Val Loss: 0.5023, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 140/200, Train Loss: 0.3331, Train ACC: 0.85, Train MCC: 0.6900, Val Loss: 0.5010, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 141/200, Train Loss: 0.3670, Train ACC: 0.86, Train MCC: 0.7071, Val Loss: 0.4981, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 142/200, Train Loss: 0.2934, Train ACC: 0.91, Train MCC: 0.8129, Val Loss: 0.5052, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 143/200, Train Loss: 0.4167, Train ACC: 0.89, Train MCC: 0.7650, Val Loss: 0.4994, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 144/200, Train Loss: 0.3154, Train ACC: 0.89, Train MCC: 0.7650, Val Loss: 0.4980, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 145/200, Train Loss: 0.4038, Train ACC: 0.84, Train MCC: 0.6692, Val Loss: 0.5022, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 146/200, Train Loss: 0.3880, Train ACC: 0.83, Train MCC: 0.6573, Val Loss: 0.5076, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 147/200, Train Loss: 0.3372, Train ACC: 0.87, Train MCC: 0.7444, Val Loss: 0.4925, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 148/200, Train Loss: 0.4060, Train ACC: 0.87, Train MCC: 0.7444, Val Loss: 0.4992, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 149/200, Train Loss: 0.3667, Train ACC: 0.85, Train MCC: 0.7144, Val Loss: 0.5048, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 150/200, Train Loss: 0.3832, Train ACC: 0.85, Train MCC: 0.6900, Val Loss: 0.5012, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 151/200, Train Loss: 0.3878, Train ACC: 0.80, Train MCC: 0.6011, Val Loss: 0.4936, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 152/200, Train Loss: 0.3391, Train ACC: 0.87, Train MCC: 0.7381, Val Loss: 0.4923, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 153/200, Train Loss: 0.3269, Train ACC: 0.85, Train MCC: 0.7048, Val Loss: 0.4902, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 154/200, Train Loss: 0.4355, Train ACC: 0.82, Train MCC: 0.6213, Val Loss: 0.4888, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 155/200, Train Loss: 0.3311, Train ACC: 0.90, Train MCC: 0.7862, Val Loss: 0.4882, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 156/200, Train Loss: 0.3635, Train ACC: 0.86, Train MCC: 0.7171, Val Loss: 0.4901, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 157/200, Train Loss: 0.3432, Train ACC: 0.86, Train MCC: 0.7171, Val Loss: 0.4953, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 158/200, Train Loss: 0.3838, Train ACC: 0.83, Train MCC: 0.6362, Val Loss: 0.5049, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 159/200, Train Loss: 0.3789, Train ACC: 0.84, Train MCC: 0.6692, Val Loss: 0.5051, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 160/200, Train Loss: 0.3117, Train ACC: 0.90, Train MCC: 0.7818, Val Loss: 0.4920, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 161/200, Train Loss: 0.3190, Train ACC: 0.86, Train MCC: 0.7171, Val Loss: 0.4932, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 162/200, Train Loss: 0.3499, Train ACC: 0.89, Train MCC: 0.7596, Val Loss: 0.5009, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 163/200, Train Loss: 0.3547, Train ACC: 0.84, Train MCC: 0.6767, Val Loss: 0.4864, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 164/200, Train Loss: 0.4088, Train ACC: 0.80, Train MCC: 0.5938, Val Loss: 0.4860, Val ACC: 0.67, Val MCC: 0.3128
# Epoch 165/200, Train Loss: 0.3298, Train ACC: 0.86, Train MCC: 0.7171, Val Loss: 0.4861, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 166/200, Train Loss: 0.3336, Train ACC: 0.87, Train MCC: 0.7444, Val Loss: 0.4863, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 167/200, Train Loss: 0.3959, Train ACC: 0.86, Train MCC: 0.7244, Val Loss: 0.4832, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 168/200, Train Loss: 0.3151, Train ACC: 0.87, Train MCC: 0.7523, Val Loss: 0.5059, Val ACC: 0.62, Val MCC: 0.1943
# Epoch 169/200, Train Loss: 0.3278, Train ACC: 0.92, Train MCC: 0.8343, Val Loss: 0.5119, Val ACC: 0.62, Val MCC: 0.1943
# Epoch 170/200, Train Loss: 0.3925, Train ACC: 0.84, Train MCC: 0.6692, Val Loss: 0.5089, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 171/200, Train Loss: 0.3377, Train ACC: 0.86, Train MCC: 0.7244, Val Loss: 0.5052, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 172/200, Train Loss: 0.4268, Train ACC: 0.85, Train MCC: 0.6900, Val Loss: 0.4980, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 173/200, Train Loss: 0.3634, Train ACC: 0.85, Train MCC: 0.6900, Val Loss: 0.5034, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 174/200, Train Loss: 0.3046, Train ACC: 0.92, Train MCC: 0.8343, Val Loss: 0.4984, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 175/200, Train Loss: 0.3689, Train ACC: 0.86, Train MCC: 0.7244, Val Loss: 0.4950, Val ACC: 0.67, Val MCC: 0.3128
# Epoch 176/200, Train Loss: 0.3614, Train ACC: 0.86, Train MCC: 0.7113, Val Loss: 0.4969, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 177/200, Train Loss: 0.4113, Train ACC: 0.83, Train MCC: 0.6573, Val Loss: 0.5050, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 178/200, Train Loss: 0.3850, Train ACC: 0.79, Train MCC: 0.5815, Val Loss: 0.5014, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 179/200, Train Loss: 0.3254, Train ACC: 0.89, Train MCC: 0.7650, Val Loss: 0.5009, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 180/200, Train Loss: 0.3573, Train ACC: 0.86, Train MCC: 0.7244, Val Loss: 0.4969, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 181/200, Train Loss: 0.3053, Train ACC: 0.91, Train MCC: 0.8047, Val Loss: 0.5012, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 182/200, Train Loss: 0.3862, Train ACC: 0.84, Train MCC: 0.6692, Val Loss: 0.5041, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 183/200, Train Loss: 0.2858, Train ACC: 0.91, Train MCC: 0.8196, Val Loss: 0.4943, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 184/200, Train Loss: 0.3494, Train ACC: 0.84, Train MCC: 0.6692, Val Loss: 0.4938, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 185/200, Train Loss: 0.4204, Train ACC: 0.79, Train MCC: 0.6012, Val Loss: 0.4940, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 186/200, Train Loss: 0.4162, Train ACC: 0.84, Train MCC: 0.6692, Val Loss: 0.4997, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 187/200, Train Loss: 0.3692, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.5031, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 188/200, Train Loss: 0.3816, Train ACC: 0.90, Train MCC: 0.7792, Val Loss: 0.4955, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 189/200, Train Loss: 0.3969, Train ACC: 0.83, Train MCC: 0.6573, Val Loss: 0.4974, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 190/200, Train Loss: 0.3590, Train ACC: 0.87, Train MCC: 0.7523, Val Loss: 0.4958, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 191/200, Train Loss: 0.3099, Train ACC: 0.90, Train MCC: 0.7998, Val Loss: 0.4960, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 192/200, Train Loss: 0.3195, Train ACC: 0.89, Train MCC: 0.7596, Val Loss: 0.4904, Val ACC: 0.64, Val MCC: 0.1726
# Epoch 193/200, Train Loss: 0.4054, Train ACC: 0.80, Train MCC: 0.6097, Val Loss: 0.4913, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 194/200, Train Loss: 0.3327, Train ACC: 0.91, Train MCC: 0.8196, Val Loss: 0.4908, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 195/200, Train Loss: 0.3220, Train ACC: 0.85, Train MCC: 0.7048, Val Loss: 0.4905, Val ACC: 0.62, Val MCC: 0.1393
# Epoch 196/200, Train Loss: 0.3896, Train ACC: 0.84, Train MCC: 0.6857, Val Loss: 0.4918, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 197/200, Train Loss: 0.3448, Train ACC: 0.82, Train MCC: 0.6213, Val Loss: 0.4906, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 198/200, Train Loss: 0.3649, Train ACC: 0.85, Train MCC: 0.6967, Val Loss: 0.4891, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 199/200, Train Loss: 0.4542, Train ACC: 0.80, Train MCC: 0.5938, Val Loss: 0.4885, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 200/200, Train Loss: 0.3490, Train ACC: 0.86, Train MCC: 0.7171, Val Loss: 0.4861, Val ACC: 0.64, Val MCC: 0.2265

# %%
model = res101
model.eval()
# 加载测试数据集
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_csv_file = "/local/data1/honzh/local_repository/FL/code/4_federated/csv_files/test_data.csv"

test_dataset = CustomDatasetCSV(csv_file=test_csv_file, transform=test_transform)

test_model(model, test_dataset)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.69      0.79      2271
#            1       0.33      0.72      0.46       490
#
#     accuracy                           0.70      2761
#    macro avg       0.63      0.70      0.62      2761
# weighted avg       0.81      0.70      0.73      2761
# {'Total Acc': 0.696,
#  'nff Acc': 0.692,
#  'aff Acc': 0.716,
#  'Precision': 0.334,
#  'Recall': 0.716,
#  'Accuracy': 0.696,
#  'AUC': 0.704,
#  'MCC': 0.321,
#  'F1 Score': 0.456,
#  'ROC_AUC': 0.704,
#  'PRC-AUC': 0.29}

# %% [markdown]
# # densenet161

# %%
from torchvision.models import densenet161, DenseNet161_Weights
from torchvision import transforms, models

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the DenseNet-161 model
model = models.densenet161(weights=DenseNet161_Weights.DEFAULT)

# Modify the classifier part of the model
num_features = model.classifier.in_features
model.classifier = nn.Linear(num_features, 2)

# total layers 
total_layers = len(list(model.features.children()))

# freeze 50% layers
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.features.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False
#---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 200
batch_size = 32
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

dense161 = train_custom_model(model, train_dataset,val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/200, Train Loss: 0.6520, Train ACC: 0.66, Train MCC: 0.2297, Val Loss: 0.5488, Val ACC: 0.64, Val MCC: 0.2265
# Epoch 2/200, Train Loss: 0.5872, Train ACC: 0.67, Train MCC: 0.3245, Val Loss: 0.6150, Val ACC: 0.59, Val MCC: 0.2794
# Epoch 3/200, Train Loss: 0.4690, Train ACC: 0.82, Train MCC: 0.6213, Val Loss: 0.7018, Val ACC: 0.56, Val MCC: 0.2510
# Epoch 4/200, Train Loss: 0.4761, Train ACC: 0.72, Train MCC: 0.4484, Val Loss: 0.8018, Val ACC: 0.49, Val MCC: 0.1661
# Epoch 5/200, Train Loss: 0.4184, Train ACC: 0.80, Train MCC: 0.6097, Val Loss: 0.8349, Val ACC: 0.54, Val MCC: 0.2228
# Epoch 6/200, Train Loss: 0.3246, Train ACC: 0.89, Train MCC: 0.7650, Val Loss: 0.8731, Val ACC: 0.54, Val MCC: 0.2228
# Epoch 7/200, Train Loss: 0.3442, Train ACC: 0.89, Train MCC: 0.7559, Val Loss: 0.9160, Val ACC: 0.51, Val MCC: 0.1946
# Epoch 8/200, Train Loss: 0.4021, Train ACC: 0.82, Train MCC: 0.6382, Val Loss: 0.9537, Val ACC: 0.59, Val MCC: 0.2794
# Epoch 9/200, Train Loss: 0.2135, Train ACC: 0.94, Train MCC: 0.8824, Val Loss: 0.9619, Val ACC: 0.59, Val MCC: 0.2794
# Epoch 10/200, Train Loss: 0.2531, Train ACC: 0.90, Train MCC: 0.7862, Val Loss: 1.0443, Val ACC: 0.59, Val MCC: 0.2794
# Epoch 11/200, Train Loss: 0.2079, Train ACC: 0.92, Train MCC: 0.8304, Val Loss: 0.9022, Val ACC: 0.62, Val MCC: 0.3081
# Epoch 12/200, Train Loss: 0.1947, Train ACC: 0.93, Train MCC: 0.8528, Val Loss: 0.8235, Val ACC: 0.64, Val MCC: 0.3374
# Epoch 13/200, Train Loss: 0.2233, Train ACC: 0.90, Train MCC: 0.7818, Val Loss: 0.7391, Val ACC: 0.64, Val MCC: 0.3374
# Epoch 14/200, Train Loss: 0.1713, Train ACC: 0.94, Train MCC: 0.8789, Val Loss: 0.6807, Val ACC: 0.67, Val MCC: 0.3675
# Epoch 15/200, Train Loss: 0.2447, Train ACC: 0.90, Train MCC: 0.7862, Val Loss: 0.6252, Val ACC: 0.64, Val MCC: 0.2809
# Epoch 16/200, Train Loss: 0.1829, Train ACC: 0.93, Train MCC: 0.8535, Val Loss: 0.5901, Val ACC: 0.64, Val MCC: 0.2809
# Epoch 17/200, Train Loss: 0.1598, Train ACC: 0.97, Train MCC: 0.9275, Val Loss: 0.5550, Val ACC: 0.67, Val MCC: 0.3128
# Epoch 18/200, Train Loss: 0.2102, Train ACC: 0.92, Train MCC: 0.8304, Val Loss: 0.5391, Val ACC: 0.67, Val MCC: 0.3128
# Epoch 19/200, Train Loss: 0.1800, Train ACC: 0.93, Train MCC: 0.8528, Val Loss: 0.5392, Val ACC: 0.67, Val MCC: 0.3128
# Epoch 20/200, Train Loss: 0.1592, Train ACC: 0.95, Train MCC: 0.9045, Val Loss: 0.5377, Val ACC: 0.67, Val MCC: 0.3128
# Epoch 21/200, Train Loss: 0.2161, Train ACC: 0.93, Train MCC: 0.8528, Val Loss: 0.5326, Val ACC: 0.67, Val MCC: 0.3128
# Epoch 22/200, Train Loss: 0.1818, Train ACC: 0.92, Train MCC: 0.8343, Val Loss: 0.5238, Val ACC: 0.67, Val MCC: 0.3128
# Epoch 23/200, Train Loss: 0.1941, Train ACC: 0.93, Train MCC: 0.8535, Val Loss: 0.5206, Val ACC: 0.67, Val MCC: 0.3128
# Epoch 24/200, Train Loss: 0.1417, Train ACC: 0.95, Train MCC: 0.9045, Val Loss: 0.5179, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 25/200, Train Loss: 0.1243, Train ACC: 0.98, Train MCC: 0.9512, Val Loss: 0.5153, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 26/200, Train Loss: 0.1998, Train ACC: 0.94, Train MCC: 0.8824, Val Loss: 0.5092, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 27/200, Train Loss: 0.1621, Train ACC: 0.95, Train MCC: 0.9045, Val Loss: 0.5098, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 28/200, Train Loss: 0.1613, Train ACC: 0.98, Train MCC: 0.9518, Val Loss: 0.5073, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 29/200, Train Loss: 0.1497, Train ACC: 0.97, Train MCC: 0.9305, Val Loss: 0.5150, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 30/200, Train Loss: 0.1284, Train ACC: 0.97, Train MCC: 0.9275, Val Loss: 0.5135, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 31/200, Train Loss: 0.1997, Train ACC: 0.92, Train MCC: 0.8343, Val Loss: 0.5114, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 32/200, Train Loss: 0.1630, Train ACC: 0.93, Train MCC: 0.8535, Val Loss: 0.5162, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 33/200, Train Loss: 0.1156, Train ACC: 0.99, Train MCC: 0.9760, Val Loss: 0.5149, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 34/200, Train Loss: 0.1068, Train ACC: 0.98, Train MCC: 0.9512, Val Loss: 0.5086, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 35/200, Train Loss: 0.1341, Train ACC: 0.97, Train MCC: 0.9275, Val Loss: 0.5157, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 36/200, Train Loss: 0.1060, Train ACC: 0.98, Train MCC: 0.9529, Val Loss: 0.5131, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 37/200, Train Loss: 0.1507, Train ACC: 0.95, Train MCC: 0.9024, Val Loss: 0.5165, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 38/200, Train Loss: 0.1799, Train ACC: 0.92, Train MCC: 0.8399, Val Loss: 0.5119, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 39/200, Train Loss: 0.1508, Train ACC: 0.99, Train MCC: 0.9757, Val Loss: 0.5029, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 40/200, Train Loss: 0.1274, Train ACC: 0.95, Train MCC: 0.9045, Val Loss: 0.5020, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 41/200, Train Loss: 0.1938, Train ACC: 0.92, Train MCC: 0.8304, Val Loss: 0.4992, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 42/200, Train Loss: 0.1951, Train ACC: 0.92, Train MCC: 0.8304, Val Loss: 0.5015, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 43/200, Train Loss: 0.1723, Train ACC: 0.95, Train MCC: 0.9024, Val Loss: 0.5097, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 44/200, Train Loss: 0.1697, Train ACC: 0.95, Train MCC: 0.9045, Val Loss: 0.5127, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 45/200, Train Loss: 0.1696, Train ACC: 0.97, Train MCC: 0.9275, Val Loss: 0.5103, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 46/200, Train Loss: 0.1195, Train ACC: 0.95, Train MCC: 0.9045, Val Loss: 0.4991, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 47/200, Train Loss: 0.1768, Train ACC: 0.93, Train MCC: 0.8562, Val Loss: 0.5029, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 48/200, Train Loss: 0.1450, Train ACC: 0.97, Train MCC: 0.9305, Val Loss: 0.5103, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 49/200, Train Loss: 0.2461, Train ACC: 0.91, Train MCC: 0.8079, Val Loss: 0.5130, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 50/200, Train Loss: 0.1601, Train ACC: 0.95, Train MCC: 0.9045, Val Loss: 0.5144, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 51/200, Train Loss: 0.1151, Train ACC: 0.98, Train MCC: 0.9512, Val Loss: 0.5239, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 52/200, Train Loss: 0.1304, Train ACC: 0.95, Train MCC: 0.9087, Val Loss: 0.5200, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 53/200, Train Loss: 0.2166, Train ACC: 0.93, Train MCC: 0.8562, Val Loss: 0.5204, Val ACC: 0.67, Val MCC: 0.3128
# Epoch 54/200, Train Loss: 0.1679, Train ACC: 0.95, Train MCC: 0.9087, Val Loss: 0.5093, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 55/200, Train Loss: 0.2064, Train ACC: 0.89, Train MCC: 0.7596, Val Loss: 0.5066, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 56/200, Train Loss: 0.1545, Train ACC: 0.95, Train MCC: 0.9087, Val Loss: 0.5084, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 57/200, Train Loss: 0.1188, Train ACC: 0.95, Train MCC: 0.9045, Val Loss: 0.5074, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 58/200, Train Loss: 0.1733, Train ACC: 0.92, Train MCC: 0.8399, Val Loss: 0.5036, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 59/200, Train Loss: 0.1698, Train ACC: 0.90, Train MCC: 0.7818, Val Loss: 0.5072, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 60/200, Train Loss: 0.1089, Train ACC: 0.99, Train MCC: 0.9757, Val Loss: 0.5137, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 61/200, Train Loss: 0.1224, Train ACC: 0.98, Train MCC: 0.9512, Val Loss: 0.5129, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 62/200, Train Loss: 0.1048, Train ACC: 0.98, Train MCC: 0.9512, Val Loss: 0.5185, Val ACC: 0.67, Val MCC: 0.3128
# Epoch 63/200, Train Loss: 0.2275, Train ACC: 0.92, Train MCC: 0.8399, Val Loss: 0.5117, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 64/200, Train Loss: 0.2369, Train ACC: 0.92, Train MCC: 0.8304, Val Loss: 0.5149, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 65/200, Train Loss: 0.2365, Train ACC: 0.90, Train MCC: 0.7818, Val Loss: 0.5112, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 66/200, Train Loss: 0.1878, Train ACC: 0.93, Train MCC: 0.8535, Val Loss: 0.5148, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 67/200, Train Loss: 0.1757, Train ACC: 0.94, Train MCC: 0.8775, Val Loss: 0.5120, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 68/200, Train Loss: 0.1610, Train ACC: 0.95, Train MCC: 0.9023, Val Loss: 0.5149, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 69/200, Train Loss: 0.1178, Train ACC: 0.98, Train MCC: 0.9512, Val Loss: 0.5116, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 70/200, Train Loss: 0.1640, Train ACC: 0.92, Train MCC: 0.8343, Val Loss: 0.5071, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 71/200, Train Loss: 0.1554, Train ACC: 0.95, Train MCC: 0.9024, Val Loss: 0.5094, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 72/200, Train Loss: 0.1758, Train ACC: 0.94, Train MCC: 0.8824, Val Loss: 0.5103, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 73/200, Train Loss: 0.1485, Train ACC: 0.94, Train MCC: 0.8789, Val Loss: 0.5030, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 74/200, Train Loss: 0.1201, Train ACC: 0.99, Train MCC: 0.9760, Val Loss: 0.5011, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 75/200, Train Loss: 0.1550, Train ACC: 0.93, Train MCC: 0.8535, Val Loss: 0.5053, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 76/200, Train Loss: 0.1313, Train ACC: 0.97, Train MCC: 0.9275, Val Loss: 0.4992, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 77/200, Train Loss: 0.1378, Train ACC: 0.93, Train MCC: 0.8608, Val Loss: 0.4959, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 78/200, Train Loss: 0.1301, Train ACC: 0.95, Train MCC: 0.9045, Val Loss: 0.5021, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 79/200, Train Loss: 0.1507, Train ACC: 0.95, Train MCC: 0.9045, Val Loss: 0.5020, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 80/200, Train Loss: 0.1911, Train ACC: 0.94, Train MCC: 0.8824, Val Loss: 0.5021, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 81/200, Train Loss: 0.1912, Train ACC: 0.92, Train MCC: 0.8284, Val Loss: 0.4984, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 82/200, Train Loss: 0.1425, Train ACC: 0.94, Train MCC: 0.8877, Val Loss: 0.5029, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 83/200, Train Loss: 0.1651, Train ACC: 0.95, Train MCC: 0.9045, Val Loss: 0.5057, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 84/200, Train Loss: 0.1711, Train ACC: 0.93, Train MCC: 0.8562, Val Loss: 0.5089, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 85/200, Train Loss: 0.1354, Train ACC: 0.95, Train MCC: 0.9087, Val Loss: 0.5080, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 86/200, Train Loss: 0.1456, Train ACC: 0.97, Train MCC: 0.9275, Val Loss: 0.5086, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 87/200, Train Loss: 0.1348, Train ACC: 0.97, Train MCC: 0.9266, Val Loss: 0.5103, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 88/200, Train Loss: 0.1156, Train ACC: 0.97, Train MCC: 0.9275, Val Loss: 0.5030, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 89/200, Train Loss: 0.1698, Train ACC: 0.95, Train MCC: 0.9045, Val Loss: 0.5056, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 90/200, Train Loss: 0.1748, Train ACC: 0.92, Train MCC: 0.8343, Val Loss: 0.5088, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 91/200, Train Loss: 0.1391, Train ACC: 0.95, Train MCC: 0.9023, Val Loss: 0.5072, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 92/200, Train Loss: 0.1828, Train ACC: 0.92, Train MCC: 0.8399, Val Loss: 0.5093, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 93/200, Train Loss: 0.1622, Train ACC: 0.93, Train MCC: 0.8562, Val Loss: 0.5129, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 94/200, Train Loss: 0.1293, Train ACC: 0.98, Train MCC: 0.9529, Val Loss: 0.5117, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 95/200, Train Loss: 0.1529, Train ACC: 0.94, Train MCC: 0.8824, Val Loss: 0.5113, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 96/200, Train Loss: 0.1670, Train ACC: 0.95, Train MCC: 0.9023, Val Loss: 0.5046, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 97/200, Train Loss: 0.1427, Train ACC: 0.94, Train MCC: 0.8789, Val Loss: 0.5013, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 98/200, Train Loss: 0.1688, Train ACC: 0.93, Train MCC: 0.8535, Val Loss: 0.5051, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 99/200, Train Loss: 0.1373, Train ACC: 0.95, Train MCC: 0.9024, Val Loss: 0.5007, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 100/200, Train Loss: 0.1764, Train ACC: 0.92, Train MCC: 0.8284, Val Loss: 0.5054, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 101/200, Train Loss: 0.1385, Train ACC: 0.95, Train MCC: 0.9045, Val Loss: 0.5035, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 102/200, Train Loss: 0.1564, Train ACC: 0.95, Train MCC: 0.9045, Val Loss: 0.5047, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 103/200, Train Loss: 0.1349, Train ACC: 0.97, Train MCC: 0.9275, Val Loss: 0.5058, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 104/200, Train Loss: 0.1807, Train ACC: 0.93, Train MCC: 0.8562, Val Loss: 0.5087, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 105/200, Train Loss: 0.1350, Train ACC: 0.97, Train MCC: 0.9305, Val Loss: 0.5132, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 106/200, Train Loss: 0.1505, Train ACC: 0.97, Train MCC: 0.9280, Val Loss: 0.5151, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 107/200, Train Loss: 0.1912, Train ACC: 0.94, Train MCC: 0.8824, Val Loss: 0.5168, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 108/200, Train Loss: 0.1181, Train ACC: 0.97, Train MCC: 0.9305, Val Loss: 0.5158, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 109/200, Train Loss: 0.1766, Train ACC: 0.94, Train MCC: 0.8789, Val Loss: 0.5195, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 110/200, Train Loss: 0.1530, Train ACC: 0.97, Train MCC: 0.9266, Val Loss: 0.5166, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 111/200, Train Loss: 0.1513, Train ACC: 0.95, Train MCC: 0.9024, Val Loss: 0.5172, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 112/200, Train Loss: 0.1461, Train ACC: 0.94, Train MCC: 0.8824, Val Loss: 0.5147, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 113/200, Train Loss: 0.1469, Train ACC: 0.94, Train MCC: 0.8775, Val Loss: 0.5095, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 114/200, Train Loss: 0.1822, Train ACC: 0.92, Train MCC: 0.8343, Val Loss: 0.5109, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 115/200, Train Loss: 0.1190, Train ACC: 0.98, Train MCC: 0.9529, Val Loss: 0.5075, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 116/200, Train Loss: 0.1346, Train ACC: 0.98, Train MCC: 0.9512, Val Loss: 0.5061, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 117/200, Train Loss: 0.1310, Train ACC: 0.98, Train MCC: 0.9512, Val Loss: 0.5017, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 118/200, Train Loss: 0.1336, Train ACC: 0.95, Train MCC: 0.9087, Val Loss: 0.5044, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 119/200, Train Loss: 0.2170, Train ACC: 0.93, Train MCC: 0.8608, Val Loss: 0.5053, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 120/200, Train Loss: 0.1333, Train ACC: 0.95, Train MCC: 0.9023, Val Loss: 0.5058, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 121/200, Train Loss: 0.2324, Train ACC: 0.93, Train MCC: 0.8528, Val Loss: 0.5086, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 122/200, Train Loss: 0.1762, Train ACC: 0.93, Train MCC: 0.8562, Val Loss: 0.5039, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 123/200, Train Loss: 0.1228, Train ACC: 0.98, Train MCC: 0.9512, Val Loss: 0.5015, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 124/200, Train Loss: 0.1699, Train ACC: 0.94, Train MCC: 0.8775, Val Loss: 0.5002, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 125/200, Train Loss: 0.1248, Train ACC: 0.97, Train MCC: 0.9266, Val Loss: 0.4969, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 126/200, Train Loss: 0.1422, Train ACC: 0.95, Train MCC: 0.9045, Val Loss: 0.4962, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 127/200, Train Loss: 0.1393, Train ACC: 0.95, Train MCC: 0.9087, Val Loss: 0.4958, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 128/200, Train Loss: 0.1198, Train ACC: 0.95, Train MCC: 0.9045, Val Loss: 0.4980, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 129/200, Train Loss: 0.2198, Train ACC: 0.91, Train MCC: 0.8129, Val Loss: 0.5015, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 130/200, Train Loss: 0.1704, Train ACC: 0.95, Train MCC: 0.9024, Val Loss: 0.5057, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 131/200, Train Loss: 0.1561, Train ACC: 0.93, Train MCC: 0.8562, Val Loss: 0.5051, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 132/200, Train Loss: 0.1682, Train ACC: 0.93, Train MCC: 0.8562, Val Loss: 0.5099, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 133/200, Train Loss: 0.1866, Train ACC: 0.93, Train MCC: 0.8528, Val Loss: 0.5159, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 134/200, Train Loss: 0.1971, Train ACC: 0.91, Train MCC: 0.8079, Val Loss: 0.5085, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 135/200, Train Loss: 0.1291, Train ACC: 0.99, Train MCC: 0.9757, Val Loss: 0.5067, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 136/200, Train Loss: 0.1603, Train ACC: 0.95, Train MCC: 0.9087, Val Loss: 0.5121, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 137/200, Train Loss: 0.1797, Train ACC: 0.93, Train MCC: 0.8562, Val Loss: 0.5099, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 138/200, Train Loss: 0.1224, Train ACC: 0.98, Train MCC: 0.9512, Val Loss: 0.5057, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 139/200, Train Loss: 0.1916, Train ACC: 0.93, Train MCC: 0.8562, Val Loss: 0.5009, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 140/200, Train Loss: 0.1709, Train ACC: 0.94, Train MCC: 0.8782, Val Loss: 0.5000, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 141/200, Train Loss: 0.1220, Train ACC: 0.98, Train MCC: 0.9512, Val Loss: 0.5010, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 142/200, Train Loss: 0.1081, Train ACC: 0.99, Train MCC: 0.9757, Val Loss: 0.4966, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 143/200, Train Loss: 0.1296, Train ACC: 0.98, Train MCC: 0.9529, Val Loss: 0.5008, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 144/200, Train Loss: 0.1632, Train ACC: 0.94, Train MCC: 0.8789, Val Loss: 0.5044, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 145/200, Train Loss: 0.1565, Train ACC: 0.95, Train MCC: 0.9045, Val Loss: 0.5032, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 146/200, Train Loss: 0.2450, Train ACC: 0.89, Train MCC: 0.7596, Val Loss: 0.5056, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 147/200, Train Loss: 0.1479, Train ACC: 0.94, Train MCC: 0.8824, Val Loss: 0.5120, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 148/200, Train Loss: 0.1744, Train ACC: 0.94, Train MCC: 0.8789, Val Loss: 0.5129, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 149/200, Train Loss: 0.1964, Train ACC: 0.93, Train MCC: 0.8535, Val Loss: 0.5114, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 150/200, Train Loss: 0.1203, Train ACC: 0.97, Train MCC: 0.9275, Val Loss: 0.5093, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 151/200, Train Loss: 0.1495, Train ACC: 0.93, Train MCC: 0.8535, Val Loss: 0.5175, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 152/200, Train Loss: 0.1293, Train ACC: 0.97, Train MCC: 0.9275, Val Loss: 0.5211, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 153/200, Train Loss: 0.1649, Train ACC: 0.93, Train MCC: 0.8535, Val Loss: 0.5160, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 154/200, Train Loss: 0.2195, Train ACC: 0.93, Train MCC: 0.8562, Val Loss: 0.5192, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 155/200, Train Loss: 0.1955, Train ACC: 0.90, Train MCC: 0.7792, Val Loss: 0.5226, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 156/200, Train Loss: 0.1629, Train ACC: 0.95, Train MCC: 0.9045, Val Loss: 0.5223, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 157/200, Train Loss: 0.1313, Train ACC: 0.97, Train MCC: 0.9266, Val Loss: 0.5208, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 158/200, Train Loss: 0.2435, Train ACC: 0.95, Train MCC: 0.9024, Val Loss: 0.5165, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 159/200, Train Loss: 0.1366, Train ACC: 0.95, Train MCC: 0.9024, Val Loss: 0.5140, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 160/200, Train Loss: 0.2495, Train ACC: 0.91, Train MCC: 0.8079, Val Loss: 0.5154, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 161/200, Train Loss: 0.1760, Train ACC: 0.90, Train MCC: 0.7818, Val Loss: 0.5148, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 162/200, Train Loss: 0.1373, Train ACC: 0.97, Train MCC: 0.9275, Val Loss: 0.5142, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 163/200, Train Loss: 0.2386, Train ACC: 0.91, Train MCC: 0.8079, Val Loss: 0.5174, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 164/200, Train Loss: 0.1747, Train ACC: 0.95, Train MCC: 0.9023, Val Loss: 0.5186, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 165/200, Train Loss: 0.1248, Train ACC: 0.98, Train MCC: 0.9512, Val Loss: 0.5159, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 166/200, Train Loss: 0.1849, Train ACC: 0.95, Train MCC: 0.9045, Val Loss: 0.5164, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 167/200, Train Loss: 0.1273, Train ACC: 0.98, Train MCC: 0.9529, Val Loss: 0.5153, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 168/200, Train Loss: 0.1673, Train ACC: 0.95, Train MCC: 0.9024, Val Loss: 0.5222, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 169/200, Train Loss: 0.2003, Train ACC: 0.92, Train MCC: 0.8284, Val Loss: 0.5093, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 170/200, Train Loss: 0.1313, Train ACC: 0.97, Train MCC: 0.9275, Val Loss: 0.4975, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 171/200, Train Loss: 0.1328, Train ACC: 0.94, Train MCC: 0.8775, Val Loss: 0.5063, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 172/200, Train Loss: 0.1492, Train ACC: 0.98, Train MCC: 0.9518, Val Loss: 0.5002, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 173/200, Train Loss: 0.1308, Train ACC: 0.99, Train MCC: 0.9760, Val Loss: 0.5108, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 174/200, Train Loss: 0.2220, Train ACC: 0.93, Train MCC: 0.8562, Val Loss: 0.5163, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 175/200, Train Loss: 0.1764, Train ACC: 0.92, Train MCC: 0.8304, Val Loss: 0.5046, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 176/200, Train Loss: 0.1798, Train ACC: 0.93, Train MCC: 0.8562, Val Loss: 0.5080, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 177/200, Train Loss: 0.1803, Train ACC: 0.93, Train MCC: 0.8562, Val Loss: 0.5077, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 178/200, Train Loss: 0.2213, Train ACC: 0.90, Train MCC: 0.7862, Val Loss: 0.5127, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 179/200, Train Loss: 0.1684, Train ACC: 0.95, Train MCC: 0.9087, Val Loss: 0.5065, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 180/200, Train Loss: 0.2345, Train ACC: 0.93, Train MCC: 0.8562, Val Loss: 0.5128, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 181/200, Train Loss: 0.1811, Train ACC: 0.92, Train MCC: 0.8284, Val Loss: 0.5096, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 182/200, Train Loss: 0.1637, Train ACC: 0.92, Train MCC: 0.8284, Val Loss: 0.5104, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 183/200, Train Loss: 0.1900, Train ACC: 0.92, Train MCC: 0.8284, Val Loss: 0.5184, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 184/200, Train Loss: 0.1571, Train ACC: 0.92, Train MCC: 0.8343, Val Loss: 0.5086, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 185/200, Train Loss: 0.2254, Train ACC: 0.92, Train MCC: 0.8304, Val Loss: 0.5093, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 186/200, Train Loss: 0.1405, Train ACC: 0.95, Train MCC: 0.9023, Val Loss: 0.5065, Val ACC: 0.74, Val MCC: 0.4175
# Epoch 187/200, Train Loss: 0.2264, Train ACC: 0.89, Train MCC: 0.7720, Val Loss: 0.5077, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 188/200, Train Loss: 0.1333, Train ACC: 0.99, Train MCC: 0.9760, Val Loss: 0.5092, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 189/200, Train Loss: 0.1011, Train ACC: 0.98, Train MCC: 0.9529, Val Loss: 0.5159, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 190/200, Train Loss: 0.1682, Train ACC: 0.93, Train MCC: 0.8562, Val Loss: 0.5040, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 191/200, Train Loss: 0.1346, Train ACC: 0.95, Train MCC: 0.9024, Val Loss: 0.5054, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 192/200, Train Loss: 0.1316, Train ACC: 0.94, Train MCC: 0.8789, Val Loss: 0.5035, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 193/200, Train Loss: 0.1971, Train ACC: 0.92, Train MCC: 0.8399, Val Loss: 0.5099, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 194/200, Train Loss: 0.1700, Train ACC: 0.95, Train MCC: 0.9087, Val Loss: 0.5107, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 195/200, Train Loss: 0.2173, Train ACC: 0.93, Train MCC: 0.8528, Val Loss: 0.5089, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 196/200, Train Loss: 0.1789, Train ACC: 0.94, Train MCC: 0.8789, Val Loss: 0.5117, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 197/200, Train Loss: 0.2301, Train ACC: 0.91, Train MCC: 0.8129, Val Loss: 0.5115, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 198/200, Train Loss: 0.1285, Train ACC: 0.98, Train MCC: 0.9529, Val Loss: 0.5094, Val ACC: 0.72, Val MCC: 0.3807
# Epoch 199/200, Train Loss: 0.1166, Train ACC: 0.98, Train MCC: 0.9512, Val Loss: 0.5154, Val ACC: 0.69, Val MCC: 0.3459
# Epoch 200/200, Train Loss: 0.1200, Train ACC: 0.97, Train MCC: 0.9305, Val Loss: 0.5208, Val ACC: 0.67, Val MCC: 0.3128

# %%
model = dense161
model.eval()
# 加载测试数据集
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_csv_file = "/local/data1/honzh/local_repository/FL/code/4_federated/csv_files/test_data.csv"

test_dataset = CustomDatasetCSV(csv_file=test_csv_file, transform=test_transform)

test_model(model, test_dataset)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.71      0.81      2271
#            1       0.37      0.80      0.51       490
#
#     accuracy                           0.72      2761
#    macro avg       0.66      0.75      0.66      2761
# weighted avg       0.84      0.72      0.76      2761
# {'Total Acc': 0.725,
#  'nff Acc': 0.709,
#  'aff Acc': 0.796,
#  'Precision': 0.371,
#  'Recall': 0.796,
#  'Accuracy': 0.725,
#  'AUC': 0.753,
#  'MCC': 0.398,
#  'F1 Score': 0.506,
#  'ROC_AUC': 0.753,
#  'PRC-AUC': 0.332}
