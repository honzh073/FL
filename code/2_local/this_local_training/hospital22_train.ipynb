# %% [markdown]
# # Functions

# %% [markdown]
# test on hospital data without 18 22 43 45 55
#
# use CustomDatasetCSV to load test data
#
# use CustomDatasetJson to load train data
#
# with smoothed training curve, weight = 0.8
#
# test data on 4_fedrated, path:
#
# /local/data1/honzh/local_repository/FL/code/4_federated/csv_files/test_data.csv

# %%
from torch.utils.data import Dataset
from PIL import Image
import csv
from torchvision import transforms
import torch
import numpy as np
import matplotlib.pyplot as plt
import json

# # read by csv files 
class CustomDatasetCSV(Dataset):
    def __init__(self, csv_file, transform=None):
        self.data = []
        self.labels = []
        self.patient_ids = []
        self.transform = transform
        
        with open(csv_file, 'r') as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                image_path = row['ImagePath']
                label = row['Label']
                patient_id = row['PatientID']
                
                if label == 'NFF':
                    label = 0
                elif label == 'AFF':
                    label = 1
                else:
                    raise ValueError("Invalid label in CSV file.")
                
                self.data.append((image_path, label))
                self.labels.append(label)
                self.patient_ids.append(patient_id)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image_path, label = self.data[idx]
        image = Image.open(image_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image, label

# read by json files:
# in order to read from json file
class CustomDatasetJson(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]
        image_path = item['ImagePath']
        label = item['Label']

        # Load image
        image = Image.open(image_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        # Convert label to numerical representation
        if label == 'NFF':
            label = 0
        elif label == 'AFF':
            label = 1
        else:
            raise ValueError("Invalid label in JSON data.")

        return image, label

# show image by csvfiles
# def show_image(dataset, num_images=5):
#     random_indices = np.random.choice(len(dataset), num_images, replace=False)
    
#     plt.figure(figsize=(15, 5))
#     for i, idx in enumerate(random_indices):
#         image, label = dataset[idx]
#         filename = dataset.data[idx][0]
#         truncated_filename = filename.split('/')[-1][:15]
        
#         print(f"Image location: {filename}")

#         plt.subplot(1, num_images, i + 1)
#         plt.title(f"Label: {label}")
#         plt.imshow(image[0])
#         plt.axis('off')
#     plt.show()

# show image by json files


# show x ray image
def show_image(dataset, num_images=5):
    random_indices = np.random.choice(len(dataset), num_images, replace=False)
    
    plt.figure(figsize=(15, 5))
    for i, idx in enumerate(random_indices):
        data_point = dataset[idx]
        image_path = data_point["ImagePath"]
        label = data_point["Label"]

        image = Image.open(image_path)
        
        plt.subplot(1, num_images, i + 1)
        plt.title(f"Label: {label}")
        plt.imshow(image)
        plt.axis('off')
    plt.show()


# model parameters number
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# calculate class weight
def get_class_weight(train_dataset):
    train_nff_count = sum(1 for _, label in train_dataset if label == 0)
    train_aff_count = sum(1 for _, label in train_dataset if label == 1)
    class_weight_nff = 1 / (2 * (train_nff_count / (train_nff_count + train_aff_count)))
    class_weight_aff = 1 / (2 * (train_aff_count / (train_nff_count + train_aff_count)))
    
    return [class_weight_nff, class_weight_aff]

# %%
# import pandas as pd
# from sklearn.model_selection import train_test_split

# # Load the original CSV file
# csv_file_path = "/local/data1/honzh/local_repository/FL/code/2_local/hospital18.csv"
# df = pd.read_csv(csv_file_path)

# # Unique patient IDs
# unique_patient_ids = df['PatientID'].unique()

# # Split the patient IDs into training and validation sets
# train_patient_ids, val_patient_ids = train_test_split(unique_patient_ids, test_size=0.3, random_state=1)

# # Create subsets based on patient IDs
# train_data = df[df['PatientID'].isin(train_patient_ids)]
# val_data = df[df['PatientID'].isin(val_patient_ids)]

# # Save the subsets to separate CSV files if needed
# train_data.to_csv("/local/data1/honzh/local_repository/FL/code/2_local/hospital18_train.csv", index=False)
# val_data.to_csv("/local/data1/honzh/local_repository/FL/code/2_local/hospital18_val.csv", index=False)

# %% [markdown]
# # train model function and best model by acc

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import matthews_corrcoef
import random


# Set random seed
seed = 1
torch.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)

# CUDA seed 
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

def smooth_curve(points, factor=0.8):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points

# train function with early stopping
def train_custom_model(model, train_dataset, val_dataset, num_epochs, batch_size, optimizer):
    # patience = 40  # early stopping
    classweight = get_class_weight(train_dataset)
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    criterion = nn.CrossEntropyLoss(weight=torch.Tensor(classweight).to(device))

    train_loader = DataLoader(train_dataset, batch_size=batch_size,shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    # Create a learning rate scheduler
    lr_scheduler_step = 10  # Adjust this value based on your requirement
    scheduler = lr_scheduler.StepLR(optimizer, step_size=lr_scheduler_step, gamma=0.1)

    best_acc = 0  # Initialize best accuracy value  # Change here
    best_model = None

    # consecutive_no_improvement = 0  # Counter for consecutive epochs without improvement

    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []
    train_mccs = []  # List to store MCC values for each epoch
    val_mccs = []  # List to store MCC values for each epoch

    for epoch in range(num_epochs):
        model.train()
        correct_train = 0
        total_train = 0
        train_loss = 0

        all_train_labels = []  # List to store labels for the entire training set
        all_train_predictions = []  # List to store predictions for the entire training set

        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
            train_loss += loss.item()

            all_train_labels.extend(labels.cpu().numpy())
            all_train_predictions.extend(predicted.cpu().numpy())

        train_accuracy = correct_train / total_train
        train_loss /= len(train_loader)

        # Calculate MCC for training set
        train_mcc = matthews_corrcoef(all_train_labels, all_train_predictions)

        model.eval()
        correct_validation = 0
        total_validation = 0
        validation_loss = 0

        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)

                _, predicted = torch.max(outputs.data, 1)
                total_validation += labels.size(0)
                correct_validation += (predicted == labels).sum().item()
                validation_loss += loss.item()

            validation_accuracy = correct_validation / total_validation
            validation_loss /= len(val_loader)

            # Calculate MCC for validation set
            all_val_labels = []  # List to store labels for the entire validation set
            all_val_predictions = []  # List to store predictions for the entire validation set
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                outputs = model(images)
                _, predicted = torch.max(outputs.data, 1)
                all_val_labels.extend(labels.cpu().numpy())
                all_val_predictions.extend(predicted.cpu().numpy())

            val_mcc = matthews_corrcoef(all_val_labels, all_val_predictions)

            print(f"Epoch {epoch + 1}/{num_epochs}, "
                  f"Train Loss: {train_loss:.4f}, Train ACC: {train_accuracy:.2f}, Train MCC: {train_mcc:.4f}, "
                  f"Val Loss: {validation_loss:.4f}, Val ACC: {validation_accuracy:.2f}, Val MCC: {val_mcc:.4f}")

            # Early stopping check
            if validation_accuracy > best_acc:  # Change here
                best_acc = validation_accuracy  # Change here
                # Save the best model
                best_model = model
                
            # early stopping 
            # if consecutive_no_improvement >= patience:
            #     print(f"No improvement in MCC for {patience} consecutive epochs. Early stopping.")
            #     break

        # Append metrics for plotting
        train_losses.append(train_loss)
        val_losses.append(validation_loss)
        train_accuracies.append(train_accuracy)
        val_accuracies.append(validation_accuracy)
        train_mccs.append(train_mcc)
        val_mccs.append(val_mcc)

        # Step the learning rate scheduler
        scheduler.step()

    # Plotting with smoothing and original curves
    plt.figure(figsize=(15, 5))

    # Plotting Loss
    plt.subplot(1, 3, 1)
    plt.plot(range(1, len(train_losses) + 1), smooth_curve(train_losses), label='Train Loss(smoothed)', color='blue')
    plt.plot(range(1, len(val_losses) + 1), smooth_curve(val_losses), label='Validation Loss (smoothed)', color='orange')
    plt.plot(range(1, len(train_losses) + 1), train_losses, linestyle='dashed', label='Train Loss', color='lightblue')
    plt.plot(range(1, len(val_losses) + 1), val_losses, linestyle='dashed', label='Validation Loss', color='navajowhite')
    plt.xlabel('Epoch', fontsize = 15)
    plt.ylabel('Loss', fontsize = 15)
    plt.ylim(0, 1)  # Set Y-axis limits
    plt.legend()

    # Plotting Accuracy
    plt.subplot(1, 3, 2)
    plt.plot(range(1, len(train_accuracies) + 1), smooth_curve(train_accuracies), label='Train Accuracy (smoothed)', color='green')
    plt.plot(range(1, len(val_accuracies) + 1), smooth_curve(val_accuracies), label='Validation Accuracy (smoothed)', color='red')
    plt.plot(range(1, len(train_accuracies) + 1), train_accuracies, linestyle='dashed', label='Train Accuracy', color='lightgreen')
    plt.plot(range(1, len(val_accuracies) + 1), val_accuracies, linestyle='dashed', label='Validation Accuracy', color='lightcoral')
    plt.xlabel('Epoch', fontsize = 15)
    plt.ylabel('Accuracy', fontsize = 15)
    plt.ylim(0, 1)  # Set Y-axis limits
    plt.legend()

    # Plotting MCC
    plt.subplot(1, 3, 3)
    plt.plot(range(1, len(train_mccs) + 1), smooth_curve(train_mccs), label='Train MCC (smoothed)', color='purple')
    plt.plot(range(1, len(val_mccs) + 1), smooth_curve(val_mccs), label='Validation MCC (smoothed)', color='black')
    plt.plot(range(1, len(train_mccs) + 1), train_mccs, linestyle='dashed', label='Train MCC', color='plum')
    plt.plot(range(1, len(val_mccs) + 1), val_mccs, linestyle='dashed', label='Validation MCC', color='grey')
    plt.xlabel('Epoch', fontsize = 15)
    plt.ylabel('MCC', fontsize = 15)
    plt.ylim(0, 1)  # Set Y-axis limits
    plt.legend()

    plt.tight_layout()
    plt.show()

    return best_model  # Return the model with the best MCC

# %% [markdown]
# # test model performance

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import matthews_corrcoef, f1_score
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, average_precision_score, precision_score, recall_score, accuracy_score
import torchvision.transforms as transforms
import random

def test_model(model, test_dataset):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, pin_memory=True)
    model = model.to(device)

    model.eval()

    correct_test_nff = 0
    correct_test_aff = 0
    total_nff = 0
    total_aff = 0
    total_test = 0
    test_loss = 0

    criterion = nn.CrossEntropyLoss()

    with torch.no_grad():
        all_predictions = []
        all_labels = []
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            _, predicted = torch.max(outputs.data, 1)
            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            total_test += labels.size(0)
            total_nff += (labels == 0).sum().item()
            total_aff += (labels == 1).sum().item()
            correct_test_nff += ((predicted == labels) & (labels == 0)).sum().item()
            correct_test_aff += ((predicted == labels) & (labels == 1)).sum().item()
            test_loss += loss.item()

    # Check if total_aff is zero before performing the division
    test_accuracy_nff = correct_test_nff / total_nff if total_nff != 0 else 0
    test_accuracy_aff = correct_test_aff / total_aff if total_aff != 0 else 0
    test_accuracy_total = (correct_test_nff + correct_test_aff) / total_test
    test_loss /= len(test_loader)

    conf_matrix = confusion_matrix(all_labels, all_predictions)

    # Directly use class labels as strings in target_names
    target_names = ['NFF', 'AFF']

    classification_rep = classification_report(all_labels, all_predictions)

    # Calculate AUC
    auc_score = roc_auc_score(all_labels, all_predictions)

    # Calculate Matthew's correlation coefficient
    mcc_score = matthews_corrcoef(all_labels, all_predictions)

    # Calculate F1 score
    f1_score_value = f1_score(all_labels, all_predictions)

    # Calculate Precision, Recall, Accuracy, ROC-AUC, and PRC-AUC
    precision_value = precision_score(all_labels, all_predictions)
    recall_value = recall_score(all_labels, all_predictions)
    accuracy_value = accuracy_score(all_labels, all_predictions)
    roc_auc_value = roc_auc_score(all_labels, all_predictions)
    prc_auc_value = average_precision_score(all_labels, all_predictions)

    # Store metrics in a dictionary
    metrics = {
        "Total Acc": round(test_accuracy_total, 3),
        "nff Acc": round(test_accuracy_nff, 3),
        "aff Acc": round(test_accuracy_aff, 3),
        "Precision": round(precision_value, 3),
        "Recall": round(recall_value, 3),
        "Accuracy": round(accuracy_value, 3),
        "AUC": round(auc_score, 3),
        "MCC": round(mcc_score, 3),
        "F1 Score": round(f1_score_value, 3),
        "ROC_AUC": round(roc_auc_value, 3),
        "PRC-AUC": round(prc_auc_value, 3)
    }

    # Confusion Matrix
    plt.figure(figsize=(6, 4))
    sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=target_names, yticklabels=target_names)
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()

    # Classification Report
    print("Classification Report:")
    print(classification_rep)

    # Print all metrics
    # for metric_name, metric_value in metrics.items():
    #     print(f"{metric_name}: {metric_value}")

    return metrics

# %%
# Image transformations
train_transforms = transforms.Compose([
    transforms.RandomRotation(degrees=30),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.GaussianBlur(kernel_size=3),
    transforms.RandomEqualize(),
    transforms.RandomAdjustSharpness(sharpness_factor=5),
    transforms.RandomPerspective(distortion_scale=0.6),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

val_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])



# Load by csv data
# train_dataset = CustomDataset('/local/data1/honzh/local_repository/FL/code/2_local/hospital18_train.csv', transform=train_transforms)
# val_dataset = CustomDataset('/local/data1/honzh/local_repository/FL/code/2_local/hospital18_val.csv', transform=val_transforms)
# class_weights = get_class_weight(train_dataset)
# print('Training class weights:', class_weights)

# Load by JSON data
with open('/local/data1/honzh/local_repository/FL/code/2_local/data_files/hospital22_1.json', 'r') as json_file:
    json_data = json.load(json_file)
    train_data = json_data['train']
    val_data = json_data['val']

train_dataset = CustomDatasetJson(train_data, transform=train_transforms)
val_dataset = CustomDatasetJson(val_data, transform=val_transforms)


# Show images
# show_image(train_dataset, 5)

# Calculate numbers
print('-----------------------------------')
train_NFF_count = sum(1 for _, label in train_dataset if label == 0)
train_AFF_count = sum(1 for _, label in train_dataset if label == 1)

print(f"train AFF: {train_AFF_count}, ratio: {train_AFF_count / (train_AFF_count + train_NFF_count):.2f}")
print(f"----- NFF: {train_NFF_count}, ratio: {train_NFF_count / (train_AFF_count + train_NFF_count):.2f}")

print('-----------------------------------')
train_NFF_count = sum(1 for _, label in val_dataset if label == 0)
train_AFF_count = sum(1 for _, label in val_dataset if label == 1)

print(f"val AFF: {train_AFF_count}, ratio: {train_AFF_count / (train_AFF_count + train_NFF_count):.2f}")
print(f"----- NFF: {train_NFF_count}, ratio: {train_NFF_count / (train_AFF_count + train_NFF_count):.2f}")
# Out:
# -----------------------------------
# train AFF: 27, ratio: 0.40
# ----- NFF: 40, ratio: 0.60
# -----------------------------------
# val AFF: 17, ratio: 0.57
# ----- NFF: 13, ratio: 0.43

# %% [markdown]
# # VGG 19

# %%
from torchvision.models import vgg19, VGG19_Weights
from torchvision import transforms, models

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the VGG-19 model
model = models.vgg19(weights=VGG19_Weights.DEFAULT)

# Modify the classifier part of the model
num_features = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_features, 2)

# layer number
total_layers = len(list(model.features.children()))

# freeze 50% layer
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.features.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False
# ---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 200
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

vgg19 = train_custom_model(model, train_dataset, val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/200, Train Loss: 0.6091, Train ACC: 0.55, Train MCC: 0.1279, Val Loss: 1.0718, Val ACC: 0.43, Val MCC: 0.0000
# Epoch 2/200, Train Loss: 0.7965, Train ACC: 0.61, Train MCC: 0.1498, Val Loss: 0.8992, Val ACC: 0.47, Val MCC: 0.1624
# Epoch 3/200, Train Loss: 0.5784, Train ACC: 0.63, Train MCC: 0.1822, Val Loss: 0.9484, Val ACC: 0.43, Val MCC: 0.0000
# Epoch 4/200, Train Loss: 0.5675, Train ACC: 0.66, Train MCC: 0.2620, Val Loss: 1.1180, Val ACC: 0.43, Val MCC: 0.0000
# Epoch 5/200, Train Loss: 0.7752, Train ACC: 0.66, Train MCC: 0.2605, Val Loss: 0.8070, Val ACC: 0.50, Val MCC: 0.2337
# Epoch 6/200, Train Loss: 0.4952, Train ACC: 0.75, Train MCC: 0.4651, Val Loss: 0.6400, Val ACC: 0.60, Val MCC: 0.2018
# Epoch 7/200, Train Loss: 0.4742, Train ACC: 0.66, Train MCC: 0.4239, Val Loss: 0.6923, Val ACC: 0.57, Val MCC: 0.1648
# Epoch 8/200, Train Loss: 0.5933, Train ACC: 0.63, Train MCC: 0.3583, Val Loss: 1.5489, Val ACC: 0.50, Val MCC: 0.2337
# Epoch 9/200, Train Loss: 0.5400, Train ACC: 0.76, Train MCC: 0.4944, Val Loss: 1.7540, Val ACC: 0.50, Val MCC: 0.2337
# Epoch 10/200, Train Loss: 0.6421, Train ACC: 0.69, Train MCC: 0.3258, Val Loss: 1.0858, Val ACC: 0.50, Val MCC: 0.1451
# Epoch 11/200, Train Loss: 0.4944, Train ACC: 0.76, Train MCC: 0.5106, Val Loss: 1.0342, Val ACC: 0.50, Val MCC: 0.1451
# Epoch 12/200, Train Loss: 0.7475, Train ACC: 0.76, Train MCC: 0.5037, Val Loss: 0.9956, Val ACC: 0.50, Val MCC: 0.1451
# Epoch 13/200, Train Loss: 0.5632, Train ACC: 0.72, Train MCC: 0.4144, Val Loss: 0.9737, Val ACC: 0.50, Val MCC: 0.1451
# Epoch 14/200, Train Loss: 0.8880, Train ACC: 0.72, Train MCC: 0.4144, Val Loss: 0.9400, Val ACC: 0.50, Val MCC: 0.1451
# Epoch 15/200, Train Loss: 0.7252, Train ACC: 0.75, Train MCC: 0.4761, Val Loss: 0.8803, Val ACC: 0.50, Val MCC: 0.1451
# Epoch 16/200, Train Loss: 0.5326, Train ACC: 0.82, Train MCC: 0.6334, Val Loss: 0.8335, Val ACC: 0.50, Val MCC: 0.1451
# Epoch 17/200, Train Loss: 0.7040, Train ACC: 0.70, Train MCC: 0.3728, Val Loss: 0.7989, Val ACC: 0.50, Val MCC: 0.1451
# Epoch 18/200, Train Loss: 0.5577, Train ACC: 0.79, Train MCC: 0.5657, Val Loss: 0.7763, Val ACC: 0.53, Val MCC: 0.2106
# Epoch 19/200, Train Loss: 0.5051, Train ACC: 0.73, Train MCC: 0.4492, Val Loss: 0.7672, Val ACC: 0.53, Val MCC: 0.2106
# Epoch 20/200, Train Loss: 0.5612, Train ACC: 0.84, Train MCC: 0.6555, Val Loss: 0.7580, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 21/200, Train Loss: 0.6787, Train ACC: 0.78, Train MCC: 0.5322, Val Loss: 0.7575, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 22/200, Train Loss: 0.4179, Train ACC: 0.76, Train MCC: 0.5192, Val Loss: 0.7579, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 23/200, Train Loss: 0.6047, Train ACC: 0.87, Train MCC: 0.7228, Val Loss: 0.7580, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 24/200, Train Loss: 0.6658, Train ACC: 0.78, Train MCC: 0.5378, Val Loss: 0.7576, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 25/200, Train Loss: 0.7259, Train ACC: 0.75, Train MCC: 0.4761, Val Loss: 0.7567, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 26/200, Train Loss: 0.5217, Train ACC: 0.78, Train MCC: 0.5322, Val Loss: 0.7559, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 27/200, Train Loss: 0.7858, Train ACC: 0.78, Train MCC: 0.5285, Val Loss: 0.7546, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 28/200, Train Loss: 0.4212, Train ACC: 0.76, Train MCC: 0.4986, Val Loss: 0.7526, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 29/200, Train Loss: 0.5102, Train ACC: 0.79, Train MCC: 0.5616, Val Loss: 0.7516, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 30/200, Train Loss: 0.5673, Train ACC: 0.79, Train MCC: 0.5657, Val Loss: 0.7513, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 31/200, Train Loss: 0.4216, Train ACC: 0.73, Train MCC: 0.4492, Val Loss: 0.7512, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 32/200, Train Loss: 0.4821, Train ACC: 0.78, Train MCC: 0.5378, Val Loss: 0.7512, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 33/200, Train Loss: 0.3870, Train ACC: 0.72, Train MCC: 0.4144, Val Loss: 0.7512, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 34/200, Train Loss: 0.4950, Train ACC: 0.76, Train MCC: 0.4986, Val Loss: 0.7512, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 35/200, Train Loss: 0.5247, Train ACC: 0.85, Train MCC: 0.7023, Val Loss: 0.7511, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 36/200, Train Loss: 0.4959, Train ACC: 0.78, Train MCC: 0.5453, Val Loss: 0.7510, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 37/200, Train Loss: 0.4915, Train ACC: 0.78, Train MCC: 0.5285, Val Loss: 0.7508, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 38/200, Train Loss: 0.5114, Train ACC: 0.78, Train MCC: 0.5271, Val Loss: 0.7507, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 39/200, Train Loss: 0.6419, Train ACC: 0.78, Train MCC: 0.5322, Val Loss: 0.7504, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 40/200, Train Loss: 0.4587, Train ACC: 0.87, Train MCC: 0.7228, Val Loss: 0.7502, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 41/200, Train Loss: 0.4775, Train ACC: 0.79, Train MCC: 0.5596, Val Loss: 0.7502, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 42/200, Train Loss: 0.5394, Train ACC: 0.73, Train MCC: 0.4357, Val Loss: 0.7502, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 43/200, Train Loss: 0.4201, Train ACC: 0.78, Train MCC: 0.5660, Val Loss: 0.7502, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 44/200, Train Loss: 0.5931, Train ACC: 0.75, Train MCC: 0.4615, Val Loss: 0.7502, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 45/200, Train Loss: 0.6767, Train ACC: 0.81, Train MCC: 0.6064, Val Loss: 0.7502, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 46/200, Train Loss: 0.4985, Train ACC: 0.81, Train MCC: 0.5995, Val Loss: 0.7502, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 47/200, Train Loss: 0.3802, Train ACC: 0.76, Train MCC: 0.5037, Val Loss: 0.7502, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 48/200, Train Loss: 0.7135, Train ACC: 0.85, Train MCC: 0.6877, Val Loss: 0.7502, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 49/200, Train Loss: 0.4934, Train ACC: 0.73, Train MCC: 0.4417, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 50/200, Train Loss: 0.5561, Train ACC: 0.78, Train MCC: 0.5378, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 51/200, Train Loss: 0.5912, Train ACC: 0.76, Train MCC: 0.5037, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 52/200, Train Loss: 0.3895, Train ACC: 0.85, Train MCC: 0.6948, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 53/200, Train Loss: 0.3801, Train ACC: 0.84, Train MCC: 0.6676, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 54/200, Train Loss: 0.6220, Train ACC: 0.81, Train MCC: 0.5946, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 55/200, Train Loss: 0.5402, Train ACC: 0.70, Train MCC: 0.3877, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 56/200, Train Loss: 0.4306, Train ACC: 0.78, Train MCC: 0.5378, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 57/200, Train Loss: 0.4550, Train ACC: 0.76, Train MCC: 0.5296, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 58/200, Train Loss: 0.6805, Train ACC: 0.67, Train MCC: 0.3263, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 59/200, Train Loss: 0.5527, Train ACC: 0.70, Train MCC: 0.3877, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 60/200, Train Loss: 0.3667, Train ACC: 0.82, Train MCC: 0.6245, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 61/200, Train Loss: 0.6255, Train ACC: 0.73, Train MCC: 0.4417, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 62/200, Train Loss: 0.5923, Train ACC: 0.79, Train MCC: 0.5802, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 63/200, Train Loss: 0.3987, Train ACC: 0.82, Train MCC: 0.6334, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 64/200, Train Loss: 0.7729, Train ACC: 0.76, Train MCC: 0.4955, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 65/200, Train Loss: 0.4423, Train ACC: 0.75, Train MCC: 0.4697, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 66/200, Train Loss: 0.4482, Train ACC: 0.72, Train MCC: 0.4073, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 67/200, Train Loss: 0.4932, Train ACC: 0.81, Train MCC: 0.5995, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 68/200, Train Loss: 0.6655, Train ACC: 0.78, Train MCC: 0.5378, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 69/200, Train Loss: 0.6142, Train ACC: 0.82, Train MCC: 0.6278, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 70/200, Train Loss: 0.5627, Train ACC: 0.75, Train MCC: 0.4697, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 71/200, Train Loss: 0.4845, Train ACC: 0.78, Train MCC: 0.5322, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 72/200, Train Loss: 0.5898, Train ACC: 0.76, Train MCC: 0.5037, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 73/200, Train Loss: 0.6083, Train ACC: 0.75, Train MCC: 0.4761, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 74/200, Train Loss: 0.6346, Train ACC: 0.70, Train MCC: 0.3796, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 75/200, Train Loss: 0.5535, Train ACC: 0.78, Train MCC: 0.5322, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 76/200, Train Loss: 0.6614, Train ACC: 0.81, Train MCC: 0.5920, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 77/200, Train Loss: 0.7126, Train ACC: 0.78, Train MCC: 0.5453, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 78/200, Train Loss: 0.6045, Train ACC: 0.73, Train MCC: 0.4314, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 79/200, Train Loss: 0.3204, Train ACC: 0.79, Train MCC: 0.5802, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 80/200, Train Loss: 0.7133, Train ACC: 0.81, Train MCC: 0.5995, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 81/200, Train Loss: 0.4051, Train ACC: 0.81, Train MCC: 0.5995, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 82/200, Train Loss: 0.6453, Train ACC: 0.73, Train MCC: 0.4492, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 83/200, Train Loss: 0.5421, Train ACC: 0.72, Train MCC: 0.4016, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 84/200, Train Loss: 0.6031, Train ACC: 0.79, Train MCC: 0.5616, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 85/200, Train Loss: 0.4163, Train ACC: 0.87, Train MCC: 0.7228, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 86/200, Train Loss: 0.6384, Train ACC: 0.75, Train MCC: 0.4841, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 87/200, Train Loss: 0.5677, Train ACC: 0.81, Train MCC: 0.5946, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 88/200, Train Loss: 0.4188, Train ACC: 0.81, Train MCC: 0.5995, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 89/200, Train Loss: 0.6565, Train ACC: 0.73, Train MCC: 0.4417, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 90/200, Train Loss: 0.5259, Train ACC: 0.76, Train MCC: 0.4955, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 91/200, Train Loss: 0.7335, Train ACC: 0.72, Train MCC: 0.4144, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 92/200, Train Loss: 0.4145, Train ACC: 0.79, Train MCC: 0.5720, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 93/200, Train Loss: 0.5310, Train ACC: 0.75, Train MCC: 0.4697, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 94/200, Train Loss: 0.6098, Train ACC: 0.79, Train MCC: 0.5657, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 95/200, Train Loss: 0.5730, Train ACC: 0.79, Train MCC: 0.5657, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 96/200, Train Loss: 0.4458, Train ACC: 0.81, Train MCC: 0.5946, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 97/200, Train Loss: 0.3938, Train ACC: 0.81, Train MCC: 0.5946, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 98/200, Train Loss: 0.5107, Train ACC: 0.78, Train MCC: 0.5285, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 99/200, Train Loss: 0.4345, Train ACC: 0.76, Train MCC: 0.5037, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 100/200, Train Loss: 0.4147, Train ACC: 0.81, Train MCC: 0.6156, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 101/200, Train Loss: 0.4948, Train ACC: 0.76, Train MCC: 0.5192, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 102/200, Train Loss: 0.5615, Train ACC: 0.72, Train MCC: 0.3975, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 103/200, Train Loss: 0.5057, Train ACC: 0.78, Train MCC: 0.5322, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 104/200, Train Loss: 0.4279, Train ACC: 0.76, Train MCC: 0.5037, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 105/200, Train Loss: 0.6072, Train ACC: 0.72, Train MCC: 0.4328, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 106/200, Train Loss: 0.5112, Train ACC: 0.79, Train MCC: 0.5616, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 107/200, Train Loss: 0.4056, Train ACC: 0.72, Train MCC: 0.4016, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 108/200, Train Loss: 0.4680, Train ACC: 0.84, Train MCC: 0.6571, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 109/200, Train Loss: 0.4159, Train ACC: 0.75, Train MCC: 0.4841, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 110/200, Train Loss: 0.5618, Train ACC: 0.81, Train MCC: 0.5919, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 111/200, Train Loss: 0.6846, Train ACC: 0.82, Train MCC: 0.6278, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 112/200, Train Loss: 0.6652, Train ACC: 0.72, Train MCC: 0.4144, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 113/200, Train Loss: 0.3584, Train ACC: 0.78, Train MCC: 0.5322, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 114/200, Train Loss: 0.5549, Train ACC: 0.73, Train MCC: 0.4288, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 115/200, Train Loss: 0.3545, Train ACC: 0.84, Train MCC: 0.6571, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 116/200, Train Loss: 0.4465, Train ACC: 0.73, Train MCC: 0.4314, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 117/200, Train Loss: 0.5303, Train ACC: 0.76, Train MCC: 0.5037, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 118/200, Train Loss: 0.4812, Train ACC: 0.70, Train MCC: 0.3796, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 119/200, Train Loss: 0.4602, Train ACC: 0.73, Train MCC: 0.4417, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 120/200, Train Loss: 0.4817, Train ACC: 0.82, Train MCC: 0.6245, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 121/200, Train Loss: 0.6364, Train ACC: 0.78, Train MCC: 0.5285, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 122/200, Train Loss: 0.4036, Train ACC: 0.81, Train MCC: 0.6064, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 123/200, Train Loss: 0.3938, Train ACC: 0.76, Train MCC: 0.5037, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 124/200, Train Loss: 0.5242, Train ACC: 0.67, Train MCC: 0.3032, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 125/200, Train Loss: 0.5515, Train ACC: 0.78, Train MCC: 0.5285, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 126/200, Train Loss: 0.4544, Train ACC: 0.82, Train MCC: 0.6278, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 127/200, Train Loss: 0.5094, Train ACC: 0.78, Train MCC: 0.5322, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 128/200, Train Loss: 0.4208, Train ACC: 0.79, Train MCC: 0.5720, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 129/200, Train Loss: 0.4495, Train ACC: 0.81, Train MCC: 0.5920, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 130/200, Train Loss: 0.4601, Train ACC: 0.76, Train MCC: 0.5037, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 131/200, Train Loss: 0.5895, Train ACC: 0.82, Train MCC: 0.6237, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 132/200, Train Loss: 0.4758, Train ACC: 0.76, Train MCC: 0.5037, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 133/200, Train Loss: 0.4744, Train ACC: 0.70, Train MCC: 0.3796, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 134/200, Train Loss: 0.4314, Train ACC: 0.82, Train MCC: 0.6245, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 135/200, Train Loss: 0.4671, Train ACC: 0.81, Train MCC: 0.5919, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 136/200, Train Loss: 0.4367, Train ACC: 0.81, Train MCC: 0.5946, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 137/200, Train Loss: 0.4495, Train ACC: 0.81, Train MCC: 0.5995, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 138/200, Train Loss: 0.4238, Train ACC: 0.76, Train MCC: 0.5037, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 139/200, Train Loss: 0.3998, Train ACC: 0.79, Train MCC: 0.5802, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 140/200, Train Loss: 0.4275, Train ACC: 0.79, Train MCC: 0.5596, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 141/200, Train Loss: 0.3666, Train ACC: 0.79, Train MCC: 0.5616, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 142/200, Train Loss: 0.4051, Train ACC: 0.85, Train MCC: 0.6912, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 143/200, Train Loss: 0.5525, Train ACC: 0.73, Train MCC: 0.4582, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 144/200, Train Loss: 0.6399, Train ACC: 0.70, Train MCC: 0.3796, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 145/200, Train Loss: 0.5026, Train ACC: 0.78, Train MCC: 0.5453, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 146/200, Train Loss: 0.4907, Train ACC: 0.78, Train MCC: 0.5285, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 147/200, Train Loss: 0.4713, Train ACC: 0.81, Train MCC: 0.5946, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 148/200, Train Loss: 0.5247, Train ACC: 0.75, Train MCC: 0.4697, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 149/200, Train Loss: 0.6548, Train ACC: 0.76, Train MCC: 0.5106, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 150/200, Train Loss: 0.5667, Train ACC: 0.66, Train MCC: 0.2747, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 151/200, Train Loss: 0.7614, Train ACC: 0.69, Train MCC: 0.3719, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 152/200, Train Loss: 0.3934, Train ACC: 0.79, Train MCC: 0.5596, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 153/200, Train Loss: 0.6061, Train ACC: 0.75, Train MCC: 0.4761, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 154/200, Train Loss: 0.4370, Train ACC: 0.82, Train MCC: 0.6334, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 155/200, Train Loss: 0.6072, Train ACC: 0.78, Train MCC: 0.5322, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 156/200, Train Loss: 0.4552, Train ACC: 0.76, Train MCC: 0.4986, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 157/200, Train Loss: 0.3917, Train ACC: 0.81, Train MCC: 0.5920, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 158/200, Train Loss: 0.5251, Train ACC: 0.70, Train MCC: 0.3673, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 159/200, Train Loss: 0.5298, Train ACC: 0.76, Train MCC: 0.4955, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 160/200, Train Loss: 0.5492, Train ACC: 0.75, Train MCC: 0.4761, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 161/200, Train Loss: 0.6018, Train ACC: 0.75, Train MCC: 0.4697, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 162/200, Train Loss: 0.3995, Train ACC: 0.76, Train MCC: 0.4986, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 163/200, Train Loss: 0.4076, Train ACC: 0.75, Train MCC: 0.4761, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 164/200, Train Loss: 0.4412, Train ACC: 0.79, Train MCC: 0.5596, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 165/200, Train Loss: 0.4920, Train ACC: 0.76, Train MCC: 0.4955, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 166/200, Train Loss: 0.6284, Train ACC: 0.69, Train MCC: 0.3382, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 167/200, Train Loss: 0.3988, Train ACC: 0.78, Train MCC: 0.5378, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 168/200, Train Loss: 0.4764, Train ACC: 0.81, Train MCC: 0.5946, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 169/200, Train Loss: 0.5401, Train ACC: 0.75, Train MCC: 0.4761, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 170/200, Train Loss: 0.6621, Train ACC: 0.75, Train MCC: 0.5051, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 171/200, Train Loss: 0.4108, Train ACC: 0.73, Train MCC: 0.4417, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 172/200, Train Loss: 0.4277, Train ACC: 0.73, Train MCC: 0.4582, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 173/200, Train Loss: 0.5028, Train ACC: 0.84, Train MCC: 0.6571, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 174/200, Train Loss: 0.4590, Train ACC: 0.67, Train MCC: 0.3176, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 175/200, Train Loss: 0.4434, Train ACC: 0.78, Train MCC: 0.5322, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 176/200, Train Loss: 0.6714, Train ACC: 0.81, Train MCC: 0.5946, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 177/200, Train Loss: 0.4431, Train ACC: 0.75, Train MCC: 0.4761, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 178/200, Train Loss: 0.4012, Train ACC: 0.85, Train MCC: 0.7023, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 179/200, Train Loss: 0.5945, Train ACC: 0.78, Train MCC: 0.5453, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 180/200, Train Loss: 0.6489, Train ACC: 0.72, Train MCC: 0.4073, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 181/200, Train Loss: 0.4881, Train ACC: 0.79, Train MCC: 0.5802, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 182/200, Train Loss: 0.4576, Train ACC: 0.82, Train MCC: 0.6245, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 183/200, Train Loss: 0.6020, Train ACC: 0.79, Train MCC: 0.5657, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 184/200, Train Loss: 0.3055, Train ACC: 0.82, Train MCC: 0.6237, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 185/200, Train Loss: 0.5543, Train ACC: 0.78, Train MCC: 0.5285, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 186/200, Train Loss: 0.5506, Train ACC: 0.76, Train MCC: 0.5037, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 187/200, Train Loss: 0.6314, Train ACC: 0.79, Train MCC: 0.5905, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 188/200, Train Loss: 0.3269, Train ACC: 0.84, Train MCC: 0.6571, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 189/200, Train Loss: 0.4913, Train ACC: 0.76, Train MCC: 0.5037, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 190/200, Train Loss: 0.6112, Train ACC: 0.72, Train MCC: 0.4144, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 191/200, Train Loss: 0.8953, Train ACC: 0.78, Train MCC: 0.5660, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 192/200, Train Loss: 0.4325, Train ACC: 0.82, Train MCC: 0.6278, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 193/200, Train Loss: 0.3667, Train ACC: 0.70, Train MCC: 0.3796, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 194/200, Train Loss: 0.4608, Train ACC: 0.81, Train MCC: 0.5995, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 195/200, Train Loss: 0.5514, Train ACC: 0.76, Train MCC: 0.5192, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 196/200, Train Loss: 0.5706, Train ACC: 0.75, Train MCC: 0.4615, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 197/200, Train Loss: 0.5683, Train ACC: 0.73, Train MCC: 0.4492, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 198/200, Train Loss: 0.4116, Train ACC: 0.67, Train MCC: 0.3176, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 199/200, Train Loss: 0.5567, Train ACC: 0.75, Train MCC: 0.4697, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 200/200, Train Loss: 0.6442, Train ACC: 0.79, Train MCC: 0.5802, Val Loss: 0.7501, Val ACC: 0.53, Val MCC: 0.1643

# %%
model = vgg19
model.eval()
# 加载测试数据集
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_csv_file = "/local/data1/honzh/local_repository/FL/code/4_federated/csv_files/test_data.csv"

test_dataset = CustomDatasetCSV(csv_file=test_csv_file, transform=test_transform)

test_model(model, test_dataset)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.55      0.68      2271
#            1       0.25      0.70      0.37       490
#
#     accuracy                           0.58      2761
#    macro avg       0.57      0.62      0.53      2761
# weighted avg       0.78      0.58      0.63      2761
# {'Total Acc': 0.579,
#  'nff Acc': 0.554,
#  'aff Acc': 0.696,
#  'Precision': 0.252,
#  'Recall': 0.696,
#  'Accuracy': 0.579,
#  'AUC': 0.625,
#  'MCC': 0.191,
#  'F1 Score': 0.37,
#  'ROC_AUC': 0.625,
#  'PRC-AUC': 0.229}

# %% [markdown]
# # ResNet50 50% freezed

# %%
from torchvision.models import resnet50, ResNet50_Weights
from torchvision import transforms, models

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

model = models.resnet50(weights=ResNet50_Weights.DEFAULT)

num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)

# layer number
total_layers = len(list(model.children()))

# freeze 50% layer
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False

# modify full connection layer
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)

#---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 200
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

res50 = train_custom_model(model, train_dataset,val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/200, Train Loss: 0.6988, Train ACC: 0.55, Train MCC: -0.1175, Val Loss: 0.7689, Val ACC: 0.47, Val MCC: 0.0673
# Epoch 2/200, Train Loss: 0.7352, Train ACC: 0.66, Train MCC: 0.2513, Val Loss: 0.7565, Val ACC: 0.50, Val MCC: 0.2337
# Epoch 3/200, Train Loss: 0.6834, Train ACC: 0.63, Train MCC: 0.2112, Val Loss: 0.7483, Val ACC: 0.47, Val MCC: 0.1624
# Epoch 4/200, Train Loss: 0.6816, Train ACC: 0.61, Train MCC: 0.2253, Val Loss: 0.7456, Val ACC: 0.47, Val MCC: 0.1624
# Epoch 5/200, Train Loss: 0.6852, Train ACC: 0.60, Train MCC: 0.2736, Val Loss: 0.7337, Val ACC: 0.43, Val MCC: -0.0528
# Epoch 6/200, Train Loss: 0.6401, Train ACC: 0.55, Train MCC: 0.2461, Val Loss: 0.7230, Val ACC: 0.47, Val MCC: 0.0053
# Epoch 7/200, Train Loss: 0.6167, Train ACC: 0.46, Train MCC: 0.1148, Val Loss: 0.7148, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 8/200, Train Loss: 0.6762, Train ACC: 0.54, Train MCC: 0.2820, Val Loss: 0.7168, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 9/200, Train Loss: 0.6334, Train ACC: 0.58, Train MCC: 0.2700, Val Loss: 0.7251, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 10/200, Train Loss: 0.7191, Train ACC: 0.63, Train MCC: 0.4413, Val Loss: 0.7159, Val ACC: 0.43, Val MCC: -0.0528
# Epoch 11/200, Train Loss: 0.6240, Train ACC: 0.52, Train MCC: 0.1747, Val Loss: 0.7223, Val ACC: 0.43, Val MCC: -0.0528
# Epoch 12/200, Train Loss: 0.6449, Train ACC: 0.64, Train MCC: 0.4293, Val Loss: 0.7212, Val ACC: 0.40, Val MCC: -0.1570
# Epoch 13/200, Train Loss: 0.6197, Train ACC: 0.61, Train MCC: 0.3888, Val Loss: 0.7242, Val ACC: 0.37, Val MCC: -0.2507
# Epoch 14/200, Train Loss: 0.6428, Train ACC: 0.54, Train MCC: 0.2492, Val Loss: 0.7303, Val ACC: 0.33, Val MCC: -0.3309
# Epoch 15/200, Train Loss: 0.6273, Train ACC: 0.61, Train MCC: 0.3607, Val Loss: 0.7344, Val ACC: 0.33, Val MCC: -0.3309
# Epoch 16/200, Train Loss: 0.6246, Train ACC: 0.63, Train MCC: 0.3819, Val Loss: 0.7311, Val ACC: 0.40, Val MCC: -0.1570
# Epoch 17/200, Train Loss: 0.7361, Train ACC: 0.57, Train MCC: 0.2693, Val Loss: 0.7279, Val ACC: 0.47, Val MCC: 0.1624
# Epoch 18/200, Train Loss: 0.6777, Train ACC: 0.60, Train MCC: 0.3392, Val Loss: 0.7258, Val ACC: 0.47, Val MCC: 0.1624
# Epoch 19/200, Train Loss: 0.5681, Train ACC: 0.66, Train MCC: 0.3822, Val Loss: 0.7258, Val ACC: 0.53, Val MCC: 0.2915
# Epoch 20/200, Train Loss: 0.5942, Train ACC: 0.66, Train MCC: 0.4239, Val Loss: 0.7233, Val ACC: 0.50, Val MCC: 0.1451
# Epoch 21/200, Train Loss: 0.6745, Train ACC: 0.63, Train MCC: 0.4091, Val Loss: 0.7221, Val ACC: 0.50, Val MCC: 0.1451
# Epoch 22/200, Train Loss: 0.6350, Train ACC: 0.61, Train MCC: 0.3365, Val Loss: 0.7186, Val ACC: 0.43, Val MCC: -0.0528
# Epoch 23/200, Train Loss: 0.6322, Train ACC: 0.64, Train MCC: 0.3801, Val Loss: 0.7109, Val ACC: 0.43, Val MCC: -0.0673
# Epoch 24/200, Train Loss: 0.6440, Train ACC: 0.58, Train MCC: 0.2700, Val Loss: 0.7184, Val ACC: 0.47, Val MCC: 0.0301
# Epoch 25/200, Train Loss: 0.6415, Train ACC: 0.55, Train MCC: 0.1857, Val Loss: 0.7221, Val ACC: 0.43, Val MCC: -0.0528
# Epoch 26/200, Train Loss: 0.6327, Train ACC: 0.55, Train MCC: 0.2234, Val Loss: 0.7177, Val ACC: 0.47, Val MCC: 0.0301
# Epoch 27/200, Train Loss: 0.5620, Train ACC: 0.67, Train MCC: 0.4694, Val Loss: 0.7123, Val ACC: 0.43, Val MCC: -0.0673
# Epoch 28/200, Train Loss: 0.5963, Train ACC: 0.61, Train MCC: 0.2965, Val Loss: 0.7088, Val ACC: 0.47, Val MCC: 0.0053
# Epoch 29/200, Train Loss: 0.6236, Train ACC: 0.63, Train MCC: 0.3819, Val Loss: 0.7077, Val ACC: 0.47, Val MCC: 0.0053
# Epoch 30/200, Train Loss: 0.6533, Train ACC: 0.54, Train MCC: 0.1993, Val Loss: 0.7041, Val ACC: 0.47, Val MCC: 0.0053
# Epoch 31/200, Train Loss: 0.6246, Train ACC: 0.60, Train MCC: 0.2927, Val Loss: 0.6911, Val ACC: 0.50, Val MCC: 0.0476
# Epoch 32/200, Train Loss: 0.6934, Train ACC: 0.60, Train MCC: 0.2736, Val Loss: 0.6818, Val ACC: 0.57, Val MCC: 0.1648
# Epoch 33/200, Train Loss: 0.5975, Train ACC: 0.58, Train MCC: 0.2700, Val Loss: 0.6844, Val ACC: 0.57, Val MCC: 0.1648
# Epoch 34/200, Train Loss: 0.6145, Train ACC: 0.61, Train MCC: 0.3153, Val Loss: 0.6988, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 35/200, Train Loss: 0.6013, Train ACC: 0.67, Train MCC: 0.4449, Val Loss: 0.6952, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 36/200, Train Loss: 0.6307, Train ACC: 0.60, Train MCC: 0.2736, Val Loss: 0.6955, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 37/200, Train Loss: 0.6076, Train ACC: 0.64, Train MCC: 0.3801, Val Loss: 0.6924, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 38/200, Train Loss: 0.5563, Train ACC: 0.61, Train MCC: 0.2965, Val Loss: 0.6932, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 39/200, Train Loss: 0.6335, Train ACC: 0.60, Train MCC: 0.3144, Val Loss: 0.6989, Val ACC: 0.50, Val MCC: 0.0476
# Epoch 40/200, Train Loss: 0.6578, Train ACC: 0.67, Train MCC: 0.4449, Val Loss: 0.7009, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 41/200, Train Loss: 0.7415, Train ACC: 0.61, Train MCC: 0.3365, Val Loss: 0.6953, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 42/200, Train Loss: 0.6966, Train ACC: 0.63, Train MCC: 0.3819, Val Loss: 0.6970, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 43/200, Train Loss: 0.6226, Train ACC: 0.61, Train MCC: 0.3365, Val Loss: 0.7000, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 44/200, Train Loss: 0.6316, Train ACC: 0.64, Train MCC: 0.3599, Val Loss: 0.6969, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 45/200, Train Loss: 0.6567, Train ACC: 0.57, Train MCC: 0.2469, Val Loss: 0.6970, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 46/200, Train Loss: 0.6625, Train ACC: 0.58, Train MCC: 0.2920, Val Loss: 0.6929, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 47/200, Train Loss: 0.7088, Train ACC: 0.49, Train MCC: 0.0861, Val Loss: 0.6874, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 48/200, Train Loss: 0.6821, Train ACC: 0.64, Train MCC: 0.3599, Val Loss: 0.6840, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 49/200, Train Loss: 0.7061, Train ACC: 0.64, Train MCC: 0.3801, Val Loss: 0.6809, Val ACC: 0.60, Val MCC: 0.2466
# Epoch 50/200, Train Loss: 0.6057, Train ACC: 0.60, Train MCC: 0.3144, Val Loss: 0.6823, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 51/200, Train Loss: 0.6136, Train ACC: 0.58, Train MCC: 0.3474, Val Loss: 0.6824, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 52/200, Train Loss: 0.7271, Train ACC: 0.54, Train MCC: 0.2223, Val Loss: 0.6808, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 53/200, Train Loss: 0.6853, Train ACC: 0.58, Train MCC: 0.2920, Val Loss: 0.6803, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 54/200, Train Loss: 0.5784, Train ACC: 0.67, Train MCC: 0.4694, Val Loss: 0.6787, Val ACC: 0.50, Val MCC: 0.0476
# Epoch 55/200, Train Loss: 0.6326, Train ACC: 0.64, Train MCC: 0.3599, Val Loss: 0.6797, Val ACC: 0.47, Val MCC: -0.0326
# Epoch 56/200, Train Loss: 0.5559, Train ACC: 0.66, Train MCC: 0.4239, Val Loss: 0.6793, Val ACC: 0.47, Val MCC: -0.0326
# Epoch 57/200, Train Loss: 0.6342, Train ACC: 0.61, Train MCC: 0.3153, Val Loss: 0.6844, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 58/200, Train Loss: 0.7138, Train ACC: 0.61, Train MCC: 0.2965, Val Loss: 0.6836, Val ACC: 0.50, Val MCC: 0.0476
# Epoch 59/200, Train Loss: 0.7370, Train ACC: 0.60, Train MCC: 0.2927, Val Loss: 0.6830, Val ACC: 0.50, Val MCC: 0.0476
# Epoch 60/200, Train Loss: 0.5992, Train ACC: 0.55, Train MCC: 0.2234, Val Loss: 0.6863, Val ACC: 0.50, Val MCC: 0.0476
# Epoch 61/200, Train Loss: 0.7185, Train ACC: 0.55, Train MCC: 0.1857, Val Loss: 0.6887, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 62/200, Train Loss: 0.6622, Train ACC: 0.61, Train MCC: 0.3365, Val Loss: 0.6882, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 63/200, Train Loss: 0.6663, Train ACC: 0.51, Train MCC: 0.0813, Val Loss: 0.6864, Val ACC: 0.50, Val MCC: 0.0476
# Epoch 64/200, Train Loss: 0.5946, Train ACC: 0.60, Train MCC: 0.2927, Val Loss: 0.6833, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 65/200, Train Loss: 0.5608, Train ACC: 0.58, Train MCC: 0.2505, Val Loss: 0.6808, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 66/200, Train Loss: 0.5883, Train ACC: 0.64, Train MCC: 0.3420, Val Loss: 0.6809, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 67/200, Train Loss: 0.6223, Train ACC: 0.60, Train MCC: 0.2927, Val Loss: 0.6855, Val ACC: 0.50, Val MCC: 0.0476
# Epoch 68/200, Train Loss: 0.6041, Train ACC: 0.64, Train MCC: 0.3599, Val Loss: 0.6820, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 69/200, Train Loss: 0.6842, Train ACC: 0.60, Train MCC: 0.3144, Val Loss: 0.6806, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 70/200, Train Loss: 0.6148, Train ACC: 0.51, Train MCC: 0.0959, Val Loss: 0.6796, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 71/200, Train Loss: 0.6760, Train ACC: 0.66, Train MCC: 0.4494, Val Loss: 0.6780, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 72/200, Train Loss: 0.5770, Train ACC: 0.60, Train MCC: 0.3144, Val Loss: 0.6797, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 73/200, Train Loss: 0.6809, Train ACC: 0.67, Train MCC: 0.4045, Val Loss: 0.6717, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 74/200, Train Loss: 0.6994, Train ACC: 0.64, Train MCC: 0.4293, Val Loss: 0.6734, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 75/200, Train Loss: 0.6551, Train ACC: 0.52, Train MCC: 0.1747, Val Loss: 0.6777, Val ACC: 0.47, Val MCC: -0.0326
# Epoch 76/200, Train Loss: 0.6340, Train ACC: 0.58, Train MCC: 0.2700, Val Loss: 0.6796, Val ACC: 0.53, Val MCC: 0.0860
# Epoch 77/200, Train Loss: 0.6537, Train ACC: 0.55, Train MCC: 0.2035, Val Loss: 0.6791, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 78/200, Train Loss: 0.5768, Train ACC: 0.67, Train MCC: 0.4694, Val Loss: 0.6818, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 79/200, Train Loss: 0.6053, Train ACC: 0.67, Train MCC: 0.4694, Val Loss: 0.6824, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 80/200, Train Loss: 0.6772, Train ACC: 0.67, Train MCC: 0.4449, Val Loss: 0.6889, Val ACC: 0.50, Val MCC: 0.0476
# Epoch 81/200, Train Loss: 0.6282, Train ACC: 0.54, Train MCC: 0.1615, Val Loss: 0.6820, Val ACC: 0.57, Val MCC: 0.1648
# Epoch 82/200, Train Loss: 0.7279, Train ACC: 0.52, Train MCC: 0.1370, Val Loss: 0.6806, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 83/200, Train Loss: 0.6369, Train ACC: 0.63, Train MCC: 0.3193, Val Loss: 0.6835, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 84/200, Train Loss: 0.5987, Train ACC: 0.60, Train MCC: 0.2564, Val Loss: 0.6825, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 85/200, Train Loss: 0.6600, Train ACC: 0.55, Train MCC: 0.1696, Val Loss: 0.6826, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 86/200, Train Loss: 0.5928, Train ACC: 0.63, Train MCC: 0.3819, Val Loss: 0.6823, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 87/200, Train Loss: 0.6949, Train ACC: 0.63, Train MCC: 0.3583, Val Loss: 0.6802, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 88/200, Train Loss: 0.7278, Train ACC: 0.58, Train MCC: 0.2920, Val Loss: 0.6792, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 89/200, Train Loss: 0.5810, Train ACC: 0.58, Train MCC: 0.2505, Val Loss: 0.6773, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 90/200, Train Loss: 0.7363, Train ACC: 0.66, Train MCC: 0.4017, Val Loss: 0.6803, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 91/200, Train Loss: 0.6575, Train ACC: 0.60, Train MCC: 0.2564, Val Loss: 0.6802, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 92/200, Train Loss: 0.6081, Train ACC: 0.60, Train MCC: 0.2927, Val Loss: 0.6808, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 93/200, Train Loss: 0.5998, Train ACC: 0.66, Train MCC: 0.4017, Val Loss: 0.6793, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 94/200, Train Loss: 0.5939, Train ACC: 0.55, Train MCC: 0.2035, Val Loss: 0.6810, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 95/200, Train Loss: 0.7148, Train ACC: 0.45, Train MCC: -0.0104, Val Loss: 0.6998, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 96/200, Train Loss: 0.6542, Train ACC: 0.67, Train MCC: 0.4449, Val Loss: 0.6938, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 97/200, Train Loss: 0.6302, Train ACC: 0.64, Train MCC: 0.4029, Val Loss: 0.6996, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 98/200, Train Loss: 0.6249, Train ACC: 0.61, Train MCC: 0.2965, Val Loss: 0.6922, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 99/200, Train Loss: 0.6710, Train ACC: 0.57, Train MCC: 0.2693, Val Loss: 0.6909, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 100/200, Train Loss: 0.6616, Train ACC: 0.58, Train MCC: 0.2700, Val Loss: 0.6868, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 101/200, Train Loss: 0.6607, Train ACC: 0.55, Train MCC: 0.2035, Val Loss: 0.6868, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 102/200, Train Loss: 0.7074, Train ACC: 0.72, Train MCC: 0.4889, Val Loss: 0.6787, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 103/200, Train Loss: 0.6836, Train ACC: 0.66, Train MCC: 0.3822, Val Loss: 0.6718, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 104/200, Train Loss: 0.6082, Train ACC: 0.63, Train MCC: 0.3193, Val Loss: 0.6758, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 105/200, Train Loss: 0.6362, Train ACC: 0.60, Train MCC: 0.2736, Val Loss: 0.6774, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 106/200, Train Loss: 0.6555, Train ACC: 0.64, Train MCC: 0.3801, Val Loss: 0.6750, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 107/200, Train Loss: 0.6443, Train ACC: 0.58, Train MCC: 0.2700, Val Loss: 0.6780, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 108/200, Train Loss: 0.6638, Train ACC: 0.63, Train MCC: 0.3193, Val Loss: 0.6752, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 109/200, Train Loss: 0.5895, Train ACC: 0.64, Train MCC: 0.4029, Val Loss: 0.6774, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 110/200, Train Loss: 0.6252, Train ACC: 0.60, Train MCC: 0.2927, Val Loss: 0.6823, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 111/200, Train Loss: 0.5832, Train ACC: 0.63, Train MCC: 0.3583, Val Loss: 0.6816, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 112/200, Train Loss: 0.6081, Train ACC: 0.66, Train MCC: 0.4494, Val Loss: 0.6806, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 113/200, Train Loss: 0.6171, Train ACC: 0.60, Train MCC: 0.3144, Val Loss: 0.6834, Val ACC: 0.50, Val MCC: 0.0476
# Epoch 114/200, Train Loss: 0.6105, Train ACC: 0.61, Train MCC: 0.3153, Val Loss: 0.6830, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 115/200, Train Loss: 0.7094, Train ACC: 0.61, Train MCC: 0.3365, Val Loss: 0.6778, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 116/200, Train Loss: 0.7308, Train ACC: 0.57, Train MCC: 0.2953, Val Loss: 0.6776, Val ACC: 0.50, Val MCC: 0.0476
# Epoch 117/200, Train Loss: 0.6069, Train ACC: 0.60, Train MCC: 0.3144, Val Loss: 0.6796, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 118/200, Train Loss: 0.6252, Train ACC: 0.55, Train MCC: 0.1857, Val Loss: 0.6808, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 119/200, Train Loss: 0.6384, Train ACC: 0.61, Train MCC: 0.3153, Val Loss: 0.6804, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 120/200, Train Loss: 0.5911, Train ACC: 0.67, Train MCC: 0.4980, Val Loss: 0.6842, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 121/200, Train Loss: 0.6331, Train ACC: 0.63, Train MCC: 0.3193, Val Loss: 0.6866, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 122/200, Train Loss: 0.6008, Train ACC: 0.57, Train MCC: 0.2271, Val Loss: 0.6904, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 123/200, Train Loss: 0.6544, Train ACC: 0.63, Train MCC: 0.3377, Val Loss: 0.6861, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 124/200, Train Loss: 0.7224, Train ACC: 0.70, Train MCC: 0.4869, Val Loss: 0.6827, Val ACC: 0.50, Val MCC: 0.0476
# Epoch 125/200, Train Loss: 0.7375, Train ACC: 0.60, Train MCC: 0.2736, Val Loss: 0.6828, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 126/200, Train Loss: 0.6725, Train ACC: 0.64, Train MCC: 0.4293, Val Loss: 0.6807, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 127/200, Train Loss: 0.6820, Train ACC: 0.64, Train MCC: 0.3801, Val Loss: 0.6781, Val ACC: 0.57, Val MCC: 0.1648
# Epoch 128/200, Train Loss: 0.6355, Train ACC: 0.61, Train MCC: 0.2796, Val Loss: 0.6813, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 129/200, Train Loss: 0.6262, Train ACC: 0.69, Train MCC: 0.4895, Val Loss: 0.6835, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 130/200, Train Loss: 0.7797, Train ACC: 0.55, Train MCC: 0.2035, Val Loss: 0.6823, Val ACC: 0.60, Val MCC: 0.2466
# Epoch 131/200, Train Loss: 0.6307, Train ACC: 0.61, Train MCC: 0.3365, Val Loss: 0.6844, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 132/200, Train Loss: 0.6098, Train ACC: 0.61, Train MCC: 0.2965, Val Loss: 0.6825, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 133/200, Train Loss: 0.5878, Train ACC: 0.69, Train MCC: 0.4658, Val Loss: 0.6838, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 134/200, Train Loss: 0.6285, Train ACC: 0.64, Train MCC: 0.4029, Val Loss: 0.6856, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 135/200, Train Loss: 0.6163, Train ACC: 0.60, Train MCC: 0.2927, Val Loss: 0.6855, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 136/200, Train Loss: 0.7073, Train ACC: 0.66, Train MCC: 0.4239, Val Loss: 0.6872, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 137/200, Train Loss: 0.6170, Train ACC: 0.64, Train MCC: 0.4293, Val Loss: 0.6879, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 138/200, Train Loss: 0.7281, Train ACC: 0.54, Train MCC: 0.2223, Val Loss: 0.6886, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 139/200, Train Loss: 0.6006, Train ACC: 0.61, Train MCC: 0.3607, Val Loss: 0.6846, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 140/200, Train Loss: 0.6211, Train ACC: 0.67, Train MCC: 0.4694, Val Loss: 0.6870, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 141/200, Train Loss: 0.7074, Train ACC: 0.58, Train MCC: 0.2700, Val Loss: 0.6868, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 142/200, Train Loss: 0.6775, Train ACC: 0.67, Train MCC: 0.4449, Val Loss: 0.6852, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 143/200, Train Loss: 0.6679, Train ACC: 0.61, Train MCC: 0.2965, Val Loss: 0.6887, Val ACC: 0.50, Val MCC: 0.0476
# Epoch 144/200, Train Loss: 0.6072, Train ACC: 0.64, Train MCC: 0.4029, Val Loss: 0.6838, Val ACC: 0.50, Val MCC: 0.0476
# Epoch 145/200, Train Loss: 0.5907, Train ACC: 0.70, Train MCC: 0.4669, Val Loss: 0.6862, Val ACC: 0.47, Val MCC: -0.0326
# Epoch 146/200, Train Loss: 0.6387, Train ACC: 0.61, Train MCC: 0.3153, Val Loss: 0.6828, Val ACC: 0.47, Val MCC: -0.0326
# Epoch 147/200, Train Loss: 0.6483, Train ACC: 0.66, Train MCC: 0.4017, Val Loss: 0.6833, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 148/200, Train Loss: 0.6567, Train ACC: 0.57, Train MCC: 0.1934, Val Loss: 0.6813, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 149/200, Train Loss: 0.6295, Train ACC: 0.61, Train MCC: 0.3153, Val Loss: 0.6833, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 150/200, Train Loss: 0.7189, Train ACC: 0.66, Train MCC: 0.3822, Val Loss: 0.6823, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 151/200, Train Loss: 0.7080, Train ACC: 0.64, Train MCC: 0.3801, Val Loss: 0.6816, Val ACC: 0.50, Val MCC: 0.0476
# Epoch 152/200, Train Loss: 0.7082, Train ACC: 0.70, Train MCC: 0.4869, Val Loss: 0.6776, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 153/200, Train Loss: 0.6012, Train ACC: 0.70, Train MCC: 0.4669, Val Loss: 0.6888, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 154/200, Train Loss: 0.7340, Train ACC: 0.64, Train MCC: 0.3420, Val Loss: 0.6908, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 155/200, Train Loss: 0.6059, Train ACC: 0.60, Train MCC: 0.2927, Val Loss: 0.6893, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 156/200, Train Loss: 0.6341, Train ACC: 0.64, Train MCC: 0.3599, Val Loss: 0.6842, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 157/200, Train Loss: 0.6972, Train ACC: 0.66, Train MCC: 0.4239, Val Loss: 0.6807, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 158/200, Train Loss: 0.6568, Train ACC: 0.57, Train MCC: 0.2693, Val Loss: 0.6802, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 159/200, Train Loss: 0.6302, Train ACC: 0.57, Train MCC: 0.2693, Val Loss: 0.6852, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 160/200, Train Loss: 0.6369, Train ACC: 0.61, Train MCC: 0.3153, Val Loss: 0.6788, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 161/200, Train Loss: 0.6803, Train ACC: 0.60, Train MCC: 0.3683, Val Loss: 0.6796, Val ACC: 0.57, Val MCC: 0.1648
# Epoch 162/200, Train Loss: 0.5881, Train ACC: 0.60, Train MCC: 0.3144, Val Loss: 0.6779, Val ACC: 0.57, Val MCC: 0.1648
# Epoch 163/200, Train Loss: 0.6762, Train ACC: 0.67, Train MCC: 0.4449, Val Loss: 0.6767, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 164/200, Train Loss: 0.6058, Train ACC: 0.58, Train MCC: 0.2505, Val Loss: 0.6740, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 165/200, Train Loss: 0.6844, Train ACC: 0.58, Train MCC: 0.2505, Val Loss: 0.6796, Val ACC: 0.57, Val MCC: 0.1648
# Epoch 166/200, Train Loss: 0.6394, Train ACC: 0.63, Train MCC: 0.3377, Val Loss: 0.6857, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 167/200, Train Loss: 0.7458, Train ACC: 0.57, Train MCC: 0.2693, Val Loss: 0.6833, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 168/200, Train Loss: 0.6311, Train ACC: 0.54, Train MCC: 0.2223, Val Loss: 0.6809, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 169/200, Train Loss: 0.6526, Train ACC: 0.63, Train MCC: 0.3583, Val Loss: 0.6806, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 170/200, Train Loss: 0.6733, Train ACC: 0.57, Train MCC: 0.2271, Val Loss: 0.6781, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 171/200, Train Loss: 0.6143, Train ACC: 0.60, Train MCC: 0.3144, Val Loss: 0.6873, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 172/200, Train Loss: 0.7015, Train ACC: 0.63, Train MCC: 0.3819, Val Loss: 0.7020, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 173/200, Train Loss: 0.6981, Train ACC: 0.60, Train MCC: 0.2927, Val Loss: 0.6967, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 174/200, Train Loss: 0.6051, Train ACC: 0.69, Train MCC: 0.4895, Val Loss: 0.6926, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 175/200, Train Loss: 0.7162, Train ACC: 0.61, Train MCC: 0.3365, Val Loss: 0.6870, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 176/200, Train Loss: 0.6398, Train ACC: 0.52, Train MCC: 0.1370, Val Loss: 0.6831, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 177/200, Train Loss: 0.5941, Train ACC: 0.69, Train MCC: 0.5169, Val Loss: 0.6877, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 178/200, Train Loss: 0.6815, Train ACC: 0.60, Train MCC: 0.2927, Val Loss: 0.6866, Val ACC: 0.50, Val MCC: 0.0710
# Epoch 179/200, Train Loss: 0.6201, Train ACC: 0.54, Train MCC: 0.1615, Val Loss: 0.6875, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 180/200, Train Loss: 0.6579, Train ACC: 0.61, Train MCC: 0.3153, Val Loss: 0.6911, Val ACC: 0.50, Val MCC: 0.0476
# Epoch 181/200, Train Loss: 0.6870, Train ACC: 0.69, Train MCC: 0.4895, Val Loss: 0.6893, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 182/200, Train Loss: 0.6559, Train ACC: 0.63, Train MCC: 0.3819, Val Loss: 0.6947, Val ACC: 0.50, Val MCC: 0.0476
# Epoch 183/200, Train Loss: 0.5795, Train ACC: 0.60, Train MCC: 0.3392, Val Loss: 0.7026, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 184/200, Train Loss: 0.6551, Train ACC: 0.61, Train MCC: 0.3365, Val Loss: 0.6992, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 185/200, Train Loss: 0.6286, Train ACC: 0.55, Train MCC: 0.2234, Val Loss: 0.6946, Val ACC: 0.50, Val MCC: 0.0710
# Epoch 186/200, Train Loss: 0.6228, Train ACC: 0.57, Train MCC: 0.2271, Val Loss: 0.6944, Val ACC: 0.50, Val MCC: 0.0710
# Epoch 187/200, Train Loss: 0.6558, Train ACC: 0.61, Train MCC: 0.3888, Val Loss: 0.6911, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 188/200, Train Loss: 0.6815, Train ACC: 0.72, Train MCC: 0.5080, Val Loss: 0.6847, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 189/200, Train Loss: 0.5755, Train ACC: 0.69, Train MCC: 0.4658, Val Loss: 0.6803, Val ACC: 0.60, Val MCC: 0.2466
# Epoch 190/200, Train Loss: 0.6721, Train ACC: 0.52, Train MCC: 0.1209, Val Loss: 0.6762, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 191/200, Train Loss: 0.7084, Train ACC: 0.60, Train MCC: 0.2564, Val Loss: 0.6718, Val ACC: 0.57, Val MCC: 0.1648
# Epoch 192/200, Train Loss: 0.6108, Train ACC: 0.66, Train MCC: 0.4017, Val Loss: 0.6887, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 193/200, Train Loss: 0.6963, Train ACC: 0.61, Train MCC: 0.2965, Val Loss: 0.6903, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 194/200, Train Loss: 0.6104, Train ACC: 0.63, Train MCC: 0.3819, Val Loss: 0.6889, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 195/200, Train Loss: 0.6350, Train ACC: 0.66, Train MCC: 0.4017, Val Loss: 0.6886, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 196/200, Train Loss: 0.6548, Train ACC: 0.57, Train MCC: 0.2693, Val Loss: 0.6876, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 197/200, Train Loss: 0.5793, Train ACC: 0.70, Train MCC: 0.4869, Val Loss: 0.6878, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 198/200, Train Loss: 0.6301, Train ACC: 0.69, Train MCC: 0.4895, Val Loss: 0.6891, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 199/200, Train Loss: 0.6909, Train ACC: 0.55, Train MCC: 0.2461, Val Loss: 0.6839, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 200/200, Train Loss: 0.6224, Train ACC: 0.69, Train MCC: 0.4451, Val Loss: 0.6859, Val ACC: 0.57, Val MCC: 0.1903

# %%
model = res50
model.eval()
# 加载测试数据集
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_csv_file = "/local/data1/honzh/local_repository/FL/code/4_federated/csv_files/test_data.csv"

test_dataset = CustomDatasetCSV(csv_file=test_csv_file, transform=test_transform)

test_model(model, test_dataset)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.45      0.60      2271
#            1       0.23      0.76      0.35       490
#
#     accuracy                           0.51      2761
#    macro avg       0.56      0.61      0.48      2761
# weighted avg       0.78      0.51      0.56      2761
# {'Total Acc': 0.507,
#  'nff Acc': 0.451,
#  'aff Acc': 0.763,
#  'Precision': 0.231,
#  'Recall': 0.763,
#  'Accuracy': 0.507,
#  'AUC': 0.607,
#  'MCC': 0.167,
#  'F1 Score': 0.355,
#  'ROC_AUC': 0.607,
#  'PRC-AUC': 0.218}

# %% [markdown]
# # ResNet 101

# %%
from torchvision.models import resnet101, ResNet101_Weights
from torchvision import transforms, models

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the ResNet-101 model
model = models.resnet101(weights=ResNet101_Weights.DEFAULT)

num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)

# layer number
total_layers = len(list(model.children()))

# freeze 50% layer
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False

# modify full connection layer
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)
#---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 200
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

res101 = train_custom_model(model, train_dataset,val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/200, Train Loss: 0.6798, Train ACC: 0.63, Train MCC: 0.3028, Val Loss: 0.7868, Val ACC: 0.43, Val MCC: -0.0360
# Epoch 2/200, Train Loss: 0.6662, Train ACC: 0.63, Train MCC: 0.2742, Val Loss: 0.7620, Val ACC: 0.47, Val MCC: 0.0673
# Epoch 3/200, Train Loss: 0.6679, Train ACC: 0.58, Train MCC: 0.2330, Val Loss: 0.7449, Val ACC: 0.43, Val MCC: -0.0528
# Epoch 4/200, Train Loss: 0.6577, Train ACC: 0.61, Train MCC: 0.2796, Val Loss: 0.7440, Val ACC: 0.43, Val MCC: -0.0528
# Epoch 5/200, Train Loss: 0.6679, Train ACC: 0.66, Train MCC: 0.4017, Val Loss: 0.7430, Val ACC: 0.47, Val MCC: 0.0301
# Epoch 6/200, Train Loss: 0.5861, Train ACC: 0.67, Train MCC: 0.3470, Val Loss: 0.7333, Val ACC: 0.47, Val MCC: 0.0301
# Epoch 7/200, Train Loss: 0.6226, Train ACC: 0.67, Train MCC: 0.3877, Val Loss: 0.7267, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 8/200, Train Loss: 0.6032, Train ACC: 0.66, Train MCC: 0.3822, Val Loss: 0.7196, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 9/200, Train Loss: 0.5597, Train ACC: 0.73, Train MCC: 0.4950, Val Loss: 0.7180, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 10/200, Train Loss: 0.5821, Train ACC: 0.75, Train MCC: 0.5509, Val Loss: 0.7143, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 11/200, Train Loss: 0.6136, Train ACC: 0.84, Train MCC: 0.7014, Val Loss: 0.7126, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 12/200, Train Loss: 0.5417, Train ACC: 0.64, Train MCC: 0.3420, Val Loss: 0.7162, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 13/200, Train Loss: 0.6822, Train ACC: 0.70, Train MCC: 0.4869, Val Loss: 0.7277, Val ACC: 0.47, Val MCC: 0.0053
# Epoch 14/200, Train Loss: 0.7276, Train ACC: 0.69, Train MCC: 0.4451, Val Loss: 0.7254, Val ACC: 0.47, Val MCC: 0.0053
# Epoch 15/200, Train Loss: 0.6683, Train ACC: 0.70, Train MCC: 0.4669, Val Loss: 0.7266, Val ACC: 0.47, Val MCC: 0.0301
# Epoch 16/200, Train Loss: 0.6750, Train ACC: 0.70, Train MCC: 0.4201, Val Loss: 0.7270, Val ACC: 0.47, Val MCC: 0.0301
# Epoch 17/200, Train Loss: 0.5840, Train ACC: 0.67, Train MCC: 0.3726, Val Loss: 0.7281, Val ACC: 0.47, Val MCC: 0.0301
# Epoch 18/200, Train Loss: 0.6494, Train ACC: 0.69, Train MCC: 0.4107, Val Loss: 0.7239, Val ACC: 0.43, Val MCC: -0.0673
# Epoch 19/200, Train Loss: 0.6836, Train ACC: 0.70, Train MCC: 0.4669, Val Loss: 0.7281, Val ACC: 0.40, Val MCC: -0.1537
# Epoch 20/200, Train Loss: 0.5542, Train ACC: 0.66, Train MCC: 0.3492, Val Loss: 0.7315, Val ACC: 0.47, Val MCC: 0.0301
# Epoch 21/200, Train Loss: 0.6161, Train ACC: 0.72, Train MCC: 0.4573, Val Loss: 0.7297, Val ACC: 0.40, Val MCC: -0.1504
# Epoch 22/200, Train Loss: 0.6603, Train ACC: 0.69, Train MCC: 0.4107, Val Loss: 0.7293, Val ACC: 0.43, Val MCC: -0.0673
# Epoch 23/200, Train Loss: 0.6632, Train ACC: 0.73, Train MCC: 0.5111, Val Loss: 0.7253, Val ACC: 0.47, Val MCC: 0.0053
# Epoch 24/200, Train Loss: 0.6599, Train ACC: 0.73, Train MCC: 0.4810, Val Loss: 0.7250, Val ACC: 0.43, Val MCC: -0.0811
# Epoch 25/200, Train Loss: 0.5960, Train ACC: 0.81, Train MCC: 0.6156, Val Loss: 0.7137, Val ACC: 0.40, Val MCC: -0.1537
# Epoch 26/200, Train Loss: 0.6462, Train ACC: 0.67, Train MCC: 0.3726, Val Loss: 0.7144, Val ACC: 0.47, Val MCC: 0.0053
# Epoch 27/200, Train Loss: 0.6165, Train ACC: 0.75, Train MCC: 0.5051, Val Loss: 0.7164, Val ACC: 0.43, Val MCC: -0.0673
# Epoch 28/200, Train Loss: 0.5591, Train ACC: 0.76, Train MCC: 0.5562, Val Loss: 0.7181, Val ACC: 0.40, Val MCC: -0.1504
# Epoch 29/200, Train Loss: 0.7589, Train ACC: 0.66, Train MCC: 0.3352, Val Loss: 0.7152, Val ACC: 0.47, Val MCC: 0.0053
# Epoch 30/200, Train Loss: 0.5558, Train ACC: 0.69, Train MCC: 0.3834, Val Loss: 0.7136, Val ACC: 0.47, Val MCC: -0.0147
# Epoch 31/200, Train Loss: 0.6065, Train ACC: 0.69, Train MCC: 0.4107, Val Loss: 0.7076, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 32/200, Train Loss: 0.6600, Train ACC: 0.73, Train MCC: 0.4810, Val Loss: 0.7090, Val ACC: 0.43, Val MCC: -0.0673
# Epoch 33/200, Train Loss: 0.5710, Train ACC: 0.78, Train MCC: 0.5660, Val Loss: 0.7121, Val ACC: 0.50, Val MCC: 0.0710
# Epoch 34/200, Train Loss: 0.5579, Train ACC: 0.75, Train MCC: 0.5335, Val Loss: 0.7057, Val ACC: 0.47, Val MCC: -0.0147
# Epoch 35/200, Train Loss: 0.6675, Train ACC: 0.67, Train MCC: 0.3726, Val Loss: 0.7018, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 36/200, Train Loss: 0.6754, Train ACC: 0.70, Train MCC: 0.4079, Val Loss: 0.6990, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 37/200, Train Loss: 0.5652, Train ACC: 0.81, Train MCC: 0.6064, Val Loss: 0.6923, Val ACC: 0.57, Val MCC: 0.1438
# Epoch 38/200, Train Loss: 0.5592, Train ACC: 0.78, Train MCC: 0.5546, Val Loss: 0.6959, Val ACC: 0.57, Val MCC: 0.1438
# Epoch 39/200, Train Loss: 0.6303, Train ACC: 0.67, Train MCC: 0.3592, Val Loss: 0.7137, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 40/200, Train Loss: 0.6906, Train ACC: 0.81, Train MCC: 0.6403, Val Loss: 0.7091, Val ACC: 0.47, Val MCC: -0.0326
# Epoch 41/200, Train Loss: 0.5925, Train ACC: 0.76, Train MCC: 0.5192, Val Loss: 0.7058, Val ACC: 0.53, Val MCC: 0.0860
# Epoch 42/200, Train Loss: 0.5380, Train ACC: 0.81, Train MCC: 0.6268, Val Loss: 0.7074, Val ACC: 0.50, Val MCC: 0.0476
# Epoch 43/200, Train Loss: 0.6203, Train ACC: 0.78, Train MCC: 0.5546, Val Loss: 0.7032, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 44/200, Train Loss: 0.6499, Train ACC: 0.69, Train MCC: 0.4269, Val Loss: 0.7136, Val ACC: 0.50, Val MCC: 0.0476
# Epoch 45/200, Train Loss: 0.6774, Train ACC: 0.64, Train MCC: 0.2982, Val Loss: 0.7081, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 46/200, Train Loss: 0.5346, Train ACC: 0.69, Train MCC: 0.4107, Val Loss: 0.7083, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 47/200, Train Loss: 0.5496, Train ACC: 0.76, Train MCC: 0.5296, Val Loss: 0.7149, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 48/200, Train Loss: 0.6569, Train ACC: 0.69, Train MCC: 0.3834, Val Loss: 0.7079, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 49/200, Train Loss: 0.7360, Train ACC: 0.67, Train MCC: 0.3726, Val Loss: 0.7033, Val ACC: 0.53, Val MCC: 0.0860
# Epoch 50/200, Train Loss: 0.6857, Train ACC: 0.69, Train MCC: 0.3719, Val Loss: 0.7094, Val ACC: 0.57, Val MCC: 0.1648
# Epoch 51/200, Train Loss: 0.6840, Train ACC: 0.66, Train MCC: 0.3492, Val Loss: 0.7142, Val ACC: 0.50, Val MCC: 0.0476
# Epoch 52/200, Train Loss: 0.5546, Train ACC: 0.75, Train MCC: 0.5183, Val Loss: 0.7136, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 53/200, Train Loss: 0.5404, Train ACC: 0.81, Train MCC: 0.6156, Val Loss: 0.7192, Val ACC: 0.47, Val MCC: 0.0053
# Epoch 54/200, Train Loss: 0.6126, Train ACC: 0.70, Train MCC: 0.4338, Val Loss: 0.7269, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 55/200, Train Loss: 0.6800, Train ACC: 0.81, Train MCC: 0.6403, Val Loss: 0.7214, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 56/200, Train Loss: 0.5665, Train ACC: 0.70, Train MCC: 0.4201, Val Loss: 0.7212, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 57/200, Train Loss: 0.5378, Train ACC: 0.78, Train MCC: 0.5546, Val Loss: 0.7270, Val ACC: 0.47, Val MCC: -0.0147
# Epoch 58/200, Train Loss: 0.6262, Train ACC: 0.69, Train MCC: 0.3962, Val Loss: 0.7240, Val ACC: 0.47, Val MCC: -0.0147
# Epoch 59/200, Train Loss: 0.5237, Train ACC: 0.81, Train MCC: 0.6563, Val Loss: 0.7211, Val ACC: 0.47, Val MCC: -0.0147
# Epoch 60/200, Train Loss: 0.6237, Train ACC: 0.70, Train MCC: 0.4079, Val Loss: 0.7191, Val ACC: 0.47, Val MCC: -0.0147
# Epoch 61/200, Train Loss: 0.5380, Train ACC: 0.73, Train MCC: 0.4688, Val Loss: 0.7144, Val ACC: 0.50, Val MCC: 0.0476
# Epoch 62/200, Train Loss: 0.6364, Train ACC: 0.75, Train MCC: 0.5183, Val Loss: 0.7191, Val ACC: 0.47, Val MCC: -0.0147
# Epoch 63/200, Train Loss: 0.6024, Train ACC: 0.73, Train MCC: 0.4688, Val Loss: 0.7267, Val ACC: 0.47, Val MCC: -0.0147
# Epoch 64/200, Train Loss: 0.6240, Train ACC: 0.75, Train MCC: 0.5335, Val Loss: 0.7203, Val ACC: 0.47, Val MCC: -0.0147
# Epoch 65/200, Train Loss: 0.5982, Train ACC: 0.75, Train MCC: 0.5051, Val Loss: 0.7277, Val ACC: 0.43, Val MCC: -0.0951
# Epoch 66/200, Train Loss: 0.6761, Train ACC: 0.73, Train MCC: 0.4950, Val Loss: 0.7306, Val ACC: 0.43, Val MCC: -0.0951
# Epoch 67/200, Train Loss: 0.5601, Train ACC: 0.72, Train MCC: 0.4573, Val Loss: 0.7276, Val ACC: 0.50, Val MCC: 0.0476
# Epoch 68/200, Train Loss: 0.6086, Train ACC: 0.64, Train MCC: 0.3260, Val Loss: 0.7281, Val ACC: 0.47, Val MCC: 0.0053
# Epoch 69/200, Train Loss: 0.5271, Train ACC: 0.75, Train MCC: 0.5051, Val Loss: 0.7221, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 70/200, Train Loss: 0.6361, Train ACC: 0.69, Train MCC: 0.3834, Val Loss: 0.7128, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 71/200, Train Loss: 0.6990, Train ACC: 0.70, Train MCC: 0.4201, Val Loss: 0.7181, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 72/200, Train Loss: 0.6143, Train ACC: 0.69, Train MCC: 0.4269, Val Loss: 0.7209, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 73/200, Train Loss: 0.6410, Train ACC: 0.75, Train MCC: 0.5051, Val Loss: 0.7130, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 74/200, Train Loss: 0.7676, Train ACC: 0.73, Train MCC: 0.4810, Val Loss: 0.7126, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 75/200, Train Loss: 0.7290, Train ACC: 0.64, Train MCC: 0.2982, Val Loss: 0.7178, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 76/200, Train Loss: 0.7238, Train ACC: 0.72, Train MCC: 0.4573, Val Loss: 0.7244, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 77/200, Train Loss: 0.6490, Train ACC: 0.75, Train MCC: 0.5335, Val Loss: 0.7224, Val ACC: 0.47, Val MCC: 0.0053
# Epoch 78/200, Train Loss: 0.6697, Train ACC: 0.70, Train MCC: 0.4079, Val Loss: 0.7276, Val ACC: 0.50, Val MCC: 0.0710
# Epoch 79/200, Train Loss: 0.6520, Train ACC: 0.66, Train MCC: 0.3352, Val Loss: 0.7051, Val ACC: 0.60, Val MCC: 0.2466
# Epoch 80/200, Train Loss: 0.6292, Train ACC: 0.76, Train MCC: 0.5419, Val Loss: 0.6964, Val ACC: 0.60, Val MCC: 0.2466
# Epoch 81/200, Train Loss: 0.6834, Train ACC: 0.69, Train MCC: 0.4107, Val Loss: 0.6950, Val ACC: 0.60, Val MCC: 0.2466
# Epoch 82/200, Train Loss: 0.6893, Train ACC: 0.64, Train MCC: 0.3114, Val Loss: 0.7042, Val ACC: 0.50, Val MCC: 0.0476
# Epoch 83/200, Train Loss: 0.5847, Train ACC: 0.72, Train MCC: 0.4442, Val Loss: 0.7048, Val ACC: 0.50, Val MCC: 0.0710
# Epoch 84/200, Train Loss: 0.5899, Train ACC: 0.76, Train MCC: 0.5419, Val Loss: 0.7044, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 85/200, Train Loss: 0.5375, Train ACC: 0.67, Train MCC: 0.4045, Val Loss: 0.7046, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 86/200, Train Loss: 0.6437, Train ACC: 0.66, Train MCC: 0.3648, Val Loss: 0.7034, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 87/200, Train Loss: 0.5277, Train ACC: 0.72, Train MCC: 0.4889, Val Loss: 0.7051, Val ACC: 0.50, Val MCC: 0.0710
# Epoch 88/200, Train Loss: 0.6229, Train ACC: 0.78, Train MCC: 0.5660, Val Loss: 0.6994, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 89/200, Train Loss: 0.5229, Train ACC: 0.66, Train MCC: 0.3492, Val Loss: 0.7033, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 90/200, Train Loss: 0.5956, Train ACC: 0.75, Train MCC: 0.5335, Val Loss: 0.7098, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 91/200, Train Loss: 0.5669, Train ACC: 0.73, Train MCC: 0.5111, Val Loss: 0.7211, Val ACC: 0.47, Val MCC: 0.0301
# Epoch 92/200, Train Loss: 0.6739, Train ACC: 0.69, Train MCC: 0.4269, Val Loss: 0.7203, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 93/200, Train Loss: 0.6415, Train ACC: 0.70, Train MCC: 0.4338, Val Loss: 0.7225, Val ACC: 0.43, Val MCC: -0.0673
# Epoch 94/200, Train Loss: 0.6787, Train ACC: 0.73, Train MCC: 0.4810, Val Loss: 0.7163, Val ACC: 0.50, Val MCC: 0.1451
# Epoch 95/200, Train Loss: 0.5781, Train ACC: 0.70, Train MCC: 0.4338, Val Loss: 0.7224, Val ACC: 0.50, Val MCC: 0.1451
# Epoch 96/200, Train Loss: 0.6590, Train ACC: 0.72, Train MCC: 0.4442, Val Loss: 0.7191, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 97/200, Train Loss: 0.5899, Train ACC: 0.75, Train MCC: 0.4937, Val Loss: 0.7190, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 98/200, Train Loss: 0.5819, Train ACC: 0.70, Train MCC: 0.4338, Val Loss: 0.7225, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 99/200, Train Loss: 0.6810, Train ACC: 0.75, Train MCC: 0.5183, Val Loss: 0.7208, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 100/200, Train Loss: 0.5489, Train ACC: 0.75, Train MCC: 0.5183, Val Loss: 0.7299, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 101/200, Train Loss: 0.5905, Train ACC: 0.73, Train MCC: 0.4810, Val Loss: 0.7331, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 102/200, Train Loss: 0.6177, Train ACC: 0.70, Train MCC: 0.4494, Val Loss: 0.7300, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 103/200, Train Loss: 0.5546, Train ACC: 0.78, Train MCC: 0.5660, Val Loss: 0.7310, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 104/200, Train Loss: 0.6354, Train ACC: 0.70, Train MCC: 0.4669, Val Loss: 0.7339, Val ACC: 0.43, Val MCC: -0.0811
# Epoch 105/200, Train Loss: 0.5769, Train ACC: 0.67, Train MCC: 0.3726, Val Loss: 0.7243, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 106/200, Train Loss: 0.6151, Train ACC: 0.72, Train MCC: 0.4442, Val Loss: 0.7334, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 107/200, Train Loss: 0.6320, Train ACC: 0.75, Train MCC: 0.5051, Val Loss: 0.7216, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 108/200, Train Loss: 0.6870, Train ACC: 0.75, Train MCC: 0.5183, Val Loss: 0.7232, Val ACC: 0.50, Val MCC: 0.0710
# Epoch 109/200, Train Loss: 0.6630, Train ACC: 0.76, Train MCC: 0.5296, Val Loss: 0.7269, Val ACC: 0.47, Val MCC: 0.0053
# Epoch 110/200, Train Loss: 0.5674, Train ACC: 0.69, Train MCC: 0.4107, Val Loss: 0.7296, Val ACC: 0.47, Val MCC: -0.0147
# Epoch 111/200, Train Loss: 0.6432, Train ACC: 0.78, Train MCC: 0.5660, Val Loss: 0.7254, Val ACC: 0.50, Val MCC: 0.0710
# Epoch 112/200, Train Loss: 0.5971, Train ACC: 0.67, Train MCC: 0.3726, Val Loss: 0.7328, Val ACC: 0.47, Val MCC: 0.0301
# Epoch 113/200, Train Loss: 0.6685, Train ACC: 0.69, Train MCC: 0.4107, Val Loss: 0.7336, Val ACC: 0.47, Val MCC: 0.0053
# Epoch 114/200, Train Loss: 0.5680, Train ACC: 0.76, Train MCC: 0.5562, Val Loss: 0.7397, Val ACC: 0.47, Val MCC: 0.0053
# Epoch 115/200, Train Loss: 0.5751, Train ACC: 0.72, Train MCC: 0.4573, Val Loss: 0.7288, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 116/200, Train Loss: 0.5012, Train ACC: 0.70, Train MCC: 0.4494, Val Loss: 0.7302, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 117/200, Train Loss: 0.5583, Train ACC: 0.75, Train MCC: 0.4937, Val Loss: 0.7275, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 118/200, Train Loss: 0.6158, Train ACC: 0.73, Train MCC: 0.4950, Val Loss: 0.7289, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 119/200, Train Loss: 0.6478, Train ACC: 0.72, Train MCC: 0.4721, Val Loss: 0.7280, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 120/200, Train Loss: 0.5587, Train ACC: 0.72, Train MCC: 0.4573, Val Loss: 0.7306, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 121/200, Train Loss: 0.6726, Train ACC: 0.73, Train MCC: 0.5111, Val Loss: 0.7332, Val ACC: 0.47, Val MCC: 0.0301
# Epoch 122/200, Train Loss: 0.5533, Train ACC: 0.78, Train MCC: 0.5949, Val Loss: 0.7122, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 123/200, Train Loss: 0.5801, Train ACC: 0.72, Train MCC: 0.4721, Val Loss: 0.7136, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 124/200, Train Loss: 0.5442, Train ACC: 0.69, Train MCC: 0.3834, Val Loss: 0.7117, Val ACC: 0.47, Val MCC: 0.0053
# Epoch 125/200, Train Loss: 0.6623, Train ACC: 0.73, Train MCC: 0.4950, Val Loss: 0.7244, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 126/200, Train Loss: 0.6306, Train ACC: 0.73, Train MCC: 0.4810, Val Loss: 0.7313, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 127/200, Train Loss: 0.4660, Train ACC: 0.72, Train MCC: 0.4721, Val Loss: 0.7392, Val ACC: 0.47, Val MCC: 0.0301
# Epoch 128/200, Train Loss: 0.5674, Train ACC: 0.73, Train MCC: 0.4810, Val Loss: 0.7356, Val ACC: 0.47, Val MCC: 0.0301
# Epoch 129/200, Train Loss: 0.5915, Train ACC: 0.73, Train MCC: 0.5111, Val Loss: 0.7411, Val ACC: 0.43, Val MCC: -0.0528
# Epoch 130/200, Train Loss: 0.5356, Train ACC: 0.73, Train MCC: 0.4810, Val Loss: 0.7338, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 131/200, Train Loss: 0.5450, Train ACC: 0.76, Train MCC: 0.5419, Val Loss: 0.7344, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 132/200, Train Loss: 0.4916, Train ACC: 0.75, Train MCC: 0.5183, Val Loss: 0.7365, Val ACC: 0.43, Val MCC: -0.0528
# Epoch 133/200, Train Loss: 0.7372, Train ACC: 0.73, Train MCC: 0.4810, Val Loss: 0.7327, Val ACC: 0.47, Val MCC: 0.0301
# Epoch 134/200, Train Loss: 0.6717, Train ACC: 0.73, Train MCC: 0.5111, Val Loss: 0.7272, Val ACC: 0.47, Val MCC: 0.0301
# Epoch 135/200, Train Loss: 0.6501, Train ACC: 0.70, Train MCC: 0.4494, Val Loss: 0.7328, Val ACC: 0.47, Val MCC: 0.0301
# Epoch 136/200, Train Loss: 0.6619, Train ACC: 0.73, Train MCC: 0.4950, Val Loss: 0.7132, Val ACC: 0.57, Val MCC: 0.2691
# Epoch 137/200, Train Loss: 0.5431, Train ACC: 0.75, Train MCC: 0.5335, Val Loss: 0.7128, Val ACC: 0.50, Val MCC: 0.0710
# Epoch 138/200, Train Loss: 0.5682, Train ACC: 0.81, Train MCC: 0.6156, Val Loss: 0.7137, Val ACC: 0.53, Val MCC: 0.2106
# Epoch 139/200, Train Loss: 0.6215, Train ACC: 0.73, Train MCC: 0.4810, Val Loss: 0.7165, Val ACC: 0.53, Val MCC: 0.2106
# Epoch 140/200, Train Loss: 0.5604, Train ACC: 0.76, Train MCC: 0.5419, Val Loss: 0.7217, Val ACC: 0.50, Val MCC: 0.1451
# Epoch 141/200, Train Loss: 0.6609, Train ACC: 0.70, Train MCC: 0.4494, Val Loss: 0.7156, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 142/200, Train Loss: 0.6060, Train ACC: 0.69, Train MCC: 0.4107, Val Loss: 0.7128, Val ACC: 0.47, Val MCC: 0.0301
# Epoch 143/200, Train Loss: 0.6076, Train ACC: 0.75, Train MCC: 0.5183, Val Loss: 0.7139, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 144/200, Train Loss: 0.5781, Train ACC: 0.76, Train MCC: 0.5296, Val Loss: 0.7186, Val ACC: 0.47, Val MCC: 0.0301
# Epoch 145/200, Train Loss: 0.5663, Train ACC: 0.76, Train MCC: 0.5419, Val Loss: 0.7145, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 146/200, Train Loss: 0.5285, Train ACC: 0.70, Train MCC: 0.4201, Val Loss: 0.7212, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 147/200, Train Loss: 0.6970, Train ACC: 0.76, Train MCC: 0.5419, Val Loss: 0.7197, Val ACC: 0.47, Val MCC: 0.0301
# Epoch 148/200, Train Loss: 0.5478, Train ACC: 0.70, Train MCC: 0.4494, Val Loss: 0.7168, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 149/200, Train Loss: 0.6707, Train ACC: 0.64, Train MCC: 0.3260, Val Loss: 0.7113, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 150/200, Train Loss: 0.5571, Train ACC: 0.78, Train MCC: 0.5793, Val Loss: 0.7094, Val ACC: 0.47, Val MCC: 0.0053
# Epoch 151/200, Train Loss: 0.6208, Train ACC: 0.73, Train MCC: 0.4950, Val Loss: 0.7131, Val ACC: 0.47, Val MCC: 0.0301
# Epoch 152/200, Train Loss: 0.6614, Train ACC: 0.76, Train MCC: 0.5419, Val Loss: 0.7132, Val ACC: 0.47, Val MCC: 0.0301
# Epoch 153/200, Train Loss: 0.6808, Train ACC: 0.72, Train MCC: 0.4442, Val Loss: 0.7104, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 154/200, Train Loss: 0.5511, Train ACC: 0.76, Train MCC: 0.5419, Val Loss: 0.7037, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 155/200, Train Loss: 0.4968, Train ACC: 0.75, Train MCC: 0.5335, Val Loss: 0.7069, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 156/200, Train Loss: 0.6765, Train ACC: 0.72, Train MCC: 0.4442, Val Loss: 0.7008, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 157/200, Train Loss: 0.6005, Train ACC: 0.72, Train MCC: 0.4889, Val Loss: 0.7057, Val ACC: 0.53, Val MCC: 0.2106
# Epoch 158/200, Train Loss: 0.4956, Train ACC: 0.73, Train MCC: 0.4582, Val Loss: 0.7110, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 159/200, Train Loss: 0.6078, Train ACC: 0.70, Train MCC: 0.4338, Val Loss: 0.7176, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 160/200, Train Loss: 0.5350, Train ACC: 0.73, Train MCC: 0.4810, Val Loss: 0.7117, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 161/200, Train Loss: 0.5478, Train ACC: 0.69, Train MCC: 0.3962, Val Loss: 0.7198, Val ACC: 0.50, Val MCC: 0.0710
# Epoch 162/200, Train Loss: 0.5895, Train ACC: 0.70, Train MCC: 0.4494, Val Loss: 0.7237, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 163/200, Train Loss: 0.6517, Train ACC: 0.73, Train MCC: 0.4688, Val Loss: 0.7179, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 164/200, Train Loss: 0.4798, Train ACC: 0.72, Train MCC: 0.4573, Val Loss: 0.7090, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 165/200, Train Loss: 0.6516, Train ACC: 0.70, Train MCC: 0.4494, Val Loss: 0.7028, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 166/200, Train Loss: 0.4707, Train ACC: 0.76, Train MCC: 0.5419, Val Loss: 0.7056, Val ACC: 0.60, Val MCC: 0.2466
# Epoch 167/200, Train Loss: 0.6240, Train ACC: 0.76, Train MCC: 0.5562, Val Loss: 0.6963, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 168/200, Train Loss: 0.5719, Train ACC: 0.67, Train MCC: 0.4045, Val Loss: 0.7170, Val ACC: 0.50, Val MCC: 0.0710
# Epoch 169/200, Train Loss: 0.6045, Train ACC: 0.66, Train MCC: 0.3492, Val Loss: 0.7076, Val ACC: 0.47, Val MCC: -0.0147
# Epoch 170/200, Train Loss: 0.6654, Train ACC: 0.70, Train MCC: 0.4494, Val Loss: 0.7004, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 171/200, Train Loss: 0.5523, Train ACC: 0.73, Train MCC: 0.4950, Val Loss: 0.7005, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 172/200, Train Loss: 0.7137, Train ACC: 0.73, Train MCC: 0.4950, Val Loss: 0.7026, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 173/200, Train Loss: 0.5784, Train ACC: 0.66, Train MCC: 0.3492, Val Loss: 0.6976, Val ACC: 0.63, Val MCC: 0.3330
# Epoch 174/200, Train Loss: 0.5517, Train ACC: 0.82, Train MCC: 0.6513, Val Loss: 0.7062, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 175/200, Train Loss: 0.6168, Train ACC: 0.75, Train MCC: 0.4937, Val Loss: 0.7017, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 176/200, Train Loss: 0.6078, Train ACC: 0.76, Train MCC: 0.5296, Val Loss: 0.7236, Val ACC: 0.47, Val MCC: 0.0053
# Epoch 177/200, Train Loss: 0.5313, Train ACC: 0.72, Train MCC: 0.4721, Val Loss: 0.7141, Val ACC: 0.50, Val MCC: 0.0710
# Epoch 178/200, Train Loss: 0.5371, Train ACC: 0.81, Train MCC: 0.6403, Val Loss: 0.7241, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 179/200, Train Loss: 0.6626, Train ACC: 0.78, Train MCC: 0.5793, Val Loss: 0.7104, Val ACC: 0.47, Val MCC: 0.0053
# Epoch 180/200, Train Loss: 0.6859, Train ACC: 0.70, Train MCC: 0.4494, Val Loss: 0.7150, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 181/200, Train Loss: 0.6167, Train ACC: 0.64, Train MCC: 0.3114, Val Loss: 0.7097, Val ACC: 0.50, Val MCC: 0.0710
# Epoch 182/200, Train Loss: 0.5871, Train ACC: 0.75, Train MCC: 0.5051, Val Loss: 0.7068, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 183/200, Train Loss: 0.6418, Train ACC: 0.76, Train MCC: 0.5296, Val Loss: 0.7136, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 184/200, Train Loss: 0.5570, Train ACC: 0.76, Train MCC: 0.5562, Val Loss: 0.7079, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 185/200, Train Loss: 0.6301, Train ACC: 0.73, Train MCC: 0.4950, Val Loss: 0.7234, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 186/200, Train Loss: 0.6558, Train ACC: 0.73, Train MCC: 0.4688, Val Loss: 0.7164, Val ACC: 0.47, Val MCC: 0.0053
# Epoch 187/200, Train Loss: 0.6446, Train ACC: 0.73, Train MCC: 0.4810, Val Loss: 0.7219, Val ACC: 0.47, Val MCC: 0.0053
# Epoch 188/200, Train Loss: 0.7051, Train ACC: 0.67, Train MCC: 0.3592, Val Loss: 0.7223, Val ACC: 0.47, Val MCC: 0.0053
# Epoch 189/200, Train Loss: 0.5784, Train ACC: 0.72, Train MCC: 0.4573, Val Loss: 0.7236, Val ACC: 0.47, Val MCC: 0.0053
# Epoch 190/200, Train Loss: 0.6336, Train ACC: 0.72, Train MCC: 0.4573, Val Loss: 0.7172, Val ACC: 0.47, Val MCC: 0.0053
# Epoch 191/200, Train Loss: 0.6632, Train ACC: 0.69, Train MCC: 0.4107, Val Loss: 0.7120, Val ACC: 0.50, Val MCC: 0.0710
# Epoch 192/200, Train Loss: 0.5978, Train ACC: 0.82, Train MCC: 0.6513, Val Loss: 0.7048, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 193/200, Train Loss: 0.6076, Train ACC: 0.73, Train MCC: 0.4950, Val Loss: 0.7085, Val ACC: 0.50, Val MCC: 0.0710
# Epoch 194/200, Train Loss: 0.6847, Train ACC: 0.72, Train MCC: 0.4573, Val Loss: 0.7144, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 195/200, Train Loss: 0.6392, Train ACC: 0.72, Train MCC: 0.4721, Val Loss: 0.7166, Val ACC: 0.53, Val MCC: 0.1321
# Epoch 196/200, Train Loss: 0.6221, Train ACC: 0.78, Train MCC: 0.5660, Val Loss: 0.7190, Val ACC: 0.47, Val MCC: -0.0147
# Epoch 197/200, Train Loss: 0.6365, Train ACC: 0.81, Train MCC: 0.6156, Val Loss: 0.7268, Val ACC: 0.43, Val MCC: -0.0951
# Epoch 198/200, Train Loss: 0.5226, Train ACC: 0.72, Train MCC: 0.5080, Val Loss: 0.7254, Val ACC: 0.47, Val MCC: -0.0147
# Epoch 199/200, Train Loss: 0.6370, Train ACC: 0.69, Train MCC: 0.3962, Val Loss: 0.7295, Val ACC: 0.47, Val MCC: -0.0147
# Epoch 200/200, Train Loss: 0.5945, Train ACC: 0.70, Train MCC: 0.4494, Val Loss: 0.7242, Val ACC: 0.47, Val MCC: -0.0147

# %%
model = res101
model.eval()
# 加载测试数据集
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_csv_file = "/local/data1/honzh/local_repository/FL/code/4_federated/csv_files/test_data.csv"

test_dataset = CustomDatasetCSV(csv_file=test_csv_file, transform=test_transform)

test_model(model, test_dataset)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.48      0.62      2271
#            1       0.22      0.68      0.33       490
#
#     accuracy                           0.52      2761
#    macro avg       0.55      0.58      0.48      2761
# weighted avg       0.76      0.52      0.57      2761
# {'Total Acc': 0.515,
#  'nff Acc': 0.48,
#  'aff Acc': 0.68,
#  'Precision': 0.22,
#  'Recall': 0.68,
#  'Accuracy': 0.515,
#  'AUC': 0.58,
#  'MCC': 0.122,
#  'F1 Score': 0.332,
#  'ROC_AUC': 0.58,
#  'PRC-AUC': 0.206}

# %% [markdown]
# # densenet161

# %%
from torchvision.models import densenet161, DenseNet161_Weights
from torchvision import transforms, models

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the DenseNet-161 model
model = models.densenet161(weights=DenseNet161_Weights.DEFAULT)

# Modify the classifier part of the model
num_features = model.classifier.in_features
model.classifier = nn.Linear(num_features, 2)

# total layers 
total_layers = len(list(model.features.children()))

# freeze 50% layers
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.features.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False
#---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 200
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

dense161 = train_custom_model(model, train_dataset,val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/200, Train Loss: 0.7322, Train ACC: 0.55, Train MCC: 0.0469, Val Loss: 0.7095, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 2/200, Train Loss: 0.6991, Train ACC: 0.61, Train MCC: 0.2373, Val Loss: 0.7187, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 3/200, Train Loss: 0.5898, Train ACC: 0.72, Train MCC: 0.4721, Val Loss: 0.7567, Val ACC: 0.50, Val MCC: 0.0476
# Epoch 4/200, Train Loss: 0.5340, Train ACC: 0.69, Train MCC: 0.4269, Val Loss: 0.8270, Val ACC: 0.57, Val MCC: 0.2691
# Epoch 5/200, Train Loss: 0.5440, Train ACC: 0.69, Train MCC: 0.4658, Val Loss: 0.8888, Val ACC: 0.53, Val MCC: 0.2915
# Epoch 6/200, Train Loss: 0.4643, Train ACC: 0.73, Train MCC: 0.4950, Val Loss: 0.8817, Val ACC: 0.50, Val MCC: 0.1451
# Epoch 7/200, Train Loss: 0.4804, Train ACC: 0.73, Train MCC: 0.5294, Val Loss: 0.8079, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 8/200, Train Loss: 0.7700, Train ACC: 0.78, Train MCC: 0.5949, Val Loss: 0.7830, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 9/200, Train Loss: 0.4257, Train ACC: 0.79, Train MCC: 0.6344, Val Loss: 0.7995, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 10/200, Train Loss: 0.4605, Train ACC: 0.82, Train MCC: 0.6961, Val Loss: 0.7917, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 11/200, Train Loss: 0.6344, Train ACC: 0.87, Train MCC: 0.7485, Val Loss: 0.8016, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 12/200, Train Loss: 0.3545, Train ACC: 0.85, Train MCC: 0.7122, Val Loss: 0.7998, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 13/200, Train Loss: 0.4475, Train ACC: 0.90, Train MCC: 0.7983, Val Loss: 0.8648, Val ACC: 0.47, Val MCC: 0.0301
# Epoch 14/200, Train Loss: 0.6217, Train ACC: 0.84, Train MCC: 0.7014, Val Loss: 0.8401, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 15/200, Train Loss: 0.3777, Train ACC: 0.82, Train MCC: 0.6637, Val Loss: 0.8535, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 16/200, Train Loss: 0.3843, Train ACC: 0.76, Train MCC: 0.5562, Val Loss: 0.8725, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 17/200, Train Loss: 0.4176, Train ACC: 0.82, Train MCC: 0.6513, Val Loss: 0.8621, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 18/200, Train Loss: 0.3717, Train ACC: 0.82, Train MCC: 0.6413, Val Loss: 0.8785, Val ACC: 0.50, Val MCC: 0.1009
# Epoch 19/200, Train Loss: 0.5334, Train ACC: 0.79, Train MCC: 0.6174, Val Loss: 0.8828, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 20/200, Train Loss: 0.3402, Train ACC: 0.84, Train MCC: 0.7014, Val Loss: 0.8828, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 21/200, Train Loss: 0.3669, Train ACC: 0.81, Train MCC: 0.6563, Val Loss: 0.8789, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 22/200, Train Loss: 0.5932, Train ACC: 0.82, Train MCC: 0.6786, Val Loss: 0.8284, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 23/200, Train Loss: 0.4442, Train ACC: 0.85, Train MCC: 0.7398, Val Loss: 0.8428, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 24/200, Train Loss: 0.2988, Train ACC: 0.84, Train MCC: 0.6765, Val Loss: 0.8270, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 25/200, Train Loss: 0.3104, Train ACC: 0.90, Train MCC: 0.8094, Val Loss: 0.8017, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 26/200, Train Loss: 0.3944, Train ACC: 0.87, Train MCC: 0.7624, Val Loss: 0.8001, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 27/200, Train Loss: 0.3450, Train ACC: 0.87, Train MCC: 0.7485, Val Loss: 0.8022, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 28/200, Train Loss: 0.3652, Train ACC: 0.85, Train MCC: 0.7398, Val Loss: 0.8170, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 29/200, Train Loss: 0.4349, Train ACC: 0.85, Train MCC: 0.7247, Val Loss: 0.8172, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 30/200, Train Loss: 0.4656, Train ACC: 0.87, Train MCC: 0.7485, Val Loss: 0.8570, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 31/200, Train Loss: 0.4591, Train ACC: 0.82, Train MCC: 0.6637, Val Loss: 0.8364, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 32/200, Train Loss: 0.3322, Train ACC: 0.82, Train MCC: 0.6786, Val Loss: 0.8626, Val ACC: 0.53, Val MCC: 0.1643
# Epoch 33/200, Train Loss: 0.4474, Train ACC: 0.84, Train MCC: 0.7014, Val Loss: 0.8194, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 34/200, Train Loss: 0.5128, Train ACC: 0.82, Train MCC: 0.6637, Val Loss: 0.8241, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 35/200, Train Loss: 0.5964, Train ACC: 0.90, Train MCC: 0.7983, Val Loss: 0.7896, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 36/200, Train Loss: 0.3286, Train ACC: 0.76, Train MCC: 0.5728, Val Loss: 0.8074, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 37/200, Train Loss: 0.7224, Train ACC: 0.85, Train MCC: 0.7247, Val Loss: 0.7913, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 38/200, Train Loss: 0.3424, Train ACC: 0.84, Train MCC: 0.7014, Val Loss: 0.7851, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 39/200, Train Loss: 0.3118, Train ACC: 0.88, Train MCC: 0.7731, Val Loss: 0.7765, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 40/200, Train Loss: 0.5244, Train ACC: 0.82, Train MCC: 0.6637, Val Loss: 0.7943, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 41/200, Train Loss: 0.6153, Train ACC: 0.85, Train MCC: 0.7398, Val Loss: 0.7801, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 42/200, Train Loss: 0.4720, Train ACC: 0.90, Train MCC: 0.7983, Val Loss: 0.7989, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 43/200, Train Loss: 0.3052, Train ACC: 0.84, Train MCC: 0.6877, Val Loss: 0.8113, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 44/200, Train Loss: 0.3641, Train ACC: 0.87, Train MCC: 0.7485, Val Loss: 0.8303, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 45/200, Train Loss: 0.4051, Train ACC: 0.84, Train MCC: 0.7177, Val Loss: 0.8076, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 46/200, Train Loss: 0.6046, Train ACC: 0.88, Train MCC: 0.7633, Val Loss: 0.8236, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 47/200, Train Loss: 0.3462, Train ACC: 0.82, Train MCC: 0.6637, Val Loss: 0.8131, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 48/200, Train Loss: 0.3156, Train ACC: 0.90, Train MCC: 0.7983, Val Loss: 0.8347, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 49/200, Train Loss: 0.4433, Train ACC: 0.88, Train MCC: 0.7731, Val Loss: 0.8528, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 50/200, Train Loss: 0.4478, Train ACC: 0.82, Train MCC: 0.6786, Val Loss: 0.8532, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 51/200, Train Loss: 0.4301, Train ACC: 0.82, Train MCC: 0.6637, Val Loss: 0.8839, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 52/200, Train Loss: 0.4895, Train ACC: 0.84, Train MCC: 0.7014, Val Loss: 0.8649, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 53/200, Train Loss: 0.2941, Train ACC: 0.85, Train MCC: 0.7023, Val Loss: 0.8617, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 54/200, Train Loss: 0.4758, Train ACC: 0.82, Train MCC: 0.6786, Val Loss: 0.8182, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 55/200, Train Loss: 0.7084, Train ACC: 0.81, Train MCC: 0.6403, Val Loss: 0.7946, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 56/200, Train Loss: 0.3431, Train ACC: 0.84, Train MCC: 0.7014, Val Loss: 0.8123, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 57/200, Train Loss: 0.5158, Train ACC: 0.79, Train MCC: 0.6028, Val Loss: 0.8285, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 58/200, Train Loss: 0.3540, Train ACC: 0.90, Train MCC: 0.7900, Val Loss: 0.8125, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 59/200, Train Loss: 0.6916, Train ACC: 0.88, Train MCC: 0.7731, Val Loss: 0.7856, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 60/200, Train Loss: 0.3680, Train ACC: 0.84, Train MCC: 0.6877, Val Loss: 0.7629, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 61/200, Train Loss: 0.4153, Train ACC: 0.82, Train MCC: 0.6637, Val Loss: 0.7485, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 62/200, Train Loss: 0.3480, Train ACC: 0.82, Train MCC: 0.6637, Val Loss: 0.7541, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 63/200, Train Loss: 0.6097, Train ACC: 0.84, Train MCC: 0.7177, Val Loss: 0.7401, Val ACC: 0.47, Val MCC: -0.0498
# Epoch 64/200, Train Loss: 0.2794, Train ACC: 0.88, Train MCC: 0.7731, Val Loss: 0.7541, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 65/200, Train Loss: 0.6015, Train ACC: 0.79, Train MCC: 0.6174, Val Loss: 0.7370, Val ACC: 0.43, Val MCC: -0.1258
# Epoch 66/200, Train Loss: 0.3265, Train ACC: 0.87, Train MCC: 0.7485, Val Loss: 0.7591, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 67/200, Train Loss: 0.3916, Train ACC: 0.85, Train MCC: 0.7398, Val Loss: 0.7730, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 68/200, Train Loss: 0.3466, Train ACC: 0.84, Train MCC: 0.7014, Val Loss: 0.7860, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 69/200, Train Loss: 0.5578, Train ACC: 0.82, Train MCC: 0.6637, Val Loss: 0.8003, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 70/200, Train Loss: 0.3694, Train ACC: 0.81, Train MCC: 0.6403, Val Loss: 0.8272, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 71/200, Train Loss: 0.4209, Train ACC: 0.85, Train MCC: 0.7122, Val Loss: 0.8064, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 72/200, Train Loss: 0.6146, Train ACC: 0.81, Train MCC: 0.6563, Val Loss: 0.7851, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 73/200, Train Loss: 0.3271, Train ACC: 0.87, Train MCC: 0.7288, Val Loss: 0.7710, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 74/200, Train Loss: 0.3820, Train ACC: 0.87, Train MCC: 0.7485, Val Loss: 0.7867, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 75/200, Train Loss: 0.5715, Train ACC: 0.82, Train MCC: 0.6513, Val Loss: 0.8152, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 76/200, Train Loss: 0.3015, Train ACC: 0.81, Train MCC: 0.6403, Val Loss: 0.8140, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 77/200, Train Loss: 0.3461, Train ACC: 0.87, Train MCC: 0.7374, Val Loss: 0.7988, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 78/200, Train Loss: 0.4150, Train ACC: 0.85, Train MCC: 0.7122, Val Loss: 0.7909, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 79/200, Train Loss: 0.4553, Train ACC: 0.82, Train MCC: 0.6637, Val Loss: 0.8111, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 80/200, Train Loss: 0.3656, Train ACC: 0.90, Train MCC: 0.7983, Val Loss: 0.8165, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 81/200, Train Loss: 0.3719, Train ACC: 0.87, Train MCC: 0.7485, Val Loss: 0.8232, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 82/200, Train Loss: 0.6310, Train ACC: 0.85, Train MCC: 0.7122, Val Loss: 0.8090, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 83/200, Train Loss: 0.6142, Train ACC: 0.88, Train MCC: 0.7731, Val Loss: 0.7936, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 84/200, Train Loss: 0.4970, Train ACC: 0.87, Train MCC: 0.7374, Val Loss: 0.8027, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 85/200, Train Loss: 0.3809, Train ACC: 0.82, Train MCC: 0.6637, Val Loss: 0.7736, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 86/200, Train Loss: 0.2688, Train ACC: 0.84, Train MCC: 0.6877, Val Loss: 0.7701, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 87/200, Train Loss: 0.3871, Train ACC: 0.84, Train MCC: 0.6877, Val Loss: 0.7985, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 88/200, Train Loss: 0.5287, Train ACC: 0.81, Train MCC: 0.6403, Val Loss: 0.8338, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 89/200, Train Loss: 0.3335, Train ACC: 0.85, Train MCC: 0.7122, Val Loss: 0.8346, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 90/200, Train Loss: 0.3742, Train ACC: 0.88, Train MCC: 0.7856, Val Loss: 0.8210, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 91/200, Train Loss: 0.7332, Train ACC: 0.82, Train MCC: 0.6637, Val Loss: 0.8081, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 92/200, Train Loss: 0.4289, Train ACC: 0.85, Train MCC: 0.7122, Val Loss: 0.8326, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 93/200, Train Loss: 0.3565, Train ACC: 0.88, Train MCC: 0.7633, Val Loss: 0.8190, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 94/200, Train Loss: 0.4036, Train ACC: 0.84, Train MCC: 0.6877, Val Loss: 0.8243, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 95/200, Train Loss: 0.2797, Train ACC: 0.84, Train MCC: 0.7014, Val Loss: 0.8082, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 96/200, Train Loss: 0.4847, Train ACC: 0.78, Train MCC: 0.5660, Val Loss: 0.7970, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 97/200, Train Loss: 0.2817, Train ACC: 0.88, Train MCC: 0.7731, Val Loss: 0.7774, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 98/200, Train Loss: 0.6465, Train ACC: 0.87, Train MCC: 0.7485, Val Loss: 0.7726, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 99/200, Train Loss: 0.3851, Train ACC: 0.87, Train MCC: 0.7374, Val Loss: 0.7821, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 100/200, Train Loss: 0.6419, Train ACC: 0.85, Train MCC: 0.7247, Val Loss: 0.7855, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 101/200, Train Loss: 0.4762, Train ACC: 0.85, Train MCC: 0.7247, Val Loss: 0.7945, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 102/200, Train Loss: 0.3340, Train ACC: 0.87, Train MCC: 0.7374, Val Loss: 0.7925, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 103/200, Train Loss: 0.6033, Train ACC: 0.88, Train MCC: 0.7731, Val Loss: 0.7909, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 104/200, Train Loss: 0.3038, Train ACC: 0.85, Train MCC: 0.7398, Val Loss: 0.8018, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 105/200, Train Loss: 0.3027, Train ACC: 0.85, Train MCC: 0.7398, Val Loss: 0.8065, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 106/200, Train Loss: 0.3285, Train ACC: 0.82, Train MCC: 0.6637, Val Loss: 0.8147, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 107/200, Train Loss: 0.4527, Train ACC: 0.90, Train MCC: 0.7983, Val Loss: 0.8244, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 108/200, Train Loss: 0.3363, Train ACC: 0.87, Train MCC: 0.7485, Val Loss: 0.8318, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 109/200, Train Loss: 0.2596, Train ACC: 0.90, Train MCC: 0.7983, Val Loss: 0.8055, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 110/200, Train Loss: 0.4181, Train ACC: 0.82, Train MCC: 0.6786, Val Loss: 0.8232, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 111/200, Train Loss: 0.4393, Train ACC: 0.78, Train MCC: 0.5660, Val Loss: 0.8059, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 112/200, Train Loss: 0.4942, Train ACC: 0.85, Train MCC: 0.7122, Val Loss: 0.8065, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 113/200, Train Loss: 0.3050, Train ACC: 0.87, Train MCC: 0.7624, Val Loss: 0.8056, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 114/200, Train Loss: 0.3085, Train ACC: 0.90, Train MCC: 0.8094, Val Loss: 0.8072, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 115/200, Train Loss: 0.3610, Train ACC: 0.85, Train MCC: 0.7122, Val Loss: 0.7899, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 116/200, Train Loss: 0.2795, Train ACC: 0.90, Train MCC: 0.8094, Val Loss: 0.7892, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 117/200, Train Loss: 0.2979, Train ACC: 0.87, Train MCC: 0.7624, Val Loss: 0.7859, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 118/200, Train Loss: 0.3769, Train ACC: 0.82, Train MCC: 0.6637, Val Loss: 0.8036, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 119/200, Train Loss: 0.3599, Train ACC: 0.85, Train MCC: 0.7247, Val Loss: 0.7778, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 120/200, Train Loss: 0.7159, Train ACC: 0.87, Train MCC: 0.7485, Val Loss: 0.7608, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 121/200, Train Loss: 0.6097, Train ACC: 0.84, Train MCC: 0.6877, Val Loss: 0.7697, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 122/200, Train Loss: 0.2986, Train ACC: 0.84, Train MCC: 0.6765, Val Loss: 0.7895, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 123/200, Train Loss: 0.3821, Train ACC: 0.79, Train MCC: 0.6174, Val Loss: 0.7882, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 124/200, Train Loss: 0.3282, Train ACC: 0.88, Train MCC: 0.7856, Val Loss: 0.7709, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 125/200, Train Loss: 0.3945, Train ACC: 0.87, Train MCC: 0.7624, Val Loss: 0.7675, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 126/200, Train Loss: 0.4294, Train ACC: 0.85, Train MCC: 0.7247, Val Loss: 0.7729, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 127/200, Train Loss: 0.3916, Train ACC: 0.87, Train MCC: 0.7485, Val Loss: 0.7727, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 128/200, Train Loss: 0.3448, Train ACC: 0.79, Train MCC: 0.5802, Val Loss: 0.7674, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 129/200, Train Loss: 0.3057, Train ACC: 0.87, Train MCC: 0.7485, Val Loss: 0.7728, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 130/200, Train Loss: 0.2887, Train ACC: 0.84, Train MCC: 0.6877, Val Loss: 0.7963, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 131/200, Train Loss: 0.3257, Train ACC: 0.85, Train MCC: 0.7023, Val Loss: 0.7809, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 132/200, Train Loss: 0.2716, Train ACC: 0.87, Train MCC: 0.7624, Val Loss: 0.7729, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 133/200, Train Loss: 0.2814, Train ACC: 0.87, Train MCC: 0.7485, Val Loss: 0.7588, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 134/200, Train Loss: 0.3222, Train ACC: 0.88, Train MCC: 0.7633, Val Loss: 0.7686, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 135/200, Train Loss: 0.3793, Train ACC: 0.87, Train MCC: 0.7624, Val Loss: 0.7884, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 136/200, Train Loss: 0.5882, Train ACC: 0.87, Train MCC: 0.7624, Val Loss: 0.7916, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 137/200, Train Loss: 0.5058, Train ACC: 0.90, Train MCC: 0.8094, Val Loss: 0.7798, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 138/200, Train Loss: 0.3427, Train ACC: 0.84, Train MCC: 0.6877, Val Loss: 0.7786, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 139/200, Train Loss: 0.2792, Train ACC: 0.88, Train MCC: 0.7856, Val Loss: 0.7965, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 140/200, Train Loss: 0.3458, Train ACC: 0.84, Train MCC: 0.7177, Val Loss: 0.8202, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 141/200, Train Loss: 0.4574, Train ACC: 0.85, Train MCC: 0.7247, Val Loss: 0.8270, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 142/200, Train Loss: 0.4155, Train ACC: 0.87, Train MCC: 0.7485, Val Loss: 0.8458, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 143/200, Train Loss: 0.3424, Train ACC: 0.87, Train MCC: 0.7485, Val Loss: 0.8017, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 144/200, Train Loss: 0.3527, Train ACC: 0.85, Train MCC: 0.7247, Val Loss: 0.8098, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 145/200, Train Loss: 0.4744, Train ACC: 0.82, Train MCC: 0.6637, Val Loss: 0.8697, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 146/200, Train Loss: 0.4255, Train ACC: 0.85, Train MCC: 0.7247, Val Loss: 0.8458, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 147/200, Train Loss: 0.6143, Train ACC: 0.85, Train MCC: 0.7247, Val Loss: 0.8201, Val ACC: 0.57, Val MCC: 0.2231
# Epoch 148/200, Train Loss: 0.6110, Train ACC: 0.82, Train MCC: 0.6961, Val Loss: 0.7829, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 149/200, Train Loss: 0.6138, Train ACC: 0.87, Train MCC: 0.7374, Val Loss: 0.8009, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 150/200, Train Loss: 0.6336, Train ACC: 0.87, Train MCC: 0.7288, Val Loss: 0.7774, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 151/200, Train Loss: 0.2988, Train ACC: 0.87, Train MCC: 0.7485, Val Loss: 0.7601, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 152/200, Train Loss: 0.5692, Train ACC: 0.85, Train MCC: 0.7247, Val Loss: 0.7956, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 153/200, Train Loss: 0.3946, Train ACC: 0.82, Train MCC: 0.6637, Val Loss: 0.7874, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 154/200, Train Loss: 0.3754, Train ACC: 0.84, Train MCC: 0.7014, Val Loss: 0.7760, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 155/200, Train Loss: 0.5944, Train ACC: 0.87, Train MCC: 0.7624, Val Loss: 0.7698, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 156/200, Train Loss: 0.3174, Train ACC: 0.81, Train MCC: 0.6403, Val Loss: 0.7772, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 157/200, Train Loss: 0.4721, Train ACC: 0.84, Train MCC: 0.6765, Val Loss: 0.7741, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 158/200, Train Loss: 0.6271, Train ACC: 0.87, Train MCC: 0.7485, Val Loss: 0.7766, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 159/200, Train Loss: 0.2867, Train ACC: 0.85, Train MCC: 0.7247, Val Loss: 0.7867, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 160/200, Train Loss: 0.4769, Train ACC: 0.91, Train MCC: 0.8339, Val Loss: 0.7867, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 161/200, Train Loss: 0.3596, Train ACC: 0.88, Train MCC: 0.7731, Val Loss: 0.7847, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 162/200, Train Loss: 0.3583, Train ACC: 0.94, Train MCC: 0.8854, Val Loss: 0.7861, Val ACC: 0.47, Val MCC: -0.0498
# Epoch 163/200, Train Loss: 0.3632, Train ACC: 0.87, Train MCC: 0.7374, Val Loss: 0.7802, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 164/200, Train Loss: 0.2718, Train ACC: 0.94, Train MCC: 0.8791, Val Loss: 0.7970, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 165/200, Train Loss: 0.3675, Train ACC: 0.85, Train MCC: 0.7122, Val Loss: 0.7849, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 166/200, Train Loss: 0.3234, Train ACC: 0.82, Train MCC: 0.6786, Val Loss: 0.8078, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 167/200, Train Loss: 0.4304, Train ACC: 0.79, Train MCC: 0.6174, Val Loss: 0.8191, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 168/200, Train Loss: 0.6125, Train ACC: 0.81, Train MCC: 0.6563, Val Loss: 0.8111, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 169/200, Train Loss: 0.3898, Train ACC: 0.85, Train MCC: 0.7247, Val Loss: 0.8026, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 170/200, Train Loss: 0.6644, Train ACC: 0.85, Train MCC: 0.7247, Val Loss: 0.7904, Val ACC: 0.47, Val MCC: -0.0498
# Epoch 171/200, Train Loss: 0.4976, Train ACC: 0.87, Train MCC: 0.7374, Val Loss: 0.8010, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 172/200, Train Loss: 0.4847, Train ACC: 0.84, Train MCC: 0.6877, Val Loss: 0.8153, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 173/200, Train Loss: 0.5142, Train ACC: 0.88, Train MCC: 0.7731, Val Loss: 0.7856, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 174/200, Train Loss: 0.7049, Train ACC: 0.79, Train MCC: 0.6028, Val Loss: 0.7929, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 175/200, Train Loss: 0.6119, Train ACC: 0.84, Train MCC: 0.7177, Val Loss: 0.7968, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 176/200, Train Loss: 0.5999, Train ACC: 0.81, Train MCC: 0.6750, Val Loss: 0.7753, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 177/200, Train Loss: 0.3669, Train ACC: 0.88, Train MCC: 0.7856, Val Loss: 0.7822, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 178/200, Train Loss: 0.6177, Train ACC: 0.81, Train MCC: 0.6268, Val Loss: 0.7759, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 179/200, Train Loss: 0.5005, Train ACC: 0.81, Train MCC: 0.6268, Val Loss: 0.8189, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 180/200, Train Loss: 0.3274, Train ACC: 0.90, Train MCC: 0.8094, Val Loss: 0.8250, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 181/200, Train Loss: 0.3165, Train ACC: 0.81, Train MCC: 0.6403, Val Loss: 0.8138, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 182/200, Train Loss: 0.6258, Train ACC: 0.82, Train MCC: 0.6786, Val Loss: 0.7724, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 183/200, Train Loss: 0.3765, Train ACC: 0.84, Train MCC: 0.6765, Val Loss: 0.7821, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 184/200, Train Loss: 0.4548, Train ACC: 0.84, Train MCC: 0.7177, Val Loss: 0.7924, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 185/200, Train Loss: 0.6653, Train ACC: 0.87, Train MCC: 0.7485, Val Loss: 0.7638, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 186/200, Train Loss: 0.3624, Train ACC: 0.79, Train MCC: 0.6028, Val Loss: 0.7758, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 187/200, Train Loss: 0.3877, Train ACC: 0.78, Train MCC: 0.5949, Val Loss: 0.7717, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 188/200, Train Loss: 0.3701, Train ACC: 0.84, Train MCC: 0.6877, Val Loss: 0.7760, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 189/200, Train Loss: 0.5920, Train ACC: 0.84, Train MCC: 0.7014, Val Loss: 0.7791, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 190/200, Train Loss: 0.3768, Train ACC: 0.84, Train MCC: 0.7177, Val Loss: 0.7780, Val ACC: 0.50, Val MCC: 0.0275
# Epoch 191/200, Train Loss: 0.4062, Train ACC: 0.82, Train MCC: 0.6786, Val Loss: 0.7858, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 192/200, Train Loss: 0.3237, Train ACC: 0.85, Train MCC: 0.7398, Val Loss: 0.7996, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 193/200, Train Loss: 0.3437, Train ACC: 0.85, Train MCC: 0.7247, Val Loss: 0.7797, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 194/200, Train Loss: 0.6122, Train ACC: 0.84, Train MCC: 0.6877, Val Loss: 0.7736, Val ACC: 0.53, Val MCC: 0.1070
# Epoch 195/200, Train Loss: 0.3971, Train ACC: 0.76, Train MCC: 0.5728, Val Loss: 0.7728, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 196/200, Train Loss: 0.3474, Train ACC: 0.88, Train MCC: 0.7856, Val Loss: 0.7744, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 197/200, Train Loss: 0.5371, Train ACC: 0.85, Train MCC: 0.7122, Val Loss: 0.7669, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 198/200, Train Loss: 0.3742, Train ACC: 0.88, Train MCC: 0.7731, Val Loss: 0.7684, Val ACC: 0.57, Val MCC: 0.1903
# Epoch 199/200, Train Loss: 0.5667, Train ACC: 0.78, Train MCC: 0.5793, Val Loss: 0.8083, Val ACC: 0.60, Val MCC: 0.2789
# Epoch 200/200, Train Loss: 0.3096, Train ACC: 0.85, Train MCC: 0.7247, Val Loss: 0.8093, Val ACC: 0.60, Val MCC: 0.2789

# %%
model = dense161
model.eval()
# 加载测试数据集
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_csv_file = "/local/data1/honzh/local_repository/FL/code/4_federated/csv_files/test_data.csv"

test_dataset = CustomDatasetCSV(csv_file=test_csv_file, transform=test_transform)

test_model(model, test_dataset)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.40      0.56      2271
#            1       0.23      0.83      0.36       490
#
#     accuracy                           0.48      2761
#    macro avg       0.57      0.62      0.46      2761
# weighted avg       0.79      0.48      0.52      2761
# {'Total Acc': 0.477,
#  'nff Acc': 0.401,
#  'aff Acc': 0.831,
#  'Precision': 0.23,
#  'Recall': 0.831,
#  'Accuracy': 0.477,
#  'AUC': 0.616,
#  'MCC': 0.184,
#  'F1 Score': 0.361,
#  'ROC_AUC': 0.616,
#  'PRC-AUC': 0.221}
