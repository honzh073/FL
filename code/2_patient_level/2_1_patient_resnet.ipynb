# %% [markdown]
# # 1 Image Processing

# %%
# import os
# import random
# import shutil

# # 原始数据集根文件夹
# dataset_root = '/local/data1/honzh073/data/patient_level'

# # 目标数据集文件夹
# target_dataset_folder = '/local/data1/honzh073/data/patient_level_dataset'

# # 创建目标数据集文件夹
# os.makedirs(target_dataset_folder, exist_ok=True)

# # AFF和NFF文件夹
# fracture_types = ['AFF', 'NFF']

# # 分割数据集的比例
# train_ratio = 0.7
# val_ratio = 0.15
# test_ratio = 0.15

# # 遍历AFF和NFF文件夹
# for fracture_type in fracture_types:
#     source_folder = os.path.join(dataset_root, fracture_type)
#     patients = os.listdir(source_folder)
    
#     # 随机打乱患者顺序
#     random.shuffle(patients)
    
#     # 划分数据集
#     total_patients = len(patients)
#     train_end = int(total_patients * train_ratio)
#     val_end = train_end + int(total_patients * val_ratio)
    
#     train_patients = patients[:train_end]
#     val_patients = patients[train_end:val_end]
#     test_patients = patients[val_end:]
    
#     # 复制图片到相应的数据集文件夹
#     for patient_id in train_patients:
#         source_path = os.path.join(source_folder, patient_id)
#         target_path = os.path.join(target_dataset_folder, 'train', fracture_type, patient_id)
#         shutil.copytree(source_path, target_path)
    
#     for patient_id in val_patients:
#         source_path = os.path.join(source_folder, patient_id)
#         target_path = os.path.join(target_dataset_folder, 'val', fracture_type, patient_id)
#         shutil.copytree(source_path, target_path)
    
#     for patient_id in test_patients:
#         source_path = os.path.join(source_folder, patient_id)
#         target_path = os.path.join(target_dataset_folder, 'test', fracture_type, patient_id)
#         shutil.copytree(source_path, target_path)

# print("Dataset split completed.")

# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, random_split
import random
import matplotlib.pyplot as plt
import numpy as np
from torch import optim
from torch.optim import lr_scheduler
import torchvision.models as models

# ----------------------------------------------------------------------------------------------
# Augmentation
# Define data augmentation transforms
# Define data augmentation transforms
train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(20),  # Randomly rotate the image up to 30 degrees
    transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.1),  # Adjust color
    transforms.RandomApply([transforms.RandomAffine(degrees=0, translate=(0.1, 0.1))], p=0.5),  # Random affine transformation
    transforms.RandomApply([transforms.RandomPerspective(distortion_scale=0.2)], p=0.5),  # Randomly apply perspective transformations
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),  # Random resized crop
    transforms.ToTensor(),  # Convert the image to a PyTorch tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # Normalize the image to RGB
])

test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert the image to a PyTorch tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # Normalize the image to RGB
])

# Define the data loaders
train_dataset = ImageFolder(root='/local/data1/honzh073/data/patient_level_dataset/train', transform=train_transform)
validation_dataset = ImageFolder(root='/local/data1/honzh073/data/patient_level_dataset/val', transform=test_transform)
test_dataset = ImageFolder(root='/local/data1/honzh073/data/patient_level_dataset/test', transform=test_transform)

batch_size = 64

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, pin_memory=True)
validation_loader = DataLoader(validation_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)

# ----------------------------------------------------------------------------------------------
# Check if CUDA is available
if torch.cuda.is_available():
    print("CUDA is available!")
    device = torch.device("cuda:0")  # Use GPU 0
else:
    print("CUDA is not available.")
    device = torch.device("cpu")
# ----------------------------------------------------------------------------------------------
print('done!')
# Out:
# CUDA is available!
# done!

# %% [markdown]
# # Plot Images

# %%
# Get some random indices from the validation dataset
random_indices = np.random.choice(len(validation_dataset), 5, replace=False)

# Print image file paths
for i, idx in enumerate(random_indices):
    filename = validation_dataset.samples[idx][0]  # Get the filename
    print(f"Image {i + 1} Path: {filename}")

# Plot images (transformed) with truncated names
plt.figure(figsize=(15, 5))
for i, idx in enumerate(random_indices):
    image, label = validation_dataset[idx]  # Use validation_dataset directly
    filename = validation_dataset.samples[idx][0]  # Get the filename
    truncated_filename = filename.split('/')[-1][:15]  # Extract the last part and truncate to 15 characters
    plt.subplot(1, 5, i + 1)
    plt.title(f"Label: {label}")
    # plt.imshow(image[0], cmap='gray')  # Single-channel (grayscale)
    plt.imshow(image[0])  # Single-channel (grayscale)

    plt.axis('off')
plt.show()
# Out:
# Image 1 Path: /local/data1/honzh073/data/patient_level_dataset/val/NFF/patient_LHCMGJOOKK/patient_LHCMGJOOKK_hospital_48_NFF_image_4.png
# Image 2 Path: /local/data1/honzh073/data/patient_level_dataset/val/NFF/patient_RQNENTKTRY/patient_RQNENTKTRY_hospital_50_NFF_image_4.png
# Image 3 Path: /local/data1/honzh073/data/patient_level_dataset/val/NFF/patient_UUGXPAINQL/patient_UUGXPAINQL_hospital_39_NFF_image_1.png
# Image 4 Path: /local/data1/honzh073/data/patient_level_dataset/val/NFF/patient_FQJCJGGQNK/patient_FQJCJGGQNK_hospital_21_NFF_image_6.png
# Image 5 Path: /local/data1/honzh073/data/patient_level_dataset/val/AFF/patient_YFULNYERJC/patient_YFULNYERJC_hospital_100_AFF_image_1.png

# %% [markdown]
# # Class weights of Training Dataset

# %%
# ---------------------------------------------------------------------------------
import os

def count_number(path_folder):
    # AFF和NFF文件夹路径
    aff_folder = os.path.join(path_folder, 'AFF')
    nff_folder = os.path.join(path_folder, 'NFF')

    # 统计AFF和NFF文件夹中的图片数量
    aff_image_count = sum(len(files) for _, _, files in os.walk(aff_folder))
    nff_image_count = sum(len(files) for _, _, files in os.walk(nff_folder))
    
    return aff_image_count, nff_image_count

print('Total:')
path_folder = '/local/data1/honzh073/data/patient_level'
total_aff_num, total_nff_num = count_number(path_folder)
print('aff number:', total_aff_num, '; nff number:', total_nff_num)

print('Train:')
path_folder = '/local/data1/honzh073/data/patient_level_dataset/train'
aff_num, nff_num = count_number(path_folder)
print('aff number:', aff_num, '; nff number:', nff_num)
print('%:', round(aff_num / total_aff_num * 100, 0), '; %:', round(nff_num / total_nff_num * 100, 0))

print('Val:')
path_folder = '/local/data1/honzh073/data/patient_level_dataset/val'
aff_num, nff_num = count_number(path_folder)
print('aff number:', aff_num, '; nff number:', nff_num)
print('%:', round(aff_num / total_aff_num * 100, 0), '; %:', round(nff_num / total_nff_num * 100, 0))

print('Test:')
path_folder = '/local/data1/honzh073/data/patient_level_dataset/test'
aff_num, nff_num = count_number(path_folder)
print('aff number:', aff_num, '; nff number:', nff_num)
print('%:', round(aff_num / total_aff_num * 100, 0), '; %:', round(nff_num / total_nff_num * 100, 0))

# aff and nff numbers in training dataset
train_aff_count = sum(1 for _, label in train_dataset if label == 0)  # 0 AFF
train_nff_count = sum(1 for _, label in train_dataset if label == 1)  # 1 NFF

# ---------------------------------------------------------------------------------
# Calculate class weights
n_aff_train = train_aff_count
n_nff_train = train_nff_count

class_weight_aff = 1 / (2 * (n_aff_train / (n_aff_train + n_nff_train)))
class_weight_nff = 1 / (2 * (n_nff_train / (n_aff_train + n_nff_train)))

print(f"Class Weight for AFF (0): {class_weight_aff:.4f}")
print(f"Class Weight for NFF (1): {class_weight_nff:.4f}")
# Out:
# Total:
# aff number: 868 ; nff number: 3474
# Train:
# aff number: 608 ; nff number: 2440
# %: 70.0 ; %: 70.0
# Val:
# aff number: 120 ; nff number: 498
# %: 14.0 ; %: 14.0
# Test:
# aff number: 140 ; nff number: 536
# %: 16.0 ; %: 15.0
# Class Weight for AFF (0): 2.5066
# Class Weight for NFF (1): 0.6246

# %% [markdown]
# # ResNet152
# ## lr = 0.0001, step_size = 10, and gamma = 0.1

# %%
from torchvision.models import resnet152, ResNet152_Weights
# from torch.utils.tensorboard import SummaryWriter  # 导入TensorBoard的SummaryWriter
import torch

# pretrained model location
torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Settings
lr = 0.0001
step_size = 10
gamma = 0.1

# Class weights
class_weights = [class_weight_aff, class_weight_nff]
class_weights = torch.Tensor(class_weights).to(device)

# ResNet152
model = models.resnet152(weights=ResNet152_Weights.DEFAULT)
model = model.to(device)

# Update the output layer
model.fc = nn.Linear(2048, 2)  # output layer classes number = dataset classes number
model = model.to(device)

# Loss function
criterion = nn.CrossEntropyLoss(weight=class_weights)
criterion = criterion.to(device)

optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)

# Training (loss and accuracy)
train_losses = []
validation_losses = []
train_accuracies = []
validation_accuracies = []

# writer = SummaryWriter('logs')

num_epochs = 100
for epoch in range(num_epochs):
    model.train()
    correct_train = 0
    total_train = 0
    
    for images, labels in train_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()
    
    train_accuracy = 100 * correct_train / total_train
    
    model.eval()
    correct_validation = 0
    total_validation = 0
    validation_loss = 0
    
    with torch.no_grad():
        for images, labels in validation_loader:
            images = images.to(device)
            labels = labels.to(device)
            
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            _, predicted = torch.max(outputs.data, 1)
            total_validation += labels.size(0)
            correct_validation += (predicted == labels).sum().item()
            validation_loss += loss.item()
    
    validation_accuracy = 100 * correct_validation / total_validation
    validation_loss /= len(validation_loader)
    
    train_losses.append(loss.item())
    validation_losses.append(validation_loss)
    train_accuracies.append(train_accuracy)
    validation_accuracies.append(validation_accuracy)
    
    # # 写入训练集的损失和准确度
    # writer.add_scalar('Loss/train', loss.item(), epoch)
    # writer.add_scalar('Accuracy/train', train_accuracy, epoch)

    # # 写入验证集的损失和准确度
    # writer.add_scalar('Loss/validation', validation_loss, epoch)
    # writer.add_scalar('Accuracy/validation', validation_accuracy, epoch)
    
    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {loss.item():.4f}, Validation Loss: {validation_loss:.4f}, Train Acc: {train_accuracy:.2f}%, Validation Acc: {validation_accuracy:.2f}%")
    
    scheduler.step()  # Step the learning rate scheduler

# Plot loss and accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(validation_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(validation_accuracies, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.show()
# Out:
# Epoch 1/100, Train Loss: 0.3971, Validation Loss: 0.4912, Train Acc: 66.34%, Validation Acc: 79.13%
# Epoch 2/100, Train Loss: 0.1319, Validation Loss: 0.2268, Train Acc: 81.69%, Validation Acc: 92.07%
# Epoch 3/100, Train Loss: 0.2675, Validation Loss: 0.2235, Train Acc: 88.29%, Validation Acc: 90.78%
# Epoch 4/100, Train Loss: 0.2729, Validation Loss: 0.1706, Train Acc: 90.55%, Validation Acc: 94.82%
# Epoch 5/100, Train Loss: 0.2707, Validation Loss: 0.1916, Train Acc: 91.93%, Validation Acc: 91.91%
# Epoch 6/100, Train Loss: 0.2113, Validation Loss: 0.1441, Train Acc: 93.27%, Validation Acc: 94.01%
# Epoch 7/100, Train Loss: 0.2359, Validation Loss: 0.1718, Train Acc: 94.72%, Validation Acc: 94.66%
# Epoch 8/100, Train Loss: 0.2314, Validation Loss: 0.1226, Train Acc: 95.01%, Validation Acc: 95.15%
# Epoch 9/100, Train Loss: 0.3637, Validation Loss: 0.1814, Train Acc: 96.00%, Validation Acc: 93.20%
# Epoch 10/100, Train Loss: 0.1453, Validation Loss: 0.1639, Train Acc: 95.64%, Validation Acc: 94.01%
# Epoch 11/100, Train Loss: 0.2062, Validation Loss: 0.1398, Train Acc: 96.23%, Validation Acc: 94.82%
# Epoch 12/100, Train Loss: 0.2277, Validation Loss: 0.1413, Train Acc: 97.15%, Validation Acc: 94.66%
# Epoch 13/100, Train Loss: 0.1876, Validation Loss: 0.1249, Train Acc: 97.41%, Validation Acc: 95.31%
# Epoch 14/100, Train Loss: 0.1438, Validation Loss: 0.1168, Train Acc: 97.54%, Validation Acc: 95.79%
# Epoch 15/100, Train Loss: 0.1615, Validation Loss: 0.1136, Train Acc: 97.64%, Validation Acc: 96.44%
# Epoch 16/100, Train Loss: 0.1831, Validation Loss: 0.1220, Train Acc: 97.90%, Validation Acc: 95.63%
# Epoch 17/100, Train Loss: 0.1855, Validation Loss: 0.1195, Train Acc: 97.97%, Validation Acc: 95.47%
# Epoch 18/100, Train Loss: 0.1692, Validation Loss: 0.1149, Train Acc: 98.00%, Validation Acc: 95.79%
# Epoch 19/100, Train Loss: 0.1395, Validation Loss: 0.1099, Train Acc: 98.00%, Validation Acc: 96.12%
# Epoch 69/100, Train Loss: 0.1813, Validation Loss: 0.1127, Train Acc: 98.65%, Validation Acc: 96.12%
# Epoch 70/100, Train Loss: 0.1890, Validation Loss: 0.1163, Train Acc: 98.43%, Validation Acc: 96.12%
# Epoch 71/100, Train Loss: 0.1586, Validation Loss: 0.1120, Train Acc: 98.33%, Validation Acc: 96.12%
# Epoch 72/100, Train Loss: 0.1801, Validation Loss: 0.1123, Train Acc: 98.56%, Validation Acc: 96.28%
# Epoch 73/100, Train Loss: 0.1892, Validation Loss: 0.1170, Train Acc: 98.29%, Validation Acc: 96.12%
# Epoch 74/100, Train Loss: 0.1710, Validation Loss: 0.1147, Train Acc: 98.39%, Validation Acc: 96.12%
# Epoch 75/100, Train Loss: 0.1739, Validation Loss: 0.1138, Train Acc: 98.43%, Validation Acc: 96.12%
# Epoch 76/100, Train Loss: 0.1738, Validation Loss: 0.1150, Train Acc: 98.33%, Validation Acc: 96.12%
# Epoch 77/100, Train Loss: 0.1728, Validation Loss: 0.1135, Train Acc: 97.97%, Validation Acc: 96.12%
# Epoch 78/100, Train Loss: 0.1750, Validation Loss: 0.1142, Train Acc: 98.03%, Validation Acc: 95.95%
# Epoch 79/100, Train Loss: 0.1649, Validation Loss: 0.1126, Train Acc: 98.46%, Validation Acc: 96.12%
# Epoch 80/100, Train Loss: 0.1578, Validation Loss: 0.1122, Train Acc: 98.59%, Validation Acc: 96.28%
# Epoch 81/100, Train Loss: 0.1861, Validation Loss: 0.1162, Train Acc: 98.52%, Validation Acc: 96.12%
# Epoch 82/100, Train Loss: 0.1854, Validation Loss: 0.1163, Train Acc: 98.10%, Validation Acc: 96.12%
# Epoch 83/100, Train Loss: 0.1862, Validation Loss: 0.1155, Train Acc: 98.46%, Validation Acc: 96.28%
# Epoch 84/100, Train Loss: 0.1899, Validation Loss: 0.1165, Train Acc: 98.29%, Validation Acc: 96.28%
# Epoch 85/100, Train Loss: 0.1862, Validation Loss: 0.1157, Train Acc: 98.26%, Validation Acc: 96.28%
# Epoch 86/100, Train Loss: 0.1785, Validation Loss: 0.1159, Train Acc: 97.97%, Validation Acc: 96.12%
# Epoch 87/100, Train Loss: 0.1876, Validation Loss: 0.1150, Train Acc: 98.36%, Validation Acc: 96.12%
# Epoch 88/100, Train Loss: 0.1840, Validation Loss: 0.1149, Train Acc: 98.29%, Validation Acc: 96.12%
# Epoch 89/100, Train Loss: 0.1784, Validation Loss: 0.1153, Train Acc: 98.29%, Validation Acc: 96.44%
# Epoch 90/100, Train Loss: 0.1782, Validation Loss: 0.1141, Train Acc: 98.62%, Validation Acc: 96.12%
# Epoch 91/100, Train Loss: 0.1755, Validation Loss: 0.1145, Train Acc: 98.33%, Validation Acc: 96.44%
# Epoch 92/100, Train Loss: 0.1668, Validation Loss: 0.1142, Train Acc: 98.79%, Validation Acc: 95.95%
# Epoch 93/100, Train Loss: 0.1871, Validation Loss: 0.1170, Train Acc: 98.52%, Validation Acc: 96.28%
# Epoch 94/100, Train Loss: 0.1708, Validation Loss: 0.1129, Train Acc: 98.13%, Validation Acc: 96.12%
# Epoch 95/100, Train Loss: 0.1930, Validation Loss: 0.1173, Train Acc: 98.56%, Validation Acc: 96.12%
# Epoch 96/100, Train Loss: 0.1952, Validation Loss: 0.1179, Train Acc: 98.82%, Validation Acc: 96.28%
# Epoch 97/100, Train Loss: 0.1895, Validation Loss: 0.1159, Train Acc: 98.29%, Validation Acc: 96.12%
# Epoch 98/100, Train Loss: 0.1723, Validation Loss: 0.1125, Train Acc: 98.62%, Validation Acc: 96.28%
# Epoch 99/100, Train Loss: 0.1570, Validation Loss: 0.1106, Train Acc: 98.69%, Validation Acc: 95.95%
# Epoch 100/100, Train Loss: 0.1810, Validation Loss: 0.1142, Train Acc: 98.52%, Validation Acc: 96.12%

# %%
# Define the data loaders
# test_dataset = ImageFolder(root='/local/data1/honzh073/data/hospital_33', transform=transform)

# batch_size = 64

# test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True, pin_memory=True)

from sklearn.metrics import confusion_matrix, classification_report

# Test dataset performance
model.eval()
correct_test = 0
total_test = 0
test_loss = 0

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        loss = criterion(outputs, labels)

        _, predicted = torch.max(outputs.data, 1)
        total_test += labels.size(0)
        correct_test += (predicted == labels).sum().item()
        test_loss += loss.item()

test_accuracy = 100 * correct_test / total_test
test_loss /= len(test_loader)

print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_accuracy:.2f}%")


original_classes = train_loader.dataset.classes

# confusion matrix
with torch.no_grad():
    all_predictions = []
    all_labels = []

    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)

        all_predictions.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

conf_matrix = confusion_matrix(all_labels, all_predictions)

# Precision、Recall、F1 Score
classification_rep = classification_report(all_labels, all_predictions, target_names=original_classes)

print("Confusion Matrix:")
print(conf_matrix)
print("Classification Report:")
print(classification_rep)
# Out:
# Test Loss: 0.1769, Test Acc: 92.90%
# Confusion Matrix:
# [[126  14]
#  [ 34 502]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          AFF       0.79      0.90      0.84       140
#          NFF       0.97      0.94      0.95       536
#
#     accuracy                           0.93       676
#    macro avg       0.88      0.92      0.90       676
# weighted avg       0.93      0.93      0.93       676

# %% [markdown]
# # Save model

# %%
# Save the trained VGG model
torch.save(model.state_dict(), '/local/data1/honzh073/saved_model/patient_level_resnet152.pth')

# %%
def eva(test_loader):
        
    # Test dataset performance
    model.eval()
    correct_test = 0
    total_test = 0
    test_loss = 0

    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            _, predicted = torch.max(outputs.data, 1)
            total_test += labels.size(0)
            correct_test += (predicted == labels).sum().item()
            test_loss += loss.item()

    test_accuracy = 100 * correct_test / total_test
    test_loss /= len(test_loader)

    print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_accuracy:.2f}%")

    from sklearn.metrics import confusion_matrix, classification_report

    original_classes = train_loader.dataset.classes

    # confusion matrix
    with torch.no_grad():
        all_predictions = []
        all_labels = []

        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)

            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    conf_matrix = confusion_matrix(all_labels, all_predictions)

    # Precision、Recall、F1 Score
    classification_rep = classification_report(all_labels, all_predictions, target_names=original_classes)

    print("Confusion Matrix:")
    print(conf_matrix)
    print("Classification Report:")
    print(classification_rep)

# %%
# 在所有image上的表现
images = ImageFolder(root='/local/data1/honzh073/data/8bit_by_types', transform=test_transform)

image_loader = DataLoader(images, batch_size=batch_size, shuffle=False, pin_memory=True)

eva(image_loader)
# Out:
# Test Loss: 0.1539, Test Acc: 93.67%
# Confusion Matrix:
# [[ 818   50]
#  [ 225 3249]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          AFF       0.78      0.94      0.86       868
#          NFF       0.98      0.94      0.96      3474
#
#     accuracy                           0.94      4342
#    macro avg       0.88      0.94      0.91      4342
# weighted avg       0.94      0.94      0.94      4342
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Clean GPU memory

# %%
torch.cuda.empty_cache()

# %% [markdown]
# # VGG19

# %%
from torchvision.models import vgg19, VGG19_Weights

# Settings
lr = 0.0001
step_size = 10
gamma = 0.1

# Move class weights to the selected device
class_weights = [class_weight_aff, class_weight_nff]
class_weights = torch.Tensor(class_weights).to(device)

# VGG19
model = models.vgg19(weights=VGG19_Weights.DEFAULT)  # Load the pre-trained VGG19 model
model.classifier[6] = nn.Linear(4096, 2)  # Modify the last fully connected layer
model = model.to(device)

# Loss function
criterion = nn.CrossEntropyLoss(weight=class_weights)
criterion = criterion.to(device)

optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)

# Training and validation
train_losses = []
validation_losses = []
train_accuracies = []
validation_accuracies = []

num_epochs = 50
for epoch in range(num_epochs):
    model.train()
    correct_train = 0
    total_train = 0

    for images, labels in train_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    train_accuracy = 100 * correct_train / total_train

    model.eval()
    correct_validation = 0
    total_validation = 0
    validation_loss = 0

    with torch.no_grad():
        for images, labels in validation_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            _, predicted = torch.max(outputs.data, 1)
            total_validation += labels.size(0)
            correct_validation += (predicted == labels).sum().item()
            validation_loss += loss.item()

    validation_accuracy = 100 * correct_validation / total_validation
    validation_loss /= len(validation_loader)

    train_losses.append(loss.item())
    validation_losses.append(validation_loss)
    train_accuracies.append(train_accuracy)
    validation_accuracies.append(validation_accuracy)

    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {loss.item():.4f}, Validation Loss: {validation_loss:.4f}, Train Acc: {train_accuracy:.2f}%, Validation Acc: {validation_accuracy:.2f}%")

    scheduler.step()  # Step the learning rate scheduler

# Plot loss and accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(validation_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(validation_accuracies, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.show()

# Test the model on the test dataset
model.eval()
correct_test = 0
total_test = 0
test_loss = 0

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        loss = criterion(outputs, labels)

        _, predicted = torch.max(outputs.data, 1)
        total_test += labels.size(0)
        correct_test += (predicted == labels).sum().item()
        test_loss += loss.item()

test_accuracy = 100 * correct_test / total_test
test_loss /= len(test_loader)

print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_accuracy:.2f}%")
# Out:
# Epoch 1/50, Train Loss: 0