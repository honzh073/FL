# %% [markdown]
# # Functions

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_curve, roc_auc_score

torch.manual_seed(1)

def show_image(dataset, num_images=5):
    # Get random indices
    random_indices = np.random.choice(len(dataset), num_images, replace=False)

    # Plot images with truncated names
    plt.figure(figsize=(15, 5))
    for i, idx in enumerate(random_indices):
        image, label = dataset[idx]  # Use the dataset directly
        filename = dataset.data[idx][0]  # Get the filename from dataset's internal data attribute
        truncated_filename = filename.split('/')[-1][:15]  # Extract the last part and truncate to 15 characters
        
        # Print the original filename
        print(f"Image location: {filename}")

        plt.subplot(1, num_images, i + 1)
        plt.title(f"Label: {label}")
        plt.imshow(image[0])  # Assuming single-channel (grayscale) image
        # plt.imshow(image[0], cmap='gray')  # Assuming single-channel (grayscale) image

        plt.axis('off')
    plt.show()
    
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_classweight(train_dataset):
    train_nff_count = sum(1 for _, label in train_dataset if label == 0)  # 0 NFF
    train_aff_count = sum(1 for _, label in train_dataset if label == 1)  # 1 AFF
    class_weight_nff = 1 / (2 * (train_nff_count / (train_nff_count + train_aff_count)))
    class_weight_aff = 1 / (2 * (train_aff_count / (train_nff_count + train_aff_count)))
    
    return [class_weight_nff, class_weight_aff] # 0 nff , 1 aff

# %%
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import csv
from torchvision import transforms, models
from sklearn.model_selection import KFold
# Define your image transformations for training and testing
from torchvision import transforms
# Custom dataset class
import os
import csv
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn as nn
from torchvision import models
from torchvision import transforms
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_curve, roc_auc_score
import torch.nn.functional as F
import json

# custom dataset on csv files
class CustomDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]
        image_path = item['ImagePath']
        label = item['Label']

        # Load image
        image = Image.open(image_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        # Convert label to numerical representation
        if label == 'NFF':
            label = 0
        elif label == 'AFF':
            label = 1
        else:
            raise ValueError("Invalid label in JSON data.")

        return image, label

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])


# augmentation
train_transforms = transforms.Compose([
    transforms.RandomRotation(degrees=30),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.GaussianBlur(kernel_size=3),
    transforms.RandomAdjustSharpness(sharpness_factor=5),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
# Define data augmentation transforms for validation data
val_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load JSON data
with open('/local/data1/honzh073/local_repository/FL/code/4_centralized_learning/csv_files/combined_data2.json', 'r') as json_file:
    json_data = json.load(json_file)
    train_data = json_data['train']
    val_data = json_data['val']

train_dataset = CustomDataset(train_data, transform=train_transforms)
val_dataset = CustomDataset(val_data, transform=val_transforms)

# classweight
classweight = get_classweight(train_dataset)
print('training class weight', classweight)


# # print images
# show_image(train_dataset, 5)

# calculate numbers
print("train")
print('-----------------------------------')
train_NFF_count = sum(1 for _, label in train_dataset if label == 0)  # 0 NFF
train_AFF_count = sum(1 for _, label in train_dataset if label == 1)  # 1 AFF

print(f"train AFF: {train_AFF_count}, ratio: {train_AFF_count / (train_AFF_count + train_NFF_count):.2f}")
print(f"----- NFF: {train_NFF_count}, ratio: {train_NFF_count / (train_AFF_count + train_NFF_count):.2f}")

print("val")
print('-----------------------------------')
train_NFF_count = sum(1 for _, label in val_dataset if label == 0)  # 0 NFF
train_AFF_count = sum(1 for _, label in val_dataset if label == 1)  # 1 AFF

print(f"train AFF: {train_AFF_count}, ratio: {train_AFF_count / (train_AFF_count + train_NFF_count):.2f}")
print(f"----- NFF: {train_NFF_count}, ratio: {train_NFF_count / (train_AFF_count + train_NFF_count):.2f}")
# Out:
# training class weight [0.6814946619217082, 1.8774509803921569]
# train
# -----------------------------------
# train AFF: 102, ratio: 0.27
# ----- NFF: 281, ratio: 0.73
# val
# -----------------------------------
# train AFF: 44, ratio: 0.26
# ----- NFF: 124, ratio: 0.74

# %%
# custom dataset on csv files
class CustomCsvDataset(Dataset):
    def __init__(self, csv_file, transform=None):
        self.data = []
        self.labels = []  # Store labels separately
        self.patient_ids = []  # Store patient IDs separately
        self.hospital_ids = []  # Store hospital IDs separately
        self.transform = transform
        
        # read csv
        with open(csv_file, 'r') as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                image_path = row['ImagePath']
                label = row['Label']
                patient_id = row['PatientID']
                hospital_id = row['HospitalID']

                if label == 'NFF':
                    label = 0
                elif label == 'AFF':
                    label = 1
                else:
                    raise ValueError("Invalid label in CSV file.")
                self.data.append((image_path, label))
                self.labels.append(label)
                self.patient_ids.append(patient_id)
                self.hospital_ids.append(int(hospital_id))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image_path, label = self.data[idx]
        image = Image.open(image_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image, label

# %%
import torch
import random
import numpy as np

# 设置随机数种子
seed = 1
torch.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)

# 设置CUDA随机数种子（如果使用GPU）
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader
from sklearn.model_selection import StratifiedKFold
from torch.utils.data import DataLoader
from sklearn.metrics import roc_auc_score, confusion_matrix, classification_report




# ------------------------------------------------------------------------------------------------------
def train_custom_model(model, train_dataset, val_dataset, num_epochs, batch_size, optimizer=None):
    classweight = get_classweight(train_dataset) # get_classweight is a function defined above
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    model = model.to(device)
    criterion = nn.CrossEntropyLoss(weight=torch.Tensor(classweight).to(device))
    
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    for epoch in range(num_epochs):
        model.train()
        correct_train = 0
        total_train = 0

        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()

        train_accuracy = 100 * correct_train / total_train

        model.eval()
        correct_validation = 0
        total_validation = 0
        validation_loss = 0

        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                _, predicted = torch.max(outputs.data, 1)
                total_validation += labels.size(0)
                correct_validation += (predicted == labels).sum().item()
                validation_loss += loss.item()

        validation_accuracy = 100 * correct_validation / total_validation
        validation_loss /= len(val_loader)

        print(f"Epoch {epoch+1}/{num_epochs}, "
              f"Train ACC: {train_accuracy:.2f}%, "
              f"Validation ACC: {validation_accuracy:.2f}%")
    
    return model

# ------------------------------------------------------------------------------------------------------
def test_model(model, test_dataset, batch_size):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)
    model = model.to(device)

    model.eval()

    correct_test_nff = 0
    correct_test_aff = 0
    total_nff = 0
    total_aff = 0
    total_test = 0
    test_loss = 0

    criterion = nn.CrossEntropyLoss()

    with torch.no_grad():
        all_predictions = []
        all_labels = []
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            _, predicted = torch.max(outputs.data, 1)
            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            total_test += labels.size(0)
            total_nff += (labels == 0).sum().item()
            total_aff += (labels == 1).sum().item()
            correct_test_nff += ((predicted == labels) & (labels == 0)).sum().item()
            correct_test_aff += ((predicted == labels) & (labels == 1)).sum().item()
            test_loss += loss.item()

    # Check if total_aff is zero before performing the division
    test_accuracy_nff = 100 * (correct_test_nff / total_nff) if total_nff != 0 else 0
    test_accuracy_aff = 100 * (correct_test_aff / total_aff) if total_aff != 0 else 0
    test_accuracy_total = 100 * (correct_test_nff + correct_test_aff) / total_test
    test_loss /= len(test_loader)

    # Handle the case where there is only one class
    if len(set(all_labels)) > 1:
        auc_score = roc_auc_score(all_labels, all_predictions)
    else:
        auc_score = 0  # Default value if only one class is present

    conf_matrix = confusion_matrix(all_labels, all_predictions)

    # Directly use class labels as strings in target_names
    target_names = ['NFF', 'AFF']

    classification_rep = classification_report(all_labels, all_predictions, target_names=target_names, labels=[0, 1], zero_division=1)

    # Store metrics in a dictionary
    metrics = {
        "Test Loss": test_loss,
        "Total Test Accuracy": test_accuracy_total,
        "Test Accuracy (NFF)": test_accuracy_nff,
        "Test Accuracy (AFF)": test_accuracy_aff,
        "AUC": auc_score,
        "Confusion Matrix": conf_matrix,
        "Classification Report": classification_rep
    }
    return metrics

# %%
results = []

# %% [markdown]
# # VGG 19

# %%
from torchvision.models import vgg19, VGG19_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the VGG-19 model
model = models.vgg19(weights=VGG19_Weights.DEFAULT)

# Modify the classifier part of the model
num_features = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_features, 2)

# layer number
total_layers = len(list(model.features.children()))

# freeze 50% layer
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.features.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False
# ---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 20
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

v19 = train_custom_model(model, train_dataset, val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/20, Train ACC: 55.87%, Validation ACC: 72.62%
# Epoch 2/20, Train ACC: 61.88%, Validation ACC: 72.62%
# Epoch 3/20, Train ACC: 68.93%, Validation ACC: 79.17%
# Epoch 4/20, Train ACC: 69.19%, Validation ACC: 80.95%
# Epoch 5/20, Train ACC: 75.20%, Validation ACC: 73.81%
# Epoch 6/20, Train ACC: 80.16%, Validation ACC: 85.12%
# Epoch 7/20, Train ACC: 81.98%, Validation ACC: 88.10%
# Epoch 8/20, Train ACC: 89.30%, Validation ACC: 84.52%
# Epoch 9/20, Train ACC: 87.47%, Validation ACC: 76.79%
# Epoch 10/20, Train ACC: 91.64%, Validation ACC: 84.52%
# Epoch 11/20, Train ACC: 87.99%, Validation ACC: 83.93%
# Epoch 12/20, Train ACC: 87.99%, Validation ACC: 86.31%
# Epoch 13/20, Train ACC: 89.03%, Validation ACC: 85.12%
# Epoch 14/20, Train ACC: 92.43%, Validation ACC: 83.33%
# Epoch 15/20, Train ACC: 90.60%, Validation ACC: 85.71%
# Epoch 16/20, Train ACC: 89.82%, Validation ACC: 85.71%
# Epoch 17/20, Train ACC: 94.78%, Validation ACC: 85.12%
# Epoch 18/20, Train ACC: 95.56%, Validation ACC: 83.33%
# Epoch 19/20, Train ACC: 95.56%, Validation ACC: 86.31%
# Epoch 20/20, Train ACC: 93.21%, Validation ACC: 88.10%

# %%
model = v19
model.eval()
# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomCsvDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(10, 5))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
torch.cuda.empty_cache()
results.append(average_performance)
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.28235507011413574
# Total Test Accuracy: 91.30434782608695
# Test Accuracy (NFF): 91.30434782608695
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21  2]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.91      0.95        23
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.91        23
#    macro avg       0.50      0.96      0.48        23
# weighted avg       1.00      0.91      0.95        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 0.004947865381836891
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         0
#          AFF       1.00      1.00      1.00         3
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.4574225842952728
# Total Test Accuracy: 82.85714285714286
# Test Accuracy (NFF): 78.26086956521739
# Test Accuracy (AFF): 91.66666666666666
# Confusion Matrix:
#  [[18  5]
#  [ 1 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.78      0.86        23
#          AFF       0.69      0.92      0.79        12
#
#     accuracy                           0.83        35
#    macro avg       0.82      0.85      0.82        35
# weighted avg       0.86      0.83      0.83        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.03275817260146141
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         2
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.2902600793167949
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 80.0
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[48 12]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.80      0.88        60
#          AFF       0.25      0.80      0.38         5
#
#     accuracy                           0.80        65
#    macro avg       0.61      0.80      0.63        65
# weighted avg       0.92      0.80      0.84        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.36317166686058044
# Total Test Accuracy: 78.57142857142857
# Test Accuracy (NFF): 72.22222222222221
# Test Accuracy (AFF): 90.0
# Confusion Matrix:
#  [[26 10]
#  [ 2 18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.72      0.81        36
#          AFF       0.64      0.90      0.75        20
#
#     accuracy                           0.79        56
#    macro avg       0.79      0.81      0.78        56
# weighted avg       0.83      0.79      0.79        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.3676912486553192
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 83.33333333333334
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[5 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.83      0.91         6
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.83         6
#    macro avg       0.50      0.92      0.45         6
# weighted avg       1.00      0.83      0.91         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.5161861628293991
# Total Test Accuracy: 81.55339805825243
# Test Accuracy (NFF): 82.5
# Test Accuracy (AFF): 78.26086956521739
# Confusion Matrix:
#  [[66 14]
#  [ 5 18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.82      0.87        80
#          AFF       0.56      0.78      0.65        23
#
#     accuracy                           0.82       103
#    macro avg       0.75      0.80      0.76       103
# weighted avg       0.85      0.82      0.83       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.13325326144695282
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 0.2777380207553506
# Total Test Accuracy: 84.05797101449275
# Test Accuracy (NFF): 84.90566037735849
# Test Accuracy (AFF): 81.25
# Confusion Matrix:
#  [[45  8]
#  [ 3 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.85      0.89        53
#          AFF       0.62      0.81      0.70        16
#
#     accuracy                           0.84        69
#    macro avg       0.78      0.83      0.80        69
# weighted avg       0.86      0.84      0.85        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.20106331631541252
# Total Test Accuracy: 88.31168831168831
# Test Accuracy (NFF): 90.625
# Test Accuracy (AFF): 76.92307692307693
# Confusion Matrix:
#  [[58  6]
#  [ 3 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.91      0.93        64
#          AFF       0.62      0.77      0.69        13
#
#     accuracy                           0.88        77
#    macro avg       0.79      0.84      0.81        77
# weighted avg       0.90      0.88      0.89        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.31609266996383667
# Total Test Accuracy: 85.47008547008546
# Test Accuracy (NFF): 84.95575221238938
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[96 17]
#  [ 0  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.85      0.92       113
#          AFF       0.19      1.00      0.32         4
#
#     accuracy                           0.85       117
#    macro avg       0.60      0.92      0.62       117
# weighted avg       0.97      0.85      0.90       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.21361522376537323
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 88.37209302325581
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[38  5]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.94        43
#          AFF       0.29      1.00      0.44         2
#
#     accuracy                           0.89        45
#    macro avg       0.64      0.94      0.69        45
# weighted avg       0.97      0.89      0.92        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.12505660951137543
# Total Test Accuracy: 90.47619047619048
# Test Accuracy (NFF): 90.47619047619048
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[19  2]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.90      0.95        21
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.90        21
#    macro avg       0.50      0.95      0.48        21
# weighted avg       1.00      0.90      0.95        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 1.1376874446868896
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         3
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.20974862575531006
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         4
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 0.3075488917529583
# Total Test Accuracy: 83.09859154929578
# Test Accuracy (NFF): 83.6734693877551
# Test Accuracy (AFF): 81.81818181818183
# Confusion Matrix:
#  [[41  8]
#  [ 4 18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.84      0.87        49
#          AFF       0.69      0.82      0.75        22
#
#     accuracy                           0.83        71
#    macro avg       0.80      0.83      0.81        71
# weighted avg       0.84      0.83      0.83        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.18340912461280823
# Total Test Accuracy: 92.85714285714286
# Test Accuracy (NFF): 89.1566265060241
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[74  9]
#  [ 0 43]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.89      0.94        83
#          AFF       0.83      1.00      0.91        43
#
#     accuracy                           0.93       126
#    macro avg       0.91      0.95      0.92       126
# weighted avg       0.94      0.93      0.93       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.31789878010749817
# Total Test Accuracy: 91.11111111111111
# Test Accuracy (NFF): 95.0
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[38  2]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.95      0.95        40
#          AFF       0.60      0.60      0.60         5
#
#     accuracy                           0.91        45
#    macro avg       0.77      0.77      0.78        45
# weighted avg       0.91      0.91      0.91        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.2147781252861023
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[7 1]
#  [0 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.93         8
#          AFF       0.50      1.00      0.67         1
#
#     accuracy                           0.89         9
#    macro avg       0.75      0.94      0.80         9
# weighted avg       0.94      0.89      0.90         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.4975415915250778
# Total Test Accuracy: 81.5126050420168
# Test Accuracy (NFF): 83.52941176470588
# Test Accuracy (AFF): 76.47058823529412
# Confusion Matrix:
#  [[71 14]
#  [ 8 26]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.84      0.87        85
#          AFF       0.65      0.76      0.70        34
#
#     accuracy                           0.82       119
#    macro avg       0.77      0.80      0.78       119
# weighted avg       0.83      0.82      0.82       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 0.3963322825729847
# Total Test Accuracy: 82.47422680412372
# Test Accuracy (NFF): 86.79245283018868
# Test Accuracy (AFF): 77.27272727272727
# Confusion Matrix:
#  [[46  7]
#  [10 34]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.82      0.87      0.84        53
#          AFF       0.83      0.77      0.80        44
#
#     accuracy                           0.82        97
#    macro avg       0.83      0.82      0.82        97
# weighted avg       0.82      0.82      0.82        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.018783491104841232
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.4321663901209831
# Total Test Accuracy: 83.51648351648352
# Test Accuracy (NFF): 81.81818181818183
# Test Accuracy (AFF): 92.85714285714286
# Confusion Matrix:
#  [[63 14]
#  [ 1 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.82      0.89        77
#          AFF       0.48      0.93      0.63        14
#
#     accuracy                           0.84        91
#    macro avg       0.73      0.87      0.76        91
# weighted avg       0.91      0.84      0.85        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 0.895953893661499
# Total Test Accuracy: 55.55555555555556
# Test Accuracy (NFF): 53.333333333333336
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[8 7]
#  [1 2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.53      0.67        15
#          AFF       0.22      0.67      0.33         3
#
#     accuracy                           0.56        18
#    macro avg       0.56      0.60      0.50        18
# weighted avg       0.78      0.56      0.61        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.47564786672592163
# Total Test Accuracy: 88.46153846153847
# Test Accuracy (NFF): 94.44444444444444
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[17  1]
#  [ 2  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.94      0.92        18
#          AFF       0.86      0.75      0.80         8
#
#     accuracy                           0.88        26
#    macro avg       0.88      0.85      0.86        26
# weighted avg       0.88      0.88      0.88        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.21618960797786713
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 88.23529411764706
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[15  2]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.94        17
#          AFF       0.33      1.00      0.50         1
#
#     accuracy                           0.89        18
#    macro avg       0.67      0.94      0.72        18
# weighted avg       0.96      0.89      0.91        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.347553089261055
# Total Test Accuracy: 81.72043010752688
# Test Accuracy (NFF): 78.48101265822784
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[62 17]
#  [ 0 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.78      0.88        79
#          AFF       0.45      1.00      0.62        14
#
#     accuracy                           0.82        93
#    macro avg       0.73      0.89      0.75        93
# weighted avg       0.92      0.82      0.84        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 0.8477954864501953
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 57.14285714285714
# Confusion Matrix:
#  [[8 1]
#  [3 4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.73      0.89      0.80         9
#          AFF       0.80      0.57      0.67         7
#
#     accuracy                           0.75        16
#    macro avg       0.76      0.73      0.73        16
# weighted avg       0.76      0.75      0.74        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 1.1100722551345825
# Total Test Accuracy: 33.333333333333336
# Test Accuracy (NFF): 33.33333333333333
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2 4]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.33      0.50         6
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.33         6
#    macro avg       0.50      0.67      0.25         6
# weighted avg       1.00      0.33      0.50         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 0.2060626819729805
# Total Test Accuracy: 89.28571428571429
# Test Accuracy (NFF): 89.55223880597015
# Test Accuracy (AFF): 88.23529411764706
# Confusion Matrix:
#  [[60  7]
#  [ 2 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.90      0.93        67
#          AFF       0.68      0.88      0.77        17
#
#     accuracy                           0.89        84
#    macro avg       0.82      0.89      0.85        84
# weighted avg       0.91      0.89      0.90        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.018539199605584145
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.36495641867319745
# Total Test Accuracy: 81.75675675675676
# Test Accuracy (NFF): 82.53968253968253
# Test Accuracy (AFF): 77.27272727272727
# Confusion Matrix:
#  [[104  22]
#  [  5  17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.83      0.89       126
#          AFF       0.44      0.77      0.56        22
#
#     accuracy                           0.82       148
#    macro avg       0.70      0.80      0.72       148
# weighted avg       0.88      0.82      0.84       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.13420815765857697
# Total Test Accuracy: 91.17647058823529
# Test Accuracy (NFF): 91.17647058823529
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[31  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.91      0.95        34
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.91        34
#    macro avg       0.50      0.96      0.48        34
# weighted avg       1.00      0.91      0.95        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.1144016906619072
# Total Test Accuracy: 94.11764705882354
# Test Accuracy (NFF): 92.85714285714286
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[13  1]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.93      0.96        14
#          AFF       0.75      1.00      0.86         3
#
#     accuracy                           0.94        17
#    macro avg       0.88      0.96      0.91        17
# weighted avg       0.96      0.94      0.94        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.3357592225074768
# Total Test Accuracy: 84.88372093023256
# Test Accuracy (NFF): 88.23529411764706
# Test Accuracy (AFF): 72.22222222222221
# Confusion Matrix:
#  [[60  8]
#  [ 5 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.88      0.90        68
#          AFF       0.62      0.72      0.67        18
#
#     accuracy                           0.85        86
#    macro avg       0.77      0.80      0.78        86
# weighted avg       0.86      0.85      0.85        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.3029409945011139
# Total Test Accuracy: 88.0
# Test Accuracy (NFF): 88.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[22  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.94        25
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.88        25
#    macro avg       0.50      0.94      0.47        25
# weighted avg       1.00      0.88      0.94        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.9199551343917847
# Total Test Accuracy: 68.96551724137932
# Test Accuracy (NFF): 60.86956521739131
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[14  9]
#  [ 0  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.61      0.76        23
#          AFF       0.40      1.00      0.57         6
#
#     accuracy                           0.69        29
#    macro avg       0.70      0.80      0.66        29
# weighted avg       0.88      0.69      0.72        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.4941968694329262
# Total Test Accuracy: 73.33333333333333
# Test Accuracy (NFF): 72.85714285714285
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[51 19]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.73      0.84        70
#          AFF       0.17      0.80      0.29         5
#
#     accuracy                           0.73        75
#    macro avg       0.58      0.76      0.56        75
# weighted avg       0.93      0.73      0.80        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 0.007646413519978523
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 1.0063685178756714
# Total Test Accuracy: 60.0
# Test Accuracy (NFF): 60.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9 6]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.60      0.75        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.60        15
#    macro avg       0.50      0.80      0.37        15
# weighted avg       1.00      0.60      0.75        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.21616061218082905
# Total Test Accuracy: 94.6938775510204
# Test Accuracy (NFF): 94.70588235294117
# Test Accuracy (AFF): 94.66666666666667
# Confusion Matrix:
#  [[161   9]
#  [  4  71]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.95      0.96       170
#          AFF       0.89      0.95      0.92        75
#
#     accuracy                           0.95       245
#    macro avg       0.93      0.95      0.94       245
# weighted avg       0.95      0.95      0.95       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.20823955535888672
# Total Test Accuracy: 90.3225806451613
# Test Accuracy (NFF): 92.3076923076923
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[24  2]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.92      0.94        26
#          AFF       0.67      0.80      0.73         5
#
#     accuracy                           0.90        31
#    macro avg       0.81      0.86      0.83        31
# weighted avg       0.91      0.90      0.91        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.47412922978401184
# Total Test Accuracy: 83.47107438016529
# Test Accuracy (NFF): 82.95454545454545
# Test Accuracy (AFF): 84.84848484848484
# Confusion Matrix:
#  [[73 15]
#  [ 5 28]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.83      0.88        88
#          AFF       0.65      0.85      0.74        33
#
#     accuracy                           0.83       121
#    macro avg       0.79      0.84      0.81       121
# weighted avg       0.86      0.83      0.84       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.22494521737098694
# Total Test Accuracy: 86.36363636363636
# Test Accuracy (NFF): 86.36363636363636
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[19  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.86      0.93        22
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.86        22
#    macro avg       0.50      0.93      0.46        22
# weighted avg       1.00      0.86      0.93        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.20257657766342163
# Total Test Accuracy: 90.81632653061224
# Test Accuracy (NFF): 89.74358974358975
# Test Accuracy (AFF): 95.0
# Confusion Matrix:
#  [[70  8]
#  [ 1 19]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.90      0.94        78
#          AFF       0.70      0.95      0.81        20
#
#     accuracy                           0.91        98
#    macro avg       0.84      0.92      0.87        98
# weighted avg       0.93      0.91      0.91        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.32195280492305756
# Total Test Accuracy: 88.73239436619718
# Test Accuracy (NFF): 90.625
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[58  6]
#  [ 2  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.91      0.94        64
#          AFF       0.45      0.71      0.56         7
#
#     accuracy                           0.89        71
#    macro avg       0.71      0.81      0.75        71
# weighted avg       0.92      0.89      0.90        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.44752275943756104
# Total Test Accuracy: 80.70175438596492
# Test Accuracy (NFF): 80.7017543859649
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[46 11]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.81      0.89        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.81        57
#    macro avg       0.50      0.90      0.45        57
# weighted avg       1.00      0.81      0.89        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.5809574574232101
# Total Test Accuracy: 76.69902912621359
# Test Accuracy (NFF): 76.31578947368422
# Test Accuracy (AFF): 77.77777777777779
# Confusion Matrix:
#  [[58 18]
#  [ 6 21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.76      0.83        76
#          AFF       0.54      0.78      0.64        27
#
#     accuracy                           0.77       103
#    macro avg       0.72      0.77      0.73       103
# weighted avg       0.81      0.77      0.78       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.16314859688282013
# Total Test Accuracy: 91.13924050632912
# Test Accuracy (NFF): 91.66666666666666
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[66  6]
#  [ 1  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.92      0.95        72
#          AFF       0.50      0.86      0.63         7
#
#     accuracy                           0.91        79
#    macro avg       0.74      0.89      0.79        79
# weighted avg       0.94      0.91      0.92        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.031234771013259888
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[24  0]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        24
#          AFF       1.00      1.00      1.00         2
#
#     accuracy                           1.00        26
#    macro avg       1.00      1.00      1.00        26
# weighted avg       1.00      1.00      1.00        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 0.2952025532722473
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 77.77777777777779
# Confusion Matrix:
#  [[3 0]
#  [2 7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.60      1.00      0.75         3
#          AFF       1.00      0.78      0.88         9
#
#     accuracy                           0.83        12
#    macro avg       0.80      0.89      0.81        12
# weighted avg       0.90      0.83      0.84        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.3191678822040558
# Total Test Accuracy: 88.80597014925372
# Test Accuracy (NFF): 88.67924528301887
# Test Accuracy (AFF): 89.28571428571429
# Confusion Matrix:
#  [[94 12]
#  [ 3 25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.89      0.93       106
#          AFF       0.68      0.89      0.77        28
#
#     accuracy                           0.89       134
#    macro avg       0.82      0.89      0.85       134
# weighted avg       0.91      0.89      0.89       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.1632380485534668
# Total Test Accuracy: 93.33333333333333
# Test Accuracy (NFF): 94.07894736842105
# Test Accuracy (AFF): 89.28571428571429
# Confusion Matrix:
#  [[143   9]
#  [  3  25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.94      0.96       152
#          AFF       0.74      0.89      0.81        28
#
#     accuracy                           0.93       180
#    macro avg       0.86      0.92      0.88       180
# weighted avg       0.94      0.93      0.94       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.28747501969337463
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 85.18518518518519
# Test Accuracy (AFF): 69.23076923076923
# Confusion Matrix:
#  [[23  4]
#  [ 4  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.85      0.85        27
#          AFF       0.69      0.69      0.69        13
#
#     accuracy                           0.80        40
#    macro avg       0.77      0.77      0.77        40
# weighted avg       0.80      0.80      0.80        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 1.207668423652649
# Total Test Accuracy: 33.333333333333336
# Test Accuracy (NFF): 33.33333333333333
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[1 2]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.33      0.50         3
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.33         3
#    macro avg       0.50      0.67      0.25         3
# weighted avg       1.00      0.33      0.50         3
#
#
# Performance for Hospital 58:
#
# Test Loss: 0.5052031874656677
# Total Test Accuracy: 85.96491228070175
# Test Accuracy (NFF): 75.86206896551724
# Test Accuracy (AFF): 96.42857142857143
# Confusion Matrix:
#  [[22  7]
#  [ 1 27]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.76      0.85        29
#          AFF       0.79      0.96      0.87        28
#
#     accuracy                           0.86        57
#    macro avg       0.88      0.86      0.86        57
# weighted avg       0.88      0.86      0.86        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.035072240978479385
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.5556574165821075
# Total Test Accuracy: 82.11382113821138
# Test Accuracy (NFF): 83.0
# Test Accuracy (AFF): 78.26086956521739
# Confusion Matrix:
#  [[83 17]
#  [ 5 18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.83      0.88       100
#          AFF       0.51      0.78      0.62        23
#
#     accuracy                           0.82       123
#    macro avg       0.73      0.81      0.75       123
# weighted avg       0.86      0.82      0.83       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.5228753685951233
# Total Test Accuracy: 79.36507936507937
# Test Accuracy (NFF): 76.08695652173914
# Test Accuracy (AFF): 88.23529411764706
# Confusion Matrix:
#  [[35 11]
#  [ 2 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.76      0.84        46
#          AFF       0.58      0.88      0.70        17
#
#     accuracy                           0.79        63
#    macro avg       0.76      0.82      0.77        63
# weighted avg       0.85      0.79      0.80        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 0.6277681589126587
# Total Test Accuracy: 75.47169811320755
# Test Accuracy (NFF): 75.60975609756098
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[31 10]
#  [ 3  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.76      0.83        41
#          AFF       0.47      0.75      0.58        12
#
#     accuracy                           0.75        53
#    macro avg       0.69      0.75      0.70        53
# weighted avg       0.81      0.75      0.77        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 0.06620126217603683
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.3728038966655731
# Total Test Accuracy: 81.25
# Test Accuracy (NFF): 81.25
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[26  6]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.81      0.90        32
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.81        32
#    macro avg       0.50      0.91      0.45        32
# weighted avg       1.00      0.81      0.90        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.11462404578924179
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[8 0]
#  [0 2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         2
#
#     accuracy                           1.00        10
#    macro avg       1.00      1.00      1.00        10
# weighted avg       1.00      1.00      1.00        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.22741952538490295
# Total Test Accuracy: 81.81818181818181
# Test Accuracy (NFF): 88.23529411764706
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[15  2]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.88      0.88        17
#          AFF       0.60      0.60      0.60         5
#
#     accuracy                           0.82        22
#    macro avg       0.74      0.74      0.74        22
# weighted avg       0.82      0.82      0.82        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.2294606864452362
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 89.65517241379311
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[26  3]
#  [ 1  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.90      0.93        29
#          AFF       0.67      0.86      0.75         7
#
#     accuracy                           0.89        36
#    macro avg       0.81      0.88      0.84        36
# weighted avg       0.91      0.89      0.89        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.43231118756991166
# Total Test Accuracy: 82.26600985221675
# Test Accuracy (NFF): 81.88736681887366
# Test Accuracy (AFF): 83.87096774193549
# Confusion Matrix:
#  [[538 119]
#  [ 25 130]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.82      0.88       657
#          AFF       0.52      0.84      0.64       155
#
#     accuracy                           0.82       812
#    macro avg       0.74      0.83      0.76       812
# weighted avg       0.87      0.82      0.84       812
#
#
# Average Total Test Accuracy: 84.75094885441308

# %% [markdown]
# # ResNet50

# %%
from torchvision.models import resnet50, ResNet50_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the ResNet-101 model
model = models.resnet50(weights=ResNet50_Weights.DEFAULT)

num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)

# layer number
total_layers = len(list(model.children()))

# freeze 50% layer
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False

# modify full connection layer
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)

# ---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 20
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

res50 = train_custom_model(model, train_dataset, val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/20, Train ACC: 55.61%, Validation ACC: 49.40%
# Epoch 2/20, Train ACC: 63.71%, Validation ACC: 73.81%
# Epoch 3/20, Train ACC: 65.80%, Validation ACC: 75.60%
# Epoch 4/20, Train ACC: 64.75%, Validation ACC: 76.19%
# Epoch 5/20, Train ACC: 69.97%, Validation ACC: 80.36%
# Epoch 6/20, Train ACC: 74.93%, Validation ACC: 82.14%
# Epoch 7/20, Train ACC: 79.11%, Validation ACC: 83.33%
# Epoch 8/20, Train ACC: 82.77%, Validation ACC: 85.12%
# Epoch 9/20, Train ACC: 83.29%, Validation ACC: 86.90%
# Epoch 10/20, Train ACC: 87.47%, Validation ACC: 84.52%
# Epoch 11/20, Train ACC: 90.08%, Validation ACC: 83.93%
# Epoch 12/20, Train ACC: 90.60%, Validation ACC: 82.74%
# Epoch 13/20, Train ACC: 90.60%, Validation ACC: 83.33%
# Epoch 14/20, Train ACC: 93.73%, Validation ACC: 83.93%
# Epoch 15/20, Train ACC: 93.99%, Validation ACC: 83.93%
# Epoch 16/20, Train ACC: 94.52%, Validation ACC: 83.93%
# Epoch 17/20, Train ACC: 92.95%, Validation ACC: 86.31%
# Epoch 18/20, Train ACC: 95.56%, Validation ACC: 85.71%
# Epoch 19/20, Train ACC: 95.04%, Validation ACC: 84.52%
# Epoch 20/20, Train ACC: 94.26%, Validation ACC: 86.90%

# %%
model = res50
model.eval()
# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomCsvDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(10, 5))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
torch.cuda.empty_cache()
results.append(average_performance)
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.11657126992940903
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        23
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        23
#    macro avg       1.00      1.00      1.00        23
# weighted avg       1.00      1.00      1.00        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 0.008630307391285896
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         0
#          AFF       1.00      1.00      1.00         3
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.45855602622032166
# Total Test Accuracy: 82.85714285714286
# Test Accuracy (NFF): 91.30434782608695
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[21  2]
#  [ 4  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      0.91      0.87        23
#          AFF       0.80      0.67      0.73        12
#
#     accuracy                           0.83        35
#    macro avg       0.82      0.79      0.80        35
# weighted avg       0.83      0.83      0.82        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.16342982649803162
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         2
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.34334346652030945
# Total Test Accuracy: 87.6923076923077
# Test Accuracy (NFF): 91.66666666666666
# Test Accuracy (AFF): 40.0
# Confusion Matrix:
#  [[55  5]
#  [ 3  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.92      0.93        60
#          AFF       0.29      0.40      0.33         5
#
#     accuracy                           0.88        65
#    macro avg       0.62      0.66      0.63        65
# weighted avg       0.90      0.88      0.89        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.31801527738571167
# Total Test Accuracy: 83.92857142857143
# Test Accuracy (NFF): 97.22222222222221
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[35  1]
#  [ 8 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      0.97      0.89        36
#          AFF       0.92      0.60      0.73        20
#
#     accuracy                           0.84        56
#    macro avg       0.87      0.79      0.81        56
# weighted avg       0.85      0.84      0.83        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.16046936810016632
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.3113238662481308
# Total Test Accuracy: 88.3495145631068
# Test Accuracy (NFF): 95.0
# Test Accuracy (AFF): 65.21739130434783
# Confusion Matrix:
#  [[76  4]
#  [ 8 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.95      0.93        80
#          AFF       0.79      0.65      0.71        23
#
#     accuracy                           0.88       103
#    macro avg       0.85      0.80      0.82       103
# weighted avg       0.88      0.88      0.88       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.15125399827957153
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 0.3605833202600479
# Total Test Accuracy: 85.5072463768116
# Test Accuracy (NFF): 92.45283018867924
# Test Accuracy (AFF): 62.5
# Confusion Matrix:
#  [[49  4]
#  [ 6 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.92      0.91        53
#          AFF       0.71      0.62      0.67        16
#
#     accuracy                           0.86        69
#    macro avg       0.80      0.77      0.79        69
# weighted avg       0.85      0.86      0.85        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.18008534610271454
# Total Test Accuracy: 89.6103896103896
# Test Accuracy (NFF): 92.1875
# Test Accuracy (AFF): 76.92307692307693
# Confusion Matrix:
#  [[59  5]
#  [ 3 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.92      0.94        64
#          AFF       0.67      0.77      0.71        13
#
#     accuracy                           0.90        77
#    macro avg       0.81      0.85      0.83        77
# weighted avg       0.90      0.90      0.90        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.1607665941119194
# Total Test Accuracy: 96.58119658119658
# Test Accuracy (NFF): 96.46017699115043
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[109   4]
#  [  0   4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98       113
#          AFF       0.50      1.00      0.67         4
#
#     accuracy                           0.97       117
#    macro avg       0.75      0.98      0.82       117
# weighted avg       0.98      0.97      0.97       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.23627100884914398
# Total Test Accuracy: 91.11111111111111
# Test Accuracy (NFF): 93.02325581395348
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[40  3]
#  [ 1  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.93      0.95        43
#          AFF       0.25      0.50      0.33         2
#
#     accuracy                           0.91        45
#    macro avg       0.61      0.72      0.64        45
# weighted avg       0.94      0.91      0.92        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.06012732535600662
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        21
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 0.17556710541248322
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.08157871663570404
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         4
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 0.449149951338768
# Total Test Accuracy: 81.69014084507042
# Test Accuracy (NFF): 91.83673469387756
# Test Accuracy (AFF): 59.09090909090909
# Confusion Matrix:
#  [[45  4]
#  [ 9 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.83      0.92      0.87        49
#          AFF       0.76      0.59      0.67        22
#
#     accuracy                           0.82        71
#    macro avg       0.80      0.75      0.77        71
# weighted avg       0.81      0.82      0.81        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.11909671500325203
# Total Test Accuracy: 96.03174603174604
# Test Accuracy (NFF): 96.3855421686747
# Test Accuracy (AFF): 95.34883720930233
# Confusion Matrix:
#  [[80  3]
#  [ 2 41]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.96      0.97        83
#          AFF       0.93      0.95      0.94        43
#
#     accuracy                           0.96       126
#    macro avg       0.95      0.96      0.96       126
# weighted avg       0.96      0.96      0.96       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.22296874225139618
# Total Test Accuracy: 86.66666666666667
# Test Accuracy (NFF): 92.5
# Test Accuracy (AFF): 40.0
# Confusion Matrix:
#  [[37  3]
#  [ 3  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.93      0.93        40
#          AFF       0.40      0.40      0.40         5
#
#     accuracy                           0.87        45
#    macro avg       0.66      0.66      0.66        45
# weighted avg       0.87      0.87      0.87        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.3074544668197632
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[8 0]
#  [1 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      1.00      0.94         8
#          AFF       1.00      0.00      0.00         1
#
#     accuracy                           0.89         9
#    macro avg       0.94      0.50      0.47         9
# weighted avg       0.90      0.89      0.84         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.49958477914333344
# Total Test Accuracy: 76.47058823529412
# Test Accuracy (NFF): 83.52941176470588
# Test Accuracy (AFF): 58.82352941176471
# Confusion Matrix:
#  [[71 14]
#  [14 20]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      0.84      0.84        85
#          AFF       0.59      0.59      0.59        34
#
#     accuracy                           0.76       119
#    macro avg       0.71      0.71      0.71       119
# weighted avg       0.76      0.76      0.76       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 0.6401759386062622
# Total Test Accuracy: 69.0721649484536
# Test Accuracy (NFF): 92.45283018867924
# Test Accuracy (AFF): 40.909090909090914
# Confusion Matrix:
#  [[49  4]
#  [26 18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.65      0.92      0.77        53
#          AFF       0.82      0.41      0.55        44
#
#     accuracy                           0.69        97
#    macro avg       0.74      0.67      0.66        97
# weighted avg       0.73      0.69      0.67        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.04249795898795128
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.2213481366634369
# Total Test Accuracy: 95.6043956043956
# Test Accuracy (NFF): 98.7012987012987
# Test Accuracy (AFF): 78.57142857142857
# Confusion Matrix:
#  [[76  1]
#  [ 3 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.99      0.97        77
#          AFF       0.92      0.79      0.85        14
#
#     accuracy                           0.96        91
#    macro avg       0.94      0.89      0.91        91
# weighted avg       0.96      0.96      0.95        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 0.2459624856710434
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 93.33333333333333
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[14  1]
#  [ 1  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.93      0.93        15
#          AFF       0.67      0.67      0.67         3
#
#     accuracy                           0.89        18
#    macro avg       0.80      0.80      0.80        18
# weighted avg       0.89      0.89      0.89        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.368073433637619
# Total Test Accuracy: 88.46153846153847
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 62.5
# Confusion Matrix:
#  [[18  0]
#  [ 3  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.86      1.00      0.92        18
#          AFF       1.00      0.62      0.77         8
#
#     accuracy                           0.88        26
#    macro avg       0.93      0.81      0.85        26
# weighted avg       0.90      0.88      0.88        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.10733234137296677
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[17  0]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        17
#          AFF       1.00      1.00      1.00         1
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.30553168058395386
# Total Test Accuracy: 88.17204301075269
# Test Accuracy (NFF): 93.67088607594937
# Test Accuracy (AFF): 57.14285714285714
# Confusion Matrix:
#  [[74  5]
#  [ 6  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.94      0.93        79
#          AFF       0.62      0.57      0.59        14
#
#     accuracy                           0.88        93
#    macro avg       0.77      0.75      0.76        93
# weighted avg       0.88      0.88      0.88        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 0.6609311699867249
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 42.857142857142854
# Confusion Matrix:
#  [[9 0]
#  [4 3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.69      1.00      0.82         9
#          AFF       1.00      0.43      0.60         7
#
#     accuracy                           0.75        16
#    macro avg       0.85      0.71      0.71        16
# weighted avg       0.83      0.75      0.72        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 0.15648430585861206
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 0.20428971201181412
# Total Test Accuracy: 91.66666666666667
# Test Accuracy (NFF): 92.53731343283582
# Test Accuracy (AFF): 88.23529411764706
# Confusion Matrix:
#  [[62  5]
#  [ 2 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.93      0.95        67
#          AFF       0.75      0.88      0.81        17
#
#     accuracy                           0.92        84
#    macro avg       0.86      0.90      0.88        84
# weighted avg       0.92      0.92      0.92        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.03754730895161629
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.29064709941546124
# Total Test Accuracy: 88.51351351351352
# Test Accuracy (NFF): 94.44444444444444
# Test Accuracy (AFF): 54.54545454545454
# Confusion Matrix:
#  [[119   7]
#  [ 10  12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.94      0.93       126
#          AFF       0.63      0.55      0.59        22
#
#     accuracy                           0.89       148
#    macro avg       0.78      0.74      0.76       148
# weighted avg       0.88      0.89      0.88       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.1458577662706375
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[34]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        34
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        34
#    macro avg       1.00      1.00      1.00        34
# weighted avg       1.00      1.00      1.00        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.12630237638950348
# Total Test Accuracy: 94.11764705882354
# Test Accuracy (NFF): 92.85714285714286
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[13  1]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.93      0.96        14
#          AFF       0.75      1.00      0.86         3
#
#     accuracy                           0.94        17
#    macro avg       0.88      0.96      0.91        17
# weighted avg       0.96      0.94      0.94        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.2965877801179886
# Total Test Accuracy: 84.88372093023256
# Test Accuracy (NFF): 86.76470588235294
# Test Accuracy (AFF): 77.77777777777779
# Confusion Matrix:
#  [[59  9]
#  [ 4 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.87      0.90        68
#          AFF       0.61      0.78      0.68        18
#
#     accuracy                           0.85        86
#    macro avg       0.77      0.82      0.79        86
# weighted avg       0.87      0.85      0.86        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.0942363291978836
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        25
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        25
#    macro avg       1.00      1.00      1.00        25
# weighted avg       1.00      1.00      1.00        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.31785324215888977
# Total Test Accuracy: 89.65517241379311
# Test Accuracy (NFF): 91.30434782608695
# Test Accuracy (AFF): 83.33333333333334
# Confusion Matrix:
#  [[21  2]
#  [ 1  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.91      0.93        23
#          AFF       0.71      0.83      0.77         6
#
#     accuracy                           0.90        29
#    macro avg       0.83      0.87      0.85        29
# weighted avg       0.90      0.90      0.90        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.21678324416279793
# Total Test Accuracy: 88.0
# Test Accuracy (NFF): 92.85714285714286
# Test Accuracy (AFF): 20.0
# Confusion Matrix:
#  [[65  5]
#  [ 4  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.93      0.94        70
#          AFF       0.17      0.20      0.18         5
#
#     accuracy                           0.88        75
#    macro avg       0.55      0.56      0.56        75
# weighted avg       0.89      0.88      0.89        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 0.013367886655032635
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 0.3143836557865143
# Total Test Accuracy: 93.33333333333333
# Test Accuracy (NFF): 93.33333333333333
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[14  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.93      0.97        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.93        15
#    macro avg       0.50      0.97      0.48        15
# weighted avg       1.00      0.93      0.97        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.1554233282804489
# Total Test Accuracy: 95.10204081632654
# Test Accuracy (NFF): 98.82352941176471
# Test Accuracy (AFF): 86.66666666666667
# Confusion Matrix:
#  [[168   2]
#  [ 10  65]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.99      0.97       170
#          AFF       0.97      0.87      0.92        75
#
#     accuracy                           0.95       245
#    macro avg       0.96      0.93      0.94       245
# weighted avg       0.95      0.95      0.95       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.253040611743927
# Total Test Accuracy: 93.54838709677419
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[26  0]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      1.00      0.96        26
#          AFF       1.00      0.60      0.75         5
#
#     accuracy                           0.94        31
#    macro avg       0.96      0.80      0.86        31
# weighted avg       0.94      0.94      0.93        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.18036364763975143
# Total Test Accuracy: 94.21487603305785
# Test Accuracy (NFF): 95.45454545454545
# Test Accuracy (AFF): 90.9090909090909
# Confusion Matrix:
#  [[84  4]
#  [ 3 30]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.95      0.96        88
#          AFF       0.88      0.91      0.90        33
#
#     accuracy                           0.94       121
#    macro avg       0.92      0.93      0.93       121
# weighted avg       0.94      0.94      0.94       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.06682687252759933
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[22]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        22
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        22
#    macro avg       1.00      1.00      1.00        22
# weighted avg       1.00      1.00      1.00        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.27479052543640137
# Total Test Accuracy: 88.77551020408163
# Test Accuracy (NFF): 97.43589743589743
# Test Accuracy (AFF): 55.00000000000001
# Confusion Matrix:
#  [[76  2]
#  [ 9 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.97      0.93        78
#          AFF       0.85      0.55      0.67        20
#
#     accuracy                           0.89        98
#    macro avg       0.87      0.76      0.80        98
# weighted avg       0.88      0.89      0.88        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.10575378965586424
# Total Test Accuracy: 94.36619718309859
# Test Accuracy (NFF): 96.875
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[62  2]
#  [ 2  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.97      0.97        64
#          AFF       0.71      0.71      0.71         7
#
#     accuracy                           0.94        71
#    macro avg       0.84      0.84      0.84        71
# weighted avg       0.94      0.94      0.94        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.36273837089538574
# Total Test Accuracy: 82.45614035087719
# Test Accuracy (NFF): 82.45614035087719
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[47 10]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.82      0.90        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.82        57
#    macro avg       0.50      0.91      0.45        57
# weighted avg       1.00      0.82      0.90        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.5081289559602737
# Total Test Accuracy: 80.58252427184466
# Test Accuracy (NFF): 92.10526315789474
# Test Accuracy (AFF): 48.148148148148145
# Confusion Matrix:
#  [[70  6]
#  [14 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.83      0.92      0.88        76
#          AFF       0.68      0.48      0.57        27
#
#     accuracy                           0.81       103
#    macro avg       0.76      0.70      0.72       103
# weighted avg       0.79      0.81      0.79       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.24868174642324448
# Total Test Accuracy: 91.13924050632912
# Test Accuracy (NFF): 94.44444444444444
# Test Accuracy (AFF): 57.14285714285714
# Confusion Matrix:
#  [[68  4]
#  [ 3  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.94      0.95        72
#          AFF       0.50      0.57      0.53         7
#
#     accuracy                           0.91        79
#    macro avg       0.73      0.76      0.74        79
# weighted avg       0.92      0.91      0.91        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.1158183291554451
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[24  0]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        24
#          AFF       1.00      1.00      1.00         2
#
#     accuracy                           1.00        26
#    macro avg       1.00      1.00      1.00        26
# weighted avg       1.00      1.00      1.00        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 0.9131565093994141
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 55.55555555555556
# Confusion Matrix:
#  [[3 0]
#  [4 5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.43      1.00      0.60         3
#          AFF       1.00      0.56      0.71         9
#
#     accuracy                           0.67        12
#    macro avg       0.71      0.78      0.66        12
# weighted avg       0.86      0.67      0.69        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.1866787113249302
# Total Test Accuracy: 92.53731343283582
# Test Accuracy (NFF): 97.16981132075472
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[103   3]
#  [  7  21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.97      0.95       106
#          AFF       0.88      0.75      0.81        28
#
#     accuracy                           0.93       134
#    macro avg       0.91      0.86      0.88       134
# weighted avg       0.92      0.93      0.92       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.19515473023056984
# Total Test Accuracy: 93.33333333333333
# Test Accuracy (NFF): 99.3421052631579
# Test Accuracy (AFF): 60.71428571428571
# Confusion Matrix:
#  [[151   1]
#  [ 11  17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.99      0.96       152
#          AFF       0.94      0.61      0.74        28
#
#     accuracy                           0.93       180
#    macro avg       0.94      0.80      0.85       180
# weighted avg       0.93      0.93      0.93       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.3891027867794037
# Total Test Accuracy: 82.5
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 46.15384615384615
# Confusion Matrix:
#  [[27  0]
#  [ 7  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.79      1.00      0.89        27
#          AFF       1.00      0.46      0.63        13
#
#     accuracy                           0.82        40
#    macro avg       0.90      0.73      0.76        40
# weighted avg       0.86      0.82      0.80        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 0.004138001706451178
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 58:
#
# Test Loss: 0.4207705557346344
# Total Test Accuracy: 82.45614035087719
# Test Accuracy (NFF): 93.10344827586206
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[27  2]
#  [ 8 20]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.77      0.93      0.84        29
#          AFF       0.91      0.71      0.80        28
#
#     accuracy                           0.82        57
#    macro avg       0.84      0.82      0.82        57
# weighted avg       0.84      0.82      0.82        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.13835464417934418
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.3458350747823715
# Total Test Accuracy: 86.17886178861788
# Test Accuracy (NFF): 93.0
# Test Accuracy (AFF): 56.52173913043478
# Confusion Matrix:
#  [[93  7]
#  [10 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.93      0.92       100
#          AFF       0.65      0.57      0.60        23
#
#     accuracy                           0.86       123
#    macro avg       0.78      0.75      0.76       123
# weighted avg       0.86      0.86      0.86       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.26381781697273254
# Total Test Accuracy: 87.3015873015873
# Test Accuracy (NFF): 97.82608695652173
# Test Accuracy (AFF): 58.82352941176471
# Confusion Matrix:
#  [[45  1]
#  [ 7 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.98      0.92        46
#          AFF       0.91      0.59      0.71        17
#
#     accuracy                           0.87        63
#    macro avg       0.89      0.78      0.82        63
# weighted avg       0.88      0.87      0.86        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 0.4293173551559448
# Total Test Accuracy: 84.90566037735849
# Test Accuracy (NFF): 90.2439024390244
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[37  4]
#  [ 4  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.90      0.90        41
#          AFF       0.67      0.67      0.67        12
#
#     accuracy                           0.85        53
#    macro avg       0.78      0.78      0.78        53
# weighted avg       0.85      0.85      0.85        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 0.2694159150123596
# Total Test Accuracy: 87.5
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[7 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.93         8
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.88         8
#    macro avg       0.50      0.94      0.47         8
# weighted avg       1.00      0.88      0.93         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.05990033969283104
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[32]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        32
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        32
#    macro avg       1.00      1.00      1.00        32
# weighted avg       1.00      1.00      1.00        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.34225791692733765
# Total Test Accuracy: 90.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[8 0]
#  [1 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      1.00      0.94         8
#          AFF       1.00      0.50      0.67         2
#
#     accuracy                           0.90        10
#    macro avg       0.94      0.75      0.80        10
# weighted avg       0.91      0.90      0.89        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.522986114025116
# Total Test Accuracy: 81.81818181818181
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 20.0
# Confusion Matrix:
#  [[17  0]
#  [ 4  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      1.00      0.89        17
#          AFF       1.00      0.20      0.33         5
#
#     accuracy                           0.82        22
#    macro avg       0.90      0.60      0.61        22
# weighted avg       0.85      0.82      0.77        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.24478285014629364
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 42.857142857142854
# Confusion Matrix:
#  [[29  0]
#  [ 4  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      1.00      0.94        29
#          AFF       1.00      0.43      0.60         7
#
#     accuracy                           0.89        36
#    macro avg       0.94      0.71      0.77        36
# weighted avg       0.90      0.89      0.87        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.32708415389060974
# Total Test Accuracy: 86.57635467980296
# Test Accuracy (NFF): 93.15068493150685
# Test Accuracy (AFF): 58.70967741935483
# Confusion Matrix:
#  [[612  45]
#  [ 64  91]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.93      0.92       657
#          AFF       0.67      0.59      0.63       155
#
#     accuracy                           0.87       812
#    macro avg       0.79      0.76      0.77       812
# weighted avg       0.86      0.87      0.86       812
#
#
# Average Total Test Accuracy: 91.06869404207812

# %% [markdown]
# # ResNet101

# %%
from torchvision.models import resnet101, ResNet101_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the ResNet-101 model
model = models.resnet101(weights=ResNet101_Weights.DEFAULT)

num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)


# layer number
total_layers = len(list(model.children()))

# freeze 50% layer
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False

# modify full connection layer
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)

# ---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 20
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

res101 = train_custom_model(model, train_dataset, val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/20, Train ACC: 47.78%, Validation ACC: 57.74%
# Epoch 2/20, Train ACC: 56.66%, Validation ACC: 72.02%
# Epoch 3/20, Train ACC: 68.41%, Validation ACC: 79.17%
# Epoch 4/20, Train ACC: 74.41%, Validation ACC: 76.79%
# Epoch 5/20, Train ACC: 71.02%, Validation ACC: 73.21%
# Epoch 6/20, Train ACC: 75.46%, Validation ACC: 73.21%
# Epoch 7/20, Train ACC: 79.63%, Validation ACC: 77.98%
# Epoch 8/20, Train ACC: 84.33%, Validation ACC: 84.52%
# Epoch 9/20, Train ACC: 86.68%, Validation ACC: 83.33%
# Epoch 10/20, Train ACC: 89.03%, Validation ACC: 83.33%
# Epoch 11/20, Train ACC: 91.38%, Validation ACC: 85.71%
# Epoch 12/20, Train ACC: 93.21%, Validation ACC: 86.90%
# Epoch 13/20, Train ACC: 93.47%, Validation ACC: 85.71%
# Epoch 14/20, Train ACC: 93.73%, Validation ACC: 86.90%
# Epoch 15/20, Train ACC: 95.82%, Validation ACC: 87.50%
# Epoch 16/20, Train ACC: 95.56%, Validation ACC: 85.71%
# Epoch 17/20, Train ACC: 95.82%, Validation ACC: 87.50%
# Epoch 18/20, Train ACC: 96.61%, Validation ACC: 86.31%
# Epoch 19/20, Train ACC: 96.61%, Validation ACC: 87.50%
# Epoch 20/20, Train ACC: 97.91%, Validation ACC: 87.50%

# %%
model = res101
model.eval()
# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomCsvDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(15, 5))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
torch.cuda.empty_cache()
results.append(average_performance)
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.15578100085258484
# Total Test Accuracy: 95.65217391304348
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[22  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        23
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.96        23
#    macro avg       0.50      0.98      0.49        23
# weighted avg       1.00      0.96      0.98        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 0.010330197401344776
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         0
#          AFF       1.00      1.00      1.00         3
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.3611871302127838
# Total Test Accuracy: 88.57142857142857
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[22  1]
#  [ 3  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.96      0.92        23
#          AFF       0.90      0.75      0.82        12
#
#     accuracy                           0.89        35
#    macro avg       0.89      0.85      0.87        35
# weighted avg       0.89      0.89      0.88        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.06091674789786339
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         2
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.2727778530679643
# Total Test Accuracy: 83.07692307692308
# Test Accuracy (NFF): 83.33333333333334
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[50 10]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.83      0.90        60
#          AFF       0.29      0.80      0.42         5
#
#     accuracy                           0.83        65
#    macro avg       0.63      0.82      0.66        65
# weighted avg       0.93      0.83      0.86        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.3025970458984375
# Total Test Accuracy: 89.28571428571429
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 90.0
# Confusion Matrix:
#  [[32  4]
#  [ 2 18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.89      0.91        36
#          AFF       0.82      0.90      0.86        20
#
#     accuracy                           0.89        56
#    macro avg       0.88      0.89      0.89        56
# weighted avg       0.90      0.89      0.89        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.08997437357902527
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.589460015296936
# Total Test Accuracy: 81.55339805825243
# Test Accuracy (NFF): 85.0
# Test Accuracy (AFF): 69.56521739130434
# Confusion Matrix:
#  [[68 12]
#  [ 7 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.85      0.88        80
#          AFF       0.57      0.70      0.63        23
#
#     accuracy                           0.82       103
#    macro avg       0.74      0.77      0.75       103
# weighted avg       0.83      0.82      0.82       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.06604056805372238
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 0.32610801607370377
# Total Test Accuracy: 89.85507246376811
# Test Accuracy (NFF): 98.11320754716981
# Test Accuracy (AFF): 62.5
# Confusion Matrix:
#  [[52  1]
#  [ 6 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.98      0.94        53
#          AFF       0.91      0.62      0.74        16
#
#     accuracy                           0.90        69
#    macro avg       0.90      0.80      0.84        69
# weighted avg       0.90      0.90      0.89        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.3044069316238165
# Total Test Accuracy: 83.11688311688312
# Test Accuracy (NFF): 85.9375
# Test Accuracy (AFF): 69.23076923076923
# Confusion Matrix:
#  [[55  9]
#  [ 4  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.86      0.89        64
#          AFF       0.50      0.69      0.58        13
#
#     accuracy                           0.83        77
#    macro avg       0.72      0.78      0.74        77
# weighted avg       0.86      0.83      0.84        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.36716246604919434
# Total Test Accuracy: 91.45299145299145
# Test Accuracy (NFF): 91.1504424778761
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[103  10]
#  [  0   4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.91      0.95       113
#          AFF       0.29      1.00      0.44         4
#
#     accuracy                           0.91       117
#    macro avg       0.64      0.96      0.70       117
# weighted avg       0.98      0.91      0.94       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.3165253698825836
# Total Test Accuracy: 91.11111111111111
# Test Accuracy (NFF): 93.02325581395348
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[40  3]
#  [ 1  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.93      0.95        43
#          AFF       0.25      0.50      0.33         2
#
#     accuracy                           0.91        45
#    macro avg       0.61      0.72      0.64        45
# weighted avg       0.94      0.91      0.92        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.18240682780742645
# Total Test Accuracy: 90.47619047619048
# Test Accuracy (NFF): 90.47619047619048
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[19  2]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.90      0.95        21
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.90        21
#    macro avg       0.50      0.95      0.48        21
# weighted avg       1.00      0.90      0.95        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 0.5278302431106567
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         3
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.01871265470981598
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         4
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 0.16113241016864777
# Total Test Accuracy: 91.54929577464789
# Test Accuracy (NFF): 93.87755102040816
# Test Accuracy (AFF): 86.36363636363636
# Confusion Matrix:
#  [[46  3]
#  [ 3 19]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.94      0.94        49
#          AFF       0.86      0.86      0.86        22
#
#     accuracy                           0.92        71
#    macro avg       0.90      0.90      0.90        71
# weighted avg       0.92      0.92      0.92        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.10717618558555841
# Total Test Accuracy: 98.41269841269842
# Test Accuracy (NFF): 98.79518072289156
# Test Accuracy (AFF): 97.67441860465115
# Confusion Matrix:
#  [[82  1]
#  [ 1 42]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.99      0.99        83
#          AFF       0.98      0.98      0.98        43
#
#     accuracy                           0.98       126
#    macro avg       0.98      0.98      0.98       126
# weighted avg       0.98      0.98      0.98       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.4641181230545044
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 95.0
# Test Accuracy (AFF): 40.0
# Confusion Matrix:
#  [[38  2]
#  [ 3  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.95      0.94        40
#          AFF       0.50      0.40      0.44         5
#
#     accuracy                           0.89        45
#    macro avg       0.71      0.68      0.69        45
# weighted avg       0.88      0.89      0.88        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.015173603780567646
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[8 0]
#  [0 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         1
#
#     accuracy                           1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.7155661582946777
# Total Test Accuracy: 81.5126050420168
# Test Accuracy (NFF): 85.88235294117646
# Test Accuracy (AFF): 70.58823529411765
# Confusion Matrix:
#  [[73 12]
#  [10 24]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.86      0.87        85
#          AFF       0.67      0.71      0.69        34
#
#     accuracy                           0.82       119
#    macro avg       0.77      0.78      0.78       119
# weighted avg       0.82      0.82      0.82       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 0.42147399485111237
# Total Test Accuracy: 82.47422680412372
# Test Accuracy (NFF): 90.56603773584906
# Test Accuracy (AFF): 72.72727272727273
# Confusion Matrix:
#  [[48  5]
#  [12 32]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.80      0.91      0.85        53
#          AFF       0.86      0.73      0.79        44
#
#     accuracy                           0.82        97
#    macro avg       0.83      0.82      0.82        97
# weighted avg       0.83      0.82      0.82        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.0012552491389214993
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.35270164906978607
# Total Test Accuracy: 85.71428571428571
# Test Accuracy (NFF): 84.4155844155844
# Test Accuracy (AFF): 92.85714285714286
# Confusion Matrix:
#  [[65 12]
#  [ 1 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.84      0.91        77
#          AFF       0.52      0.93      0.67        14
#
#     accuracy                           0.86        91
#    macro avg       0.75      0.89      0.79        91
# weighted avg       0.91      0.86      0.87        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 0.7920024394989014
# Total Test Accuracy: 77.77777777777777
# Test Accuracy (NFF): 80.0
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[12  3]
#  [ 1  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.80      0.86        15
#          AFF       0.40      0.67      0.50         3
#
#     accuracy                           0.78        18
#    macro avg       0.66      0.73      0.68        18
# weighted avg       0.84      0.78      0.80        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.10771587491035461
# Total Test Accuracy: 96.15384615384616
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 87.5
# Confusion Matrix:
#  [[18  0]
#  [ 1  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      1.00      0.97        18
#          AFF       1.00      0.88      0.93         8
#
#     accuracy                           0.96        26
#    macro avg       0.97      0.94      0.95        26
# weighted avg       0.96      0.96      0.96        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.06365302950143814
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[17  0]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        17
#          AFF       1.00      1.00      1.00         1
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.22389347106218338
# Total Test Accuracy: 93.54838709677419
# Test Accuracy (NFF): 93.67088607594937
# Test Accuracy (AFF): 92.85714285714286
# Confusion Matrix:
#  [[74  5]
#  [ 1 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.94      0.96        79
#          AFF       0.72      0.93      0.81        14
#
#     accuracy                           0.94        93
#    macro avg       0.85      0.93      0.89        93
# weighted avg       0.95      0.94      0.94        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 0.23004275560379028
# Total Test Accuracy: 93.75
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[8 1]
#  [0 7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.89      0.94         9
#          AFF       0.88      1.00      0.93         7
#
#     accuracy                           0.94        16
#    macro avg       0.94      0.94      0.94        16
# weighted avg       0.95      0.94      0.94        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 0.7019283771514893
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 83.33333333333334
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[5 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.83      0.91         6
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.83         6
#    macro avg       0.50      0.92      0.45         6
# weighted avg       1.00      0.83      0.91         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 0.38002368062734604
# Total Test Accuracy: 90.47619047619048
# Test Accuracy (NFF): 91.04477611940298
# Test Accuracy (AFF): 88.23529411764706
# Confusion Matrix:
#  [[61  6]
#  [ 2 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.91      0.94        67
#          AFF       0.71      0.88      0.79        17
#
#     accuracy                           0.90        84
#    macro avg       0.84      0.90      0.86        84
# weighted avg       0.92      0.90      0.91        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.01827310025691986
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.3449910382429759
# Total Test Accuracy: 87.16216216216216
# Test Accuracy (NFF): 89.68253968253968
# Test Accuracy (AFF): 72.72727272727273
# Confusion Matrix:
#  [[113  13]
#  [  6  16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.90      0.92       126
#          AFF       0.55      0.73      0.63        22
#
#     accuracy                           0.87       148
#    macro avg       0.75      0.81      0.77       148
# weighted avg       0.89      0.87      0.88       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.4103005528450012
# Total Test Accuracy: 76.47058823529412
# Test Accuracy (NFF): 76.47058823529412
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[26  8]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.76      0.87        34
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.76        34
#    macro avg       0.50      0.88      0.43        34
# weighted avg       1.00      0.76      0.87        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.04838600382208824
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[14  0]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        14
#          AFF       1.00      1.00      1.00         3
#
#     accuracy                           1.00        17
#    macro avg       1.00      1.00      1.00        17
# weighted avg       1.00      1.00      1.00        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.2850819528102875
# Total Test Accuracy: 82.55813953488372
# Test Accuracy (NFF): 82.35294117647058
# Test Accuracy (AFF): 83.33333333333334
# Confusion Matrix:
#  [[56 12]
#  [ 3 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.82      0.88        68
#          AFF       0.56      0.83      0.67        18
#
#     accuracy                           0.83        86
#    macro avg       0.75      0.83      0.77        86
# weighted avg       0.87      0.83      0.84        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.29332220554351807
# Total Test Accuracy: 88.0
# Test Accuracy (NFF): 88.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[22  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.94        25
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.88        25
#    macro avg       0.50      0.94      0.47        25
# weighted avg       1.00      0.88      0.94        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.9795390367507935
# Total Test Accuracy: 82.75862068965517
# Test Accuracy (NFF): 82.6086956521739
# Test Accuracy (AFF): 83.33333333333334
# Confusion Matrix:
#  [[19  4]
#  [ 1  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.83      0.88        23
#          AFF       0.56      0.83      0.67         6
#
#     accuracy                           0.83        29
#    macro avg       0.75      0.83      0.78        29
# weighted avg       0.87      0.83      0.84        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.3064229376614094
# Total Test Accuracy: 86.66666666666667
# Test Accuracy (NFF): 88.57142857142857
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[62  8]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.89      0.93        70
#          AFF       0.27      0.60      0.37         5
#
#     accuracy                           0.87        75
#    macro avg       0.62      0.74      0.65        75
# weighted avg       0.92      0.87      0.89        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 0.0006147184176370502
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 0.28230470418930054
# Total Test Accuracy: 93.33333333333333
# Test Accuracy (NFF): 93.33333333333333
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[14  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.93      0.97        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.93        15
#    macro avg       0.50      0.97      0.48        15
# weighted avg       1.00      0.93      0.97        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.19813574198633432
# Total Test Accuracy: 95.10204081632654
# Test Accuracy (NFF): 97.6470588235294
# Test Accuracy (AFF): 89.33333333333333
# Confusion Matrix:
#  [[166   4]
#  [  8  67]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.98      0.97       170
#          AFF       0.94      0.89      0.92        75
#
#     accuracy                           0.95       245
#    macro avg       0.95      0.93      0.94       245
# weighted avg       0.95      0.95      0.95       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.17487457394599915
# Total Test Accuracy: 90.3225806451613
# Test Accuracy (NFF): 92.3076923076923
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[24  2]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.92      0.94        26
#          AFF       0.67      0.80      0.73         5
#
#     accuracy                           0.90        31
#    macro avg       0.81      0.86      0.83        31
# weighted avg       0.91      0.90      0.91        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.3858320266008377
# Total Test Accuracy: 87.60330578512396
# Test Accuracy (NFF): 89.77272727272727
# Test Accuracy (AFF): 81.81818181818183
# Confusion Matrix:
#  [[79  9]
#  [ 6 27]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.90      0.91        88
#          AFF       0.75      0.82      0.78        33
#
#     accuracy                           0.88       121
#    macro avg       0.84      0.86      0.85       121
# weighted avg       0.88      0.88      0.88       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.13052338361740112
# Total Test Accuracy: 90.9090909090909
# Test Accuracy (NFF): 90.9090909090909
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[20  2]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.91      0.95        22
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.91        22
#    macro avg       0.50      0.95      0.48        22
# weighted avg       1.00      0.91      0.95        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.28471309691667557
# Total Test Accuracy: 88.77551020408163
# Test Accuracy (NFF): 89.74358974358975
# Test Accuracy (AFF): 85.0
# Confusion Matrix:
#  [[70  8]
#  [ 3 17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.90      0.93        78
#          AFF       0.68      0.85      0.76        20
#
#     accuracy                           0.89        98
#    macro avg       0.82      0.87      0.84        98
# weighted avg       0.90      0.89      0.89        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.17547527700662613
# Total Test Accuracy: 91.54929577464789
# Test Accuracy (NFF): 92.1875
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[59  5]
#  [ 1  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.92      0.95        64
#          AFF       0.55      0.86      0.67         7
#
#     accuracy                           0.92        71
#    macro avg       0.76      0.89      0.81        71
# weighted avg       0.94      0.92      0.92        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.560808539390564
# Total Test Accuracy: 85.96491228070175
# Test Accuracy (NFF): 85.96491228070175
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[49  8]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.86      0.92        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.86        57
#    macro avg       0.50      0.93      0.46        57
# weighted avg       1.00      0.86      0.92        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.4890598803758621
# Total Test Accuracy: 79.6116504854369
# Test Accuracy (NFF): 89.47368421052632
# Test Accuracy (AFF): 51.85185185185185
# Confusion Matrix:
#  [[68  8]
#  [13 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      0.89      0.87        76
#          AFF       0.64      0.52      0.57        27
#
#     accuracy                           0.80       103
#    macro avg       0.74      0.71      0.72       103
# weighted avg       0.79      0.80      0.79       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.1469864770770073
# Total Test Accuracy: 93.67088607594937
# Test Accuracy (NFF): 94.44444444444444
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[68  4]
#  [ 1  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.94      0.96        72
#          AFF       0.60      0.86      0.71         7
#
#     accuracy                           0.94        79
#    macro avg       0.79      0.90      0.84        79
# weighted avg       0.95      0.94      0.94        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.21780778467655182
# Total Test Accuracy: 92.3076923076923
# Test Accuracy (NFF): 91.66666666666666
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[22  2]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.92      0.96        24
#          AFF       0.50      1.00      0.67         2
#
#     accuracy                           0.92        26
#    macro avg       0.75      0.96      0.81        26
# weighted avg       0.96      0.92      0.93        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 1.0372742414474487
# Total Test Accuracy: 58.333333333333336
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 44.44444444444444
# Confusion Matrix:
#  [[3 0]
#  [5 4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.38      1.00      0.55         3
#          AFF       1.00      0.44      0.62         9
#
#     accuracy                           0.58        12
#    macro avg       0.69      0.72      0.58        12
# weighted avg       0.84      0.58      0.60        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.5725945482651392
# Total Test Accuracy: 90.29850746268657
# Test Accuracy (NFF): 91.50943396226415
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[97  9]
#  [ 4 24]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.92      0.94       106
#          AFF       0.73      0.86      0.79        28
#
#     accuracy                           0.90       134
#    macro avg       0.84      0.89      0.86       134
# weighted avg       0.91      0.90      0.91       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.15242463598648706
# Total Test Accuracy: 94.44444444444444
# Test Accuracy (NFF): 96.71052631578947
# Test Accuracy (AFF): 82.14285714285714
# Confusion Matrix:
#  [[147   5]
#  [  5  23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.97      0.97       152
#          AFF       0.82      0.82      0.82        28
#
#     accuracy                           0.94       180
#    macro avg       0.89      0.89      0.89       180
# weighted avg       0.94      0.94      0.94       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.3529701232910156
# Total Test Accuracy: 87.5
# Test Accuracy (NFF): 96.29629629629629
# Test Accuracy (AFF): 69.23076923076923
# Confusion Matrix:
#  [[26  1]
#  [ 4  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.96      0.91        27
#          AFF       0.90      0.69      0.78        13
#
#     accuracy                           0.88        40
#    macro avg       0.88      0.83      0.85        40
# weighted avg       0.88      0.88      0.87        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 0.427890419960022
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         3
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# Performance for Hospital 58:
#
# Test Loss: 0.41953837871551514
# Total Test Accuracy: 89.47368421052632
# Test Accuracy (NFF): 86.20689655172413
# Test Accuracy (AFF): 92.85714285714286
# Confusion Matrix:
#  [[25  4]
#  [ 2 26]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.86      0.89        29
#          AFF       0.87      0.93      0.90        28
#
#     accuracy                           0.89        57
#    macro avg       0.90      0.90      0.89        57
# weighted avg       0.90      0.89      0.89        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.06571032851934433
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.408998504281044
# Total Test Accuracy: 86.17886178861788
# Test Accuracy (NFF): 92.0
# Test Accuracy (AFF): 60.86956521739131
# Confusion Matrix:
#  [[92  8]
#  [ 9 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.92      0.92       100
#          AFF       0.64      0.61      0.62        23
#
#     accuracy                           0.86       123
#    macro avg       0.77      0.76      0.77       123
# weighted avg       0.86      0.86      0.86       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.30351197719573975
# Total Test Accuracy: 85.71428571428571
# Test Accuracy (NFF): 89.13043478260869
# Test Accuracy (AFF): 76.47058823529412
# Confusion Matrix:
#  [[41  5]
#  [ 4 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.89      0.90        46
#          AFF       0.72      0.76      0.74        17
#
#     accuracy                           0.86        63
#    macro avg       0.82      0.83      0.82        63
# weighted avg       0.86      0.86      0.86        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 0.7060827612876892
# Total Test Accuracy: 79.24528301886792
# Test Accuracy (NFF): 82.92682926829268
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[34  7]
#  [ 4  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.83      0.86        41
#          AFF       0.53      0.67      0.59        12
#
#     accuracy                           0.79        53
#    macro avg       0.71      0.75      0.73        53
# weighted avg       0.81      0.79      0.80        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 0.4193345010280609
# Total Test Accuracy: 87.5
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[7 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.93         8
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.88         8
#    macro avg       0.50      0.94      0.47         8
# weighted avg       1.00      0.88      0.93         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.21813558042049408
# Total Test Accuracy: 93.75
# Test Accuracy (NFF): 93.75
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[30  2]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.94      0.97        32
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.94        32
#    macro avg       0.50      0.97      0.48        32
# weighted avg       1.00      0.94      0.97        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.06047620251774788
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[8 0]
#  [0 2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         2
#
#     accuracy                           1.00        10
#    macro avg       1.00      1.00      1.00        10
# weighted avg       1.00      1.00      1.00        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.35134339332580566
# Total Test Accuracy: 86.36363636363636
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 40.0
# Confusion Matrix:
#  [[17  0]
#  [ 3  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      1.00      0.92        17
#          AFF       1.00      0.40      0.57         5
#
#     accuracy                           0.86        22
#    macro avg       0.93      0.70      0.75        22
# weighted avg       0.88      0.86      0.84        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.1376388669013977
# Total Test Accuracy: 91.66666666666667
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 57.14285714285714
# Confusion Matrix:
#  [[29  0]
#  [ 3  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      1.00      0.95        29
#          AFF       1.00      0.57      0.73         7
#
#     accuracy                           0.92        36
#    macro avg       0.95      0.79      0.84        36
# weighted avg       0.92      0.92      0.91        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.3767300374232806
# Total Test Accuracy: 85.5911330049261
# Test Accuracy (NFF): 88.2800608828006
# Test Accuracy (AFF): 74.19354838709677
# Confusion Matrix:
#  [[580  77]
#  [ 40 115]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.88      0.91       657
#          AFF       0.60      0.74      0.66       155
#
#     accuracy                           0.86       812
#    macro avg       0.77      0.81      0.79       812
# weighted avg       0.87      0.86      0.86       812
#
#
# Average Total Test Accuracy: 89.40153831714062

# %% [markdown]
# # ResNet152

# %%
from torchvision.models import resnet152, ResNet152_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the ResNet
model = models.resnet152(weights=ResNet152_Weights.DEFAULT)

num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)


# layer number
total_layers = len(list(model.children()))

# freeze 50% layer
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False

# modify full connection layer
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)

# ---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 20
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

res152 = train_custom_model(model, train_dataset, val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/20, Train ACC: 54.83%, Validation ACC: 72.02%
# Epoch 2/20, Train ACC: 64.23%, Validation ACC: 72.62%
# Epoch 3/20, Train ACC: 75.98%, Validation ACC: 77.38%
# Epoch 4/20, Train ACC: 77.28%, Validation ACC: 79.17%
# Epoch 5/20, Train ACC: 78.85%, Validation ACC: 79.76%
# Epoch 6/20, Train ACC: 83.03%, Validation ACC: 83.93%
# Epoch 7/20, Train ACC: 87.21%, Validation ACC: 83.93%
# Epoch 8/20, Train ACC: 91.12%, Validation ACC: 85.71%
# Epoch 9/20, Train ACC: 93.21%, Validation ACC: 85.71%
# Epoch 10/20, Train ACC: 94.26%, Validation ACC: 85.71%
# Epoch 11/20, Train ACC: 93.73%, Validation ACC: 88.69%
# Epoch 12/20, Train ACC: 96.61%, Validation ACC: 88.10%
# Epoch 13/20, Train ACC: 96.61%, Validation ACC: 86.31%
# Epoch 14/20, Train ACC: 96.08%, Validation ACC: 86.90%
# Epoch 15/20, Train ACC: 96.87%, Validation ACC: 89.29%
# Epoch 16/20, Train ACC: 97.65%, Validation ACC: 88.10%
# Epoch 17/20, Train ACC: 96.61%, Validation ACC: 88.69%
# Epoch 18/20, Train ACC: 97.13%, Validation ACC: 92.26%
# Epoch 19/20, Train ACC: 99.22%, Validation ACC: 89.29%
# Epoch 20/20, Train ACC: 97.13%, Validation ACC: 91.67%

# %%
model = res152
model.eval()
# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomCsvDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(10, 5))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
torch.cuda.empty_cache()
results.append(average_performance)
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.7198715806007385
# Total Test Accuracy: 78.26086956521739
# Test Accuracy (NFF): 78.26086956521739
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[18  5]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.78      0.88        23
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.78        23
#    macro avg       0.50      0.89      0.44        23
# weighted avg       1.00      0.78      0.88        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 0.0037891932297497988
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         0
#          AFF       1.00      1.00      1.00         3
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.9135740995407104
# Total Test Accuracy: 62.857142857142854
# Test Accuracy (NFF): 60.86956521739131
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[14  9]
#  [ 4  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.78      0.61      0.68        23
#          AFF       0.47      0.67      0.55        12
#
#     accuracy                           0.63        35
#    macro avg       0.62      0.64      0.62        35
# weighted avg       0.67      0.63      0.64        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.734677791595459
# Total Test Accuracy: 50.0
# Test Accuracy (NFF): 50.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[1 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.50      0.67         2
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.75      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.3296247646212578
# Total Test Accuracy: 83.07692307692308
# Test Accuracy (NFF): 83.33333333333334
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[50 10]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.83      0.90        60
#          AFF       0.29      0.80      0.42         5
#
#     accuracy                           0.83        65
#    macro avg       0.63      0.82      0.66        65
# weighted avg       0.93      0.83      0.86        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.4322372078895569
# Total Test Accuracy: 87.5
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 85.0
# Confusion Matrix:
#  [[32  4]
#  [ 3 17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.89      0.90        36
#          AFF       0.81      0.85      0.83        20
#
#     accuracy                           0.88        56
#    macro avg       0.86      0.87      0.87        56
# weighted avg       0.88      0.88      0.88        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.2602367699146271
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 83.33333333333334
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[5 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.83      0.91         6
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.83         6
#    macro avg       0.50      0.92      0.45         6
# weighted avg       1.00      0.83      0.91         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.4672761857509613
# Total Test Accuracy: 83.49514563106796
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 69.56521739130434
# Confusion Matrix:
#  [[70 10]
#  [ 7 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.88      0.89        80
#          AFF       0.62      0.70      0.65        23
#
#     accuracy                           0.83       103
#    macro avg       0.76      0.79      0.77       103
# weighted avg       0.84      0.83      0.84       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.09793379157781601
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.89      0.94         9
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.89         9
#    macro avg       0.50      0.94      0.47         9
# weighted avg       1.00      0.89      0.94         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 0.8690676391124725
# Total Test Accuracy: 78.26086956521739
# Test Accuracy (NFF): 75.47169811320755
# Test Accuracy (AFF): 87.5
# Confusion Matrix:
#  [[40 13]
#  [ 2 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.75      0.84        53
#          AFF       0.52      0.88      0.65        16
#
#     accuracy                           0.78        69
#    macro avg       0.74      0.81      0.75        69
# weighted avg       0.85      0.78      0.80        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.45075828582048416
# Total Test Accuracy: 75.32467532467533
# Test Accuracy (NFF): 76.5625
# Test Accuracy (AFF): 69.23076923076923
# Confusion Matrix:
#  [[49 15]
#  [ 4  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.77      0.84        64
#          AFF       0.38      0.69      0.49        13
#
#     accuracy                           0.75        77
#    macro avg       0.65      0.73      0.66        77
# weighted avg       0.83      0.75      0.78        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.6945014894008636
# Total Test Accuracy: 83.76068376068376
# Test Accuracy (NFF): 83.1858407079646
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[94 19]
#  [ 0  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.83      0.91       113
#          AFF       0.17      1.00      0.30         4
#
#     accuracy                           0.84       117
#    macro avg       0.59      0.92      0.60       117
# weighted avg       0.97      0.84      0.89       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.22477984428405762
# Total Test Accuracy: 93.33333333333333
# Test Accuracy (NFF): 95.34883720930233
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[41  2]
#  [ 1  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.95      0.96        43
#          AFF       0.33      0.50      0.40         2
#
#     accuracy                           0.93        45
#    macro avg       0.65      0.73      0.68        45
# weighted avg       0.95      0.93      0.94        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.03854140639305115
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        21
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 0.5773773789405823
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         3
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 1.1951931715011597
# Total Test Accuracy: 50.0
# Test Accuracy (NFF): 50.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2 2]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.50      0.67         4
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.50         4
#    macro avg       0.50      0.75      0.33         4
# weighted avg       1.00      0.50      0.67         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 0.2358687799423933
# Total Test Accuracy: 87.32394366197182
# Test Accuracy (NFF): 89.79591836734694
# Test Accuracy (AFF): 81.81818181818183
# Confusion Matrix:
#  [[44  5]
#  [ 4 18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.90      0.91        49
#          AFF       0.78      0.82      0.80        22
#
#     accuracy                           0.87        71
#    macro avg       0.85      0.86      0.85        71
# weighted avg       0.88      0.87      0.87        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.09701967239379883
# Total Test Accuracy: 95.23809523809524
# Test Accuracy (NFF): 93.97590361445783
# Test Accuracy (AFF): 97.67441860465115
# Confusion Matrix:
#  [[78  5]
#  [ 1 42]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.94      0.96        83
#          AFF       0.89      0.98      0.93        43
#
#     accuracy                           0.95       126
#    macro avg       0.94      0.96      0.95       126
# weighted avg       0.96      0.95      0.95       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.23849427700042725
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 90.0
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[36  4]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.90      0.94        40
#          AFF       0.50      0.80      0.62         5
#
#     accuracy                           0.89        45
#    macro avg       0.74      0.85      0.78        45
# weighted avg       0.92      0.89      0.90        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.05603615939617157
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[8 0]
#  [0 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         1
#
#     accuracy                           1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.7262528836727142
# Total Test Accuracy: 72.26890756302521
# Test Accuracy (NFF): 69.41176470588235
# Test Accuracy (AFF): 79.41176470588235
# Confusion Matrix:
#  [[59 26]
#  [ 7 27]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.69      0.78        85
#          AFF       0.51      0.79      0.62        34
#
#     accuracy                           0.72       119
#    macro avg       0.70      0.74      0.70       119
# weighted avg       0.78      0.72      0.74       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 0.8308588862419128
# Total Test Accuracy: 77.31958762886597
# Test Accuracy (NFF): 81.13207547169812
# Test Accuracy (AFF): 72.72727272727273
# Confusion Matrix:
#  [[43 10]
#  [12 32]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.78      0.81      0.80        53
#          AFF       0.76      0.73      0.74        44
#
#     accuracy                           0.77        97
#    macro avg       0.77      0.77      0.77        97
# weighted avg       0.77      0.77      0.77        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.03988845273852348
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.46813875436782837
# Total Test Accuracy: 82.41758241758242
# Test Accuracy (NFF): 81.81818181818183
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[63 14]
#  [ 2 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.82      0.89        77
#          AFF       0.46      0.86      0.60        14
#
#     accuracy                           0.82        91
#    macro avg       0.72      0.84      0.74        91
# weighted avg       0.89      0.82      0.84        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 1.6117076873779297
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 60.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[9 6]
#  [0 3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.60      0.75        15
#          AFF       0.33      1.00      0.50         3
#
#     accuracy                           0.67        18
#    macro avg       0.67      0.80      0.62        18
# weighted avg       0.89      0.67      0.71        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.3170238137245178
# Total Test Accuracy: 88.46153846153847
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 87.5
# Confusion Matrix:
#  [[16  2]
#  [ 1  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.89      0.91        18
#          AFF       0.78      0.88      0.82         8
#
#     accuracy                           0.88        26
#    macro avg       0.86      0.88      0.87        26
# weighted avg       0.89      0.88      0.89        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.2878723442554474
# Total Test Accuracy: 94.44444444444444
# Test Accuracy (NFF): 94.11764705882352
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[16  1]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.94      0.97        17
#          AFF       0.50      1.00      0.67         1
#
#     accuracy                           0.94        18
#    macro avg       0.75      0.97      0.82        18
# weighted avg       0.97      0.94      0.95        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.46856600046157837
# Total Test Accuracy: 84.94623655913979
# Test Accuracy (NFF): 86.07594936708861
# Test Accuracy (AFF): 78.57142857142857
# Confusion Matrix:
#  [[68 11]
#  [ 3 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.86      0.91        79
#          AFF       0.50      0.79      0.61        14
#
#     accuracy                           0.85        93
#    macro avg       0.73      0.82      0.76        93
# weighted avg       0.89      0.85      0.86        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 0.5400950312614441
# Total Test Accuracy: 81.25
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[6 3]
#  [0 7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         9
#          AFF       0.70      1.00      0.82         7
#
#     accuracy                           0.81        16
#    macro avg       0.85      0.83      0.81        16
# weighted avg       0.87      0.81      0.81        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 1.2449332475662231
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4 2]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         6
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         6
#    macro avg       0.50      0.83      0.40         6
# weighted avg       1.00      0.67      0.80         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 0.4143163152039051
# Total Test Accuracy: 80.95238095238095
# Test Accuracy (NFF): 79.1044776119403
# Test Accuracy (AFF): 88.23529411764706
# Confusion Matrix:
#  [[53 14]
#  [ 2 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.79      0.87        67
#          AFF       0.52      0.88      0.65        17
#
#     accuracy                           0.81        84
#    macro avg       0.74      0.84      0.76        84
# weighted avg       0.87      0.81      0.83        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.021285906434059143
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.4709782501061757
# Total Test Accuracy: 83.10810810810811
# Test Accuracy (NFF): 83.33333333333334
# Test Accuracy (AFF): 81.81818181818183
# Confusion Matrix:
#  [[105  21]
#  [  4  18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.83      0.89       126
#          AFF       0.46      0.82      0.59        22
#
#     accuracy                           0.83       148
#    macro avg       0.71      0.83      0.74       148
# weighted avg       0.89      0.83      0.85       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.19973823428153992
# Total Test Accuracy: 88.23529411764706
# Test Accuracy (NFF): 88.23529411764706
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[30  4]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.94        34
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.88        34
#    macro avg       0.50      0.94      0.47        34
# weighted avg       1.00      0.88      0.94        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.7474409937858582
# Total Test Accuracy: 70.58823529411765
# Test Accuracy (NFF): 64.28571428571429
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[9 5]
#  [0 3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.64      0.78        14
#          AFF       0.38      1.00      0.55         3
#
#     accuracy                           0.71        17
#    macro avg       0.69      0.82      0.66        17
# weighted avg       0.89      0.71      0.74        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.912692129611969
# Total Test Accuracy: 75.5813953488372
# Test Accuracy (NFF): 72.05882352941177
# Test Accuracy (AFF): 88.88888888888889
# Confusion Matrix:
#  [[49 19]
#  [ 2 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.72      0.82        68
#          AFF       0.46      0.89      0.60        18
#
#     accuracy                           0.76        86
#    macro avg       0.71      0.80      0.71        86
# weighted avg       0.86      0.76      0.78        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.45952650904655457
# Total Test Accuracy: 84.0
# Test Accuracy (NFF): 84.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21  4]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.84      0.91        25
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.84        25
#    macro avg       0.50      0.92      0.46        25
# weighted avg       1.00      0.84      0.91        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 1.1097238063812256
# Total Test Accuracy: 72.41379310344827
# Test Accuracy (NFF): 69.56521739130434
# Test Accuracy (AFF): 83.33333333333334
# Confusion Matrix:
#  [[16  7]
#  [ 1  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.70      0.80        23
#          AFF       0.42      0.83      0.56         6
#
#     accuracy                           0.72        29
#    macro avg       0.68      0.76      0.68        29
# weighted avg       0.83      0.72      0.75        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.41832150146365166
# Total Test Accuracy: 78.66666666666667
# Test Accuracy (NFF): 82.85714285714286
# Test Accuracy (AFF): 20.0
# Confusion Matrix:
#  [[58 12]
#  [ 4  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.83      0.88        70
#          AFF       0.08      0.20      0.11         5
#
#     accuracy                           0.79        75
#    macro avg       0.51      0.51      0.49        75
# weighted avg       0.88      0.79      0.83        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 0.004408931825309992
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 1.141306757926941
# Total Test Accuracy: 60.0
# Test Accuracy (NFF): 60.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9 6]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.60      0.75        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.60        15
#    macro avg       0.50      0.80      0.37        15
# weighted avg       1.00      0.60      0.75        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.11132959555834532
# Total Test Accuracy: 97.14285714285714
# Test Accuracy (NFF): 96.47058823529412
# Test Accuracy (AFF): 98.66666666666667
# Confusion Matrix:
#  [[164   6]
#  [  1  74]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.96      0.98       170
#          AFF       0.93      0.99      0.95        75
#
#     accuracy                           0.97       245
#    macro avg       0.96      0.98      0.97       245
# weighted avg       0.97      0.97      0.97       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.6247367262840271
# Total Test Accuracy: 77.41935483870968
# Test Accuracy (NFF): 73.07692307692307
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[19  7]
#  [ 0  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.73      0.84        26
#          AFF       0.42      1.00      0.59         5
#
#     accuracy                           0.77        31
#    macro avg       0.71      0.87      0.72        31
# weighted avg       0.91      0.77      0.80        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.4276847392320633
# Total Test Accuracy: 84.29752066115702
# Test Accuracy (NFF): 79.54545454545455
# Test Accuracy (AFF): 96.96969696969697
# Confusion Matrix:
#  [[70 18]
#  [ 1 32]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.80      0.88        88
#          AFF       0.64      0.97      0.77        33
#
#     accuracy                           0.84       121
#    macro avg       0.81      0.88      0.83       121
# weighted avg       0.89      0.84      0.85       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.3029412031173706
# Total Test Accuracy: 95.45454545454545
# Test Accuracy (NFF): 95.45454545454545
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.95      0.98        22
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.95        22
#    macro avg       0.50      0.98      0.49        22
# weighted avg       1.00      0.95      0.98        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.43407391011714935
# Total Test Accuracy: 85.71428571428571
# Test Accuracy (NFF): 87.17948717948718
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[68 10]
#  [ 4 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.87      0.91        78
#          AFF       0.62      0.80      0.70        20
#
#     accuracy                           0.86        98
#    macro avg       0.78      0.84      0.80        98
# weighted avg       0.88      0.86      0.86        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.16050192713737488
# Total Test Accuracy: 92.95774647887323
# Test Accuracy (NFF): 92.1875
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[59  5]
#  [ 0  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.92      0.96        64
#          AFF       0.58      1.00      0.74         7
#
#     accuracy                           0.93        71
#    macro avg       0.79      0.96      0.85        71
# weighted avg       0.96      0.93      0.94        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.9390987753868103
# Total Test Accuracy: 77.19298245614036
# Test Accuracy (NFF): 77.19298245614034
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[44 13]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.77      0.87        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.77        57
#    macro avg       0.50      0.89      0.44        57
# weighted avg       1.00      0.77      0.87        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.5564126223325729
# Total Test Accuracy: 84.46601941747574
# Test Accuracy (NFF): 86.8421052631579
# Test Accuracy (AFF): 77.77777777777779
# Confusion Matrix:
#  [[66 10]
#  [ 6 21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.87      0.89        76
#          AFF       0.68      0.78      0.72        27
#
#     accuracy                           0.84       103
#    macro avg       0.80      0.82      0.81       103
# weighted avg       0.85      0.84      0.85       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.3716876059770584
# Total Test Accuracy: 82.27848101265823
# Test Accuracy (NFF): 84.72222222222221
# Test Accuracy (AFF): 57.14285714285714
# Confusion Matrix:
#  [[61 11]
#  [ 3  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.85      0.90        72
#          AFF       0.27      0.57      0.36         7
#
#     accuracy                           0.82        79
#    macro avg       0.61      0.71      0.63        79
# weighted avg       0.89      0.82      0.85        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.20478203892707825
# Total Test Accuracy: 88.46153846153847
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[21  3]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.93        24
#          AFF       0.40      1.00      0.57         2
#
#     accuracy                           0.88        26
#    macro avg       0.70      0.94      0.75        26
# weighted avg       0.95      0.88      0.91        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 0.4517532289028168
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 77.77777777777779
# Confusion Matrix:
#  [[3 0]
#  [2 7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.60      1.00      0.75         3
#          AFF       1.00      0.78      0.88         9
#
#     accuracy                           0.83        12
#    macro avg       0.80      0.89      0.81        12
# weighted avg       0.90      0.83      0.84        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.28798791983475286
# Total Test Accuracy: 88.05970149253731
# Test Accuracy (NFF): 88.67924528301887
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[94 12]
#  [ 4 24]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.89      0.92       106
#          AFF       0.67      0.86      0.75        28
#
#     accuracy                           0.88       134
#    macro avg       0.81      0.87      0.84       134
# weighted avg       0.90      0.88      0.89       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.17793524265289307
# Total Test Accuracy: 95.55555555555556
# Test Accuracy (NFF): 98.02631578947368
# Test Accuracy (AFF): 82.14285714285714
# Confusion Matrix:
#  [[149   3]
#  [  5  23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.98      0.97       152
#          AFF       0.88      0.82      0.85        28
#
#     accuracy                           0.96       180
#    macro avg       0.93      0.90      0.91       180
# weighted avg       0.95      0.96      0.95       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.5977830290794373
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 81.48148148148148
# Test Accuracy (AFF): 76.92307692307693
# Confusion Matrix:
#  [[22  5]
#  [ 3 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.81      0.85        27
#          AFF       0.67      0.77      0.71        13
#
#     accuracy                           0.80        40
#    macro avg       0.77      0.79      0.78        40
# weighted avg       0.81      0.80      0.80        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 0.00925422552973032
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 58:
#
# Test Loss: 0.7122911214828491
# Total Test Accuracy: 84.21052631578948
# Test Accuracy (NFF): 79.3103448275862
# Test Accuracy (AFF): 89.28571428571429
# Confusion Matrix:
#  [[23  6]
#  [ 3 25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.79      0.84        29
#          AFF       0.81      0.89      0.85        28
#
#     accuracy                           0.84        57
#    macro avg       0.85      0.84      0.84        57
# weighted avg       0.85      0.84      0.84        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.4203728437423706
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.89      0.94         9
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.89         9
#    macro avg       0.50      0.94      0.47         9
# weighted avg       1.00      0.89      0.94         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.5124435871839523
# Total Test Accuracy: 79.67479674796748
# Test Accuracy (NFF): 81.0
# Test Accuracy (AFF): 73.91304347826086
# Confusion Matrix:
#  [[81 19]
#  [ 6 17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.81      0.87       100
#          AFF       0.47      0.74      0.58        23
#
#     accuracy                           0.80       123
#    macro avg       0.70      0.77      0.72       123
# weighted avg       0.85      0.80      0.81       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.291169136762619
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 91.30434782608695
# Test Accuracy (AFF): 82.35294117647058
# Confusion Matrix:
#  [[42  4]
#  [ 3 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.91      0.92        46
#          AFF       0.78      0.82      0.80        17
#
#     accuracy                           0.89        63
#    macro avg       0.86      0.87      0.86        63
# weighted avg       0.89      0.89      0.89        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 0.6749977469444275
# Total Test Accuracy: 75.47169811320755
# Test Accuracy (NFF): 75.60975609756098
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[31 10]
#  [ 3  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.76      0.83        41
#          AFF       0.47      0.75      0.58        12
#
#     accuracy                           0.75        53
#    macro avg       0.69      0.75      0.70        53
# weighted avg       0.81      0.75      0.77        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 0.6395416855812073
# Total Test Accuracy: 87.5
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[7 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.93         8
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.88         8
#    macro avg       0.50      0.94      0.47         8
# weighted avg       1.00      0.88      0.93         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.35092195868492126
# Total Test Accuracy: 84.375
# Test Accuracy (NFF): 84.375
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[27  5]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.84      0.92        32
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.84        32
#    macro avg       0.50      0.92      0.46        32
# weighted avg       1.00      0.84      0.92        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.07070664316415787
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[8 0]
#  [0 2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         2
#
#     accuracy                           1.00        10
#    macro avg       1.00      1.00      1.00        10
# weighted avg       1.00      1.00      1.00        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.4815618693828583
# Total Test Accuracy: 77.27272727272727
# Test Accuracy (NFF): 82.35294117647058
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[14  3]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.82      0.85        17
#          AFF       0.50      0.60      0.55         5
#
#     accuracy                           0.77        22
#    macro avg       0.69      0.71      0.70        22
# weighted avg       0.79      0.77      0.78        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.5383051633834839
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 93.10344827586206
# Test Accuracy (AFF): 42.857142857142854
# Confusion Matrix:
#  [[27  2]
#  [ 4  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.93      0.90        29
#          AFF       0.60      0.43      0.50         7
#
#     accuracy                           0.83        36
#    macro avg       0.74      0.68      0.70        36
# weighted avg       0.82      0.83      0.82        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.5946819117436042
# Total Test Accuracy: 79.55665024630542
# Test Accuracy (NFF): 78.23439878234399
# Test Accuracy (AFF): 85.16129032258064
# Confusion Matrix:
#  [[514 143]
#  [ 23 132]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.78      0.86       657
#          AFF       0.48      0.85      0.61       155
#
#     accuracy                           0.80       812
#    macro avg       0.72      0.82      0.74       812
# weighted avg       0.87      0.80      0.81       812
#
#
# Average Total Test Accuracy: 83.3687073972838

# %% [markdown]
# # DenseNet 161

# %%
from torchvision.models import densenet161, DenseNet161_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the DenseNet-161 model
model = models.densenet161(weights=DenseNet161_Weights.DEFAULT)

# Modify the classifier part of the model
num_features = model.classifier.in_features
model.classifier = nn.Linear(num_features, 2)

# total layers 
total_layers = len(list(model.features.children()))

# freeze 50% layers
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.features.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False
            
# ---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 20
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

dense161 = train_custom_model(model, train_dataset, val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/20, Train ACC: 54.31%, Validation ACC: 78.57%
# Epoch 2/20, Train ACC: 71.28%, Validation ACC: 80.36%
# Epoch 3/20, Train ACC: 80.94%, Validation ACC: 79.17%
# Epoch 4/20, Train ACC: 86.42%, Validation ACC: 79.17%
# Epoch 5/20, Train ACC: 87.21%, Validation ACC: 75.00%
# Epoch 6/20, Train ACC: 90.60%, Validation ACC: 82.14%
# Epoch 7/20, Train ACC: 93.73%, Validation ACC: 80.36%
# Epoch 8/20, Train ACC: 91.91%, Validation ACC: 83.93%
# Epoch 9/20, Train ACC: 95.56%, Validation ACC: 88.10%
# Epoch 10/20, Train ACC: 96.08%, Validation ACC: 89.88%
# Epoch 11/20, Train ACC: 96.08%, Validation ACC: 90.48%
# Epoch 12/20, Train ACC: 97.39%, Validation ACC: 90.48%
# Epoch 13/20, Train ACC: 98.43%, Validation ACC: 89.88%
# Epoch 14/20, Train ACC: 97.91%, Validation ACC: 91.07%
# Epoch 15/20, Train ACC: 96.87%, Validation ACC: 89.88%
# Epoch 16/20, Train ACC: 98.43%, Validation ACC: 89.29%
# Epoch 17/20, Train ACC: 99.74%, Validation ACC: 91.07%
# Epoch 18/20, Train ACC: 99.74%, Validation ACC: 91.07%
# Epoch 19/20, Train ACC: 98.17%, Validation ACC: 90.48%
# Epoch 20/20, Train ACC: 96.87%, Validation ACC: 90.48%

# %%
model = dense161
model.eval()
# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomCsvDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(15, 5))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
torch.cuda.empty_cache()
results.append(average_performance)
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.07547322660684586
# Total Test Accuracy: 95.65217391304348
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[22  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        23
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.96        23
#    macro avg       0.50      0.98      0.49        23
# weighted avg       1.00      0.96      0.98        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 0.0011288740206509829
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         0
#          AFF       1.00      1.00      1.00         3
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.3625306487083435
# Total Test Accuracy: 85.71428571428571
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[22  1]
#  [ 4  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.96      0.90        23
#          AFF       0.89      0.67      0.76        12
#
#     accuracy                           0.86        35
#    macro avg       0.87      0.81      0.83        35
# weighted avg       0.86      0.86      0.85        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.012790955603122711
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         2
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.11554339248687029
# Total Test Accuracy: 92.3076923076923
# Test Accuracy (NFF): 95.0
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[57  3]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.95      0.96        60
#          AFF       0.50      0.60      0.55         5
#
#     accuracy                           0.92        65
#    macro avg       0.73      0.77      0.75        65
# weighted avg       0.93      0.92      0.93        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.2958092987537384
# Total Test Accuracy: 91.07142857142857
# Test Accuracy (NFF): 97.22222222222221
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[35  1]
#  [ 4 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.97      0.93        36
#          AFF       0.94      0.80      0.86        20
#
#     accuracy                           0.91        56
#    macro avg       0.92      0.89      0.90        56
# weighted avg       0.91      0.91      0.91        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.05108870938420296
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.4066966325044632
# Total Test Accuracy: 91.2621359223301
# Test Accuracy (NFF): 96.25
# Test Accuracy (AFF): 73.91304347826086
# Confusion Matrix:
#  [[77  3]
#  [ 6 17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.96      0.94        80
#          AFF       0.85      0.74      0.79        23
#
#     accuracy                           0.91       103
#    macro avg       0.89      0.85      0.87       103
# weighted avg       0.91      0.91      0.91       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.007376439869403839
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 0.18847237527370453
# Total Test Accuracy: 92.7536231884058
# Test Accuracy (NFF): 98.11320754716981
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[52  1]
#  [ 4 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.98      0.95        53
#          AFF       0.92      0.75      0.83        16
#
#     accuracy                           0.93        69
#    macro avg       0.93      0.87      0.89        69
# weighted avg       0.93      0.93      0.92        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.1544777429662645
# Total Test Accuracy: 93.50649350649351
# Test Accuracy (NFF): 96.875
# Test Accuracy (AFF): 76.92307692307693
# Confusion Matrix:
#  [[62  2]
#  [ 3 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.97      0.96        64
#          AFF       0.83      0.77      0.80        13
#
#     accuracy                           0.94        77
#    macro avg       0.89      0.87      0.88        77
# weighted avg       0.93      0.94      0.93        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.13347862288355827
# Total Test Accuracy: 94.87179487179488
# Test Accuracy (NFF): 94.69026548672566
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[107   6]
#  [  0   4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.95      0.97       113
#          AFF       0.40      1.00      0.57         4
#
#     accuracy                           0.95       117
#    macro avg       0.70      0.97      0.77       117
# weighted avg       0.98      0.95      0.96       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.12088275700807571
# Total Test Accuracy: 93.33333333333333
# Test Accuracy (NFF): 95.34883720930233
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[41  2]
#  [ 1  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.95      0.96        43
#          AFF       0.33      0.50      0.40         2
#
#     accuracy                           0.93        45
#    macro avg       0.65      0.73      0.68        45
# weighted avg       0.95      0.93      0.94        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.03348224610090256
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        21
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 0.11919262260198593
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.07183213531970978
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         4
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 0.3025580979883671
# Total Test Accuracy: 85.91549295774648
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 54.54545454545454
# Confusion Matrix:
#  [[49  0]
#  [10 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.83      1.00      0.91        49
#          AFF       1.00      0.55      0.71        22
#
#     accuracy                           0.86        71
#    macro avg       0.92      0.77      0.81        71
# weighted avg       0.88      0.86      0.84        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.04871339537203312
# Total Test Accuracy: 98.41269841269842
# Test Accuracy (NFF): 98.79518072289156
# Test Accuracy (AFF): 97.67441860465115
# Confusion Matrix:
#  [[82  1]
#  [ 1 42]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.99      0.99        83
#          AFF       0.98      0.98      0.98        43
#
#     accuracy                           0.98       126
#    macro avg       0.98      0.98      0.98       126
# weighted avg       0.98      0.98      0.98       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.20651748776435852
# Total Test Accuracy: 91.11111111111111
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 20.0
# Confusion Matrix:
#  [[40  0]
#  [ 4  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      1.00      0.95        40
#          AFF       1.00      0.20      0.33         5
#
#     accuracy                           0.91        45
#    macro avg       0.95      0.60      0.64        45
# weighted avg       0.92      0.91      0.88        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.03127811476588249
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[8 0]
#  [0 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         1
#
#     accuracy                           1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.4396800547838211
# Total Test Accuracy: 84.03361344537815
# Test Accuracy (NFF): 90.58823529411765
# Test Accuracy (AFF): 67.64705882352942
# Confusion Matrix:
#  [[77  8]
#  [11 23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.91      0.89        85
#          AFF       0.74      0.68      0.71        34
#
#     accuracy                           0.84       119
#    macro avg       0.81      0.79      0.80       119
# weighted avg       0.84      0.84      0.84       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 0.5467232465744019
# Total Test Accuracy: 82.47422680412372
# Test Accuracy (NFF): 94.33962264150944
# Test Accuracy (AFF): 68.18181818181817
# Confusion Matrix:
#  [[50  3]
#  [14 30]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.78      0.94      0.85        53
#          AFF       0.91      0.68      0.78        44
#
#     accuracy                           0.82        97
#    macro avg       0.85      0.81      0.82        97
# weighted avg       0.84      0.82      0.82        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.003545043058693409
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.15881698951125145
# Total Test Accuracy: 95.6043956043956
# Test Accuracy (NFF): 96.1038961038961
# Test Accuracy (AFF): 92.85714285714286
# Confusion Matrix:
#  [[74  3]
#  [ 1 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.96      0.97        77
#          AFF       0.81      0.93      0.87        14
#
#     accuracy                           0.96        91
#    macro avg       0.90      0.94      0.92        91
# weighted avg       0.96      0.96      0.96        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 0.273095965385437
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 93.33333333333333
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[14  1]
#  [ 1  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.93      0.93        15
#          AFF       0.67      0.67      0.67         3
#
#     accuracy                           0.89        18
#    macro avg       0.80      0.80      0.80        18
# weighted avg       0.89      0.89      0.89        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.32874059677124023
# Total Test Accuracy: 92.3076923076923
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[18  0]
#  [ 2  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      1.00      0.95        18
#          AFF       1.00      0.75      0.86         8
#
#     accuracy                           0.92        26
#    macro avg       0.95      0.88      0.90        26
# weighted avg       0.93      0.92      0.92        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.012908535078167915
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[17  0]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        17
#          AFF       1.00      1.00      1.00         1
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.21620699018239975
# Total Test Accuracy: 89.24731182795699
# Test Accuracy (NFF): 94.9367088607595
# Test Accuracy (AFF): 57.14285714285714
# Confusion Matrix:
#  [[75  4]
#  [ 6  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.95      0.94        79
#          AFF       0.67      0.57      0.62        14
#
#     accuracy                           0.89        93
#    macro avg       0.80      0.76      0.78        93
# weighted avg       0.89      0.89      0.89        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 0.3557162880897522
# Total Test Accuracy: 87.5
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[9 0]
#  [2 5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.82      1.00      0.90         9
#          AFF       1.00      0.71      0.83         7
#
#     accuracy                           0.88        16
#    macro avg       0.91      0.86      0.87        16
# weighted avg       0.90      0.88      0.87        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 0.24437262117862701
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 83.33333333333334
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[5 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.83      0.91         6
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.83         6
#    macro avg       0.50      0.92      0.45         6
# weighted avg       1.00      0.83      0.91         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 0.08922277204692364
# Total Test Accuracy: 92.85714285714286
# Test Accuracy (NFF): 97.01492537313433
# Test Accuracy (AFF): 76.47058823529412
# Confusion Matrix:
#  [[65  2]
#  [ 4 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.97      0.96        67
#          AFF       0.87      0.76      0.81        17
#
#     accuracy                           0.93        84
#    macro avg       0.90      0.87      0.88        84
# weighted avg       0.93      0.93      0.93        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.0015474000247195363
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.24308866262435913
# Total Test Accuracy: 89.86486486486487
# Test Accuracy (NFF): 94.44444444444444
# Test Accuracy (AFF): 63.63636363636363
# Confusion Matrix:
#  [[119   7]
#  [  8  14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.94      0.94       126
#          AFF       0.67      0.64      0.65        22
#
#     accuracy                           0.90       148
#    macro avg       0.80      0.79      0.80       148
# weighted avg       0.90      0.90      0.90       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.03930748626589775
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[34]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        34
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        34
#    macro avg       1.00      1.00      1.00        34
# weighted avg       1.00      1.00      1.00        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.03228848800063133
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[14  0]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        14
#          AFF       1.00      1.00      1.00         3
#
#     accuracy                           1.00        17
#    macro avg       1.00      1.00      1.00        17
# weighted avg       1.00      1.00      1.00        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.2313069924712181
# Total Test Accuracy: 89.53488372093024
# Test Accuracy (NFF): 94.11764705882352
# Test Accuracy (AFF): 72.22222222222221
# Confusion Matrix:
#  [[64  4]
#  [ 5 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.94      0.93        68
#          AFF       0.76      0.72      0.74        18
#
#     accuracy                           0.90        86
#    macro avg       0.85      0.83      0.84        86
# weighted avg       0.89      0.90      0.89        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.029141152277588844
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        25
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        25
#    macro avg       1.00      1.00      1.00        25
# weighted avg       1.00      1.00      1.00        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.34260469675064087
# Total Test Accuracy: 86.20689655172414
# Test Accuracy (NFF): 86.95652173913044
# Test Accuracy (AFF): 83.33333333333334
# Confusion Matrix:
#  [[20  3]
#  [ 1  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.87      0.91        23
#          AFF       0.62      0.83      0.71         6
#
#     accuracy                           0.86        29
#    macro avg       0.79      0.85      0.81        29
# weighted avg       0.88      0.86      0.87        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.3292259592562914
# Total Test Accuracy: 86.66666666666667
# Test Accuracy (NFF): 92.85714285714286
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[65  5]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.93      0.93        70
#          AFF       0.00      0.00      1.00         5
#
#     accuracy                           0.87        75
#    macro avg       0.46      0.46      0.96        75
# weighted avg       0.87      0.87      0.93        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 0.00348527985624969
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 0.4505852162837982
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 80.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[12  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.80      0.89        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.80        15
#    macro avg       0.50      0.90      0.44        15
# weighted avg       1.00      0.80      0.89        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.1260255842935294
# Total Test Accuracy: 97.14285714285714
# Test Accuracy (NFF): 98.23529411764706
# Test Accuracy (AFF): 94.66666666666667
# Confusion Matrix:
#  [[167   3]
#  [  4  71]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.98      0.98       170
#          AFF       0.96      0.95      0.95        75
#
#     accuracy                           0.97       245
#    macro avg       0.97      0.96      0.97       245
# weighted avg       0.97      0.97      0.97       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.15962505340576172
# Total Test Accuracy: 90.3225806451613
# Test Accuracy (NFF): 96.15384615384616
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[25  1]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.96      0.94        26
#          AFF       0.75      0.60      0.67         5
#
#     accuracy                           0.90        31
#    macro avg       0.84      0.78      0.81        31
# weighted avg       0.90      0.90      0.90        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.15801581740379333
# Total Test Accuracy: 95.04132231404958
# Test Accuracy (NFF): 97.72727272727273
# Test Accuracy (AFF): 87.87878787878788
# Confusion Matrix:
#  [[86  2]
#  [ 4 29]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.98      0.97        88
#          AFF       0.94      0.88      0.91        33
#
#     accuracy                           0.95       121
#    macro avg       0.95      0.93      0.94       121
# weighted avg       0.95      0.95      0.95       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.2905099391937256
# Total Test Accuracy: 90.9090909090909
# Test Accuracy (NFF): 90.9090909090909
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[20  2]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.91      0.95        22
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.91        22
#    macro avg       0.50      0.95      0.48        22
# weighted avg       1.00      0.91      0.95        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.20382618717849255
# Total Test Accuracy: 90.81632653061224
# Test Accuracy (NFF): 96.15384615384616
# Test Accuracy (AFF): 70.0
# Confusion Matrix:
#  [[75  3]
#  [ 6 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.96      0.94        78
#          AFF       0.82      0.70      0.76        20
#
#     accuracy                           0.91        98
#    macro avg       0.87      0.83      0.85        98
# weighted avg       0.91      0.91      0.91        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.10627788119018078
# Total Test Accuracy: 94.36619718309859
# Test Accuracy (NFF): 95.3125
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[61  3]
#  [ 1  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.95      0.97        64
#          AFF       0.67      0.86      0.75         7
#
#     accuracy                           0.94        71
#    macro avg       0.83      0.91      0.86        71
# weighted avg       0.95      0.94      0.95        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.2147078961133957
# Total Test Accuracy: 94.73684210526316
# Test Accuracy (NFF): 94.73684210526315
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[54  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.95      0.97        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.95        57
#    macro avg       0.50      0.97      0.49        57
# weighted avg       1.00      0.95      0.97        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.4053666740655899
# Total Test Accuracy: 88.3495145631068
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 55.55555555555556
# Confusion Matrix:
#  [[76  0]
#  [12 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.86      1.00      0.93        76
#          AFF       1.00      0.56      0.71        27
#
#     accuracy                           0.88       103
#    macro avg       0.93      0.78      0.82       103
# weighted avg       0.90      0.88      0.87       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.18319066613912582
# Total Test Accuracy: 91.13924050632912
# Test Accuracy (NFF): 95.83333333333334
# Test Accuracy (AFF): 42.857142857142854
# Confusion Matrix:
#  [[69  3]
#  [ 4  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.96      0.95        72
#          AFF       0.50      0.43      0.46         7
#
#     accuracy                           0.91        79
#    macro avg       0.72      0.69      0.71        79
# weighted avg       0.91      0.91      0.91        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.024977250024676323
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[24  0]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        24
#          AFF       1.00      1.00      1.00         2
#
#     accuracy                           1.00        26
#    macro avg       1.00      1.00      1.00        26
# weighted avg       1.00      1.00      1.00        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 1.908392310142517
# Total Test Accuracy: 50.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 33.33333333333333
# Confusion Matrix:
#  [[3 0]
#  [6 3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.33      1.00      0.50         3
#          AFF       1.00      0.33      0.50         9
#
#     accuracy                           0.50        12
#    macro avg       0.67      0.67      0.50        12
# weighted avg       0.83      0.50      0.50        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.1464477088302374
# Total Test Accuracy: 91.04477611940298
# Test Accuracy (NFF): 98.11320754716981
# Test Accuracy (AFF): 64.28571428571429
# Confusion Matrix:
#  [[104   2]
#  [ 10  18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.98      0.95       106
#          AFF       0.90      0.64      0.75        28
#
#     accuracy                           0.91       134
#    macro avg       0.91      0.81      0.85       134
# weighted avg       0.91      0.91      0.90       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.13882141886278987
# Total Test Accuracy: 96.11111111111111
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[152   0]
#  [  7  21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      1.00      0.98       152
#          AFF       1.00      0.75      0.86        28
#
#     accuracy                           0.96       180
#    macro avg       0.98      0.88      0.92       180
# weighted avg       0.96      0.96      0.96       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.44199618697166443
# Total Test Accuracy: 82.5
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 46.15384615384615
# Confusion Matrix:
#  [[27  0]
#  [ 7  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.79      1.00      0.89        27
#          AFF       1.00      0.46      0.63        13
#
#     accuracy                           0.82        40
#    macro avg       0.90      0.73      0.76        40
# weighted avg       0.86      0.82      0.80        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 0.05084748938679695
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 58:
#
# Test Loss: 0.47574907541275024
# Total Test Accuracy: 84.21052631578948
# Test Accuracy (NFF): 86.20689655172413
# Test Accuracy (AFF): 82.14285714285714
# Confusion Matrix:
#  [[25  4]
#  [ 5 23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.83      0.86      0.85        29
#          AFF       0.85      0.82      0.84        28
#
#     accuracy                           0.84        57
#    macro avg       0.84      0.84      0.84        57
# weighted avg       0.84      0.84      0.84        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.011556737124919891
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.250350221991539
# Total Test Accuracy: 91.869918699187
# Test Accuracy (NFF): 97.0
# Test Accuracy (AFF): 69.56521739130434
# Confusion Matrix:
#  [[97  3]
#  [ 7 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.97      0.95       100
#          AFF       0.84      0.70      0.76        23
#
#     accuracy                           0.92       123
#    macro avg       0.89      0.83      0.86       123
# weighted avg       0.92      0.92      0.92       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.2740752100944519
# Total Test Accuracy: 93.65079365079364
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 76.47058823529412
# Confusion Matrix:
#  [[46  0]
#  [ 4 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      1.00      0.96        46
#          AFF       1.00      0.76      0.87        17
#
#     accuracy                           0.94        63
#    macro avg       0.96      0.88      0.91        63
# weighted avg       0.94      0.94      0.93        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 0.648067057132721
# Total Test Accuracy: 83.01886792452831
# Test Accuracy (NFF): 87.8048780487805
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[36  5]
#  [ 4  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.88      0.89        41
#          AFF       0.62      0.67      0.64        12
#
#     accuracy                           0.83        53
#    macro avg       0.76      0.77      0.76        53
# weighted avg       0.84      0.83      0.83        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 0.04874620959162712
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.023914653807878494
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[32]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        32
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        32
#    macro avg       1.00      1.00      1.00        32
# weighted avg       1.00      1.00      1.00        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.043932825326919556
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[8 0]
#  [0 2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         2
#
#     accuracy                           1.00        10
#    macro avg       1.00      1.00      1.00        10
# weighted avg       1.00      1.00      1.00        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.19010300934314728
# Total Test Accuracy: 90.9090909090909
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[17  0]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      1.00      0.94        17
#          AFF       1.00      0.60      0.75         5
#
#     accuracy                           0.91        22
#    macro avg       0.95      0.80      0.85        22
# weighted avg       0.92      0.91      0.90        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.3614225387573242
# Total Test Accuracy: 86.11111111111111
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 28.57142857142857
# Confusion Matrix:
#  [[29  0]
#  [ 5  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      1.00      0.92        29
#          AFF       1.00      0.29      0.44         7
#
#     accuracy                           0.86        36
#    macro avg       0.93      0.64      0.68        36
# weighted avg       0.88      0.86      0.83        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.2991127990759336
# Total Test Accuracy: 88.42364532019704
# Test Accuracy (NFF): 92.54185692541856
# Test Accuracy (AFF): 70.96774193548387
# Confusion Matrix:
#  [[608  49]
#  [ 45 110]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.93      0.93       657
#          AFF       0.69      0.71      0.70       155
#
#     accuracy                           0.88       812
#    macro avg       0.81      0.82      0.81       812
# weighted avg       0.89      0.88      0.88       812
#
#
# Average Total Test Accuracy: 92.61352229469018

# %%
results
# Out:
# [84.75094885441308,
#  91.06869404207812,
#  89.40153831714062,
#  83.3687073972838,
#  92.61352229469018]

# %% [markdown]
# # Efficient B2

# %%
# from torchvision.models import efficientnet_b2, EfficientNet_B2_Weights

# torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# # Define the EfficientNetV2-M model
# model = efficientnet_b2(weights=EfficientNet_B2_Weights.DEFAULT)

# # Access input features of the classifier
# num_features = model.classifier[1].in_features

# # Modify the classifier part of the model
# model.classifier[1] = nn.Linear(in_features=num_features, out_features=2)

# # Freeze certain layers
# total_layers = len(list(model.children()))
# freeze_layers = int(total_layers * 0.5)
# for index, child in enumerate(model.children()):
#     if index < freeze_layers:
#         for param in child.parameters():
#             param.requires_grad = False

# # Hyperparameters
# num_epochs = 20
# batch_size = 8
# learning_rate = 0.0001
# optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# # Move model to GPU if available
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# model = model.to(device)

# # Train the model
# effi_b2 = train_custom_model(model, train_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
