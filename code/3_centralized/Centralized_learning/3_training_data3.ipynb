# %% [markdown]
# # Functions

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_curve, roc_auc_score

torch.manual_seed(1)

def show_image(dataset, num_images=5):
    # Get random indices
    random_indices = np.random.choice(len(dataset), num_images, replace=False)

    # Plot images with truncated names
    plt.figure(figsize=(15, 5))
    for i, idx in enumerate(random_indices):
        image, label = dataset[idx]  # Use the dataset directly
        filename = dataset.data[idx][0]  # Get the filename from dataset's internal data attribute
        truncated_filename = filename.split('/')[-1][:15]  # Extract the last part and truncate to 15 characters
        
        # Print the original filename
        print(f"Image location: {filename}")

        plt.subplot(1, num_images, i + 1)
        plt.title(f"Label: {label}")
        plt.imshow(image[0])  # Assuming single-channel (grayscale) image
        # plt.imshow(image[0], cmap='gray')  # Assuming single-channel (grayscale) image

        plt.axis('off')
    plt.show()
    
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_classweight(train_dataset):
    train_nff_count = sum(1 for _, label in train_dataset if label == 0)  # 0 NFF
    train_aff_count = sum(1 for _, label in train_dataset if label == 1)  # 1 AFF
    class_weight_nff = 1 / (2 * (train_nff_count / (train_nff_count + train_aff_count)))
    class_weight_aff = 1 / (2 * (train_aff_count / (train_nff_count + train_aff_count)))
    
    return [class_weight_nff, class_weight_aff] # 0 nff , 1 aff

# %%
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import csv
from torchvision import transforms, models
from sklearn.model_selection import KFold
# Define your image transformations for training and testing
from torchvision import transforms
# Custom dataset class
import os
import csv
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn as nn
from torchvision import models
from torchvision import transforms
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_curve, roc_auc_score
import torch.nn.functional as F
import json

# custom dataset on csv files
class CustomDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]
        image_path = item['ImagePath']
        label = item['Label']

        # Load image
        image = Image.open(image_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        # Convert label to numerical representation
        if label == 'NFF':
            label = 0
        elif label == 'AFF':
            label = 1
        else:
            raise ValueError("Invalid label in JSON data.")

        return image, label

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])


# augmentation
train_transforms = transforms.Compose([
    transforms.RandomRotation(degrees=30),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.GaussianBlur(kernel_size=3),
    transforms.RandomAdjustSharpness(sharpness_factor=5),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
# Define data augmentation transforms for validation data
val_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load JSON data
with open('/local/data1/honzh073/local_repository/FL/code/4_centralized_learning/csv_files/combined_data3.json', 'r') as json_file:
    json_data = json.load(json_file)
    train_data = json_data['train']
    val_data = json_data['val']

train_dataset = CustomDataset(train_data, transform=train_transforms)
val_dataset = CustomDataset(val_data, transform=val_transforms)

# classweight
classweight = get_classweight(train_dataset)
print('training class weight', classweight)


# # print images
# show_image(train_dataset, 5)

# calculate numbers
print("train")
print('-----------------------------------')
train_NFF_count = sum(1 for _, label in train_dataset if label == 0)  # 0 NFF
train_AFF_count = sum(1 for _, label in train_dataset if label == 1)  # 1 AFF

print(f"train AFF: {train_AFF_count}, ratio: {train_AFF_count / (train_AFF_count + train_NFF_count):.2f}")
print(f"----- NFF: {train_NFF_count}, ratio: {train_NFF_count / (train_AFF_count + train_NFF_count):.2f}")

print("val")
print('-----------------------------------')
train_NFF_count = sum(1 for _, label in val_dataset if label == 0)  # 0 NFF
train_AFF_count = sum(1 for _, label in val_dataset if label == 1)  # 1 AFF

print(f"train AFF: {train_AFF_count}, ratio: {train_AFF_count / (train_AFF_count + train_NFF_count):.2f}")
print(f"----- NFF: {train_NFF_count}, ratio: {train_NFF_count / (train_AFF_count + train_NFF_count):.2f}")
# Out:
# training class weight [0.7018518518518518, 1.738532110091743]
# train
# -----------------------------------
# train AFF: 109, ratio: 0.29
# ----- NFF: 270, ratio: 0.71
# val
# -----------------------------------
# train AFF: 37, ratio: 0.22
# ----- NFF: 135, ratio: 0.78

# %%
# custom dataset on csv files
class CustomCsvDataset(Dataset):
    def __init__(self, csv_file, transform=None):
        self.data = []
        self.labels = []  # Store labels separately
        self.patient_ids = []  # Store patient IDs separately
        self.hospital_ids = []  # Store hospital IDs separately
        self.transform = transform
        
        # read csv
        with open(csv_file, 'r') as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                image_path = row['ImagePath']
                label = row['Label']
                patient_id = row['PatientID']
                hospital_id = row['HospitalID']

                if label == 'NFF':
                    label = 0
                elif label == 'AFF':
                    label = 1
                else:
                    raise ValueError("Invalid label in CSV file.")
                self.data.append((image_path, label))
                self.labels.append(label)
                self.patient_ids.append(patient_id)
                self.hospital_ids.append(int(hospital_id))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image_path, label = self.data[idx]
        image = Image.open(image_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image, label

# %%
import torch
import random
import numpy as np

# 设置随机数种子
seed = 1
torch.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)

# 设置CUDA随机数种子（如果使用GPU）
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader
from sklearn.model_selection import StratifiedKFold
from torch.utils.data import DataLoader
from sklearn.metrics import roc_auc_score, confusion_matrix, classification_report




# ------------------------------------------------------------------------------------------------------
def train_custom_model(model, train_dataset, val_dataset, num_epochs, batch_size, optimizer=None):
    classweight = get_classweight(train_dataset) # get_classweight is a function defined above
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    model = model.to(device)
    criterion = nn.CrossEntropyLoss(weight=torch.Tensor(classweight).to(device))
    
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    for epoch in range(num_epochs):
        model.train()
        correct_train = 0
        total_train = 0

        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()

        train_accuracy = 100 * correct_train / total_train

        model.eval()
        correct_validation = 0
        total_validation = 0
        validation_loss = 0

        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                _, predicted = torch.max(outputs.data, 1)
                total_validation += labels.size(0)
                correct_validation += (predicted == labels).sum().item()
                validation_loss += loss.item()

        validation_accuracy = 100 * correct_validation / total_validation
        validation_loss /= len(val_loader)

        print(f"Epoch {epoch+1}/{num_epochs}, "
              f"Train ACC: {train_accuracy:.2f}%, "
              f"Validation ACC: {validation_accuracy:.2f}%")
    
    return model

# ------------------------------------------------------------------------------------------------------
def test_model(model, test_dataset, batch_size):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)
    model = model.to(device)

    model.eval()

    correct_test_nff = 0
    correct_test_aff = 0
    total_nff = 0
    total_aff = 0
    total_test = 0
    test_loss = 0

    criterion = nn.CrossEntropyLoss()

    with torch.no_grad():
        all_predictions = []
        all_labels = []
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            _, predicted = torch.max(outputs.data, 1)
            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            total_test += labels.size(0)
            total_nff += (labels == 0).sum().item()
            total_aff += (labels == 1).sum().item()
            correct_test_nff += ((predicted == labels) & (labels == 0)).sum().item()
            correct_test_aff += ((predicted == labels) & (labels == 1)).sum().item()
            test_loss += loss.item()

    # Check if total_aff is zero before performing the division
    test_accuracy_nff = 100 * (correct_test_nff / total_nff) if total_nff != 0 else 0
    test_accuracy_aff = 100 * (correct_test_aff / total_aff) if total_aff != 0 else 0
    test_accuracy_total = 100 * (correct_test_nff + correct_test_aff) / total_test
    test_loss /= len(test_loader)

    # Handle the case where there is only one class
    if len(set(all_labels)) > 1:
        auc_score = roc_auc_score(all_labels, all_predictions)
    else:
        auc_score = 0  # Default value if only one class is present

    conf_matrix = confusion_matrix(all_labels, all_predictions)

    # Directly use class labels as strings in target_names
    target_names = ['NFF', 'AFF']

    classification_rep = classification_report(all_labels, all_predictions, target_names=target_names, labels=[0, 1], zero_division=1)

    # Store metrics in a dictionary
    metrics = {
        "Test Loss": test_loss,
        "Total Test Accuracy": test_accuracy_total,
        "Test Accuracy (NFF)": test_accuracy_nff,
        "Test Accuracy (AFF)": test_accuracy_aff,
        "AUC": auc_score,
        "Confusion Matrix": conf_matrix,
        "Classification Report": classification_rep
    }
    return metrics

# %%
results = []

# %% [markdown]
# # VGG 19

# %%
from torchvision.models import vgg19, VGG19_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the VGG-19 model
model = models.vgg19(weights=VGG19_Weights.DEFAULT)

# Modify the classifier part of the model
num_features = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_features, 2)

# layer number
total_layers = len(list(model.features.children()))

# freeze 50% layer
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.features.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False
# ---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 20
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

v19 = train_custom_model(model, train_dataset, val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/20, Train ACC: 53.03%, Validation ACC: 74.42%
# Epoch 2/20, Train ACC: 58.84%, Validation ACC: 25.58%
# Epoch 3/20, Train ACC: 54.88%, Validation ACC: 80.81%
# Epoch 4/20, Train ACC: 68.07%, Validation ACC: 77.91%
# Epoch 5/20, Train ACC: 75.46%, Validation ACC: 85.47%
# Epoch 6/20, Train ACC: 78.63%, Validation ACC: 87.79%
# Epoch 7/20, Train ACC: 81.79%, Validation ACC: 88.95%
# Epoch 8/20, Train ACC: 83.11%, Validation ACC: 87.21%
# Epoch 9/20, Train ACC: 88.39%, Validation ACC: 81.98%
# Epoch 10/20, Train ACC: 85.75%, Validation ACC: 86.05%
# Epoch 11/20, Train ACC: 84.70%, Validation ACC: 81.98%
# Epoch 12/20, Train ACC: 89.97%, Validation ACC: 87.79%
# Epoch 13/20, Train ACC: 86.81%, Validation ACC: 86.05%
# Epoch 14/20, Train ACC: 93.40%, Validation ACC: 87.21%
# Epoch 15/20, Train ACC: 89.45%, Validation ACC: 89.53%
# Epoch 16/20, Train ACC: 92.61%, Validation ACC: 84.30%
# Epoch 17/20, Train ACC: 91.82%, Validation ACC: 84.88%
# Epoch 18/20, Train ACC: 90.77%, Validation ACC: 88.95%
# Epoch 19/20, Train ACC: 91.82%, Validation ACC: 87.79%
# Epoch 20/20, Train ACC: 92.88%, Validation ACC: 83.72%

# %%
model = v19
model.eval()
# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomCsvDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(10, 5))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
torch.cuda.empty_cache()
results.append(average_performance)
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.13985246419906616
# Total Test Accuracy: 95.65217391304348
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[22  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        23
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.96        23
#    macro avg       0.50      0.98      0.49        23
# weighted avg       1.00      0.96      0.98        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 0.30694761872291565
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[0 0]
#  [1 2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.00      1.00      0.00         0
#          AFF       1.00      0.67      0.80         3
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.36752721667289734
# Total Test Accuracy: 88.57142857142857
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[23  0]
#  [ 4  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      1.00      0.92        23
#          AFF       1.00      0.67      0.80        12
#
#     accuracy                           0.89        35
#    macro avg       0.93      0.83      0.86        35
# weighted avg       0.90      0.89      0.88        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.030679069459438324
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         2
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.22697142511606216
# Total Test Accuracy: 90.76923076923077
# Test Accuracy (NFF): 95.0
# Test Accuracy (AFF): 40.0
# Confusion Matrix:
#  [[57  3]
#  [ 3  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.95      0.95        60
#          AFF       0.40      0.40      0.40         5
#
#     accuracy                           0.91        65
#    macro avg       0.68      0.68      0.68        65
# weighted avg       0.91      0.91      0.91        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.5149478316307068
# Total Test Accuracy: 80.35714285714286
# Test Accuracy (NFF): 83.33333333333334
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[30  6]
#  [ 5 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.86      0.83      0.85        36
#          AFF       0.71      0.75      0.73        20
#
#     accuracy                           0.80        56
#    macro avg       0.79      0.79      0.79        56
# weighted avg       0.81      0.80      0.80        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.1551923006772995
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.37562647461891174
# Total Test Accuracy: 86.40776699029126
# Test Accuracy (NFF): 97.5
# Test Accuracy (AFF): 47.82608695652174
# Confusion Matrix:
#  [[78  2]
#  [12 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.97      0.92        80
#          AFF       0.85      0.48      0.61        23
#
#     accuracy                           0.86       103
#    macro avg       0.86      0.73      0.76       103
# weighted avg       0.86      0.86      0.85       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.050576601177453995
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 0.2917654812335968
# Total Test Accuracy: 78.26086956521739
# Test Accuracy (NFF): 92.45283018867924
# Test Accuracy (AFF): 31.25
# Confusion Matrix:
#  [[49  4]
#  [11  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.82      0.92      0.87        53
#          AFF       0.56      0.31      0.40        16
#
#     accuracy                           0.78        69
#    macro avg       0.69      0.62      0.63        69
# weighted avg       0.76      0.78      0.76        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.18942784145474434
# Total Test Accuracy: 89.6103896103896
# Test Accuracy (NFF): 96.875
# Test Accuracy (AFF): 53.84615384615385
# Confusion Matrix:
#  [[62  2]
#  [ 6  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.97      0.94        64
#          AFF       0.78      0.54      0.64        13
#
#     accuracy                           0.90        77
#    macro avg       0.84      0.75      0.79        77
# weighted avg       0.89      0.90      0.89        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.1880473792552948
# Total Test Accuracy: 91.45299145299145
# Test Accuracy (NFF): 92.03539823008849
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[104   9]
#  [  1   3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.92      0.95       113
#          AFF       0.25      0.75      0.38         4
#
#     accuracy                           0.91       117
#    macro avg       0.62      0.84      0.66       117
# weighted avg       0.97      0.91      0.93       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.1254957914352417
# Total Test Accuracy: 95.55555555555556
# Test Accuracy (NFF): 97.67441860465115
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[42  1]
#  [ 1  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.98      0.98        43
#          AFF       0.50      0.50      0.50         2
#
#     accuracy                           0.96        45
#    macro avg       0.74      0.74      0.74        45
# weighted avg       0.96      0.96      0.96        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.09492360055446625
# Total Test Accuracy: 95.23809523809524
# Test Accuracy (NFF): 95.23809523809523
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[20  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.95      0.98        21
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.95        21
#    macro avg       0.50      0.98      0.49        21
# weighted avg       1.00      0.95      0.98        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 0.6147752404212952
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         3
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.03567282855510712
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         4
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 0.4652118682861328
# Total Test Accuracy: 81.69014084507042
# Test Accuracy (NFF): 93.87755102040816
# Test Accuracy (AFF): 54.54545454545454
# Confusion Matrix:
#  [[46  3]
#  [10 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.82      0.94      0.88        49
#          AFF       0.80      0.55      0.65        22
#
#     accuracy                           0.82        71
#    macro avg       0.81      0.74      0.76        71
# weighted avg       0.81      0.82      0.81        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.2429008074104786
# Total Test Accuracy: 90.47619047619048
# Test Accuracy (NFF): 98.79518072289156
# Test Accuracy (AFF): 74.4186046511628
# Confusion Matrix:
#  [[82  1]
#  [11 32]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.99      0.93        83
#          AFF       0.97      0.74      0.84        43
#
#     accuracy                           0.90       126
#    macro avg       0.93      0.87      0.89       126
# weighted avg       0.91      0.90      0.90       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.2327447235584259
# Total Test Accuracy: 91.11111111111111
# Test Accuracy (NFF): 97.5
# Test Accuracy (AFF): 40.0
# Confusion Matrix:
#  [[39  1]
#  [ 3  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.97      0.95        40
#          AFF       0.67      0.40      0.50         5
#
#     accuracy                           0.91        45
#    macro avg       0.80      0.69      0.73        45
# weighted avg       0.90      0.91      0.90        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.5404036045074463
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 62.5
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[5 3]
#  [0 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.62      0.77         8
#          AFF       0.25      1.00      0.40         1
#
#     accuracy                           0.67         9
#    macro avg       0.62      0.81      0.58         9
# weighted avg       0.92      0.67      0.73         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.49504271149635315
# Total Test Accuracy: 78.99159663865547
# Test Accuracy (NFF): 87.05882352941177
# Test Accuracy (AFF): 58.82352941176471
# Confusion Matrix:
#  [[74 11]
#  [14 20]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      0.87      0.86        85
#          AFF       0.65      0.59      0.62        34
#
#     accuracy                           0.79       119
#    macro avg       0.74      0.73      0.74       119
# weighted avg       0.78      0.79      0.79       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 0.8004644215106964
# Total Test Accuracy: 74.22680412371135
# Test Accuracy (NFF): 96.22641509433963
# Test Accuracy (AFF): 47.72727272727273
# Confusion Matrix:
#  [[51  2]
#  [23 21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.69      0.96      0.80        53
#          AFF       0.91      0.48      0.63        44
#
#     accuracy                           0.74        97
#    macro avg       0.80      0.72      0.72        97
# weighted avg       0.79      0.74      0.72        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.8417397141456604
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         3
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.35537758469581604
# Total Test Accuracy: 87.91208791208791
# Test Accuracy (NFF): 94.8051948051948
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[73  4]
#  [ 7  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.95      0.93        77
#          AFF       0.64      0.50      0.56        14
#
#     accuracy                           0.88        91
#    macro avg       0.77      0.72      0.74        91
# weighted avg       0.87      0.88      0.87        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 0.47525230050086975
# Total Test Accuracy: 72.22222222222223
# Test Accuracy (NFF): 80.0
# Test Accuracy (AFF): 33.33333333333333
# Confusion Matrix:
#  [[12  3]
#  [ 2  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.86      0.80      0.83        15
#          AFF       0.25      0.33      0.29         3
#
#     accuracy                           0.72        18
#    macro avg       0.55      0.57      0.56        18
# weighted avg       0.76      0.72      0.74        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.25972965359687805
# Total Test Accuracy: 88.46153846153847
# Test Accuracy (NFF): 94.44444444444444
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[17  1]
#  [ 2  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.94      0.92        18
#          AFF       0.86      0.75      0.80         8
#
#     accuracy                           0.88        26
#    macro avg       0.88      0.85      0.86        26
# weighted avg       0.88      0.88      0.88        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.0888068825006485
# Total Test Accuracy: 94.44444444444444
# Test Accuracy (NFF): 94.11764705882352
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[16  1]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.94      0.97        17
#          AFF       0.50      1.00      0.67         1
#
#     accuracy                           0.94        18
#    macro avg       0.75      0.97      0.82        18
# weighted avg       0.97      0.94      0.95        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.27427658438682556
# Total Test Accuracy: 89.24731182795699
# Test Accuracy (NFF): 93.67088607594937
# Test Accuracy (AFF): 64.28571428571429
# Confusion Matrix:
#  [[74  5]
#  [ 5  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.94      0.94        79
#          AFF       0.64      0.64      0.64        14
#
#     accuracy                           0.89        93
#    macro avg       0.79      0.79      0.79        93
# weighted avg       0.89      0.89      0.89        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 0.8413681387901306
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 42.857142857142854
# Confusion Matrix:
#  [[9 0]
#  [4 3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.69      1.00      0.82         9
#          AFF       1.00      0.43      0.60         7
#
#     accuracy                           0.75        16
#    macro avg       0.85      0.71      0.71        16
# weighted avg       0.83      0.75      0.72        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 0.41008397936820984
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 83.33333333333334
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[5 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.83      0.91         6
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.83         6
#    macro avg       0.50      0.92      0.45         6
# weighted avg       1.00      0.83      0.91         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 0.15214019268751144
# Total Test Accuracy: 95.23809523809524
# Test Accuracy (NFF): 98.50746268656717
# Test Accuracy (AFF): 82.35294117647058
# Confusion Matrix:
#  [[66  1]
#  [ 3 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.99      0.97        67
#          AFF       0.93      0.82      0.87        17
#
#     accuracy                           0.95        84
#    macro avg       0.94      0.90      0.92        84
# weighted avg       0.95      0.95      0.95        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.11482740193605423
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.3814252018928528
# Total Test Accuracy: 84.45945945945945
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 59.09090909090909
# Confusion Matrix:
#  [[112  14]
#  [  9  13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.89      0.91       126
#          AFF       0.48      0.59      0.53        22
#
#     accuracy                           0.84       148
#    macro avg       0.70      0.74      0.72       148
# weighted avg       0.86      0.84      0.85       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.13365380465984344
# Total Test Accuracy: 91.17647058823529
# Test Accuracy (NFF): 91.17647058823529
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[31  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.91      0.95        34
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.91        34
#    macro avg       0.50      0.96      0.48        34
# weighted avg       1.00      0.91      0.95        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.040931280702352524
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[14  0]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        14
#          AFF       1.00      1.00      1.00         3
#
#     accuracy                           1.00        17
#    macro avg       1.00      1.00      1.00        17
# weighted avg       1.00      1.00      1.00        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.3526967614889145
# Total Test Accuracy: 82.55813953488372
# Test Accuracy (NFF): 92.64705882352942
# Test Accuracy (AFF): 44.44444444444444
# Confusion Matrix:
#  [[63  5]
#  [10  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.86      0.93      0.89        68
#          AFF       0.62      0.44      0.52        18
#
#     accuracy                           0.83        86
#    macro avg       0.74      0.69      0.70        86
# weighted avg       0.81      0.83      0.81        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.3846386671066284
# Total Test Accuracy: 88.0
# Test Accuracy (NFF): 88.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[22  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.94        25
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.88        25
#    macro avg       0.50      0.94      0.47        25
# weighted avg       1.00      0.88      0.94        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.4739242196083069
# Total Test Accuracy: 79.3103448275862
# Test Accuracy (NFF): 82.6086956521739
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[19  4]
#  [ 2  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.83      0.86        23
#          AFF       0.50      0.67      0.57         6
#
#     accuracy                           0.79        29
#    macro avg       0.70      0.75      0.72        29
# weighted avg       0.82      0.79      0.80        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.21003354247659445
# Total Test Accuracy: 88.0
# Test Accuracy (NFF): 94.28571428571428
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[66  4]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.94      0.94        70
#          AFF       0.00      0.00      1.00         5
#
#     accuracy                           0.88        75
#    macro avg       0.46      0.47      0.97        75
# weighted avg       0.87      0.88      0.94        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 0.0538080595433712
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 0.5951100587844849
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 80.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[12  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.80      0.89        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.80        15
#    macro avg       0.50      0.90      0.44        15
# weighted avg       1.00      0.80      0.89        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.18988393433392048
# Total Test Accuracy: 91.42857142857143
# Test Accuracy (NFF): 94.11764705882352
# Test Accuracy (AFF): 85.33333333333334
# Confusion Matrix:
#  [[160  10]
#  [ 11  64]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.94      0.94       170
#          AFF       0.86      0.85      0.86        75
#
#     accuracy                           0.91       245
#    macro avg       0.90      0.90      0.90       245
# weighted avg       0.91      0.91      0.91       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.3986775875091553
# Total Test Accuracy: 87.09677419354838
# Test Accuracy (NFF): 88.46153846153845
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[23  3]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.88      0.92        26
#          AFF       0.57      0.80      0.67         5
#
#     accuracy                           0.87        31
#    macro avg       0.76      0.84      0.79        31
# weighted avg       0.90      0.87      0.88        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.525269940495491
# Total Test Accuracy: 79.33884297520662
# Test Accuracy (NFF): 89.77272727272727
# Test Accuracy (AFF): 51.515151515151516
# Confusion Matrix:
#  [[79  9]
#  [16 17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.83      0.90      0.86        88
#          AFF       0.65      0.52      0.58        33
#
#     accuracy                           0.79       121
#    macro avg       0.74      0.71      0.72       121
# weighted avg       0.78      0.79      0.79       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.37130850553512573
# Total Test Accuracy: 77.27272727272727
# Test Accuracy (NFF): 77.27272727272727
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[17  5]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.77      0.87        22
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.77        22
#    macro avg       0.50      0.89      0.44        22
# weighted avg       1.00      0.77      0.87        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.23498136922717094
# Total Test Accuracy: 89.79591836734694
# Test Accuracy (NFF): 97.43589743589743
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[76  2]
#  [ 8 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.97      0.94        78
#          AFF       0.86      0.60      0.71        20
#
#     accuracy                           0.90        98
#    macro avg       0.88      0.79      0.82        98
# weighted avg       0.90      0.90      0.89        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.25771646201610565
# Total Test Accuracy: 91.54929577464789
# Test Accuracy (NFF): 95.3125
# Test Accuracy (AFF): 57.14285714285714
# Confusion Matrix:
#  [[61  3]
#  [ 3  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.95      0.95        64
#          AFF       0.57      0.57      0.57         7
#
#     accuracy                           0.92        71
#    macro avg       0.76      0.76      0.76        71
# weighted avg       0.92      0.92      0.92        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.27250364422798157
# Total Test Accuracy: 87.71929824561404
# Test Accuracy (NFF): 87.71929824561403
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[50  7]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.93        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.88        57
#    macro avg       0.50      0.94      0.47        57
# weighted avg       1.00      0.88      0.93        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.5021048486232758
# Total Test Accuracy: 81.55339805825243
# Test Accuracy (NFF): 94.73684210526315
# Test Accuracy (AFF): 44.44444444444444
# Confusion Matrix:
#  [[72  4]
#  [15 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.83      0.95      0.88        76
#          AFF       0.75      0.44      0.56        27
#
#     accuracy                           0.82       103
#    macro avg       0.79      0.70      0.72       103
# weighted avg       0.81      0.82      0.80       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.3340374827384949
# Total Test Accuracy: 93.67088607594937
# Test Accuracy (NFF): 98.61111111111111
# Test Accuracy (AFF): 42.857142857142854
# Confusion Matrix:
#  [[71  1]
#  [ 4  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.99      0.97        72
#          AFF       0.75      0.43      0.55         7
#
#     accuracy                           0.94        79
#    macro avg       0.85      0.71      0.76        79
# weighted avg       0.93      0.94      0.93        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.1862936168909073
# Total Test Accuracy: 96.15384615384616
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[24  0]
#  [ 1  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      1.00      0.98        24
#          AFF       1.00      0.50      0.67         2
#
#     accuracy                           0.96        26
#    macro avg       0.98      0.75      0.82        26
# weighted avg       0.96      0.96      0.96        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 0.6173927783966064
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 77.77777777777779
# Confusion Matrix:
#  [[3 0]
#  [2 7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.60      1.00      0.75         3
#          AFF       1.00      0.78      0.88         9
#
#     accuracy                           0.83        12
#    macro avg       0.80      0.89      0.81        12
# weighted avg       0.90      0.83      0.84        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.28632180392742157
# Total Test Accuracy: 89.55223880597015
# Test Accuracy (NFF): 96.22641509433963
# Test Accuracy (AFF): 64.28571428571429
# Confusion Matrix:
#  [[102   4]
#  [ 10  18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.96      0.94       106
#          AFF       0.82      0.64      0.72        28
#
#     accuracy                           0.90       134
#    macro avg       0.86      0.80      0.83       134
# weighted avg       0.89      0.90      0.89       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.2163769230246544
# Total Test Accuracy: 91.66666666666667
# Test Accuracy (NFF): 98.68421052631578
# Test Accuracy (AFF): 53.57142857142857
# Confusion Matrix:
#  [[150   2]
#  [ 13  15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.99      0.95       152
#          AFF       0.88      0.54      0.67        28
#
#     accuracy                           0.92       180
#    macro avg       0.90      0.76      0.81       180
# weighted avg       0.91      0.92      0.91       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.6902382373809814
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 81.48148148148148
# Test Accuracy (AFF): 61.53846153846154
# Confusion Matrix:
#  [[22  5]
#  [ 5  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      0.81      0.81        27
#          AFF       0.62      0.62      0.62        13
#
#     accuracy                           0.75        40
#    macro avg       0.72      0.72      0.72        40
# weighted avg       0.75      0.75      0.75        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 1.423351764678955
# Total Test Accuracy: 0.0
# Test Accuracy (NFF): 0.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[0 3]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.00      0.00       3.0
#          AFF       0.00      1.00      0.00       0.0
#
#     accuracy                           1.00       3.0
#    macro avg       0.50      0.50      0.00       3.0
# weighted avg       1.00      0.00      0.00       3.0
#
#
# Performance for Hospital 58:
#
# Test Loss: 0.5989396572113037
# Total Test Accuracy: 80.70175438596492
# Test Accuracy (NFF): 86.20689655172413
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[25  4]
#  [ 7 21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.78      0.86      0.82        29
#          AFF       0.84      0.75      0.79        28
#
#     accuracy                           0.81        57
#    macro avg       0.81      0.81      0.81        57
# weighted avg       0.81      0.81      0.81        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.0724320113658905
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.5289295166730881
# Total Test Accuracy: 80.48780487804878
# Test Accuracy (NFF): 88.0
# Test Accuracy (AFF): 47.82608695652174
# Confusion Matrix:
#  [[88 12]
#  [12 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.88      0.88       100
#          AFF       0.48      0.48      0.48        23
#
#     accuracy                           0.80       123
#    macro avg       0.68      0.68      0.68       123
# weighted avg       0.80      0.80      0.80       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.3641063868999481
# Total Test Accuracy: 80.95238095238095
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 41.17647058823529
# Confusion Matrix:
#  [[44  2]
#  [10  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      0.96      0.88        46
#          AFF       0.78      0.41      0.54        17
#
#     accuracy                           0.81        63
#    macro avg       0.80      0.68      0.71        63
# weighted avg       0.80      0.81      0.79        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 0.37770596146583557
# Total Test Accuracy: 83.01886792452831
# Test Accuracy (NFF): 87.8048780487805
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[36  5]
#  [ 4  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.88      0.89        41
#          AFF       0.62      0.67      0.64        12
#
#     accuracy                           0.83        53
#    macro avg       0.76      0.77      0.76        53
# weighted avg       0.84      0.83      0.83        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 0.07015120983123779
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.12508413195610046
# Total Test Accuracy: 93.75
# Test Accuracy (NFF): 93.75
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[30  2]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.94      0.97        32
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.94        32
#    macro avg       0.50      0.97      0.48        32
# weighted avg       1.00      0.94      0.97        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.41205424070358276
# Total Test Accuracy: 90.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[8 0]
#  [1 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      1.00      0.94         8
#          AFF       1.00      0.50      0.67         2
#
#     accuracy                           0.90        10
#    macro avg       0.94      0.75      0.80        10
# weighted avg       0.91      0.90      0.89        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.3507648706436157
# Total Test Accuracy: 86.36363636363636
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 40.0
# Confusion Matrix:
#  [[17  0]
#  [ 3  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      1.00      0.92        17
#          AFF       1.00      0.40      0.57         5
#
#     accuracy                           0.86        22
#    macro avg       0.93      0.70      0.75        22
# weighted avg       0.88      0.86      0.84        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.40703898668289185
# Total Test Accuracy: 80.55555555555556
# Test Accuracy (NFF): 89.65517241379311
# Test Accuracy (AFF): 42.857142857142854
# Confusion Matrix:
#  [[26  3]
#  [ 4  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.90      0.88        29
#          AFF       0.50      0.43      0.46         7
#
#     accuracy                           0.81        36
#    macro avg       0.68      0.66      0.67        36
# weighted avg       0.80      0.81      0.80        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.3885698433105762
# Total Test Accuracy: 84.72906403940887
# Test Accuracy (NFF): 92.3896499238965
# Test Accuracy (AFF): 52.25806451612903
# Confusion Matrix:
#  [[607  50]
#  [ 74  81]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.92      0.91       657
#          AFF       0.62      0.52      0.57       155
#
#     accuracy                           0.85       812
#    macro avg       0.75      0.72      0.74       812
# weighted avg       0.84      0.85      0.84       812
#
#
# Average Total Test Accuracy: 85.52376811471399

# %% [markdown]
# # ResNet50

# %%
from torchvision.models import resnet50, ResNet50_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the ResNet-101 model
model = models.resnet50(weights=ResNet50_Weights.DEFAULT)

num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)

# layer number
total_layers = len(list(model.children()))

# freeze 50% layer
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False

# modify full connection layer
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)

# ---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 20
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

res50 = train_custom_model(model, train_dataset, val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/20, Train ACC: 62.53%, Validation ACC: 60.47%
# Epoch 2/20, Train ACC: 67.81%, Validation ACC: 58.14%
# Epoch 3/20, Train ACC: 69.92%, Validation ACC: 55.81%
# Epoch 4/20, Train ACC: 75.99%, Validation ACC: 61.05%
# Epoch 5/20, Train ACC: 75.46%, Validation ACC: 70.93%
# Epoch 6/20, Train ACC: 75.99%, Validation ACC: 73.84%
# Epoch 7/20, Train ACC: 81.27%, Validation ACC: 77.33%
# Epoch 8/20, Train ACC: 84.17%, Validation ACC: 81.98%
# Epoch 9/20, Train ACC: 87.86%, Validation ACC: 83.14%
# Epoch 10/20, Train ACC: 90.50%, Validation ACC: 86.63%
# Epoch 11/20, Train ACC: 91.82%, Validation ACC: 87.79%
# Epoch 12/20, Train ACC: 94.46%, Validation ACC: 87.21%
# Epoch 13/20, Train ACC: 91.82%, Validation ACC: 85.47%
# Epoch 14/20, Train ACC: 93.93%, Validation ACC: 86.05%
# Epoch 15/20, Train ACC: 95.78%, Validation ACC: 88.37%
# Epoch 16/20, Train ACC: 94.99%, Validation ACC: 87.79%
# Epoch 17/20, Train ACC: 93.93%, Validation ACC: 86.63%
# Epoch 18/20, Train ACC: 96.31%, Validation ACC: 87.79%
# Epoch 19/20, Train ACC: 97.10%, Validation ACC: 89.53%
# Epoch 20/20, Train ACC: 98.42%, Validation ACC: 90.70%

# %%
model = res50
model.eval()
# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomCsvDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(10, 5))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
torch.cuda.empty_cache()
results.append(average_performance)
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.17165926098823547
# Total Test Accuracy: 95.65217391304348
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[22  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        23
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.96        23
#    macro avg       0.50      0.98      0.49        23
# weighted avg       1.00      0.96      0.98        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 0.2004300355911255
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         0
#          AFF       1.00      1.00      1.00         3
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.4018150866031647
# Total Test Accuracy: 88.57142857142857
# Test Accuracy (NFF): 91.30434782608695
# Test Accuracy (AFF): 83.33333333333334
# Confusion Matrix:
#  [[21  2]
#  [ 2 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.91      0.91        23
#          AFF       0.83      0.83      0.83        12
#
#     accuracy                           0.89        35
#    macro avg       0.87      0.87      0.87        35
# weighted avg       0.89      0.89      0.89        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.03405853360891342
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         2
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.3797529488801956
# Total Test Accuracy: 92.3076923076923
# Test Accuracy (NFF): 93.33333333333333
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[56  4]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.93      0.96        60
#          AFF       0.50      0.80      0.62         5
#
#     accuracy                           0.92        65
#    macro avg       0.74      0.87      0.79        65
# weighted avg       0.95      0.92      0.93        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.3239486515522003
# Total Test Accuracy: 85.71428571428571
# Test Accuracy (NFF): 91.66666666666666
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[33  3]
#  [ 5 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.92      0.89        36
#          AFF       0.83      0.75      0.79        20
#
#     accuracy                           0.86        56
#    macro avg       0.85      0.83      0.84        56
# weighted avg       0.86      0.86      0.86        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.1692664623260498
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.24071676284074783
# Total Test Accuracy: 89.32038834951456
# Test Accuracy (NFF): 97.5
# Test Accuracy (AFF): 60.86956521739131
# Confusion Matrix:
#  [[78  2]
#  [ 9 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.97      0.93        80
#          AFF       0.88      0.61      0.72        23
#
#     accuracy                           0.89       103
#    macro avg       0.89      0.79      0.83       103
# weighted avg       0.89      0.89      0.89       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.0661647841334343
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 0.35867859423160553
# Total Test Accuracy: 84.05797101449275
# Test Accuracy (NFF): 96.22641509433963
# Test Accuracy (AFF): 43.75
# Confusion Matrix:
#  [[51  2]
#  [ 9  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.96      0.90        53
#          AFF       0.78      0.44      0.56        16
#
#     accuracy                           0.84        69
#    macro avg       0.81      0.70      0.73        69
# weighted avg       0.83      0.84      0.82        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.23463447019457817
# Total Test Accuracy: 89.6103896103896
# Test Accuracy (NFF): 92.1875
# Test Accuracy (AFF): 76.92307692307693
# Confusion Matrix:
#  [[59  5]
#  [ 3 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.92      0.94        64
#          AFF       0.67      0.77      0.71        13
#
#     accuracy                           0.90        77
#    macro avg       0.81      0.85      0.83        77
# weighted avg       0.90      0.90      0.90        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.1759740188717842
# Total Test Accuracy: 94.87179487179488
# Test Accuracy (NFF): 94.69026548672566
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[107   6]
#  [  0   4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.95      0.97       113
#          AFF       0.40      1.00      0.57         4
#
#     accuracy                           0.95       117
#    macro avg       0.70      0.97      0.77       117
# weighted avg       0.98      0.95      0.96       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.1755717396736145
# Total Test Accuracy: 97.77777777777777
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[43  0]
#  [ 1  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      1.00      0.99        43
#          AFF       1.00      0.50      0.67         2
#
#     accuracy                           0.98        45
#    macro avg       0.99      0.75      0.83        45
# weighted avg       0.98      0.98      0.97        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.05305192992091179
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        21
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 1.1500881910324097
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         3
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.09309232234954834
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         4
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 0.6695829629898071
# Total Test Accuracy: 76.05633802816901
# Test Accuracy (NFF): 85.71428571428571
# Test Accuracy (AFF): 54.54545454545454
# Confusion Matrix:
#  [[42  7]
#  [10 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      0.86      0.83        49
#          AFF       0.63      0.55      0.59        22
#
#     accuracy                           0.76        71
#    macro avg       0.72      0.70      0.71        71
# weighted avg       0.75      0.76      0.76        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.13368413969874382
# Total Test Accuracy: 96.03174603174604
# Test Accuracy (NFF): 98.79518072289156
# Test Accuracy (AFF): 90.69767441860465
# Confusion Matrix:
#  [[82  1]
#  [ 4 39]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.99      0.97        83
#          AFF       0.97      0.91      0.94        43
#
#     accuracy                           0.96       126
#    macro avg       0.96      0.95      0.96       126
# weighted avg       0.96      0.96      0.96       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.1848694235086441
# Total Test Accuracy: 93.33333333333333
# Test Accuracy (NFF): 95.0
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[38  2]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.95      0.96        40
#          AFF       0.67      0.80      0.73         5
#
#     accuracy                           0.93        45
#    macro avg       0.82      0.88      0.84        45
# weighted avg       0.94      0.93      0.94        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.3981781601905823
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[8 0]
#  [1 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      1.00      0.94         8
#          AFF       1.00      0.00      0.00         1
#
#     accuracy                           0.89         9
#    macro avg       0.94      0.50      0.47         9
# weighted avg       0.90      0.89      0.84         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.5505883991718292
# Total Test Accuracy: 78.99159663865547
# Test Accuracy (NFF): 87.05882352941177
# Test Accuracy (AFF): 58.82352941176471
# Confusion Matrix:
#  [[74 11]
#  [14 20]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      0.87      0.86        85
#          AFF       0.65      0.59      0.62        34
#
#     accuracy                           0.79       119
#    macro avg       0.74      0.73      0.74       119
# weighted avg       0.78      0.79      0.79       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 0.5100183337926865
# Total Test Accuracy: 80.41237113402062
# Test Accuracy (NFF): 96.22641509433963
# Test Accuracy (AFF): 61.36363636363637
# Confusion Matrix:
#  [[51  2]
#  [17 27]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.75      0.96      0.84        53
#          AFF       0.93      0.61      0.74        44
#
#     accuracy                           0.80        97
#    macro avg       0.84      0.79      0.79        97
# weighted avg       0.83      0.80      0.80        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.028749970719218254
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.344918891787529
# Total Test Accuracy: 89.01098901098901
# Test Accuracy (NFF): 92.20779220779221
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[71  6]
#  [ 4 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.92      0.93        77
#          AFF       0.62      0.71      0.67        14
#
#     accuracy                           0.89        91
#    macro avg       0.79      0.82      0.80        91
# weighted avg       0.90      0.89      0.89        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 0.24520301818847656
# Total Test Accuracy: 94.44444444444444
# Test Accuracy (NFF): 93.33333333333333
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[14  1]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.93      0.97        15
#          AFF       0.75      1.00      0.86         3
#
#     accuracy                           0.94        18
#    macro avg       0.88      0.97      0.91        18
# weighted avg       0.96      0.94      0.95        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.28504663705825806
# Total Test Accuracy: 84.61538461538461
# Test Accuracy (NFF): 94.44444444444444
# Test Accuracy (AFF): 62.5
# Confusion Matrix:
#  [[17  1]
#  [ 3  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.94      0.89        18
#          AFF       0.83      0.62      0.71         8
#
#     accuracy                           0.85        26
#    macro avg       0.84      0.78      0.80        26
# weighted avg       0.84      0.85      0.84        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.2644566595554352
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 88.23529411764706
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[15  2]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.94        17
#          AFF       0.33      1.00      0.50         1
#
#     accuracy                           0.89        18
#    macro avg       0.67      0.94      0.72        18
# weighted avg       0.96      0.89      0.91        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.37623365223407745
# Total Test Accuracy: 83.87096774193549
# Test Accuracy (NFF): 88.60759493670885
# Test Accuracy (AFF): 57.14285714285714
# Confusion Matrix:
#  [[70  9]
#  [ 6  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.89      0.90        79
#          AFF       0.47      0.57      0.52        14
#
#     accuracy                           0.84        93
#    macro avg       0.70      0.73      0.71        93
# weighted avg       0.85      0.84      0.84        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 0.301286518573761
# Total Test Accuracy: 87.5
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[9 0]
#  [2 5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.82      1.00      0.90         9
#          AFF       1.00      0.71      0.83         7
#
#     accuracy                           0.88        16
#    macro avg       0.91      0.86      0.87        16
# weighted avg       0.90      0.88      0.87        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 0.24765850603580475
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 83.33333333333334
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[5 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.83      0.91         6
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.83         6
#    macro avg       0.50      0.92      0.45         6
# weighted avg       1.00      0.83      0.91         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 0.2544715702533722
# Total Test Accuracy: 82.14285714285714
# Test Accuracy (NFF): 83.5820895522388
# Test Accuracy (AFF): 76.47058823529412
# Confusion Matrix:
#  [[56 11]
#  [ 4 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.84      0.88        67
#          AFF       0.54      0.76      0.63        17
#
#     accuracy                           0.82        84
#    macro avg       0.74      0.80      0.76        84
# weighted avg       0.85      0.82      0.83        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.011903643608093262
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.2896943688392639
# Total Test Accuracy: 89.1891891891892
# Test Accuracy (NFF): 92.06349206349206
# Test Accuracy (AFF): 72.72727272727273
# Confusion Matrix:
#  [[116  10]
#  [  6  16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.92      0.94       126
#          AFF       0.62      0.73      0.67        22
#
#     accuracy                           0.89       148
#    macro avg       0.78      0.82      0.80       148
# weighted avg       0.90      0.89      0.90       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.18471381068229675
# Total Test Accuracy: 97.05882352941177
# Test Accuracy (NFF): 97.05882352941177
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[33  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.97      0.99        34
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.97        34
#    macro avg       0.50      0.99      0.49        34
# weighted avg       1.00      0.97      0.99        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.27770209312438965
# Total Test Accuracy: 82.3529411764706
# Test Accuracy (NFF): 78.57142857142857
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[11  3]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.79      0.88        14
#          AFF       0.50      1.00      0.67         3
#
#     accuracy                           0.82        17
#    macro avg       0.75      0.89      0.77        17
# weighted avg       0.91      0.82      0.84        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.3482455462217331
# Total Test Accuracy: 82.55813953488372
# Test Accuracy (NFF): 86.76470588235294
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[59  9]
#  [ 6 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.87      0.89        68
#          AFF       0.57      0.67      0.62        18
#
#     accuracy                           0.83        86
#    macro avg       0.74      0.77      0.75        86
# weighted avg       0.84      0.83      0.83        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.08501266688108444
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        25
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        25
#    macro avg       1.00      1.00      1.00        25
# weighted avg       1.00      1.00      1.00        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.3927100896835327
# Total Test Accuracy: 82.75862068965517
# Test Accuracy (NFF): 82.6086956521739
# Test Accuracy (AFF): 83.33333333333334
# Confusion Matrix:
#  [[19  4]
#  [ 1  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.83      0.88        23
#          AFF       0.56      0.83      0.67         6
#
#     accuracy                           0.83        29
#    macro avg       0.75      0.83      0.78        29
# weighted avg       0.87      0.83      0.84        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.28520727902650833
# Total Test Accuracy: 82.66666666666667
# Test Accuracy (NFF): 88.57142857142857
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[62  8]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.89      0.91        70
#          AFF       0.00      0.00      1.00         5
#
#     accuracy                           0.83        75
#    macro avg       0.46      0.44      0.95        75
# weighted avg       0.86      0.83      0.91        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 0.002085547661408782
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 0.250316321849823
# Total Test Accuracy: 86.66666666666667
# Test Accuracy (NFF): 86.66666666666667
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[13  2]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.87      0.93        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.87        15
#    macro avg       0.50      0.93      0.46        15
# weighted avg       1.00      0.87      0.93        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.11523047089576721
# Total Test Accuracy: 96.3265306122449
# Test Accuracy (NFF): 97.6470588235294
# Test Accuracy (AFF): 93.33333333333333
# Confusion Matrix:
#  [[166   4]
#  [  5  70]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.98      0.97       170
#          AFF       0.95      0.93      0.94        75
#
#     accuracy                           0.96       245
#    macro avg       0.96      0.95      0.96       245
# weighted avg       0.96      0.96      0.96       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.37367236614227295
# Total Test Accuracy: 83.87096774193549
# Test Accuracy (NFF): 88.46153846153845
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[23  3]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.88      0.90        26
#          AFF       0.50      0.60      0.55         5
#
#     accuracy                           0.84        31
#    macro avg       0.71      0.74      0.72        31
# weighted avg       0.85      0.84      0.84        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.2819790095090866
# Total Test Accuracy: 89.25619834710744
# Test Accuracy (NFF): 94.31818181818183
# Test Accuracy (AFF): 75.75757575757575
# Confusion Matrix:
#  [[83  5]
#  [ 8 25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.94      0.93        88
#          AFF       0.83      0.76      0.79        33
#
#     accuracy                           0.89       121
#    macro avg       0.87      0.85      0.86       121
# weighted avg       0.89      0.89      0.89       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.1057300865650177
# Total Test Accuracy: 95.45454545454545
# Test Accuracy (NFF): 95.45454545454545
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.95      0.98        22
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.95        22
#    macro avg       0.50      0.98      0.49        22
# weighted avg       1.00      0.95      0.98        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.2734927237033844
# Total Test Accuracy: 87.75510204081633
# Test Accuracy (NFF): 91.02564102564102
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[71  7]
#  [ 5 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.91      0.92        78
#          AFF       0.68      0.75      0.71        20
#
#     accuracy                           0.88        98
#    macro avg       0.81      0.83      0.82        98
# weighted avg       0.88      0.88      0.88        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.27247204631567
# Total Test Accuracy: 88.73239436619718
# Test Accuracy (NFF): 90.625
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[58  6]
#  [ 2  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.91      0.94        64
#          AFF       0.45      0.71      0.56         7
#
#     accuracy                           0.89        71
#    macro avg       0.71      0.81      0.75        71
# weighted avg       0.92      0.89      0.90        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.4324284791946411
# Total Test Accuracy: 84.21052631578948
# Test Accuracy (NFF): 84.21052631578947
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[48  9]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.84      0.91        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.84        57
#    macro avg       0.50      0.92      0.46        57
# weighted avg       1.00      0.84      0.91        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.5557052493095398
# Total Test Accuracy: 79.6116504854369
# Test Accuracy (NFF): 90.78947368421053
# Test Accuracy (AFF): 48.148148148148145
# Confusion Matrix:
#  [[69  7]
#  [14 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.83      0.91      0.87        76
#          AFF       0.65      0.48      0.55        27
#
#     accuracy                           0.80       103
#    macro avg       0.74      0.69      0.71       103
# weighted avg       0.78      0.80      0.79       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.20899683982133865
# Total Test Accuracy: 92.40506329113924
# Test Accuracy (NFF): 98.61111111111111
# Test Accuracy (AFF): 28.57142857142857
# Confusion Matrix:
#  [[71  1]
#  [ 5  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.99      0.96        72
#          AFF       0.67      0.29      0.40         7
#
#     accuracy                           0.92        79
#    macro avg       0.80      0.64      0.68        79
# weighted avg       0.91      0.92      0.91        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.19945070147514343
# Total Test Accuracy: 96.15384615384616
# Test Accuracy (NFF): 95.83333333333334
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[23  1]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        24
#          AFF       0.67      1.00      0.80         2
#
#     accuracy                           0.96        26
#    macro avg       0.83      0.98      0.89        26
# weighted avg       0.97      0.96      0.96        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 0.9037244319915771
# Total Test Accuracy: 58.333333333333336
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 44.44444444444444
# Confusion Matrix:
#  [[3 0]
#  [5 4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.38      1.00      0.55         3
#          AFF       1.00      0.44      0.62         9
#
#     accuracy                           0.58        12
#    macro avg       0.69      0.72      0.58        12
# weighted avg       0.84      0.58      0.60        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.3378468453884125
# Total Test Accuracy: 85.07462686567165
# Test Accuracy (NFF): 89.62264150943396
# Test Accuracy (AFF): 67.85714285714286
# Confusion Matrix:
#  [[95 11]
#  [ 9 19]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.90      0.90       106
#          AFF       0.63      0.68      0.66        28
#
#     accuracy                           0.85       134
#    macro avg       0.77      0.79      0.78       134
# weighted avg       0.85      0.85      0.85       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.15010255575180054
# Total Test Accuracy: 96.66666666666667
# Test Accuracy (NFF): 98.68421052631578
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[150   2]
#  [  4  24]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.99      0.98       152
#          AFF       0.92      0.86      0.89        28
#
#     accuracy                           0.97       180
#    macro avg       0.95      0.92      0.93       180
# weighted avg       0.97      0.97      0.97       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.6589289903640747
# Total Test Accuracy: 72.5
# Test Accuracy (NFF): 92.5925925925926
# Test Accuracy (AFF): 30.76923076923077
# Confusion Matrix:
#  [[25  2]
#  [ 9  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.74      0.93      0.82        27
#          AFF       0.67      0.31      0.42        13
#
#     accuracy                           0.73        40
#    macro avg       0.70      0.62      0.62        40
# weighted avg       0.71      0.72      0.69        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 0.006072923541069031
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 58:
#
# Test Loss: 0.4905814826488495
# Total Test Accuracy: 75.43859649122807
# Test Accuracy (NFF): 72.41379310344827
# Test Accuracy (AFF): 78.57142857142857
# Confusion Matrix:
#  [[21  8]
#  [ 6 22]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.78      0.72      0.75        29
#          AFF       0.73      0.79      0.76        28
#
#     accuracy                           0.75        57
#    macro avg       0.76      0.75      0.75        57
# weighted avg       0.76      0.75      0.75        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.2901965379714966
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.89      0.94         9
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.89         9
#    macro avg       0.50      0.94      0.47         9
# weighted avg       1.00      0.89      0.94         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.4471476674079895
# Total Test Accuracy: 84.55284552845528
# Test Accuracy (NFF): 89.0
# Test Accuracy (AFF): 65.21739130434783
# Confusion Matrix:
#  [[89 11]
#  [ 8 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.89      0.90       100
#          AFF       0.58      0.65      0.61        23
#
#     accuracy                           0.85       123
#    macro avg       0.75      0.77      0.76       123
# weighted avg       0.85      0.85      0.85       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.36052757501602173
# Total Test Accuracy: 85.71428571428571
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 58.82352941176471
# Confusion Matrix:
#  [[44  2]
#  [ 7 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.86      0.96      0.91        46
#          AFF       0.83      0.59      0.69        17
#
#     accuracy                           0.86        63
#    macro avg       0.85      0.77      0.80        63
# weighted avg       0.85      0.86      0.85        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 0.28344693779945374
# Total Test Accuracy: 84.90566037735849
# Test Accuracy (NFF): 92.6829268292683
# Test Accuracy (AFF): 58.333333333333336
# Confusion Matrix:
#  [[38  3]
#  [ 5  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.93      0.90        41
#          AFF       0.70      0.58      0.64        12
#
#     accuracy                           0.85        53
#    macro avg       0.79      0.76      0.77        53
# weighted avg       0.84      0.85      0.84        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 0.09311110526323318
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.2449178844690323
# Total Test Accuracy: 90.625
# Test Accuracy (NFF): 90.625
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[29  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.91      0.95        32
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.91        32
#    macro avg       0.50      0.95      0.48        32
# weighted avg       1.00      0.91      0.95        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.46362417936325073
# Total Test Accuracy: 70.0
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[7 1]
#  [2 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.78      0.88      0.82         8
#          AFF       0.00      0.00      1.00         2
#
#     accuracy                           0.70        10
#    macro avg       0.39      0.44      0.91        10
# weighted avg       0.62      0.70      0.86        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.6827344298362732
# Total Test Accuracy: 72.72727272727273
# Test Accuracy (NFF): 94.11764705882352
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[16  1]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.76      0.94      0.84        17
#          AFF       0.00      0.00      1.00         5
#
#     accuracy                           0.73        22
#    macro avg       0.38      0.47      0.92        22
# weighted avg       0.59      0.73      0.88        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.39550748467445374
# Total Test Accuracy: 86.11111111111111
# Test Accuracy (NFF): 96.55172413793103
# Test Accuracy (AFF): 42.857142857142854
# Confusion Matrix:
#  [[28  1]
#  [ 4  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.97      0.92        29
#          AFF       0.75      0.43      0.55         7
#
#     accuracy                           0.86        36
#    macro avg       0.81      0.70      0.73        36
# weighted avg       0.85      0.86      0.85        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.3861565188719676
# Total Test Accuracy: 85.34482758620689
# Test Accuracy (NFF): 90.71537290715372
# Test Accuracy (AFF): 62.58064516129033
# Confusion Matrix:
#  [[596  61]
#  [ 58  97]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.91      0.91       657
#          AFF       0.61      0.63      0.62       155
#
#     accuracy                           0.85       812
#    macro avg       0.76      0.77      0.76       812
# weighted avg       0.85      0.85      0.85       812
#
#
# Average Total Test Accuracy: 88.4475029191375

# %% [markdown]
# # ResNet101

# %%
from torchvision.models import resnet101, ResNet101_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the ResNet-101 model
model = models.resnet101(weights=ResNet101_Weights.DEFAULT)

num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)


# layer number
total_layers = len(list(model.children()))

# freeze 50% layer
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False

# modify full connection layer
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)

# ---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 20
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

res101 = train_custom_model(model, train_dataset, val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/20, Train ACC: 49.08%, Validation ACC: 59.30%
# Epoch 2/20, Train ACC: 63.85%, Validation ACC: 54.65%
# Epoch 3/20, Train ACC: 62.80%, Validation ACC: 53.49%
# Epoch 4/20, Train ACC: 70.18%, Validation ACC: 58.14%
# Epoch 5/20, Train ACC: 75.99%, Validation ACC: 59.88%
# Epoch 6/20, Train ACC: 78.36%, Validation ACC: 61.63%
# Epoch 7/20, Train ACC: 83.38%, Validation ACC: 68.60%
# Epoch 8/20, Train ACC: 83.38%, Validation ACC: 72.09%
# Epoch 9/20, Train ACC: 89.71%, Validation ACC: 88.37%
# Epoch 10/20, Train ACC: 89.97%, Validation ACC: 86.63%
# Epoch 11/20, Train ACC: 93.14%, Validation ACC: 87.79%
# Epoch 12/20, Train ACC: 91.03%, Validation ACC: 91.28%
# Epoch 13/20, Train ACC: 93.93%, Validation ACC: 87.21%
# Epoch 14/20, Train ACC: 93.93%, Validation ACC: 90.12%
# Epoch 15/20, Train ACC: 94.99%, Validation ACC: 88.95%
# Epoch 16/20, Train ACC: 97.89%, Validation ACC: 90.70%
# Epoch 17/20, Train ACC: 96.31%, Validation ACC: 89.53%
# Epoch 18/20, Train ACC: 98.42%, Validation ACC: 90.12%
# Epoch 19/20, Train ACC: 97.10%, Validation ACC: 90.12%
# Epoch 20/20, Train ACC: 98.68%, Validation ACC: 90.12%

# %%
model = res101
model.eval()
# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomCsvDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(15, 5))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
torch.cuda.empty_cache()
results.append(average_performance)
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.0672973021864891
# Total Test Accuracy: 95.65217391304348
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[22  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        23
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.96        23
#    macro avg       0.50      0.98      0.49        23
# weighted avg       1.00      0.96      0.98        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 0.07783495634794235
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         0
#          AFF       1.00      1.00      1.00         3
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.32010361552238464
# Total Test Accuracy: 94.28571428571429
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 91.66666666666666
# Confusion Matrix:
#  [[22  1]
#  [ 1 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.96      0.96        23
#          AFF       0.92      0.92      0.92        12
#
#     accuracy                           0.94        35
#    macro avg       0.94      0.94      0.94        35
# weighted avg       0.94      0.94      0.94        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.08569213002920151
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         2
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.12816875148564577
# Total Test Accuracy: 92.3076923076923
# Test Accuracy (NFF): 95.0
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[57  3]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.95      0.96        60
#          AFF       0.50      0.60      0.55         5
#
#     accuracy                           0.92        65
#    macro avg       0.73      0.77      0.75        65
# weighted avg       0.93      0.92      0.93        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.26986268162727356
# Total Test Accuracy: 91.07142857142857
# Test Accuracy (NFF): 97.22222222222221
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[35  1]
#  [ 4 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.97      0.93        36
#          AFF       0.94      0.80      0.86        20
#
#     accuracy                           0.91        56
#    macro avg       0.92      0.89      0.90        56
# weighted avg       0.91      0.91      0.91        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.0026617778930813074
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.49887821078300476
# Total Test Accuracy: 85.4368932038835
# Test Accuracy (NFF): 92.5
# Test Accuracy (AFF): 60.86956521739131
# Confusion Matrix:
#  [[74  6]
#  [ 9 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.93      0.91        80
#          AFF       0.70      0.61      0.65        23
#
#     accuracy                           0.85       103
#    macro avg       0.80      0.77      0.78       103
# weighted avg       0.85      0.85      0.85       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.03442437946796417
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 0.4925284879282117
# Total Test Accuracy: 84.05797101449275
# Test Accuracy (NFF): 98.11320754716981
# Test Accuracy (AFF): 37.5
# Confusion Matrix:
#  [[52  1]
#  [10  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      0.98      0.90        53
#          AFF       0.86      0.38      0.52        16
#
#     accuracy                           0.84        69
#    macro avg       0.85      0.68      0.71        69
# weighted avg       0.84      0.84      0.82        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.17298524710349739
# Total Test Accuracy: 94.8051948051948
# Test Accuracy (NFF): 98.4375
# Test Accuracy (AFF): 76.92307692307693
# Confusion Matrix:
#  [[63  1]
#  [ 3 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.98      0.97        64
#          AFF       0.91      0.77      0.83        13
#
#     accuracy                           0.95        77
#    macro avg       0.93      0.88      0.90        77
# weighted avg       0.95      0.95      0.95        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.3203508034348488
# Total Test Accuracy: 89.74358974358974
# Test Accuracy (NFF): 89.38053097345133
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[101  12]
#  [  0   4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.89      0.94       113
#          AFF       0.25      1.00      0.40         4
#
#     accuracy                           0.90       117
#    macro avg       0.62      0.95      0.67       117
# weighted avg       0.97      0.90      0.93       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.09745248407125473
# Total Test Accuracy: 95.55555555555556
# Test Accuracy (NFF): 97.67441860465115
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[42  1]
#  [ 1  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.98      0.98        43
#          AFF       0.50      0.50      0.50         2
#
#     accuracy                           0.96        45
#    macro avg       0.74      0.74      0.74        45
# weighted avg       0.96      0.96      0.96        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.024334684014320374
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        21
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 0.59620201587677
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         3
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.033793073147535324
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         4
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 0.20144698955118656
# Total Test Accuracy: 87.32394366197182
# Test Accuracy (NFF): 93.87755102040816
# Test Accuracy (AFF): 72.72727272727273
# Confusion Matrix:
#  [[46  3]
#  [ 6 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.94      0.91        49
#          AFF       0.84      0.73      0.78        22
#
#     accuracy                           0.87        71
#    macro avg       0.86      0.83      0.85        71
# weighted avg       0.87      0.87      0.87        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.16539882495999336
# Total Test Accuracy: 95.23809523809524
# Test Accuracy (NFF): 98.79518072289156
# Test Accuracy (AFF): 88.37209302325581
# Confusion Matrix:
#  [[82  1]
#  [ 5 38]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.99      0.96        83
#          AFF       0.97      0.88      0.93        43
#
#     accuracy                           0.95       126
#    macro avg       0.96      0.94      0.95       126
# weighted avg       0.95      0.95      0.95       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.2146155834197998
# Total Test Accuracy: 91.11111111111111
# Test Accuracy (NFF): 95.0
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[38  2]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.95      0.95        40
#          AFF       0.60      0.60      0.60         5
#
#     accuracy                           0.91        45
#    macro avg       0.77      0.77      0.78        45
# weighted avg       0.91      0.91      0.91        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.3369683623313904
# Total Test Accuracy: 77.77777777777777
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[7 1]
#  [1 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.88      0.88         8
#          AFF       0.00      0.00      1.00         1
#
#     accuracy                           0.78         9
#    macro avg       0.44      0.44      0.94         9
# weighted avg       0.78      0.78      0.89         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.5554386973381042
# Total Test Accuracy: 76.47058823529412
# Test Accuracy (NFF): 83.52941176470588
# Test Accuracy (AFF): 58.82352941176471
# Confusion Matrix:
#  [[71 14]
#  [14 20]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      0.84      0.84        85
#          AFF       0.59      0.59      0.59        34
#
#     accuracy                           0.76       119
#    macro avg       0.71      0.71      0.71       119
# weighted avg       0.76      0.76      0.76       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 0.4699849933385849
# Total Test Accuracy: 83.50515463917526
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 63.63636363636363
# Confusion Matrix:
#  [[53  0]
#  [16 28]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.77      1.00      0.87        53
#          AFF       1.00      0.64      0.78        44
#
#     accuracy                           0.84        97
#    macro avg       0.88      0.82      0.82        97
# weighted avg       0.87      0.84      0.83        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.0023711887188255787
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.2977302819490433
# Total Test Accuracy: 93.4065934065934
# Test Accuracy (NFF): 96.1038961038961
# Test Accuracy (AFF): 78.57142857142857
# Confusion Matrix:
#  [[74  3]
#  [ 3 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.96      0.96        77
#          AFF       0.79      0.79      0.79        14
#
#     accuracy                           0.93        91
#    macro avg       0.87      0.87      0.87        91
# weighted avg       0.93      0.93      0.93        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 0.20024524629116058
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 86.66666666666667
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[13  2]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.87      0.93        15
#          AFF       0.60      1.00      0.75         3
#
#     accuracy                           0.89        18
#    macro avg       0.80      0.93      0.84        18
# weighted avg       0.93      0.89      0.90        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.16878221929073334
# Total Test Accuracy: 92.3076923076923
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[18  0]
#  [ 2  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      1.00      0.95        18
#          AFF       1.00      0.75      0.86         8
#
#     accuracy                           0.92        26
#    macro avg       0.95      0.88      0.90        26
# weighted avg       0.93      0.92      0.92        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.1489991545677185
# Total Test Accuracy: 94.44444444444444
# Test Accuracy (NFF): 94.11764705882352
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[16  1]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.94      0.97        17
#          AFF       0.50      1.00      0.67         1
#
#     accuracy                           0.94        18
#    macro avg       0.75      0.97      0.82        18
# weighted avg       0.97      0.94      0.95        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.319119893014431
# Total Test Accuracy: 91.39784946236558
# Test Accuracy (NFF): 97.46835443037975
# Test Accuracy (AFF): 57.14285714285714
# Confusion Matrix:
#  [[77  2]
#  [ 6  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.97      0.95        79
#          AFF       0.80      0.57      0.67        14
#
#     accuracy                           0.91        93
#    macro avg       0.86      0.77      0.81        93
# weighted avg       0.91      0.91      0.91        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 0.782246470451355
# Total Test Accuracy: 81.25
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[8 1]
#  [2 5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.80      0.89      0.84         9
#          AFF       0.83      0.71      0.77         7
#
#     accuracy                           0.81        16
#    macro avg       0.82      0.80      0.81        16
# weighted avg       0.81      0.81      0.81        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 0.3703140914440155
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 83.33333333333334
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[5 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.83      0.91         6
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.83         6
#    macro avg       0.50      0.92      0.45         6
# weighted avg       1.00      0.83      0.91         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 0.6213740259408951
# Total Test Accuracy: 88.0952380952381
# Test Accuracy (NFF): 92.53731343283582
# Test Accuracy (AFF): 70.58823529411765
# Confusion Matrix:
#  [[62  5]
#  [ 5 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.93      0.93        67
#          AFF       0.71      0.71      0.71        17
#
#     accuracy                           0.88        84
#    macro avg       0.82      0.82      0.82        84
# weighted avg       0.88      0.88      0.88        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.003266026033088565
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.38240785400072735
# Total Test Accuracy: 87.83783783783784
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 81.81818181818183
# Confusion Matrix:
#  [[112  14]
#  [  4  18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.89      0.93       126
#          AFF       0.56      0.82      0.67        22
#
#     accuracy                           0.88       148
#    macro avg       0.76      0.85      0.80       148
# weighted avg       0.91      0.88      0.89       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.22483401000499725
# Total Test Accuracy: 88.23529411764706
# Test Accuracy (NFF): 88.23529411764706
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[30  4]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.94        34
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.88        34
#    macro avg       0.50      0.94      0.47        34
# weighted avg       1.00      0.88      0.94        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.062115803360939026
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[14  0]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        14
#          AFF       1.00      1.00      1.00         3
#
#     accuracy                           1.00        17
#    macro avg       1.00      1.00      1.00        17
# weighted avg       1.00      1.00      1.00        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.1972620189189911
# Total Test Accuracy: 93.02325581395348
# Test Accuracy (NFF): 98.52941176470588
# Test Accuracy (AFF): 72.22222222222221
# Confusion Matrix:
#  [[67  1]
#  [ 5 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.99      0.96        68
#          AFF       0.93      0.72      0.81        18
#
#     accuracy                           0.93        86
#    macro avg       0.93      0.85      0.88        86
# weighted avg       0.93      0.93      0.93        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.14118531346321106
# Total Test Accuracy: 96.0
# Test Accuracy (NFF): 96.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[24  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        25
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.96        25
#    macro avg       0.50      0.98      0.49        25
# weighted avg       1.00      0.96      0.98        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.4308013617992401
# Total Test Accuracy: 82.75862068965517
# Test Accuracy (NFF): 82.6086956521739
# Test Accuracy (AFF): 83.33333333333334
# Confusion Matrix:
#  [[19  4]
#  [ 1  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.83      0.88        23
#          AFF       0.56      0.83      0.67         6
#
#     accuracy                           0.83        29
#    macro avg       0.75      0.83      0.78        29
# weighted avg       0.87      0.83      0.84        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.24026650562882423
# Total Test Accuracy: 88.0
# Test Accuracy (NFF): 92.85714285714286
# Test Accuracy (AFF): 20.0
# Confusion Matrix:
#  [[65  5]
#  [ 4  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.93      0.94        70
#          AFF       0.17      0.20      0.18         5
#
#     accuracy                           0.88        75
#    macro avg       0.55      0.56      0.56        75
# weighted avg       0.89      0.88      0.89        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 0.002432999201118946
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 0.3986099660396576
# Total Test Accuracy: 86.66666666666667
# Test Accuracy (NFF): 86.66666666666667
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[13  2]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.87      0.93        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.87        15
#    macro avg       0.50      0.93      0.46        15
# weighted avg       1.00      0.87      0.93        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.056893546832725406
# Total Test Accuracy: 97.55102040816327
# Test Accuracy (NFF): 98.82352941176471
# Test Accuracy (AFF): 94.66666666666667
# Confusion Matrix:
#  [[168   2]
#  [  4  71]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.99      0.98       170
#          AFF       0.97      0.95      0.96        75
#
#     accuracy                           0.98       245
#    macro avg       0.97      0.97      0.97       245
# weighted avg       0.98      0.98      0.98       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.37831780314445496
# Total Test Accuracy: 87.09677419354838
# Test Accuracy (NFF): 92.3076923076923
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[24  2]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.92      0.92        26
#          AFF       0.60      0.60      0.60         5
#
#     accuracy                           0.87        31
#    macro avg       0.76      0.76      0.76        31
# weighted avg       0.87      0.87      0.87        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.3152361288666725
# Total Test Accuracy: 89.25619834710744
# Test Accuracy (NFF): 89.77272727272727
# Test Accuracy (AFF): 87.87878787878788
# Confusion Matrix:
#  [[79  9]
#  [ 4 29]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.90      0.92        88
#          AFF       0.76      0.88      0.82        33
#
#     accuracy                           0.89       121
#    macro avg       0.86      0.89      0.87       121
# weighted avg       0.90      0.89      0.89       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.11715925484895706
# Total Test Accuracy: 95.45454545454545
# Test Accuracy (NFF): 95.45454545454545
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.95      0.98        22
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.95        22
#    macro avg       0.50      0.98      0.49        22
# weighted avg       1.00      0.95      0.98        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.20300029963254929
# Total Test Accuracy: 91.83673469387755
# Test Accuracy (NFF): 94.87179487179486
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[74  4]
#  [ 4 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.95      0.95        78
#          AFF       0.80      0.80      0.80        20
#
#     accuracy                           0.92        98
#    macro avg       0.87      0.87      0.87        98
# weighted avg       0.92      0.92      0.92        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.16173960268497467
# Total Test Accuracy: 95.77464788732394
# Test Accuracy (NFF): 96.875
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[62  2]
#  [ 1  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.97      0.98        64
#          AFF       0.75      0.86      0.80         7
#
#     accuracy                           0.96        71
#    macro avg       0.87      0.91      0.89        71
# weighted avg       0.96      0.96      0.96        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.3435225188732147
# Total Test Accuracy: 87.71929824561404
# Test Accuracy (NFF): 87.71929824561403
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[50  7]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.93        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.88        57
#    macro avg       0.50      0.94      0.47        57
# weighted avg       1.00      0.88      0.93        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.5592162311077118
# Total Test Accuracy: 81.55339805825243
# Test Accuracy (NFF): 94.73684210526315
# Test Accuracy (AFF): 44.44444444444444
# Confusion Matrix:
#  [[72  4]
#  [15 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.83      0.95      0.88        76
#          AFF       0.75      0.44      0.56        27
#
#     accuracy                           0.82       103
#    macro avg       0.79      0.70      0.72       103
# weighted avg       0.81      0.82      0.80       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.22813542187213898
# Total Test Accuracy: 88.60759493670886
# Test Accuracy (NFF): 91.66666666666666
# Test Accuracy (AFF): 57.14285714285714
# Confusion Matrix:
#  [[66  6]
#  [ 3  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.92      0.94        72
#          AFF       0.40      0.57      0.47         7
#
#     accuracy                           0.89        79
#    macro avg       0.68      0.74      0.70        79
# weighted avg       0.91      0.89      0.89        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.1913314014673233
# Total Test Accuracy: 96.15384615384616
# Test Accuracy (NFF): 95.83333333333334
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[23  1]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        24
#          AFF       0.67      1.00      0.80         2
#
#     accuracy                           0.96        26
#    macro avg       0.83      0.98      0.89        26
# weighted avg       0.97      0.96      0.96        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 0.5568628907203674
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[3 0]
#  [3 6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.50      1.00      0.67         3
#          AFF       1.00      0.67      0.80         9
#
#     accuracy                           0.75        12
#    macro avg       0.75      0.83      0.73        12
# weighted avg       0.88      0.75      0.77        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.2890685051679611
# Total Test Accuracy: 85.07462686567165
# Test Accuracy (NFF): 90.56603773584906
# Test Accuracy (AFF): 64.28571428571429
# Confusion Matrix:
#  [[96 10]
#  [10 18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.91      0.91       106
#          AFF       0.64      0.64      0.64        28
#
#     accuracy                           0.85       134
#    macro avg       0.77      0.77      0.77       134
# weighted avg       0.85      0.85      0.85       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.12701459974050522
# Total Test Accuracy: 96.11111111111111
# Test Accuracy (NFF): 98.68421052631578
# Test Accuracy (AFF): 82.14285714285714
# Confusion Matrix:
#  [[150   2]
#  [  5  23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.99      0.98       152
#          AFF       0.92      0.82      0.87        28
#
#     accuracy                           0.96       180
#    macro avg       0.94      0.90      0.92       180
# weighted avg       0.96      0.96      0.96       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.7258006930351257
# Total Test Accuracy: 82.5
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 46.15384615384615
# Confusion Matrix:
#  [[27  0]
#  [ 7  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.79      1.00      0.89        27
#          AFF       1.00      0.46      0.63        13
#
#     accuracy                           0.82        40
#    macro avg       0.90      0.73      0.76        40
# weighted avg       0.86      0.82      0.80        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 0.31499621272087097
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         3
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# Performance for Hospital 58:
#
# Test Loss: 0.45437559485435486
# Total Test Accuracy: 87.71929824561404
# Test Accuracy (NFF): 93.10344827586206
# Test Accuracy (AFF): 82.14285714285714
# Confusion Matrix:
#  [[27  2]
#  [ 5 23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      0.93      0.89        29
#          AFF       0.92      0.82      0.87        28
#
#     accuracy                           0.88        57
#    macro avg       0.88      0.88      0.88        57
# weighted avg       0.88      0.88      0.88        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.15821701288223267
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.89      0.94         9
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.89         9
#    macro avg       0.50      0.94      0.47         9
# weighted avg       1.00      0.89      0.94         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.480609267950058
# Total Test Accuracy: 85.36585365853658
# Test Accuracy (NFF): 91.0
# Test Accuracy (AFF): 60.86956521739131
# Confusion Matrix:
#  [[91  9]
#  [ 9 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.91      0.91       100
#          AFF       0.61      0.61      0.61        23
#
#     accuracy                           0.85       123
#    macro avg       0.76      0.76      0.76       123
# weighted avg       0.85      0.85      0.85       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.4432830810546875
# Total Test Accuracy: 84.12698412698413
# Test Accuracy (NFF): 91.30434782608695
# Test Accuracy (AFF): 64.70588235294117
# Confusion Matrix:
#  [[42  4]
#  [ 6 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.91      0.89        46
#          AFF       0.73      0.65      0.69        17
#
#     accuracy                           0.84        63
#    macro avg       0.80      0.78      0.79        63
# weighted avg       0.84      0.84      0.84        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 0.5051813721656799
# Total Test Accuracy: 84.90566037735849
# Test Accuracy (NFF): 90.2439024390244
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[37  4]
#  [ 4  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.90      0.90        41
#          AFF       0.67      0.67      0.67        12
#
#     accuracy                           0.85        53
#    macro avg       0.78      0.78      0.78        53
# weighted avg       0.85      0.85      0.85        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 0.31921762228012085
# Total Test Accuracy: 87.5
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[7 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.93         8
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.88         8
#    macro avg       0.50      0.94      0.47         8
# weighted avg       1.00      0.88      0.93         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.01739947311580181
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[32]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        32
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        32
#    macro avg       1.00      1.00      1.00        32
# weighted avg       1.00      1.00      1.00        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.2805262506008148
# Total Test Accuracy: 90.0
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[7 1]
#  [0 2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.93         8
#          AFF       0.67      1.00      0.80         2
#
#     accuracy                           0.90        10
#    macro avg       0.83      0.94      0.87        10
# weighted avg       0.93      0.90      0.91        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.2631518542766571
# Total Test Accuracy: 86.36363636363636
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 40.0
# Confusion Matrix:
#  [[17  0]
#  [ 3  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      1.00      0.92        17
#          AFF       1.00      0.40      0.57         5
#
#     accuracy                           0.86        22
#    macro avg       0.93      0.70      0.75        22
# weighted avg       0.88      0.86      0.84        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.32464703917503357
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 96.55172413793103
# Test Accuracy (AFF): 57.14285714285714
# Confusion Matrix:
#  [[28  1]
#  [ 3  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.97      0.93        29
#          AFF       0.80      0.57      0.67         7
#
#     accuracy                           0.89        36
#    macro avg       0.85      0.77      0.80        36
# weighted avg       0.88      0.89      0.88        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.31870537193921894
# Total Test Accuracy: 88.54679802955665
# Test Accuracy (NFF): 94.06392694063926
# Test Accuracy (AFF): 65.16129032258064
# Confusion Matrix:
#  [[618  39]
#  [ 54 101]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.94      0.93       657
#          AFF       0.72      0.65      0.68       155
#
#     accuracy                           0.89       812
#    macro avg       0.82      0.80      0.81       812
# weighted avg       0.88      0.89      0.88       812
#
#
# Average Total Test Accuracy: 89.93011548353587

# %% [markdown]
# # ResNet152

# %%
from torchvision.models import resnet152, ResNet152_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the ResNet
model = models.resnet152(weights=ResNet152_Weights.DEFAULT)

num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)


# layer number
total_layers = len(list(model.children()))

# freeze 50% layer
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False

# modify full connection layer
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)

# ---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 20
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

res152 = train_custom_model(model, train_dataset, val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/20, Train ACC: 45.65%, Validation ACC: 50.00%
# Epoch 2/20, Train ACC: 62.80%, Validation ACC: 72.67%
# Epoch 3/20, Train ACC: 69.66%, Validation ACC: 74.42%
# Epoch 4/20, Train ACC: 75.46%, Validation ACC: 76.16%
# Epoch 5/20, Train ACC: 78.10%, Validation ACC: 82.56%
# Epoch 6/20, Train ACC: 84.70%, Validation ACC: 82.56%
# Epoch 7/20, Train ACC: 88.92%, Validation ACC: 83.14%
# Epoch 8/20, Train ACC: 89.45%, Validation ACC: 86.05%
# Epoch 9/20, Train ACC: 91.56%, Validation ACC: 85.47%
# Epoch 10/20, Train ACC: 93.93%, Validation ACC: 88.37%
# Epoch 11/20, Train ACC: 92.88%, Validation ACC: 87.21%
# Epoch 12/20, Train ACC: 95.25%, Validation ACC: 86.63%
# Epoch 13/20, Train ACC: 96.57%, Validation ACC: 85.47%
# Epoch 14/20, Train ACC: 96.57%, Validation ACC: 90.12%
# Epoch 15/20, Train ACC: 98.15%, Validation ACC: 89.53%
# Epoch 16/20, Train ACC: 96.31%, Validation ACC: 85.47%
# Epoch 17/20, Train ACC: 96.04%, Validation ACC: 82.56%
# Epoch 18/20, Train ACC: 97.10%, Validation ACC: 87.79%
# Epoch 19/20, Train ACC: 98.68%, Validation ACC: 86.05%
# Epoch 20/20, Train ACC: 98.42%, Validation ACC: 86.05%

# %%
model = res152
model.eval()
# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomCsvDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(10, 5))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
torch.cuda.empty_cache()
results.append(average_performance)
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.5050744414329529
# Total Test Accuracy: 86.95652173913044
# Test Accuracy (NFF): 86.95652173913044
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[20  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.87      0.93        23
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.87        23
#    macro avg       0.50      0.93      0.47        23
# weighted avg       1.00      0.87      0.93        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 0.003274282207712531
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         0
#          AFF       1.00      1.00      1.00         3
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.5100118517875671
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 82.6086956521739
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[19  4]
#  [ 3  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.86      0.83      0.84        23
#          AFF       0.69      0.75      0.72        12
#
#     accuracy                           0.80        35
#    macro avg       0.78      0.79      0.78        35
# weighted avg       0.80      0.80      0.80        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.6072076559066772
# Total Test Accuracy: 50.0
# Test Accuracy (NFF): 50.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[1 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.50      0.67         2
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.75      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.09596773097291589
# Total Test Accuracy: 89.23076923076923
# Test Accuracy (NFF): 91.66666666666666
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[55  5]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.92      0.94        60
#          AFF       0.38      0.60      0.46         5
#
#     accuracy                           0.89        65
#    macro avg       0.67      0.76      0.70        65
# weighted avg       0.92      0.89      0.90        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.2292780727148056
# Total Test Accuracy: 89.28571428571429
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 90.0
# Confusion Matrix:
#  [[32  4]
#  [ 2 18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.89      0.91        36
#          AFF       0.82      0.90      0.86        20
#
#     accuracy                           0.89        56
#    macro avg       0.88      0.89      0.89        56
# weighted avg       0.90      0.89      0.89        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.6367177367210388
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 83.33333333333334
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[5 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.83      0.91         6
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.83         6
#    macro avg       0.50      0.92      0.45         6
# weighted avg       1.00      0.83      0.91         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.43600673973560333
# Total Test Accuracy: 86.40776699029126
# Test Accuracy (NFF): 91.25
# Test Accuracy (AFF): 69.56521739130434
# Confusion Matrix:
#  [[73  7]
#  [ 7 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.91      0.91        80
#          AFF       0.70      0.70      0.70        23
#
#     accuracy                           0.86       103
#    macro avg       0.80      0.80      0.80       103
# weighted avg       0.86      0.86      0.86       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.04391735419631004
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 0.44566813111305237
# Total Test Accuracy: 78.26086956521739
# Test Accuracy (NFF): 86.79245283018868
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[46  7]
#  [ 8  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.87      0.86        53
#          AFF       0.53      0.50      0.52        16
#
#     accuracy                           0.78        69
#    macro avg       0.69      0.68      0.69        69
# weighted avg       0.78      0.78      0.78        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.33767873980104923
# Total Test Accuracy: 81.81818181818181
# Test Accuracy (NFF): 81.25
# Test Accuracy (AFF): 84.61538461538461
# Confusion Matrix:
#  [[52 12]
#  [ 2 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.81      0.88        64
#          AFF       0.48      0.85      0.61        13
#
#     accuracy                           0.82        77
#    macro avg       0.72      0.83      0.75        77
# weighted avg       0.88      0.82      0.84        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.5682737827301025
# Total Test Accuracy: 79.48717948717949
# Test Accuracy (NFF): 78.76106194690266
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[89 24]
#  [ 0  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.79      0.88       113
#          AFF       0.14      1.00      0.25         4
#
#     accuracy                           0.79       117
#    macro avg       0.57      0.89      0.57       117
# weighted avg       0.97      0.79      0.86       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.4634062349796295
# Total Test Accuracy: 84.44444444444444
# Test Accuracy (NFF): 88.37209302325581
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[38  5]
#  [ 2  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.88      0.92        43
#          AFF       0.00      0.00      1.00         2
#
#     accuracy                           0.84        45
#    macro avg       0.47      0.44      0.96        45
# weighted avg       0.91      0.84      0.92        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.33536577224731445
# Total Test Accuracy: 85.71428571428571
# Test Accuracy (NFF): 85.71428571428571
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[18  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.86      0.92        21
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.86        21
#    macro avg       0.50      0.93      0.46        21
# weighted avg       1.00      0.86      0.92        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 0.41284802556037903
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         3
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.3151758909225464
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 75.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.75      0.86         4
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.75         4
#    macro avg       0.50      0.88      0.43         4
# weighted avg       1.00      0.75      0.86         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 0.4310852512717247
# Total Test Accuracy: 78.87323943661971
# Test Accuracy (NFF): 81.63265306122449
# Test Accuracy (AFF): 72.72727272727273
# Confusion Matrix:
#  [[40  9]
#  [ 6 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.82      0.84        49
#          AFF       0.64      0.73      0.68        22
#
#     accuracy                           0.79        71
#    macro avg       0.75      0.77      0.76        71
# weighted avg       0.80      0.79      0.79        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.25189317017793655
# Total Test Accuracy: 92.06349206349206
# Test Accuracy (NFF): 89.1566265060241
# Test Accuracy (AFF): 97.67441860465115
# Confusion Matrix:
#  [[74  9]
#  [ 1 42]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.89      0.94        83
#          AFF       0.82      0.98      0.89        43
#
#     accuracy                           0.92       126
#    macro avg       0.91      0.93      0.92       126
# weighted avg       0.93      0.92      0.92       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.3779430091381073
# Total Test Accuracy: 84.44444444444444
# Test Accuracy (NFF): 82.5
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[33  7]
#  [ 0  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.82      0.90        40
#          AFF       0.42      1.00      0.59         5
#
#     accuracy                           0.84        45
#    macro avg       0.71      0.91      0.75        45
# weighted avg       0.94      0.84      0.87        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.1788911074399948
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[8 0]
#  [1 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      1.00      0.94         8
#          AFF       1.00      0.00      0.00         1
#
#     accuracy                           0.89         9
#    macro avg       0.94      0.50      0.47         9
# weighted avg       0.90      0.89      0.84         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.6634204983711243
# Total Test Accuracy: 77.3109243697479
# Test Accuracy (NFF): 76.47058823529412
# Test Accuracy (AFF): 79.41176470588235
# Confusion Matrix:
#  [[65 20]
#  [ 7 27]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.76      0.83        85
#          AFF       0.57      0.79      0.67        34
#
#     accuracy                           0.77       119
#    macro avg       0.74      0.78      0.75       119
# weighted avg       0.81      0.77      0.78       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 0.7103029191493988
# Total Test Accuracy: 82.47422680412372
# Test Accuracy (NFF): 83.01886792452831
# Test Accuracy (AFF): 81.81818181818183
# Confusion Matrix:
#  [[44  9]
#  [ 8 36]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.83      0.84        53
#          AFF       0.80      0.82      0.81        44
#
#     accuracy                           0.82        97
#    macro avg       0.82      0.82      0.82        97
# weighted avg       0.83      0.82      0.82        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.5958423018455505
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         3
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.41022923588752747
# Total Test Accuracy: 87.91208791208791
# Test Accuracy (NFF): 88.31168831168831
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[68  9]
#  [ 2 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.88      0.93        77
#          AFF       0.57      0.86      0.69        14
#
#     accuracy                           0.88        91
#    macro avg       0.77      0.87      0.81        91
# weighted avg       0.91      0.88      0.89        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 0.5224062204360962
# Total Test Accuracy: 72.22222222222223
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[10  5]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80        15
#          AFF       0.38      1.00      0.55         3
#
#     accuracy                           0.72        18
#    macro avg       0.69      0.83      0.67        18
# weighted avg       0.90      0.72      0.76        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.43393808603286743
# Total Test Accuracy: 84.61538461538461
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[16  2]
#  [ 2  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.89      0.89        18
#          AFF       0.75      0.75      0.75         8
#
#     accuracy                           0.85        26
#    macro avg       0.82      0.82      0.82        26
# weighted avg       0.85      0.85      0.85        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.08987083286046982
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[17  0]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        17
#          AFF       1.00      1.00      1.00         1
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.7174605131149292
# Total Test Accuracy: 77.41935483870968
# Test Accuracy (NFF): 79.74683544303798
# Test Accuracy (AFF): 64.28571428571429
# Confusion Matrix:
#  [[63 16]
#  [ 5  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.80      0.86        79
#          AFF       0.36      0.64      0.46        14
#
#     accuracy                           0.77        93
#    macro avg       0.64      0.72      0.66        93
# weighted avg       0.84      0.77      0.80        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 0.45514753460884094
# Total Test Accuracy: 81.25
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[6 3]
#  [0 7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         9
#          AFF       0.70      1.00      0.82         7
#
#     accuracy                           0.81        16
#    macro avg       0.85      0.83      0.81        16
# weighted avg       0.87      0.81      0.81        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 0.9880847930908203
# Total Test Accuracy: 50.0
# Test Accuracy (NFF): 50.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3 3]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.50      0.67         6
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.50         6
#    macro avg       0.50      0.75      0.33         6
# weighted avg       1.00      0.50      0.67         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 0.3658168986439705
# Total Test Accuracy: 79.76190476190476
# Test Accuracy (NFF): 77.61194029850746
# Test Accuracy (AFF): 88.23529411764706
# Confusion Matrix:
#  [[52 15]
#  [ 2 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.78      0.86        67
#          AFF       0.50      0.88      0.64        17
#
#     accuracy                           0.80        84
#    macro avg       0.73      0.83      0.75        84
# weighted avg       0.87      0.80      0.81        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.009864147752523422
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.675681471824646
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 76.19047619047619
# Test Accuracy (AFF): 68.18181818181817
# Confusion Matrix:
#  [[96 30]
#  [ 7 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.76      0.84       126
#          AFF       0.33      0.68      0.45        22
#
#     accuracy                           0.75       148
#    macro avg       0.63      0.72      0.64       148
# weighted avg       0.84      0.75      0.78       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.1787799596786499
# Total Test Accuracy: 91.17647058823529
# Test Accuracy (NFF): 91.17647058823529
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[31  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.91      0.95        34
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.91        34
#    macro avg       0.50      0.96      0.48        34
# weighted avg       1.00      0.91      0.95        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.39082005620002747
# Total Test Accuracy: 82.3529411764706
# Test Accuracy (NFF): 78.57142857142857
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[11  3]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.79      0.88        14
#          AFF       0.50      1.00      0.67         3
#
#     accuracy                           0.82        17
#    macro avg       0.75      0.89      0.77        17
# weighted avg       0.91      0.82      0.84        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.6924165189266205
# Total Test Accuracy: 76.74418604651163
# Test Accuracy (NFF): 76.47058823529412
# Test Accuracy (AFF): 77.77777777777779
# Confusion Matrix:
#  [[52 16]
#  [ 4 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.76      0.84        68
#          AFF       0.47      0.78      0.58        18
#
#     accuracy                           0.77        86
#    macro avg       0.70      0.77      0.71        86
# weighted avg       0.83      0.77      0.79        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.6695989966392517
# Total Test Accuracy: 76.0
# Test Accuracy (NFF): 76.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[19  6]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.76      0.86        25
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.76        25
#    macro avg       0.50      0.88      0.43        25
# weighted avg       1.00      0.76      0.86        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.6942622065544128
# Total Test Accuracy: 75.86206896551724
# Test Accuracy (NFF): 73.91304347826086
# Test Accuracy (AFF): 83.33333333333334
# Confusion Matrix:
#  [[17  6]
#  [ 1  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.74      0.83        23
#          AFF       0.45      0.83      0.59         6
#
#     accuracy                           0.76        29
#    macro avg       0.70      0.79      0.71        29
# weighted avg       0.84      0.76      0.78        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.4101096261292696
# Total Test Accuracy: 81.33333333333333
# Test Accuracy (NFF): 87.14285714285714
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[61  9]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.87      0.90        70
#          AFF       0.00      0.00      1.00         5
#
#     accuracy                           0.81        75
#    macro avg       0.46      0.44      0.95        75
# weighted avg       0.86      0.81      0.90        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 0.0025096016470342875
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 1.4650614261627197
# Total Test Accuracy: 46.666666666666664
# Test Accuracy (NFF): 46.666666666666664
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[7 8]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.47      0.64        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.47        15
#    macro avg       0.50      0.73      0.32        15
# weighted avg       1.00      0.47      0.64        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.16295415349304676
# Total Test Accuracy: 94.28571428571429
# Test Accuracy (NFF): 92.94117647058823
# Test Accuracy (AFF): 97.33333333333334
# Confusion Matrix:
#  [[158  12]
#  [  2  73]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.93      0.96       170
#          AFF       0.86      0.97      0.91        75
#
#     accuracy                           0.94       245
#    macro avg       0.92      0.95      0.94       245
# weighted avg       0.95      0.94      0.94       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.7563518285751343
# Total Test Accuracy: 70.96774193548387
# Test Accuracy (NFF): 73.07692307692307
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[19  7]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.73      0.81        26
#          AFF       0.30      0.60      0.40         5
#
#     accuracy                           0.71        31
#    macro avg       0.60      0.67      0.60        31
# weighted avg       0.81      0.71      0.74        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.5343196392059326
# Total Test Accuracy: 80.99173553719008
# Test Accuracy (NFF): 75.0
# Test Accuracy (AFF): 96.96969696969697
# Confusion Matrix:
#  [[66 22]
#  [ 1 32]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.75      0.85        88
#          AFF       0.59      0.97      0.74        33
#
#     accuracy                           0.81       121
#    macro avg       0.79      0.86      0.79       121
# weighted avg       0.88      0.81      0.82       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.30259063839912415
# Total Test Accuracy: 86.36363636363636
# Test Accuracy (NFF): 86.36363636363636
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[19  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.86      0.93        22
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.86        22
#    macro avg       0.50      0.93      0.46        22
# weighted avg       1.00      0.86      0.93        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.3762606382369995
# Total Test Accuracy: 87.75510204081633
# Test Accuracy (NFF): 88.46153846153845
# Test Accuracy (AFF): 85.0
# Confusion Matrix:
#  [[69  9]
#  [ 3 17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.88      0.92        78
#          AFF       0.65      0.85      0.74        20
#
#     accuracy                           0.88        98
#    macro avg       0.81      0.87      0.83        98
# weighted avg       0.90      0.88      0.88        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.7535026967525482
# Total Test Accuracy: 78.87323943661971
# Test Accuracy (NFF): 78.125
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[50 14]
#  [ 1  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.78      0.87        64
#          AFF       0.30      0.86      0.44         7
#
#     accuracy                           0.79        71
#    macro avg       0.64      0.82      0.66        71
# weighted avg       0.91      0.79      0.83        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.9374145269393921
# Total Test Accuracy: 64.91228070175438
# Test Accuracy (NFF): 64.91228070175438
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[37 20]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.65      0.79        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.65        57
#    macro avg       0.50      0.82      0.39        57
# weighted avg       1.00      0.65      0.79        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.618584617972374
# Total Test Accuracy: 80.58252427184466
# Test Accuracy (NFF): 82.89473684210526
# Test Accuracy (AFF): 74.07407407407408
# Confusion Matrix:
#  [[63 13]
#  [ 7 20]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.83      0.86        76
#          AFF       0.61      0.74      0.67        27
#
#     accuracy                           0.81       103
#    macro avg       0.75      0.78      0.76       103
# weighted avg       0.82      0.81      0.81       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.36388467997312546
# Total Test Accuracy: 84.81012658227849
# Test Accuracy (NFF): 86.11111111111111
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[62 10]
#  [ 2  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.86      0.91        72
#          AFF       0.33      0.71      0.45         7
#
#     accuracy                           0.85        79
#    macro avg       0.65      0.79      0.68        79
# weighted avg       0.91      0.85      0.87        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.2314721941947937
# Total Test Accuracy: 84.61538461538461
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[21  3]
#  [ 1  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.88      0.91        24
#          AFF       0.25      0.50      0.33         2
#
#     accuracy                           0.85        26
#    macro avg       0.60      0.69      0.62        26
# weighted avg       0.90      0.85      0.87        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 0.687751293182373
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[3 0]
#  [3 6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.50      1.00      0.67         3
#          AFF       1.00      0.67      0.80         9
#
#     accuracy                           0.75        12
#    macro avg       0.75      0.83      0.73        12
# weighted avg       0.88      0.75      0.77        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.20508289771775404
# Total Test Accuracy: 91.04477611940298
# Test Accuracy (NFF): 91.50943396226415
# Test Accuracy (AFF): 89.28571428571429
# Confusion Matrix:
#  [[97  9]
#  [ 3 25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.92      0.94       106
#          AFF       0.74      0.89      0.81        28
#
#     accuracy                           0.91       134
#    macro avg       0.85      0.90      0.87       134
# weighted avg       0.92      0.91      0.91       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.08193108066916466
# Total Test Accuracy: 96.66666666666667
# Test Accuracy (NFF): 98.68421052631578
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[150   2]
#  [  4  24]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.99      0.98       152
#          AFF       0.92      0.86      0.89        28
#
#     accuracy                           0.97       180
#    macro avg       0.95      0.92      0.93       180
# weighted avg       0.97      0.97      0.97       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.49959081411361694
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 85.18518518518519
# Test Accuracy (AFF): 69.23076923076923
# Confusion Matrix:
#  [[23  4]
#  [ 4  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.85      0.85        27
#          AFF       0.69      0.69      0.69        13
#
#     accuracy                           0.80        40
#    macro avg       0.77      0.77      0.77        40
# weighted avg       0.80      0.80      0.80        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 0.03187105432152748
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 58:
#
# Test Loss: 0.6213809847831726
# Total Test Accuracy: 82.45614035087719
# Test Accuracy (NFF): 79.3103448275862
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[23  6]
#  [ 4 24]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.79      0.82        29
#          AFF       0.80      0.86      0.83        28
#
#     accuracy                           0.82        57
#    macro avg       0.83      0.83      0.82        57
# weighted avg       0.83      0.82      0.82        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.7522261142730713
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.89      0.94         9
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.89         9
#    macro avg       0.50      0.94      0.47         9
# weighted avg       1.00      0.89      0.94         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.7512863874435425
# Total Test Accuracy: 76.42276422764228
# Test Accuracy (NFF): 75.0
# Test Accuracy (AFF): 82.6086956521739
# Confusion Matrix:
#  [[75 25]
#  [ 4 19]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.75      0.84       100
#          AFF       0.43      0.83      0.57        23
#
#     accuracy                           0.76       123
#    macro avg       0.69      0.79      0.70       123
# weighted avg       0.85      0.76      0.79       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.560165286064148
# Total Test Accuracy: 80.95238095238095
# Test Accuracy (NFF): 84.78260869565217
# Test Accuracy (AFF): 70.58823529411765
# Confusion Matrix:
#  [[39  7]
#  [ 5 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.85      0.87        46
#          AFF       0.63      0.71      0.67        17
#
#     accuracy                           0.81        63
#    macro avg       0.76      0.78      0.77        63
# weighted avg       0.82      0.81      0.81        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 0.9595941305160522
# Total Test Accuracy: 75.47169811320755
# Test Accuracy (NFF): 75.60975609756098
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[31 10]
#  [ 3  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.76      0.83        41
#          AFF       0.47      0.75      0.58        12
#
#     accuracy                           0.75        53
#    macro avg       0.69      0.75      0.70        53
# weighted avg       0.81      0.75      0.77        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 1.4852652549743652
# Total Test Accuracy: 50.0
# Test Accuracy (NFF): 50.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4 4]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.50      0.67         8
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.50         8
#    macro avg       0.50      0.75      0.33         8
# weighted avg       1.00      0.50      0.67         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.2054201364517212
# Total Test Accuracy: 87.5
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[28  4]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.93        32
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.88        32
#    macro avg       0.50      0.94      0.47        32
# weighted avg       1.00      0.88      0.93        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.22679252922534943
# Total Test Accuracy: 90.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[8 0]
#  [1 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      1.00      0.94         8
#          AFF       1.00      0.50      0.67         2
#
#     accuracy                           0.90        10
#    macro avg       0.94      0.75      0.80        10
# weighted avg       0.91      0.90      0.89        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.2322733849287033
# Total Test Accuracy: 86.36363636363636
# Test Accuracy (NFF): 94.11764705882352
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[16  1]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.94      0.91        17
#          AFF       0.75      0.60      0.67         5
#
#     accuracy                           0.86        22
#    macro avg       0.82      0.77      0.79        22
# weighted avg       0.86      0.86      0.86        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.6173376441001892
# Total Test Accuracy: 80.55555555555556
# Test Accuracy (NFF): 86.20689655172413
# Test Accuracy (AFF): 57.14285714285714
# Confusion Matrix:
#  [[25  4]
#  [ 3  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.86      0.88        29
#          AFF       0.50      0.57      0.53         7
#
#     accuracy                           0.81        36
#    macro avg       0.70      0.72      0.71        36
# weighted avg       0.82      0.81      0.81        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.5728279822147809
# Total Test Accuracy: 81.2807881773399
# Test Accuracy (NFF): 80.6697108066971
# Test Accuracy (AFF): 83.87096774193549
# Confusion Matrix:
#  [[530 127]
#  [ 25 130]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.81      0.87       657
#          AFF       0.51      0.84      0.63       155
#
#     accuracy                           0.81       812
#    macro avg       0.73      0.82      0.75       812
# weighted avg       0.87      0.81      0.83       812
#
#
# Average Total Test Accuracy: 81.52843310839643

# %% [markdown]
# # DenseNet 161

# %%
from torchvision.models import densenet161, DenseNet161_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the DenseNet-161 model
model = models.densenet161(weights=DenseNet161_Weights.DEFAULT)

# Modify the classifier part of the model
num_features = model.classifier.in_features
model.classifier = nn.Linear(num_features, 2)

# total layers 
total_layers = len(list(model.features.children()))

# freeze 50% layers
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.features.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False
            
# ---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 20
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

dense161 = train_custom_model(model, train_dataset, val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/20, Train ACC: 65.96%, Validation ACC: 54.65%
# Epoch 2/20, Train ACC: 64.64%, Validation ACC: 49.42%
# Epoch 3/20, Train ACC: 70.98%, Validation ACC: 55.81%
# Epoch 4/20, Train ACC: 79.68%, Validation ACC: 69.19%
# Epoch 5/20, Train ACC: 87.34%, Validation ACC: 70.93%
# Epoch 6/20, Train ACC: 89.97%, Validation ACC: 69.19%
# Epoch 7/20, Train ACC: 92.35%, Validation ACC: 75.58%
# Epoch 8/20, Train ACC: 94.20%, Validation ACC: 83.72%
# Epoch 9/20, Train ACC: 95.25%, Validation ACC: 76.74%
# Epoch 10/20, Train ACC: 97.63%, Validation ACC: 76.16%
# Epoch 11/20, Train ACC: 95.78%, Validation ACC: 84.30%
# Epoch 12/20, Train ACC: 97.89%, Validation ACC: 91.86%
# Epoch 13/20, Train ACC: 98.68%, Validation ACC: 91.28%
# Epoch 14/20, Train ACC: 98.68%, Validation ACC: 89.53%
# Epoch 15/20, Train ACC: 98.42%, Validation ACC: 85.47%
# Epoch 16/20, Train ACC: 96.83%, Validation ACC: 88.95%
# Epoch 17/20, Train ACC: 98.94%, Validation ACC: 87.21%
# Epoch 18/20, Train ACC: 98.15%, Validation ACC: 80.23%
# Epoch 19/20, Train ACC: 98.68%, Validation ACC: 85.47%
# Epoch 20/20, Train ACC: 97.36%, Validation ACC: 89.53%

# %%
model = dense161
model.eval()
# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomCsvDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(15, 5))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
torch.cuda.empty_cache()
results.append(average_performance)
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.32736992835998535
# Total Test Accuracy: 86.95652173913044
# Test Accuracy (NFF): 86.95652173913044
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[20  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.87      0.93        23
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.87        23
#    macro avg       0.50      0.93      0.47        23
# weighted avg       1.00      0.87      0.93        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 0.0034374806564301252
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         0
#          AFF       1.00      1.00      1.00         3
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.4062097668647766
# Total Test Accuracy: 85.71428571428571
# Test Accuracy (NFF): 91.30434782608695
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[21  2]
#  [ 3  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.91      0.89        23
#          AFF       0.82      0.75      0.78        12
#
#     accuracy                           0.86        35
#    macro avg       0.85      0.83      0.84        35
# weighted avg       0.86      0.86      0.86        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.15839214622974396
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         2
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.16189170628786087
# Total Test Accuracy: 87.6923076923077
# Test Accuracy (NFF): 90.0
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[54  6]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.90      0.93        60
#          AFF       0.33      0.60      0.43         5
#
#     accuracy                           0.88        65
#    macro avg       0.65      0.75      0.68        65
# weighted avg       0.92      0.88      0.89        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.1982109695672989
# Total Test Accuracy: 89.28571428571429
# Test Accuracy (NFF): 91.66666666666666
# Test Accuracy (AFF): 85.0
# Confusion Matrix:
#  [[33  3]
#  [ 3 17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.92      0.92        36
#          AFF       0.85      0.85      0.85        20
#
#     accuracy                           0.89        56
#    macro avg       0.88      0.88      0.88        56
# weighted avg       0.89      0.89      0.89        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.13424263894557953
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.4204048365354538
# Total Test Accuracy: 90.29126213592232
# Test Accuracy (NFF): 93.75
# Test Accuracy (AFF): 78.26086956521739
# Confusion Matrix:
#  [[75  5]
#  [ 5 18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.94      0.94        80
#          AFF       0.78      0.78      0.78        23
#
#     accuracy                           0.90       103
#    macro avg       0.86      0.86      0.86       103
# weighted avg       0.90      0.90      0.90       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.02315041981637478
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 0.3365542106330395
# Total Test Accuracy: 82.6086956521739
# Test Accuracy (NFF): 92.45283018867924
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[49  4]
#  [ 8  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.86      0.92      0.89        53
#          AFF       0.67      0.50      0.57        16
#
#     accuracy                           0.83        69
#    macro avg       0.76      0.71      0.73        69
# weighted avg       0.81      0.83      0.82        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.23320333613082767
# Total Test Accuracy: 84.41558441558442
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 69.23076923076923
# Confusion Matrix:
#  [[56  8]
#  [ 4  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.88      0.90        64
#          AFF       0.53      0.69      0.60        13
#
#     accuracy                           0.84        77
#    macro avg       0.73      0.78      0.75        77
# weighted avg       0.87      0.84      0.85        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.2951107770204544
# Total Test Accuracy: 85.47008547008546
# Test Accuracy (NFF): 84.95575221238938
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[96 17]
#  [ 0  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.85      0.92       113
#          AFF       0.19      1.00      0.32         4
#
#     accuracy                           0.85       117
#    macro avg       0.60      0.92      0.62       117
# weighted avg       0.97      0.85      0.90       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.0657440796494484
# Total Test Accuracy: 97.77777777777777
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[43  0]
#  [ 1  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      1.00      0.99        43
#          AFF       1.00      0.50      0.67         2
#
#     accuracy                           0.98        45
#    macro avg       0.99      0.75      0.83        45
# weighted avg       0.98      0.98      0.97        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.010214963927865028
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        21
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 0.2991192638874054
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         3
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.058755259960889816
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         4
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 0.2473303135484457
# Total Test Accuracy: 84.50704225352112
# Test Accuracy (NFF): 91.83673469387756
# Test Accuracy (AFF): 68.18181818181817
# Confusion Matrix:
#  [[45  4]
#  [ 7 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.92      0.89        49
#          AFF       0.79      0.68      0.73        22
#
#     accuracy                           0.85        71
#    macro avg       0.83      0.80      0.81        71
# weighted avg       0.84      0.85      0.84        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.19484660029411316
# Total Test Accuracy: 94.44444444444444
# Test Accuracy (NFF): 95.18072289156626
# Test Accuracy (AFF): 93.02325581395348
# Confusion Matrix:
#  [[79  4]
#  [ 3 40]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.95      0.96        83
#          AFF       0.91      0.93      0.92        43
#
#     accuracy                           0.94       126
#    macro avg       0.94      0.94      0.94       126
# weighted avg       0.94      0.94      0.94       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.2510254681110382
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 90.0
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[36  4]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.90      0.94        40
#          AFF       0.50      0.80      0.62         5
#
#     accuracy                           0.89        45
#    macro avg       0.74      0.85      0.78        45
# weighted avg       0.92      0.89      0.90        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.06365683674812317
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[8 0]
#  [0 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         1
#
#     accuracy                           1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.468898743391037
# Total Test Accuracy: 84.03361344537815
# Test Accuracy (NFF): 89.41176470588236
# Test Accuracy (AFF): 70.58823529411765
# Confusion Matrix:
#  [[76  9]
#  [10 24]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.89      0.89        85
#          AFF       0.73      0.71      0.72        34
#
#     accuracy                           0.84       119
#    macro avg       0.81      0.80      0.80       119
# weighted avg       0.84      0.84      0.84       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 0.4522079527378082
# Total Test Accuracy: 83.50515463917526
# Test Accuracy (NFF): 94.33962264150944
# Test Accuracy (AFF): 70.45454545454545
# Confusion Matrix:
#  [[50  3]
#  [13 31]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.79      0.94      0.86        53
#          AFF       0.91      0.70      0.79        44
#
#     accuracy                           0.84        97
#    macro avg       0.85      0.82      0.83        97
# weighted avg       0.85      0.84      0.83        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.022254271432757378
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.27900367230176926
# Total Test Accuracy: 87.91208791208791
# Test Accuracy (NFF): 89.6103896103896
# Test Accuracy (AFF): 78.57142857142857
# Confusion Matrix:
#  [[69  8]
#  [ 3 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.90      0.93        77
#          AFF       0.58      0.79      0.67        14
#
#     accuracy                           0.88        91
#    macro avg       0.77      0.84      0.80        91
# weighted avg       0.90      0.88      0.89        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 0.22344504296779633
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 93.33333333333333
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[14  1]
#  [ 1  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.93      0.93        15
#          AFF       0.67      0.67      0.67         3
#
#     accuracy                           0.89        18
#    macro avg       0.80      0.80      0.80        18
# weighted avg       0.89      0.89      0.89        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.2164001315832138
# Total Test Accuracy: 92.3076923076923
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[18  0]
#  [ 2  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      1.00      0.95        18
#          AFF       1.00      0.75      0.86         8
#
#     accuracy                           0.92        26
#    macro avg       0.95      0.88      0.90        26
# weighted avg       0.93      0.92      0.92        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.024403147399425507
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[17  0]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        17
#          AFF       1.00      1.00      1.00         1
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.21510037034749985
# Total Test Accuracy: 88.17204301075269
# Test Accuracy (NFF): 92.40506329113924
# Test Accuracy (AFF): 64.28571428571429
# Confusion Matrix:
#  [[73  6]
#  [ 5  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.92      0.93        79
#          AFF       0.60      0.64      0.62        14
#
#     accuracy                           0.88        93
#    macro avg       0.77      0.78      0.78        93
# weighted avg       0.89      0.88      0.88        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 0.30277329683303833
# Total Test Accuracy: 87.5
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[9 0]
#  [2 5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.82      1.00      0.90         9
#          AFF       1.00      0.71      0.83         7
#
#     accuracy                           0.88        16
#    macro avg       0.91      0.86      0.87        16
# weighted avg       0.90      0.88      0.87        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 0.36840975284576416
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 83.33333333333334
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[5 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.83      0.91         6
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.83         6
#    macro avg       0.50      0.92      0.45         6
# weighted avg       1.00      0.83      0.91         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 0.17886715289205313
# Total Test Accuracy: 90.47619047619048
# Test Accuracy (NFF): 89.55223880597015
# Test Accuracy (AFF): 94.11764705882352
# Confusion Matrix:
#  [[60  7]
#  [ 1 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.90      0.94        67
#          AFF       0.70      0.94      0.80        17
#
#     accuracy                           0.90        84
#    macro avg       0.84      0.92      0.87        84
# weighted avg       0.93      0.90      0.91        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.0028042111080139875
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.35794931401809055
# Total Test Accuracy: 84.45945945945945
# Test Accuracy (NFF): 87.3015873015873
# Test Accuracy (AFF): 68.18181818181817
# Confusion Matrix:
#  [[110  16]
#  [  7  15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.87      0.91       126
#          AFF       0.48      0.68      0.57        22
#
#     accuracy                           0.84       148
#    macro avg       0.71      0.78      0.74       148
# weighted avg       0.87      0.84      0.85       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.1770649403333664
# Total Test Accuracy: 91.17647058823529
# Test Accuracy (NFF): 91.17647058823529
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[31  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.91      0.95        34
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.91        34
#    macro avg       0.50      0.96      0.48        34
# weighted avg       1.00      0.91      0.95        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.055514123290777206
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[14  0]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        14
#          AFF       1.00      1.00      1.00         3
#
#     accuracy                           1.00        17
#    macro avg       1.00      1.00      1.00        17
# weighted avg       1.00      1.00      1.00        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.3350965902209282
# Total Test Accuracy: 83.72093023255815
# Test Accuracy (NFF): 86.76470588235294
# Test Accuracy (AFF): 72.22222222222221
# Confusion Matrix:
#  [[59  9]
#  [ 5 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.87      0.89        68
#          AFF       0.59      0.72      0.65        18
#
#     accuracy                           0.84        86
#    macro avg       0.76      0.79      0.77        86
# weighted avg       0.85      0.84      0.84        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.3022875487804413
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 80.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[20  5]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.80      0.89        25
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.80        25
#    macro avg       0.50      0.90      0.44        25
# weighted avg       1.00      0.80      0.89        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.14349906146526337
# Total Test Accuracy: 93.10344827586206
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 83.33333333333334
# Confusion Matrix:
#  [[22  1]
#  [ 1  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.96      0.96        23
#          AFF       0.83      0.83      0.83         6
#
#     accuracy                           0.93        29
#    macro avg       0.89      0.89      0.89        29
# weighted avg       0.93      0.93      0.93        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.33892698772251606
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 85.71428571428571
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[60 10]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.86      0.89        70
#          AFF       0.00      0.00      1.00         5
#
#     accuracy                           0.80        75
#    macro avg       0.46      0.43      0.94        75
# weighted avg       0.86      0.80      0.90        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 0.0030646484810858965
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 1.215519666671753
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[10  5]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67        15
#    macro avg       0.50      0.83      0.40        15
# weighted avg       1.00      0.67      0.80        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.0828671371564269
# Total Test Accuracy: 96.3265306122449
# Test Accuracy (NFF): 95.88235294117648
# Test Accuracy (AFF): 97.33333333333334
# Confusion Matrix:
#  [[163   7]
#  [  2  73]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.96      0.97       170
#          AFF       0.91      0.97      0.94        75
#
#     accuracy                           0.96       245
#    macro avg       0.95      0.97      0.96       245
# weighted avg       0.96      0.96      0.96       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.3436189591884613
# Total Test Accuracy: 83.87096774193549
# Test Accuracy (NFF): 80.76923076923077
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[21  5]
#  [ 0  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.81      0.89        26
#          AFF       0.50      1.00      0.67         5
#
#     accuracy                           0.84        31
#    macro avg       0.75      0.90      0.78        31
# weighted avg       0.92      0.84      0.86        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.4461710602045059
# Total Test Accuracy: 85.12396694214875
# Test Accuracy (NFF): 84.0909090909091
# Test Accuracy (AFF): 87.87878787878788
# Confusion Matrix:
#  [[74 14]
#  [ 4 29]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.84      0.89        88
#          AFF       0.67      0.88      0.76        33
#
#     accuracy                           0.85       121
#    macro avg       0.81      0.86      0.83       121
# weighted avg       0.87      0.85      0.86       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.2015601247549057
# Total Test Accuracy: 86.36363636363636
# Test Accuracy (NFF): 86.36363636363636
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[19  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.86      0.93        22
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.86        22
#    macro avg       0.50      0.93      0.46        22
# weighted avg       1.00      0.86      0.93        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.39429476857185364
# Total Test Accuracy: 85.71428571428571
# Test Accuracy (NFF): 84.61538461538461
# Test Accuracy (AFF): 90.0
# Confusion Matrix:
#  [[66 12]
#  [ 2 18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.85      0.90        78
#          AFF       0.60      0.90      0.72        20
#
#     accuracy                           0.86        98
#    macro avg       0.79      0.87      0.81        98
# weighted avg       0.89      0.86      0.87        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.4754394590854645
# Total Test Accuracy: 87.32394366197182
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[56  8]
#  [ 1  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.88      0.93        64
#          AFF       0.43      0.86      0.57         7
#
#     accuracy                           0.87        71
#    macro avg       0.71      0.87      0.75        71
# weighted avg       0.93      0.87      0.89        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.4273824095726013
# Total Test Accuracy: 82.45614035087719
# Test Accuracy (NFF): 82.45614035087719
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[47 10]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.82      0.90        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.82        57
#    macro avg       0.50      0.91      0.45        57
# weighted avg       1.00      0.82      0.90        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.5863564163446426
# Total Test Accuracy: 77.66990291262135
# Test Accuracy (NFF): 85.52631578947368
# Test Accuracy (AFF): 55.55555555555556
# Confusion Matrix:
#  [[65 11]
#  [12 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      0.86      0.85        76
#          AFF       0.58      0.56      0.57        27
#
#     accuracy                           0.78       103
#    macro avg       0.71      0.71      0.71       103
# weighted avg       0.77      0.78      0.78       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.1211092472076416
# Total Test Accuracy: 92.40506329113924
# Test Accuracy (NFF): 93.05555555555556
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[67  5]
#  [ 1  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.93      0.96        72
#          AFF       0.55      0.86      0.67         7
#
#     accuracy                           0.92        79
#    macro avg       0.77      0.89      0.81        79
# weighted avg       0.95      0.92      0.93        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.018970666453242302
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[24  0]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        24
#          AFF       1.00      1.00      1.00         2
#
#     accuracy                           1.00        26
#    macro avg       1.00      1.00      1.00        26
# weighted avg       1.00      1.00      1.00        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 0.870516300201416
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[3 0]
#  [3 6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.50      1.00      0.67         3
#          AFF       1.00      0.67      0.80         9
#
#     accuracy                           0.75        12
#    macro avg       0.75      0.83      0.73        12
# weighted avg       0.88      0.75      0.77        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.20833469182252884
# Total Test Accuracy: 91.04477611940298
# Test Accuracy (NFF): 91.50943396226415
# Test Accuracy (AFF): 89.28571428571429
# Confusion Matrix:
#  [[97  9]
#  [ 3 25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.92      0.94       106
#          AFF       0.74      0.89      0.81        28
#
#     accuracy                           0.91       134
#    macro avg       0.85      0.90      0.87       134
# weighted avg       0.92      0.91      0.91       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.13101608181993166
# Total Test Accuracy: 96.66666666666667
# Test Accuracy (NFF): 98.02631578947368
# Test Accuracy (AFF): 89.28571428571429
# Confusion Matrix:
#  [[149   3]
#  [  3  25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.98      0.98       152
#          AFF       0.89      0.89      0.89        28
#
#     accuracy                           0.97       180
#    macro avg       0.94      0.94      0.94       180
# weighted avg       0.97      0.97      0.97       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.43121495842933655
# Total Test Accuracy: 85.0
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 76.92307692307693
# Confusion Matrix:
#  [[24  3]
#  [ 3 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.89      0.89        27
#          AFF       0.77      0.77      0.77        13
#
#     accuracy                           0.85        40
#    macro avg       0.83      0.83      0.83        40
# weighted avg       0.85      0.85      0.85        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 0.24184274673461914
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 58:
#
# Test Loss: 0.5082658529281616
# Total Test Accuracy: 87.71929824561404
# Test Accuracy (NFF): 89.65517241379311
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[26  3]
#  [ 4 24]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.90      0.88        29
#          AFF       0.89      0.86      0.87        28
#
#     accuracy                           0.88        57
#    macro avg       0.88      0.88      0.88        57
# weighted avg       0.88      0.88      0.88        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.1017674058675766
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.37189601361751556
# Total Test Accuracy: 87.8048780487805
# Test Accuracy (NFF): 91.0
# Test Accuracy (AFF): 73.91304347826086
# Confusion Matrix:
#  [[91  9]
#  [ 6 17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.91      0.92       100
#          AFF       0.65      0.74      0.69        23
#
#     accuracy                           0.88       123
#    macro avg       0.80      0.82      0.81       123
# weighted avg       0.88      0.88      0.88       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.4074137210845947
# Total Test Accuracy: 80.95238095238095
# Test Accuracy (NFF): 80.43478260869566
# Test Accuracy (AFF): 82.35294117647058
# Confusion Matrix:
#  [[37  9]
#  [ 3 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.80      0.86        46
#          AFF       0.61      0.82      0.70        17
#
#     accuracy                           0.81        63
#    macro avg       0.77      0.81      0.78        63
# weighted avg       0.84      0.81      0.82        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 0.46011683344841003
# Total Test Accuracy: 88.67924528301887
# Test Accuracy (NFF): 92.6829268292683
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[38  3]
#  [ 3  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.93      0.93        41
#          AFF       0.75      0.75      0.75        12
#
#     accuracy                           0.89        53
#    macro avg       0.84      0.84      0.84        53
# weighted avg       0.89      0.89      0.89        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 0.0535183846950531
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.13374274969100952
# Total Test Accuracy: 90.625
# Test Accuracy (NFF): 90.625
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[29  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.91      0.95        32
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.91        32
#    macro avg       0.50      0.95      0.48        32
# weighted avg       1.00      0.91      0.95        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.2939186692237854
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[7 1]
#  [1 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.88      0.88         8
#          AFF       0.50      0.50      0.50         2
#
#     accuracy                           0.80        10
#    macro avg       0.69      0.69      0.69        10
# weighted avg       0.80      0.80      0.80        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.1886453777551651
# Total Test Accuracy: 86.36363636363636
# Test Accuracy (NFF): 94.11764705882352
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[16  1]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.94      0.91        17
#          AFF       0.75      0.60      0.67         5
#
#     accuracy                           0.86        22
#    macro avg       0.82      0.77      0.79        22
# weighted avg       0.86      0.86      0.86        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.21728865802288055
# Total Test Accuracy: 91.66666666666667
# Test Accuracy (NFF): 96.55172413793103
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[28  1]
#  [ 2  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.97      0.95        29
#          AFF       0.83      0.71      0.77         7
#
#     accuracy                           0.92        36
#    macro avg       0.88      0.84      0.86        36
# weighted avg       0.91      0.92      0.91        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.3585770313556378
# Total Test Accuracy: 86.94581280788178
# Test Accuracy (NFF): 88.58447488584474
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[582  75]
#  [ 31 124]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.89      0.92       657
#          AFF       0.62      0.80      0.70       155
#
#     accuracy                           0.87       812
#    macro avg       0.79      0.84      0.81       812
# weighted avg       0.89      0.87      0.88       812
#
#
# Average Total Test Accuracy: 89.48803067339838

# %%
results
# Out:
# [85.52376811471399,
#  88.4475029191375,
#  89.93011548353587,
#  81.52843310839643,
#  89.48803067339838]

# %% [markdown]
# # Efficient B2

# %%
# from torchvision.models import efficientnet_b2, EfficientNet_B2_Weights

# torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# # Define the EfficientNetV2-M model
# model = efficientnet_b2(weights=EfficientNet_B2_Weights.DEFAULT)

# # Access input features of the classifier
# num_features = model.classifier[1].in_features

# # Modify the classifier part of the model
# model.classifier[1] = nn.Linear(in_features=num_features, out_features=2)

# # Freeze certain layers
# total_layers = len(list(model.children()))
# freeze_layers = int(total_layers * 0.5)
# for index, child in enumerate(model.children()):
#     if index < freeze_layers:
#         for param in child.parameters():
#             param.requires_grad = False

# # Hyperparameters
# num_epochs = 20
# batch_size = 8
# learning_rate = 0.0001
# optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# # Move model to GPU if available
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# model = model.to(device)

# # Train the model
# effi_b2 = train_custom_model(model, train_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
