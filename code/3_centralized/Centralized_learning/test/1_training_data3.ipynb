# %% [markdown]
# # Functions

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score
from torch.utils.data import Dataset
from PIL import Image
import csv
from torchvision import transforms, models
import json
import seaborn as sns
from sklearn.metrics import matthews_corrcoef, f1_score
import random
import torch.optim as optim
from torch.optim import lr_scheduler


# 设置随机数种子
seed = 1
torch.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)

# 设置CUDA随机数种子（如果使用GPU）
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
# json train
class CustomDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]
        image_path = item['ImagePath']
        label = item['Label']

        # Load image
        image = Image.open(image_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        # Convert label to numerical representation
        if label == 'NFF':
            label = 0
        elif label == 'AFF':
            label = 1
        else:
            raise ValueError("Invalid label in JSON data.")

        return image, label
    
# csv
class CustomCsvDataset(Dataset):
    def __init__(self, csv_file, transform=None):
        self.data = []
        self.labels = []  # Store labels separately
        self.patient_ids = []  # Store patient IDs separately
        self.hospital_ids = []  # Store hospital IDs separately
        self.transform = transform
        
        # read csv
        with open(csv_file, 'r') as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                image_path = row['ImagePath']
                label = row['Label']
                patient_id = row['PatientID']
                hospital_id = row['HospitalID']

                if label == 'NFF':
                    label = 0
                elif label == 'AFF':
                    label = 1
                else:
                    raise ValueError("Invalid label in CSV file.")
                self.data.append((image_path, label))
                self.labels.append(label)
                self.patient_ids.append(patient_id)
                self.hospital_ids.append(int(hospital_id))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image_path, label = self.data[idx]
        image = Image.open(image_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image, label

def show_image(dataset, num_images=5):
    # Get random indices
    random_indices = np.random.choice(len(dataset), num_images, replace=False)

    # Plot images with truncated names
    plt.figure(figsize=(15, 5))
    for i, idx in enumerate(random_indices):
        image, label = dataset[idx]  # Use the dataset directly
        filename = dataset.data[idx][0]  # Get the filename from dataset's internal data attribute
        truncated_filename = filename.split('/')[-1][:15]  # Extract the last part and truncate to 15 characters
        
        # Print the original filename
        print(f"Image location: {filename}")

        plt.subplot(1, num_images, i + 1)
        plt.title(f"Label: {label}")
        plt.imshow(image[0])  # Assuming single-channel (grayscale) image
        # plt.imshow(image[0], cmap='gray')  # Assuming single-channel (grayscale) image

        plt.axis('off')
    plt.show()
    
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_classweight(train_dataset):
    train_nff_count = sum(1 for _, label in train_dataset if label == 0)  # 0 NFF
    train_aff_count = sum(1 for _, label in train_dataset if label == 1)  # 1 AFF
    class_weight_nff = 1 / (2 * (train_nff_count / (train_nff_count + train_aff_count)))
    class_weight_aff = 1 / (2 * (train_aff_count / (train_nff_count + train_aff_count)))
    
    return [class_weight_nff, class_weight_aff] # 0 nff , 1 aff

def test_model(model, test_dataset):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, pin_memory=True)
    model = model.to(device)

    model.eval()

    correct_test_nff = 0
    correct_test_aff = 0
    total_nff = 0
    total_aff = 0
    total_test = 0
    test_loss = 0

    criterion = nn.CrossEntropyLoss()

    with torch.no_grad():
        all_predictions = []
        all_labels = []
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            _, predicted = torch.max(outputs.data, 1)
            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            total_test += labels.size(0)
            total_nff += (labels == 0).sum().item()
            total_aff += (labels == 1).sum().item()
            correct_test_nff += ((predicted == labels) & (labels == 0)).sum().item()
            correct_test_aff += ((predicted == labels) & (labels == 1)).sum().item()
            test_loss += loss.item()

    # Check if total_aff is zero before performing the division
    test_accuracy_nff = correct_test_nff / total_nff if total_nff != 0 else 0
    test_accuracy_aff = correct_test_aff / total_aff if total_aff != 0 else 0
    test_accuracy_total = (correct_test_nff + correct_test_aff) / total_test
    test_loss /= len(test_loader)

    conf_matrix = confusion_matrix(all_labels, all_predictions)

    # Directly use class labels as strings in target_names
    target_names = ['NFF', 'AFF']

    classification_rep = classification_report(all_labels, all_predictions)

    # Calculate AUC
    auc_score = roc_auc_score(all_labels, all_predictions)

    # Calculate Matthew's correlation coefficient
    mcc_score = matthews_corrcoef(all_labels, all_predictions)

    # Calculate F1 score
    f1_score_value = f1_score(all_labels, all_predictions)

    # Store metrics in a dictionary
    metrics = {
        # "Test Loss": round(test_loss, 3),
        "Total Acc": round(test_accuracy_total, 3),
        "nff Acc": round(test_accuracy_nff, 3),
        "aff Acc": round(test_accuracy_aff, 3),
        "AUC": round(auc_score, 3),
        "MCC": round(mcc_score, 3),
        "F1 Score": round(f1_score_value, 3),
    }

    # Confusion Matrix
    plt.figure(figsize=(6, 4))
    sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=target_names, yticklabels=target_names)
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()

    # Classification Report
    print("Classification Report:")
    print(classification_rep)

    return metrics
# ------------------------------------------------------------------------------------------------------
def train_custom_model(model, train_dataset, val_dataset, num_epochs, batch_size, optimizer=None):
    classweight = get_classweight(train_dataset)  # get_classweight is a function defined above
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    model = model.to(device)
    criterion = nn.CrossEntropyLoss(weight=torch.Tensor(classweight).to(device))

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    # Define the optimizer
    if optimizer is None:
        optimizer = optim.Adam(model.parameters(), lr=0.001)  # You can change the optimizer and initial learning rate

    # Define the learning rate scheduler
    lr_scheduler_step_size = 10
    lr_scheduler_gamma = 0.1
    scheduler = lr_scheduler.StepLR(optimizer, step_size=lr_scheduler_step_size, gamma=lr_scheduler_gamma)

    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        model.train()
        correct_train = 0
        total_train = 0

        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()

        train_accuracy = 100 * correct_train / total_train

        model.eval()
        correct_validation = 0
        total_validation = 0
        validation_loss = 0

        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                _, predicted = torch.max(outputs.data, 1)
                total_validation += labels.size(0)
                correct_validation += (predicted == labels).sum().item()
                validation_loss += loss.item()

        validation_accuracy = 100 * correct_validation / total_validation
        validation_loss /= len(val_loader)

        print(f"Epoch {epoch+1}/{num_epochs}, "
              f"Train ACC: {train_accuracy:.2f}%, "
              f"Validation ACC: {validation_accuracy:.2f}%")

        # Store accuracies for plotting
        train_accuracies.append(train_accuracy)
        val_accuracies.append(validation_accuracy)

        # Step the learning rate scheduler
        scheduler.step()

    # Plotting the accuracy curves
    plt.plot(range(1, num_epochs+1), train_accuracies, label='Train Accuracy')
    plt.plot(range(1, num_epochs+1), val_accuracies, label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

    return model

# %%
# augmentation
train_transforms = transforms.Compose([
    transforms.RandomRotation(degrees=30),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.GaussianBlur(kernel_size=3),
    transforms.RandomAdjustSharpness(sharpness_factor=5),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

val_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])


# Load JSON data
with open('/local/data1/honzh073/local_repository/FL/code/4_centralized_learning/csv_files/combined_data3.json', 'r') as json_file:
    json_data = json.load(json_file)
    train_data = json_data['train']
    val_data = json_data['val']

train_dataset = CustomDataset(train_data, transform=train_transforms)
val_dataset = CustomDataset(val_data, transform=val_transforms)

# classweight
classweight = get_classweight(train_dataset)
print('training class weight', classweight)

# # print images
# show_image(train_dataset, 5)

# calculate numbers
print("train")
print('-----------------------------------')
train_NFF_count = sum(1 for _, label in train_dataset if label == 0)  # 0 NFF
train_AFF_count = sum(1 for _, label in train_dataset if label == 1)  # 1 AFF

print(f"train AFF: {train_AFF_count}, ratio: {train_AFF_count / (train_AFF_count + train_NFF_count):.2f}")
print(f"----- NFF: {train_NFF_count}, ratio: {train_NFF_count / (train_AFF_count + train_NFF_count):.2f}")

print("val")
print('-----------------------------------')
train_NFF_count = sum(1 for _, label in val_dataset if label == 0)  # 0 NFF
train_AFF_count = sum(1 for _, label in val_dataset if label == 1)  # 1 AFF

print(f"train AFF: {train_AFF_count}, ratio: {train_AFF_count / (train_AFF_count + train_NFF_count):.2f}")
print(f"----- NFF: {train_NFF_count}, ratio: {train_NFF_count / (train_AFF_count + train_NFF_count):.2f}")
# Out:
# training class weight [0.7018518518518518, 1.738532110091743]
# train
# -----------------------------------
# train AFF: 109, ratio: 0.29
# ----- NFF: 270, ratio: 0.71
# val
# -----------------------------------
# train AFF: 37, ratio: 0.22
# ----- NFF: 135, ratio: 0.78

# %% [markdown]
# # VGG 19

# %%
from torchvision.models import vgg19, VGG19_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the VGG-19 model
model = models.vgg19(weights=VGG19_Weights.DEFAULT)

# Modify the classifier part of the model
num_features = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_features, 2)

# layer number
total_layers = len(list(model.features.children()))

# freeze 50% layer
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.features.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False
# ---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 100
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

v19 = train_custom_model(model, train_dataset, val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/100, Train ACC: 51.19%, Validation ACC: 34.88%
# Epoch 2/100, Train ACC: 55.15%, Validation ACC: 77.91%
# Epoch 3/100, Train ACC: 62.01%, Validation ACC: 63.95%
# Epoch 4/100, Train ACC: 67.02%, Validation ACC: 24.42%
# Epoch 5/100, Train ACC: 60.69%, Validation ACC: 59.88%
# Epoch 6/100, Train ACC: 62.53%, Validation ACC: 69.77%
# Epoch 7/100, Train ACC: 77.57%, Validation ACC: 56.98%
# Epoch 8/100, Train ACC: 75.46%, Validation ACC: 74.42%
# Epoch 9/100, Train ACC: 82.06%, Validation ACC: 72.09%
# Epoch 10/100, Train ACC: 84.70%, Validation ACC: 87.79%
# Epoch 11/100, Train ACC: 87.34%, Validation ACC: 79.65%
# Epoch 12/100, Train ACC: 85.49%, Validation ACC: 84.88%
# Epoch 13/100, Train ACC: 88.65%, Validation ACC: 85.47%
# Epoch 14/100, Train ACC: 89.18%, Validation ACC: 83.72%
# Epoch 15/100, Train ACC: 89.18%, Validation ACC: 82.56%
# Epoch 16/100, Train ACC: 89.97%, Validation ACC: 82.56%
# Epoch 17/100, Train ACC: 88.39%, Validation ACC: 84.30%
# Epoch 18/100, Train ACC: 91.56%, Validation ACC: 85.47%
# Epoch 19/100, Train ACC: 90.24%, Validation ACC: 86.05%
# Epoch 20/100, Train ACC: 89.97%, Validation ACC: 84.88%
# Epoch 21/100, Train ACC: 92.61%, Validation ACC: 85.47%
# Epoch 22/100, Train ACC: 88.92%, Validation ACC: 85.47%
# Epoch 23/100, Train ACC: 91.56%, Validation ACC: 84.88%
# Epoch 24/100, Train ACC: 90.77%, Validation ACC: 86.05%
# Epoch 25/100, Train ACC: 90.50%, Validation ACC: 86.05%
# Epoch 26/100, Train ACC: 92.08%, Validation ACC: 85.47%
# Epoch 27/100, Train ACC: 92.35%, Validation ACC: 84.88%
# Epoch 28/100, Train ACC: 90.24%, Validation ACC: 86.05%
# Epoch 29/100, Train ACC: 93.14%, Validation ACC: 86.05%
# Epoch 30/100, Train ACC: 90.24%, Validation ACC: 86.05%
# Epoch 31/100, Train ACC: 92.61%, Validation ACC: 86.05%
# Epoch 32/100, Train ACC: 91.03%, Validation ACC: 86.05%
# Epoch 33/100, Train ACC: 93.40%, Validation ACC: 86.05%
# Epoch 34/100, Train ACC: 93.40%, Validation ACC: 85.47%
# Epoch 35/100, Train ACC: 90.77%, Validation ACC: 85.47%
# Epoch 36/100, Train ACC: 91.56%, Validation ACC: 85.47%
# Epoch 37/100, Train ACC: 92.08%, Validation ACC: 85.47%
# Epoch 38/100, Train ACC: 93.14%, Validation ACC: 84.88%
# Epoch 39/100, Train ACC: 91.03%, Validation ACC: 84.88%
# Epoch 40/100, Train ACC: 91.82%, Validation ACC: 84.88%
# Epoch 41/100, Train ACC: 89.71%, Validation ACC: 84.88%
# Epoch 42/100, Train ACC: 90.50%, Validation ACC: 84.88%
# Epoch 43/100, Train ACC: 90.77%, Validation ACC: 84.88%
# Epoch 44/100, Train ACC: 93.40%, Validation ACC: 84.88%
# Epoch 45/100, Train ACC: 90.24%, Validation ACC: 84.88%
# Epoch 46/100, Train ACC: 90.77%, Validation ACC: 84.88%
# Epoch 47/100, Train ACC: 92.61%, Validation ACC: 84.88%
# Epoch 48/100, Train ACC: 91.56%, Validation ACC: 84.88%
# Epoch 49/100, Train ACC: 92.61%, Validation ACC: 84.88%
# Epoch 50/100, Train ACC: 92.35%, Validation ACC: 84.88%
# Epoch 51/100, Train ACC: 91.03%, Validation ACC: 84.88%
# Epoch 52/100, Train ACC: 90.50%, Validation ACC: 84.88%
# Epoch 53/100, Train ACC: 93.14%, Validation ACC: 84.88%
# Epoch 54/100, Train ACC: 91.03%, Validation ACC: 84.88%
# Epoch 55/100, Train ACC: 91.29%, Validation ACC: 84.88%
# Epoch 56/100, Train ACC: 91.29%, Validation ACC: 84.88%
# Epoch 57/100, Train ACC: 92.88%, Validation ACC: 84.88%
# Epoch 58/100, Train ACC: 90.77%, Validation ACC: 84.88%
# Epoch 59/100, Train ACC: 92.35%, Validation ACC: 84.88%
# Epoch 60/100, Train ACC: 92.88%, Validation ACC: 84.88%
# Epoch 61/100, Train ACC: 93.40%, Validation ACC: 84.88%
# Epoch 62/100, Train ACC: 91.03%, Validation ACC: 84.88%
# Epoch 63/100, Train ACC: 92.88%, Validation ACC: 84.88%
# Epoch 64/100, Train ACC: 91.56%, Validation ACC: 84.88%
# Epoch 65/100, Train ACC: 92.61%, Validation ACC: 84.88%
# Epoch 66/100, Train ACC: 90.24%, Validation ACC: 84.88%
# Epoch 67/100, Train ACC: 91.03%, Validation ACC: 84.88%
# Epoch 68/100, Train ACC: 88.92%, Validation ACC: 84.88%
# Epoch 69/100, Train ACC: 93.67%, Validation ACC: 84.88%
# Epoch 70/100, Train ACC: 92.08%, Validation ACC: 84.88%
# Epoch 71/100, Train ACC: 91.29%, Validation ACC: 84.88%
# Epoch 72/100, Train ACC: 92.61%, Validation ACC: 84.88%
# Epoch 73/100, Train ACC: 90.77%, Validation ACC: 84.88%
# Epoch 74/100, Train ACC: 92.08%, Validation ACC: 84.88%
# Epoch 75/100, Train ACC: 92.88%, Validation ACC: 84.88%
# Epoch 76/100, Train ACC: 90.77%, Validation ACC: 84.88%
# Epoch 77/100, Train ACC: 91.29%, Validation ACC: 84.88%
# Epoch 78/100, Train ACC: 92.08%, Validation ACC: 84.88%
# Epoch 79/100, Train ACC: 87.60%, Validation ACC: 84.88%
# Epoch 80/100, Train ACC: 91.56%, Validation ACC: 84.88%
# Epoch 81/100, Train ACC: 90.77%, Validation ACC: 84.88%
# Epoch 82/100, Train ACC: 91.03%, Validation ACC: 84.88%
# Epoch 83/100, Train ACC: 92.88%, Validation ACC: 84.88%
# Epoch 84/100, Train ACC: 90.24%, Validation ACC: 84.88%
# Epoch 85/100, Train ACC: 91.56%, Validation ACC: 84.88%
# Epoch 86/100, Train ACC: 91.56%, Validation ACC: 84.88%
# Epoch 87/100, Train ACC: 89.97%, Validation ACC: 84.88%
# Epoch 88/100, Train ACC: 92.61%, Validation ACC: 84.88%
# Epoch 89/100, Train ACC: 91.29%, Validation ACC: 84.88%
# Epoch 90/100, Train ACC: 93.40%, Validation ACC: 84.88%
# Epoch 91/100, Train ACC: 91.56%, Validation ACC: 84.88%
# Epoch 92/100, Train ACC: 91.03%, Validation ACC: 84.88%
# Epoch 93/100, Train ACC: 88.39%, Validation ACC: 84.88%
# Epoch 94/100, Train ACC: 89.71%, Validation ACC: 84.88%
# Epoch 95/100, Train ACC: 92.35%, Validation ACC: 84.88%
# Epoch 96/100, Train ACC: 91.56%, Validation ACC: 84.88%
# Epoch 97/100, Train ACC: 92.88%, Validation ACC: 84.88%
# Epoch 98/100, Train ACC: 92.88%, Validation ACC: 84.88%
# Epoch 99/100, Train ACC: 91.82%, Validation ACC: 84.88%
# Epoch 100/100, Train ACC: 92.61%, Validation ACC: 84.88%

# %%
model = v19
model.eval()
# 加载测试数据集
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomCsvDataset(csv_file=test_csv_file, transform=test_transform)

test_model(model, test_dataset)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90      3474
#            1       0.59      0.74      0.66       868
#
#     accuracy                           0.85      4342
#    macro avg       0.76      0.81      0.78      4342
# weighted avg       0.86      0.85      0.85      4342
# {'Total Acc': 0.847,
#  'nff Acc': 0.874,
#  'aff Acc': 0.741,
#  'AUC': 0.807,
#  'MCC': 0.568,
#  'F1 Score': 0.659}

# %% [markdown]
# # ResNet50

# %%
from torchvision.models import resnet50, ResNet50_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the ResNet-101 model
model = models.resnet50(weights=ResNet50_Weights.DEFAULT)

num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)

# layer number
total_layers = len(list(model.children()))

# freeze 50% layer
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False

# modify full connection layer
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)

# ---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 100
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

res50 = train_custom_model(model, train_dataset, val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/100, Train ACC: 55.94%, Validation ACC: 73.26%
# Epoch 2/100, Train ACC: 67.81%, Validation ACC: 73.84%
# Epoch 3/100, Train ACC: 71.50%, Validation ACC: 61.05%
# Epoch 4/100, Train ACC: 74.14%, Validation ACC: 59.30%
# Epoch 5/100, Train ACC: 72.30%, Validation ACC: 61.63%
# Epoch 6/100, Train ACC: 76.78%, Validation ACC: 68.02%
# Epoch 7/100, Train ACC: 80.47%, Validation ACC: 76.16%
# Epoch 8/100, Train ACC: 83.38%, Validation ACC: 82.56%
# Epoch 9/100, Train ACC: 88.13%, Validation ACC: 83.14%
# Epoch 10/100, Train ACC: 87.34%, Validation ACC: 80.23%
# Epoch 11/100, Train ACC: 89.45%, Validation ACC: 81.98%
# Epoch 12/100, Train ACC: 91.29%, Validation ACC: 80.81%
# Epoch 13/100, Train ACC: 90.50%, Validation ACC: 83.14%
# Epoch 14/100, Train ACC: 90.24%, Validation ACC: 85.47%
# Epoch 15/100, Train ACC: 92.08%, Validation ACC: 86.63%
# Epoch 16/100, Train ACC: 91.56%, Validation ACC: 86.63%
# Epoch 17/100, Train ACC: 92.88%, Validation ACC: 86.05%
# Epoch 18/100, Train ACC: 93.40%, Validation ACC: 86.05%
# Epoch 19/100, Train ACC: 90.50%, Validation ACC: 86.63%
# Epoch 20/100, Train ACC: 94.20%, Validation ACC: 87.21%
# Epoch 21/100, Train ACC: 92.35%, Validation ACC: 87.21%
# Epoch 22/100, Train ACC: 92.88%, Validation ACC: 86.63%
# Epoch 23/100, Train ACC: 94.20%, Validation ACC: 86.63%
# Epoch 24/100, Train ACC: 94.20%, Validation ACC: 86.63%
# Epoch 25/100, Train ACC: 92.61%, Validation ACC: 84.88%
# Epoch 26/100, Train ACC: 91.82%, Validation ACC: 86.05%
# Epoch 27/100, Train ACC: 93.14%, Validation ACC: 86.63%
# Epoch 28/100, Train ACC: 93.40%, Validation ACC: 85.47%
# Epoch 29/100, Train ACC: 92.88%, Validation ACC: 85.47%
# Epoch 30/100, Train ACC: 93.40%, Validation ACC: 85.47%
# Epoch 31/100, Train ACC: 93.93%, Validation ACC: 84.88%
# Epoch 32/100, Train ACC: 94.99%, Validation ACC: 86.63%
# Epoch 33/100, Train ACC: 92.61%, Validation ACC: 84.88%
# Epoch 34/100, Train ACC: 92.88%, Validation ACC: 86.05%
# Epoch 35/100, Train ACC: 92.88%, Validation ACC: 86.05%
# Epoch 36/100, Train ACC: 93.67%, Validation ACC: 86.63%
# Epoch 37/100, Train ACC: 94.46%, Validation ACC: 87.21%
# Epoch 38/100, Train ACC: 92.35%, Validation ACC: 86.63%
# Epoch 39/100, Train ACC: 91.82%, Validation ACC: 85.47%
# Epoch 40/100, Train ACC: 93.93%, Validation ACC: 86.05%
# Epoch 41/100, Train ACC: 93.93%, Validation ACC: 85.47%
# Epoch 42/100, Train ACC: 93.14%, Validation ACC: 86.05%
# Epoch 43/100, Train ACC: 93.14%, Validation ACC: 85.47%
# Epoch 44/100, Train ACC: 92.61%, Validation ACC: 85.47%
# Epoch 45/100, Train ACC: 93.93%, Validation ACC: 86.63%
# Epoch 46/100, Train ACC: 93.67%, Validation ACC: 86.63%
# Epoch 47/100, Train ACC: 93.67%, Validation ACC: 86.05%
# Epoch 48/100, Train ACC: 91.29%, Validation ACC: 86.05%
# Epoch 49/100, Train ACC: 93.40%, Validation ACC: 86.05%
# Epoch 50/100, Train ACC: 91.82%, Validation ACC: 84.88%
# Epoch 51/100, Train ACC: 93.14%, Validation ACC: 86.05%
# Epoch 52/100, Train ACC: 93.14%, Validation ACC: 86.05%
# Epoch 53/100, Train ACC: 92.88%, Validation ACC: 86.05%
# Epoch 54/100, Train ACC: 88.92%, Validation ACC: 85.47%
# Epoch 55/100, Train ACC: 92.08%, Validation ACC: 86.05%
# Epoch 56/100, Train ACC: 92.35%, Validation ACC: 86.63%
# Epoch 57/100, Train ACC: 94.46%, Validation ACC: 86.05%
# Epoch 58/100, Train ACC: 92.88%, Validation ACC: 84.88%
# Epoch 59/100, Train ACC: 92.88%, Validation ACC: 85.47%
# Epoch 60/100, Train ACC: 92.88%, Validation ACC: 87.21%
# Epoch 61/100, Train ACC: 92.88%, Validation ACC: 86.05%
# Epoch 62/100, Train ACC: 91.82%, Validation ACC: 85.47%
# Epoch 63/100, Train ACC: 92.61%, Validation ACC: 86.63%
# Epoch 64/100, Train ACC: 94.46%, Validation ACC: 86.05%
# Epoch 65/100, Train ACC: 93.67%, Validation ACC: 86.05%
# Epoch 66/100, Train ACC: 92.61%, Validation ACC: 85.47%
# Epoch 67/100, Train ACC: 94.20%, Validation ACC: 85.47%
# Epoch 68/100, Train ACC: 92.61%, Validation ACC: 86.63%
# Epoch 69/100, Train ACC: 94.46%, Validation ACC: 86.05%
# Epoch 70/100, Train ACC: 93.93%, Validation ACC: 85.47%
# Epoch 71/100, Train ACC: 92.35%, Validation ACC: 86.05%
# Epoch 72/100, Train ACC: 92.08%, Validation ACC: 86.05%
# Epoch 73/100, Train ACC: 92.88%, Validation ACC: 86.05%
# Epoch 74/100, Train ACC: 94.72%, Validation ACC: 86.05%
# Epoch 75/100, Train ACC: 90.50%, Validation ACC: 86.63%
# Epoch 76/100, Train ACC: 93.67%, Validation ACC: 86.63%
# Epoch 77/100, Train ACC: 92.88%, Validation ACC: 85.47%
# Epoch 78/100, Train ACC: 93.67%, Validation ACC: 86.63%
# Epoch 79/100, Train ACC: 93.67%, Validation ACC: 86.63%
# Epoch 80/100, Train ACC: 93.40%, Validation ACC: 85.47%
# Epoch 81/100, Train ACC: 92.61%, Validation ACC: 86.05%
# Epoch 82/100, Train ACC: 91.56%, Validation ACC: 86.05%
# Epoch 83/100, Train ACC: 91.56%, Validation ACC: 86.63%
# Epoch 84/100, Train ACC: 92.61%, Validation ACC: 85.47%
# Epoch 85/100, Train ACC: 92.61%, Validation ACC: 84.88%
# Epoch 86/100, Train ACC: 91.82%, Validation ACC: 85.47%
# Epoch 87/100, Train ACC: 92.08%, Validation ACC: 86.63%
# Epoch 88/100, Train ACC: 95.78%, Validation ACC: 85.47%
# Epoch 89/100, Train ACC: 92.35%, Validation ACC: 85.47%
# Epoch 90/100, Train ACC: 93.67%, Validation ACC: 85.47%
# Epoch 91/100, Train ACC: 92.61%, Validation ACC: 85.47%
# Epoch 92/100, Train ACC: 91.56%, Validation ACC: 86.05%
# Epoch 93/100, Train ACC: 92.88%, Validation ACC: 86.05%
# Epoch 94/100, Train ACC: 93.93%, Validation ACC: 86.63%
# Epoch 95/100, Train ACC: 91.03%, Validation ACC: 86.05%
# Epoch 96/100, Train ACC: 93.93%, Validation ACC: 86.05%
# Epoch 97/100, Train ACC: 92.88%, Validation ACC: 85.47%
# Epoch 98/100, Train ACC: 93.40%, Validation ACC: 86.63%
# Epoch 99/100, Train ACC: 91.03%, Validation ACC: 86.63%
# Epoch 100/100, Train ACC: 92.35%, Validation ACC: 87.21%

# %%
model = res50
model.eval()
# 加载测试数据集
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomCsvDataset(csv_file=test_csv_file, transform=test_transform)

test_model(model, test_dataset)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90      3474
#            1       0.60      0.69      0.64       868
#
#     accuracy                           0.84      4342
#    macro avg       0.76      0.79      0.77      4342
# weighted avg       0.85      0.84      0.85      4342
# {'Total Acc': 0.845,
#  'nff Acc': 0.884,
#  'aff Acc': 0.689,
#  'AUC': 0.786,
#  'MCC': 0.544,
#  'F1 Score': 0.64}

# %% [markdown]
# # ResNet101

# %%
from torchvision.models import resnet101, ResNet101_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the ResNet-101 model
model = models.resnet101(weights=ResNet101_Weights.DEFAULT)

num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)


# layer number
total_layers = len(list(model.children()))

# freeze 50% layer
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False

# modify full connection layer
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)

# ---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 100
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

res101 = train_custom_model(model, train_dataset, val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/100, Train ACC: 48.55%, Validation ACC: 63.37%
# Epoch 2/100, Train ACC: 61.74%, Validation ACC: 74.42%
# Epoch 3/100, Train ACC: 73.88%, Validation ACC: 72.09%
# Epoch 4/100, Train ACC: 70.71%, Validation ACC: 68.60%
# Epoch 5/100, Train ACC: 70.98%, Validation ACC: 61.63%
# Epoch 6/100, Train ACC: 75.73%, Validation ACC: 67.44%
# Epoch 7/100, Train ACC: 83.38%, Validation ACC: 79.65%
# Epoch 8/100, Train ACC: 85.22%, Validation ACC: 84.88%
# Epoch 9/100, Train ACC: 88.65%, Validation ACC: 83.72%
# Epoch 10/100, Train ACC: 91.56%, Validation ACC: 86.05%
# Epoch 11/100, Train ACC: 91.03%, Validation ACC: 86.63%
# Epoch 12/100, Train ACC: 91.56%, Validation ACC: 87.21%
# Epoch 13/100, Train ACC: 91.82%, Validation ACC: 88.37%
# Epoch 14/100, Train ACC: 93.14%, Validation ACC: 88.37%
# Epoch 15/100, Train ACC: 94.46%, Validation ACC: 88.95%
# Epoch 16/100, Train ACC: 90.24%, Validation ACC: 89.53%
# Epoch 17/100, Train ACC: 93.40%, Validation ACC: 89.53%
# Epoch 18/100, Train ACC: 91.82%, Validation ACC: 88.95%
# Epoch 19/100, Train ACC: 91.82%, Validation ACC: 88.37%
# Epoch 20/100, Train ACC: 94.20%, Validation ACC: 88.95%
# Epoch 21/100, Train ACC: 93.14%, Validation ACC: 88.37%
# Epoch 22/100, Train ACC: 94.20%, Validation ACC: 88.37%
# Epoch 23/100, Train ACC: 92.35%, Validation ACC: 88.95%
# Epoch 24/100, Train ACC: 93.93%, Validation ACC: 88.37%
# Epoch 25/100, Train ACC: 92.08%, Validation ACC: 88.37%
# Epoch 26/100, Train ACC: 91.29%, Validation ACC: 87.79%
# Epoch 27/100, Train ACC: 95.78%, Validation ACC: 87.79%
# Epoch 28/100, Train ACC: 94.46%, Validation ACC: 87.79%
# Epoch 29/100, Train ACC: 94.72%, Validation ACC: 87.79%
# Epoch 30/100, Train ACC: 93.67%, Validation ACC: 88.37%
# Epoch 31/100, Train ACC: 94.46%, Validation ACC: 87.79%
# Epoch 32/100, Train ACC: 93.40%, Validation ACC: 87.21%
# Epoch 33/100, Train ACC: 94.72%, Validation ACC: 87.79%
# Epoch 34/100, Train ACC: 94.46%, Validation ACC: 87.21%
# Epoch 35/100, Train ACC: 94.20%, Validation ACC: 87.21%
# Epoch 36/100, Train ACC: 94.20%, Validation ACC: 87.79%
# Epoch 37/100, Train ACC: 93.67%, Validation ACC: 87.79%
# Epoch 38/100, Train ACC: 92.35%, Validation ACC: 87.79%
# Epoch 39/100, Train ACC: 95.25%, Validation ACC: 88.37%
# Epoch 40/100, Train ACC: 93.67%, Validation ACC: 87.79%
# Epoch 41/100, Train ACC: 94.72%, Validation ACC: 88.37%
# Epoch 42/100, Train ACC: 95.25%, Validation ACC: 88.37%
# Epoch 43/100, Train ACC: 96.04%, Validation ACC: 87.79%
# Epoch 44/100, Train ACC: 94.46%, Validation ACC: 88.37%
# Epoch 45/100, Train ACC: 94.72%, Validation ACC: 88.37%
# Epoch 46/100, Train ACC: 95.25%, Validation ACC: 88.95%
# Epoch 47/100, Train ACC: 93.93%, Validation ACC: 88.37%
# Epoch 48/100, Train ACC: 94.20%, Validation ACC: 87.79%
# Epoch 49/100, Train ACC: 92.08%, Validation ACC: 87.79%
# Epoch 50/100, Train ACC: 93.93%, Validation ACC: 87.21%
# Epoch 51/100, Train ACC: 94.20%, Validation ACC: 87.21%
# Epoch 52/100, Train ACC: 94.20%, Validation ACC: 87.21%
# Epoch 53/100, Train ACC: 94.72%, Validation ACC: 88.37%
# Epoch 54/100, Train ACC: 94.72%, Validation ACC: 87.21%
# Epoch 55/100, Train ACC: 93.93%, Validation ACC: 87.79%
# Epoch 56/100, Train ACC: 94.72%, Validation ACC: 87.21%
# Epoch 57/100, Train ACC: 93.40%, Validation ACC: 87.21%
# Epoch 58/100, Train ACC: 93.93%, Validation ACC: 87.21%
# Epoch 59/100, Train ACC: 94.72%, Validation ACC: 87.21%
# Epoch 60/100, Train ACC: 93.14%, Validation ACC: 88.37%
# Epoch 61/100, Train ACC: 93.14%, Validation ACC: 88.37%
# Epoch 62/100, Train ACC: 95.51%, Validation ACC: 88.37%
# Epoch 63/100, Train ACC: 93.93%, Validation ACC: 88.37%
# Epoch 64/100, Train ACC: 94.99%, Validation ACC: 88.37%
# Epoch 65/100, Train ACC: 94.46%, Validation ACC: 87.79%
# Epoch 66/100, Train ACC: 93.93%, Validation ACC: 87.79%
# Epoch 67/100, Train ACC: 94.46%, Validation ACC: 89.53%
# Epoch 68/100, Train ACC: 92.35%, Validation ACC: 88.37%
# Epoch 69/100, Train ACC: 94.46%, Validation ACC: 88.37%
# Epoch 70/100, Train ACC: 92.88%, Validation ACC: 88.95%
# Epoch 71/100, Train ACC: 94.46%, Validation ACC: 88.95%
# Epoch 72/100, Train ACC: 94.20%, Validation ACC: 88.95%
# Epoch 73/100, Train ACC: 94.46%, Validation ACC: 88.37%
# Epoch 74/100, Train ACC: 95.25%, Validation ACC: 87.21%
# Epoch 75/100, Train ACC: 93.40%, Validation ACC: 87.79%
# Epoch 76/100, Train ACC: 93.93%, Validation ACC: 87.79%
# Epoch 77/100, Train ACC: 94.72%, Validation ACC: 87.79%
# Epoch 78/100, Train ACC: 93.67%, Validation ACC: 88.95%
# Epoch 79/100, Train ACC: 95.51%, Validation ACC: 87.79%
# Epoch 80/100, Train ACC: 93.67%, Validation ACC: 87.79%
# Epoch 81/100, Train ACC: 93.93%, Validation ACC: 88.37%
# Epoch 82/100, Train ACC: 92.88%, Validation ACC: 87.79%
# Epoch 83/100, Train ACC: 94.99%, Validation ACC: 87.79%
# Epoch 84/100, Train ACC: 93.40%, Validation ACC: 87.79%
# Epoch 85/100, Train ACC: 93.40%, Validation ACC: 87.79%
# Epoch 86/100, Train ACC: 94.46%, Validation ACC: 89.53%
# Epoch 87/100, Train ACC: 95.25%, Validation ACC: 88.37%
# Epoch 88/100, Train ACC: 94.46%, Validation ACC: 87.79%
# Epoch 89/100, Train ACC: 94.99%, Validation ACC: 87.79%
# Epoch 90/100, Train ACC: 92.61%, Validation ACC: 87.79%
# Epoch 91/100, Train ACC: 95.78%, Validation ACC: 87.79%
# Epoch 92/100, Train ACC: 95.25%, Validation ACC: 87.21%
# Epoch 93/100, Train ACC: 92.61%, Validation ACC: 87.21%
# Epoch 94/100, Train ACC: 94.20%, Validation ACC: 87.21%
# Epoch 95/100, Train ACC: 92.08%, Validation ACC: 87.21%
# Epoch 96/100, Train ACC: 93.67%, Validation ACC: 87.21%
# Epoch 97/100, Train ACC: 94.99%, Validation ACC: 88.37%
# Epoch 98/100, Train ACC: 92.88%, Validation ACC: 87.79%
# Epoch 99/100, Train ACC: 92.08%, Validation ACC: 88.37%
# Epoch 100/100, Train ACC: 94.20%, Validation ACC: 87.79%

# %%
model = res101
model.eval()
# 加载测试数据集
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomCsvDataset(csv_file=test_csv_file, transform=test_transform)

test_model(model, test_dataset)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92      3474
#            1       0.70      0.65      0.67       868
#
#     accuracy                           0.87      4342
#    macro avg       0.80      0.79      0.80      4342
# weighted avg       0.87      0.87      0.87      4342
# {'Total Acc': 0.873,
#  'nff Acc': 0.929,
#  'aff Acc': 0.647,
#  'AUC': 0.788,
#  'MCC': 0.593,
#  'F1 Score': 0.671}

# %% [markdown]
# # DenseNet 161

# %%
from torchvision.models import densenet161, DenseNet161_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the DenseNet-161 model
model = models.densenet161(weights=DenseNet161_Weights.DEFAULT)

# Modify the classifier part of the model
num_features = model.classifier.in_features
model.classifier = nn.Linear(num_features, 2)

# total layers 
total_layers = len(list(model.features.children()))

# freeze 50% layers
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.features.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False
            
# ---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 100
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

dense161 = train_custom_model(model, train_dataset, val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/100, Train ACC: 58.05%, Validation ACC: 80.81%
# Epoch 2/100, Train ACC: 72.03%, Validation ACC: 77.91%
# Epoch 3/100, Train ACC: 79.42%, Validation ACC: 73.26%
# Epoch 4/100, Train ACC: 82.06%, Validation ACC: 84.88%
# Epoch 5/100, Train ACC: 88.13%, Validation ACC: 83.72%
# Epoch 6/100, Train ACC: 92.88%, Validation ACC: 86.05%
# Epoch 7/100, Train ACC: 92.88%, Validation ACC: 87.21%
# Epoch 8/100, Train ACC: 93.67%, Validation ACC: 88.95%
# Epoch 9/100, Train ACC: 96.57%, Validation ACC: 91.28%
# Epoch 10/100, Train ACC: 97.10%, Validation ACC: 88.37%
# Epoch 11/100, Train ACC: 97.63%, Validation ACC: 88.95%
# Epoch 12/100, Train ACC: 98.68%, Validation ACC: 88.95%
# Epoch 13/100, Train ACC: 97.36%, Validation ACC: 90.12%
# Epoch 14/100, Train ACC: 98.42%, Validation ACC: 89.53%
# Epoch 15/100, Train ACC: 98.15%, Validation ACC: 90.12%
# Epoch 16/100, Train ACC: 98.94%, Validation ACC: 89.53%
# Epoch 17/100, Train ACC: 99.21%, Validation ACC: 89.53%
# Epoch 18/100, Train ACC: 98.68%, Validation ACC: 89.53%
# Epoch 19/100, Train ACC: 98.68%, Validation ACC: 90.70%
# Epoch 20/100, Train ACC: 99.47%, Validation ACC: 90.12%
# Epoch 21/100, Train ACC: 98.68%, Validation ACC: 90.12%
# Epoch 22/100, Train ACC: 98.94%, Validation ACC: 89.53%
# Epoch 23/100, Train ACC: 98.15%, Validation ACC: 90.12%
# Epoch 24/100, Train ACC: 99.21%, Validation ACC: 89.53%
# Epoch 25/100, Train ACC: 98.15%, Validation ACC: 90.12%
# Epoch 26/100, Train ACC: 99.47%, Validation ACC: 90.12%
# Epoch 27/100, Train ACC: 97.63%, Validation ACC: 89.53%
# Epoch 28/100, Train ACC: 97.89%, Validation ACC: 89.53%
# Epoch 29/100, Train ACC: 98.94%, Validation ACC: 89.53%
# Epoch 30/100, Train ACC: 99.21%, Validation ACC: 89.53%
# Epoch 31/100, Train ACC: 97.10%, Validation ACC: 89.53%
# Epoch 32/100, Train ACC: 99.21%, Validation ACC: 90.12%
# Epoch 33/100, Train ACC: 99.21%, Validation ACC: 89.53%
# Epoch 34/100, Train ACC: 99.47%, Validation ACC: 89.53%
# Epoch 35/100, Train ACC: 100.00%, Validation ACC: 89.53%
# Epoch 36/100, Train ACC: 99.21%, Validation ACC: 89.53%
# Epoch 37/100, Train ACC: 98.68%, Validation ACC: 89.53%
# Epoch 38/100, Train ACC: 98.68%, Validation ACC: 89.53%
# Epoch 39/100, Train ACC: 98.42%, Validation ACC: 90.12%
# Epoch 40/100, Train ACC: 98.68%, Validation ACC: 90.12%
# Epoch 41/100, Train ACC: 99.47%, Validation ACC: 90.12%
# Epoch 42/100, Train ACC: 99.47%, Validation ACC: 90.12%
# Epoch 43/100, Train ACC: 98.68%, Validation ACC: 90.12%
# Epoch 44/100, Train ACC: 99.74%, Validation ACC: 89.53%
# Epoch 45/100, Train ACC: 98.42%, Validation ACC: 89.53%
# Epoch 46/100, Train ACC: 98.94%, Validation ACC: 89.53%
# Epoch 47/100, Train ACC: 97.89%, Validation ACC: 90.12%
# Epoch 48/100, Train ACC: 98.68%, Validation ACC: 90.12%
# Epoch 49/100, Train ACC: 96.83%, Validation ACC: 89.53%
# Epoch 50/100, Train ACC: 98.94%, Validation ACC: 88.95%
# Epoch 51/100, Train ACC: 98.94%, Validation ACC: 90.12%
# Epoch 52/100, Train ACC: 99.21%, Validation ACC: 89.53%
# Epoch 53/100, Train ACC: 98.94%, Validation ACC: 89.53%
# Epoch 54/100, Train ACC: 99.47%, Validation ACC: 89.53%
# Epoch 55/100, Train ACC: 98.42%, Validation ACC: 89.53%
# Epoch 56/100, Train ACC: 98.68%, Validation ACC: 89.53%
# Epoch 57/100, Train ACC: 98.42%, Validation ACC: 89.53%
# Epoch 58/100, Train ACC: 98.68%, Validation ACC: 88.37%
# Epoch 59/100, Train ACC: 98.94%, Validation ACC: 88.95%
# Epoch 60/100, Train ACC: 99.21%, Validation ACC: 90.12%
# Epoch 61/100, Train ACC: 99.21%, Validation ACC: 90.12%
# Epoch 62/100, Train ACC: 98.42%, Validation ACC: 89.53%
# Epoch 63/100, Train ACC: 98.68%, Validation ACC: 90.12%
# Epoch 64/100, Train ACC: 98.94%, Validation ACC: 89.53%
# Epoch 65/100, Train ACC: 97.89%, Validation ACC: 89.53%
# Epoch 66/100, Train ACC: 99.47%, Validation ACC: 90.12%
# Epoch 67/100, Train ACC: 99.47%, Validation ACC: 89.53%
# Epoch 68/100, Train ACC: 99.21%, Validation ACC: 89.53%
# Epoch 69/100, Train ACC: 99.47%, Validation ACC: 89.53%
# Epoch 70/100, Train ACC: 98.42%, Validation ACC: 89.53%
# Epoch 71/100, Train ACC: 99.47%, Validation ACC: 89.53%
# Epoch 72/100, Train ACC: 98.68%, Validation ACC: 89.53%
# Epoch 73/100, Train ACC: 99.21%, Validation ACC: 89.53%
# Epoch 74/100, Train ACC: 99.47%, Validation ACC: 90.12%
# Epoch 75/100, Train ACC: 97.89%, Validation ACC: 89.53%
# Epoch 76/100, Train ACC: 98.94%, Validation ACC: 90.12%
# Epoch 77/100, Train ACC: 97.10%, Validation ACC: 90.12%
# Epoch 78/100, Train ACC: 97.89%, Validation ACC: 90.12%
# Epoch 79/100, Train ACC: 98.94%, Validation ACC: 90.12%
# Epoch 80/100, Train ACC: 98.42%, Validation ACC: 89.53%
# Epoch 81/100, Train ACC: 98.42%, Validation ACC: 90.12%
# Epoch 82/100, Train ACC: 98.68%, Validation ACC: 89.53%
# Epoch 83/100, Train ACC: 98.42%, Validation ACC: 90.12%
# Epoch 84/100, Train ACC: 98.15%, Validation ACC: 90.70%
# Epoch 85/100, Train ACC: 98.94%, Validation ACC: 89.53%
# Epoch 86/100, Train ACC: 98.68%, Validation ACC: 89.53%
# Epoch 87/100, Train ACC: 99.21%, Validation ACC: 89.53%
# Epoch 88/100, Train ACC: 98.94%, Validation ACC: 90.12%
# Epoch 89/100, Train ACC: 98.94%, Validation ACC: 89.53%
# Epoch 90/100, Train ACC: 100.00%, Validation ACC: 89.53%
# Epoch 91/100, Train ACC: 98.42%, Validation ACC: 89.53%
# Epoch 92/100, Train ACC: 98.94%, Validation ACC: 89.53%
# Epoch 93/100, Train ACC: 97.63%, Validation ACC: 90.12%
# Epoch 94/100, Train ACC: 97.63%, Validation ACC: 89.53%
# Epoch 95/100, Train ACC: 98.94%, Validation ACC: 90.12%
# Epoch 96/100, Train ACC: 98.68%, Validation ACC: 90.12%
# Epoch 97/100, Train ACC: 98.68%, Validation ACC: 89.53%
# Epoch 98/100, Train ACC: 98.68%, Validation ACC: 89.53%
# Epoch 99/100, Train ACC: 97.63%, Validation ACC: 90.12%
# Epoch 100/100, Train ACC: 99.47%, Validation ACC: 89.53%

# %%
model = dense161
model.eval()
# 加载测试数据集
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomCsvDataset(csv_file=test_csv_file, transform=test_transform)

test_model(model, test_dataset)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93      3474
#            1       0.72      0.74      0.73       868
#
#     accuracy                           0.89      4342
#    macro avg       0.83      0.83      0.83      4342
# weighted avg       0.89      0.89      0.89      4342
# {'Total Acc': 0.891,
#  'nff Acc': 0.929,
#  'aff Acc': 0.737,
#  'AUC': 0.833,
#  'MCC': 0.662,
#  'F1 Score': 0.73}

# %% [markdown]
# # Efficient B2

# %%
# from torchvision.models import efficientnet_b2, EfficientNet_B2_Weights

# torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# # Define the EfficientNetV2-M model
# model = efficientnet_b2(weights=EfficientNet_B2_Weights.DEFAULT)

# # Access input features of the classifier
# num_features = model.classifier[1].in_features

# # Modify the classifier part of the model
# model.classifier[1] = nn.Linear(in_features=num_features, out_features=2)

# # Freeze certain layers
# total_layers = len(list(model.children()))
# freeze_layers = int(total_layers * 0.5)
# for index, child in enumerate(model.children()):
#     if index < freeze_layers:
#         for param in child.parameters():
#             param.requires_grad = False

# # Hyperparameters
# num_epochs = 20
# batch_size = 64
# learning_rate = 0.0001
# optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# # Move model to GPU if available
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# model = model.to(device)

# # Train the model
# effi_b2 = train_custom_model(model, train_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
