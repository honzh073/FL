# %% [markdown]
# # create data

# %%
# import pandas as pd

# df_hospital18 = pd.read_csv("/local/data1/honzh/local_repository/FL/code/2_local/hospital18.csv")
# df_hospital43 = pd.read_csv("/local/data1/honzh/local_repository/FL/code/2_local/hospital43.csv")
# df_hospital55 = pd.read_csv("/local/data1/honzh/local_repository/FL/code/2_local/hospital55.csv")


# df_combined = pd.concat([df_hospital18, df_hospital43, df_hospital55], ignore_index=True)

# df_combined.to_csv("/local/data1/honzh/local_repository/FL/code/3_centralized/this_centralized/centralized_data.csv", index=False)

# %%
# import pandas as pd
# from sklearn.model_selection import train_test_split

# # Load the original CSV file
# csv_file_path = "/local/data1/honzh/local_repository/FL/code/3_centralized/this_centralized/centralized_data.csv"
# df = pd.read_csv(csv_file_path)

# # Unique patient IDs
# unique_patient_ids = df['PatientID'].unique()

# # Split the patient IDs into training and validation sets
# train_patient_ids, val_patient_ids = train_test_split(unique_patient_ids, test_size=0.3, random_state=1)

# # Create subsets based on patient IDs
# train_data = df[df['PatientID'].isin(train_patient_ids)]
# val_data = df[df['PatientID'].isin(val_patient_ids)]

# # Save the subsets to separate CSV files if needed
# train_data.to_csv("/local/data1/honzh/local_repository/FL/code/3_centralized/this_centralized/centralized_train.csv", index=False)
# val_data.to_csv("/local/data1/honzh/local_repository/FL/code/3_centralized/this_centralized/centralized_val.csv", index=False)

# %%
# import json
# import os
# import pandas as pd

# # Function to read data from JSON file
# def read_json_file(file_path):
#     with open(file_path, 'r') as file:
#         data = json.load(file)
#     return data

# # Function to create CSV file
# def create_csv_file(output_path, data):
#     df = pd.DataFrame(data)
#     df.to_csv(output_path, index=False)

# # Paths to JSON files
# json_file_paths = [
#     '/local/data1/honzh/local_repository/FL/code/1_create_data/data1/hospital18_1.json',
#     '/local/data1/honzh/local_repository/FL/code/1_create_data/data1/hospital22_1.json',
#     '/local/data1/honzh/local_repository/FL/code/1_create_data/data1/hospital43_1.json',
#     '/local/data1/honzh/local_repository/FL/code/1_create_data/data1/hospital45_1.json',
#     '/local/data1/honzh/local_repository/FL/code/1_create_data/data1/hospital55_1.json'
# ]

# # Output CSV file paths
# output_csv_paths = [
#     '/local/data1/honzh/local_repository/FL/code/3_centralized/csv_files/5node_train.csv',
#     '/local/data1/honzh/local_repository/FL/code/3_centralized/csv_files/5node_val.csv'
# ]

# # Read data from JSON files and create CSV files
# combined_train_data = []
# combined_val_data = []

# for json_path in json_file_paths:
#     json_data = read_json_file(json_path)
#     combined_train_data.extend(json_data.get('train', []))
#     combined_val_data.extend(json_data.get('val', []))

# # Create CSV files
# create_csv_file(output_csv_paths[0], combined_train_data)
# create_csv_file(output_csv_paths[1], combined_val_data)

# # Display success message
# print("CSV files created.")

# %%
from torch.utils.data import Dataset
from PIL import Image
import csv
from torchvision import transforms
import torch
import numpy as np
import matplotlib.pyplot as plt

  
class CustomDataset(Dataset):
    def __init__(self, csv_file, transform=None):
        self.data = []
        self.labels = []
        self.patient_ids = []
        self.transform = transform
        
        with open(csv_file, 'r') as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                image_path = row['ImagePath']
                label = row['Label']
                patient_id = row['PatientID']
                
                if label == 'NFF':
                    label = 0
                elif label == 'AFF':
                    label = 1
                else:
                    raise ValueError("Invalid label in CSV file.")
                
                self.data.append((image_path, label))
                self.labels.append(label)
                self.patient_ids.append(patient_id)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image_path, label = self.data[idx]
        image = Image.open(image_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image, label

# show x ray image
def show_image(dataset, num_images=5):
    random_indices = np.random.choice(len(dataset), num_images, replace=False)
    
    plt.figure(figsize=(15, 5))
    for i, idx in enumerate(random_indices):
        image, label = dataset[idx]
        filename = dataset.data[idx][0]
        truncated_filename = filename.split('/')[-1][:15]
        
        print(f"Image location: {filename}")

        plt.subplot(1, num_images, i + 1)
        plt.title(f"Label: {label}")
        plt.imshow(image[0])
        plt.axis('off')
    plt.show()

# model parameters number
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# calculate class weight
def get_class_weight(train_dataset):
    train_nff_count = sum(1 for _, label in train_dataset if label == 0)
    train_aff_count = sum(1 for _, label in train_dataset if label == 1)
    class_weight_nff = 1 / (2 * (train_nff_count / (train_nff_count + train_aff_count)))
    class_weight_aff = 1 / (2 * (train_aff_count / (train_nff_count + train_aff_count)))
    
    
    return [class_weight_nff, class_weight_aff]

# %% [markdown]
# # smooth accuracy loss mcc

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import matthews_corrcoef

import random

# Set random seed
seed = 1
torch.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)

# CUDA seed 
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

def smooth_curve(points, factor=0.8):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points

# train function with early stopping
def train_custom_model(model, train_dataset, val_dataset, num_epochs, batch_size, optimizer):
    # patience = 40  # early stopping
    classweight = get_class_weight(train_dataset)
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    criterion = nn.CrossEntropyLoss(weight=torch.Tensor(classweight).to(device))

    train_loader = DataLoader(train_dataset, batch_size=batch_size,shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    # Create a learning rate scheduler
    lr_scheduler_step = 10  # Adjust this value based on your requirement
    scheduler = lr_scheduler.StepLR(optimizer, step_size=lr_scheduler_step, gamma=0.1)

    best_acc = 0  # Initialize best accuracy value  # Change here
    best_model = None

    # consecutive_no_improvement = 0  # Counter for consecutive epochs without improvement

    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []
    train_mccs = []  # List to store MCC values for each epoch
    val_mccs = []  # List to store MCC values for each epoch

    for epoch in range(num_epochs):
        model.train()
        correct_train = 0
        total_train = 0
        train_loss = 0

        all_train_labels = []  # List to store labels for the entire training set
        all_train_predictions = []  # List to store predictions for the entire training set

        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
            train_loss += loss.item()

            all_train_labels.extend(labels.cpu().numpy())
            all_train_predictions.extend(predicted.cpu().numpy())

        train_accuracy = correct_train / total_train
        train_loss /= len(train_loader)

        # Calculate MCC for training set
        train_mcc = matthews_corrcoef(all_train_labels, all_train_predictions)

        model.eval()
        correct_validation = 0
        total_validation = 0
        validation_loss = 0

        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)

                _, predicted = torch.max(outputs.data, 1)
                total_validation += labels.size(0)
                correct_validation += (predicted == labels).sum().item()
                validation_loss += loss.item()

            validation_accuracy = correct_validation / total_validation
            validation_loss /= len(val_loader)

            # Calculate MCC for validation set
            all_val_labels = []  # List to store labels for the entire validation set
            all_val_predictions = []  # List to store predictions for the entire validation set
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                outputs = model(images)
                _, predicted = torch.max(outputs.data, 1)
                all_val_labels.extend(labels.cpu().numpy())
                all_val_predictions.extend(predicted.cpu().numpy())

            val_mcc = matthews_corrcoef(all_val_labels, all_val_predictions)

            print(f"Epoch {epoch + 1}/{num_epochs}, "
                  f"Train Loss: {train_loss:.4f}, Train ACC: {train_accuracy:.2f}%, Train MCC: {train_mcc:.4f}, "
                  f"Val Loss: {validation_loss:.4f}, Val ACC: {validation_accuracy:.2f}, Val MCC: {val_mcc:.4f}")

            # Early stopping check
            if validation_accuracy > best_acc:  # Change here
                best_acc = validation_accuracy  # Change here
                # Save the best model
                best_model = model
                
            # early stopping 
            # if consecutive_no_improvement >= patience:
            #     print(f"No improvement in MCC for {patience} consecutive epochs. Early stopping.")
            #     break

        # Append metrics for plotting
        train_losses.append(train_loss)
        val_losses.append(validation_loss)
        train_accuracies.append(train_accuracy)
        val_accuracies.append(validation_accuracy)
        train_mccs.append(train_mcc)
        val_mccs.append(val_mcc)

        # Step the learning rate scheduler
        scheduler.step()

    # Plotting with smoothing and original curves
    plt.figure(figsize=(15, 5))

    # Plotting Loss
    plt.subplot(1, 3, 1)
    plt.plot(range(1, len(train_losses) + 1), smooth_curve(train_losses), label='Train Loss(smoothed)', color='blue')
    plt.plot(range(1, len(val_losses) + 1), smooth_curve(val_losses), label='Validation Loss (smoothed)', color='orange')
    plt.plot(range(1, len(train_losses) + 1), train_losses, linestyle='dashed', label='Train Loss', color='lightblue')
    plt.plot(range(1, len(val_losses) + 1), val_losses, linestyle='dashed', label='Validation Loss', color='navajowhite')
    plt.xlabel('Epoch', fontsize = 15)
    plt.ylabel('Loss', fontsize = 15)
    plt.ylim(0, 1)  # Set Y-axis limits
    plt.legend()

    # Plotting Accuracy
    plt.subplot(1, 3, 2)
    plt.plot(range(1, len(train_accuracies) + 1), smooth_curve(train_accuracies), label='Train Accuracy (smoothed)', color='green')
    plt.plot(range(1, len(val_accuracies) + 1), smooth_curve(val_accuracies), label='Validation Accuracy (smoothed)', color='red')
    plt.plot(range(1, len(train_accuracies) + 1), train_accuracies, linestyle='dashed', label='Train Accuracy', color='lightgreen')
    plt.plot(range(1, len(val_accuracies) + 1), val_accuracies, linestyle='dashed', label='Validation Accuracy', color='lightcoral')
    plt.xlabel('Epoch', fontsize = 15)
    plt.ylabel('Accuracy', fontsize = 15)
    plt.ylim(0, 1)  # Set Y-axis limits
    plt.legend()

    # Plotting MCC
    plt.subplot(1, 3, 3)
    plt.plot(range(1, len(train_mccs) + 1), smooth_curve(train_mccs), label='Train MCC (smoothed)', color='purple')
    plt.plot(range(1, len(val_mccs) + 1), smooth_curve(val_mccs), label='Validation MCC (smoothed)', color='black')
    plt.plot(range(1, len(train_mccs) + 1), train_mccs, linestyle='dashed', label='Train MCC', color='plum')
    plt.plot(range(1, len(val_mccs) + 1), val_mccs, linestyle='dashed', label='Validation MCC', color='grey')
    plt.xlabel('Epoch', fontsize = 15)
    plt.ylabel('MCC', fontsize = 15)
    plt.ylim(0, 1)  # Set Y-axis limits
    plt.legend()

    plt.tight_layout()
    plt.show()

    return best_model  # Return the model with the best MCC

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import matthews_corrcoef, f1_score
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, average_precision_score, precision_score, recall_score, accuracy_score
import torchvision.transforms as transforms
import random

def test_model(model, test_dataset):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, pin_memory=True)
    model = model.to(device)

    model.eval()

    correct_test_nff = 0
    correct_test_aff = 0
    total_nff = 0
    total_aff = 0
    total_test = 0
    test_loss = 0

    criterion = nn.CrossEntropyLoss()

    with torch.no_grad():
        all_predictions = []
        all_labels = []
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            _, predicted = torch.max(outputs.data, 1)
            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            total_test += labels.size(0)
            total_nff += (labels == 0).sum().item()
            total_aff += (labels == 1).sum().item()
            correct_test_nff += ((predicted == labels) & (labels == 0)).sum().item()
            correct_test_aff += ((predicted == labels) & (labels == 1)).sum().item()
            test_loss += loss.item()

    # Check if total_aff is zero before performing the division
    test_accuracy_nff = correct_test_nff / total_nff if total_nff != 0 else 0
    test_accuracy_aff = correct_test_aff / total_aff if total_aff != 0 else 0
    test_accuracy_total = (correct_test_nff + correct_test_aff) / total_test
    test_loss /= len(test_loader)

    conf_matrix = confusion_matrix(all_labels, all_predictions)

    # Directly use class labels as strings in target_names
    target_names = ['NFF', 'AFF']

    classification_rep = classification_report(all_labels, all_predictions)

    # Calculate AUC
    auc_score = roc_auc_score(all_labels, all_predictions)

    # Calculate Matthew's correlation coefficient
    mcc_score = matthews_corrcoef(all_labels, all_predictions)

    # Calculate F1 score
    f1_score_value = f1_score(all_labels, all_predictions)

    # Calculate Precision, Recall, Accuracy, ROC-AUC, and PRC-AUC
    precision_value = precision_score(all_labels, all_predictions)
    recall_value = recall_score(all_labels, all_predictions)
    accuracy_value = accuracy_score(all_labels, all_predictions)
    roc_auc_value = roc_auc_score(all_labels, all_predictions)
    prc_auc_value = average_precision_score(all_labels, all_predictions)

    # Store metrics in a dictionary
    metrics = {
        "Total Acc": round(test_accuracy_total, 3),
        "nff Acc": round(test_accuracy_nff, 3),
        "aff Acc": round(test_accuracy_aff, 3),
        "Precision": round(precision_value, 3),
        "Recall": round(recall_value, 3),
        "Accuracy": round(accuracy_value, 3),
        "AUC": round(auc_score, 3),
        "MCC": round(mcc_score, 3),
        "F1 Score": round(f1_score_value, 3),
        "ROC_AUC": round(roc_auc_value, 3),
        "PRC-AUC": round(prc_auc_value, 3)
    }

    # Confusion Matrix
    plt.figure(figsize=(6, 4))
    sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=target_names, yticklabels=target_names)
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()

    # Classification Report
    print("Classification Report:")
    print(classification_rep)

    # Print all metrics
    # for metric_name, metric_value in metrics.items():
    #     print(f"{metric_name}: {metric_value}")

    return metrics

# %%
# Image transformations
train_transforms = transforms.Compose([
    transforms.RandomRotation(degrees=30),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.GaussianBlur(kernel_size=3),
    transforms.RandomEqualize(),
    transforms.RandomAdjustSharpness(sharpness_factor=5),
    # transforms.RandomPerspective(distortion_scale=0.6),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

val_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load datasets
train_dataset = CustomDataset('/local/data1/honzh/local_repository/FL/code/3_centralized/csv_files/5node_train.csv', transform=train_transforms)
val_dataset = CustomDataset('/local/data1/honzh/local_repository/FL/code/3_centralized/csv_files/5node_val.csv', transform=val_transforms)
class_weights = get_class_weight(train_dataset)
print('Training class weights:', class_weights)

# Show images
show_image(train_dataset, 5)

# Calculate numbers
print('-----------------------------------')
train_NFF_count = sum(1 for _, label in train_dataset if label == 0)
train_AFF_count = sum(1 for _, label in train_dataset if label == 1)

print(f"train AFF: {train_AFF_count}, ratio: {train_AFF_count / (train_AFF_count + train_NFF_count):.2f}")
print(f"----- NFF: {train_NFF_count}, ratio: {train_NFF_count / (train_AFF_count + train_NFF_count):.2f}")

print('-----------------------------------')
train_NFF_count = sum(1 for _, label in val_dataset if label == 0)
train_AFF_count = sum(1 for _, label in val_dataset if label == 1)

print(f"val AFF: {train_AFF_count}, ratio: {train_AFF_count / (train_AFF_count + train_NFF_count):.2f}")
print(f"----- NFF: {train_NFF_count}, ratio: {train_NFF_count / (train_AFF_count + train_NFF_count):.2f}")
# Out:
# Training class weights: [0.7015706806282722, 1.7402597402597402]
# Image location: /local/data1/honzh/data/8bit_down224/patient_MDONJWILGU_hospital_45_NFF_image_6.png
# Image location: /local/data1/honzh/data/8bit_down224/patient_BTRPFSSIAV_hospital_55_NFF_image_5.png
# Image location: /local/data1/honzh/data/8bit_down224/patient_NYQYGRHRSB_hospital_43_NFF_image_2.png
# Image location: /local/data1/honzh/data/8bit_down224/patient_YCCDEQOBYS_hospital_43_NFF_image_3.png
# Image location: /local/data1/honzh/data/8bit_down224/patient_XWSXMJCZWA_hospital_43_NFF_image_2.png
# -----------------------------------
# train AFF: 154, ratio: 0.29
# ----- NFF: 382, ratio: 0.71
# -----------------------------------
# val AFF: 69, ratio: 0.30
# ----- NFF: 164, ratio: 0.70

# %% [markdown]
# # VGG 19

# %%
from torchvision.models import vgg19, VGG19_Weights
from torchvision import transforms, models

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the VGG-19 model
model = models.vgg19(weights=VGG19_Weights.DEFAULT)

# Modify the classifier part of the model
num_features = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_features, 2)

# layer number
total_layers = len(list(model.features.children()))

# freeze 50% layer
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.features.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False
# ---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 200
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

vgg19 = train_custom_model(model, train_dataset, val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/200, Train Loss: 0.7153, Train ACC: 0.56%, Train MCC: 0.0534, Val Loss: 0.6761, Val ACC: 0.72, Val MCC: 0.2898
# Epoch 2/200, Train Loss: 0.6421, Train ACC: 0.62%, Train MCC: 0.2469, Val Loss: 0.6911, Val ACC: 0.52, Val MCC: 0.2107
# Epoch 3/200, Train Loss: 0.5923, Train ACC: 0.68%, Train MCC: 0.3396, Val Loss: 0.6156, Val ACC: 0.69, Val MCC: 0.4202
# Epoch 4/200, Train Loss: 0.5207, Train ACC: 0.74%, Train MCC: 0.4365, Val Loss: 0.6729, Val ACC: 0.82, Val MCC: 0.5396
# Epoch 5/200, Train Loss: 0.4607, Train ACC: 0.79%, Train MCC: 0.5256, Val Loss: 0.6853, Val ACC: 0.83, Val MCC: 0.5638
# Epoch 6/200, Train Loss: 0.4372, Train ACC: 0.84%, Train MCC: 0.6127, Val Loss: 0.4683, Val ACC: 0.78, Val MCC: 0.5645
# Epoch 7/200, Train Loss: 0.4243, Train ACC: 0.85%, Train MCC: 0.6212, Val Loss: 0.5688, Val ACC: 0.85, Val MCC: 0.6352
# Epoch 8/200, Train Loss: 0.3435, Train ACC: 0.85%, Train MCC: 0.6532, Val Loss: 0.7343, Val ACC: 0.83, Val MCC: 0.5641
# Epoch 9/200, Train Loss: 0.2926, Train ACC: 0.89%, Train MCC: 0.7339, Val Loss: 0.5316, Val ACC: 0.81, Val MCC: 0.5635
# Epoch 10/200, Train Loss: 0.3733, Train ACC: 0.83%, Train MCC: 0.6465, Val Loss: 0.5454, Val ACC: 0.81, Val MCC: 0.5592
# Epoch 11/200, Train Loss: 0.3301, Train ACC: 0.90%, Train MCC: 0.7493, Val Loss: 0.5644, Val ACC: 0.82, Val MCC: 0.5519
# Epoch 12/200, Train Loss: 0.3243, Train ACC: 0.89%, Train MCC: 0.7364, Val Loss: 0.5556, Val ACC: 0.81, Val MCC: 0.5592
# Epoch 13/200, Train Loss: 0.2717, Train ACC: 0.88%, Train MCC: 0.7262, Val Loss: 0.5761, Val ACC: 0.82, Val MCC: 0.5671
# Epoch 14/200, Train Loss: 0.2447, Train ACC: 0.90%, Train MCC: 0.7764, Val Loss: 0.6464, Val ACC: 0.84, Val MCC: 0.5974
# Epoch 15/200, Train Loss: 0.2254, Train ACC: 0.92%, Train MCC: 0.8021, Val Loss: 0.6038, Val ACC: 0.81, Val MCC: 0.5348
# Epoch 16/200, Train Loss: 0.2118, Train ACC: 0.90%, Train MCC: 0.7794, Val Loss: 0.6192, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 17/200, Train Loss: 0.1863, Train ACC: 0.93%, Train MCC: 0.8260, Val Loss: 0.6633, Val ACC: 0.83, Val MCC: 0.5712
# Epoch 18/200, Train Loss: 0.2412, Train ACC: 0.90%, Train MCC: 0.7672, Val Loss: 0.6203, Val ACC: 0.82, Val MCC: 0.5641
# Epoch 19/200, Train Loss: 0.2322, Train ACC: 0.92%, Train MCC: 0.8121, Val Loss: 0.6229, Val ACC: 0.82, Val MCC: 0.5696
# Epoch 20/200, Train Loss: 0.1626, Train ACC: 0.92%, Train MCC: 0.8203, Val Loss: 0.6318, Val ACC: 0.82, Val MCC: 0.5696
# Epoch 21/200, Train Loss: 0.1896, Train ACC: 0.94%, Train MCC: 0.8538, Val Loss: 0.6235, Val ACC: 0.82, Val MCC: 0.5607
# Epoch 22/200, Train Loss: 0.1711, Train ACC: 0.93%, Train MCC: 0.8328, Val Loss: 0.6282, Val ACC: 0.82, Val MCC: 0.5696
# Epoch 23/200, Train Loss: 0.1945, Train ACC: 0.92%, Train MCC: 0.8192, Val Loss: 0.6332, Val ACC: 0.82, Val MCC: 0.5696
# Epoch 24/200, Train Loss: 0.1801, Train ACC: 0.95%, Train MCC: 0.8726, Val Loss: 0.6460, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 25/200, Train Loss: 0.2029, Train ACC: 0.90%, Train MCC: 0.7707, Val Loss: 0.6572, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 26/200, Train Loss: 0.1558, Train ACC: 0.94%, Train MCC: 0.8707, Val Loss: 0.6665, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 27/200, Train Loss: 0.1887, Train ACC: 0.93%, Train MCC: 0.8242, Val Loss: 0.6676, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 28/200, Train Loss: 0.2021, Train ACC: 0.94%, Train MCC: 0.8529, Val Loss: 0.6719, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 29/200, Train Loss: 0.1737, Train ACC: 0.93%, Train MCC: 0.8304, Val Loss: 0.6719, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 30/200, Train Loss: 0.1769, Train ACC: 0.93%, Train MCC: 0.8320, Val Loss: 0.6757, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 31/200, Train Loss: 0.1973, Train ACC: 0.93%, Train MCC: 0.8292, Val Loss: 0.6760, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 32/200, Train Loss: 0.1508, Train ACC: 0.94%, Train MCC: 0.8538, Val Loss: 0.6744, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 33/200, Train Loss: 0.1646, Train ACC: 0.93%, Train MCC: 0.8350, Val Loss: 0.6740, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 34/200, Train Loss: 0.1778, Train ACC: 0.93%, Train MCC: 0.8454, Val Loss: 0.6733, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 35/200, Train Loss: 0.1756, Train ACC: 0.93%, Train MCC: 0.8381, Val Loss: 0.6731, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 36/200, Train Loss: 0.1550, Train ACC: 0.94%, Train MCC: 0.8529, Val Loss: 0.6735, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 37/200, Train Loss: 0.1846, Train ACC: 0.93%, Train MCC: 0.8355, Val Loss: 0.6743, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 38/200, Train Loss: 0.1757, Train ACC: 0.92%, Train MCC: 0.8166, Val Loss: 0.6753, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 39/200, Train Loss: 0.1572, Train ACC: 0.94%, Train MCC: 0.8480, Val Loss: 0.6760, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 40/200, Train Loss: 0.1414, Train ACC: 0.95%, Train MCC: 0.8742, Val Loss: 0.6762, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 41/200, Train Loss: 0.1576, Train ACC: 0.94%, Train MCC: 0.8548, Val Loss: 0.6763, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 42/200, Train Loss: 0.1716, Train ACC: 0.95%, Train MCC: 0.8826, Val Loss: 0.6763, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 43/200, Train Loss: 0.1764, Train ACC: 0.93%, Train MCC: 0.8400, Val Loss: 0.6762, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 44/200, Train Loss: 0.1673, Train ACC: 0.95%, Train MCC: 0.8742, Val Loss: 0.6760, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 45/200, Train Loss: 0.2218, Train ACC: 0.92%, Train MCC: 0.8144, Val Loss: 0.6757, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 46/200, Train Loss: 0.1587, Train ACC: 0.94%, Train MCC: 0.8508, Val Loss: 0.6754, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 47/200, Train Loss: 0.1640, Train ACC: 0.93%, Train MCC: 0.8281, Val Loss: 0.6753, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 48/200, Train Loss: 0.1639, Train ACC: 0.92%, Train MCC: 0.8026, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 49/200, Train Loss: 0.1812, Train ACC: 0.93%, Train MCC: 0.8211, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 50/200, Train Loss: 0.1336, Train ACC: 0.94%, Train MCC: 0.8498, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 51/200, Train Loss: 0.1669, Train ACC: 0.94%, Train MCC: 0.8498, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 52/200, Train Loss: 0.1749, Train ACC: 0.93%, Train MCC: 0.8430, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 53/200, Train Loss: 0.1714, Train ACC: 0.94%, Train MCC: 0.8603, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 54/200, Train Loss: 0.1554, Train ACC: 0.95%, Train MCC: 0.8717, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 55/200, Train Loss: 0.1760, Train ACC: 0.94%, Train MCC: 0.8548, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 56/200, Train Loss: 0.1453, Train ACC: 0.94%, Train MCC: 0.8696, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 57/200, Train Loss: 0.1860, Train ACC: 0.93%, Train MCC: 0.8310, Val Loss: 0.6753, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 58/200, Train Loss: 0.2074, Train ACC: 0.91%, Train MCC: 0.7975, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 59/200, Train Loss: 0.1686, Train ACC: 0.94%, Train MCC: 0.8603, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 60/200, Train Loss: 0.1592, Train ACC: 0.93%, Train MCC: 0.8480, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 61/200, Train Loss: 0.1730, Train ACC: 0.93%, Train MCC: 0.8260, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 62/200, Train Loss: 0.1818, Train ACC: 0.93%, Train MCC: 0.8221, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 63/200, Train Loss: 0.1762, Train ACC: 0.93%, Train MCC: 0.8420, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 64/200, Train Loss: 0.1601, Train ACC: 0.94%, Train MCC: 0.8570, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 65/200, Train Loss: 0.1728, Train ACC: 0.94%, Train MCC: 0.8498, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 66/200, Train Loss: 0.1578, Train ACC: 0.94%, Train MCC: 0.8652, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 67/200, Train Loss: 0.1466, Train ACC: 0.95%, Train MCC: 0.8717, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 68/200, Train Loss: 0.1612, Train ACC: 0.94%, Train MCC: 0.8668, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 69/200, Train Loss: 0.1868, Train ACC: 0.93%, Train MCC: 0.8242, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 70/200, Train Loss: 0.1973, Train ACC: 0.93%, Train MCC: 0.8242, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 71/200, Train Loss: 0.1884, Train ACC: 0.92%, Train MCC: 0.8126, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 72/200, Train Loss: 0.1528, Train ACC: 0.93%, Train MCC: 0.8281, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 73/200, Train Loss: 0.1692, Train ACC: 0.93%, Train MCC: 0.8459, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 74/200, Train Loss: 0.1563, Train ACC: 0.95%, Train MCC: 0.8717, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 75/200, Train Loss: 0.1737, Train ACC: 0.93%, Train MCC: 0.8242, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 76/200, Train Loss: 0.2359, Train ACC: 0.91%, Train MCC: 0.7902, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 77/200, Train Loss: 0.1842, Train ACC: 0.94%, Train MCC: 0.8548, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 78/200, Train Loss: 0.1682, Train ACC: 0.94%, Train MCC: 0.8668, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 79/200, Train Loss: 0.1687, Train ACC: 0.92%, Train MCC: 0.8215, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 80/200, Train Loss: 0.1576, Train ACC: 0.95%, Train MCC: 0.8687, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 81/200, Train Loss: 0.1420, Train ACC: 0.96%, Train MCC: 0.9002, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 82/200, Train Loss: 0.1596, Train ACC: 0.93%, Train MCC: 0.8469, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 83/200, Train Loss: 0.1889, Train ACC: 0.91%, Train MCC: 0.7975, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 84/200, Train Loss: 0.1495, Train ACC: 0.94%, Train MCC: 0.8686, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 85/200, Train Loss: 0.1665, Train ACC: 0.93%, Train MCC: 0.8315, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 86/200, Train Loss: 0.1735, Train ACC: 0.94%, Train MCC: 0.8519, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 87/200, Train Loss: 0.1972, Train ACC: 0.93%, Train MCC: 0.8231, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 88/200, Train Loss: 0.1539, Train ACC: 0.94%, Train MCC: 0.8530, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 89/200, Train Loss: 0.1647, Train ACC: 0.93%, Train MCC: 0.8459, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 90/200, Train Loss: 0.1561, Train ACC: 0.94%, Train MCC: 0.8489, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 91/200, Train Loss: 0.1528, Train ACC: 0.94%, Train MCC: 0.8548, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 92/200, Train Loss: 0.1840, Train ACC: 0.93%, Train MCC: 0.8310, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 93/200, Train Loss: 0.1844, Train ACC: 0.93%, Train MCC: 0.8325, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 94/200, Train Loss: 0.1841, Train ACC: 0.93%, Train MCC: 0.8320, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 95/200, Train Loss: 0.1709, Train ACC: 0.94%, Train MCC: 0.8555, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 96/200, Train Loss: 0.1970, Train ACC: 0.92%, Train MCC: 0.8165, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 97/200, Train Loss: 0.1543, Train ACC: 0.93%, Train MCC: 0.8400, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 98/200, Train Loss: 0.1883, Train ACC: 0.94%, Train MCC: 0.8480, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 99/200, Train Loss: 0.1940, Train ACC: 0.93%, Train MCC: 0.8400, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 100/200, Train Loss: 0.1961, Train ACC: 0.93%, Train MCC: 0.8185, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 101/200, Train Loss: 0.1770, Train ACC: 0.93%, Train MCC: 0.8409, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 102/200, Train Loss: 0.1647, Train ACC: 0.94%, Train MCC: 0.8508, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 103/200, Train Loss: 0.1833, Train ACC: 0.93%, Train MCC: 0.8281, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 104/200, Train Loss: 0.1794, Train ACC: 0.93%, Train MCC: 0.8303, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 105/200, Train Loss: 0.1679, Train ACC: 0.94%, Train MCC: 0.8611, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 106/200, Train Loss: 0.1647, Train ACC: 0.93%, Train MCC: 0.8404, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 107/200, Train Loss: 0.1521, Train ACC: 0.94%, Train MCC: 0.8603, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 108/200, Train Loss: 0.1894, Train ACC: 0.93%, Train MCC: 0.8202, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 109/200, Train Loss: 0.1576, Train ACC: 0.94%, Train MCC: 0.8498, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 110/200, Train Loss: 0.1730, Train ACC: 0.94%, Train MCC: 0.8570, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 111/200, Train Loss: 0.1891, Train ACC: 0.93%, Train MCC: 0.8454, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 112/200, Train Loss: 0.1477, Train ACC: 0.95%, Train MCC: 0.8839, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 113/200, Train Loss: 0.1861, Train ACC: 0.93%, Train MCC: 0.8420, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 114/200, Train Loss: 0.1412, Train ACC: 0.95%, Train MCC: 0.8864, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 115/200, Train Loss: 0.1763, Train ACC: 0.95%, Train MCC: 0.8874, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 116/200, Train Loss: 0.1354, Train ACC: 0.95%, Train MCC: 0.8868, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 117/200, Train Loss: 0.1459, Train ACC: 0.95%, Train MCC: 0.8746, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 118/200, Train Loss: 0.1594, Train ACC: 0.94%, Train MCC: 0.8588, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 119/200, Train Loss: 0.2146, Train ACC: 0.93%, Train MCC: 0.8310, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 120/200, Train Loss: 0.1884, Train ACC: 0.93%, Train MCC: 0.8231, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 121/200, Train Loss: 0.1542, Train ACC: 0.93%, Train MCC: 0.8360, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 122/200, Train Loss: 0.1603, Train ACC: 0.93%, Train MCC: 0.8253, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 123/200, Train Loss: 0.1400, Train ACC: 0.95%, Train MCC: 0.8735, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 124/200, Train Loss: 0.1877, Train ACC: 0.92%, Train MCC: 0.8192, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 125/200, Train Loss: 0.1792, Train ACC: 0.93%, Train MCC: 0.8353, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 126/200, Train Loss: 0.1801, Train ACC: 0.93%, Train MCC: 0.8459, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 127/200, Train Loss: 0.1518, Train ACC: 0.95%, Train MCC: 0.8701, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 128/200, Train Loss: 0.1676, Train ACC: 0.93%, Train MCC: 0.8449, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 129/200, Train Loss: 0.1690, Train ACC: 0.94%, Train MCC: 0.8630, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 130/200, Train Loss: 0.1641, Train ACC: 0.95%, Train MCC: 0.8815, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 131/200, Train Loss: 0.1926, Train ACC: 0.95%, Train MCC: 0.8687, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 132/200, Train Loss: 0.1806, Train ACC: 0.93%, Train MCC: 0.8360, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 133/200, Train Loss: 0.1803, Train ACC: 0.92%, Train MCC: 0.8171, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 134/200, Train Loss: 0.2005, Train ACC: 0.92%, Train MCC: 0.8089, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 135/200, Train Loss: 0.1757, Train ACC: 0.94%, Train MCC: 0.8558, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 136/200, Train Loss: 0.1888, Train ACC: 0.92%, Train MCC: 0.8142, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 137/200, Train Loss: 0.1779, Train ACC: 0.93%, Train MCC: 0.8333, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 138/200, Train Loss: 0.1797, Train ACC: 0.94%, Train MCC: 0.8538, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 139/200, Train Loss: 0.1786, Train ACC: 0.94%, Train MCC: 0.8578, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 140/200, Train Loss: 0.1562, Train ACC: 0.95%, Train MCC: 0.8709, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 141/200, Train Loss: 0.1535, Train ACC: 0.93%, Train MCC: 0.8342, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 142/200, Train Loss: 0.1687, Train ACC: 0.93%, Train MCC: 0.8400, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 143/200, Train Loss: 0.1942, Train ACC: 0.93%, Train MCC: 0.8220, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 144/200, Train Loss: 0.1607, Train ACC: 0.93%, Train MCC: 0.8449, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 145/200, Train Loss: 0.1763, Train ACC: 0.94%, Train MCC: 0.8657, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 146/200, Train Loss: 0.1929, Train ACC: 0.92%, Train MCC: 0.8126, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 147/200, Train Loss: 0.1647, Train ACC: 0.93%, Train MCC: 0.8278, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 148/200, Train Loss: 0.1611, Train ACC: 0.93%, Train MCC: 0.8469, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 149/200, Train Loss: 0.1669, Train ACC: 0.93%, Train MCC: 0.8360, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 150/200, Train Loss: 0.1743, Train ACC: 0.94%, Train MCC: 0.8530, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 151/200, Train Loss: 0.1403, Train ACC: 0.94%, Train MCC: 0.8668, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 152/200, Train Loss: 0.2080, Train ACC: 0.91%, Train MCC: 0.8027, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 153/200, Train Loss: 0.1563, Train ACC: 0.94%, Train MCC: 0.8489, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 154/200, Train Loss: 0.1946, Train ACC: 0.93%, Train MCC: 0.8260, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 155/200, Train Loss: 0.1754, Train ACC: 0.93%, Train MCC: 0.8382, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 156/200, Train Loss: 0.1677, Train ACC: 0.94%, Train MCC: 0.8645, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 157/200, Train Loss: 0.1669, Train ACC: 0.93%, Train MCC: 0.8270, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 158/200, Train Loss: 0.1431, Train ACC: 0.94%, Train MCC: 0.8597, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 159/200, Train Loss: 0.1742, Train ACC: 0.94%, Train MCC: 0.8591, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 160/200, Train Loss: 0.1785, Train ACC: 0.95%, Train MCC: 0.8750, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 161/200, Train Loss: 0.1271, Train ACC: 0.95%, Train MCC: 0.8834, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 162/200, Train Loss: 0.1634, Train ACC: 0.94%, Train MCC: 0.8489, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 163/200, Train Loss: 0.1699, Train ACC: 0.95%, Train MCC: 0.8832, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 164/200, Train Loss: 0.1740, Train ACC: 0.94%, Train MCC: 0.8538, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 165/200, Train Loss: 0.1702, Train ACC: 0.93%, Train MCC: 0.8331, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 166/200, Train Loss: 0.1506, Train ACC: 0.94%, Train MCC: 0.8668, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 167/200, Train Loss: 0.1520, Train ACC: 0.95%, Train MCC: 0.8701, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 168/200, Train Loss: 0.1686, Train ACC: 0.94%, Train MCC: 0.8457, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 169/200, Train Loss: 0.1459, Train ACC: 0.94%, Train MCC: 0.8660, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 170/200, Train Loss: 0.1905, Train ACC: 0.93%, Train MCC: 0.8382, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 171/200, Train Loss: 0.1412, Train ACC: 0.94%, Train MCC: 0.8611, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 172/200, Train Loss: 0.1687, Train ACC: 0.94%, Train MCC: 0.8562, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 173/200, Train Loss: 0.1643, Train ACC: 0.93%, Train MCC: 0.8360, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 174/200, Train Loss: 0.1927, Train ACC: 0.94%, Train MCC: 0.8611, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 175/200, Train Loss: 0.1624, Train ACC: 0.93%, Train MCC: 0.8320, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 176/200, Train Loss: 0.1927, Train ACC: 0.94%, Train MCC: 0.8588, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 177/200, Train Loss: 0.1462, Train ACC: 0.94%, Train MCC: 0.8592, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 178/200, Train Loss: 0.1865, Train ACC: 0.92%, Train MCC: 0.8227, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 179/200, Train Loss: 0.1698, Train ACC: 0.94%, Train MCC: 0.8619, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 180/200, Train Loss: 0.1799, Train ACC: 0.93%, Train MCC: 0.8420, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 181/200, Train Loss: 0.1597, Train ACC: 0.93%, Train MCC: 0.8381, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 182/200, Train Loss: 0.1788, Train ACC: 0.95%, Train MCC: 0.8839, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 183/200, Train Loss: 0.1495, Train ACC: 0.93%, Train MCC: 0.8404, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 184/200, Train Loss: 0.1780, Train ACC: 0.93%, Train MCC: 0.8360, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 185/200, Train Loss: 0.1626, Train ACC: 0.93%, Train MCC: 0.8469, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 186/200, Train Loss: 0.2396, Train ACC: 0.90%, Train MCC: 0.7556, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 187/200, Train Loss: 0.1827, Train ACC: 0.93%, Train MCC: 0.8350, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 188/200, Train Loss: 0.1518, Train ACC: 0.94%, Train MCC: 0.8668, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 189/200, Train Loss: 0.1712, Train ACC: 0.93%, Train MCC: 0.8320, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 190/200, Train Loss: 0.1772, Train ACC: 0.93%, Train MCC: 0.8360, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 191/200, Train Loss: 0.1905, Train ACC: 0.94%, Train MCC: 0.8637, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 192/200, Train Loss: 0.1910, Train ACC: 0.92%, Train MCC: 0.8215, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 193/200, Train Loss: 0.1654, Train ACC: 0.92%, Train MCC: 0.8203, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 194/200, Train Loss: 0.1900, Train ACC: 0.94%, Train MCC: 0.8489, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 195/200, Train Loss: 0.1839, Train ACC: 0.93%, Train MCC: 0.8221, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 196/200, Train Loss: 0.1543, Train ACC: 0.95%, Train MCC: 0.8874, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 197/200, Train Loss: 0.1869, Train ACC: 0.92%, Train MCC: 0.8053, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 198/200, Train Loss: 0.1810, Train ACC: 0.92%, Train MCC: 0.8181, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 199/200, Train Loss: 0.1678, Train ACC: 0.93%, Train MCC: 0.8440, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787
# Epoch 200/200, Train Loss: 0.1972, Train ACC: 0.93%, Train MCC: 0.8331, Val Loss: 0.6752, Val ACC: 0.83, Val MCC: 0.5787

# %%
model = vgg19
model.eval()
# 加载测试数据集
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_csv_file = "/local/data1/honzh/local_repository/FL/code/4_federated/csv_files/test_data.csv"

test_dataset = CustomDataset(csv_file=test_csv_file, transform=test_transform)

test_model(model, test_dataset)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93      2271
#            1       0.66      0.80      0.73       490
#
#     accuracy                           0.89      2761
#    macro avg       0.81      0.86      0.83      2761
# weighted avg       0.90      0.89      0.90      2761
# {'Total Acc': 0.893,
#  'nff Acc': 0.913,
#  'aff Acc': 0.8,
#  'Precision': 0.664,
#  'Recall': 0.8,
#  'Accuracy': 0.893,
#  'AUC': 0.856,
#  'MCC': 0.664,
#  'F1 Score': 0.726,
#  'ROC_AUC': 0.856,
#  'PRC-AUC': 0.567}

# %% [markdown]
# # ResNet50 50% freezed

# %%
from torchvision.models import resnet50, ResNet50_Weights
from torchvision import transforms, models

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

model = models.resnet50(weights=ResNet50_Weights.DEFAULT)

num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)

# layer number
total_layers = len(list(model.children()))

# freeze 50% layer
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False

# modify full connection layer
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)

#---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 200
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

res50 = train_custom_model(model, train_dataset,val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/200, Train Loss: 0.6916, Train ACC: 0.51%, Train MCC: -0.0022, Val Loss: 0.7007, Val ACC: 0.58, Val MCC: -0.0028
# Epoch 2/200, Train Loss: 0.6665, Train ACC: 0.63%, Train MCC: 0.2259, Val Loss: 0.6916, Val ACC: 0.67, Val MCC: 0.1568
# Epoch 3/200, Train Loss: 0.6413, Train ACC: 0.65%, Train MCC: 0.2471, Val Loss: 0.6924, Val ACC: 0.66, Val MCC: 0.1112
# Epoch 4/200, Train Loss: 0.6153, Train ACC: 0.68%, Train MCC: 0.3132, Val Loss: 0.6975, Val ACC: 0.70, Val MCC: 0.1611
# Epoch 5/200, Train Loss: 0.5576, Train ACC: 0.74%, Train MCC: 0.4421, Val Loss: 0.6387, Val ACC: 0.73, Val MCC: 0.3141
# Epoch 6/200, Train Loss: 0.5029, Train ACC: 0.73%, Train MCC: 0.4717, Val Loss: 0.5978, Val ACC: 0.75, Val MCC: 0.3658
# Epoch 7/200, Train Loss: 0.4825, Train ACC: 0.75%, Train MCC: 0.4825, Val Loss: 0.7367, Val ACC: 0.76, Val MCC: 0.3841
# Epoch 8/200, Train Loss: 0.4006, Train ACC: 0.80%, Train MCC: 0.5741, Val Loss: 0.8198, Val ACC: 0.75, Val MCC: 0.3752
# Epoch 9/200, Train Loss: 0.3413, Train ACC: 0.85%, Train MCC: 0.6629, Val Loss: 0.7244, Val ACC: 0.78, Val MCC: 0.4817
# Epoch 10/200, Train Loss: 0.2978, Train ACC: 0.87%, Train MCC: 0.7096, Val Loss: 0.7034, Val ACC: 0.79, Val MCC: 0.5144
# Epoch 11/200, Train Loss: 0.2867, Train ACC: 0.89%, Train MCC: 0.7393, Val Loss: 0.7125, Val ACC: 0.81, Val MCC: 0.5209
# Epoch 12/200, Train Loss: 0.2717, Train ACC: 0.89%, Train MCC: 0.7470, Val Loss: 0.7288, Val ACC: 0.80, Val MCC: 0.5056
# Epoch 13/200, Train Loss: 0.2401, Train ACC: 0.89%, Train MCC: 0.7601, Val Loss: 0.6907, Val ACC: 0.81, Val MCC: 0.5302
# Epoch 14/200, Train Loss: 0.2612, Train ACC: 0.91%, Train MCC: 0.7950, Val Loss: 0.6869, Val ACC: 0.81, Val MCC: 0.5209
# Epoch 15/200, Train Loss: 0.2467, Train ACC: 0.91%, Train MCC: 0.7918, Val Loss: 0.6865, Val ACC: 0.81, Val MCC: 0.5209
# Epoch 16/200, Train Loss: 0.2582, Train ACC: 0.90%, Train MCC: 0.7640, Val Loss: 0.6742, Val ACC: 0.81, Val MCC: 0.5209
# Epoch 17/200, Train Loss: 0.2369, Train ACC: 0.91%, Train MCC: 0.7902, Val Loss: 0.6418, Val ACC: 0.80, Val MCC: 0.5029
# Epoch 18/200, Train Loss: 0.2632, Train ACC: 0.90%, Train MCC: 0.7815, Val Loss: 0.6473, Val ACC: 0.80, Val MCC: 0.5065
# Epoch 19/200, Train Loss: 0.2165, Train ACC: 0.91%, Train MCC: 0.7987, Val Loss: 0.6451, Val ACC: 0.82, Val MCC: 0.5486
# Epoch 20/200, Train Loss: 0.2238, Train ACC: 0.91%, Train MCC: 0.7987, Val Loss: 0.6575, Val ACC: 0.81, Val MCC: 0.5241
# Epoch 21/200, Train Loss: 0.2101, Train ACC: 0.91%, Train MCC: 0.7918, Val Loss: 0.6500, Val ACC: 0.82, Val MCC: 0.5519
# Epoch 22/200, Train Loss: 0.2432, Train ACC: 0.91%, Train MCC: 0.7937, Val Loss: 0.6527, Val ACC: 0.81, Val MCC: 0.5433
# Epoch 23/200, Train Loss: 0.2104, Train ACC: 0.92%, Train MCC: 0.8089, Val Loss: 0.6493, Val ACC: 0.81, Val MCC: 0.5433
# Epoch 24/200, Train Loss: 0.2223, Train ACC: 0.91%, Train MCC: 0.8042, Val Loss: 0.6403, Val ACC: 0.82, Val MCC: 0.5555
# Epoch 25/200, Train Loss: 0.2244, Train ACC: 0.91%, Train MCC: 0.7888, Val Loss: 0.6547, Val ACC: 0.81, Val MCC: 0.5398
# Epoch 26/200, Train Loss: 0.2420, Train ACC: 0.90%, Train MCC: 0.7709, Val Loss: 0.6367, Val ACC: 0.81, Val MCC: 0.5387
# Epoch 27/200, Train Loss: 0.1918, Train ACC: 0.93%, Train MCC: 0.8454, Val Loss: 0.6383, Val ACC: 0.81, Val MCC: 0.5387
# Epoch 28/200, Train Loss: 0.1965, Train ACC: 0.92%, Train MCC: 0.8215, Val Loss: 0.6496, Val ACC: 0.82, Val MCC: 0.5641
# Epoch 29/200, Train Loss: 0.2161, Train ACC: 0.92%, Train MCC: 0.8203, Val Loss: 0.6528, Val ACC: 0.82, Val MCC: 0.5641
# Epoch 30/200, Train Loss: 0.2189, Train ACC: 0.91%, Train MCC: 0.8020, Val Loss: 0.6527, Val ACC: 0.82, Val MCC: 0.5555
# Epoch 31/200, Train Loss: 0.2162, Train ACC: 0.92%, Train MCC: 0.8129, Val Loss: 0.6675, Val ACC: 0.82, Val MCC: 0.5519
# Epoch 32/200, Train Loss: 0.2408, Train ACC: 0.90%, Train MCC: 0.7707, Val Loss: 0.6679, Val ACC: 0.81, Val MCC: 0.5398
# Epoch 33/200, Train Loss: 0.2041, Train ACC: 0.93%, Train MCC: 0.8420, Val Loss: 0.6608, Val ACC: 0.82, Val MCC: 0.5555
# Epoch 34/200, Train Loss: 0.2090, Train ACC: 0.93%, Train MCC: 0.8231, Val Loss: 0.6531, Val ACC: 0.80, Val MCC: 0.5225
# Epoch 35/200, Train Loss: 0.2435, Train ACC: 0.89%, Train MCC: 0.7533, Val Loss: 0.6373, Val ACC: 0.82, Val MCC: 0.5592
# Epoch 36/200, Train Loss: 0.2736, Train ACC: 0.90%, Train MCC: 0.7764, Val Loss: 0.6576, Val ACC: 0.82, Val MCC: 0.5519
# Epoch 37/200, Train Loss: 0.2436, Train ACC: 0.90%, Train MCC: 0.7684, Val Loss: 0.6479, Val ACC: 0.82, Val MCC: 0.5592
# Epoch 38/200, Train Loss: 0.2005, Train ACC: 0.93%, Train MCC: 0.8416, Val Loss: 0.6300, Val ACC: 0.81, Val MCC: 0.5509
# Epoch 39/200, Train Loss: 0.2105, Train ACC: 0.92%, Train MCC: 0.8064, Val Loss: 0.6513, Val ACC: 0.81, Val MCC: 0.5470
# Epoch 40/200, Train Loss: 0.2274, Train ACC: 0.91%, Train MCC: 0.7874, Val Loss: 0.6582, Val ACC: 0.82, Val MCC: 0.5519
# Epoch 41/200, Train Loss: 0.2065, Train ACC: 0.93%, Train MCC: 0.8265, Val Loss: 0.6409, Val ACC: 0.81, Val MCC: 0.5387
# Epoch 42/200, Train Loss: 0.2351, Train ACC: 0.91%, Train MCC: 0.7888, Val Loss: 0.6409, Val ACC: 0.82, Val MCC: 0.5592
# Epoch 43/200, Train Loss: 0.2191, Train ACC: 0.93%, Train MCC: 0.8370, Val Loss: 0.6540, Val ACC: 0.81, Val MCC: 0.5398
# Epoch 44/200, Train Loss: 0.1849, Train ACC: 0.93%, Train MCC: 0.8366, Val Loss: 0.6476, Val ACC: 0.81, Val MCC: 0.5433
# Epoch 45/200, Train Loss: 0.2122, Train ACC: 0.91%, Train MCC: 0.7933, Val Loss: 0.6620, Val ACC: 0.80, Val MCC: 0.5225
# Epoch 46/200, Train Loss: 0.2238, Train ACC: 0.92%, Train MCC: 0.8152, Val Loss: 0.6543, Val ACC: 0.82, Val MCC: 0.5641
# Epoch 47/200, Train Loss: 0.2195, Train ACC: 0.91%, Train MCC: 0.8056, Val Loss: 0.6479, Val ACC: 0.81, Val MCC: 0.5470
# Epoch 48/200, Train Loss: 0.2502, Train ACC: 0.91%, Train MCC: 0.7874, Val Loss: 0.6658, Val ACC: 0.82, Val MCC: 0.5555
# Epoch 49/200, Train Loss: 0.2190, Train ACC: 0.92%, Train MCC: 0.8153, Val Loss: 0.6644, Val ACC: 0.81, Val MCC: 0.5398
# Epoch 50/200, Train Loss: 0.2048, Train ACC: 0.93%, Train MCC: 0.8310, Val Loss: 0.6442, Val ACC: 0.82, Val MCC: 0.5641
# Epoch 51/200, Train Loss: 0.2299, Train ACC: 0.92%, Train MCC: 0.8142, Val Loss: 0.6532, Val ACC: 0.81, Val MCC: 0.5398
# Epoch 52/200, Train Loss: 0.2563, Train ACC: 0.91%, Train MCC: 0.7925, Val Loss: 0.6730, Val ACC: 0.81, Val MCC: 0.5311
# Epoch 53/200, Train Loss: 0.2285, Train ACC: 0.91%, Train MCC: 0.7969, Val Loss: 0.6538, Val ACC: 0.81, Val MCC: 0.5509
# Epoch 54/200, Train Loss: 0.2041, Train ACC: 0.93%, Train MCC: 0.8404, Val Loss: 0.6349, Val ACC: 0.82, Val MCC: 0.5592
# Epoch 55/200, Train Loss: 0.2274, Train ACC: 0.92%, Train MCC: 0.8064, Val Loss: 0.6373, Val ACC: 0.81, Val MCC: 0.5509
# Epoch 56/200, Train Loss: 0.2265, Train ACC: 0.90%, Train MCC: 0.7794, Val Loss: 0.6429, Val ACC: 0.81, Val MCC: 0.5509
# Epoch 57/200, Train Loss: 0.2318, Train ACC: 0.91%, Train MCC: 0.7976, Val Loss: 0.6666, Val ACC: 0.82, Val MCC: 0.5486
# Epoch 58/200, Train Loss: 0.2500, Train ACC: 0.90%, Train MCC: 0.7743, Val Loss: 0.6647, Val ACC: 0.82, Val MCC: 0.5486
# Epoch 59/200, Train Loss: 0.2262, Train ACC: 0.91%, Train MCC: 0.8042, Val Loss: 0.6544, Val ACC: 0.81, Val MCC: 0.5433
# Epoch 60/200, Train Loss: 0.2188, Train ACC: 0.93%, Train MCC: 0.8231, Val Loss: 0.6494, Val ACC: 0.82, Val MCC: 0.5592
# Epoch 61/200, Train Loss: 0.1918, Train ACC: 0.91%, Train MCC: 0.7954, Val Loss: 0.6512, Val ACC: 0.82, Val MCC: 0.5641
# Epoch 62/200, Train Loss: 0.2224, Train ACC: 0.93%, Train MCC: 0.8301, Val Loss: 0.6380, Val ACC: 0.81, Val MCC: 0.5509
# Epoch 63/200, Train Loss: 0.2309, Train ACC: 0.91%, Train MCC: 0.7937, Val Loss: 0.6451, Val ACC: 0.82, Val MCC: 0.5555
# Epoch 64/200, Train Loss: 0.2119, Train ACC: 0.91%, Train MCC: 0.7848, Val Loss: 0.6470, Val ACC: 0.80, Val MCC: 0.5305
# Epoch 65/200, Train Loss: 0.2345, Train ACC: 0.92%, Train MCC: 0.8115, Val Loss: 0.6338, Val ACC: 0.80, Val MCC: 0.5347
# Epoch 66/200, Train Loss: 0.2192, Train ACC: 0.94%, Train MCC: 0.8480, Val Loss: 0.6560, Val ACC: 0.81, Val MCC: 0.5470
# Epoch 67/200, Train Loss: 0.1961, Train ACC: 0.93%, Train MCC: 0.8253, Val Loss: 0.6555, Val ACC: 0.81, Val MCC: 0.5311
# Epoch 68/200, Train Loss: 0.2068, Train ACC: 0.91%, Train MCC: 0.7976, Val Loss: 0.6473, Val ACC: 0.82, Val MCC: 0.5592
# Epoch 69/200, Train Loss: 0.2337, Train ACC: 0.90%, Train MCC: 0.7707, Val Loss: 0.6458, Val ACC: 0.82, Val MCC: 0.5592
# Epoch 70/200, Train Loss: 0.2735, Train ACC: 0.90%, Train MCC: 0.7775, Val Loss: 0.6327, Val ACC: 0.82, Val MCC: 0.5592
# Epoch 71/200, Train Loss: 0.2360, Train ACC: 0.89%, Train MCC: 0.7584, Val Loss: 0.6424, Val ACC: 0.81, Val MCC: 0.5509
# Epoch 72/200, Train Loss: 0.1939, Train ACC: 0.93%, Train MCC: 0.8315, Val Loss: 0.6388, Val ACC: 0.81, Val MCC: 0.5387
# Epoch 73/200, Train Loss: 0.2184, Train ACC: 0.91%, Train MCC: 0.8027, Val Loss: 0.6274, Val ACC: 0.81, Val MCC: 0.5509
# Epoch 74/200, Train Loss: 0.2204, Train ACC: 0.92%, Train MCC: 0.8103, Val Loss: 0.6311, Val ACC: 0.81, Val MCC: 0.5427
# Epoch 75/200, Train Loss: 0.2234, Train ACC: 0.91%, Train MCC: 0.8027, Val Loss: 0.6424, Val ACC: 0.81, Val MCC: 0.5387
# Epoch 76/200, Train Loss: 0.2333, Train ACC: 0.91%, Train MCC: 0.8042, Val Loss: 0.6616, Val ACC: 0.81, Val MCC: 0.5398
# Epoch 77/200, Train Loss: 0.2377, Train ACC: 0.91%, Train MCC: 0.7899, Val Loss: 0.6554, Val ACC: 0.82, Val MCC: 0.5762
# Epoch 78/200, Train Loss: 0.2286, Train ACC: 0.92%, Train MCC: 0.8038, Val Loss: 0.6567, Val ACC: 0.81, Val MCC: 0.5398
# Epoch 79/200, Train Loss: 0.1780, Train ACC: 0.93%, Train MCC: 0.8480, Val Loss: 0.6500, Val ACC: 0.81, Val MCC: 0.5470
# Epoch 80/200, Train Loss: 0.2042, Train ACC: 0.92%, Train MCC: 0.8190, Val Loss: 0.6562, Val ACC: 0.81, Val MCC: 0.5348
# Epoch 81/200, Train Loss: 0.2015, Train ACC: 0.93%, Train MCC: 0.8318, Val Loss: 0.6414, Val ACC: 0.82, Val MCC: 0.5592
# Epoch 82/200, Train Loss: 0.2108, Train ACC: 0.91%, Train MCC: 0.7888, Val Loss: 0.6337, Val ACC: 0.81, Val MCC: 0.5427
# Epoch 83/200, Train Loss: 0.1880, Train ACC: 0.92%, Train MCC: 0.8139, Val Loss: 0.6459, Val ACC: 0.80, Val MCC: 0.5305
# Epoch 84/200, Train Loss: 0.2301, Train ACC: 0.90%, Train MCC: 0.7815, Val Loss: 0.6545, Val ACC: 0.81, Val MCC: 0.5433
# Epoch 85/200, Train Loss: 0.2156, Train ACC: 0.93%, Train MCC: 0.8328, Val Loss: 0.6653, Val ACC: 0.82, Val MCC: 0.5519
# Epoch 86/200, Train Loss: 0.2118, Train ACC: 0.94%, Train MCC: 0.8519, Val Loss: 0.6565, Val ACC: 0.82, Val MCC: 0.5555
# Epoch 87/200, Train Loss: 0.2051, Train ACC: 0.92%, Train MCC: 0.8227, Val Loss: 0.6425, Val ACC: 0.81, Val MCC: 0.5509
# Epoch 88/200, Train Loss: 0.2135, Train ACC: 0.91%, Train MCC: 0.8013, Val Loss: 0.6344, Val ACC: 0.81, Val MCC: 0.5470
# Epoch 89/200, Train Loss: 0.2323, Train ACC: 0.90%, Train MCC: 0.7786, Val Loss: 0.6393, Val ACC: 0.81, Val MCC: 0.5387
# Epoch 90/200, Train Loss: 0.2367, Train ACC: 0.91%, Train MCC: 0.7824, Val Loss: 0.6478, Val ACC: 0.81, Val MCC: 0.5387
# Epoch 91/200, Train Loss: 0.2013, Train ACC: 0.93%, Train MCC: 0.8278, Val Loss: 0.6483, Val ACC: 0.81, Val MCC: 0.5387
# Epoch 92/200, Train Loss: 0.2417, Train ACC: 0.92%, Train MCC: 0.8126, Val Loss: 0.6558, Val ACC: 0.81, Val MCC: 0.5387
# Epoch 93/200, Train Loss: 0.2503, Train ACC: 0.90%, Train MCC: 0.7633, Val Loss: 0.6487, Val ACC: 0.81, Val MCC: 0.5509
# Epoch 94/200, Train Loss: 0.2198, Train ACC: 0.92%, Train MCC: 0.8051, Val Loss: 0.6510, Val ACC: 0.81, Val MCC: 0.5470
# Epoch 95/200, Train Loss: 0.2158, Train ACC: 0.90%, Train MCC: 0.7749, Val Loss: 0.6659, Val ACC: 0.81, Val MCC: 0.5311
# Epoch 96/200, Train Loss: 0.2338, Train ACC: 0.91%, Train MCC: 0.7837, Val Loss: 0.6634, Val ACC: 0.82, Val MCC: 0.5519
# Epoch 97/200, Train Loss: 0.2084, Train ACC: 0.91%, Train MCC: 0.7933, Val Loss: 0.6428, Val ACC: 0.82, Val MCC: 0.5555
# Epoch 98/200, Train Loss: 0.2407, Train ACC: 0.91%, Train MCC: 0.7937, Val Loss: 0.6569, Val ACC: 0.82, Val MCC: 0.5555
# Epoch 99/200, Train Loss: 0.2492, Train ACC: 0.89%, Train MCC: 0.7404, Val Loss: 0.6522, Val ACC: 0.81, Val MCC: 0.5470
# Epoch 100/200, Train Loss: 0.2629, Train ACC: 0.90%, Train MCC: 0.7728, Val Loss: 0.6472, Val ACC: 0.81, Val MCC: 0.5470
# Epoch 101/200, Train Loss: 0.2213, Train ACC: 0.92%, Train MCC: 0.8181, Val Loss: 0.6373, Val ACC: 0.81, Val MCC: 0.5470
# Epoch 102/200, Train Loss: 0.2344, Train ACC: 0.91%, Train MCC: 0.7837, Val Loss: 0.6568, Val ACC: 0.82, Val MCC: 0.5641
# Epoch 103/200, Train Loss: 0.2544, Train ACC: 0.89%, Train MCC: 0.7537, Val Loss: 0.6312, Val ACC: 0.81, Val MCC: 0.5509
# Epoch 104/200, Train Loss: 0.2398, Train ACC: 0.92%, Train MCC: 0.8051, Val Loss: 0.6480, Val ACC: 0.81, Val MCC: 0.5470
# Epoch 105/200, Train Loss: 0.2295, Train ACC: 0.92%, Train MCC: 0.8089, Val Loss: 0.6502, Val ACC: 0.81, Val MCC: 0.5387
# Epoch 106/200, Train Loss: 0.2844, Train ACC: 0.90%, Train MCC: 0.7559, Val Loss: 0.6529, Val ACC: 0.82, Val MCC: 0.5555
# Epoch 107/200, Train Loss: 0.2091, Train ACC: 0.91%, Train MCC: 0.7987, Val Loss: 0.6588, Val ACC: 0.81, Val MCC: 0.5433
# Epoch 108/200, Train Loss: 0.2402, Train ACC: 0.91%, Train MCC: 0.7824, Val Loss: 0.6516, Val ACC: 0.81, Val MCC: 0.5470
# Epoch 109/200, Train Loss: 0.2322, Train ACC: 0.91%, Train MCC: 0.7975, Val Loss: 0.6285, Val ACC: 0.81, Val MCC: 0.5427
# Epoch 110/200, Train Loss: 0.2473, Train ACC: 0.89%, Train MCC: 0.7410, Val Loss: 0.6481, Val ACC: 0.81, Val MCC: 0.5509
# Epoch 111/200, Train Loss: 0.2214, Train ACC: 0.93%, Train MCC: 0.8253, Val Loss: 0.6493, Val ACC: 0.81, Val MCC: 0.5387
# Epoch 112/200, Train Loss: 0.2017, Train ACC: 0.93%, Train MCC: 0.8469, Val Loss: 0.6571, Val ACC: 0.81, Val MCC: 0.5348
# Epoch 113/200, Train Loss: 0.2332, Train ACC: 0.90%, Train MCC: 0.7800, Val Loss: 0.6709, Val ACC: 0.82, Val MCC: 0.5486
# Epoch 114/200, Train Loss: 0.2276, Train ACC: 0.91%, Train MCC: 0.7939, Val Loss: 0.6674, Val ACC: 0.81, Val MCC: 0.5398
# Epoch 115/200, Train Loss: 0.2343, Train ACC: 0.91%, Train MCC: 0.7837, Val Loss: 0.6527, Val ACC: 0.82, Val MCC: 0.5641
# Epoch 116/200, Train Loss: 0.2288, Train ACC: 0.92%, Train MCC: 0.8240, Val Loss: 0.6555, Val ACC: 0.81, Val MCC: 0.5433
# Epoch 117/200, Train Loss: 0.2522, Train ACC: 0.90%, Train MCC: 0.7734, Val Loss: 0.6495, Val ACC: 0.80, Val MCC: 0.5264
# Epoch 118/200, Train Loss: 0.2026, Train ACC: 0.92%, Train MCC: 0.8126, Val Loss: 0.6398, Val ACC: 0.81, Val MCC: 0.5509
# Epoch 119/200, Train Loss: 0.2017, Train ACC: 0.92%, Train MCC: 0.8180, Val Loss: 0.6522, Val ACC: 0.81, Val MCC: 0.5348
# Epoch 120/200, Train Loss: 0.2235, Train ACC: 0.90%, Train MCC: 0.7620, Val Loss: 0.6623, Val ACC: 0.81, Val MCC: 0.5433
# Epoch 121/200, Train Loss: 0.2146, Train ACC: 0.93%, Train MCC: 0.8292, Val Loss: 0.6425, Val ACC: 0.81, Val MCC: 0.5387
# Epoch 122/200, Train Loss: 0.2192, Train ACC: 0.92%, Train MCC: 0.8227, Val Loss: 0.6502, Val ACC: 0.82, Val MCC: 0.5555
# Epoch 123/200, Train Loss: 0.2069, Train ACC: 0.92%, Train MCC: 0.8078, Val Loss: 0.6460, Val ACC: 0.81, Val MCC: 0.5427
# Epoch 124/200, Train Loss: 0.2267, Train ACC: 0.92%, Train MCC: 0.8142, Val Loss: 0.6456, Val ACC: 0.80, Val MCC: 0.5305
# Epoch 125/200, Train Loss: 0.2104, Train ACC: 0.93%, Train MCC: 0.8442, Val Loss: 0.6344, Val ACC: 0.81, Val MCC: 0.5427
# Epoch 126/200, Train Loss: 0.2384, Train ACC: 0.92%, Train MCC: 0.8152, Val Loss: 0.6460, Val ACC: 0.80, Val MCC: 0.5305
# Epoch 127/200, Train Loss: 0.2074, Train ACC: 0.91%, Train MCC: 0.8027, Val Loss: 0.6455, Val ACC: 0.81, Val MCC: 0.5470
# Epoch 128/200, Train Loss: 0.2106, Train ACC: 0.91%, Train MCC: 0.7950, Val Loss: 0.6346, Val ACC: 0.81, Val MCC: 0.5509
# Epoch 129/200, Train Loss: 0.2165, Train ACC: 0.93%, Train MCC: 0.8320, Val Loss: 0.6492, Val ACC: 0.81, Val MCC: 0.5387
# Epoch 130/200, Train Loss: 0.1886, Train ACC: 0.93%, Train MCC: 0.8304, Val Loss: 0.6456, Val ACC: 0.81, Val MCC: 0.5387
# Epoch 131/200, Train Loss: 0.2530, Train ACC: 0.90%, Train MCC: 0.7773, Val Loss: 0.6449, Val ACC: 0.82, Val MCC: 0.5592
# Epoch 132/200, Train Loss: 0.2058, Train ACC: 0.92%, Train MCC: 0.8129, Val Loss: 0.6358, Val ACC: 0.81, Val MCC: 0.5470
# Epoch 133/200, Train Loss: 0.2435, Train ACC: 0.91%, Train MCC: 0.7891, Val Loss: 0.6382, Val ACC: 0.81, Val MCC: 0.5509
# Epoch 134/200, Train Loss: 0.2069, Train ACC: 0.92%, Train MCC: 0.8180, Val Loss: 0.6618, Val ACC: 0.82, Val MCC: 0.5641
# Epoch 135/200, Train Loss: 0.2013, Train ACC: 0.94%, Train MCC: 0.8608, Val Loss: 0.6409, Val ACC: 0.81, Val MCC: 0.5387
# Epoch 136/200, Train Loss: 0.2084, Train ACC: 0.92%, Train MCC: 0.8114, Val Loss: 0.6467, Val ACC: 0.82, Val MCC: 0.5641
# Epoch 137/200, Train Loss: 0.2300, Train ACC: 0.91%, Train MCC: 0.7939, Val Loss: 0.6455, Val ACC: 0.81, Val MCC: 0.5348
# Epoch 138/200, Train Loss: 0.2271, Train ACC: 0.89%, Train MCC: 0.7549, Val Loss: 0.6578, Val ACC: 0.80, Val MCC: 0.5102
# Epoch 139/200, Train Loss: 0.1968, Train ACC: 0.92%, Train MCC: 0.8227, Val Loss: 0.6622, Val ACC: 0.82, Val MCC: 0.5607
# Epoch 140/200, Train Loss: 0.2219, Train ACC: 0.92%, Train MCC: 0.8129, Val Loss: 0.6607, Val ACC: 0.81, Val MCC: 0.5433
# Epoch 141/200, Train Loss: 0.2295, Train ACC: 0.92%, Train MCC: 0.8165, Val Loss: 0.6420, Val ACC: 0.80, Val MCC: 0.5305
# Epoch 142/200, Train Loss: 0.2493, Train ACC: 0.90%, Train MCC: 0.7779, Val Loss: 0.6508, Val ACC: 0.81, Val MCC: 0.5509
# Epoch 143/200, Train Loss: 0.2434, Train ACC: 0.91%, Train MCC: 0.7863, Val Loss: 0.6366, Val ACC: 0.81, Val MCC: 0.5509
# Epoch 144/200, Train Loss: 0.2266, Train ACC: 0.92%, Train MCC: 0.8102, Val Loss: 0.6448, Val ACC: 0.82, Val MCC: 0.5555
# Epoch 145/200, Train Loss: 0.2283, Train ACC: 0.92%, Train MCC: 0.8115, Val Loss: 0.6450, Val ACC: 0.81, Val MCC: 0.5433
# Epoch 146/200, Train Loss: 0.2242, Train ACC: 0.91%, Train MCC: 0.7975, Val Loss: 0.6714, Val ACC: 0.81, Val MCC: 0.5398
# Epoch 147/200, Train Loss: 0.2318, Train ACC: 0.92%, Train MCC: 0.8171, Val Loss: 0.6502, Val ACC: 0.82, Val MCC: 0.5592
# Epoch 148/200, Train Loss: 0.2300, Train ACC: 0.91%, Train MCC: 0.7888, Val Loss: 0.6394, Val ACC: 0.81, Val MCC: 0.5470
# Epoch 149/200, Train Loss: 0.2070, Train ACC: 0.93%, Train MCC: 0.8430, Val Loss: 0.6555, Val ACC: 0.81, Val MCC: 0.5348
# Epoch 150/200, Train Loss: 0.2170, Train ACC: 0.91%, Train MCC: 0.7939, Val Loss: 0.6596, Val ACC: 0.82, Val MCC: 0.5607
# Epoch 151/200, Train Loss: 0.2201, Train ACC: 0.90%, Train MCC: 0.7728, Val Loss: 0.6381, Val ACC: 0.81, Val MCC: 0.5470
# Epoch 152/200, Train Loss: 0.2258, Train ACC: 0.92%, Train MCC: 0.8064, Val Loss: 0.6456, Val ACC: 0.80, Val MCC: 0.5225
# Epoch 153/200, Train Loss: 0.2160, Train ACC: 0.93%, Train MCC: 0.8253, Val Loss: 0.6447, Val ACC: 0.81, Val MCC: 0.5433
# Epoch 154/200, Train Loss: 0.2286, Train ACC: 0.91%, Train MCC: 0.7925, Val Loss: 0.6277, Val ACC: 0.81, Val MCC: 0.5509
# Epoch 155/200, Train Loss: 0.2273, Train ACC: 0.91%, Train MCC: 0.7861, Val Loss: 0.6540, Val ACC: 0.81, Val MCC: 0.5470
# Epoch 156/200, Train Loss: 0.2111, Train ACC: 0.91%, Train MCC: 0.8056, Val Loss: 0.6541, Val ACC: 0.81, Val MCC: 0.5348
# Epoch 157/200, Train Loss: 0.2186, Train ACC: 0.91%, Train MCC: 0.7837, Val Loss: 0.6545, Val ACC: 0.81, Val MCC: 0.5387
# Epoch 158/200, Train Loss: 0.2268, Train ACC: 0.91%, Train MCC: 0.7899, Val Loss: 0.6371, Val ACC: 0.80, Val MCC: 0.5305
# Epoch 159/200, Train Loss: 0.2304, Train ACC: 0.92%, Train MCC: 0.8089, Val Loss: 0.6247, Val ACC: 0.81, Val MCC: 0.5427
# Epoch 160/200, Train Loss: 0.2462, Train ACC: 0.91%, Train MCC: 0.7912, Val Loss: 0.6271, Val ACC: 0.81, Val MCC: 0.5427
# Epoch 161/200, Train Loss: 0.2274, Train ACC: 0.91%, Train MCC: 0.7925, Val Loss: 0.6375, Val ACC: 0.81, Val MCC: 0.5509
# Epoch 162/200, Train Loss: 0.2070, Train ACC: 0.91%, Train MCC: 0.8000, Val Loss: 0.6391, Val ACC: 0.81, Val MCC: 0.5387
# Epoch 163/200, Train Loss: 0.2463, Train ACC: 0.91%, Train MCC: 0.7848, Val Loss: 0.6329, Val ACC: 0.82, Val MCC: 0.5592
# Epoch 164/200, Train Loss: 0.2011, Train ACC: 0.92%, Train MCC: 0.8203, Val Loss: 0.6528, Val ACC: 0.82, Val MCC: 0.5592
# Epoch 165/200, Train Loss: 0.1936, Train ACC: 0.92%, Train MCC: 0.8152, Val Loss: 0.6475, Val ACC: 0.82, Val MCC: 0.5676
# Epoch 166/200, Train Loss: 0.2430, Train ACC: 0.90%, Train MCC: 0.7647, Val Loss: 0.6656, Val ACC: 0.81, Val MCC: 0.5433
# Epoch 167/200, Train Loss: 0.2311, Train ACC: 0.90%, Train MCC: 0.7815, Val Loss: 0.6509, Val ACC: 0.81, Val MCC: 0.5470
# Epoch 168/200, Train Loss: 0.2014, Train ACC: 0.92%, Train MCC: 0.8064, Val Loss: 0.6431, Val ACC: 0.81, Val MCC: 0.5470
# Epoch 169/200, Train Loss: 0.2352, Train ACC: 0.90%, Train MCC: 0.7672, Val Loss: 0.6471, Val ACC: 0.82, Val MCC: 0.5592
# Epoch 170/200, Train Loss: 0.2022, Train ACC: 0.92%, Train MCC: 0.8203, Val Loss: 0.6526, Val ACC: 0.82, Val MCC: 0.5641
# Epoch 171/200, Train Loss: 0.1963, Train ACC: 0.92%, Train MCC: 0.8166, Val Loss: 0.6435, Val ACC: 0.81, Val MCC: 0.5387
# Epoch 172/200, Train Loss: 0.2067, Train ACC: 0.90%, Train MCC: 0.7815, Val Loss: 0.6454, Val ACC: 0.81, Val MCC: 0.5348
# Epoch 173/200, Train Loss: 0.2684, Train ACC: 0.89%, Train MCC: 0.7339, Val Loss: 0.6389, Val ACC: 0.81, Val MCC: 0.5387
# Epoch 174/200, Train Loss: 0.2166, Train ACC: 0.91%, Train MCC: 0.8005, Val Loss: 0.6630, Val ACC: 0.82, Val MCC: 0.5641
# Epoch 175/200, Train Loss: 0.2164, Train ACC: 0.92%, Train MCC: 0.8139, Val Loss: 0.6642, Val ACC: 0.81, Val MCC: 0.5398
# Epoch 176/200, Train Loss: 0.1933, Train ACC: 0.93%, Train MCC: 0.8355, Val Loss: 0.6668, Val ACC: 0.81, Val MCC: 0.5275
# Epoch 177/200, Train Loss: 0.2227, Train ACC: 0.91%, Train MCC: 0.7969, Val Loss: 0.6426, Val ACC: 0.82, Val MCC: 0.5592
# Epoch 178/200, Train Loss: 0.2144, Train ACC: 0.91%, Train MCC: 0.7903, Val Loss: 0.6353, Val ACC: 0.81, Val MCC: 0.5427
# Epoch 179/200, Train Loss: 0.2373, Train ACC: 0.91%, Train MCC: 0.8013, Val Loss: 0.6479, Val ACC: 0.81, Val MCC: 0.5427
# Epoch 180/200, Train Loss: 0.2158, Train ACC: 0.92%, Train MCC: 0.8114, Val Loss: 0.6444, Val ACC: 0.80, Val MCC: 0.5264
# Epoch 181/200, Train Loss: 0.2121, Train ACC: 0.92%, Train MCC: 0.8042, Val Loss: 0.6546, Val ACC: 0.82, Val MCC: 0.5555
# Epoch 182/200, Train Loss: 0.2039, Train ACC: 0.93%, Train MCC: 0.8303, Val Loss: 0.6648, Val ACC: 0.82, Val MCC: 0.5728
# Epoch 183/200, Train Loss: 0.1972, Train ACC: 0.93%, Train MCC: 0.8381, Val Loss: 0.6447, Val ACC: 0.81, Val MCC: 0.5387
# Epoch 184/200, Train Loss: 0.2714, Train ACC: 0.90%, Train MCC: 0.7661, Val Loss: 0.6531, Val ACC: 0.82, Val MCC: 0.5555
# Epoch 185/200, Train Loss: 0.2309, Train ACC: 0.91%, Train MCC: 0.7874, Val Loss: 0.6603, Val ACC: 0.82, Val MCC: 0.5555
# Epoch 186/200, Train Loss: 0.2243, Train ACC: 0.91%, Train MCC: 0.7886, Val Loss: 0.6750, Val ACC: 0.80, Val MCC: 0.5188
# Epoch 187/200, Train Loss: 0.2153, Train ACC: 0.91%, Train MCC: 0.7975, Val Loss: 0.6488, Val ACC: 0.81, Val MCC: 0.5509
# Epoch 188/200, Train Loss: 0.2209, Train ACC: 0.92%, Train MCC: 0.8051, Val Loss: 0.6639, Val ACC: 0.80, Val MCC: 0.5152
# Epoch 189/200, Train Loss: 0.2008, Train ACC: 0.91%, Train MCC: 0.7914, Val Loss: 0.6615, Val ACC: 0.81, Val MCC: 0.5364
# Epoch 190/200, Train Loss: 0.2005, Train ACC: 0.93%, Train MCC: 0.8442, Val Loss: 0.6643, Val ACC: 0.81, Val MCC: 0.5275
# Epoch 191/200, Train Loss: 0.2238, Train ACC: 0.92%, Train MCC: 0.8180, Val Loss: 0.6611, Val ACC: 0.81, Val MCC: 0.5433
# Epoch 192/200, Train Loss: 0.1855, Train ACC: 0.93%, Train MCC: 0.8480, Val Loss: 0.6433, Val ACC: 0.81, Val MCC: 0.5387
# Epoch 193/200, Train Loss: 0.2092, Train ACC: 0.91%, Train MCC: 0.7950, Val Loss: 0.6396, Val ACC: 0.82, Val MCC: 0.5555
# Epoch 194/200, Train Loss: 0.2216, Train ACC: 0.91%, Train MCC: 0.7852, Val Loss: 0.6464, Val ACC: 0.81, Val MCC: 0.5348
# Epoch 195/200, Train Loss: 0.2276, Train ACC: 0.91%, Train MCC: 0.7797, Val Loss: 0.6500, Val ACC: 0.80, Val MCC: 0.5264
# Epoch 196/200, Train Loss: 0.2142, Train ACC: 0.91%, Train MCC: 0.8000, Val Loss: 0.6544, Val ACC: 0.81, Val MCC: 0.5311
# Epoch 197/200, Train Loss: 0.2164, Train ACC: 0.91%, Train MCC: 0.7939, Val Loss: 0.6483, Val ACC: 0.81, Val MCC: 0.5348
# Epoch 198/200, Train Loss: 0.2098, Train ACC: 0.92%, Train MCC: 0.8089, Val Loss: 0.6515, Val ACC: 0.81, Val MCC: 0.5398
# Epoch 199/200, Train Loss: 0.2199, Train ACC: 0.92%, Train MCC: 0.8203, Val Loss: 0.6493, Val ACC: 0.81, Val MCC: 0.5470
# Epoch 200/200, Train Loss: 0.1982, Train ACC: 0.93%, Train MCC: 0.8492, Val Loss: 0.6438, Val ACC: 0.82, Val MCC: 0.5592

# %%
model = res50
model.eval()
# 加载测试数据集
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_csv_file = "/local/data1/honzh/local_repository/FL/code/4_federated/csv_files/test_data.csv"

test_dataset = CustomDataset(csv_file=test_csv_file, transform=test_transform)

test_model(model, test_dataset)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.90      0.92      2271
#            1       0.62      0.72      0.67       490
#
#     accuracy                           0.87      2761
#    macro avg       0.78      0.81      0.79      2761
# weighted avg       0.88      0.87      0.88      2761
# {'Total Acc': 0.872,
#  'nff Acc': 0.904,
#  'aff Acc': 0.724,
#  'Precision': 0.618,
#  'Recall': 0.724,
#  'Accuracy': 0.872,
#  'AUC': 0.814,
#  'MCC': 0.591,
#  'F1 Score': 0.667,
#  'ROC_AUC': 0.814,
#  'PRC-AUC': 0.497}

# %% [markdown]
# # ResNet 101

# %%
from torchvision.models import resnet101, ResNet101_Weights
from torchvision import transforms, models

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the ResNet-101 model
model = models.resnet101(weights=ResNet101_Weights.DEFAULT)

num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)

# layer number
total_layers = len(list(model.children()))

# freeze 50% layer
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False

# modify full connection layer
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)
#---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 200
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

res101 = train_custom_model(model, train_dataset,val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/200, Train Loss: 0.6918, Train ACC: 0.59%, Train MCC: 0.0655, Val Loss: 0.6862, Val ACC: 0.69, Val MCC: 0.0588
# Epoch 2/200, Train Loss: 0.6707, Train ACC: 0.57%, Train MCC: 0.1278, Val Loss: 0.6783, Val ACC: 0.70, Val MCC: 0.1717
# Epoch 3/200, Train Loss: 0.6181, Train ACC: 0.66%, Train MCC: 0.3222, Val Loss: 0.6637, Val ACC: 0.70, Val MCC: 0.2003
# Epoch 4/200, Train Loss: 0.5583, Train ACC: 0.73%, Train MCC: 0.4195, Val Loss: 0.6497, Val ACC: 0.75, Val MCC: 0.3279
# Epoch 5/200, Train Loss: 0.4853, Train ACC: 0.78%, Train MCC: 0.5268, Val Loss: 0.5881, Val ACC: 0.76, Val MCC: 0.4362
# Epoch 6/200, Train Loss: 0.4582, Train ACC: 0.77%, Train MCC: 0.5151, Val Loss: 0.7797, Val ACC: 0.79, Val MCC: 0.4656
# Epoch 7/200, Train Loss: 0.3861, Train ACC: 0.84%, Train MCC: 0.6525, Val Loss: 0.8345, Val ACC: 0.81, Val MCC: 0.5149
# Epoch 8/200, Train Loss: 0.3114, Train ACC: 0.88%, Train MCC: 0.7149, Val Loss: 0.7426, Val ACC: 0.83, Val MCC: 0.5638
# Epoch 9/200, Train Loss: 0.2690, Train ACC: 0.90%, Train MCC: 0.7728, Val Loss: 0.7919, Val ACC: 0.85, Val MCC: 0.6226
# Epoch 10/200, Train Loss: 0.2289, Train ACC: 0.91%, Train MCC: 0.8042, Val Loss: 0.6922, Val ACC: 0.85, Val MCC: 0.6347
# Epoch 11/200, Train Loss: 0.1866, Train ACC: 0.94%, Train MCC: 0.8619, Val Loss: 0.6149, Val ACC: 0.86, Val MCC: 0.6499
# Epoch 12/200, Train Loss: 0.1935, Train ACC: 0.93%, Train MCC: 0.8360, Val Loss: 0.5897, Val ACC: 0.87, Val MCC: 0.6845
# Epoch 13/200, Train Loss: 0.1642, Train ACC: 0.95%, Train MCC: 0.8742, Val Loss: 0.5764, Val ACC: 0.87, Val MCC: 0.6714
# Epoch 14/200, Train Loss: 0.1768, Train ACC: 0.94%, Train MCC: 0.8519, Val Loss: 0.5684, Val ACC: 0.87, Val MCC: 0.6714
# Epoch 15/200, Train Loss: 0.1412, Train ACC: 0.95%, Train MCC: 0.8839, Val Loss: 0.5675, Val ACC: 0.88, Val MCC: 0.6919
# Epoch 16/200, Train Loss: 0.1491, Train ACC: 0.96%, Train MCC: 0.9007, Val Loss: 0.5607, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 17/200, Train Loss: 0.1407, Train ACC: 0.95%, Train MCC: 0.8701, Val Loss: 0.5742, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 18/200, Train Loss: 0.1566, Train ACC: 0.94%, Train MCC: 0.8570, Val Loss: 0.5791, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 19/200, Train Loss: 0.1799, Train ACC: 0.93%, Train MCC: 0.8390, Val Loss: 0.5799, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 20/200, Train Loss: 0.2042, Train ACC: 0.93%, Train MCC: 0.8360, Val Loss: 0.5819, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 21/200, Train Loss: 0.1446, Train ACC: 0.95%, Train MCC: 0.8873, Val Loss: 0.5682, Val ACC: 0.88, Val MCC: 0.7024
# Epoch 22/200, Train Loss: 0.1758, Train ACC: 0.93%, Train MCC: 0.8292, Val Loss: 0.5929, Val ACC: 0.88, Val MCC: 0.7024
# Epoch 23/200, Train Loss: 0.2031, Train ACC: 0.92%, Train MCC: 0.8081, Val Loss: 0.5982, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 24/200, Train Loss: 0.1424, Train ACC: 0.96%, Train MCC: 0.8950, Val Loss: 0.6007, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 25/200, Train Loss: 0.1675, Train ACC: 0.93%, Train MCC: 0.8392, Val Loss: 0.6044, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 26/200, Train Loss: 0.1390, Train ACC: 0.94%, Train MCC: 0.8657, Val Loss: 0.6028, Val ACC: 0.87, Val MCC: 0.6685
# Epoch 27/200, Train Loss: 0.1388, Train ACC: 0.95%, Train MCC: 0.8883, Val Loss: 0.6019, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 28/200, Train Loss: 0.1320, Train ACC: 0.95%, Train MCC: 0.8847, Val Loss: 0.5893, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 29/200, Train Loss: 0.1493, Train ACC: 0.94%, Train MCC: 0.8668, Val Loss: 0.6093, Val ACC: 0.88, Val MCC: 0.6908
# Epoch 30/200, Train Loss: 0.1470, Train ACC: 0.95%, Train MCC: 0.8815, Val Loss: 0.6023, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 31/200, Train Loss: 0.1280, Train ACC: 0.95%, Train MCC: 0.8815, Val Loss: 0.6135, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 32/200, Train Loss: 0.1417, Train ACC: 0.95%, Train MCC: 0.8824, Val Loss: 0.6199, Val ACC: 0.88, Val MCC: 0.6908
# Epoch 33/200, Train Loss: 0.1042, Train ACC: 0.97%, Train MCC: 0.9326, Val Loss: 0.6244, Val ACC: 0.87, Val MCC: 0.6796
# Epoch 34/200, Train Loss: 0.1463, Train ACC: 0.95%, Train MCC: 0.8791, Val Loss: 0.6165, Val ACC: 0.87, Val MCC: 0.6685
# Epoch 35/200, Train Loss: 0.1687, Train ACC: 0.95%, Train MCC: 0.8750, Val Loss: 0.6117, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 36/200, Train Loss: 0.1327, Train ACC: 0.94%, Train MCC: 0.8696, Val Loss: 0.6163, Val ACC: 0.87, Val MCC: 0.6685
# Epoch 37/200, Train Loss: 0.2046, Train ACC: 0.95%, Train MCC: 0.8746, Val Loss: 0.5953, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 38/200, Train Loss: 0.1542, Train ACC: 0.94%, Train MCC: 0.8529, Val Loss: 0.6137, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 39/200, Train Loss: 0.1711, Train ACC: 0.93%, Train MCC: 0.8392, Val Loss: 0.5959, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 40/200, Train Loss: 0.1320, Train ACC: 0.95%, Train MCC: 0.8815, Val Loss: 0.5889, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 41/200, Train Loss: 0.1263, Train ACC: 0.95%, Train MCC: 0.8717, Val Loss: 0.5895, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 42/200, Train Loss: 0.1339, Train ACC: 0.96%, Train MCC: 0.8944, Val Loss: 0.5915, Val ACC: 0.88, Val MCC: 0.7024
# Epoch 43/200, Train Loss: 0.1418, Train ACC: 0.96%, Train MCC: 0.8936, Val Loss: 0.6056, Val ACC: 0.88, Val MCC: 0.7020
# Epoch 44/200, Train Loss: 0.1673, Train ACC: 0.93%, Train MCC: 0.8431, Val Loss: 0.6088, Val ACC: 0.88, Val MCC: 0.7024
# Epoch 45/200, Train Loss: 0.1706, Train ACC: 0.94%, Train MCC: 0.8548, Val Loss: 0.5965, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 46/200, Train Loss: 0.1384, Train ACC: 0.95%, Train MCC: 0.8855, Val Loss: 0.6026, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 47/200, Train Loss: 0.1426, Train ACC: 0.94%, Train MCC: 0.8647, Val Loss: 0.5946, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 48/200, Train Loss: 0.1484, Train ACC: 0.95%, Train MCC: 0.8839, Val Loss: 0.5800, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 49/200, Train Loss: 0.1292, Train ACC: 0.95%, Train MCC: 0.8717, Val Loss: 0.5831, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 50/200, Train Loss: 0.1389, Train ACC: 0.95%, Train MCC: 0.8735, Val Loss: 0.5990, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 51/200, Train Loss: 0.1281, Train ACC: 0.95%, Train MCC: 0.8913, Val Loss: 0.5936, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 52/200, Train Loss: 0.1547, Train ACC: 0.93%, Train MCC: 0.8480, Val Loss: 0.6129, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 53/200, Train Loss: 0.1364, Train ACC: 0.95%, Train MCC: 0.8873, Val Loss: 0.6267, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 54/200, Train Loss: 0.1245, Train ACC: 0.95%, Train MCC: 0.8815, Val Loss: 0.5999, Val ACC: 0.88, Val MCC: 0.7024
# Epoch 55/200, Train Loss: 0.1338, Train ACC: 0.95%, Train MCC: 0.8709, Val Loss: 0.6175, Val ACC: 0.86, Val MCC: 0.6572
# Epoch 56/200, Train Loss: 0.1237, Train ACC: 0.96%, Train MCC: 0.8971, Val Loss: 0.6057, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 57/200, Train Loss: 0.1491, Train ACC: 0.96%, Train MCC: 0.8977, Val Loss: 0.6042, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 58/200, Train Loss: 0.1584, Train ACC: 0.95%, Train MCC: 0.8735, Val Loss: 0.6023, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 59/200, Train Loss: 0.1550, Train ACC: 0.95%, Train MCC: 0.8768, Val Loss: 0.6071, Val ACC: 0.88, Val MCC: 0.6908
# Epoch 60/200, Train Loss: 0.1535, Train ACC: 0.94%, Train MCC: 0.8558, Val Loss: 0.6125, Val ACC: 0.88, Val MCC: 0.6908
# Epoch 61/200, Train Loss: 0.1392, Train ACC: 0.96%, Train MCC: 0.9013, Val Loss: 0.6010, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 62/200, Train Loss: 0.1343, Train ACC: 0.96%, Train MCC: 0.9067, Val Loss: 0.5898, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 63/200, Train Loss: 0.1270, Train ACC: 0.96%, Train MCC: 0.9061, Val Loss: 0.5973, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 64/200, Train Loss: 0.1697, Train ACC: 0.93%, Train MCC: 0.8469, Val Loss: 0.6045, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 65/200, Train Loss: 0.1662, Train ACC: 0.94%, Train MCC: 0.8597, Val Loss: 0.5987, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 66/200, Train Loss: 0.1296, Train ACC: 0.96%, Train MCC: 0.9067, Val Loss: 0.5921, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 67/200, Train Loss: 0.1558, Train ACC: 0.94%, Train MCC: 0.8628, Val Loss: 0.5930, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 68/200, Train Loss: 0.1171, Train ACC: 0.96%, Train MCC: 0.9139, Val Loss: 0.5973, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 69/200, Train Loss: 0.1490, Train ACC: 0.96%, Train MCC: 0.8929, Val Loss: 0.5845, Val ACC: 0.88, Val MCC: 0.7024
# Epoch 70/200, Train Loss: 0.1474, Train ACC: 0.94%, Train MCC: 0.8538, Val Loss: 0.5752, Val ACC: 0.88, Val MCC: 0.7024
# Epoch 71/200, Train Loss: 0.1308, Train ACC: 0.96%, Train MCC: 0.9026, Val Loss: 0.5713, Val ACC: 0.88, Val MCC: 0.7024
# Epoch 72/200, Train Loss: 0.0979, Train ACC: 0.97%, Train MCC: 0.9308, Val Loss: 0.5864, Val ACC: 0.88, Val MCC: 0.7024
# Epoch 73/200, Train Loss: 0.1516, Train ACC: 0.95%, Train MCC: 0.8778, Val Loss: 0.5976, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 74/200, Train Loss: 0.1571, Train ACC: 0.94%, Train MCC: 0.8597, Val Loss: 0.6143, Val ACC: 0.88, Val MCC: 0.6908
# Epoch 75/200, Train Loss: 0.1211, Train ACC: 0.96%, Train MCC: 0.9179, Val Loss: 0.6104, Val ACC: 0.88, Val MCC: 0.6908
# Epoch 76/200, Train Loss: 0.1317, Train ACC: 0.95%, Train MCC: 0.8873, Val Loss: 0.6084, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 77/200, Train Loss: 0.1252, Train ACC: 0.96%, Train MCC: 0.8936, Val Loss: 0.6091, Val ACC: 0.87, Val MCC: 0.6685
# Epoch 78/200, Train Loss: 0.1229, Train ACC: 0.96%, Train MCC: 0.9002, Val Loss: 0.6028, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 79/200, Train Loss: 0.1507, Train ACC: 0.95%, Train MCC: 0.8881, Val Loss: 0.5828, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 80/200, Train Loss: 0.1466, Train ACC: 0.95%, Train MCC: 0.8896, Val Loss: 0.5983, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 81/200, Train Loss: 0.1571, Train ACC: 0.94%, Train MCC: 0.8538, Val Loss: 0.6120, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 82/200, Train Loss: 0.1269, Train ACC: 0.95%, Train MCC: 0.8933, Val Loss: 0.6011, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 83/200, Train Loss: 0.1756, Train ACC: 0.94%, Train MCC: 0.8529, Val Loss: 0.5905, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 84/200, Train Loss: 0.1535, Train ACC: 0.96%, Train MCC: 0.9007, Val Loss: 0.5888, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 85/200, Train Loss: 0.1296, Train ACC: 0.96%, Train MCC: 0.9002, Val Loss: 0.6284, Val ACC: 0.88, Val MCC: 0.6908
# Epoch 86/200, Train Loss: 0.1423, Train ACC: 0.96%, Train MCC: 0.8953, Val Loss: 0.6293, Val ACC: 0.87, Val MCC: 0.6683
# Epoch 87/200, Train Loss: 0.1402, Train ACC: 0.95%, Train MCC: 0.8824, Val Loss: 0.6277, Val ACC: 0.86, Val MCC: 0.6572
# Epoch 88/200, Train Loss: 0.1490, Train ACC: 0.95%, Train MCC: 0.8883, Val Loss: 0.5948, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 89/200, Train Loss: 0.1704, Train ACC: 0.94%, Train MCC: 0.8588, Val Loss: 0.5722, Val ACC: 0.88, Val MCC: 0.7024
# Epoch 90/200, Train Loss: 0.1451, Train ACC: 0.94%, Train MCC: 0.8558, Val Loss: 0.5746, Val ACC: 0.88, Val MCC: 0.7024
# Epoch 91/200, Train Loss: 0.1315, Train ACC: 0.95%, Train MCC: 0.8904, Val Loss: 0.6297, Val ACC: 0.87, Val MCC: 0.6796
# Epoch 92/200, Train Loss: 0.1662, Train ACC: 0.96%, Train MCC: 0.8985, Val Loss: 0.6251, Val ACC: 0.86, Val MCC: 0.6457
# Epoch 93/200, Train Loss: 0.1406, Train ACC: 0.95%, Train MCC: 0.8798, Val Loss: 0.6191, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 94/200, Train Loss: 0.1353, Train ACC: 0.96%, Train MCC: 0.8993, Val Loss: 0.5990, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 95/200, Train Loss: 0.1438, Train ACC: 0.95%, Train MCC: 0.8775, Val Loss: 0.6140, Val ACC: 0.87, Val MCC: 0.6796
# Epoch 96/200, Train Loss: 0.1355, Train ACC: 0.96%, Train MCC: 0.8929, Val Loss: 0.6040, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 97/200, Train Loss: 0.1277, Train ACC: 0.96%, Train MCC: 0.8982, Val Loss: 0.6099, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 98/200, Train Loss: 0.1431, Train ACC: 0.95%, Train MCC: 0.8933, Val Loss: 0.5921, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 99/200, Train Loss: 0.1322, Train ACC: 0.96%, Train MCC: 0.8993, Val Loss: 0.5918, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 100/200, Train Loss: 0.1546, Train ACC: 0.96%, Train MCC: 0.8977, Val Loss: 0.5858, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 101/200, Train Loss: 0.1299, Train ACC: 0.95%, Train MCC: 0.8785, Val Loss: 0.5810, Val ACC: 0.88, Val MCC: 0.7024
# Epoch 102/200, Train Loss: 0.1504, Train ACC: 0.95%, Train MCC: 0.8757, Val Loss: 0.5973, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 103/200, Train Loss: 0.1434, Train ACC: 0.96%, Train MCC: 0.9067, Val Loss: 0.5917, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 104/200, Train Loss: 0.1657, Train ACC: 0.95%, Train MCC: 0.8775, Val Loss: 0.5828, Val ACC: 0.88, Val MCC: 0.7024
# Epoch 105/200, Train Loss: 0.1431, Train ACC: 0.95%, Train MCC: 0.8778, Val Loss: 0.5978, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 106/200, Train Loss: 0.1356, Train ACC: 0.97%, Train MCC: 0.9205, Val Loss: 0.5895, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 107/200, Train Loss: 0.1582, Train ACC: 0.94%, Train MCC: 0.8652, Val Loss: 0.5852, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 108/200, Train Loss: 0.1356, Train ACC: 0.96%, Train MCC: 0.9033, Val Loss: 0.5915, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 109/200, Train Loss: 0.1492, Train ACC: 0.95%, Train MCC: 0.8815, Val Loss: 0.5993, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 110/200, Train Loss: 0.1954, Train ACC: 0.93%, Train MCC: 0.8429, Val Loss: 0.6047, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 111/200, Train Loss: 0.1431, Train ACC: 0.95%, Train MCC: 0.8757, Val Loss: 0.5931, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 112/200, Train Loss: 0.1292, Train ACC: 0.96%, Train MCC: 0.9019, Val Loss: 0.5987, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 113/200, Train Loss: 0.1387, Train ACC: 0.96%, Train MCC: 0.8929, Val Loss: 0.5869, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 114/200, Train Loss: 0.1371, Train ACC: 0.96%, Train MCC: 0.8972, Val Loss: 0.5957, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 115/200, Train Loss: 0.1383, Train ACC: 0.94%, Train MCC: 0.8696, Val Loss: 0.5927, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 116/200, Train Loss: 0.1717, Train ACC: 0.94%, Train MCC: 0.8578, Val Loss: 0.6129, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 117/200, Train Loss: 0.1411, Train ACC: 0.96%, Train MCC: 0.8944, Val Loss: 0.5772, Val ACC: 0.88, Val MCC: 0.7024
# Epoch 118/200, Train Loss: 0.1299, Train ACC: 0.95%, Train MCC: 0.8798, Val Loss: 0.6009, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 119/200, Train Loss: 0.1178, Train ACC: 0.96%, Train MCC: 0.9051, Val Loss: 0.6038, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 120/200, Train Loss: 0.1308, Train ACC: 0.96%, Train MCC: 0.8929, Val Loss: 0.5827, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 121/200, Train Loss: 0.1266, Train ACC: 0.96%, Train MCC: 0.8953, Val Loss: 0.6011, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 122/200, Train Loss: 0.1686, Train ACC: 0.94%, Train MCC: 0.8597, Val Loss: 0.5862, Val ACC: 0.88, Val MCC: 0.7024
# Epoch 123/200, Train Loss: 0.1125, Train ACC: 0.96%, Train MCC: 0.9061, Val Loss: 0.5696, Val ACC: 0.88, Val MCC: 0.7136
# Epoch 124/200, Train Loss: 0.1515, Train ACC: 0.95%, Train MCC: 0.8726, Val Loss: 0.5963, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 125/200, Train Loss: 0.1369, Train ACC: 0.96%, Train MCC: 0.9074, Val Loss: 0.5925, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 126/200, Train Loss: 0.1505, Train ACC: 0.95%, Train MCC: 0.8778, Val Loss: 0.5895, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 127/200, Train Loss: 0.1528, Train ACC: 0.94%, Train MCC: 0.8637, Val Loss: 0.6008, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 128/200, Train Loss: 0.1395, Train ACC: 0.95%, Train MCC: 0.8847, Val Loss: 0.5752, Val ACC: 0.88, Val MCC: 0.7024
# Epoch 129/200, Train Loss: 0.1183, Train ACC: 0.96%, Train MCC: 0.9033, Val Loss: 0.5933, Val ACC: 0.88, Val MCC: 0.7024
# Epoch 130/200, Train Loss: 0.1231, Train ACC: 0.95%, Train MCC: 0.8864, Val Loss: 0.6105, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 131/200, Train Loss: 0.1644, Train ACC: 0.94%, Train MCC: 0.8619, Val Loss: 0.5893, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 132/200, Train Loss: 0.1511, Train ACC: 0.94%, Train MCC: 0.8707, Val Loss: 0.5889, Val ACC: 0.88, Val MCC: 0.7024
# Epoch 133/200, Train Loss: 0.1314, Train ACC: 0.96%, Train MCC: 0.9013, Val Loss: 0.6129, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 134/200, Train Loss: 0.1269, Train ACC: 0.96%, Train MCC: 0.9026, Val Loss: 0.6077, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 135/200, Train Loss: 0.1446, Train ACC: 0.94%, Train MCC: 0.8718, Val Loss: 0.5987, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 136/200, Train Loss: 0.1550, Train ACC: 0.94%, Train MCC: 0.8489, Val Loss: 0.5904, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 137/200, Train Loss: 0.1265, Train ACC: 0.96%, Train MCC: 0.9074, Val Loss: 0.5997, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 138/200, Train Loss: 0.1902, Train ACC: 0.94%, Train MCC: 0.8529, Val Loss: 0.6142, Val ACC: 0.87, Val MCC: 0.6683
# Epoch 139/200, Train Loss: 0.1358, Train ACC: 0.95%, Train MCC: 0.8815, Val Loss: 0.5990, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 140/200, Train Loss: 0.1228, Train ACC: 0.96%, Train MCC: 0.8985, Val Loss: 0.6207, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 141/200, Train Loss: 0.1451, Train ACC: 0.95%, Train MCC: 0.8785, Val Loss: 0.6027, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 142/200, Train Loss: 0.1274, Train ACC: 0.96%, Train MCC: 0.9026, Val Loss: 0.6038, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 143/200, Train Loss: 0.1324, Train ACC: 0.95%, Train MCC: 0.8717, Val Loss: 0.5937, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 144/200, Train Loss: 0.1340, Train ACC: 0.95%, Train MCC: 0.8847, Val Loss: 0.5850, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 145/200, Train Loss: 0.1568, Train ACC: 0.94%, Train MCC: 0.8668, Val Loss: 0.5873, Val ACC: 0.88, Val MCC: 0.7024
# Epoch 146/200, Train Loss: 0.1634, Train ACC: 0.95%, Train MCC: 0.8824, Val Loss: 0.5852, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 147/200, Train Loss: 0.1246, Train ACC: 0.97%, Train MCC: 0.9212, Val Loss: 0.5759, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 148/200, Train Loss: 0.1362, Train ACC: 0.95%, Train MCC: 0.8894, Val Loss: 0.5912, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 149/200, Train Loss: 0.1475, Train ACC: 0.96%, Train MCC: 0.8929, Val Loss: 0.5976, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 150/200, Train Loss: 0.1305, Train ACC: 0.96%, Train MCC: 0.9011, Val Loss: 0.5909, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 151/200, Train Loss: 0.1427, Train ACC: 0.95%, Train MCC: 0.8757, Val Loss: 0.5761, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 152/200, Train Loss: 0.1399, Train ACC: 0.93%, Train MCC: 0.8442, Val Loss: 0.5936, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 153/200, Train Loss: 0.1333, Train ACC: 0.95%, Train MCC: 0.8873, Val Loss: 0.5967, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 154/200, Train Loss: 0.1294, Train ACC: 0.94%, Train MCC: 0.8696, Val Loss: 0.5992, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 155/200, Train Loss: 0.1260, Train ACC: 0.96%, Train MCC: 0.8985, Val Loss: 0.6106, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 156/200, Train Loss: 0.1430, Train ACC: 0.95%, Train MCC: 0.8798, Val Loss: 0.6063, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 157/200, Train Loss: 0.1352, Train ACC: 0.95%, Train MCC: 0.8864, Val Loss: 0.5961, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 158/200, Train Loss: 0.1535, Train ACC: 0.94%, Train MCC: 0.8677, Val Loss: 0.6004, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 159/200, Train Loss: 0.1483, Train ACC: 0.94%, Train MCC: 0.8686, Val Loss: 0.5867, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 160/200, Train Loss: 0.1348, Train ACC: 0.96%, Train MCC: 0.8953, Val Loss: 0.5865, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 161/200, Train Loss: 0.1911, Train ACC: 0.93%, Train MCC: 0.8281, Val Loss: 0.6364, Val ACC: 0.88, Val MCC: 0.6908
# Epoch 162/200, Train Loss: 0.1537, Train ACC: 0.94%, Train MCC: 0.8588, Val Loss: 0.6048, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 163/200, Train Loss: 0.1330, Train ACC: 0.95%, Train MCC: 0.8798, Val Loss: 0.6205, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 164/200, Train Loss: 0.1361, Train ACC: 0.94%, Train MCC: 0.8680, Val Loss: 0.6015, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 165/200, Train Loss: 0.1271, Train ACC: 0.97%, Train MCC: 0.9193, Val Loss: 0.5914, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 166/200, Train Loss: 0.1423, Train ACC: 0.94%, Train MCC: 0.8660, Val Loss: 0.6025, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 167/200, Train Loss: 0.1078, Train ACC: 0.97%, Train MCC: 0.9212, Val Loss: 0.6047, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 168/200, Train Loss: 0.1315, Train ACC: 0.96%, Train MCC: 0.8936, Val Loss: 0.5934, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 169/200, Train Loss: 0.1425, Train ACC: 0.95%, Train MCC: 0.8775, Val Loss: 0.6254, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 170/200, Train Loss: 0.1517, Train ACC: 0.95%, Train MCC: 0.8824, Val Loss: 0.6179, Val ACC: 0.87, Val MCC: 0.6685
# Epoch 171/200, Train Loss: 0.1576, Train ACC: 0.95%, Train MCC: 0.8855, Val Loss: 0.6083, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 172/200, Train Loss: 0.1445, Train ACC: 0.95%, Train MCC: 0.8775, Val Loss: 0.5930, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 173/200, Train Loss: 0.1341, Train ACC: 0.95%, Train MCC: 0.8756, Val Loss: 0.5883, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 174/200, Train Loss: 0.1405, Train ACC: 0.94%, Train MCC: 0.8647, Val Loss: 0.6000, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 175/200, Train Loss: 0.1580, Train ACC: 0.94%, Train MCC: 0.8647, Val Loss: 0.5851, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 176/200, Train Loss: 0.1400, Train ACC: 0.95%, Train MCC: 0.8791, Val Loss: 0.5893, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 177/200, Train Loss: 0.1476, Train ACC: 0.95%, Train MCC: 0.8888, Val Loss: 0.5777, Val ACC: 0.88, Val MCC: 0.7024
# Epoch 178/200, Train Loss: 0.1652, Train ACC: 0.94%, Train MCC: 0.8558, Val Loss: 0.6033, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 179/200, Train Loss: 0.1361, Train ACC: 0.96%, Train MCC: 0.8977, Val Loss: 0.5891, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 180/200, Train Loss: 0.1429, Train ACC: 0.96%, Train MCC: 0.8972, Val Loss: 0.5949, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 181/200, Train Loss: 0.1232, Train ACC: 0.96%, Train MCC: 0.9019, Val Loss: 0.5972, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 182/200, Train Loss: 0.1569, Train ACC: 0.93%, Train MCC: 0.8504, Val Loss: 0.6049, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 183/200, Train Loss: 0.1364, Train ACC: 0.95%, Train MCC: 0.8913, Val Loss: 0.6164, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 184/200, Train Loss: 0.1637, Train ACC: 0.94%, Train MCC: 0.8558, Val Loss: 0.6102, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 185/200, Train Loss: 0.1390, Train ACC: 0.95%, Train MCC: 0.8896, Val Loss: 0.6127, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 186/200, Train Loss: 0.1563, Train ACC: 0.95%, Train MCC: 0.8806, Val Loss: 0.5934, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 187/200, Train Loss: 0.1514, Train ACC: 0.94%, Train MCC: 0.8637, Val Loss: 0.6013, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 188/200, Train Loss: 0.1333, Train ACC: 0.95%, Train MCC: 0.8795, Val Loss: 0.5977, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 189/200, Train Loss: 0.1674, Train ACC: 0.94%, Train MCC: 0.8677, Val Loss: 0.5787, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 190/200, Train Loss: 0.1440, Train ACC: 0.95%, Train MCC: 0.8701, Val Loss: 0.5832, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 191/200, Train Loss: 0.1396, Train ACC: 0.94%, Train MCC: 0.8597, Val Loss: 0.5861, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 192/200, Train Loss: 0.1384, Train ACC: 0.95%, Train MCC: 0.8824, Val Loss: 0.5949, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 193/200, Train Loss: 0.1422, Train ACC: 0.94%, Train MCC: 0.8637, Val Loss: 0.5778, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 194/200, Train Loss: 0.1491, Train ACC: 0.95%, Train MCC: 0.8742, Val Loss: 0.5801, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 195/200, Train Loss: 0.1505, Train ACC: 0.95%, Train MCC: 0.8775, Val Loss: 0.5810, Val ACC: 0.88, Val MCC: 0.6912
# Epoch 196/200, Train Loss: 0.1327, Train ACC: 0.96%, Train MCC: 0.9067, Val Loss: 0.6022, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 197/200, Train Loss: 0.1310, Train ACC: 0.96%, Train MCC: 0.8936, Val Loss: 0.6059, Val ACC: 0.87, Val MCC: 0.6799
# Epoch 198/200, Train Loss: 0.1557, Train ACC: 0.96%, Train MCC: 0.8985, Val Loss: 0.5917, Val ACC: 0.88, Val MCC: 0.7024
# Epoch 199/200, Train Loss: 0.1397, Train ACC: 0.95%, Train MCC: 0.8839, Val Loss: 0.5739, Val ACC: 0.88, Val MCC: 0.7024
# Epoch 200/200, Train Loss: 0.1136, Train ACC: 0.96%, Train MCC: 0.9051, Val Loss: 0.5869, Val ACC: 0.88, Val MCC: 0.7024

# %%
model = res101
model.eval()
# 加载测试数据集
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_csv_file = "/local/data1/honzh/local_repository/FL/code/4_federated/csv_files/test_data.csv"

test_dataset = CustomDataset(csv_file=test_csv_file, transform=test_transform)

test_model(model, test_dataset)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93      2271
#            1       0.67      0.77      0.72       490
#
#     accuracy                           0.89      2761
#    macro avg       0.81      0.84      0.83      2761
# weighted avg       0.90      0.89      0.90      2761
# {'Total Acc': 0.893,
#  'nff Acc': 0.92,
#  'aff Acc': 0.769,
#  'Precision': 0.674,
#  'Recall': 0.769,
#  'Accuracy': 0.893,
#  'AUC': 0.845,
#  'MCC': 0.655,
#  'F1 Score': 0.719,
#  'ROC_AUC': 0.845,
#  'PRC-AUC': 0.56}

# %% [markdown]
# # densenet161

# %%
from torchvision.models import densenet161, DenseNet161_Weights
from torchvision import transforms, models

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the DenseNet-161 model
model = models.densenet161(weights=DenseNet161_Weights.DEFAULT)

# Modify the classifier part of the model
num_features = model.classifier.in_features
model.classifier = nn.Linear(num_features, 2)

# total layers 
total_layers = len(list(model.features.children()))

# freeze 50% layers
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.features.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False
#---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 200
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

dense161 = train_custom_model(model, train_dataset,val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/200, Train Loss: 0.6665, Train ACC: 0.60%, Train MCC: 0.1668, Val Loss: 0.6539, Val ACC: 0.60, Val MCC: 0.2502
# Epoch 2/200, Train Loss: 0.5599, Train ACC: 0.71%, Train MCC: 0.4354, Val Loss: 0.6856, Val ACC: 0.56, Val MCC: 0.2391
# Epoch 3/200, Train Loss: 0.4476, Train ACC: 0.80%, Train MCC: 0.5507, Val Loss: 0.6683, Val ACC: 0.62, Val MCC: 0.2799
# Epoch 4/200, Train Loss: 0.3500, Train ACC: 0.85%, Train MCC: 0.6591, Val Loss: 0.6031, Val ACC: 0.67, Val MCC: 0.3983
# Epoch 5/200, Train Loss: 0.2893, Train ACC: 0.90%, Train MCC: 0.7556, Val Loss: 0.5243, Val ACC: 0.79, Val MCC: 0.5332
# Epoch 6/200, Train Loss: 0.2359, Train ACC: 0.93%, Train MCC: 0.8221, Val Loss: 0.5792, Val ACC: 0.78, Val MCC: 0.5338
# Epoch 7/200, Train Loss: 0.2143, Train ACC: 0.92%, Train MCC: 0.8115, Val Loss: 0.6400, Val ACC: 0.85, Val MCC: 0.6383
# Epoch 8/200, Train Loss: 0.1755, Train ACC: 0.94%, Train MCC: 0.8580, Val Loss: 0.6984, Val ACC: 0.84, Val MCC: 0.6092
# Epoch 9/200, Train Loss: 0.1540, Train ACC: 0.95%, Train MCC: 0.8709, Val Loss: 0.7023, Val ACC: 0.83, Val MCC: 0.5832
# Epoch 10/200, Train Loss: 0.1223, Train ACC: 0.96%, Train MCC: 0.9157, Val Loss: 0.7792, Val ACC: 0.85, Val MCC: 0.6135
# Epoch 11/200, Train Loss: 0.1015, Train ACC: 0.96%, Train MCC: 0.9060, Val Loss: 0.7146, Val ACC: 0.85, Val MCC: 0.6167
# Epoch 12/200, Train Loss: 0.1184, Train ACC: 0.96%, Train MCC: 0.8977, Val Loss: 0.6768, Val ACC: 0.86, Val MCC: 0.6499
# Epoch 13/200, Train Loss: 0.0765, Train ACC: 0.98%, Train MCC: 0.9479, Val Loss: 0.6609, Val ACC: 0.86, Val MCC: 0.6599
# Epoch 14/200, Train Loss: 0.0845, Train ACC: 0.98%, Train MCC: 0.9409, Val Loss: 0.6120, Val ACC: 0.85, Val MCC: 0.6401
# Epoch 15/200, Train Loss: 0.0788, Train ACC: 0.98%, Train MCC: 0.9515, Val Loss: 0.6140, Val ACC: 0.85, Val MCC: 0.6210
# Epoch 16/200, Train Loss: 0.0983, Train ACC: 0.97%, Train MCC: 0.9378, Val Loss: 0.6097, Val ACC: 0.85, Val MCC: 0.6210
# Epoch 17/200, Train Loss: 0.0737, Train ACC: 0.97%, Train MCC: 0.9342, Val Loss: 0.6039, Val ACC: 0.86, Val MCC: 0.6518
# Epoch 18/200, Train Loss: 0.1189, Train ACC: 0.97%, Train MCC: 0.9369, Val Loss: 0.5911, Val ACC: 0.86, Val MCC: 0.6518
# Epoch 19/200, Train Loss: 0.0678, Train ACC: 0.98%, Train MCC: 0.9553, Val Loss: 0.5977, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 20/200, Train Loss: 0.0633, Train ACC: 0.99%, Train MCC: 0.9636, Val Loss: 0.6255, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 21/200, Train Loss: 0.0826, Train ACC: 0.98%, Train MCC: 0.9412, Val Loss: 0.6264, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 22/200, Train Loss: 0.0768, Train ACC: 0.98%, Train MCC: 0.9409, Val Loss: 0.6219, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 23/200, Train Loss: 0.0733, Train ACC: 0.99%, Train MCC: 0.9684, Val Loss: 0.6219, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 24/200, Train Loss: 0.0819, Train ACC: 0.97%, Train MCC: 0.9373, Val Loss: 0.6157, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 25/200, Train Loss: 0.0500, Train ACC: 0.99%, Train MCC: 0.9865, Val Loss: 0.6389, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 26/200, Train Loss: 0.0969, Train ACC: 0.98%, Train MCC: 0.9473, Val Loss: 0.6123, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 27/200, Train Loss: 0.0890, Train ACC: 0.97%, Train MCC: 0.9240, Val Loss: 0.6303, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 28/200, Train Loss: 0.0600, Train ACC: 0.99%, Train MCC: 0.9687, Val Loss: 0.6320, Val ACC: 0.85, Val MCC: 0.6401
# Epoch 29/200, Train Loss: 0.0760, Train ACC: 0.98%, Train MCC: 0.9600, Val Loss: 0.6128, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 30/200, Train Loss: 0.0681, Train ACC: 0.98%, Train MCC: 0.9503, Val Loss: 0.6168, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 31/200, Train Loss: 0.0746, Train ACC: 0.98%, Train MCC: 0.9420, Val Loss: 0.6066, Val ACC: 0.86, Val MCC: 0.6539
# Epoch 32/200, Train Loss: 0.0603, Train ACC: 0.98%, Train MCC: 0.9463, Val Loss: 0.6215, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 33/200, Train Loss: 0.0564, Train ACC: 0.98%, Train MCC: 0.9596, Val Loss: 0.6198, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 34/200, Train Loss: 0.0569, Train ACC: 0.99%, Train MCC: 0.9690, Val Loss: 0.6204, Val ACC: 0.86, Val MCC: 0.6518
# Epoch 35/200, Train Loss: 0.0723, Train ACC: 0.99%, Train MCC: 0.9637, Val Loss: 0.6328, Val ACC: 0.85, Val MCC: 0.6401
# Epoch 36/200, Train Loss: 0.0557, Train ACC: 0.99%, Train MCC: 0.9640, Val Loss: 0.6198, Val ACC: 0.85, Val MCC: 0.6401
# Epoch 37/200, Train Loss: 0.0664, Train ACC: 0.99%, Train MCC: 0.9643, Val Loss: 0.6205, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 38/200, Train Loss: 0.0923, Train ACC: 0.97%, Train MCC: 0.9283, Val Loss: 0.6148, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 39/200, Train Loss: 0.0520, Train ACC: 0.99%, Train MCC: 0.9864, Val Loss: 0.6200, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 40/200, Train Loss: 0.0401, Train ACC: 0.99%, Train MCC: 0.9774, Val Loss: 0.6232, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 41/200, Train Loss: 0.0712, Train ACC: 0.99%, Train MCC: 0.9643, Val Loss: 0.6334, Val ACC: 0.85, Val MCC: 0.6401
# Epoch 42/200, Train Loss: 0.0627, Train ACC: 0.98%, Train MCC: 0.9550, Val Loss: 0.6297, Val ACC: 0.85, Val MCC: 0.6401
# Epoch 43/200, Train Loss: 0.0474, Train ACC: 0.99%, Train MCC: 0.9682, Val Loss: 0.6237, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 44/200, Train Loss: 0.0539, Train ACC: 0.98%, Train MCC: 0.9600, Val Loss: 0.6316, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 45/200, Train Loss: 0.0817, Train ACC: 0.98%, Train MCC: 0.9420, Val Loss: 0.6183, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 46/200, Train Loss: 0.0667, Train ACC: 0.99%, Train MCC: 0.9687, Val Loss: 0.6188, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 47/200, Train Loss: 0.0641, Train ACC: 0.98%, Train MCC: 0.9459, Val Loss: 0.6126, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 48/200, Train Loss: 0.0504, Train ACC: 0.98%, Train MCC: 0.9596, Val Loss: 0.6307, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 49/200, Train Loss: 0.0678, Train ACC: 0.97%, Train MCC: 0.9384, Val Loss: 0.6212, Val ACC: 0.85, Val MCC: 0.6401
# Epoch 50/200, Train Loss: 0.0557, Train ACC: 0.98%, Train MCC: 0.9600, Val Loss: 0.6215, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 51/200, Train Loss: 0.0916, Train ACC: 0.99%, Train MCC: 0.9643, Val Loss: 0.6039, Val ACC: 0.86, Val MCC: 0.6539
# Epoch 52/200, Train Loss: 0.0815, Train ACC: 0.98%, Train MCC: 0.9416, Val Loss: 0.6007, Val ACC: 0.86, Val MCC: 0.6539
# Epoch 53/200, Train Loss: 0.0679, Train ACC: 0.98%, Train MCC: 0.9416, Val Loss: 0.6107, Val ACC: 0.86, Val MCC: 0.6539
# Epoch 54/200, Train Loss: 0.0695, Train ACC: 0.98%, Train MCC: 0.9412, Val Loss: 0.6051, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 55/200, Train Loss: 0.0546, Train ACC: 0.99%, Train MCC: 0.9818, Val Loss: 0.6003, Val ACC: 0.86, Val MCC: 0.6539
# Epoch 56/200, Train Loss: 0.0672, Train ACC: 0.98%, Train MCC: 0.9503, Val Loss: 0.5991, Val ACC: 0.86, Val MCC: 0.6539
# Epoch 57/200, Train Loss: 0.0681, Train ACC: 0.99%, Train MCC: 0.9640, Val Loss: 0.6094, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 58/200, Train Loss: 0.0604, Train ACC: 0.98%, Train MCC: 0.9596, Val Loss: 0.6075, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 59/200, Train Loss: 0.0665, Train ACC: 0.98%, Train MCC: 0.9596, Val Loss: 0.6128, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 60/200, Train Loss: 0.0759, Train ACC: 0.98%, Train MCC: 0.9547, Val Loss: 0.6258, Val ACC: 0.85, Val MCC: 0.6401
# Epoch 61/200, Train Loss: 0.0585, Train ACC: 0.99%, Train MCC: 0.9643, Val Loss: 0.6219, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 62/200, Train Loss: 0.0694, Train ACC: 0.98%, Train MCC: 0.9547, Val Loss: 0.6259, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 63/200, Train Loss: 0.0726, Train ACC: 0.98%, Train MCC: 0.9468, Val Loss: 0.6238, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 64/200, Train Loss: 0.0784, Train ACC: 0.98%, Train MCC: 0.9463, Val Loss: 0.6178, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 65/200, Train Loss: 0.0823, Train ACC: 0.97%, Train MCC: 0.9336, Val Loss: 0.6072, Val ACC: 0.86, Val MCC: 0.6539
# Epoch 66/200, Train Loss: 0.0634, Train ACC: 0.98%, Train MCC: 0.9550, Val Loss: 0.6251, Val ACC: 0.85, Val MCC: 0.6401
# Epoch 67/200, Train Loss: 0.0747, Train ACC: 0.98%, Train MCC: 0.9558, Val Loss: 0.6183, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 68/200, Train Loss: 0.0532, Train ACC: 0.99%, Train MCC: 0.9730, Val Loss: 0.6253, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 69/200, Train Loss: 0.0704, Train ACC: 0.98%, Train MCC: 0.9506, Val Loss: 0.6169, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 70/200, Train Loss: 0.0443, Train ACC: 0.99%, Train MCC: 0.9819, Val Loss: 0.6104, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 71/200, Train Loss: 0.0580, Train ACC: 0.99%, Train MCC: 0.9773, Val Loss: 0.6160, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 72/200, Train Loss: 0.0537, Train ACC: 0.98%, Train MCC: 0.9593, Val Loss: 0.6169, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 73/200, Train Loss: 0.0596, Train ACC: 0.99%, Train MCC: 0.9727, Val Loss: 0.6239, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 74/200, Train Loss: 0.0503, Train ACC: 0.98%, Train MCC: 0.9596, Val Loss: 0.6243, Val ACC: 0.85, Val MCC: 0.6401
# Epoch 75/200, Train Loss: 0.0596, Train ACC: 0.99%, Train MCC: 0.9730, Val Loss: 0.6325, Val ACC: 0.85, Val MCC: 0.6401
# Epoch 76/200, Train Loss: 0.0615, Train ACC: 0.99%, Train MCC: 0.9640, Val Loss: 0.6274, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 77/200, Train Loss: 0.0704, Train ACC: 0.98%, Train MCC: 0.9550, Val Loss: 0.6256, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 78/200, Train Loss: 0.0512, Train ACC: 0.99%, Train MCC: 0.9684, Val Loss: 0.6298, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 79/200, Train Loss: 0.0614, Train ACC: 0.98%, Train MCC: 0.9459, Val Loss: 0.6172, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 80/200, Train Loss: 0.0492, Train ACC: 0.99%, Train MCC: 0.9774, Val Loss: 0.6139, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 81/200, Train Loss: 0.0890, Train ACC: 0.99%, Train MCC: 0.9640, Val Loss: 0.6131, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 82/200, Train Loss: 0.0597, Train ACC: 0.99%, Train MCC: 0.9643, Val Loss: 0.6157, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 83/200, Train Loss: 0.0729, Train ACC: 0.97%, Train MCC: 0.9384, Val Loss: 0.6261, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 84/200, Train Loss: 0.0495, Train ACC: 0.99%, Train MCC: 0.9818, Val Loss: 0.6222, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 85/200, Train Loss: 0.0546, Train ACC: 0.98%, Train MCC: 0.9550, Val Loss: 0.6331, Val ACC: 0.85, Val MCC: 0.6401
# Epoch 86/200, Train Loss: 0.0774, Train ACC: 0.97%, Train MCC: 0.9336, Val Loss: 0.6329, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 87/200, Train Loss: 0.0545, Train ACC: 0.99%, Train MCC: 0.9728, Val Loss: 0.6206, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 88/200, Train Loss: 0.0554, Train ACC: 0.99%, Train MCC: 0.9640, Val Loss: 0.6173, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 89/200, Train Loss: 0.0720, Train ACC: 0.98%, Train MCC: 0.9553, Val Loss: 0.6170, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 90/200, Train Loss: 0.0708, Train ACC: 0.98%, Train MCC: 0.9553, Val Loss: 0.6212, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 91/200, Train Loss: 0.0575, Train ACC: 0.99%, Train MCC: 0.9636, Val Loss: 0.6199, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 92/200, Train Loss: 0.0466, Train ACC: 0.99%, Train MCC: 0.9863, Val Loss: 0.6318, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 93/200, Train Loss: 0.0646, Train ACC: 0.98%, Train MCC: 0.9550, Val Loss: 0.6161, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 94/200, Train Loss: 0.0639, Train ACC: 0.99%, Train MCC: 0.9730, Val Loss: 0.6187, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 95/200, Train Loss: 0.0505, Train ACC: 0.98%, Train MCC: 0.9596, Val Loss: 0.6210, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 96/200, Train Loss: 0.0637, Train ACC: 0.99%, Train MCC: 0.9637, Val Loss: 0.6220, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 97/200, Train Loss: 0.0556, Train ACC: 0.99%, Train MCC: 0.9643, Val Loss: 0.6224, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 98/200, Train Loss: 0.0856, Train ACC: 0.98%, Train MCC: 0.9553, Val Loss: 0.6227, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 99/200, Train Loss: 0.0566, Train ACC: 0.99%, Train MCC: 0.9637, Val Loss: 0.6163, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 100/200, Train Loss: 0.0494, Train ACC: 0.99%, Train MCC: 0.9733, Val Loss: 0.6218, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 101/200, Train Loss: 0.0593, Train ACC: 0.99%, Train MCC: 0.9637, Val Loss: 0.6232, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 102/200, Train Loss: 0.0546, Train ACC: 0.99%, Train MCC: 0.9640, Val Loss: 0.6156, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 103/200, Train Loss: 0.0754, Train ACC: 0.99%, Train MCC: 0.9730, Val Loss: 0.6083, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 104/200, Train Loss: 0.0516, Train ACC: 0.98%, Train MCC: 0.9600, Val Loss: 0.6106, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 105/200, Train Loss: 0.0628, Train ACC: 0.98%, Train MCC: 0.9550, Val Loss: 0.6162, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 106/200, Train Loss: 0.0543, Train ACC: 0.99%, Train MCC: 0.9684, Val Loss: 0.6082, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 107/200, Train Loss: 0.0470, Train ACC: 0.98%, Train MCC: 0.9600, Val Loss: 0.6140, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 108/200, Train Loss: 0.0779, Train ACC: 0.98%, Train MCC: 0.9426, Val Loss: 0.6139, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 109/200, Train Loss: 0.0546, Train ACC: 0.98%, Train MCC: 0.9547, Val Loss: 0.6102, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 110/200, Train Loss: 0.0611, Train ACC: 0.99%, Train MCC: 0.9640, Val Loss: 0.6178, Val ACC: 0.85, Val MCC: 0.6401
# Epoch 111/200, Train Loss: 0.0683, Train ACC: 0.98%, Train MCC: 0.9506, Val Loss: 0.6241, Val ACC: 0.85, Val MCC: 0.6401
# Epoch 112/200, Train Loss: 0.0568, Train ACC: 0.99%, Train MCC: 0.9733, Val Loss: 0.6211, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 113/200, Train Loss: 0.0649, Train ACC: 0.99%, Train MCC: 0.9643, Val Loss: 0.6225, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 114/200, Train Loss: 0.0555, Train ACC: 0.99%, Train MCC: 0.9684, Val Loss: 0.6293, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 115/200, Train Loss: 0.0551, Train ACC: 0.99%, Train MCC: 0.9690, Val Loss: 0.6227, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 116/200, Train Loss: 0.0529, Train ACC: 0.99%, Train MCC: 0.9682, Val Loss: 0.6167, Val ACC: 0.85, Val MCC: 0.6401
# Epoch 117/200, Train Loss: 0.0772, Train ACC: 0.99%, Train MCC: 0.9640, Val Loss: 0.6274, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 118/200, Train Loss: 0.0543, Train ACC: 0.99%, Train MCC: 0.9773, Val Loss: 0.6121, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 119/200, Train Loss: 0.0543, Train ACC: 0.99%, Train MCC: 0.9690, Val Loss: 0.6189, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 120/200, Train Loss: 0.0427, Train ACC: 0.99%, Train MCC: 0.9682, Val Loss: 0.6118, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 121/200, Train Loss: 0.0763, Train ACC: 0.98%, Train MCC: 0.9506, Val Loss: 0.6100, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 122/200, Train Loss: 0.0775, Train ACC: 0.98%, Train MCC: 0.9468, Val Loss: 0.6005, Val ACC: 0.86, Val MCC: 0.6539
# Epoch 123/200, Train Loss: 0.0673, Train ACC: 0.98%, Train MCC: 0.9591, Val Loss: 0.6097, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 124/200, Train Loss: 0.0612, Train ACC: 0.98%, Train MCC: 0.9593, Val Loss: 0.6108, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 125/200, Train Loss: 0.0577, Train ACC: 0.99%, Train MCC: 0.9728, Val Loss: 0.6186, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 126/200, Train Loss: 0.0521, Train ACC: 0.99%, Train MCC: 0.9690, Val Loss: 0.6225, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 127/200, Train Loss: 0.0762, Train ACC: 0.98%, Train MCC: 0.9510, Val Loss: 0.6156, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 128/200, Train Loss: 0.0596, Train ACC: 0.98%, Train MCC: 0.9593, Val Loss: 0.6139, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 129/200, Train Loss: 0.0701, Train ACC: 0.99%, Train MCC: 0.9773, Val Loss: 0.6165, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 130/200, Train Loss: 0.0681, Train ACC: 0.98%, Train MCC: 0.9420, Val Loss: 0.6176, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 131/200, Train Loss: 0.0530, Train ACC: 0.99%, Train MCC: 0.9637, Val Loss: 0.6131, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 132/200, Train Loss: 0.0736, Train ACC: 0.98%, Train MCC: 0.9593, Val Loss: 0.6236, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 133/200, Train Loss: 0.0518, Train ACC: 0.99%, Train MCC: 0.9637, Val Loss: 0.6120, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 134/200, Train Loss: 0.0526, Train ACC: 0.99%, Train MCC: 0.9727, Val Loss: 0.6158, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 135/200, Train Loss: 0.0576, Train ACC: 0.99%, Train MCC: 0.9637, Val Loss: 0.6256, Val ACC: 0.85, Val MCC: 0.6401
# Epoch 136/200, Train Loss: 0.0759, Train ACC: 0.97%, Train MCC: 0.9294, Val Loss: 0.6080, Val ACC: 0.86, Val MCC: 0.6539
# Epoch 137/200, Train Loss: 0.0641, Train ACC: 0.98%, Train MCC: 0.9459, Val Loss: 0.6098, Val ACC: 0.86, Val MCC: 0.6539
# Epoch 138/200, Train Loss: 0.0681, Train ACC: 0.98%, Train MCC: 0.9426, Val Loss: 0.6188, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 139/200, Train Loss: 0.0588, Train ACC: 0.98%, Train MCC: 0.9596, Val Loss: 0.6159, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 140/200, Train Loss: 0.0615, Train ACC: 0.99%, Train MCC: 0.9730, Val Loss: 0.6037, Val ACC: 0.86, Val MCC: 0.6539
# Epoch 141/200, Train Loss: 0.0616, Train ACC: 0.99%, Train MCC: 0.9643, Val Loss: 0.5979, Val ACC: 0.86, Val MCC: 0.6539
# Epoch 142/200, Train Loss: 0.0555, Train ACC: 0.99%, Train MCC: 0.9684, Val Loss: 0.6153, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 143/200, Train Loss: 0.0625, Train ACC: 0.98%, Train MCC: 0.9600, Val Loss: 0.6158, Val ACC: 0.86, Val MCC: 0.6539
# Epoch 144/200, Train Loss: 0.0517, Train ACC: 0.98%, Train MCC: 0.9596, Val Loss: 0.6151, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 145/200, Train Loss: 0.0793, Train ACC: 0.97%, Train MCC: 0.9330, Val Loss: 0.6215, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 146/200, Train Loss: 0.0564, Train ACC: 0.99%, Train MCC: 0.9684, Val Loss: 0.6128, Val ACC: 0.85, Val MCC: 0.6401
# Epoch 147/200, Train Loss: 0.0676, Train ACC: 0.99%, Train MCC: 0.9690, Val Loss: 0.6212, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 148/200, Train Loss: 0.0636, Train ACC: 0.98%, Train MCC: 0.9506, Val Loss: 0.6297, Val ACC: 0.85, Val MCC: 0.6401
# Epoch 149/200, Train Loss: 0.0667, Train ACC: 0.98%, Train MCC: 0.9596, Val Loss: 0.6296, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 150/200, Train Loss: 0.0651, Train ACC: 0.98%, Train MCC: 0.9500, Val Loss: 0.6276, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 151/200, Train Loss: 0.0580, Train ACC: 0.99%, Train MCC: 0.9777, Val Loss: 0.6226, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 152/200, Train Loss: 0.0887, Train ACC: 0.98%, Train MCC: 0.9420, Val Loss: 0.6107, Val ACC: 0.86, Val MCC: 0.6539
# Epoch 153/200, Train Loss: 0.0575, Train ACC: 0.99%, Train MCC: 0.9681, Val Loss: 0.6200, Val ACC: 0.86, Val MCC: 0.6518
# Epoch 154/200, Train Loss: 0.0821, Train ACC: 0.98%, Train MCC: 0.9503, Val Loss: 0.6305, Val ACC: 0.85, Val MCC: 0.6401
# Epoch 155/200, Train Loss: 0.0652, Train ACC: 0.98%, Train MCC: 0.9506, Val Loss: 0.6344, Val ACC: 0.85, Val MCC: 0.6401
# Epoch 156/200, Train Loss: 0.0803, Train ACC: 0.97%, Train MCC: 0.9274, Val Loss: 0.6351, Val ACC: 0.85, Val MCC: 0.6401
# Epoch 157/200, Train Loss: 0.0765, Train ACC: 0.98%, Train MCC: 0.9553, Val Loss: 0.6236, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 158/200, Train Loss: 0.0585, Train ACC: 0.99%, Train MCC: 0.9637, Val Loss: 0.6150, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 159/200, Train Loss: 0.0593, Train ACC: 0.99%, Train MCC: 0.9637, Val Loss: 0.6167, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 160/200, Train Loss: 0.0687, Train ACC: 0.98%, Train MCC: 0.9547, Val Loss: 0.6184, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 161/200, Train Loss: 0.0519, Train ACC: 0.99%, Train MCC: 0.9819, Val Loss: 0.6172, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 162/200, Train Loss: 0.0460, Train ACC: 0.99%, Train MCC: 0.9637, Val Loss: 0.6106, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 163/200, Train Loss: 0.0693, Train ACC: 0.98%, Train MCC: 0.9596, Val Loss: 0.6172, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 164/200, Train Loss: 0.0626, Train ACC: 0.99%, Train MCC: 0.9640, Val Loss: 0.6145, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 165/200, Train Loss: 0.0506, Train ACC: 0.99%, Train MCC: 0.9687, Val Loss: 0.6162, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 166/200, Train Loss: 0.0586, Train ACC: 0.99%, Train MCC: 0.9687, Val Loss: 0.6102, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 167/200, Train Loss: 0.0741, Train ACC: 0.98%, Train MCC: 0.9503, Val Loss: 0.6264, Val ACC: 0.85, Val MCC: 0.6401
# Epoch 168/200, Train Loss: 0.0803, Train ACC: 0.98%, Train MCC: 0.9547, Val Loss: 0.6032, Val ACC: 0.86, Val MCC: 0.6539
# Epoch 169/200, Train Loss: 0.0696, Train ACC: 0.98%, Train MCC: 0.9416, Val Loss: 0.6169, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 170/200, Train Loss: 0.0538, Train ACC: 0.99%, Train MCC: 0.9643, Val Loss: 0.6153, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 171/200, Train Loss: 0.0627, Train ACC: 0.99%, Train MCC: 0.9684, Val Loss: 0.6206, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 172/200, Train Loss: 0.0557, Train ACC: 0.99%, Train MCC: 0.9684, Val Loss: 0.6237, Val ACC: 0.85, Val MCC: 0.6401
# Epoch 173/200, Train Loss: 0.0648, Train ACC: 0.99%, Train MCC: 0.9682, Val Loss: 0.6336, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 174/200, Train Loss: 0.0734, Train ACC: 0.98%, Train MCC: 0.9459, Val Loss: 0.6156, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 175/200, Train Loss: 0.0563, Train ACC: 0.98%, Train MCC: 0.9596, Val Loss: 0.6127, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 176/200, Train Loss: 0.0484, Train ACC: 0.99%, Train MCC: 0.9728, Val Loss: 0.6233, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 177/200, Train Loss: 0.0474, Train ACC: 0.99%, Train MCC: 0.9777, Val Loss: 0.6212, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 178/200, Train Loss: 0.0517, Train ACC: 0.99%, Train MCC: 0.9730, Val Loss: 0.6179, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 179/200, Train Loss: 0.0519, Train ACC: 0.99%, Train MCC: 0.9774, Val Loss: 0.6156, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 180/200, Train Loss: 0.0492, Train ACC: 0.99%, Train MCC: 0.9728, Val Loss: 0.6170, Val ACC: 0.86, Val MCC: 0.6539
# Epoch 181/200, Train Loss: 0.0624, Train ACC: 0.98%, Train MCC: 0.9547, Val Loss: 0.6273, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 182/200, Train Loss: 0.0577, Train ACC: 0.99%, Train MCC: 0.9684, Val Loss: 0.6249, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 183/200, Train Loss: 0.0631, Train ACC: 0.99%, Train MCC: 0.9637, Val Loss: 0.6278, Val ACC: 0.86, Val MCC: 0.6518
# Epoch 184/200, Train Loss: 0.0735, Train ACC: 0.98%, Train MCC: 0.9412, Val Loss: 0.6340, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 185/200, Train Loss: 0.0590, Train ACC: 0.99%, Train MCC: 0.9730, Val Loss: 0.6292, Val ACC: 0.85, Val MCC: 0.6401
# Epoch 186/200, Train Loss: 0.0462, Train ACC: 0.99%, Train MCC: 0.9864, Val Loss: 0.6179, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 187/200, Train Loss: 0.0472, Train ACC: 0.99%, Train MCC: 0.9728, Val Loss: 0.6181, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 188/200, Train Loss: 0.0727, Train ACC: 0.98%, Train MCC: 0.9506, Val Loss: 0.6081, Val ACC: 0.86, Val MCC: 0.6539
# Epoch 189/200, Train Loss: 0.0602, Train ACC: 0.98%, Train MCC: 0.9503, Val Loss: 0.6135, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 190/200, Train Loss: 0.0635, Train ACC: 0.98%, Train MCC: 0.9593, Val Loss: 0.6184, Val ACC: 0.85, Val MCC: 0.6305
# Epoch 191/200, Train Loss: 0.0680, Train ACC: 0.98%, Train MCC: 0.9550, Val Loss: 0.6219, Val ACC: 0.85, Val MCC: 0.6401
# Epoch 192/200, Train Loss: 0.0638, Train ACC: 0.98%, Train MCC: 0.9515, Val Loss: 0.6075, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 193/200, Train Loss: 0.0568, Train ACC: 0.99%, Train MCC: 0.9773, Val Loss: 0.6265, Val ACC: 0.85, Val MCC: 0.6401
# Epoch 194/200, Train Loss: 0.0648, Train ACC: 0.98%, Train MCC: 0.9593, Val Loss: 0.6187, Val ACC: 0.86, Val MCC: 0.6518
# Epoch 195/200, Train Loss: 0.0542, Train ACC: 0.99%, Train MCC: 0.9640, Val Loss: 0.6182, Val ACC: 0.86, Val MCC: 0.6518
# Epoch 196/200, Train Loss: 0.0813, Train ACC: 0.97%, Train MCC: 0.9330, Val Loss: 0.6219, Val ACC: 0.85, Val MCC: 0.6401
# Epoch 197/200, Train Loss: 0.0640, Train ACC: 0.99%, Train MCC: 0.9684, Val Loss: 0.6120, Val ACC: 0.85, Val MCC: 0.6422
# Epoch 198/200, Train Loss: 0.0742, Train ACC: 0.98%, Train MCC: 0.9547, Val Loss: 0.6066, Val ACC: 0.86, Val MCC: 0.6539
# Epoch 199/200, Train Loss: 0.0784, Train ACC: 0.98%, Train MCC: 0.9515, Val Loss: 0.6045, Val ACC: 0.86, Val MCC: 0.6539
# Epoch 200/200, Train Loss: 0.0535, Train ACC: 0.99%, Train MCC: 0.9687, Val Loss: 0.6239, Val ACC: 0.85, Val MCC: 0.6305

# %%
model = dense161
model.eval()
# 加载测试数据集
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_csv_file = "/local/data1/honzh/local_repository/FL/code/4_federated/csv_files/test_data.csv"

test_dataset = CustomDataset(csv_file=test_csv_file, transform=test_transform)

test_model(model, test_dataset)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93      2271
#            1       0.66      0.79      0.72       490
#
#     accuracy                           0.89      2761
#    macro avg       0.81      0.85      0.83      2761
# weighted avg       0.90      0.89      0.89      2761
# {'Total Acc': 0.891,
#  'nff Acc': 0.914,
#  'aff Acc': 0.788,
#  'Precision': 0.663,
#  'Recall': 0.788,
#  'Accuracy': 0.891,
#  'AUC': 0.851,
#  'MCC': 0.657,
#  'F1 Score': 0.72,
#  'ROC_AUC': 0.851,
#  'PRC-AUC': 0.56}
