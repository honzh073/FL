# %% [markdown]
# # create data

# %%
# import pandas as pd

# df_hospital18 = pd.read_csv("/local/data1/honzh/local_repository/FL/code/2_local/hospital18.csv")
# df_hospital43 = pd.read_csv("/local/data1/honzh/local_repository/FL/code/2_local/hospital43.csv")
# df_hospital55 = pd.read_csv("/local/data1/honzh/local_repository/FL/code/2_local/hospital55.csv")


# df_combined = pd.concat([df_hospital18, df_hospital43, df_hospital55], ignore_index=True)

# df_combined.to_csv("/local/data1/honzh/local_repository/FL/code/3_centralized/this_centralized/centralized_data.csv", index=False)

# %% [markdown]
# # create csv file

# %%
# import json
# import os
# import pandas as pd

# # Function to read data from JSON file
# def read_json_file(file_path):
#     with open(file_path, 'r') as file:
#         data = json.load(file)
#     return data

# # Function to create CSV file
# def create_csv_file(output_path, data):
#     df = pd.DataFrame(data)
#     df.to_csv(output_path, index=False)

# # Paths to JSON files
# json_file_paths = [
#     '/local/data1/honzh/local_repository/FL/code/1_create_data/data1/hospital18_1.json',
#     '/local/data1/honzh/local_repository/FL/code/1_create_data/data1/hospital22_1.json',
#     '/local/data1/honzh/local_repository/FL/code/1_create_data/data1/hospital43_1.json',
#     '/local/data1/honzh/local_repository/FL/code/1_create_data/data1/hospital45_1.json',
#     '/local/data1/honzh/local_repository/FL/code/1_create_data/data1/hospital55_1.json'
# ]

# # Output CSV file paths
# output_csv_paths = [
#     '/local/data1/honzh/local_repository/FL/code/3_centralized/csv_files/5node_train.csv',
#     '/local/data1/honzh/local_repository/FL/code/3_centralized/csv_files/5node_val.csv'
# ]

# # Read data from JSON files and create CSV files
# combined_train_data = []
# combined_val_data = []

# for json_path in json_file_paths:
#     json_data = read_json_file(json_path)
#     combined_train_data.extend(json_data.get('train', []))
#     combined_val_data.extend(json_data.get('val', []))

# # Create CSV files
# create_csv_file(output_csv_paths[0], combined_train_data)
# create_csv_file(output_csv_paths[1], combined_val_data)

# # Display success message
# print("CSV files created.")

# %% [markdown]
# # split train and validation dataset

# %%
# import pandas as pd
# from sklearn.model_selection import train_test_split

# # Load the original CSV file
# csv_file_path = "/local/data1/honzh/local_repository/FL/code/3_centralized/this_centralized/centralized_data.csv"
# df = pd.read_csv(csv_file_path)

# # Unique patient IDs
# unique_patient_ids = df['PatientID'].unique()

# # Split the patient IDs into training and validation sets
# train_patient_ids, val_patient_ids = train_test_split(unique_patient_ids, test_size=0.3, random_state=1)

# # Create subsets based on patient IDs
# train_data = df[df['PatientID'].isin(train_patient_ids)]
# val_data = df[df['PatientID'].isin(val_patient_ids)]

# # Save the subsets to separate CSV files if needed
# train_data.to_csv("/local/data1/honzh/local_repository/FL/code/3_centralized/this_centralized/centralized_train.csv", index=False)
# val_data.to_csv("/local/data1/honzh/local_repository/FL/code/3_centralized/this_centralized/centralized_val.csv", index=False)

# %%
from torch.utils.data import Dataset
from PIL import Image
import csv
from torchvision import transforms
import torch
import numpy as np
import matplotlib.pyplot as plt

  
class CustomDataset(Dataset):
    def __init__(self, csv_file, transform=None):
        self.data = []
        self.labels = []
        self.patient_ids = []
        self.transform = transform
        
        with open(csv_file, 'r') as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                image_path = row['ImagePath']
                label = row['Label']
                patient_id = row['PatientID']
                
                if label == 'NFF':
                    label = 0
                elif label == 'AFF':
                    label = 1
                else:
                    raise ValueError("Invalid label in CSV file.")
                
                self.data.append((image_path, label))
                self.labels.append(label)
                self.patient_ids.append(patient_id)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image_path, label = self.data[idx]
        image = Image.open(image_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image, label

# show x ray image
def show_image(dataset, num_images=5):
    random_indices = np.random.choice(len(dataset), num_images, replace=False)
    
    plt.figure(figsize=(15, 5))
    for i, idx in enumerate(random_indices):
        image, label = dataset[idx]
        filename = dataset.data[idx][0]
        truncated_filename = filename.split('/')[-1][:15]
        
        print(f"Image location: {filename}")

        plt.subplot(1, num_images, i + 1)
        plt.title(f"Label: {label}")
        plt.imshow(image[0])
        plt.axis('off')
    plt.show()

# model parameters number
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# calculate class weight
def get_class_weight(train_dataset):
    train_nff_count = sum(1 for _, label in train_dataset if label == 0)
    train_aff_count = sum(1 for _, label in train_dataset if label == 1)
    class_weight_nff = 1 / (2 * (train_nff_count / (train_nff_count + train_aff_count)))
    class_weight_aff = 1 / (2 * (train_aff_count / (train_nff_count + train_aff_count)))
    
    
    return [class_weight_nff, class_weight_aff]

# %% [markdown]
# # smooth accuracy loss mcc

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import matthews_corrcoef

import random

# Set random seed
seed = 1
torch.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)

# CUDA seed 
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

def smooth_curve(points, factor=0.8):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points

# train function with early stopping
def train_custom_model(model, train_dataset, val_dataset, num_epochs, batch_size, optimizer):
    # patience = 40  # early stopping
    classweight = get_class_weight(train_dataset)
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model = model.to(device)
    criterion = nn.CrossEntropyLoss(weight=torch.Tensor(classweight).to(device))

    train_loader = DataLoader(train_dataset, batch_size=batch_size,shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    # Create a learning rate scheduler
    lr_scheduler_step = 10  # Adjust this value based on your requirement
    scheduler = lr_scheduler.StepLR(optimizer, step_size=lr_scheduler_step, gamma=0.1)

    best_acc = 0  # Initialize best accuracy value  # Change here
    best_model = None

    # consecutive_no_improvement = 0  # Counter for consecutive epochs without improvement

    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []
    train_mccs = []  # List to store MCC values for each epoch
    val_mccs = []  # List to store MCC values for each epoch

    for epoch in range(num_epochs):
        model.train()
        correct_train = 0
        total_train = 0
        train_loss = 0

        all_train_labels = []  # List to store labels for the entire training set
        all_train_predictions = []  # List to store predictions for the entire training set

        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
            train_loss += loss.item()

            all_train_labels.extend(labels.cpu().numpy())
            all_train_predictions.extend(predicted.cpu().numpy())

        train_accuracy = correct_train / total_train
        train_loss /= len(train_loader)

        # Calculate MCC for training set
        train_mcc = matthews_corrcoef(all_train_labels, all_train_predictions)

        model.eval()
        correct_validation = 0
        total_validation = 0
        validation_loss = 0

        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)

                _, predicted = torch.max(outputs.data, 1)
                total_validation += labels.size(0)
                correct_validation += (predicted == labels).sum().item()
                validation_loss += loss.item()

            validation_accuracy = correct_validation / total_validation
            validation_loss /= len(val_loader)

            # Calculate MCC for validation set
            all_val_labels = []  # List to store labels for the entire validation set
            all_val_predictions = []  # List to store predictions for the entire validation set
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                outputs = model(images)
                _, predicted = torch.max(outputs.data, 1)
                all_val_labels.extend(labels.cpu().numpy())
                all_val_predictions.extend(predicted.cpu().numpy())

            val_mcc = matthews_corrcoef(all_val_labels, all_val_predictions)

            print(f"Epoch {epoch + 1}/{num_epochs}, "
                  f"Train Loss: {train_loss:.4f}, Train ACC: {train_accuracy:.2f}%, Train MCC: {train_mcc:.4f}, "
                  f"Val Loss: {validation_loss:.4f}, Val ACC: {validation_accuracy:.2f}, Val MCC: {val_mcc:.4f}")

            # Early stopping check
            if validation_accuracy > best_acc:  # Change here
                best_acc = validation_accuracy  # Change here
                # Save the best model
                best_model = model
                
            # early stopping 
            # if consecutive_no_improvement >= patience:
            #     print(f"No improvement in MCC for {patience} consecutive epochs. Early stopping.")
            #     break

        # Append metrics for plotting
        train_losses.append(train_loss)
        val_losses.append(validation_loss)
        train_accuracies.append(train_accuracy)
        val_accuracies.append(validation_accuracy)
        train_mccs.append(train_mcc)
        val_mccs.append(val_mcc)

        # Step the learning rate scheduler
        scheduler.step()

    # Plotting with smoothing and original curves
    plt.figure(figsize=(15, 5))

    # Plotting Loss
    plt.subplot(1, 3, 1)
    plt.plot(range(1, len(train_losses) + 1), smooth_curve(train_losses), label='Train Loss(smoothed)', color='blue')
    plt.plot(range(1, len(val_losses) + 1), smooth_curve(val_losses), label='Validation Loss (smoothed)', color='orange')
    plt.plot(range(1, len(train_losses) + 1), train_losses, linestyle='dashed', label='Train Loss', color='lightblue')
    plt.plot(range(1, len(val_losses) + 1), val_losses, linestyle='dashed', label='Validation Loss', color='navajowhite')
    plt.xlabel('Epoch', fontsize = 15)
    plt.ylabel('Loss', fontsize = 15)
    plt.ylim(0, 1)  # Set Y-axis limits
    plt.legend()

    # Plotting Accuracy
    plt.subplot(1, 3, 2)
    plt.plot(range(1, len(train_accuracies) + 1), smooth_curve(train_accuracies), label='Train Accuracy (smoothed)', color='green')
    plt.plot(range(1, len(val_accuracies) + 1), smooth_curve(val_accuracies), label='Validation Accuracy (smoothed)', color='red')
    plt.plot(range(1, len(train_accuracies) + 1), train_accuracies, linestyle='dashed', label='Train Accuracy', color='lightgreen')
    plt.plot(range(1, len(val_accuracies) + 1), val_accuracies, linestyle='dashed', label='Validation Accuracy', color='lightcoral')
    plt.xlabel('Epoch', fontsize = 15)
    plt.ylabel('Accuracy', fontsize = 15)
    plt.ylim(0, 1)  # Set Y-axis limits
    plt.legend()

    # Plotting MCC
    plt.subplot(1, 3, 3)
    plt.plot(range(1, len(train_mccs) + 1), smooth_curve(train_mccs), label='Train MCC (smoothed)', color='purple')
    plt.plot(range(1, len(val_mccs) + 1), smooth_curve(val_mccs), label='Validation MCC (smoothed)', color='black')
    plt.plot(range(1, len(train_mccs) + 1), train_mccs, linestyle='dashed', label='Train MCC', color='plum')
    plt.plot(range(1, len(val_mccs) + 1), val_mccs, linestyle='dashed', label='Validation MCC', color='grey')
    plt.xlabel('Epoch', fontsize = 15)
    plt.ylabel('MCC', fontsize = 15)
    plt.ylim(0, 1)  # Set Y-axis limits
    plt.legend()

    plt.tight_layout()
    plt.show()

    return best_model  # Return the model with the best MCC

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import matthews_corrcoef, f1_score
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, average_precision_score, precision_score, recall_score, accuracy_score
import torchvision.transforms as transforms
import random

def test_model(model, test_dataset):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, pin_memory=True)
    model = model.to(device)

    model.eval()

    correct_test_nff = 0
    correct_test_aff = 0
    total_nff = 0
    total_aff = 0
    total_test = 0
    test_loss = 0

    criterion = nn.CrossEntropyLoss()

    with torch.no_grad():
        all_predictions = []
        all_labels = []
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            _, predicted = torch.max(outputs.data, 1)
            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            total_test += labels.size(0)
            total_nff += (labels == 0).sum().item()
            total_aff += (labels == 1).sum().item()
            correct_test_nff += ((predicted == labels) & (labels == 0)).sum().item()
            correct_test_aff += ((predicted == labels) & (labels == 1)).sum().item()
            test_loss += loss.item()

    # Check if total_aff is zero before performing the division
    test_accuracy_nff = correct_test_nff / total_nff if total_nff != 0 else 0
    test_accuracy_aff = correct_test_aff / total_aff if total_aff != 0 else 0
    test_accuracy_total = (correct_test_nff + correct_test_aff) / total_test
    test_loss /= len(test_loader)

    conf_matrix = confusion_matrix(all_labels, all_predictions)

    # Directly use class labels as strings in target_names
    target_names = ['NFF', 'AFF']

    classification_rep = classification_report(all_labels, all_predictions)

    # Calculate AUC
    auc_score = roc_auc_score(all_labels, all_predictions)

    # Calculate Matthew's correlation coefficient
    mcc_score = matthews_corrcoef(all_labels, all_predictions)

    # Calculate F1 score
    f1_score_value = f1_score(all_labels, all_predictions)

    # Calculate Precision, Recall, Accuracy, ROC-AUC, and PRC-AUC
    precision_value = precision_score(all_labels, all_predictions)
    recall_value = recall_score(all_labels, all_predictions)
    accuracy_value = accuracy_score(all_labels, all_predictions)
    roc_auc_value = roc_auc_score(all_labels, all_predictions)
    prc_auc_value = average_precision_score(all_labels, all_predictions)

    # Store metrics in a dictionary
    metrics = {
        "Total Acc": round(test_accuracy_total, 3),
        "nff Acc": round(test_accuracy_nff, 3),
        "aff Acc": round(test_accuracy_aff, 3),
        "Precision": round(precision_value, 3),
        "Recall": round(recall_value, 3),
        "Accuracy": round(accuracy_value, 3),
        "AUC": round(auc_score, 3),
        "MCC": round(mcc_score, 3),
        "F1 Score": round(f1_score_value, 3),
        "ROC_AUC": round(roc_auc_value, 3),
        "PRC-AUC": round(prc_auc_value, 3)
    }

    # Confusion Matrix
    plt.figure(figsize=(6, 4))
    sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=target_names, yticklabels=target_names)
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()

    # Classification Report
    print("Classification Report:")
    print(classification_rep)

    # Print all metrics
    # for metric_name, metric_value in metrics.items():
    #     print(f"{metric_name}: {metric_value}")

    return metrics

# %%
# Image transformations
train_transforms = transforms.Compose([
    transforms.RandomRotation(degrees=30),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.GaussianBlur(kernel_size=3),
    transforms.RandomEqualize(),
    transforms.RandomAdjustSharpness(sharpness_factor=5),
    # transforms.RandomPerspective(distortion_scale=0.6),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

val_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load datasets
train_dataset = CustomDataset('/local/data1/honzh/local_repository/FL/code/3_centralized/csv_files/5node_train.csv', transform=train_transforms)
val_dataset = CustomDataset('/local/data1/honzh/local_repository/FL/code/3_centralized/csv_files/5node_val.csv', transform=val_transforms)
class_weights = get_class_weight(train_dataset)
print('Training class weights:', class_weights)

# Show images
show_image(train_dataset, 5)

# Calculate numbers
print('-----------------------------------')
train_NFF_count = sum(1 for _, label in train_dataset if label == 0)
train_AFF_count = sum(1 for _, label in train_dataset if label == 1)

print(f"train AFF: {train_AFF_count}, ratio: {train_AFF_count / (train_AFF_count + train_NFF_count):.2f}")
print(f"----- NFF: {train_NFF_count}, ratio: {train_NFF_count / (train_AFF_count + train_NFF_count):.2f}")

print('-----------------------------------')
train_NFF_count = sum(1 for _, label in val_dataset if label == 0)
train_AFF_count = sum(1 for _, label in val_dataset if label == 1)

print(f"val AFF: {train_AFF_count}, ratio: {train_AFF_count / (train_AFF_count + train_NFF_count):.2f}")
print(f"----- NFF: {train_NFF_count}, ratio: {train_NFF_count / (train_AFF_count + train_NFF_count):.2f}")
# Out:
# Training class weights: [0.7015706806282722, 1.7402597402597402]
# Image location: /local/data1/honzh/data/8bit_down224/patient_MDONJWILGU_hospital_45_NFF_image_6.png
# Image location: /local/data1/honzh/data/8bit_down224/patient_BTRPFSSIAV_hospital_55_NFF_image_5.png
# Image location: /local/data1/honzh/data/8bit_down224/patient_NYQYGRHRSB_hospital_43_NFF_image_2.png
# Image location: /local/data1/honzh/data/8bit_down224/patient_YCCDEQOBYS_hospital_43_NFF_image_3.png
# Image location: /local/data1/honzh/data/8bit_down224/patient_XWSXMJCZWA_hospital_43_NFF_image_2.png
# -----------------------------------
# train AFF: 154, ratio: 0.29
# ----- NFF: 382, ratio: 0.71
# -----------------------------------
# val AFF: 69, ratio: 0.30
# ----- NFF: 164, ratio: 0.70

# %% [markdown]
# # VGG 19

# %%
from torchvision.models import vgg19, VGG19_Weights
from torchvision import transforms, models

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the VGG-19 model
model = models.vgg19(weights=VGG19_Weights.DEFAULT)

# Modify the classifier part of the model
num_features = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_features, 2)

# layer number
total_layers = len(list(model.features.children()))

# freeze 50% layer
freeze_layers = int(total_layers * 0.3)
for index, child in enumerate(model.features.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False
# ---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 200
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

vgg19 = train_custom_model(model, train_dataset, val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/200, Train Loss: 0.7136, Train ACC: 0.57%, Train MCC: 0.0702, Val Loss: 0.6588, Val ACC: 0.75, Val MCC: 0.3744
# Epoch 2/200, Train Loss: 0.6396, Train ACC: 0.64%, Train MCC: 0.2434, Val Loss: 0.8992, Val ACC: 0.33, Val MCC: 0.0169
# Epoch 3/200, Train Loss: 0.6991, Train ACC: 0.64%, Train MCC: 0.1716, Val Loss: 0.6296, Val ACC: 0.71, Val MCC: 0.3673
# Epoch 4/200, Train Loss: 0.6029, Train ACC: 0.66%, Train MCC: 0.3511, Val Loss: 0.5625, Val ACC: 0.81, Val MCC: 0.5188
# Epoch 5/200, Train Loss: 0.4785, Train ACC: 0.77%, Train MCC: 0.5068, Val Loss: 0.5656, Val ACC: 0.80, Val MCC: 0.5028
# Epoch 6/200, Train Loss: 0.4291, Train ACC: 0.83%, Train MCC: 0.6136, Val Loss: 0.5730, Val ACC: 0.77, Val MCC: 0.4636
# Epoch 7/200, Train Loss: 0.3884, Train ACC: 0.84%, Train MCC: 0.6360, Val Loss: 0.6185, Val ACC: 0.84, Val MCC: 0.6021
# Epoch 8/200, Train Loss: 0.3826, Train ACC: 0.83%, Train MCC: 0.6102, Val Loss: 0.5338, Val ACC: 0.86, Val MCC: 0.6458
# Epoch 9/200, Train Loss: 0.3337, Train ACC: 0.85%, Train MCC: 0.6500, Val Loss: 0.4949, Val ACC: 0.75, Val MCC: 0.5083
# Epoch 10/200, Train Loss: 0.3094, Train ACC: 0.85%, Train MCC: 0.6611, Val Loss: 0.4967, Val ACC: 0.83, Val MCC: 0.6038
# Epoch 11/200, Train Loss: 0.2208, Train ACC: 0.92%, Train MCC: 0.8014, Val Loss: 0.4872, Val ACC: 0.80, Val MCC: 0.5579
# Epoch 12/200, Train Loss: 0.2521, Train ACC: 0.89%, Train MCC: 0.7445, Val Loss: 0.5343, Val ACC: 0.80, Val MCC: 0.5482
# Epoch 13/200, Train Loss: 0.2218, Train ACC: 0.89%, Train MCC: 0.7639, Val Loss: 0.5418, Val ACC: 0.83, Val MCC: 0.5994
# Epoch 14/200, Train Loss: 0.1781, Train ACC: 0.93%, Train MCC: 0.8291, Val Loss: 0.5553, Val ACC: 0.84, Val MCC: 0.6175
# Epoch 15/200, Train Loss: 0.1827, Train ACC: 0.92%, Train MCC: 0.8139, Val Loss: 0.5329, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 16/200, Train Loss: 0.2127, Train ACC: 0.92%, Train MCC: 0.8126, Val Loss: 0.5188, Val ACC: 0.85, Val MCC: 0.6360
# Epoch 17/200, Train Loss: 0.1413, Train ACC: 0.95%, Train MCC: 0.8815, Val Loss: 0.5490, Val ACC: 0.85, Val MCC: 0.6471
# Epoch 18/200, Train Loss: 0.1434, Train ACC: 0.93%, Train MCC: 0.8504, Val Loss: 0.5851, Val ACC: 0.85, Val MCC: 0.6382
# Epoch 19/200, Train Loss: 0.1861, Train ACC: 0.93%, Train MCC: 0.8404, Val Loss: 0.5154, Val ACC: 0.83, Val MCC: 0.6168
# Epoch 20/200, Train Loss: 0.1569, Train ACC: 0.94%, Train MCC: 0.8668, Val Loss: 0.5367, Val ACC: 0.83, Val MCC: 0.6115
# Epoch 21/200, Train Loss: 0.1359, Train ACC: 0.94%, Train MCC: 0.8498, Val Loss: 0.5221, Val ACC: 0.83, Val MCC: 0.6035
# Epoch 22/200, Train Loss: 0.1256, Train ACC: 0.94%, Train MCC: 0.8707, Val Loss: 0.5267, Val ACC: 0.83, Val MCC: 0.6115
# Epoch 23/200, Train Loss: 0.1457, Train ACC: 0.94%, Train MCC: 0.8647, Val Loss: 0.5276, Val ACC: 0.84, Val MCC: 0.6235
# Epoch 24/200, Train Loss: 0.1357, Train ACC: 0.96%, Train MCC: 0.8944, Val Loss: 0.5377, Val ACC: 0.84, Val MCC: 0.6195
# Epoch 25/200, Train Loss: 0.2099, Train ACC: 0.91%, Train MCC: 0.7912, Val Loss: 0.5388, Val ACC: 0.84, Val MCC: 0.6195
# Epoch 26/200, Train Loss: 0.1653, Train ACC: 0.93%, Train MCC: 0.8449, Val Loss: 0.5322, Val ACC: 0.85, Val MCC: 0.6435
# Epoch 27/200, Train Loss: 0.1417, Train ACC: 0.93%, Train MCC: 0.8416, Val Loss: 0.5338, Val ACC: 0.85, Val MCC: 0.6435
# Epoch 28/200, Train Loss: 0.1629, Train ACC: 0.95%, Train MCC: 0.8873, Val Loss: 0.5474, Val ACC: 0.84, Val MCC: 0.6315
# Epoch 29/200, Train Loss: 0.1509, Train ACC: 0.94%, Train MCC: 0.8696, Val Loss: 0.5528, Val ACC: 0.85, Val MCC: 0.6412
# Epoch 30/200, Train Loss: 0.1426, Train ACC: 0.94%, Train MCC: 0.8558, Val Loss: 0.5538, Val ACC: 0.85, Val MCC: 0.6412
# Epoch 31/200, Train Loss: 0.1580, Train ACC: 0.95%, Train MCC: 0.8726, Val Loss: 0.5540, Val ACC: 0.85, Val MCC: 0.6412
# Epoch 32/200, Train Loss: 0.1299, Train ACC: 0.96%, Train MCC: 0.8993, Val Loss: 0.5526, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 33/200, Train Loss: 0.1325, Train ACC: 0.95%, Train MCC: 0.8888, Val Loss: 0.5525, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 34/200, Train Loss: 0.1927, Train ACC: 0.93%, Train MCC: 0.8315, Val Loss: 0.5523, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 35/200, Train Loss: 0.1553, Train ACC: 0.93%, Train MCC: 0.8459, Val Loss: 0.5507, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 36/200, Train Loss: 0.1607, Train ACC: 0.94%, Train MCC: 0.8519, Val Loss: 0.5500, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 37/200, Train Loss: 0.1712, Train ACC: 0.95%, Train MCC: 0.8735, Val Loss: 0.5498, Val ACC: 0.84, Val MCC: 0.6241
# Epoch 38/200, Train Loss: 0.1405, Train ACC: 0.93%, Train MCC: 0.8504, Val Loss: 0.5501, Val ACC: 0.84, Val MCC: 0.6241
# Epoch 39/200, Train Loss: 0.1199, Train ACC: 0.96%, Train MCC: 0.9082, Val Loss: 0.5515, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 40/200, Train Loss: 0.1268, Train ACC: 0.94%, Train MCC: 0.8696, Val Loss: 0.5527, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 41/200, Train Loss: 0.1278, Train ACC: 0.95%, Train MCC: 0.8855, Val Loss: 0.5527, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 42/200, Train Loss: 0.1598, Train ACC: 0.94%, Train MCC: 0.8611, Val Loss: 0.5528, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 43/200, Train Loss: 0.1343, Train ACC: 0.94%, Train MCC: 0.8569, Val Loss: 0.5527, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 44/200, Train Loss: 0.1388, Train ACC: 0.94%, Train MCC: 0.8686, Val Loss: 0.5528, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 45/200, Train Loss: 0.1499, Train ACC: 0.95%, Train MCC: 0.8826, Val Loss: 0.5527, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 46/200, Train Loss: 0.1376, Train ACC: 0.94%, Train MCC: 0.8730, Val Loss: 0.5527, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 47/200, Train Loss: 0.1331, Train ACC: 0.95%, Train MCC: 0.8824, Val Loss: 0.5528, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 48/200, Train Loss: 0.1295, Train ACC: 0.93%, Train MCC: 0.8442, Val Loss: 0.5530, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 49/200, Train Loss: 0.1358, Train ACC: 0.95%, Train MCC: 0.8775, Val Loss: 0.5531, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 50/200, Train Loss: 0.1124, Train ACC: 0.96%, Train MCC: 0.8953, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 51/200, Train Loss: 0.1627, Train ACC: 0.93%, Train MCC: 0.8420, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 52/200, Train Loss: 0.1368, Train ACC: 0.94%, Train MCC: 0.8567, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 53/200, Train Loss: 0.1547, Train ACC: 0.95%, Train MCC: 0.8855, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 54/200, Train Loss: 0.1122, Train ACC: 0.95%, Train MCC: 0.8806, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 55/200, Train Loss: 0.1390, Train ACC: 0.95%, Train MCC: 0.8826, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 56/200, Train Loss: 0.1399, Train ACC: 0.94%, Train MCC: 0.8668, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 57/200, Train Loss: 0.1400, Train ACC: 0.94%, Train MCC: 0.8618, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 58/200, Train Loss: 0.1337, Train ACC: 0.94%, Train MCC: 0.8686, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 59/200, Train Loss: 0.1341, Train ACC: 0.95%, Train MCC: 0.8757, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 60/200, Train Loss: 0.1328, Train ACC: 0.94%, Train MCC: 0.8628, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 61/200, Train Loss: 0.1638, Train ACC: 0.94%, Train MCC: 0.8489, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 62/200, Train Loss: 0.1489, Train ACC: 0.94%, Train MCC: 0.8668, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 63/200, Train Loss: 0.1313, Train ACC: 0.96%, Train MCC: 0.8936, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 64/200, Train Loss: 0.1225, Train ACC: 0.95%, Train MCC: 0.8873, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 65/200, Train Loss: 0.1601, Train ACC: 0.95%, Train MCC: 0.8735, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 66/200, Train Loss: 0.1248, Train ACC: 0.95%, Train MCC: 0.8785, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 67/200, Train Loss: 0.1245, Train ACC: 0.96%, Train MCC: 0.9019, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 68/200, Train Loss: 0.1218, Train ACC: 0.96%, Train MCC: 0.9067, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 69/200, Train Loss: 0.1170, Train ACC: 0.96%, Train MCC: 0.8962, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 70/200, Train Loss: 0.1482, Train ACC: 0.94%, Train MCC: 0.8686, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 71/200, Train Loss: 0.1505, Train ACC: 0.93%, Train MCC: 0.8381, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 72/200, Train Loss: 0.1405, Train ACC: 0.96%, Train MCC: 0.8985, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 73/200, Train Loss: 0.1368, Train ACC: 0.94%, Train MCC: 0.8677, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 74/200, Train Loss: 0.1320, Train ACC: 0.96%, Train MCC: 0.8993, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 75/200, Train Loss: 0.1438, Train ACC: 0.94%, Train MCC: 0.8508, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 76/200, Train Loss: 0.1943, Train ACC: 0.93%, Train MCC: 0.8366, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 77/200, Train Loss: 0.1637, Train ACC: 0.95%, Train MCC: 0.8913, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 78/200, Train Loss: 0.1250, Train ACC: 0.94%, Train MCC: 0.8707, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 79/200, Train Loss: 0.1431, Train ACC: 0.94%, Train MCC: 0.8647, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 80/200, Train Loss: 0.1137, Train ACC: 0.96%, Train MCC: 0.8977, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 81/200, Train Loss: 0.1096, Train ACC: 0.96%, Train MCC: 0.8936, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 82/200, Train Loss: 0.1135, Train ACC: 0.96%, Train MCC: 0.8993, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 83/200, Train Loss: 0.1401, Train ACC: 0.94%, Train MCC: 0.8608, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 84/200, Train Loss: 0.1046, Train ACC: 0.95%, Train MCC: 0.8815, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 85/200, Train Loss: 0.1433, Train ACC: 0.93%, Train MCC: 0.8469, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 86/200, Train Loss: 0.1387, Train ACC: 0.94%, Train MCC: 0.8647, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 87/200, Train Loss: 0.1405, Train ACC: 0.94%, Train MCC: 0.8647, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 88/200, Train Loss: 0.1386, Train ACC: 0.94%, Train MCC: 0.8592, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 89/200, Train Loss: 0.1336, Train ACC: 0.94%, Train MCC: 0.8554, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 90/200, Train Loss: 0.1155, Train ACC: 0.96%, Train MCC: 0.9042, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 91/200, Train Loss: 0.1081, Train ACC: 0.95%, Train MCC: 0.8798, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 92/200, Train Loss: 0.1551, Train ACC: 0.94%, Train MCC: 0.8696, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 93/200, Train Loss: 0.1557, Train ACC: 0.94%, Train MCC: 0.8611, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 94/200, Train Loss: 0.1292, Train ACC: 0.95%, Train MCC: 0.8824, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 95/200, Train Loss: 0.1366, Train ACC: 0.95%, Train MCC: 0.8839, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 96/200, Train Loss: 0.1699, Train ACC: 0.93%, Train MCC: 0.8431, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 97/200, Train Loss: 0.1087, Train ACC: 0.96%, Train MCC: 0.8972, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 98/200, Train Loss: 0.1681, Train ACC: 0.93%, Train MCC: 0.8366, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 99/200, Train Loss: 0.1719, Train ACC: 0.94%, Train MCC: 0.8562, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 100/200, Train Loss: 0.1540, Train ACC: 0.95%, Train MCC: 0.8888, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 101/200, Train Loss: 0.1562, Train ACC: 0.94%, Train MCC: 0.8529, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 102/200, Train Loss: 0.1681, Train ACC: 0.93%, Train MCC: 0.8400, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 103/200, Train Loss: 0.1500, Train ACC: 0.94%, Train MCC: 0.8538, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 104/200, Train Loss: 0.1325, Train ACC: 0.95%, Train MCC: 0.8766, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 105/200, Train Loss: 0.1310, Train ACC: 0.95%, Train MCC: 0.8864, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 106/200, Train Loss: 0.1371, Train ACC: 0.94%, Train MCC: 0.8608, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 107/200, Train Loss: 0.1457, Train ACC: 0.95%, Train MCC: 0.8881, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 108/200, Train Loss: 0.1619, Train ACC: 0.95%, Train MCC: 0.8766, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 109/200, Train Loss: 0.1167, Train ACC: 0.96%, Train MCC: 0.9002, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 110/200, Train Loss: 0.1380, Train ACC: 0.94%, Train MCC: 0.8597, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 111/200, Train Loss: 0.1450, Train ACC: 0.94%, Train MCC: 0.8580, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 112/200, Train Loss: 0.1467, Train ACC: 0.94%, Train MCC: 0.8578, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 113/200, Train Loss: 0.1557, Train ACC: 0.93%, Train MCC: 0.8303, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 114/200, Train Loss: 0.1237, Train ACC: 0.94%, Train MCC: 0.8630, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 115/200, Train Loss: 0.1533, Train ACC: 0.95%, Train MCC: 0.8855, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 116/200, Train Loss: 0.1429, Train ACC: 0.94%, Train MCC: 0.8548, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 117/200, Train Loss: 0.1171, Train ACC: 0.95%, Train MCC: 0.8817, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 118/200, Train Loss: 0.1726, Train ACC: 0.93%, Train MCC: 0.8366, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 119/200, Train Loss: 0.1572, Train ACC: 0.93%, Train MCC: 0.8420, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 120/200, Train Loss: 0.1399, Train ACC: 0.94%, Train MCC: 0.8668, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 121/200, Train Loss: 0.1657, Train ACC: 0.93%, Train MCC: 0.8442, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 122/200, Train Loss: 0.1142, Train ACC: 0.96%, Train MCC: 0.8936, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 123/200, Train Loss: 0.1147, Train ACC: 0.95%, Train MCC: 0.8845, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 124/200, Train Loss: 0.1388, Train ACC: 0.95%, Train MCC: 0.8750, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 125/200, Train Loss: 0.1613, Train ACC: 0.94%, Train MCC: 0.8580, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 126/200, Train Loss: 0.1484, Train ACC: 0.94%, Train MCC: 0.8508, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 127/200, Train Loss: 0.1264, Train ACC: 0.95%, Train MCC: 0.8768, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 128/200, Train Loss: 0.1346, Train ACC: 0.94%, Train MCC: 0.8604, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 129/200, Train Loss: 0.1320, Train ACC: 0.95%, Train MCC: 0.8896, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 130/200, Train Loss: 0.1409, Train ACC: 0.94%, Train MCC: 0.8498, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 131/200, Train Loss: 0.1397, Train ACC: 0.95%, Train MCC: 0.8756, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 132/200, Train Loss: 0.1225, Train ACC: 0.95%, Train MCC: 0.8829, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 133/200, Train Loss: 0.1554, Train ACC: 0.92%, Train MCC: 0.8282, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 134/200, Train Loss: 0.1721, Train ACC: 0.95%, Train MCC: 0.8709, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 135/200, Train Loss: 0.1270, Train ACC: 0.95%, Train MCC: 0.8746, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 136/200, Train Loss: 0.1744, Train ACC: 0.92%, Train MCC: 0.8014, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 137/200, Train Loss: 0.1641, Train ACC: 0.95%, Train MCC: 0.8701, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 138/200, Train Loss: 0.1393, Train ACC: 0.95%, Train MCC: 0.8904, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 139/200, Train Loss: 0.1408, Train ACC: 0.95%, Train MCC: 0.8717, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 140/200, Train Loss: 0.1250, Train ACC: 0.96%, Train MCC: 0.8929, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 141/200, Train Loss: 0.1300, Train ACC: 0.95%, Train MCC: 0.8735, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 142/200, Train Loss: 0.1315, Train ACC: 0.94%, Train MCC: 0.8647, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 143/200, Train Loss: 0.1520, Train ACC: 0.94%, Train MCC: 0.8608, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 144/200, Train Loss: 0.1613, Train ACC: 0.94%, Train MCC: 0.8657, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 145/200, Train Loss: 0.1418, Train ACC: 0.96%, Train MCC: 0.8985, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 146/200, Train Loss: 0.1578, Train ACC: 0.93%, Train MCC: 0.8315, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 147/200, Train Loss: 0.1335, Train ACC: 0.95%, Train MCC: 0.8768, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 148/200, Train Loss: 0.1437, Train ACC: 0.94%, Train MCC: 0.8542, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 149/200, Train Loss: 0.1282, Train ACC: 0.94%, Train MCC: 0.8668, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 150/200, Train Loss: 0.1369, Train ACC: 0.96%, Train MCC: 0.8944, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 151/200, Train Loss: 0.1246, Train ACC: 0.94%, Train MCC: 0.8628, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 152/200, Train Loss: 0.1599, Train ACC: 0.94%, Train MCC: 0.8558, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 153/200, Train Loss: 0.1268, Train ACC: 0.95%, Train MCC: 0.8847, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 154/200, Train Loss: 0.1867, Train ACC: 0.93%, Train MCC: 0.8430, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 155/200, Train Loss: 0.1315, Train ACC: 0.94%, Train MCC: 0.8608, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 156/200, Train Loss: 0.1445, Train ACC: 0.94%, Train MCC: 0.8628, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 157/200, Train Loss: 0.1330, Train ACC: 0.94%, Train MCC: 0.8569, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 158/200, Train Loss: 0.1110, Train ACC: 0.96%, Train MCC: 0.8972, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 159/200, Train Loss: 0.1230, Train ACC: 0.94%, Train MCC: 0.8686, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 160/200, Train Loss: 0.1227, Train ACC: 0.96%, Train MCC: 0.9109, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 161/200, Train Loss: 0.1109, Train ACC: 0.95%, Train MCC: 0.8855, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 162/200, Train Loss: 0.1570, Train ACC: 0.93%, Train MCC: 0.8420, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 163/200, Train Loss: 0.1683, Train ACC: 0.94%, Train MCC: 0.8498, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 164/200, Train Loss: 0.1152, Train ACC: 0.95%, Train MCC: 0.8766, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 165/200, Train Loss: 0.1252, Train ACC: 0.94%, Train MCC: 0.8718, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 166/200, Train Loss: 0.1243, Train ACC: 0.95%, Train MCC: 0.8785, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 167/200, Train Loss: 0.1069, Train ACC: 0.97%, Train MCC: 0.9212, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 168/200, Train Loss: 0.1279, Train ACC: 0.95%, Train MCC: 0.8798, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 169/200, Train Loss: 0.1061, Train ACC: 0.96%, Train MCC: 0.8922, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 170/200, Train Loss: 0.1417, Train ACC: 0.94%, Train MCC: 0.8652, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 171/200, Train Loss: 0.1076, Train ACC: 0.95%, Train MCC: 0.8824, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 172/200, Train Loss: 0.1389, Train ACC: 0.94%, Train MCC: 0.8538, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 173/200, Train Loss: 0.1481, Train ACC: 0.94%, Train MCC: 0.8668, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 174/200, Train Loss: 0.1739, Train ACC: 0.95%, Train MCC: 0.8687, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 175/200, Train Loss: 0.1298, Train ACC: 0.95%, Train MCC: 0.8839, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 176/200, Train Loss: 0.1563, Train ACC: 0.94%, Train MCC: 0.8519, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 177/200, Train Loss: 0.1237, Train ACC: 0.95%, Train MCC: 0.8785, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 178/200, Train Loss: 0.1456, Train ACC: 0.94%, Train MCC: 0.8637, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 179/200, Train Loss: 0.1499, Train ACC: 0.94%, Train MCC: 0.8521, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 180/200, Train Loss: 0.1246, Train ACC: 0.96%, Train MCC: 0.8993, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 181/200, Train Loss: 0.1315, Train ACC: 0.95%, Train MCC: 0.8766, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 182/200, Train Loss: 0.1286, Train ACC: 0.95%, Train MCC: 0.8824, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 183/200, Train Loss: 0.1335, Train ACC: 0.94%, Train MCC: 0.8508, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 184/200, Train Loss: 0.1402, Train ACC: 0.93%, Train MCC: 0.8392, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 185/200, Train Loss: 0.1265, Train ACC: 0.95%, Train MCC: 0.8824, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 186/200, Train Loss: 0.1339, Train ACC: 0.95%, Train MCC: 0.8839, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 187/200, Train Loss: 0.1427, Train ACC: 0.95%, Train MCC: 0.8855, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 188/200, Train Loss: 0.1177, Train ACC: 0.95%, Train MCC: 0.8883, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 189/200, Train Loss: 0.1316, Train ACC: 0.95%, Train MCC: 0.8815, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 190/200, Train Loss: 0.1299, Train ACC: 0.95%, Train MCC: 0.8864, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 191/200, Train Loss: 0.1226, Train ACC: 0.96%, Train MCC: 0.8993, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 192/200, Train Loss: 0.1527, Train ACC: 0.94%, Train MCC: 0.8529, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 193/200, Train Loss: 0.1515, Train ACC: 0.94%, Train MCC: 0.8637, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 194/200, Train Loss: 0.1522, Train ACC: 0.94%, Train MCC: 0.8628, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 195/200, Train Loss: 0.1476, Train ACC: 0.95%, Train MCC: 0.8775, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 196/200, Train Loss: 0.1305, Train ACC: 0.95%, Train MCC: 0.8726, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 197/200, Train Loss: 0.1622, Train ACC: 0.93%, Train MCC: 0.8315, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 198/200, Train Loss: 0.1395, Train ACC: 0.95%, Train MCC: 0.8735, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 199/200, Train Loss: 0.1310, Train ACC: 0.95%, Train MCC: 0.8791, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326
# Epoch 200/200, Train Loss: 0.1171, Train ACC: 0.95%, Train MCC: 0.8806, Val Loss: 0.5532, Val ACC: 0.85, Val MCC: 0.6326

# %%
model = vgg19
model.eval()
# 加载测试数据集
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_csv_file = "/local/data1/honzh/local_repository/FL/code/4_federated/csv_files/test_data.csv"

test_dataset = CustomDataset(csv_file=test_csv_file, transform=test_transform)

test_model(model, test_dataset)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.88      0.92      2271
#            1       0.60      0.87      0.71       490
#
#     accuracy                           0.88      2761
#    macro avg       0.79      0.87      0.82      2761
# weighted avg       0.90      0.88      0.88      2761
# {'Total Acc': 0.876,
#  'nff Acc': 0.878,
#  'aff Acc': 0.865,
#  'Precision': 0.605,
#  'Recall': 0.865,
#  'Accuracy': 0.876,
#  'AUC': 0.872,
#  'MCC': 0.653,
#  'F1 Score': 0.712,
#  'ROC_AUC': 0.872,
#  'PRC-AUC': 0.547}
