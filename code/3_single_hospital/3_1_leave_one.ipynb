# %% [markdown]
# # Create all image csv files

# %%
import os
import csv

def create_csv(image_folder, csv_file_path):
    # Define the CSV header fields
    fieldnames = ['HospitalID', 'PatientID', 'ImageID', 'ImagePath', 'Label']
    
    # Open the CSV file in write mode
    with open(csv_file_path, 'w', newline='') as csvfile:
        # Create a CSV writer object and write the header
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        # Iterate through files in the folder
        for filename in sorted(os.listdir(image_folder)):
            # Construct the complete image file path
            image_path = os.path.join(image_folder, filename)

            # Parse the filename to extract HospitalID, PatientID, image number, and image label
            parts = filename.split('_')
            hospital_id = parts[3]
            patient_id = parts[1]
            image_number = parts[6]
            image_label = parts[4]

            # Write data into the CSV file
            writer.writerow({
                'HospitalID': hospital_id,
                'PatientID': patient_id,
                'ImageID': image_number,
                'ImagePath': image_path,
                'Label': image_label
            })

    # Print a message indicating that the CSV file has been created and saved
    print("CSV file has been created and saved to:", csv_file_path)


image_folder = "/local/data1/honzh073/data/8bit_downsample_256"
csv_file_path = "/local/data1/honzh073/local_repo/FL/code/3_single_hospital/csv_files/image_data.csv"
create_csv(image_folder, csv_file_path)
# Out:
# CSV file has been created and saved to: /local/data1/honzh073/local_repo/FL/code/3_single_hospital/csv_files/image_data.csv

# %% [markdown]
# # Split by patient ID on single hospital

# %%
import csv
from collections import defaultdict
import random

def split_and_save_data(input_csv_path, output_folder, target_hospital_ids, train_ratio, seed):
    patient_data = defaultdict(list)
    
    with open(input_csv_path, 'r') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            if row['HospitalID'] in target_hospital_ids:
                patient_id = row['PatientID']
                patient_data[patient_id].append(row)

    num_patients = len(patient_data)

    num_train = int(num_patients * train_ratio)

    # get random IDs
    all_patient_ids = list(patient_data.keys())

    random.seed(seed)
    random.shuffle(all_patient_ids)

    # split by ID
    train_patients = all_patient_ids[ : num_train]
    test_patients = all_patient_ids[num_train: ]

    # iter by patient IDs
    train_data = []
    test_data = []

    for patient_id, images in patient_data.items():
        if patient_id in train_patients:
            train_data.extend(images)
        elif patient_id in test_patients:
            test_data.extend(images)

    # write to csv
    def write_to_csv(file_path, data):
        with open(file_path, 'w', newline='') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=data[0].keys())
            writer.writeheader()
            writer.writerows(data)

    # Write to CSV files
    write_to_csv(os.path.join(output_folder, 'cross_train.csv'), train_data)
    write_to_csv(os.path.join(output_folder, 'cross_test.csv'), test_data)
    
    print("Saved train.csv, test.csv.")

# input and output path
input_csv_path = "/local/data1/honzh073/local_repo/FL/code/3_single_hospital/csv_files/image_data.csv"
output_folder = '/local/data1/honzh073/local_repo/FL/code/3_single_hospital/csv_files/'

# single hospital id
target_hospital_ids = ['43']

# random seed
seed = 1

# train and val dataset ratio
train_ratio = 0.7
# test_ratio = 0.3 # unnecessary

split_and_save_data(input_csv_path, output_folder,
                    train_ratio=train_ratio,
                    target_hospital_ids = target_hospital_ids,
                    seed = seed)
# Out:
# Saved train.csv, test.csv.

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import models
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_curve, roc_auc_score

# get training class weight, aff : nff = 2:8
def get_classweight(train_dataset):
    train_nff_count = sum(1 for _, label,_ in train_dataset if label == 0)  # 0 NFF
    train_aff_count = sum(1 for _, label,_ in train_dataset if label == 1)  # 1 AFF
    class_weight_nff = 1 / (2 * (train_nff_count / (train_nff_count + train_aff_count)))
    class_weight_aff = 1 / (2 * (train_aff_count / (train_nff_count + train_aff_count)))
    
    return [class_weight_nff, class_weight_aff] # 0 nff , 1 aff 

# training function
def train_model(train_loader, validation_loader, classweight, num_epochs, lr, step_size, gamma, model_name):
    # Load pre-trained model
    torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')
    
    if model_name == 'resnet18':
        from torchvision.models import resnet18, ResNet18_Weights
        model = models.resnet18(weights=ResNet18_Weights.DEFAULT)
    
    elif model_name == 'resnet50':
        from torchvision.models import resnet50, ResNet50_Weights
        model = models.resnet50(weights=ResNet50_Weights.DEFAULT)
        
    elif model_name == 'resnet101':
        from torchvision.models import resnet101, ResNet101_Weights
        model = models.resnet101(weights=ResNet101_Weights.DEFAULT)
         
    elif model_name == 'resnet152':
        from torchvision.models import resnet152, ResNet152_Weights
        model = models.resnet152(weights=ResNet152_Weights.DEFAULT)
        
    elif model_name == 'densenet161':
        from torchvision.models import densenet161, DenseNet161_Weights
        model = models.densenet161(weights=DenseNet161_Weights.DEFAULT)

    elif model_name == 'vgg19':
        from torchvision.models import vgg19, VGG19_Weights
        model = models.vgg19(weights=VGG19_Weights.DEFAULT)
        
    else:
        raise ValueError("Invalid model type. 'vgg19' 'resnet50' 'resnet101' 'resnet152' or 'densenet161'.")
    
    # freeze all layers except fc
    # for param in model.parameters():
    #     param.requires_grad = False
    
    # fc
    num_class = 2
    
    if model_name == 'densenet161':
        in_features = model.classifier.in_features
        model.classifier = nn.Sequential(nn.Dropout(0.5),nn.Linear(in_features, num_class)) # dropout
        # model.classifier = nn.Sequential(nn.Linear(in_features, num_class)) # no dropout
    if model_name == 'vgg19':
        in_features = model.classifier[0].in_features
        model.classifier = nn.Sequential(nn.Dropout(0.5),nn.Linear(in_features, num_class)) # dropout
        # model.classifier = nn.Sequential(nn.Linear(in_features, num_class)) # no dropout
    # fc1 = vgg_model.classifier[0]

    else:
        in_features = model.fc.in_features
        model.fc = nn.Sequential(nn.Dropout(0.5), nn.Linear(in_features, num_class)) # dropout
        # model.fc = nn.Sequential(nn.Linear(in_features, num_class)) # no dropout
    
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    model = model.to(device)

    # # DataParallel speed up
    # if torch.cuda.device_count() > 1:
    #     print("multiple GPU:", torch.cuda.device_count())
    #     model = nn.DataParallel(model)
    # else:
    #     print("single GPU")
    #     model = model.to(device)
    
    # loss function and learning rate
    criterion = nn.CrossEntropyLoss(weight=torch.Tensor(classweight).to(device))
    # optimizer = optim.Adam(model.parameters(), lr=lr)
    
    optimizer = optim.RMSprop(model.parameters(), lr=lr)

    scheduler = lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)
    # # scheduler = lr_scheduler.ExponentialLR(optimizer, gamma=0.9)
    # scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, 'min')

        
    # Loss, ACC
    train_losses = []
    validation_losses = []
    train_accuracies = []
    validation_accuracies = []
    
    # select best model
    best_validation_accuracy = 0
    best_model = None

    for epoch in range(num_epochs):
        model.train()
        correct_train = 0
        total_train = 0
        
        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
        
        train_accuracy = 100 * correct_train / total_train
        
        model.eval()
        correct_validation_aff = 0
        total_validation_aff = 0
        correct_validation = 0
        total_validation = 0
        validation_loss = 0
        
        with torch.no_grad():
            for images, labels in validation_loader:
                images = images.to(device)
                labels = labels.to(device)
                
                outputs = model(images)
                loss = criterion(outputs, labels)
                
                _, predicted = torch.max(outputs.data, 1)
                total_validation += labels.size(0)
                correct_validation += (predicted == labels).sum().item()
                validation_loss += loss.item()
                # Calculate accuracy for AFF class
                total_validation_aff += torch.sum(labels == 1).item()
                correct_validation_aff += torch.sum((predicted == 1) & (labels == 1)).item()

        validation_accuracy_aff = 100 * correct_validation_aff / total_validation_aff

        # validation accuracy and loss
        validation_accuracy = 100 * correct_validation / total_validation
        validation_loss /= len(validation_loader)
        
        train_losses.append(loss.item())
        validation_losses.append(validation_loss)
        train_accuracies.append(train_accuracy)
        validation_accuracies.append(validation_accuracy)
        
        print(f"Epoch {epoch+1}/{num_epochs}, "
            f"train Loss: {loss.item():.4f}, "
            f"val Loss: {validation_loss:.4f}, "
            f"train ACC: {train_accuracy:.2f}%, "
            f"Val ACC: {validation_accuracy:.2f}%")
        
        # scheduler.step()
        scheduler.step()

        # select by high aff ACC
        # if validation_accuracy_aff > best_accuracy:
        #     best_accuracy = validation_accuracy_aff
        #     best_model = model.module if isinstance(model, nn.DataParallel) else model

        if validation_accuracy > best_validation_accuracy:
            best_validation_accuracy = validation_accuracy
            # best_model = model.module  # DataParallel
            best_model = model  # single device
            
    # Plot train/val loss,  accuracy
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Train Loss')
    plt.plot(validation_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(train_accuracies, label='Train Accuracy')
    plt.plot(validation_accuracies, label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.legend() 

    plt.show()

    return best_model

def test_model(model, test_dataset, batch_size):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)
    model.eval()
    
    correct_test = 0
    total_test = 0
    test_loss = 0
    
    criterion = nn.CrossEntropyLoss()
    
    with torch.no_grad():
        all_predictions = []
        all_labels = []
        for images, labels,_ in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            _, predicted = torch.max(outputs.data, 1)
            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            total_test += labels.size(0)
            correct_test += (predicted == labels).sum().item()
            test_loss += loss.item()

    test_accuracy = 100 * correct_test / total_test
    test_loss /= len(test_loader)

    print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_accuracy:.2f}%")
     
    auc_score = roc_auc_score(all_labels, all_predictions)
    conf_matrix = confusion_matrix(all_labels, all_predictions)
    
    # Precision、Recall、F1 Score
    class_labels = {0: 'NFF', 1: 'AFF'}

    classification_rep = classification_report(all_labels, all_predictions, target_names=[class_labels[i] for i in range(len(class_labels))])
    print("AUC:", auc_score)
    print("Confusion Matrix:")
    print(conf_matrix)
    print("Classification Report:")
    print(classification_rep)

    plot_roc_curve(all_labels, all_predictions)
    
def plot_roc_curve(all_labels, all_predictions):
    fpr, tpr, thresholds = roc_curve(all_labels, all_predictions)
    roc_auc = roc_auc_score(all_labels, all_predictions)

    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc='lower right')
    plt.show()

def show_image(dataset, num_images=5):
    # Get random indices
    random_indices = np.random.choice(len(dataset), num_images, replace=False)

    # Plot images with truncated names
    plt.figure(figsize=(15, 5))
    for i, idx in enumerate(random_indices):
        image, label, patient_id = dataset[idx]  # Use the dataset directly
        filename = dataset.data[idx][0]  # Get the filename from dataset's internal data attribute
        truncated_filename = filename.split('/')[-1][:15]  # Extract the last part and truncate to 15 characters
        
        # Print the original filename
        print(f"Image location: {filename}")

        plt.subplot(1, num_images, i + 1)
        plt.title(f"Label: {label}")
        plt.imshow(image[0])  # Assuming single-channel (grayscale) image
        # plt.imshow(image[0], cmap='gray')  # Assuming single-channel (grayscale) image

        plt.axis('off')
    plt.show()
    
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
import csv
import pandas as pd

import csv
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from sklearn.model_selection import KFold
from tqdm import tqdm

# Custom dataset class
class CustomDataset(Dataset):
    def __init__(self, csv_file, transform=None):
        self.data = []
        self.labels = []  # Store labels separately
        self.patient_ids = []  # Store patient IDs separately

        self.transform = transform
        # read csv
        with open(csv_file, 'r') as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                image_path = row['ImagePath']
                label = row['Label']
                patient_id = row['PatientID']  # Assuming 'PatientID' is the column name in your CSV file

                if label == 'NFF':
                    label = 0
                elif label == 'AFF':
                    label = 1
                else:
                    raise ValueError("Invalid label in CSV file.")
                self.data.append((image_path,label, label))
                self.labels.append(label)
                self.patient_ids.append(patient_id)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image_path, label, patient_id = self.data[idx]  # add patient id
        image = Image.open(image_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image, label, patient_id

# Define your image transformations for training and testing
train_transform = transforms.Compose([
    transforms.RandomRotation(degrees=30),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomResizedCrop(256, scale=(0.8, 1.0)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.GaussianBlur(kernel_size=3),
    transforms.RandomAdjustSharpness(sharpness_factor=5),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load the datasets using CustomDataset class
train_dataset = CustomDataset('/local/data1/honzh073/local_repo/FL/code/3_single_hospital/csv_files/cross_train.csv', transform=train_transform)
test_dataset = CustomDataset('/local/data1/honzh073/local_repo/FL/code/3_single_hospital/csv_files/cross_test.csv', transform=test_transform)

# classweight
classweight = get_classweight(train_dataset)
print('training class weight', classweight)

# device
# device = torch.device("cuda:0" if  torch.cuda.is_available() else "cpu")

show_image(train_dataset, 10)

print("Saved train.csv, val.csv, test.csv.")
print('-----------------------------------')
train_NFF_count = sum(1 for _, label, _ in train_dataset if label == 0)  # 0 NFF
train_AFF_count = sum(1 for _, label, _ in train_dataset if label == 1)  # 1 AFF

# For test dataset
test_NFF_count = sum(1 for _, label, _ in test_dataset if label == 0)  # 0 NFF
test_AFF_count = sum(1 for _, label, _ in test_dataset if label == 1)  # 1 AFF


print(f"train AFF: {train_AFF_count}, ratio: {train_AFF_count / (train_AFF_count + train_NFF_count):.2f}")
print(f"----- NFF: {train_NFF_count}, ratio: {train_NFF_count / (train_AFF_count + train_NFF_count):.2f}")
print('-----------------------------------')
print(f"test AFF: {test_AFF_count}, ratio: {test_AFF_count / (test_AFF_count + test_NFF_count):.2f}")
print(f"---- NFF: {test_NFF_count}, ratio: {test_NFF_count / (test_AFF_count + test_NFF_count):.2f}")
# Out:
# training class weight [0.7363636363636363, 1.5576923076923077]
# Image location: /local/data1/honzh073/data/8bit_downsample_256/patient_UVSPTMWBZC_hospital_43_NFF_image_1.png
# Image location: /local/data1/honzh073/data/8bit_downsample_256/patient_TADAVBRLUJ_hospital_43_NFF_image_2.png
# Image location: /local/data1/honzh073/data/8bit_downsample_256/patient_EYRSUJGIZG_hospital_43_AFF_image_1.png
# Image location: /local/data1/honzh073/data/8bit_downsample_256/patient_JLKUTLSYUS_hospital_43_NFF_image_1.png
# Image location: /local/data1/honzh073/data/8bit_downsample_256/patient_OWBXDVUXDN_hospital_43_NFF_image_2.png
# Image location: /local/data1/honzh073/data/8bit_downsample_256/patient_JLKUTLSYUS_hospital_43_NFF_image_3.png
# Image location: /local/data1/honzh073/data/8bit_downsample_256/patient_GFRVIURAPK_hospital_43_NFF_image_1.png
# Image location: /local/data1/honzh073/data/8bit_downsample_256/patient_ZHFQURFRCS_hospital_43_AFF_image_1.png
# Image location: /local/data1/honzh073/data/8bit_downsample_256/patient_YKGTKOEZOD_hospital_43_AFF_image_3.png
# Image location: /local/data1/honzh073/data/8bit_downsample_256/patient_NGLGWBFXUD_hospital_43_AFF_image_1.png
# Saved train.csv, val.csv, test.csv.
# -----------------------------------
# train AFF: 52, ratio: 0.32
# ----- NFF: 110, ratio: 0.68
# -----------------------------------
# test AFF: 23, ratio: 0.28
# ---- NFF: 60, ratio: 0.72

# %%
def test_model(model, test_dataset, batch_size):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)
    model.eval()
    
    correct_test = 0
    total_test = 0
    test_loss = 0
    
    criterion = nn.CrossEntropyLoss()
    
    with torch.no_grad():
        all_predictions = []
        all_labels = []
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            _, predicted = torch.max(outputs.data, 1)
            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            total_test += labels.size(0)
            correct_test += (predicted == labels).sum().item()
            test_loss += loss.item()

    test_accuracy = 100 * correct_test / total_test
    test_loss /= len(test_loader)

    print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_accuracy:.2f}%")
     
    auc_score = roc_auc_score(all_labels, all_predictions)
    conf_matrix = confusion_matrix(all_labels, all_predictions)
    
    # Precision、Recall、F1 Score
    class_labels = {0: 'NFF', 1: 'AFF'}

    classification_rep = classification_report(all_labels, all_predictions, target_names=[class_labels[i] for i in range(len(class_labels))])
    print("AUC:", auc_score)
    print("Confusion Matrix:")
    print(conf_matrix)
    print("Classification Report:")
    print(classification_rep)

    plot_roc_curve(all_labels, all_predictions)

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import LeaveOneGroupOut
from torchvision.models import resnet101, ResNet101_Weights


patient_ids = train_dataset.patient_ids
# use LabelEncoder, make Patient id to int
label_encoder = LabelEncoder()
encoded_patient_ids = label_encoder.fit_transform(patient_ids)

# leave one out
logo = LeaveOneGroupOut()

# get class weight
classweight = get_classweight(train_dataset)

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Define the ResNet-101 model
model = models.resnet101(weights=ResNet101_Weights.DEFAULT)
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)  # Assuming 2 classes, change it according to your problem
model = model.to(device)

# Define your loss function and optimizer
# criterion = nn.CrossEntropyLoss()
criterion = nn.CrossEntropyLoss(weight=torch.Tensor(classweight).to(device))

optimizer = optim.RMSprop(model.parameters(), lr=0.0001)
scheduler = lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# # Define the number of splits for cross-validation
# n_splits = 5
# # kf = KFold(n_splits=n_splits, shuffle=True, random_state=1)
# kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=1)

# Perform k-fold cross-validation
# for fold, (train_idx, val_idx) in enumerate(kf.split(range(len(train_dataset)), train_dataset.patient_ids)): # fold by patientID
for fold, (train_idx, val_idx) in enumerate(logo.split(X=range(len(train_dataset)), groups=encoded_patient_ids)): # leave one out
# for fold, (train_idx, val_idx) in enumerate(kf.split(range(len(train_dataset)))): # fold by datasets
    # print(f'Fold {fold + 1}/{n_splits}')
    # print(f'Fold {fold + 1}/{len(logo)}')
    print(f'Fold {fold + 1}/{len(np.unique(encoded_patient_ids))}')

    # Create data loaders for training and validation subsets
    train_sampler = torch.utils.data.SubsetRandomSampler(train_idx)
    val_sampler = torch.utils.data.SubsetRandomSampler(val_idx)

    train_loader = DataLoader(train_dataset, batch_size=64, sampler=train_sampler)
    val_loader = DataLoader(train_dataset, batch_size=64, sampler=val_sampler)

    # Training loop
    num_epochs = 10  # Choose the number of epochs
        # Loss, ACC
    train_losses = []
    validation_losses = []
    train_accuracies = []
    validation_accuracies = []
    
    for epoch in range(num_epochs):
        model.train()
        correct_train = 0
        total_train = 0
        
        for images, labels,_ in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
        
        train_accuracy = 100 * correct_train / total_train
        
        model.eval()
        correct_validation_aff = 0
        total_validation_aff = 0
        correct_validation = 0
        total_validation = 0
        validation_loss = 0
        
        with torch.no_grad():
            for images, labels,_ in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                
                outputs = model(images)
                loss = criterion(outputs, labels)
                
                _, predicted = torch.max(outputs.data, 1)
                total_validation += labels.size(0)
                correct_validation += (predicted == labels).sum().item()
                validation_loss += loss.item()
                # Calculate accuracy for AFF class
                total_validation_aff += torch.sum(labels == 1).item()
                correct_validation_aff += torch.sum((predicted == 1) & (labels == 1)).item()

        # validation_accuracy_aff = 100 * correct_validation_aff / total_validation_aff

        # validation accuracy and loss
        validation_accuracy = 100 * correct_validation / total_validation
        validation_loss /= len(val_loader)
        
        train_losses.append(loss.item())
        validation_losses.append(validation_loss)
        train_accuracies.append(train_accuracy)
        validation_accuracies.append(validation_accuracy)
        
        print(f"Epoch {epoch+1}/{num_epochs}, "
            f"train Loss: {loss.item():.4f}, "
            f"val Loss: {validation_loss:.4f}, "
            f"train ACC: {train_accuracy:.2f}%, "
            f"Val ACC: {validation_accuracy:.2f}%")
        scheduler.step()
# Out:
# Fold 1/46
# Epoch 1/10, train Loss: 0.5055, val Loss: 0.5055, train ACC: 53.12%, Val ACC: 100.00%
# Epoch 2/10, train Loss: 0.6985, val Loss: 0.6985, train ACC: 68.12%, Val ACC: 50.00%
# Epoch 3/10, train Loss: 0.1078, val Loss: 0.1078, train ACC: 64.38%, Val ACC: 100.00%
# Epoch 4/10, train Loss: 0.2786, val Loss: 0.2786, train ACC: 77.50%, Val ACC: 100.00%
# Epoch 5/10, train Loss: 0.5803, val Loss: 0.5803, train ACC: 78.12%, Val ACC: 50.00%
# Epoch 6/10, train Loss: 0.1258, val Loss: 0.1258, train ACC: 80.00%, Val ACC: 100.00%
# Epoch 7/10, train Loss: 0.3958, val Loss: 0.3958, train ACC: 86.25%, Val ACC: 100.00%
# Epoch 8/10, train Loss: 0.3385, val Loss: 0.3385, train ACC: 86.88%, Val ACC: 100.00%
# Epoch 9/10, train Loss: 0.1350, val Loss: 0.1350, train ACC: 92.50%, Val ACC: 100.00%
# Epoch 10/10, train Loss: 0.0992, val Loss: 0.0992, train ACC: 90.00%, Val ACC: 100.00%
# Fold 2/46
# Epoch 1/10, train Loss: 0.0032, val Loss: 0.0032, train ACC: 89.74%, Val ACC: 100.00%
# Epoch 2/10, train Loss: 0.0201, val Loss: 0.0201, train ACC: 90.38%, Val ACC: 100.00%
# Epoch 3/10, train Loss: 0.0044, val Loss: 0.0044, train ACC: 89.74%, Val ACC: 100.00%
# Epoch 4/10, train Loss: 0.0274, val Loss: 0.0274, train ACC: 90.38%, Val ACC: 100.00%
# Epoch 5/10, train Loss: 0.0120, val Loss: 0.0120, train ACC: 96.79%, Val ACC: 100.00%
# Epoch 6/10, train Loss: 0.0137, val Loss: 0.0137, train ACC: 94.87%, Val ACC: 100.00%
# Epoch 7/10, train Loss: 0.0062, val Loss: 0.0062, train ACC: 92.31%, Val ACC: 100.00%
# Epoch 8/10, train Loss: 0.0013, val Loss: 0.0013, train ACC: 96.79%, Val ACC: 100.00%
# Epoch 9/10, train Loss: 0.0109, val Loss: 0.0109, train ACC: 93.59%, Val ACC: 100.00%
# Epoch 10/10, train Loss: 0.0008, val Loss: 0.0008, train ACC: 96.15%, Val ACC: 100.00%
# Fold 3/46
# Epoch 1/10, train Loss: 0.3732, val Loss: 0.3732, train ACC: 93.67%, Val ACC: 75.00%
# Epoch 2/10, train Loss: 0.1946, val Loss: 0.1946, train ACC: 94.94%, Val ACC: 100.00%
# Epoch 3/10, train Loss: 0.2337, val Loss: 0.2337, train ACC: 96.84%, Val ACC: 100.00%
# Epoch 4/10, train Loss: 0.3296, val Loss: 0.3296, train ACC: 96.84%, Val ACC: 75.00%
# Epoch 5/10, train Loss: 0.1155, val Loss: 0.1155, train ACC: 95.57%, Val ACC: 100.00%
# Epoch 6/10, train Loss: 0.0847, val Loss: 0.0847, train ACC: 96.20%, Val ACC: 100.00%
# Epoch 7/10, train Loss: 0.1401, val Loss: 0.1401, train ACC: 95.57%, Val ACC: 100.00%
# Epoch 8/10, train Loss: 0.2701, val Loss: 0.2701, train ACC: 96.84%, Val ACC: 100.00%
# Epoch 9/10, train Loss: 0.2028, val Loss: 0.2028, train ACC: 97.47%, Val ACC: 100.00%
# Epoch 10/10, train Loss: 0.1425, val Loss: 0.1425, train ACC: 96.20%, Val ACC: 100.00%
# Fold 4/46
# Epoch 1/10, train Loss: 0.3316, val Loss: 0.3316, train ACC: 95.60%, Val ACC: 66.67%
# Epoch 2/10, train Loss: 0.1076, val Loss: 0.1076, train ACC: 96.86%, Val ACC: 100.00%
# Epoch 3/10, train Loss: 0.0829, val Loss: 0.0829, train ACC: 93.71%, Val ACC: 100.00%
# Epoch 4/10, train Loss: 0.2270, val Loss: 0.2270, train ACC: 98.11%, Val ACC: 100.00%
# Epoch 5/10, train Loss: 0.5670, val Loss: 0.5670, train ACC: 94.97%, Val ACC: 66.67%
# Epoch 6/10, train Loss: 0.0412, val Loss: 0.0412, train ACC: 96.23%, Val ACC: 100.00%
# Epoch 7/10, train Loss: 0.0578, val Loss: 0.0578, train ACC: 96.86%, Val ACC: 100.00%
# Epoch 8/10, train Loss: 0.1655, val Loss: 0.1655, train ACC: 95.60%, Val ACC: 100.00%
# Epoch 9/10, train Loss: 0.1491, val Loss: 0.1491, train ACC: 96.23%, Val ACC: 100.00%
# Epoch 10/10, train Loss: 0.0902, val Loss: 0.0902, train ACC: 97.48%, Val ACC: 100.00%
# Fold 5/46
# Epoch 1/10, train Loss: 0.0421, val Loss: 0.0421, train ACC: 94.94%, Val ACC: 100.00%
# Epoch 2/10, train Loss: 0.1012, val Loss: 0.1012, train ACC: 96.20%, Val ACC: 100.00%
# Epoch 3/10, train Loss: 0.0216, val Loss: 0.0216, train ACC: 94.94%, Val ACC: 100.00%
# Epoch 4/10, train Loss: 0.0096, val Loss: 0.0096, train ACC: 94.94%, Val ACC: 100.00%
# Epoch 5/10, train Loss: 0.0021, val Loss: 0.0021, train ACC: 96.20%, Val ACC: 100.00%
# Epoch 6/10, train Loss: 0.0106, val Loss: 0.0106, train ACC: 96.20%, Val ACC: 100.00%
# Epoch 7/10, train Loss: 0.0492, val Loss: 0.0492, train ACC: 98.10%, Val ACC: 100.00%
# Epoch 8/10, train Loss: 0.0019, val Loss: 0.0019, train ACC: 95.57%, Val ACC: 100.00%
# Epoch 9/10, train Loss: 0.
train ACC: 96.84%, Val ACC: 100.00%
# Epoch 4/10, train Loss: 0.0262, val Loss: 0.0262, train ACC: 97.47%, Val ACC: 100.00%
# Epoch 5/10, train Loss: 0.0658, val Loss: 0.0658, train ACC: 91.77%, Val ACC: 100.00%
# Epoch 6/10, train Loss: 0.4020, val Loss: 0.4020, train ACC: 97.47%, Val ACC: 75.00%
# Epoch 7/10, train Loss: 0.1035, val Loss: 0.1035, train ACC: 94.94%, Val ACC: 100.00%
# Epoch 8/10, train Loss: 0.4725, val Loss: 0.4725, train ACC: 95.57%, Val ACC: 75.00%
# Epoch 9/10, train Loss: 0.0118, val Loss: 0.0118, train ACC: 96.20%, Val ACC: 100.00%
# Epoch 10/10, train Loss: 0.0938, val Loss: 0.0938, train ACC: 92.41%, Val ACC: 100.00%
# Fold 23/46
# Epoch 1/10, train Loss: 0.0856, val Loss: 0.0856, train ACC: 96.25%, Val ACC: 100.00%
# Epoch 2/10, train Loss: 0.0009, val Loss: 0.0009, train ACC: 96.25%, Val ACC: 100.00%
# Epoch 3/10, train Loss: 0.0077, val Loss: 0.0077, train ACC: 98.12%, Val ACC: 100.00%
# Epoch 4/10, train Loss: 0.0087, val Loss: 0.0087, train ACC: 96.25%, Val ACC: 100.00%
# Epoch 5/10, train Loss: 0.0592, val Loss: 0.0592, train ACC: 96.25%, Val ACC: 100.00%
# Epoch 6/10, train Loss: 0.0096, val Loss: 0.0096, train ACC: 96.25%, Val ACC: 100.00%
# Epoch 7/10, train Loss: 0.0758, val Loss: 0.0758, train ACC: 96.25%, Val ACC: 100.00%
# Epoch 8/10, train Loss: 0.0102, val Loss: 0.0102, train ACC: 95.62%, Val ACC: 100.00%
# Epoch 9/10, train Loss: 0.0043, val Loss: 0.0043, train ACC: 97.50%, Val ACC: 100.00%
# Epoch 10/10, train Loss: 0.0124, val Loss: 0.0124, train ACC: 97.50%, Val ACC: 100.00%
# Fold 24/46
# Epoch 1/10, train Loss: 0.0497, val Loss: 0.0497, train ACC: 95.62%, Val ACC: 100.00%
# Epoch 2/10, train Loss: 0.0195, val Loss: 0.0195, train ACC: 95.00%, Val ACC: 100.00%
# Epoch 3/10, train Loss: 0.0573, val Loss: 0.0573, train ACC: 93.75%, Val ACC: 100.00%
# Epoch 4/10, train Loss: 0.0216, val Loss: 0.0216, train ACC: 96.88%, Val ACC: 100.00%
# Epoch 5/10, train Loss: 0.1207, val Loss: 0.1207, train ACC: 92.50%, Val ACC: 100.00%
# Epoch 6/10, train Loss: 0.0581, val Loss: 0.0581, train ACC: 97.50%, Val ACC: 100.00%
# Epoch 7/10, train Loss: 0.1898, val Loss: 0.1898, train ACC: 96.25%, Val ACC: 100.00%
# Epoch 8/10, train Loss: 0.0713, val Loss: 0.0713, train ACC: 95.62%, Val ACC: 100.00%
# Epoch 9/10, train Loss: 0.2527, val Loss: 0.2527, train ACC: 95.62%, Val ACC: 100.00%
# Epoch 10/10, train Loss: 0.1731, val Loss: 0.1731, train ACC: 96.25%, Val ACC: 100.00%
# Fold 25/46
# Epoch 1/10, train Loss: 1.3941, val Loss: 1.3941, train ACC: 96.86%, Val ACC: 33.33%
# Epoch 2/10, train Loss: 0.3689, val Loss: 0.3689, train ACC: 99.37%, Val ACC: 100.00%
# Epoch 3/10, train Loss: 1.4133, val Loss: 1.4133, train ACC: 95.60%, Val ACC: 33.33%
# Epoch 4/10, train Loss: 0.6558, val Loss: 0.6558, train ACC: 96.86%, Val ACC: 66.67%
# Epoch 5/10, train Loss: 0.3002, val Loss: 0.3002, train ACC: 96.23%, Val ACC: 100.00%
# Epoch 6/10, train Loss: 0.0557, val Loss: 0.0557, train ACC: 95.60%, Val ACC: 100.00%
# Epoch 7/10, train Loss: 0.3949, val Loss: 0.3949, train ACC: 94.97%, Val ACC: 66.67%
# Epoch 8/10, train Loss: 0.6071, val Loss: 0.6071, train ACC: 96.86%, Val ACC: 66.67%
# Epoch 9/10, train Loss: 0.5951, val Loss: 0.5951, train ACC: 91.82%, Val ACC: 66.67%
# Epoch 10/10, train Loss: 0.5072, val Loss: 0.5072, train ACC: 97.48%, Val ACC: 66.67%
# Fold 26/46
# Epoch 1/10, train Loss: 0.0263, val Loss: 0.0263, train ACC: 94.30%, Val ACC: 100.00%
# Epoch 2/10, train Loss: 0.0467, val Loss: 0.0467, train ACC: 95.57%, Val ACC: 100.00%
# Epoch 3/10, train Loss: 0.0167, val Loss: 0.0167, train ACC: 96.20%, Val ACC: 100.00%
# Epoch 4/10, train Loss: 0.0088, val Loss: 0.0088, train ACC: 97.47%, Val ACC: 100.00%
# Epoch 5/10, train Loss: 0.0208, val Loss: 0.0208, train ACC: 96.20%, Val ACC: 100.00%
# Epoch 6/10, train Loss: 0.0511, val Loss: 0.0511, train ACC: 94.94%, Val ACC: 100.00%
# Epoch 7/10, train Loss: 0.0292, val Loss: 0.0292, train ACC: 96.20%, Val ACC: 100.00%
# Epoch 8/10, train Loss: 0.0458, val Loss: 0.0458, train ACC: 96.20%, Val ACC: 100.00%
# Epoch 9/10, train Loss: 0.0091, val Loss: 0.0091, train ACC: 97.47%, Val ACC: 100.00%
# Epoch 10/10, train Loss: 0.0152, val Loss: 0.0152, train ACC: 92.41%, Val ACC: 100.00%
# Fold 27/46
# Epoch 1/10, train Loss: 0.0356, val Loss: 0.0356, train ACC: 92.36%, Val ACC: 100.00%
# Epoch 2/10, train Loss: 0.0432, val Loss: 0.0432, train ACC: 96.18%, Val ACC: 100.00%
# Epoch 3/10, train Loss: 0.0019, val Loss: 0.0019, train ACC: 94.90%, Val ACC: 100.00%
# Epoch 4/10, train Loss: 0.0331, val Loss: 0.0331, train ACC: 96.82%, Val ACC: 100.00%
# Epoch 5/10, train Loss: 0.0101, val Loss: 0.0101, train ACC: 96.18%, Val ACC: 100.00%
# Epoch 6/10, train Loss: 0.0086, val Loss: 0.0086, train ACC: 96.18%, Val ACC: 100.00%
# Epoch 7/10, train Loss: 0.0432, val Loss: 0.0432, train ACC: 96.18%, Val ACC: 100.00%
# Epoch 8/10, train Loss: 0.1497, val Loss: 0.1497, train ACC: 94.27%, Val ACC: 80.00%
# Epoch 9/10, train Loss: 0.0139, val Loss: 0.0139, train ACC: 98.73%, Val ACC: 100.00%
# Epoch 10/10, train Loss: 0.
train ACC: 96.84%, Val ACC: 100.00%
# Epoch 8/10, train Loss: 0.0187, val Loss: 0.0187, train ACC: 96.20%, Val ACC: 100.00%
# Epoch 9/10, train Loss: 0.0107, val Loss: 0.0107, train ACC: 95.57%, Val ACC: 100.00%
# Epoch 10/10, train Loss: 0.0273, val Loss: 0.0273, train ACC: 95.57%, Val ACC: 100.00%
# Fold 34/46
# Epoch 1/10, train Loss: 0.1178, val Loss: 0.1178, train ACC: 94.34%, Val ACC: 100.00%
# Epoch 2/10, train Loss: 0.0401, val Loss: 0.0401, train ACC: 96.86%, Val ACC: 100.00%
# Epoch 3/10, train Loss: 0.0286, val Loss: 0.0286, train ACC: 98.74%, Val ACC: 100.00%
# Epoch 4/10, train Loss: 0.1154, val Loss: 0.1154, train ACC: 98.11%, Val ACC: 100.00%
# Epoch 5/10, train Loss: 0.1343, val Loss: 0.1343, train ACC: 96.86%, Val ACC: 100.00%
# Epoch 6/10, train Loss: 0.1009, val Loss: 0.1009, train ACC: 95.60%, Val ACC: 100.00%
# Epoch 7/10, train Loss: 0.0092, val Loss: 0.0092, train ACC: 97.48%, Val ACC: 100.00%
# Epoch 8/10, train Loss: 0.1110, val Loss: 0.1110, train ACC: 93.08%, Val ACC: 100.00%
# Epoch 9/10, train Loss: 0.0634, val Loss: 0.0634, train ACC: 95.60%, Val ACC: 100.00%
# Epoch 10/10, train Loss: 0.0311, val Loss: 0.0311, train ACC: 92.45%, Val ACC: 100.00%
# Fold 35/46
# Epoch 1/10, train Loss: 1.3818, val Loss: 1.3818, train ACC: 98.12%, Val ACC: 50.00%
# Epoch 2/10, train Loss: 0.0346, val Loss: 0.0346, train ACC: 96.88%, Val ACC: 100.00%
# Epoch 3/10, train Loss: 0.0142, val Loss: 0.0142, train ACC: 96.88%, Val ACC: 100.00%
# Epoch 4/10, train Loss: 0.1298, val Loss: 0.1298, train ACC: 96.88%, Val ACC: 100.00%
# Epoch 5/10, train Loss: 0.1322, val Loss: 0.1322, train ACC: 96.25%, Val ACC: 100.00%
# Epoch 6/10, train Loss: 0.0553, val Loss: 0.0553, train ACC: 96.25%, Val ACC: 100.00%
# Epoch 7/10, train Loss: 0.0242, val Loss: 0.0242, train ACC: 93.12%, Val ACC: 100.00%
# Epoch 8/10, train Loss: 0.0170, val Loss: 0.0170, train ACC: 95.00%, Val ACC: 100.00%
# Epoch 9/10, train Loss: 0.0276, val Loss: 0.0276, train ACC: 96.88%, Val ACC: 100.00%
# Epoch 10/10, train Loss: 0.1184, val Loss: 0.1184, train ACC: 95.62%, Val ACC: 100.00%
# Fold 36/46
# Epoch 1/10, train Loss: 0.2423, val Loss: 0.2423, train ACC: 97.47%, Val ACC: 100.00%
# Epoch 2/10, train Loss: 0.2027, val Loss: 0.2027, train ACC: 94.30%, Val ACC: 100.00%
# Epoch 3/10, train Loss: 0.3353, val Loss: 0.3353, train ACC: 96.20%, Val ACC: 75.00%
# Epoch 4/10, train Loss: 0.2218, val Loss: 0.2218, train ACC: 96.20%, Val ACC: 100.00%
# Epoch 5/10, train Loss: 0.2505, val Loss: 0.2505, train ACC: 96.20%, Val ACC: 100.00%
# Epoch 6/10, train Loss: 0.3189, val Loss: 0.3189, train ACC: 93.67%, Val ACC: 75.00%
# Epoch 7/10, train Loss: 0.0383, val Loss: 0.0383, train ACC: 93.04%, Val ACC: 100.00%
# Epoch 8/10, train Loss: 0.0638, val Loss: 0.0638, train ACC: 95.57%, Val ACC: 100.00%
# Epoch 9/10, train Loss: 0.1560, val Loss: 0.1560, train ACC: 98.10%, Val ACC: 100.00%
# Epoch 10/10, train Loss: 0.1166, val Loss: 0.1166, train ACC: 96.20%, Val ACC: 100.00%
# Fold 37/46
# Epoch 1/10, train Loss: 0.0493, val Loss: 0.0493, train ACC: 94.94%, Val ACC: 100.00%
# Epoch 2/10, train Loss: 0.0634, val Loss: 0.0634, train ACC: 95.57%, Val ACC: 100.00%
# Epoch 3/10, train Loss: 0.1189, val Loss: 0.1189, train ACC: 95.57%, Val ACC: 100.00%
# Epoch 4/10, train Loss: 0.0086, val Loss: 0.0086, train ACC: 93.67%, Val ACC: 100.00%
# Epoch 5/10, train Loss: 0.0234, val Loss: 0.0234, train ACC: 96.20%, Val ACC: 100.00%
# Epoch 6/10, train Loss: 0.0701, val Loss: 0.0701, train ACC: 97.47%, Val ACC: 100.00%
# Epoch 7/10, train Loss: 0.0409, val Loss: 0.0409, train ACC: 97.47%, Val ACC: 100.00%
# Epoch 8/10, train Loss: 0.0175, val Loss: 0.0175, train ACC: 96.84%, Val ACC: 100.00%
# Epoch 9/10, train Loss: 0.0830, val Loss: 0.0830, train ACC: 93.04%, Val ACC: 100.00%
# Epoch 10/10, train Loss: 0.0224, val Loss: 0.0224, train ACC: 96.20%, Val ACC: 100.00%
# Fold 38/46
# Epoch 1/10, train Loss: 0.0235, val Loss: 0.0235, train ACC: 93.71%, Val ACC: 100.00%
# Epoch 2/10, train Loss: 0.1069, val Loss: 0.1069, train ACC: 93.08%, Val ACC: 100.00%
# Epoch 3/10, train Loss: 0.0372, val Loss: 0.0372, train ACC: 94.97%, Val ACC: 100.00%
# Epoch 4/10, train Loss: 0.5922, val Loss: 0.5922, train ACC: 97.48%, Val ACC: 66.67%
# Epoch 5/10, train Loss: 0.0418, val Loss: 0.0418, train ACC: 98.74%, Val ACC: 100.00%
# Epoch 6/10, train Loss: 0.0827, val Loss: 0.0827, train ACC: 96.23%, Val ACC: 100.00%
# Epoch 7/10, train Loss: 0.1161, val Loss: 0.1161, train ACC: 97.48%, Val ACC: 100.00%
# Epoch 8/10, train Loss: 0.0386, val Loss: 0.0386, train ACC: 96.86%, Val ACC: 100.00%
# Epoch 9/10, train Loss: 0.0065, val Loss: 0.0065, train ACC: 96.23%, Val ACC: 100.00%
# Epoch 10/10, train Loss: 0.0549, val Loss: 0.0549, train ACC: 96.86%, Val ACC: 100.00%
# Fold 39/46
# Epoch 1/10, train Loss: 0.4965, val Loss: 0.4965, train ACC: 95.00%, Val ACC: 100.00%
# Epoch 2/10, train Loss: 0.3049, val Loss: 0.3049, train ACC: 98.75%, Val ACC: 100.00%
# Epoch 3/10, train Loss: 0.7876, val Loss: 0.7876, train ACC: 96.25%, Val ACC: 50.00%
# Epoch 4/10, train Loss: 0.2475, val Loss: 0.2475, train ACC: 97.50%, Val ACC: 100.00%
# Epoch 5/10, train Loss: 0.2287, val Loss: 0.2287, train ACC: 97.50%, Val ACC: 100.00%
# Epoch 6/10, train Loss: 0.5332, val Loss: 0.5332, train ACC: 95.62%, Val ACC: 50.00%
# Epoch 7/10, train Loss: 0.6420, val Loss: 0.6420, train ACC: 93.12%, Val ACC: 50.00%
# Epoch 8/10, train Loss: 0.1737, val Loss: 0.1737, train ACC: 98.12%, Val ACC: 100.00%
# Epoch 9/10, train Loss: 0.3827, val Loss: 0.3827, train ACC: 98.12%, Val ACC: 100.00%
# Epoch 10/10, train Loss: 0.6258, val Loss: 0.6258, train ACC: 94.38%, Val ACC: 100.00%
# Fold 40/46
# Epoch 1/10, train Loss: 0.1162, val Loss: 0.1162, train ACC: 95.62%, Val ACC: 100.00%
# Epoch 2/10, train Loss: 0.6156, val Loss: 0.6156, train ACC: 96.25%, Val ACC: 100.00%
# Epoch 3/10, train Loss: 0.2854, val Loss: 0.2854, train ACC: 93.75%, Val ACC: 100.00%
# Epoch 4/10, train Loss: 0.2619, val Loss: 0.2619, train ACC: 96.88%, Val ACC: 100.00%
# Epoch 5/10, train Loss: 0.5310, val Loss: 0.5310, train ACC: 91.88%, Val ACC: 100.00%
# Epoch 6/10, train Loss: 0.0828, val Loss: 0.0828, train ACC: 95.62%, Val ACC: 100.00%
# Epoch 7/10, train Loss: 0.2501, val Loss: 0.2501, train ACC: 95.00%, Val ACC: 100.00%
# Epoch 8/10, train Loss: 0.3040, val Loss: 0.3040, train ACC: 97.50%, Val ACC: 100.00%
# Epoch 9/10, train Loss: 0.5038, val Loss: 0.5038, train ACC: 96.25%, Val ACC: 100.00%
# Epoch 10/10, train Loss: 0.6846, val Loss: 0.6846, train ACC: 96.25%, Val ACC: 50.00%
# Fold 41/46
# Epoch 1/10, train Loss: 0.0292, val Loss: 0.0292, train ACC: 97.48%, Val ACC: 100.00%
# Epoch 2/10, train Loss: 0.0334, val Loss: 0.0334, train ACC: 98.11%, Val ACC: 100.00%
# Epoch 3/10, train Loss: 0.1227, val Loss: 0.1227, train ACC: 96.23%, Val ACC: 100.00%
# Epoch 4/10, train Loss: 0.0055, val Loss: 0.0055, train ACC: 95.60%, Val ACC: 100.00%
# Epoch 5/10, train Loss: 0.1748, val Loss: 0.1748, train ACC: 96.86%, Val ACC: 100.00%
# Epoch 6/10, train Loss: 0.0324, val Loss: 0.0324, train ACC: 96.86%, Val ACC: 100.00%
# Epoch 7/10, train Loss: 0.4464, val Loss: 0.4464, train ACC: 97.48%, Val ACC: 66.67%
# Epoch 8/10, train Loss: 0.0699, val Loss: 0.0699, train ACC: 92.45%, Val ACC: 100.00%
# Epoch 9/10, train Loss: 0.0084, val Loss: 0.0084, train ACC: 99.37%, Val ACC: 100.00%
# Epoch 10/10, train Loss: 0.0010, val Loss: 0.0010, train ACC: 94.97%, Val ACC: 100.00%
# Fold 42/46
# Epoch 1/10, train Loss: 0.4126, val Loss: 0.4126, train ACC: 96.23%, Val ACC: 66.67%
# Epoch 2/10, train Loss: 0.7483, val Loss: 0.7483, train ACC: 93.71%, Val ACC: 33.33%
# Epoch 3/10, train Loss: 0.8084, val Loss: 0.8084, train ACC: 97.48%, Val ACC: 66.67%
# Epoch 4/10, train Loss: 1.0378, val Loss: 1.0378, train ACC: 94.34%, Val ACC: 33.33%
# Epoch 5/10, train Loss: 1.4428, val Loss: 1.4428, train ACC: 96.86%, Val ACC: 33.33%
# Epoch 6/10, train Loss: 0.3975, val Loss: 0.3975, train ACC: 98.11%, Val ACC: 100.00%
# Epoch 7/10, train Loss: 1.1966, val Loss: 1.1966, train ACC: 96.23%, Val ACC: 33.33%
# Epoch 8/10, train Loss: 0.6468, val Loss: 0.6468, train ACC: 97.48%, Val ACC: 33.33%
# Epoch 9/10, train Loss: 0.6652, val Loss: 0.6652, train ACC: 95.60%, Val ACC: 66.67%
# Epoch 10/10, train Loss: 0.6888, val Loss: 0.6888, train ACC: 97.48%, Val ACC: 66.67%
# Fold 43/46
# Epoch 1/10, train Loss: 0.0489, val Loss: 0.0489, train ACC: 95.62%, Val ACC: 100.00%
# Epoch 2/10, train Loss: 0.1638, val Loss: 0.1638, train ACC: 95.62%, Val ACC: 100.00%
# Epoch 3/10, train Loss: 0.8161, val Loss: 0.8161, train ACC: 95.00%, Val ACC: 0.00%
# Epoch 4/10, train Loss: 0.1497, val Loss: 0.1497, train ACC: 93.12%, Val ACC: 100.00%
# Epoch 5/10, train Loss: 0.1475, val Loss: 0.1475, train ACC: 96.25%, Val ACC: 100.00%
# Epoch 6/10, train Loss: 0.1918, val Loss: 0.1918, train ACC: 94.38%, Val ACC: 100.00%
# Epoch 7/10, train Loss: 0.1847, val Loss: 0.1847, train ACC: 93.75%, Val ACC: 100.00%
# Epoch 8/10, train Loss: 0.2121, val Loss: 0.2121, train ACC: 95.62%, Val ACC: 100.00%
# Epoch 9/10, train Loss: 0.0666, val Loss: 0.0666, train ACC: 96.88%, Val ACC: 100.00%
# Epoch 10/10, train Loss: 0.3102, val Loss: 0.3102, train ACC: 96.25%, Val ACC: 100.00%
# Fold 44/46
# Epoch 1/10, train Loss: 0.0190, val Loss: 0.0190, train ACC: 96.23%, Val ACC: 100.00%
# Epoch 2/10, train Loss: 0.1833, val Loss: 0.1833, train ACC: 97.48%, Val ACC: 100.00%
# Epoch 3/10, train Loss: 0.0136, val Loss: 0.0136, train ACC: 91.82%, Val ACC: 100.00%
# Epoch 4/10, train Loss: 0.0044, val Loss: 0.0044, train ACC: 94.97%, Val ACC: 100.00%
# Epoch 5/10, train Loss: 0.0080, val Loss: 0.0080, train ACC: 96.86%, Val ACC: 100.00%
# Epoch 6/10, train Loss: 0.0470, val Loss: 0.0470, train ACC: 96.86%, Val ACC: 100.00%
# Epoch 7/10, train Loss: 0.0048, val Loss: 0.0048, train ACC: 94.97%, Val ACC: 100.00%
# Epoch 8/10, train Loss: 0.0039, val Loss: 0.0039, train ACC: 98.11%, Val ACC: 100.00%
# Epoch 9/10, train Loss: 0.0034, val Loss: 0.0034, train ACC: 97.48%, Val ACC: 100.00%
# Epoch 10/10, train Loss: 0.0261, val Loss: 0.0261, train ACC: 96.23%, Val ACC: 100.00%
# Fold 45/46
# Epoch 1/10, train Loss: 0.0501, val Loss: 0.0501, train ACC: 96.86%, Val ACC: 100.00%
# Epoch 2/10, train Loss: 0.3359, val Loss: 0.3359, train ACC: 96.23%, Val ACC: 66.67%
# Epoch 3/10, train Loss: 0.1098, val Loss: 0.1098, train ACC: 94.97%, Val ACC: 100.00%
# Epoch 4/10, train Loss: 0.0839, val Loss: 0.0839, train ACC: 94.97%, Val ACC: 100.00%
# Epoch 5/10, train Loss: 0.1447, val Loss: 0.1447, train ACC: 94.97%, Val ACC: 100.00%
# Epoch 6/10, train Loss: 0.1462, val Loss: 0.1462, train ACC: 94.34%, Val ACC: 100.00%
# Epoch 7/10, train Loss: 0.0391, val Loss: 0.0391, train ACC: 95.60%, Val ACC: 100.00%
# Epoch 8/10, train Loss: 0.2045, val Loss: 0.2045, train ACC: 93.71%, Val ACC: 100.00%
# Epoch 9/10, train Loss: 0.1475, val Loss: 0.1475, train ACC: 97.48%, Val ACC: 100.00%
# Epoch 10/10, train Loss: 0.2279, val Loss: 0.2279, train ACC: 95.60%, Val ACC: 100.00%
# Fold 46/46
# Epoch 1/10, train Loss: 0.0331, val Loss: 0.0331, train ACC: 96.82%, Val ACC: 100.00%
# Epoch 2/10, train Loss: 0.0346, val Loss: 0.0346, train ACC: 97.45%, Val ACC: 100.00%
# Epoch 3/10, train Loss: 0.0124, val Loss: 0.0124, train ACC: 96.82%, Val ACC: 100.00%
# Epoch 4/10, train Loss: 0.1842, val Loss: 0.1842, train ACC: 95.54%, Val ACC: 100.00%
# Epoch 5/10, train Loss: 0.0400, val Loss: 0.0400, train ACC: 94.90%, Val ACC: 100.00%
# Epoch 6/10, train Loss: 0.0234, val Loss: 0.0234, train ACC: 96.18%, Val ACC: 100.00%
# Epoch 7/10, train Loss: 0.0120, val Loss: 0.0120, train ACC: 96.18%, Val ACC: 100.00%
# Epoch 8/10, train Loss: 0.0447, val Loss: 0.0447, train ACC: 98.09%, Val ACC: 100.00%
# Epoch 9/10, train Loss: 0.0313, val Loss: 0.0313, train ACC: 95.54%, Val ACC: 100.00%
# Epoch 10/10, train Loss: 0.0324, val Loss: 0.0324, train ACC: 94.27%, Val ACC: 100.00%

# %%
test_model(model=model, test_dataset=test_dataset, batch_size=64)
# Out:
# Test Loss: 0.4856, Test Acc: 77.11%
# AUC: 0.7746376811594202
# Confusion Matrix:
# [[46 14]
#  [ 5 18]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          NFF       0.90      0.77      0.83        60
#          AFF       0.56      0.78      0.65        23
#
#     accuracy                           0.77        83
#    macro avg       0.73      0.77      0.74        83
# weighted avg       0.81      0.77      0.78        83

# %% [markdown]
# # ResNet 152

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import LeaveOneGroupOut
from torchvision.models import resnet152, ResNet152_Weights


patient_ids = train_dataset.patient_ids
# use LabelEncoder, make Patient id to int
label_encoder = LabelEncoder()
encoded_patient_ids = label_encoder.fit_transform(patient_ids)

# leave one out
logo = LeaveOneGroupOut()

# get class weight
classweight = get_classweight(train_dataset)

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Define the ResNet-101 model
model = models.resnet152(weights=ResNet152_Weights.DEFAULT)
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)  # Assuming 2 classes, change it according to your problem
model = model.to(device)

# Define your loss function and optimizer
# criterion = nn.CrossEntropyLoss()
criterion = nn.CrossEntropyLoss(weight=torch.Tensor(classweight).to(device))

optimizer = optim.RMSprop(model.parameters(), lr=0.0001)
scheduler = lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# # Define the number of splits for cross-validation
# n_splits = 5
# # kf = KFold(n_splits=n_splits, shuffle=True, random_state=1)
# kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=1)

# Perform k-fold cross-validation
# for fold, (train_idx, val_idx) in enumerate(kf.split(range(len(train_dataset)), train_dataset.patient_ids)): # fold by patientID
for fold, (train_idx, val_idx) in enumerate(logo.split(X=range(len(train_dataset)), groups=encoded_patient_ids)): # leave one out
# for fold, (train_idx, val_idx) in enumerate(kf.split(range(len(train_dataset)))): # fold by datasets
    # print(f'Fold {fold + 1}/{n_splits}')
    # print(f'Fold {fold + 1}/{len(logo)}')
    print(f'Fold {fold + 1}/{len(np.unique(encoded_patient_ids))}')

    # Create data loaders for training and validation subsets
    train_sampler = torch.utils.data.SubsetRandomSampler(train_idx)
    val_sampler = torch.utils.data.SubsetRandomSampler(val_idx)

    train_loader = DataLoader(train_dataset, batch_size=64, sampler=train_sampler)
    val_loader = DataLoader(train_dataset, batch_size=64, sampler=val_sampler)

    # Training loop
    num_epochs = 10  # Choose the number of epochs
        # Loss, ACC
    train_losses = []
    validation_losses = []
    train_accuracies = []
    validation_accuracies = []
    
    for epoch in range(num_epochs):
        model.train()
        correct_train = 0
        total_train = 0
        
        for images, labels,_ in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
        
        train_accuracy = 100 * correct_train / total_train
        
        model.eval()
        correct_validation_aff = 0
        total_validation_aff = 0
        correct_validation = 0
        total_validation = 0
        validation_loss = 0
        
        with torch.no_grad():
            for images, labels,_ in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                
                outputs = model(images)
                loss = criterion(outputs, labels)
                
                _, predicted = torch.max(outputs.data, 1)
                total_validation += labels.size(0)
                correct_validation += (predicted == labels).sum().item()
                validation_loss += loss.item()
                # Calculate accuracy for AFF class
                total_validation_aff += torch.sum(labels == 1).item()
                correct_validation_aff += torch.sum((predicted == 1) & (labels == 1)).item()

        # validation_accuracy_aff = 100 * correct_validation_aff / total_validation_aff

        # validation accuracy and loss
        validation_accuracy = 100 * correct_validation / total_validation
        validation_loss /= len(val_loader)
        
        train_losses.append(loss.item())
        validation_losses.append(validation_loss)
        train_accuracies.append(train_accuracy)
        validation_accuracies.append(validation_accuracy)
        
        print(f"Epoch {epoch+1}/{num_epochs}, "
            f"train Loss: {loss.item():.4f}, "
            f"val Loss: {validation_loss:.4f}, "
            f"train ACC: {train_accuracy:.2f}%, "
            f"Val ACC: {validation_accuracy:.2f}%")
        scheduler.step()

# %%
test_model(model=model, test_dataset=test_dataset, batch_size=64)
