# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import models
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import os
import random
import shutil
from sklearn.metrics import roc_auc_score

def split_by_patient(dataset_root, target_root, train_ratio, val_ratio):
    if not os.path.exists(target_root):
        # create target root if not exit
        os.makedirs(target_root)

        # AFF and NFF folder
        fracture_types = ['0_NFF', '1_AFF' ]
        for fracture_type in fracture_types:
            source_folder = os.path.join(dataset_root, fracture_type)
            patients = os.listdir(source_folder)
            
            # select random patients
            random.seed(123)
            random.shuffle(patients)
            
            # split patients
            total_patients = len(patients)
            train_end = int(total_patients * train_ratio)
            val_end = train_end + int(total_patients * val_ratio)
            
            train_patients = patients[:train_end]
            val_patients = patients[train_end:val_end]
            test_patients = patients[val_end:]
            
            # copy images to folder
            for patient_id in train_patients:
                source_path = os.path.join(source_folder, patient_id)
                target_path = os.path.join(target_root, 'train', fracture_type, patient_id)
                shutil.copytree(source_path, target_path)
            
            for patient_id in val_patients:
                source_path = os.path.join(source_folder, patient_id)
                target_path = os.path.join(target_root, 'val', fracture_type, patient_id)
                shutil.copytree(source_path, target_path)
            
            for patient_id in test_patients:
                source_path = os.path.join(source_folder, patient_id)
                target_path = os.path.join(target_root, 'test', fracture_type, patient_id)
                shutil.copytree(source_path, target_path)
        print("Dataset split completed.")
    
    else:
        print("Target dataset folder already exists.")

def create_dataset(train_root, val_root, test_root):
    # Define data augmentation transforms
    train_transform = transforms.Compose([
        transforms.RandomHorizontalFlip(p=1),
        transforms.RandomVerticalFlip(p=1),
        transforms.RandomRotation(degrees=(0, 180)),
        transforms.ColorJitter(brightness=0.5, contrast=0.1, saturation=0.1, hue=0.3),
        # transforms.RandomApply([transforms.RandomAffine(degrees=0, translate=(0.1, 0.1))], p=1),
        transforms.GaussianBlur(kernel_size=(5,9), sigma=(0.1, 5)),
        transforms.RandomInvert(),
        transforms.RandomPosterize(bits=2),
        transforms.RandomAdjustSharpness(sharpness_factor=4),
        # transforms.RandomAutocontrast(),
        transforms.RandomApply([transforms.RandomPerspective(distortion_scale=0.2)], p=1),
        transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

    # Define the data loaders
    train_dataset = ImageFolder(root=train_root, transform=train_transform)
    validation_dataset = ImageFolder(root=val_root, transform=test_transform)
    test_dataset = ImageFolder(root=test_root, transform=test_transform)

    return train_dataset, validation_dataset, test_dataset

def show_image(dataset, num_images=5):
    # Get some random indices from the dataset
    random_indices = np.random.choice(len(dataset), num_images, replace=False)

    # Plot images with truncated names
    plt.figure(figsize=(15, 5))
    for i, idx in enumerate(random_indices):
        image, label = dataset[idx]  # Use the dataset directly
        filename = dataset.samples[idx][0]  # Get the filename
        truncated_filename = filename.split('/')[-1][:15]  # Extract the last part and truncate to 15 characters
        plt.subplot(1, num_images, i + 1)
        plt.title(f"Label: {label}")
        plt.imshow(image[0], cmap='gray')  # Assuming single-channel (grayscale) image
        # plt.imshow(image[0])  # Assuming single-channel (grayscale) image
        plt.axis('off')
    plt.show()

def get_classweight(train_dataset):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    # aff and nff numbers in training dataset
    train_aff_count = sum(1 for _, label in train_dataset if label == 0)  # 0 AFF
    train_nff_count = sum(1 for _, label in train_dataset if label == 1)  # 1 NFF

    # Calculate class weights
    n_aff_train = train_aff_count
    n_nff_train = train_nff_count

    class_weight_aff = 1 / (2 * (n_aff_train / (n_aff_train + n_nff_train)))
    class_weight_nff = 1 / (2 * (n_nff_train / (n_aff_train + n_nff_train)))
    
    return [class_weight_aff, class_weight_nff]
    
def train_model(train_loader, validation_loader, classweight, num_epochs, lr, step_size, gamma, model_name, device):

    # Load pre-trained model
    torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')
    if model_name == 'resnet152':
        from torchvision.models import resnet152, ResNet152_Weights
        model = models.resnet152(weights=ResNet152_Weights.DEFAULT)
        
    elif model_name == 'densenet161':
        from torchvision.models import densenet161, DenseNet161_Weights
        model = models.densenet161(weights=DenseNet161_Weights.DEFAULT)
        
    elif model_name == 'resnet50':
        from torchvision.models import resnet50, ResNet50_Weights
        model = models.resnet50(weights=ResNet50_Weights.DEFAULT)

    elif model_name == 'vgg19':
        from torchvision.models import vgg19, VGG19_Weights
        model = models.vgg19(weights=VGG19_Weights.DEFAULT)

    elif model_name == 'resnet101':
        from torchvision.models import resnet101, ResNet101_Weights
        model = models.resnet101(weights=ResNet101_Weights.DEFAULT)
        
    else:
        raise ValueError("Invalid model type. 'vgg19' 'resnet50' 'resnet101' 'resnet152' or 'densenet161'.")
    
    # Modify the output layer
    num_classes = 2
    if model_name == 'densenet161':
        in_features = model.classifier.in_features
        model.classifier = nn.Sequential(nn.Dropout(0.5),nn.Linear(in_features, num_classes))
    else:
        in_features = model.fc.in_features
        model.fc = nn.Sequential(nn.Dropout(0.5), nn.Linear(in_features, num_classes))
    
    # Move model to the specified device
    model = model.to(device)
    
    # Loss function and optimizer
    criterion = nn.CrossEntropyLoss(weight=torch.Tensor(classweight).to(device))
    optimizer = optim.Adam(model.parameters(), lr=lr)
    scheduler = lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)
    
    # Training (loss and accuracy)
    train_losses = []
    validation_losses = []
    train_accuracies = []
    validation_accuracies = []
    
    for epoch in range(num_epochs):
        model.train()
        correct_train = 0
        total_train = 0
        
        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
        
        train_accuracy = 100 * correct_train / total_train
        
        model.eval()
        correct_validation = 0
        total_validation = 0
        validation_loss = 0
        
        with torch.no_grad():
            for images, labels in validation_loader:
                images = images.to(device)
                labels = labels.to(device)
                
                outputs = model(images)
                loss = criterion(outputs, labels)
                
                _, predicted = torch.max(outputs.data, 1)
                total_validation += labels.size(0)
                correct_validation += (predicted == labels).sum().item()
                validation_loss += loss.item()
        
        # validation accuracy and loss
        validation_accuracy = 100 * correct_validation / total_validation
        validation_loss /= len(validation_loader)
        
        train_losses.append(loss.item())
        validation_losses.append(validation_loss)
        train_accuracies.append(train_accuracy)
        validation_accuracies.append(validation_accuracy)
        
        print(f"Epoch {epoch+1}/{num_epochs}, "
            f"Train Loss: {loss.item():.4f}, "
            f"Validation Loss: {validation_loss:.4f}, "
            f"Train Acc: {train_accuracy:.2f}%, "
            f"Validation Acc: {validation_accuracy:.2f}%")
        
        scheduler.step()  # Step the learning rate scheduler

    # Plot loss and accuracy
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Train Loss')
    plt.plot(validation_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(train_accuracies, label='Train Accuracy')
    plt.plot(validation_accuracies, label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.legend() 

    plt.show()

    return model

def test_model(model, test_dataset, batch_size, device):
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)
    
    model.eval()
    correct_test = 0
    total_test = 0
    test_loss = 0
    criterion = nn.CrossEntropyLoss()

    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            _, predicted = torch.max(outputs.data, 1)
            total_test += labels.size(0)
            correct_test += (predicted == labels).sum().item()
            test_loss += loss.item()

    test_accuracy = 100 * correct_test / total_test
    test_loss /= len(test_loader)

    print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_accuracy:.2f}%")

    original_classes = test_loader.dataset.classes

    # confusion matrix
    with torch.no_grad():
        all_predictions = []
        all_labels = []

        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)

            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            
    auc_score = roc_auc_score(all_labels, all_predictions)
    conf_matrix = confusion_matrix(all_labels, all_predictions)
    
    # Precision、Recall、F1 Score
    classification_rep = classification_report(all_labels, all_predictions, target_names=original_classes)
    print("AUC:")
    print(auc_score)
    print("Confusion Matrix:")
    print(conf_matrix)
    print("Classification Report:")
    print(classification_rep)

# def test_model(model, test_loader, device):
#     model.eval()
#     all_predictions = []
#     all_labels = []
#     criterion = nn.CrossEntropyLoss()

#     with torch.no_grad():
#         correct_test = 0
#         total_test = 0
#         test_loss = 0
        
#         for images, labels in test_loader:
#             images = images.to(device)
#             labels = labels.to(device)

#             outputs = model(images)
#             loss = criterion(outputs, labels)

#             _, predicted = torch.max(outputs.data, 1)
#             total_test += labels.size(0)
#             correct_test += (predicted == labels).sum().item()
#             test_loss += loss.item()

#             probs = nn.Softmax(dim=1)(outputs)  # 将模型输出转换为概率
#             all_predictions.extend(probs[:, 0].cpu().numpy())  # 使用负类别（NFF）的概率作为预测分数
#             all_labels.extend(labels.cpu().numpy())

#         auc_score = roc_auc_score(all_labels, all_predictions)

#         print("AUC Score:", auc_score)

#         test_accuracy = 100 * correct_test / total_test
#         test_loss /= len(test_loader)

#         print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_accuracy:.2f}%")

#         original_classes = test_loader.dataset.classes

#         # confusion matrix
#         conf_matrix = confusion_matrix(all_labels, all_predictions)

#         # Precision、Recall、F1 Score
#         classification_rep = classification_report(all_labels, all_predictions, target_names=original_classes)

#         print("Confusion Matrix:")
#         print(conf_matrix)
#         print("Classification Report:")
#         print(classification_rep)

# %%
# device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# create train val and test folder
dataset_root = '/local/data1/honzh073/data/hospital_43'
target_root = '/local/data1/honzh073/data/hospital_43_data'

split_by_patient(dataset_root, target_root, train_ratio=0.6, val_ratio=0.3)

# create dataset
train_root = '/local/data1/honzh073/data/hospital_43_data/train'
val_root = '/local/data1/honzh073/data/hospital_43_data/val'
test_root='/local/data1/honzh073/data/hospital_43_data/test'


train_dataset, validation_dataset, test_dataset = create_dataset(train_root, val_root, test_root)
repeated_dataset = torch.utils.data.ConcatDataset([train_dataset] * 10)

# show image
show_image(train_dataset, 10)

# load data
batch_size = 64
train_loader = DataLoader(repeated_dataset, batch_size=batch_size, shuffle=True, pin_memory=True)
validation_loader = DataLoader(validation_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)

# classweight
classweight = get_classweight(train_dataset)
print(classweight)
# Out:
# Target dataset folder already exists.
# [0.7095238095238096, 1.6931818181818181]

# %%
# resnet50
resnet50 = train_model(train_loader, validation_loader,
                       classweight=classweight,
                       num_epochs=50, 
                       lr=0.0001, step_size=10, gamma=0.1, 
                       model_name='resnet50',
                       device = device)
# Out:
# Epoch 1/50, Train Loss: 0.6659, Validation Loss: 0.6677, Train Acc: 56.78%, Validation Acc: 66.67%
# Epoch 2/50, Train Loss: 0.6782, Validation Loss: 0.6685, Train Acc: 59.46%, Validation Acc: 69.70%
# Epoch 3/50, Train Loss: 0.2914, Validation Loss: 0.4558, Train Acc: 69.13%, Validation Acc: 60.61%
# Epoch 4/50, Train Loss: 0.2909, Validation Loss: 0.4455, Train Acc: 73.49%, Validation Acc: 71.21%
# Epoch 5/50, Train Loss: 0.1311, Validation Loss: 0.3802, Train Acc: 76.64%, Validation Acc: 69.70%
# Epoch 6/50, Train Loss: 0.4970, Validation Loss: 0.6348, Train Acc: 79.73%, Validation Acc: 75.76%
# Epoch 7/50, Train Loss: 0.2347, Validation Loss: 0.5099, Train Acc: 81.74%, Validation Acc: 81.82%
# Epoch 8/50, Train Loss: 0.2682, Validation Loss: 0.5295, Train Acc: 84.56%, Validation Acc: 81.82%
# Epoch 9/50, Train Loss: 0.1887, Validation Loss: 0.3872, Train Acc: 85.37%, Validation Acc: 78.79%
# Epoch 10/50, Train Loss: 0.3198, Validation Loss: 0.4374, Train Acc: 88.32%, Validation Acc: 78.79%
# Epoch 11/50, Train Loss: 0.5266, Validation Loss: 0.5354, Train Acc: 88.93%, Validation Acc: 75.76%
# Epoch 12/50, Train Loss: 0.6062, Validation Loss: 0.5764, Train Acc: 88.19%, Validation Acc: 78.79%
# Epoch 13/50, Train Loss: 0.5848, Validation Loss: 0.5645, Train Acc: 87.92%, Validation Acc: 75.76%
# Epoch 14/50, Train Loss: 0.6505, Validation Loss: 0.5977, Train Acc: 88.19%, Validation Acc: 83.33%
# Epoch 15/50, Train Loss: 0.6750, Validation Loss: 0.6035, Train Acc: 89.26%, Validation Acc: 78.79%
# Epoch 16/50, Train Loss: 0.6940, Validation Loss: 0.6297, Train Acc: 86.78%, Validation Acc: 75.76%
# Epoch 17/50, Train Loss: 0.9638, Validation Loss: 0.7514, Train Acc: 88.72%, Validation Acc: 80.30%
# Epoch 18/50, Train Loss: 0.7385, Validation Loss: 0.6561, Train Acc: 88.99%, Validation Acc: 81.82%
# Epoch 19/50, Train Loss: 0.7354, Validation Loss: 0.6386, Train Acc: 89.53%, Validation Acc: 81.82%
# Epoch 20/50, Train Loss: 1.1038, Validation Loss: 0.8223, Train Acc: 88.12%, Validation Acc: 83.33%
# Epoch 21/50, Train Loss: 0.9371, Validation Loss: 0.7441, Train Acc: 89.40%, Validation Acc: 81.82%
# Epoch 22/50, Train Loss: 0.9442, Validation Loss: 0.7502, Train Acc: 89.26%, Validation Acc: 83.33%
# Epoch 23/50, Train Loss: 1.2269, Validation Loss: 0.8832, Train Acc: 89.33%, Validation Acc: 83.33%
# Epoch 24/50, Train Loss: 0.9179, Validation Loss: 0.7414, Train Acc: 90.07%, Validation Acc: 80.30%
# Epoch 25/50, Train Loss: 1.1849, Validation Loss: 0.8722, Train Acc: 91.54%, Validation Acc: 83.33%
# Epoch 26/50, Train Loss: 0.8503, Validation Loss: 0.6946, Train Acc: 89.87%, Validation Acc: 78.79%
# Epoch 27/50, Train Loss: 0.8719, Validation Loss: 0.7137, Train Acc: 88.46%, Validation Acc: 78.79%
# Epoch 28/50, Train Loss: 0.9872, Validation Loss: 0.7741, Train Acc: 88.39%, Validation Acc: 83.33%
# Epoch 29/50, Train Loss: 1.1693, Validation Loss: 0.8731, Train Acc: 91.01%, Validation Acc: 81.82%
# Epoch 30/50, Train Loss: 1.1062, Validation Loss: 0.8329, Train Acc: 90.81%, Validation Acc: 81.82%
# Epoch 31/50, Train Loss: 0.9450, Validation Loss: 0.7513, Train Acc: 88.93%, Validation Acc: 80.30%
# Epoch 32/50, Train Loss: 0.8585, Validation Loss: 0.7055, Train Acc: 89.60%, Validation Acc: 81.82%
# Epoch 33/50, Train Loss: 1.1397, Validation Loss: 0.8548, Train Acc: 89.60%, Validation Acc: 81.82%
# Epoch 34/50, Train Loss: 1.0188, Validation Loss: 0.7947, Train Acc: 89.73%, Validation Acc: 81.82%
# Epoch 35/50, Train Loss: 1.3099, Validation Loss: 0.9392, Train Acc: 89.80%, Validation Acc: 80.30%
# Epoch 36/50, Train Loss: 0.9557, Validation Loss: 0.7470, Train Acc: 90.54%, Validation Acc: 80.30%
# Epoch 37/50, Train Loss: 1.2127, Validation Loss: 0.8828, Train Acc: 89.06%, Validation Acc: 83.33%
# Epoch 38/50, Train Loss: 0.7597, Validation Loss: 0.6688, Train Acc: 89.80%, Validation Acc: 80.30%
# Epoch 39/50, Train Loss: 0.9612, Validation Loss: 0.7567, Train Acc: 91.01%, Validation Acc: 83.33%
# Epoch 40/50, Train Loss: 1.1604, Validation Loss: 0.8565, Train Acc: 90.94%, Validation Acc: 83.33%
# Epoch 41/50, Train Loss: 0.9967, Validation Loss: 0.7791, Train Acc: 90.60%, Validation Acc: 83.33%
# Epoch 42/50, Train Loss: 0.7163, Validation Loss: 0.6380, Train Acc: 89.80%, Validation Acc: 83.33%
# Epoch 43/50, Train Loss: 1.0216, Validation Loss: 0.7727, Train Acc: 91.68%, Validation Acc: 81.82%
# Epoch 44/50, Train Loss: 1.2148, Validation Loss: 0.9078, Train Acc: 89.40%, Validation Acc: 81.82%
# Epoch 45/50, Train Loss: 0.7779, Validation Loss: 0.6685, Train Acc: 90.27%, Validation Acc: 80.30%
# Epoch 46/50, Train Loss: 1.1419, Validation Loss: 0.8483, Train Acc: 87.99%, Validation Acc: 81.82%
# Epoch 47/50, Train Loss: 0.9363, Validation Loss: 0.7419, Train Acc: 88.32%, Validation Acc: 81.82%
# Epoch 48/50, Train Loss: 0.8469, Validation Loss: 0.6964, Train Acc: 90.07%, Validation Acc: 78.79%
# Epoch 49/50, Train Loss: 0.9959, Validation Loss: 0.7744, Train Acc: 89.40%, Validation Acc: 81.82%
# Epoch 50/50, Train Loss: 1.1179, Validation Loss: 0.8491, Train Acc: 89.40%, Validation Acc: 83.33%

# %%
test_model(model=resnet50, test_dataset=test_dataset, batch_size=batch_size, device=device)
# Out:
# Test Loss: 0.5215, Test Acc: 86.67%
# AUC:
# 0.8552036199095022
# Confusion Matrix:
# [[16  1]
#  [ 3 10]]
# Classification Report:
#               precision    recall  f1-score   support
#
#        0_NFF       0.84      0.94      0.89        17
#        1_AFF       0.91      0.77      0.83        13
#
#     accuracy                           0.87        30
#    macro avg       0.88      0.86      0.86        30
# weighted avg       0.87      0.87      0.86        30
#
# ['0_NFF', '1_AFF']

# %%
# resnet101
resnet101 = train_model(train_loader, validation_loader, classweight, 
                        num_epochs=50,
                        lr=0.0001, step_size=10, gamma=0.1, 
                        model_name='resnet101', 
                        device=device)
# Out:
# Epoch 1/50, Train Loss: 0.6782, Validation Loss: 0.6708, Train Acc: 52.48%, Validation Acc: 75.76%
# Epoch 2/50, Train Loss: 0.4338, Validation Loss: 0.5279, Train Acc: 64.03%, Validation Acc: 65.15%
# Epoch 3/50, Train Loss: 0.1584, Validation Loss: 0.3892, Train Acc: 64.90%, Validation Acc: 60.61%
# Epoch 4/50, Train Loss: 0.0124, Validation Loss: 0.3630, Train Acc: 75.64%, Validation Acc: 69.70%
# Epoch 5/50, Train Loss: 0.1434, Validation Loss: 0.3381, Train Acc: 78.72%, Validation Acc: 83.33%
# Epoch 6/50, Train Loss: 0.1441, Validation Loss: 0.4726, Train Acc: 82.35%, Validation Acc: 62.12%
# Epoch 7/50, Train Loss: 0.0150, Validation Loss: 0.3970, Train Acc: 80.81%, Validation Acc: 84.85%
# Epoch 8/50, Train Loss: 0.0023, Validation Loss: 0.3650, Train Acc: 84.83%, Validation Acc: 80.30%
# Epoch 9/50, Train Loss: 0.0114, Validation Loss: 0.5286, Train Acc: 87.85%, Validation Acc: 78.79%
# Epoch 10/50, Train Loss: 0.0038, Validation Loss: 0.4396, Train Acc: 85.57%, Validation Acc: 84.85%
# Epoch 11/50, Train Loss: 0.0018, Validation Loss: 0.4185, Train Acc: 88.59%, Validation Acc: 84.85%
# Epoch 12/50, Train Loss: 0.0024, Validation Loss: 0.3813, Train Acc: 88.46%, Validation Acc: 84.85%
# Epoch 13/50, Train Loss: 0.0016, Validation Loss: 0.2966, Train Acc: 89.73%, Validation Acc: 83.33%
# Epoch 14/50, Train Loss: 0.0013, Validation Loss: 0.3143, Train Acc: 89.66%, Validation Acc: 80.30%
# Epoch 15/50, Train Loss: 0.0012, Validation Loss: 0.3647, Train Acc: 89.06%, Validation Acc: 80.30%
# Epoch 16/50, Train Loss: 0.0018, Validation Loss: 0.3743, Train Acc: 89.73%, Validation Acc: 81.82%
# Epoch 17/50, Train Loss: 0.0009, Validation Loss: 0.3770, Train Acc: 90.00%, Validation Acc: 81.82%
# Epoch 18/50, Train Loss: 0.0008, Validation Loss: 0.3908, Train Acc: 91.34%, Validation Acc: 81.82%
# Epoch 19/50, Train Loss: 0.0006, Validation Loss: 0.3704, Train Acc: 91.01%, Validation Acc: 81.82%
# Epoch 20/50, Train Loss: 0.0008, Validation Loss: 0.3958, Train Acc: 91.88%, Validation Acc: 81.82%
# Epoch 21/50, Train Loss: 0.0007, Validation Loss: 0.3671, Train Acc: 91.21%, Validation Acc: 81.82%
# Epoch 22/50, Train Loss: 0.0006, Validation Loss: 0.3531, Train Acc: 91.81%, Validation Acc: 81.82%
# Epoch 23/50, Train Loss: 0.0007, Validation Loss: 0.3819, Train Acc: 91.14%, Validation Acc: 81.82%
# Epoch 24/50, Train Loss: 0.0004, Validation Loss: 0.3678, Train Acc: 90.54%, Validation Acc: 80.30%
# Epoch 25/50, Train Loss: 0.0005, Validation Loss: 0.3848, Train Acc: 91.07%, Validation Acc: 81.82%
# Epoch 26/50, Train Loss: 0.0006, Validation Loss: 0.3666, Train Acc: 91.01%, Validation Acc: 80.30%
# Epoch 27/50, Train Loss: 0.0007, Validation Loss: 0.4087, Train Acc: 89.46%, Validation Acc: 81.82%
# Epoch 28/50, Train Loss: 0.0005, Validation Loss: 0.3643, Train Acc: 91.14%, Validation Acc: 80.30%
# Epoch 29/50, Train Loss: 0.0006, Validation Loss: 0.3628, Train Acc: 91.61%, Validation Acc: 81.82%
# Epoch 30/50, Train Loss: 0.0007, Validation Loss: 0.3792, Train Acc: 91.41%, Validation Acc: 78.79%
# Epoch 31/50, Train Loss: 0.0006, Validation Loss: 0.3605, Train Acc: 91.88%, Validation Acc: 80.30%
# Epoch 32/50, Train Loss: 0.0004, Validation Loss: 0.3688, Train Acc: 91.48%, Validation Acc: 78.79%
# Epoch 33/50, Train Loss: 0.0009, Validation Loss: 0.3400, Train Acc: 91.61%, Validation Acc: 81.82%
# Epoch 34/50, Train Loss: 0.0009, Validation Loss: 0.3511, Train Acc: 92.28%, Validation Acc: 81.82%
# Epoch 35/50, Train Loss: 0.0006, Validation Loss: 0.3961, Train Acc: 91.14%, Validation Acc: 80.30%
# Epoch 36/50, Train Loss: 0.0006, Validation Loss: 0.3909, Train Acc: 91.14%, Validation Acc: 81.82%
# Epoch 37/50, Train Loss: 0.0006, Validation Loss: 0.3848, Train Acc: 92.08%, Validation Acc: 81.82%
# Epoch 38/50, Train Loss: 0.0009, Validation Loss: 0.3475, Train Acc: 91.14%, Validation Acc: 83.33%
# Epoch 39/50, Train Loss: 0.0011, Validation Loss: 0.3952, Train Acc: 92.21%, Validation Acc: 81.82%
# Epoch 40/50, Train Loss: 0.0007, Validation Loss: 0.3579, Train Acc: 91.68%, Validation Acc: 78.79%
# Epoch 41/50, Train Loss: 0.0008, Validation Loss: 0.3759, Train Acc: 90.81%, Validation Acc: 81.82%
# Epoch 42/50, Train Loss: 0.0007, Validation Loss: 0.3962, Train Acc: 92.15%, Validation Acc: 81.82%
# Epoch 43/50, Train Loss: 0.0007, Validation Loss: 0.3684, Train Acc: 91.74%, Validation Acc: 80.30%
# Epoch 44/50, Train Loss: 0.0006, Validation Loss: 0.3773, Train Acc: 92.21%, Validation Acc: 81.82%
# Epoch 45/50, Train Loss: 0.0005, Validation Loss: 0.3741, Train Acc: 89.66%, Validation Acc: 80.30%
# Epoch 46/50, Train Loss: 0.0007, Validation Loss: 0.3888, Train Acc: 90.07%, Validation Acc: 81.82%
# Epoch 47/50, Train Loss: 0.0006, Validation Loss: 0.3747, Train Acc: 90.40%, Validation Acc: 80.30%
# Epoch 48/50, Train Loss: 0.0006, Validation Loss: 0.3686, Train Acc: 91.68%, Validation Acc: 81.82%
# Epoch 49/50, Train Loss: 0.0010, Validation Loss: 0.3626, Train Acc: 91.28%, Validation Acc: 81.82%
# Epoch 50/50, Train Loss: 0.0008, Validation Loss: 0.3542, Train Acc: 91.74%, Validation Acc: 81.82%

# %%
test_model(model=resnet101, test_dataset=test_dataset, batch_size=batch_size, device=device)
# Out:
# Test Loss: 0.3464, Test Acc: 93.33%
# AUC:
# 0.9230769230769231
# Confusion Matrix:
# [[17  0]
#  [ 2 11]]
# Classification Report:
#               precision    recall  f1-score   support
#
#        0_NFF       0.89      1.00      0.94        17
#        1_AFF       1.00      0.85      0.92        13
#
#     accuracy                           0.93        30
#    macro avg       0.95      0.92      0.93        30
# weighted avg       0.94      0.93      0.93        30

# %%
# resnet152
resnet152 = train_model(train_loader, validation_loader, classweight,
                        num_epochs=50, 
                        lr=0.0001, step_size=10, gamma=0.1, 
                        model_name='resnet152', 
                        device=device)
# Out:
# Epoch 1/50, Train Loss: 0.6428, Validation Loss: 0.6424, Train Acc: 56.51%, Validation Acc: 66.67%
# Epoch 2/50, Train Loss: 0.3295, Validation Loss: 0.4695, Train Acc: 67.11%, Validation Acc: 74.24%
# Epoch 3/50, Train Loss: 0.4627, Validation Loss: 0.5174, Train Acc: 74.09%, Validation Acc: 77.27%
# Epoch 4/50, Train Loss: 1.7472, Validation Loss: 1.2744, Train Acc: 78.19%, Validation Acc: 80.30%
# Epoch 5/50, Train Loss: 0.0927, Validation Loss: 0.4230, Train Acc: 81.34%, Validation Acc: 81.82%
# Epoch 6/50, Train Loss: 0.3525, Validation Loss: 0.5594, Train Acc: 85.70%, Validation Acc: 81.82%
# Epoch 7/50, Train Loss: 0.0130, Validation Loss: 0.3054, Train Acc: 83.76%, Validation Acc: 83.33%
# Epoch 8/50, Train Loss: 0.1614, Validation Loss: 0.6381, Train Acc: 85.70%, Validation Acc: 81.82%
# Epoch 9/50, Train Loss: 0.0231, Validation Loss: 0.4028, Train Acc: 87.05%, Validation Acc: 83.33%
# Epoch 10/50, Train Loss: 0.0362, Validation Loss: 0.4259, Train Acc: 90.47%, Validation Acc: 81.82%
# Epoch 11/50, Train Loss: 0.0388, Validation Loss: 0.4044, Train Acc: 90.27%, Validation Acc: 86.36%
# Epoch 12/50, Train Loss: 0.0222, Validation Loss: 0.4091, Train Acc: 89.87%, Validation Acc: 84.85%
# Epoch 13/50, Train Loss: 0.0072, Validation Loss: 0.4139, Train Acc: 90.94%, Validation Acc: 83.33%
# Epoch 14/50, Train Loss: 0.0072, Validation Loss: 0.4085, Train Acc: 91.48%, Validation Acc: 81.82%
# Epoch 15/50, Train Loss: 0.0106, Validation Loss: 0.4069, Train Acc: 91.34%, Validation Acc: 84.85%
# Epoch 16/50, Train Loss: 0.0107, Validation Loss: 0.3955, Train Acc: 91.48%, Validation Acc: 83.33%
# Epoch 17/50, Train Loss: 0.0220, Validation Loss: 0.3894, Train Acc: 93.76%, Validation Acc: 83.33%
# Epoch 18/50, Train Loss: 0.0344, Validation Loss: 0.4055, Train Acc: 92.42%, Validation Acc: 83.33%
# Epoch 19/50, Train Loss: 0.0663, Validation Loss: 0.4189, Train Acc: 92.21%, Validation Acc: 81.82%
# Epoch 20/50, Train Loss: 0.0164, Validation Loss: 0.3953, Train Acc: 92.08%, Validation Acc: 83.33%
# Epoch 21/50, Train Loss: 0.0140, Validation Loss: 0.4096, Train Acc: 92.55%, Validation Acc: 81.82%
# Epoch 22/50, Train Loss: 0.0177, Validation Loss: 0.4158, Train Acc: 92.01%, Validation Acc: 81.82%
# Epoch 23/50, Train Loss: 0.0159, Validation Loss: 0.4200, Train Acc: 92.35%, Validation Acc: 83.33%
# Epoch 24/50, Train Loss: 0.0070, Validation Loss: 0.4226, Train Acc: 91.88%, Validation Acc: 81.82%
# Epoch 25/50, Train Loss: 0.0071, Validation Loss: 0.4401, Train Acc: 93.36%, Validation Acc: 81.82%
# Epoch 26/50, Train Loss: 0.0139, Validation Loss: 0.4177, Train Acc: 92.68%, Validation Acc: 81.82%
# Epoch 27/50, Train Loss: 0.0066, Validation Loss: 0.4342, Train Acc: 91.88%, Validation Acc: 84.85%
# Epoch 28/50, Train Loss: 0.0066, Validation Loss: 0.4204, Train Acc: 92.48%, Validation Acc: 83.33%
# Epoch 29/50, Train Loss: 0.0075, Validation Loss: 0.4142, Train Acc: 93.42%, Validation Acc: 81.82%
# Epoch 30/50, Train Loss: 0.0104, Validation Loss: 0.4272, Train Acc: 91.41%, Validation Acc: 83.33%
# Epoch 31/50, Train Loss: 0.0098, Validation Loss: 0.4006, Train Acc: 92.62%, Validation Acc: 81.82%
# Epoch 32/50, Train Loss: 0.0157, Validation Loss: 0.4281, Train Acc: 92.08%, Validation Acc: 83.33%
# Epoch 33/50, Train Loss: 0.0119, Validation Loss: 0.4043, Train Acc: 93.83%, Validation Acc: 81.82%
# Epoch 34/50, Train Loss: 0.0112, Validation Loss: 0.4265, Train Acc: 92.15%, Validation Acc: 84.85%
# Epoch 35/50, Train Loss: 0.0089, Validation Loss: 0.4258, Train Acc: 92.21%, Validation Acc: 83.33%
# Epoch 36/50, Train Loss: 0.0182, Validation Loss: 0.4180, Train Acc: 92.75%, Validation Acc: 84.85%
# Epoch 37/50, Train Loss: 0.0133, Validation Loss: 0.4272, Train Acc: 91.68%, Validation Acc: 83.33%
# Epoch 38/50, Train Loss: 0.0184, Validation Loss: 0.4247, Train Acc: 92.42%, Validation Acc: 83.33%
# Epoch 39/50, Train Loss: 0.0103, Validation Loss: 0.4102, Train Acc: 92.68%, Validation Acc: 83.33%
# Epoch 40/50, Train Loss: 0.0253, Validation Loss: 0.4178, Train Acc: 93.29%, Validation Acc: 81.82%
# Epoch 41/50, Train Loss: 0.0082, Validation Loss: 0.4209, Train Acc: 92.68%, Validation Acc: 83.33%
# Epoch 42/50, Train Loss: 0.0101, Validation Loss: 0.4132, Train Acc: 93.15%, Validation Acc: 83.33%
# Epoch 43/50, Train Loss: 0.0123, Validation Loss: 0.4170, Train Acc: 91.95%, Validation Acc: 83.33%
# Epoch 44/50, Train Loss: 0.0077, Validation Loss: 0.4179, Train Acc: 91.68%, Validation Acc: 83.33%
# Epoch 45/50, Train Loss: 0.0115, Validation Loss: 0.4173, Train Acc: 91.21%, Validation Acc: 84.85%
# Epoch 46/50, Train Loss: 0.0226, Validation Loss: 0.4101, Train Acc: 92.42%, Validation Acc: 83.33%
# Epoch 47/50, Train Loss: 0.0100, Validation Loss: 0.4218, Train Acc: 92.82%, Validation Acc: 81.82%
# Epoch 48/50, Train Loss: 0.0101, Validation Loss: 0.4126, Train Acc: 91.88%, Validation Acc: 81.82%
# Epoch 49/50, Train Loss: 0.0195, Validation Loss: 0.4194, Train Acc: 93.42%, Validation Acc: 83.33%
# Epoch 50/50, Train Loss: 0.0064, Validation Loss: 0.4163, Train Acc: 94.09%, Validation Acc: 83.33%

# %%
test_model(model=resnet152, test_dataset=test_dataset, batch_size=batch_size, device=device)
# Out:
# Test Loss: 0.5042, Test Acc: 86.67%
# AUC:
# 0.8642533936651584
# Confusion Matrix:
# [[15  2]
#  [ 2 11]]
# Classification Report:
#               precision    recall  f1-score   support
#
#        0_NFF       0.88      0.88      0.88        17
#        1_AFF       0.85      0.85      0.85        13
#
#     accuracy                           0.87        30
#    macro avg       0.86      0.86      0.86        30
# weighted avg       0.87      0.87      0.87        30

# %%
# densenet161
densenet161 = train_model(train_loader, validation_loader, classweight,
                          num_epochs=100, 
                          lr=0.0001, step_size=5, gamma=0.1, 
                          model_name='densenet161', 
                          device=device)
# Out:
# Epoch 1/100, Train Loss: 0.6100, Validation Loss: 0.6532, Train Acc: 55.10%, Validation Acc: 53.03%
# Epoch 2/100, Train Loss: 0.1578, Validation Loss: 0.3801, Train Acc: 66.51%, Validation Acc: 80.30%
# Epoch 3/100, Train Loss: 0.1100, Validation Loss: 0.3722, Train Acc: 74.90%, Validation Acc: 81.82%
# Epoch 4/100, Train Loss: 0.0303, Validation Loss: 0.3708, Train Acc: 80.54%, Validation Acc: 81.82%
# Epoch 5/100, Train Loss: 0.0466, Validation Loss: 0.4191, Train Acc: 80.20%, Validation Acc: 77.27%
# Epoch 6/100, Train Loss: 0.0183, Validation Loss: 0.3684, Train Acc: 84.16%, Validation Acc: 72.73%
# Epoch 7/100, Train Loss: 0.0181, Validation Loss: 0.3639, Train Acc: 86.11%, Validation Acc: 75.76%
# Epoch 8/100, Train Loss: 0.0274, Validation Loss: 0.3489, Train Acc: 87.25%, Validation Acc: 78.79%
# Epoch 9/100, Train Loss: 0.0320, Validation Loss: 0.3532, Train Acc: 87.72%, Validation Acc: 78.79%
# Epoch 10/100, Train Loss: 0.0193, Validation Loss: 0.3393, Train Acc: 87.72%, Validation Acc: 78.79%
# Epoch 11/100, Train Loss: 0.0205, Validation Loss: 0.3394, Train Acc: 88.93%, Validation Acc: 77.27%
# Epoch 12/100, Train Loss: 0.0182, Validation Loss: 0.3409, Train Acc: 89.19%, Validation Acc: 75.76%
# Epoch 13/100, Train Loss: 0.0294, Validation Loss: 0.3407, Train Acc: 89.53%, Validation Acc: 80.30%
# Epoch 14/100, Train Loss: 0.0183, Validation Loss: 0.3347, Train Acc: 87.65%, Validation Acc: 75.76%
# Epoch 15/100, Train Loss: 0.0249, Validation Loss: 0.3406, Train Acc: 90.00%, Validation Acc: 77.27%
# Epoch 16/100, Train Loss: 0.0176, Validation Loss: 0.3501, Train Acc: 89.60%, Validation Acc: 77.27%
# Epoch 17/100, Train Loss: 0.0213, Validation Loss: 0.3438, Train Acc: 87.45%, Validation Acc: 78.79%
# Epoch 18/100, Train Loss: 0.0227, Validation Loss: 0.3385, Train Acc: 88.12%, Validation Acc: 77.27%
# Epoch 19/100, Train Loss: 0.0140, Validation Loss: 0.3455, Train Acc: 89.66%, Validation Acc: 77.27%
# Epoch 20/100, Train Loss: 0.0254, Validation Loss: 0.3338, Train Acc: 90.20%, Validation Acc: 77.27%
# Epoch 21/100, Train Loss: 0.0186, Validation Loss: 0.3356, Train Acc: 87.38%, Validation Acc: 75.76%
# Epoch 22/100, Train Loss: 0.0180, Validation Loss: 0.3354, Train Acc: 89.93%, Validation Acc: 77.27%
# Epoch 23/100, Train Loss: 0.0245, Validation Loss: 0.3372, Train Acc: 90.54%, Validation Acc: 78.79%
# Epoch 24/100, Train Loss: 0.0185, Validation Loss: 0.3502, Train Acc: 90.00%, Validation Acc: 77.27%
# Epoch 25/100, Train Loss: 0.0172, Validation Loss: 0.3384, Train Acc: 87.72%, Validation Acc: 75.76%
# Epoch 26/100, Train Loss: 0.0118, Validation Loss: 0.3417, Train Acc: 89.33%, Validation Acc: 75.76%
# Epoch 27/100, Train Loss: 0.0173, Validation Loss: 0.3455, Train Acc: 88.32%, Validation Acc: 77.27%
# Epoch 28/100, Train Loss: 0.0145, Validation Loss: 0.3387, Train Acc: 89.13%, Validation Acc: 75.76%
# Epoch 29/100, Train Loss: 0.0129, Validation Loss: 0.3427, Train Acc: 88.59%, Validation Acc: 75.76%
# Epoch 30/100, Train Loss: 0.0178, Validation Loss: 0.3439, Train Acc: 89.06%, Validation Acc: 75.76%
# Epoch 31/100, Train Loss: 0.0193, Validation Loss: 0.3412, Train Acc: 89.33%, Validation Acc: 77.27%
# Epoch 32/100, Train Loss: 0.0240, Validation Loss: 0.3469, Train Acc: 88.46%, Validation Acc: 78.79%
# Epoch 33/100, Train Loss: 0.0258, Validation Loss: 0.3378, Train Acc: 88.93%, Validation Acc: 78.79%
# Epoch 34/100, Train Loss: 0.0237, Validation Loss: 0.3410, Train Acc: 90.20%, Validation Acc: 78.79%
# Epoch 35/100, Train Loss: 0.0174, Validation Loss: 0.3395, Train Acc: 88.66%, Validation Acc: 75.76%
# Epoch 36/100, Train Loss: 0.0219, Validation Loss: 0.3487, Train Acc: 90.13%, Validation Acc: 77.27%
# Epoch 37/100, Train Loss: 0.0258, Validation Loss: 0.3481, Train Acc: 90.67%, Validation Acc: 78.79%
# Epoch 38/100, Train Loss: 0.0242, Validation Loss: 0.3409, Train Acc: 88.39%, Validation Acc: 78.79%
# Epoch 39/100, Train Loss: 0.0231, Validation Loss: 0.3470, Train Acc: 89.73%, Validation Acc: 78.79%
# Epoch 40/100, Train Loss: 0.0148, Validation Loss: 0.3409, Train Acc: 88.66%, Validation Acc: 75.76%
# Epoch 41/100, Train Loss: 0.0216, Validation Loss: 0.3402, Train Acc: 89.13%, Validation Acc: 77.27%
# Epoch 42/100, Train Loss: 0.0179, Validation Loss: 0.3416, Train Acc: 88.86%, Validation Acc: 77.27%
# Epoch 43/100, Train Loss: 0.0165, Validation Loss: 0.3305, Train Acc: 89.60%, Validation Acc: 77.27%
# Epoch 44/100, Train Loss: 0.0216, Validation Loss: 0.3409, Train Acc: 88.93%, Validation Acc: 77.27%
# Epoch 45/100, Train Loss: 0.0183, Validation Loss: 0.3388, Train Acc: 87.99%, Validation Acc: 77.27%
# Epoch 46/100, Train Loss: 0.0165, Validation Loss: 0.3414, Train Acc: 88.12%, Validation Acc: 77.27%
# Epoch 47/100, Train Loss: 0.0192, Validation Loss: 0.3379, Train Acc: 90.47%, Validation Acc: 75.76%
# Epoch 48/100, Train Loss: 0.0198, Validation Loss: 0.3385, Train Acc: 89.80%, Validation Acc: 78.79%
# Epoch 49/100, Train Loss: 0.0203, Validation Loss: 0.3433, Train Acc: 89.13%, Validation Acc: 77.27%
# Epoch 50/100, Train Loss: 0.0207, Validation Loss: 0.3308, Train Acc: 87.52%, Validation Acc: 75.76%
# Epoch 51/100, Train Loss: 0.0231, Validation Loss: 0.3392, Train Acc: 88.86%, Validation Acc: 78.79%
# Epoch 52/100, Train Loss: 0.0156, Validation Loss: 0.3412, Train Acc: 88.39%, Validation Acc: 75.76%
# Epoch 53/100, Train Loss: 0.0199, Validation Loss: 0.3408, Train Acc: 89.53%, Validation Acc: 77.27%
# Epoch 54/100, Train Loss: 0.0174, Validation Loss: 0.3385, Train Acc: 87.52%, Validation Acc: 77.27%
# Epoch 55/100, Train Loss: 0.0171, Validation Loss: 0.3426, Train Acc: 89.93%, Validation Acc: 75.76%
# Epoch 56/100, Train Loss: 0.0153, Validation Loss: 0.3434, Train Acc: 89.53%, Validation Acc: 77.27%
# Epoch 57/100, Train Loss: 0.0243, Validation Loss: 0.3471, Train Acc: 90.94%, Validation Acc: 78.79%
# Epoch 58/100, Train Loss: 0.0143, Validation Loss: 0.3423, Train Acc: 88.66%, Validation Acc: 77.27%
# Epoch 59/100, Train Loss: 0.0204, Validation Loss: 0.3414, Train Acc: 89.13%, Validation Acc: 78.79%
# Epoch 60/100, Train Loss: 0.0236, Validation Loss: 0.3387, Train Acc: 89.73%, Validation Acc: 77.27%
# Epoch 61/100, Train Loss: 0.0180, Validation Loss: 0.3358, Train Acc: 88.32%, Validation Acc: 77.27%
# Epoch 62/100, Train Loss: 0.0308, Validation Loss: 0.3399, Train Acc: 89.73%, Validation Acc: 78.79%
# Epoch 63/100, Train Loss: 0.0181, Validation Loss: 0.3427, Train Acc: 88.52%, Validation Acc: 78.79%
# Epoch 64/100, Train Loss: 0.0242, Validation Loss: 0.3378, Train Acc: 89.53%, Validation Acc: 78.79%
# Epoch 65/100, Train Loss: 0.0227, Validation Loss: 0.3331, Train Acc: 90.81%, Validation Acc: 77.27%
# Epoch 66/100, Train Loss: 0.0209, Validation Loss: 0.3351, Train Acc: 90.07%, Validation Acc: 77.27%
# Epoch 67/100, Train Loss: 0.0206, Validation Loss: 0.3410, Train Acc: 89.93%, Validation Acc: 77.27%
# Epoch 68/100, Train Loss: 0.0231, Validation Loss: 0.3404, Train Acc: 90.13%, Validation Acc: 78.79%
# Epoch 69/100, Train Loss: 0.0271, Validation Loss: 0.3451, Train Acc: 89.73%, Validation Acc: 77.27%
# Epoch 70/100, Train Loss: 0.0240, Validation Loss: 0.3412, Train Acc: 89.46%, Validation Acc: 78.79%
# Epoch 71/100, Train Loss: 0.0217, Validation Loss: 0.3449, Train Acc: 89.66%, Validation Acc: 78.79%
# Epoch 72/100, Train Loss: 0.0247, Validation Loss: 0.3325, Train Acc: 87.72%, Validation Acc: 77.27%
# Epoch 73/100, Train Loss: 0.0183, Validation Loss: 0.3377, Train Acc: 89.33%, Validation Acc: 77.27%
# Epoch 74/100, Train Loss: 0.0271, Validation Loss: 0.3473, Train Acc: 88.99%, Validation Acc: 78.79%
# Epoch 75/100, Train Loss: 0.0214, Validation Loss: 0.3324, Train Acc: 88.86%, Validation Acc: 75.76%
# Epoch 76/100, Train Loss: 0.0138, Validation Loss: 0.3435, Train Acc: 89.33%, Validation Acc: 77.27%
# Epoch 77/100, Train Loss: 0.0193, Validation Loss: 0.3417, Train Acc: 89.40%, Validation Acc: 78.79%
# Epoch 78/100, Train Loss: 0.0179, Validation Loss: 0.3388, Train Acc: 88.79%, Validation Acc: 77.27%
# Epoch 79/100, Train Loss: 0.0193, Validation Loss: 0.3429, Train Acc: 90.20%, Validation Acc: 77.27%
# Epoch 80/100, Train Loss: 0.0243, Validation Loss: 0.3441, Train Acc: 91.14%, Validation Acc: 78.79%
# Epoch 81/100, Train Loss: 0.0191, Validation Loss: 0.3377, Train Acc: 88.52%, Validation Acc: 75.76%
# Epoch 82/100, Train Loss: 0.0239, Validation Loss: 0.3346, Train Acc: 88.72%, Validation Acc: 78.79%
# Epoch 83/100, Train Loss: 0.0231, Validation Loss: 0.3419, Train Acc: 90.94%, Validation Acc: 78.79%
# Epoch 84/100, Train Loss: 0.0234, Validation Loss: 0.3364, Train Acc: 89.80%, Validation Acc: 77.27%
# Epoch 85/100, Train Loss: 0.0181, Validation Loss: 0.3373, Train Acc: 88.86%, Validation Acc: 77.27%
# Epoch 86/100, Train Loss: 0.0253, Validation Loss: 0.3335, Train Acc: 89.87%, Validation Acc: 77.27%
# Epoch 87/100, Train Loss: 0.0239, Validation Loss: 0.3351, Train Acc: 89.46%, Validation Acc: 78.79%
# Epoch 88/100, Train Loss: 0.0192, Validation Loss: 0.3400, Train Acc: 88.32%, Validation Acc: 78.79%
# Epoch 89/100, Train Loss: 0.0168, Validation Loss: 0.3424, Train Acc: 88.79%, Validation Acc: 77.27%
# Epoch 90/100, Train Loss: 0.0157, Validation Loss: 0.3316, Train Acc: 88.86%, Validation Acc: 77.27%
# Epoch 91/100, Train Loss: 0.0172, Validation Loss: 0.3345, Train Acc: 88.99%, Validation Acc: 75.76%
# Epoch 92/100, Train Loss: 0.0184, Validation Loss: 0.3363, Train Acc: 89.53%, Validation Acc: 77.27%
# Epoch 93/100, Train Loss: 0.0214, Validation Loss: 0.3622, Train Acc: 88.52%, Validation Acc: 78.79%
# Epoch 94/100, Train Loss: 0.0147, Validation Loss: 0.3301, Train Acc: 89.80%, Validation Acc: 75.76%
# Epoch 95/100, Train Loss: 0.0156, Validation Loss: 0.3368, Train Acc: 88.26%, Validation Acc: 75.76%
# Epoch 96/100, Train Loss: 0.0179, Validation Loss: 0.3446, Train Acc: 89.93%, Validation Acc: 78.79%
# Epoch 97/100, Train Loss: 0.0178, Validation Loss: 0.3417, Train Acc: 89.33%, Validation Acc: 77.27%
# Epoch 98/100, Train Loss: 0.0238, Validation Loss: 0.3392, Train Acc: 88.72%, Validation Acc: 77.27%
# Epoch 99/100, Train Loss: 0.0202, Validation Loss: 0.3402, Train Acc: 88.46%, Validation Acc: 77.27%
# Epoch 100/100, Train Loss: 0.0251, Validation Loss: 0.3443, Train Acc: 87.25%, Validation Acc: 78.79%

# %%
test_model(model=densenet161, test_dataset=test_dataset, batch_size=batch_size, device=device)
# Out:
# Test Loss: 0.3885, Test Acc: 90.00%
# AUC:
# 0.9027149321266968
# Confusion Matrix:
# [[15  2]
#  [ 1 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#        0_NFF       0.94      0.88      0.91        17
#        1_AFF       0.86      0.92      0.89        13
#
#     accuracy                           0.90        30
#    macro avg       0.90      0.90      0.90        30
# weighted avg       0.90      0.90      0.90        30
