# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import models
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import os
import random
import shutil

def split_by_patient(dataset_root, target_root, train_ratio, val_ratio):
    if not os.path.exists(target_root):
        # create target root if not exit
        os.makedirs(target_root)

        # AFF and NFF folder
        fracture_types = ['AFF', 'NFF']

        for fracture_type in fracture_types:
            source_folder = os.path.join(dataset_root, fracture_type)
            patients = os.listdir(source_folder)
            
            # select random patients
            random.seed(123)
            random.shuffle(patients)
            
            # split patients
            total_patients = len(patients)
            train_end = int(total_patients * train_ratio)
            val_end = train_end + int(total_patients * val_ratio)
            
            train_patients = patients[:train_end]
            val_patients = patients[train_end:val_end]
            test_patients = patients[val_end:]
            
            # copy images to folder
            for patient_id in train_patients:
                source_path = os.path.join(source_folder, patient_id)
                target_path = os.path.join(target_root, 'train', fracture_type, patient_id)
                shutil.copytree(source_path, target_path)
            
            for patient_id in val_patients:
                source_path = os.path.join(source_folder, patient_id)
                target_path = os.path.join(target_root, 'val', fracture_type, patient_id)
                shutil.copytree(source_path, target_path)
            
            for patient_id in test_patients:
                source_path = os.path.join(source_folder, patient_id)
                target_path = os.path.join(target_root, 'test', fracture_type, patient_id)
                shutil.copytree(source_path, target_path)
        print("Dataset split completed.")
    
    else:
        print("Target dataset folder already exists.")

def create_dataset(train_root, val_root, test_root):
    # Define data augmentation transforms
    train_transform = transforms.Compose([
        transforms.RandomHorizontalFlip(p=1),
        transforms.RandomVerticalFlip(p=1),
        transforms.RandomRotation(degrees=(0, 180)),
        transforms.ColorJitter(brightness=0.5, contrast=0.1, saturation=0.1, hue=0.3),
        # transforms.RandomApply([transforms.RandomAffine(degrees=0, translate=(0.1, 0.1))], p=1),
        transforms.GaussianBlur(kernel_size=(5,9), sigma=(0.1, 5)),
        transforms.RandomInvert(),
        transforms.RandomPosterize(bits=2),
        transforms.RandomAdjustSharpness(sharpness_factor=4),
        # transforms.RandomAutocontrast(),
        transforms.RandomApply([transforms.RandomPerspective(distortion_scale=0.2)], p=1),
        transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

    # Define the data loaders
    train_dataset = ImageFolder(root=train_root, transform=train_transform)
    validation_dataset = ImageFolder(root=val_root, transform=test_transform)
    test_dataset = ImageFolder(root=test_root, transform=test_transform)

    return train_dataset, validation_dataset, test_dataset

def show_image(dataset, num_images=5):
    # Get some random indices from the dataset
    random_indices = np.random.choice(len(dataset), num_images, replace=False)

    # Plot images with truncated names
    plt.figure(figsize=(15, 5))
    for i, idx in enumerate(random_indices):
        image, label = dataset[idx]  # Use the dataset directly
        filename = dataset.samples[idx][0]  # Get the filename
        truncated_filename = filename.split('/')[-1][:15]  # Extract the last part and truncate to 15 characters
        plt.subplot(1, num_images, i + 1)
        plt.title(f"Label: {label}")
        plt.imshow(image[0], cmap='gray')  # Assuming single-channel (grayscale) image
        # plt.imshow(image[0])  # Assuming single-channel (grayscale) image
        plt.axis('off')
    plt.show()

def get_classweight(train_dataset):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    # aff and nff numbers in training dataset
    train_aff_count = sum(1 for _, label in train_dataset if label == 0)  # 0 AFF
    train_nff_count = sum(1 for _, label in train_dataset if label == 1)  # 1 NFF

    # Calculate class weights
    n_aff_train = train_aff_count
    n_nff_train = train_nff_count

    class_weight_aff = 1 / (2 * (n_aff_train / (n_aff_train + n_nff_train)))
    class_weight_nff = 1 / (2 * (n_nff_train / (n_aff_train + n_nff_train)))
    
    return [class_weight_aff, class_weight_nff]
    
    
    
def train_model(train_loader, validation_loader, classweight, num_epochs, lr, step_size, gamma, model_name, device):

    # Load pre-trained model
    torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')
    if model_name == 'resnet152':
        from torchvision.models import resnet152, ResNet152_Weights
        model = models.resnet152(weights=ResNet152_Weights.DEFAULT)
        
    elif model_name == 'densenet161':
        from torchvision.models import densenet161, DenseNet161_Weights
        model = models.densenet161(weights=DenseNet161_Weights.DEFAULT)
        
    elif model_name == 'resnet50':
        from torchvision.models import resnet50, ResNet50_Weights
        model = models.resnet50(weights=ResNet50_Weights.DEFAULT)

    elif model_name == 'vgg19':
        from torchvision.models import vgg19, VGG19_Weights
        model = models.vgg19(weights=VGG19_Weights.DEFAULT)

    elif model_name == 'resnet101':
        from torchvision.models import resnet101, ResNet101_Weights
        model = models.resnet101(weights=ResNet101_Weights.DEFAULT)
        
    else:
        raise ValueError("Invalid model type. 'vgg19' 'resnet50' 'resnet101' 'resnet152' or 'densenet161'.")
    
    # Modify the output layer
    num_classes = 2
    if model_name == 'densenet161':
        in_features = model.classifier.in_features
        model.classifier = nn.Linear(in_features, num_classes)
    else:
        in_features = model.fc.in_features
        model.fc = nn.Linear(in_features, num_classes)
    
    # Move model to the specified device
    model = model.to(device)
    
    # Loss function and optimizer
    criterion = nn.CrossEntropyLoss(weight=torch.Tensor(classweight).to(device))
    optimizer = optim.Adam(model.parameters(), lr=lr)
    scheduler = lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)
    
    # Training (loss and accuracy)
    train_losses = []
    validation_losses = []
    train_accuracies = []
    validation_accuracies = []
    
    for epoch in range(num_epochs):
        model.train()
        correct_train = 0
        total_train = 0
        
        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
        
        train_accuracy = 100 * correct_train / total_train
        
        model.eval()
        correct_validation = 0
        total_validation = 0
        validation_loss = 0
        
        with torch.no_grad():
            for images, labels in validation_loader:
                images = images.to(device)
                labels = labels.to(device)
                
                outputs = model(images)
                loss = criterion(outputs, labels)
                
                _, predicted = torch.max(outputs.data, 1)
                total_validation += labels.size(0)
                correct_validation += (predicted == labels).sum().item()
                validation_loss += loss.item()
        
        # validation accuracy and loss
        validation_accuracy = 100 * correct_validation / total_validation
        validation_loss /= len(validation_loader)
        
        train_losses.append(loss.item())
        validation_losses.append(validation_loss)
        train_accuracies.append(train_accuracy)
        validation_accuracies.append(validation_accuracy)
        
        print(f"Epoch {epoch+1}/{num_epochs}, "
            f"Train Loss: {loss.item():.4f}, "
            f"Validation Loss: {validation_loss:.4f}, "
            f"Train Acc: {train_accuracy:.2f}%, "
            f"Validation Acc: {validation_accuracy:.2f}%")
        
        scheduler.step()  # Step the learning rate scheduler

    # Plot loss and accuracy
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Train Loss')
    plt.plot(validation_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(train_accuracies, label='Train Accuracy')
    plt.plot(validation_accuracies, label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.legend() 

    plt.show()

    return model


def test_model(model, test_dataset, batch_size, device):
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)
    
    model.eval()
    correct_test = 0
    total_test = 0
    test_loss = 0
    criterion = nn.CrossEntropyLoss()

    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            _, predicted = torch.max(outputs.data, 1)
            total_test += labels.size(0)
            correct_test += (predicted == labels).sum().item()
            test_loss += loss.item()

    test_accuracy = 100 * correct_test / total_test
    test_loss /= len(test_loader)

    print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_accuracy:.2f}%")

    original_classes = test_loader.dataset.classes

    # confusion matrix
    with torch.no_grad():
        all_predictions = []
        all_labels = []

        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)

            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    conf_matrix = confusion_matrix(all_labels, all_predictions)

    # Precision、Recall、F1 Score
    classification_rep = classification_report(all_labels, all_predictions, target_names=original_classes)

    print("Confusion Matrix:")
    print(conf_matrix)
    print("Classification Report:")
    print(classification_rep)

# %%
# device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# create train val and test folder
dataset_root = '/local/data1/honzh073/data/hospital_43'
target_root = '/local/data1/honzh073/data/hospital_43_data'

split_by_patient(dataset_root, target_root, train_ratio=0.6, val_ratio=0.3)

# create dataset
train_root = '/local/data1/honzh073/data/hospital_43_data/train'
val_root = '/local/data1/honzh073/data/hospital_43_data/val'
test_root='/local/data1/honzh073/data/hospital_43_data/test'


train_dataset, validation_dataset, test_dataset = create_dataset(train_root, val_root, test_root)
repeated_dataset = torch.utils.data.ConcatDataset([train_dataset] * 10)

# show image
show_image(train_dataset, 10)

# load data
batch_size = 64
train_loader = DataLoader(repeated_dataset, batch_size=batch_size, shuffle=True, pin_memory=True)
validation_loader = DataLoader(validation_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)

# classweight
classweight = get_classweight(train_dataset)
print(classweight)
# Out:
# Target dataset folder already exists.
# [1.6931818181818181, 0.7095238095238096]

# %%
# resnet50
resnet50 = train_model(train_loader, validation_loader,
                       classweight=classweight,
                       num_epochs=100, 
                       lr=0.0001, step_size=10, gamma=0.1, 
                       model_name='resnet50',
                       device = device)
test_model(model=resnet50, test_dataset=test_dataset, batch_size=batch_size, device=device)
# Out:
# Epoch 1/100, Train Loss: 0.5969, Validation Loss: 0.6381, Train Acc: 56.31%, Validation Acc: 74.24%
# Epoch 2/100, Train Loss: 0.9687, Validation Loss: 0.7836, Train Acc: 67.18%, Validation Acc: 74.24%
# Epoch 81/100, Train Loss: 0.0354, Validation Loss: 0.3981, Train Acc: 91.28%, Validation Acc: 78.79%
# Epoch 82/100, Train Loss: 0.0577, Validation Loss: 0.3864, Train Acc: 89.87%, Validation Acc: 80.30%
# Epoch 83/100, Train Loss: 0.0524, Validation Loss: 0.3647, Train Acc: 90.81%, Validation Acc: 78.79%
# Epoch 84/100, Train Loss: 0.0399, Validation Loss: 0.3909, Train Acc: 91.34%, Validation Acc: 78.79%
# Epoch 85/100, Train Loss: 0.0411, Validation Loss: 0.3920, Train Acc: 90.87%, Validation Acc: 80.30%
# Epoch 86/100, Train Loss: 0.0513, Validation Loss: 0.3762, Train Acc: 90.40%, Validation Acc: 78.79%
# Epoch 87/100, Train Loss: 0.0635, Validation Loss: 0.3753, Train Acc: 90.13%, Validation Acc: 80.30%
# Epoch 88/100, Train Loss: 0.0672, Validation Loss: 0.3663, Train Acc: 90.47%, Validation Acc: 78.79%
# Epoch 89/100, Train Loss: 0.1148, Validation Loss: 0.3686, Train Acc: 91.28%, Validation Acc: 78.79%
# Epoch 90/100, Train Loss: 0.0534, Validation Loss: 0.3923, Train Acc: 89.46%, Validation Acc: 77.27%
# Epoch 91/100, Train Loss: 0.0346, Validation Loss: 0.3999, Train Acc: 90.67%, Validation Acc: 81.82%
# Epoch 92/100, Train Loss: 0.0531, Validation Loss: 0.3993, Train Acc: 92.01%, Validation Acc: 78.79%
# Epoch 93/100, Train Loss: 0.0579, Validation Loss: 0.3737, Train Acc: 92.42%, Validation Acc: 80.30%
# Epoch 94/100, Train Loss: 0.0568, Validation Loss: 0.3807, Train Acc: 89.93%, Validation Acc: 80.30%
# Epoch 95/100, Train Loss: 0.0339, Validation Loss: 0.3891, Train Acc: 90.34%, Validation Acc: 80.30%
# Epoch 96/100, Train Loss: 0.0555, Validation Loss: 0.3831, Train Acc: 90.60%, Validation Acc: 78.79%
# Epoch 97/100, Train Loss: 0.0526, Validation Loss: 0.3680, Train Acc: 91.01%, Validation Acc: 78.79%
# Epoch 98/100, Train Loss: 0.0660, Validation Loss: 0.3788, Train Acc: 91.48%, Validation Acc: 78.79%
# Epoch 99/100, Train Loss: 0.0840, Validation Loss: 0.3877, Train Acc: 90.67%, Validation Acc: 78.79%
# Epoch 100/100, Train Loss: 0.0530, Validation Loss: 0.3785, Train Acc: 91.68%, Validation Acc: 80.30%
# Test Loss: 0.4376, Test Acc: 83.33%
# Confusion Matrix:
# [[10  3]
#  [ 2 15]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          AFF       0.83      0.77      0.80        13
#          NFF       0.83      0.88      0.86        17
#
#     accuracy                           0.83        30
#    macro avg       0.83      0.83      0.83        30
# weighted avg       0.83      0.83      0.83        30

# %%
# resnet101
resnet101 = train_model(train_loader, validation_loader, classweight, 
                        num_epochs=100,
                        lr=0.0001, step_size=10, gamma=0.1, 
                        model_name='resnet101', 
                        device=device)
# Out:
# Epoch 1/100, Train Loss: 0.6218, Validation Loss: 0.6298, Train Acc: 55.84%, Validation Acc: 80.30%
# Epoch 2/100, Train Loss: 0.9199, Validation Loss: 0.7440, Train Acc: 68.05%, Validation Acc: 80.30%
# Epoch 81/100, Train Loss: 0.0349, Validation Loss: 0.4263, Train Acc: 92.55%, Validation Acc: 81.82%
# Epoch 82/100, Train Loss: 0.0354, Validation Loss: 0.4049, Train Acc: 92.35%, Validation Acc: 80.30%
# Epoch 83/100, Train Loss: 0.0411, Validation Loss: 0.3981, Train Acc: 91.95%, Validation Acc: 80.30%
# Epoch 84/100, Train Loss: 0.0332, Validation Loss: 0.4135, Train Acc: 92.21%, Validation Acc: 81.82%
# Epoch 85/100, Train Loss: 0.0312, Validation Loss: 0.4276, Train Acc: 90.74%, Validation Acc: 81.82%
# Epoch 86/100, Train Loss: 0.0328, Validation Loss: 0.4220, Train Acc: 91.95%, Validation Acc: 83.33%
# Epoch 87/100, Train Loss: 0.0402, Validation Loss: 0.3969, Train Acc: 93.42%, Validation Acc: 81.82%
# Epoch 88/100, Train Loss: 0.0401, Validation Loss: 0.4105, Train Acc: 91.28%, Validation Acc: 81.82%
# Epoch 89/100, Train Loss: 0.0444, Validation Loss: 0.3880, Train Acc: 91.81%, Validation Acc: 80.30%
# Epoch 90/100, Train Loss: 0.0486, Validation Loss: 0.3801, Train Acc: 91.68%, Validation Acc: 80.30%
# Epoch 91/100, Train Loss: 0.0471, Validation Loss: 0.4053, Train Acc: 92.21%, Validation Acc: 81.82%
# Epoch 92/100, Train Loss: 0.0229, Validation Loss: 0.4496, Train Acc: 91.61%, Validation Acc: 81.82%
# Epoch 93/100, Train Loss: 0.0459, Validation Loss: 0.4300, Train Acc: 92.35%, Validation Acc: 80.30%
# Epoch 94/100, Train Loss: 0.0293, Validation Loss: 0.4248, Train Acc: 91.41%, Validation Acc: 80.30%
# Epoch 95/100, Train Loss: 0.0328, Validation Loss: 0.4205, Train Acc: 92.48%, Validation Acc: 81.82%
# Epoch 96/100, Train Loss: 0.0361, Validation Loss: 0.4096, Train Acc: 91.54%, Validation Acc: 81.82%
# Epoch 97/100, Train Loss: 0.0233, Validation Loss: 0.4483, Train Acc: 92.35%, Validation Acc: 83.33%
# Epoch 98/100, Train Loss: 0.0403, Validation Loss: 0.3954, Train Acc: 92.75%, Validation Acc: 80.30%
# Epoch 99/100, Train Loss: 0.0398, Validation Loss: 0.4242, Train Acc: 92.01%, Validation Acc: 80.30%
# Epoch 100/100, Train Loss: 0.0295, Validation Loss: 0.4312, Train Acc: 91.95%, Validation Acc: 81.82%

# %%
test_model(model=resnet101, test_dataset=test_dataset, batch_size=batch_size, device=device)
# Out:
# Test Loss: 0.8168, Test Acc: 76.67%
# Confusion Matrix:
# [[ 7  6]
#  [ 1 16]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          AFF       0.88      0.54      0.67        13
#          NFF       0.73      0.94      0.82        17
#
#     accuracy                           0.77        30
#    macro avg       0.80      0.74      0.74        30
# weighted avg       0.79      0.77      0.75        30

# %%
# resnet152
resnet152 = train_model(train_loader, validation_loader, classweight,
                        num_epochs=100, 
                        lr=0.0001, step_size=10, gamma=0.1, 
                        model_name='resnet152', 
                        device=device)
test_model(model=resnet152, test_dataset=test_dataset, batch_size=batch_size, device=device)
# Epoch 79/100, Train Loss: 0.5069, Validation Loss: 0.7264, Train Acc: 93.15%, Validation Acc: 84.85%
# Epoch 80/100, Train Loss: 0.8182, Validation Loss: 0.8772, Train Acc: 92.35%, Validation Acc: 84.85%
# Epoch 81/100, Train Loss: 0.4856, Validation Loss: 0.7431, Train Acc: 92.82%, Validation Acc: 81.82%
# Epoch 82/100, Train Loss: 0.6348, Validation Loss: 0.7767, Train Acc: 92.68%, Validation Acc: 86.36%
# Epoch 83/100, Train Loss: 0.7725, Validation Loss: 0.8293, Train Acc: 92.01%, Validation Acc: 86.36%
# Epoch 84/100, Train Loss: 0.6083, Validation Loss: 0.7647, Train Acc: 91.68%, Validation Acc: 86.36%
# Epoch 85/100, Train Loss: 0.7592, Validation Loss: 0.8355, Train Acc: 92.82%, Validation Acc: 86.36%
# Epoch 86/100, Train Loss: 0.9971, Validation Loss: 0.9714, Train Acc: 92.62%, Validation Acc: 81.82%
# Epoch 87/100, Train Loss: 0.4554, Validation Loss: 0.7205, Train Acc: 92.08%, Validation Acc: 83.33%
# Epoch 88/100, Train Loss: 0.8295, Validation Loss: 0.8575, Train Acc: 92.48%, Validation Acc: 83.33%
# Epoch 89/100, Train Loss: 0.8610, Validation Loss: 0.8769, Train Acc: 91.01%, Validation Acc: 84.85%
# Epoch 90/100, Train Loss: 0.7077, Validation Loss: 0.8402, Train Acc: 92.55%, Validation Acc: 86.36%
# Epoch 91/100, Train Loss: 0.5642, Validation Loss: 0.7842, Train Acc: 93.76%, Validation Acc: 83.33%
# Epoch 92/100, Train Loss: 0.6118, Validation Loss: 0.7843, Train Acc: 92.48%, Validation Acc: 84.85%
# Epoch 93/100, Train Loss: 0.8073, Validation Loss: 0.8660, Train Acc: 92.15%, Validation Acc: 86.36%
# Epoch 94/100, Train Loss: 0.8245, Validation Loss: 0.8609, Train Acc: 92.42%, Validation Acc: 83.33%
# Epoch 95/100, Train Loss: 0.6285, Validation Loss: 0.7832, Train Acc: 92.35%, Validation Acc: 83.33%
# Epoch 96/100, Train Loss: 0.7071, Validation Loss: 0.8188, Train Acc: 93.09%, Validation Acc: 83.33%
# Epoch 97/100, Train Loss: 0.7513, Validation Loss: 0.8446, Train Acc: 92.21%, Validation Acc: 83.33%
# Epoch 98/100, Train Loss: 0.6010, Validation Loss: 0.7892, Train Acc: 91.74%, Validation Acc: 83.33%
# Epoch 99/100, Train Loss: 0.7759, Validation Loss: 0.8794, Train Acc: 92.82%, Validation Acc: 84.85%
# Epoch 100/100, Train Loss: 0.7310, Validation Loss: 0.8195, Train Acc: 92.01%, Validation Acc: 86.36%
# Test Loss: 0.9065, Test Acc: 73.33%
# Confusion Matrix:
# [[10  3]
#  [ 5 12]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          AFF       0.67      0.77      0.71        13
#          NFF       0.80      0.71      0.75        17
#
#     accuracy                           0.73        30
#    macro avg       0.73      0.74      0.73        30
# weighted avg       0.74      0.73      0.73        30

# %%
# densenet161
densenet161 = train_model(train_loader, validation_loader, classweight,
                          num_epochs=100, 
                          lr=0.0001, step_size=5, gamma=0.1, 
                          model_name='densenet161', 
                          device=device)
test_model(model=densenet161, test_dataset=test_dataset, batch_size=batch_size, device=device)
# Out:
# Epoch 1/100, Train Loss: 0.9657, Validation Loss: 0.7554, Train Acc: 61.61%, Validation Acc: 72.73%
# Epoch 2/100, Train Loss: 2.2659, Validation Loss: 1.4429, Train Acc: 73.42%, Validation Acc: 69.70%
# Epoch 3/100, Train Loss: 0.3347, Validation Loss: 0.5645, Train Acc: 78.93%, Validation Acc: 77.27%
# Epoch 4/100, Train Loss: 0.0844, Validation Loss: 0.3337, Train Acc: 84.56%, Validation Acc: 81.82%
# Epoch 5/100, Train Loss: 0.0158, Validation Loss: 0.5070, Train Acc: 85.70%, Validation Acc: 80.30%
# Epoch 6/100, Train Loss: 0.0699, Validation Loss: 0.3242, Train Acc: 84.36%, Validation Acc: 86.36%
# Epoch 7/100, Train Loss: 0.0568, Validation Loss: 0.3095, Train Acc: 88.99%, Validation Acc: 86.36%
# Epoch 8/100, Train Loss: 0.0531, Validation Loss: 0.3070, Train Acc: 90.00%, Validation Acc: 84.85%
# Epoch 9/100, Train Loss: 0.0547, Validation Loss: 0.2968, Train Acc: 89.13%, Validation Acc: 87.88%
# Epoch 10/100, Train Loss: 0.0416, Validation Loss: 0.2993, Train Acc: 92.08%, Validation Acc: 86.36%
# Epoch 11/100, Train Loss: 0.0436, Validation Loss: 0.2931, Train Acc: 91.34%, Validation Acc: 87.88%
# Epoch 12/100, Train Loss: 0.0414, Validation Loss: 0.2981, Train Acc: 91.81%, Validation Acc: 87.88%
# Epoch 13/100, Train Loss: 0.0441, Validation Loss: 0.2952, Train Acc: 89.60%, Validation Acc: 87.88%
# Epoch 14/100, Train Loss: 0.0387, Validation Loss: 0.2917, Train Acc: 90.34%, Validation Acc: 87.88%
# Epoch 15/100, Train Loss: 0.0327, Validation Loss: 0.3098, Train Acc: 90.00%, Validation Acc: 86.36%
# Epoch 16/100, Train Loss: 0.0452, Validation Loss: 0.2931, Train Acc: 91.88%, Validation Acc: 87.88%
# Epoch 17/100, Train Loss: 0.0403, Validation Loss: 0.3083, Train Acc: 89.93%, Validation Acc: 86.36%
# Epoch 18/100, Train Loss: 0.0418, Validation Loss: 0.3036, Train Acc: 91.88%, Validation Acc: 86.36%
# Epoch 19/100, Train Loss: 0.0387, Validation Loss: 0.2947, Train Acc: 90.54%, Validation Acc: 86.36%
# Epoch 20/100, Train Loss: 0.0341, Validation Loss: 0.3099, Train Acc: 91.74%, Validation Acc: 84.85%
# Epoch 21/100, Train Loss: 0.0294, Validation Loss: 0.3140, Train Acc: 90.94%, Validation Acc: 83.33%
# Epoch 22/100, Train Loss: 0.0326, Validation Loss: 0.3250, Train Acc: 90.34%, Validation Acc: 84.85%
# Epoch 23/100, Train Loss: 0.0408, Validation Loss: 0.3081, Train Acc: 90.40%, Validation Acc: 86.36%
# Epoch 24/100, Train Loss: 0.0339, Validation Loss: 0.3136, Train Acc: 92.21%, Validation Acc: 84.85%
# Epoch 25/100, Train Loss: 0.0437, Validation Loss: 0.2987, Train Acc: 90.07%, Validation Acc: 86.36%
# Epoch 26/100, Train Loss: 0.0394, Validation Loss: 0.2985, Train Acc: 90.40%, Validation Acc: 86.36%
# Epoch 27/100, Train Loss: 0.0411, Validation Loss: 0.2959, Train Acc: 91.68%, Validation Acc: 86.36%
# Epoch 28/100, Train Loss: 0.0438, Validation Loss: 0.2886, Train Acc: 91.34%, Validation Acc: 87.88%
# Epoch 29/100, Train Loss: 0.0410, Validation Loss: 0.2991, Train Acc: 91.54%, Validation Acc: 86.36%
# Epoch 30/100, Train Loss: 0.0338, Validation Loss: 0.3172, Train Acc: 91.81%, Validation Acc: 84.85%
# Epoch 31/100, Train Loss: 0.0359, Validation Loss: 0.3008, Train Acc: 90.67%, Validation Acc: 86.36%
# Epoch 32/100, Train Loss: 0.0303, Validation Loss: 0.3172, Train Acc: 92.48%, Validation Acc: 83.33%
# Epoch 33/100, Train Loss: 0.0318, Validation Loss: 0.3100, Train Acc: 91.41%, Validation Acc: 86.36%
# Epoch 34/100, Train Loss: 0.0378, Validation Loss: 0.3071, Train Acc: 91.81%, Validation Acc: 86.36%
# Epoch 35/100, Train Loss: 0.0451, Validation Loss: 0.2977, Train Acc: 92.21%, Validation Acc: 87.88%
# Epoch 36/100, Train Loss: 0.0398, Validation Loss: 0.3158, Train Acc: 90.40%, Validation Acc: 83.33%
# Epoch 37/100, Train Loss: 0.0310, Validation Loss: 0.3202, Train Acc: 90.67%, Validation Acc: 83.33%
# Epoch 38/100, Train Loss: 0.0330, Validation Loss: 0.3275, Train Acc: 90.00%, Validation Acc: 83.33%
# Epoch 39/100, Train Loss: 0.0381, Validation Loss: 0.3086, Train Acc: 92.35%, Validation Acc: 86.36%
# Epoch 40/100, Train Loss: 0.0377, Validation Loss: 0.3084, Train Acc: 91.48%, Validation Acc: 84.85%
# Epoch 41/100, Train Loss: 0.0388, Validation Loss: 0.2988, Train Acc: 90.87%, Validation Acc: 86.36%
# Epoch 42/100, Train Loss: 0.0333, Validation Loss: 0.3074, Train Acc: 90.81%, Validation Acc: 84.85%
# Epoch 43/100, Train Loss: 0.0355, Validation Loss: 0.3042, Train Acc: 90.74%, Validation Acc: 86.36%
# Epoch 44/100, Train Loss: 0.0393, Validation Loss: 0.3008, Train Acc: 91.54%, Validation Acc: 86.36%
# Epoch 45/100, Train Loss: 0.0312, Validation Loss: 0.3098, Train Acc: 90.87%, Validation Acc: 86.36%
# Epoch 46/100, Train Loss: 0.0263, Validation Loss: 0.3351, Train Acc: 89.53%, Validation Acc: 84.85%
# Epoch 47/100, Train Loss: 0.0413, Validation Loss: 0.3028, Train Acc: 91.41%, Validation Acc: 86.36%
# Epoch 48/100, Train Loss: 0.0407, Validation Loss: 0.2959, Train Acc: 90.20%, Validation Acc: 87.88%
# Epoch 49/100, Train Loss: 0.0393, Validation Loss: 0.3042, Train Acc: 91.95%, Validation Acc: 86.36%
# Epoch 50/100, Train Loss: 0.0376, Validation Loss: 0.3087, Train Acc: 90.40%, Validation Acc: 84.85%
# Epoch 51/100, Train Loss: 0.0391, Validation Loss: 0.2977, Train Acc: 90.20%, Validation Acc: 86.36%
# Epoch 52/100, Train Loss: 0.0358, Validation Loss: 0.3185, Train Acc: 92.35%, Validation Acc: 83.33%
# Epoch 53/100, Train Loss: 0.0407, Validation Loss: 0.3002, Train Acc: 91.81%, Validation Acc: 86.36%
# Epoch 54/100, Train Loss: 0.0319, Validation Loss: 0.3161, Train Acc: 91.61%, Validation Acc: 83.33%
# Epoch 55/100, Train Loss: 0.0378, Validation Loss: 0.2974, Train Acc: 92.01%, Validation Acc: 87.88%
# Epoch 56/100, Train Loss: 0.0398, Validation Loss: 0.3053, Train Acc: 92.42%, Validation Acc: 86.36%
# Epoch 57/100, Train Loss: 0.0350, Validation Loss: 0.3055, Train Acc: 91.07%, Validation Acc: 86.36%
# Epoch 58/100, Train Loss: 0.0388, Validation Loss: 0.3077, Train Acc: 90.94%, Validation Acc: 86.36%
# Epoch 59/100, Train Loss: 0.0343, Validation Loss: 0.3111, Train Acc: 90.27%, Validation Acc: 84.85%
# Epoch 60/100, Train Loss: 0.0351, Validation Loss: 0.3146, Train Acc: 90.20%, Validation Acc: 83.33%
# Epoch 61/100, Train Loss: 0.0336, Validation Loss: 0.3121, Train Acc: 91.34%, Validation Acc: 83.33%
# Epoch 62/100, Train Loss: 0.0468, Validation Loss: 0.2954, Train Acc: 91.61%, Validation Acc: 87.88%
# Epoch 63/100, Train Loss: 0.0425, Validation Loss: 0.2890, Train Acc: 91.14%, Validation Acc: 87.88%
# Epoch 64/100, Train Loss: 0.0336, Validation Loss: 0.3146, Train Acc: 91.74%, Validation Acc: 84.85%
# Epoch 65/100, Train Loss: 0.0357, Validation Loss: 0.3140, Train Acc: 90.60%, Validation Acc: 84.85%
# Epoch 66/100, Train Loss: 0.0345, Validation Loss: 0.3149, Train Acc: 92.75%, Validation Acc: 83.33%
# Epoch 67/100, Train Loss: 0.0362, Validation Loss: 0.3072, Train Acc: 90.47%, Validation Acc: 86.36%
# Epoch 68/100, Train Loss: 0.0435, Validation Loss: 0.2977, Train Acc: 89.66%, Validation Acc: 87.88%
# Epoch 69/100, Train Loss: 0.0424, Validation Loss: 0.2920, Train Acc: 91.01%, Validation Acc: 87.88%
# Epoch 70/100, Train Loss: 0.0388, Validation Loss: 0.3098, Train Acc: 90.94%, Validation Acc: 84.85%
# Epoch 71/100, Train Loss: 0.0423, Validation Loss: 0.2956, Train Acc: 91.68%, Validation Acc: 87.88%
# Epoch 72/100, Train Loss: 0.0375, Validation Loss: 0.3043, Train Acc: 91.48%, Validation Acc: 86.36%
# Epoch 73/100, Train Loss: 0.0358, Validation Loss: 0.3058, Train Acc: 91.41%, Validation Acc: 84.85%
# Epoch 74/100, Train Loss: 0.0364, Validation Loss: 0.3160, Train Acc: 92.15%, Validation Acc: 83.33%
# Epoch 75/100, Train Loss: 0.0425, Validation Loss: 0.3064, Train Acc: 91.14%, Validation Acc: 84.85%
# Epoch 76/100, Train Loss: 0.0405, Validation Loss: 0.2906, Train Acc: 91.81%, Validation Acc: 87.88%
# Epoch 77/100, Train Loss: 0.0370, Validation Loss: 0.3086, Train Acc: 91.54%, Validation Acc: 84.85%
# Epoch 78/100, Train Loss: 0.0496, Validation Loss: 0.2913, Train Acc: 92.42%, Validation Acc: 87.88%
# Epoch 79/100, Train Loss: 0.0402, Validation Loss: 0.3022, Train Acc: 90.34%, Validation Acc: 86.36%
# Epoch 80/100, Train Loss: 0.0362, Validation Loss: 0.3041, Train Acc: 90.54%, Validation Acc: 86.36%
# Epoch 81/100, Train Loss: 0.0326, Validation Loss: 0.3075, Train Acc: 91.21%, Validation Acc: 86.36%
# Epoch 82/100, Train Loss: 0.0322, Validation Loss: 0.3132, Train Acc: 90.74%, Validation Acc: 83.33%
# Epoch 83/100, Train Loss: 0.0305, Validation Loss: 0.3227, Train Acc: 91.07%, Validation Acc: 83.33%
# Epoch 84/100, Train Loss: 0.0291, Validation Loss: 0.3189, Train Acc: 90.60%, Validation Acc: 83.33%
# Epoch 85/100, Train Loss: 0.0320, Validation Loss: 0.3147, Train Acc: 90.67%, Validation Acc: 84.85%
# Epoch 86/100, Train Loss: 0.0306, Validation Loss: 0.3161, Train Acc: 91.34%, Validation Acc: 84.85%
# Epoch 87/100, Train Loss: 0.0333, Validation Loss: 0.3172, Train Acc: 91.54%, Validation Acc: 83.33%
# Epoch 88/100, Train Loss: 0.0362, Validation Loss: 0.3018, Train Acc: 90.13%, Validation Acc: 86.36%
# Epoch 89/100, Train Loss: 0.0341, Validation Loss: 0.3090, Train Acc: 90.67%, Validation Acc: 86.36%
# Epoch 90/100, Train Loss: 0.0418, Validation Loss: 0.2987, Train Acc: 91.28%, Validation Acc: 86.36%
# Epoch 91/100, Train Loss: 0.0371, Validation Loss: 0.3005, Train Acc: 91.14%, Validation Acc: 86.36%
# Epoch 92/100, Train Loss: 0.0421, Validation Loss: 0.3008, Train Acc: 90.13%, Validation Acc: 86.36%
# Epoch 93/100, Train Loss: 0.0415, Validation Loss: 0.3017, Train Acc: 90.07%, Validation Acc: 86.36%
# Epoch 94/100, Train Loss: 0.0314, Validation Loss: 0.3127, Train Acc: 90.74%, Validation Acc: 84.85%
# Epoch 95/100, Train Loss: 0.0430, Validation Loss: 0.3013, Train Acc: 91.34%, Validation Acc: 86.36%
# Epoch 96/100, Train Loss: 0.0357, Validation Loss: 0.3100, Train Acc: 91.81%, Validation Acc: 86.36%
# Epoch 97/100, Train Loss: 0.0401, Validation Loss: 0.2946, Train Acc: 91.21%, Validation Acc: 87.88%
# Epoch 98/100, Train Loss: 0.0350, Validation Loss: 0.3109, Train Acc: 91.88%, Validation Acc: 83.33%
# Epoch 99/100, Train Loss: 0.0359, Validation Loss: 0.3094, Train Acc: 89.80%, Validation Acc: 84.85%
# Epoch 100/100, Train Loss: 0.0353, Validation Loss: 0.3020, Train Acc: 92.42%, Validation Acc: 86.36%
# Test Loss: 0.4135, Test Acc: 90.00%
# Confusion Matrix:
# [[10  3]
#  [ 0 17]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          AFF       1.00      0.77      0.87        13
#          NFF       0.85      1.00      0.92        17
#
#     accuracy                           0.90        30
#    macro avg       0.93      0.88      0.89        30
# weighted avg       0.91      0.90      0.90        30
