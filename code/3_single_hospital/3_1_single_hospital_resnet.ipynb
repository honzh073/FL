# %% [markdown]
# # 1 Create train, validation and test dataset

# %%
import os
import random
import shutil

# 原始数据集根文件夹
dataset_root = '/local/data1/honzh073/data/hospital_43'

# 目标数据集文件夹
target_dataset_folder = '/local/data1/honzh073/data/hospital_43_data'

# 创建目标数据集文件夹
os.makedirs(target_dataset_folder, exist_ok=True)

# AFF和NFF文件夹
fracture_types = ['AFF', 'NFF']

# 分割数据集的比例
train_ratio = 0.7
val_ratio = 0.15
test_ratio = 0.15

# 遍历AFF和NFF文件夹
for fracture_type in fracture_types:
    source_folder = os.path.join(dataset_root, fracture_type)
    patients = os.listdir(source_folder)
    
    # 随机打乱患者顺序
    random.shuffle(patients)
    
    # 划分数据集
    total_patients = len(patients)
    train_end = int(total_patients * train_ratio)
    val_end = train_end + int(total_patients * val_ratio)
    
    train_patients = patients[:train_end]
    val_patients = patients[train_end:val_end]
    test_patients = patients[val_end:]
    
    # 复制图片到相应的数据集文件夹
    for patient_id in train_patients:
        source_path = os.path.join(source_folder, patient_id)
        target_path = os.path.join(target_dataset_folder, 'train', fracture_type, patient_id)
        shutil.copytree(source_path, target_path)
    
    for patient_id in val_patients:
        source_path = os.path.join(source_folder, patient_id)
        target_path = os.path.join(target_dataset_folder, 'val', fracture_type, patient_id)
        shutil.copytree(source_path, target_path)
    
    for patient_id in test_patients:
        source_path = os.path.join(source_folder, patient_id)
        target_path = os.path.join(target_dataset_folder, 'test', fracture_type, patient_id)
        shutil.copytree(source_path, target_path)

print("Dataset split completed.")
# Out:
# Dataset split completed.

# %%
import os

def count_number(path_folder):
    # AFF和NFF文件夹路径
    aff_folder = os.path.join(path_folder, 'AFF')
    nff_folder = os.path.join(path_folder, 'NFF')

    # 统计AFF和NFF文件夹中的图片数量
    aff_image_count = sum(len(files) for _, _, files in os.walk(aff_folder))
    nff_image_count = sum(len(files) for _, _, files in os.walk(nff_folder))
    
    return aff_image_count, nff_image_count

print('total:')
path_folder = '/local/data1/honzh073/data/hospital_43'
total_aff_num, total_nff_num = count_number(path_folder)
print('aff number:', total_aff_num, '; nff number:', total_nff_num)

print('train:')
path_folder = '/local/data1/honzh073/data/hospital_43_data/train'
aff_num, nff_num = count_number(path_folder)
print('aff number:', aff_num, '; nff number:', nff_num)
print('%:', aff_num / total_aff_num , '; %:', nff_num / total_nff_num)

print('val:')
path_folder = '/local/data1/honzh073/data/hospital_43_data/val'
aff_num, nff_num = count_number(path_folder)
print('aff number:', aff_num, '; nff number:', nff_num)
print('%:', aff_num / total_aff_num , '; %:', nff_num / total_nff_num)


print('test:')
path_folder = '/local/data1/honzh073/data/hospital_43_data/test'
aff_num, nff_num = count_number(path_folder)
print('aff number:', aff_num, '; nff number:', nff_num)
print('%:', aff_num / total_aff_num , '; %:', nff_num / total_nff_num)
# Out:
# total:
# aff number: 75 ; nff number: 170
# train:
# aff number: 34 ; nff number: 85
# %: 0.4533333333333333 ; %: 0.5
# val:
# aff number: 19 ; nff number: 38
# %: 0.25333333333333335 ; %: 0.2235294117647059
# test:
# aff number: 22 ; nff number: 47
# %: 0.29333333333333333 ; %: 0.27647058823529413

# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, random_split
import random
import matplotlib.pyplot as plt
import numpy as np
from torch import optim
from torch.optim import lr_scheduler
import torchvision.models as models

# ----------------------------------------------------------------------------------------------
# Augmentation
# Define data augmentation transforms
transform = transforms.Compose([
    # transforms.RandomHorizontalFlip(),
    # transforms.RandomVerticalFlip(),
    # transforms.RandomRotation(90),  # Randomly rotate the image up to 30 degrees
    # transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),  # Adjust color
    # transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),  # Random affine transformation
    # transforms.RandomPerspective(),  # Random perspective transformation
    # transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),  # Random resized crop
    transforms.ToTensor(),  # Convert the image to a PyTorch tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # Normalize the image to RGB
])

# Define the data loaders
train_dataset = ImageFolder(root='/local/data1/honzh073/data/hospital_43_data/train', transform=transform)
validation_dataset = ImageFolder(root='/local/data1/honzh073/data/hospital_43_data/val', transform=transform)
test_dataset = ImageFolder(root='/local/data1/honzh073/data/hospital_43_data/test', transform=transform)


batch_size = 8

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, pin_memory=True)
validation_loader = DataLoader(validation_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)

# ----------------------------------------------------------------------------------------------
# Check if CUDA is available
if torch.cuda.is_available():
    print("CUDA is available!")
    device = torch.device("cuda:0")  # Use GPU 0
else:
    print("CUDA is not available.")
    device = torch.device("cpu")
# ----------------------------------------------------------------------------------------------
print('done!')
# Out:
# CUDA is available!
# done!

# %% [markdown]
# # Plot 8 bit Images

# %%
# Get some random indices from the validation dataset
random_indices = np.random.choice(len(validation_dataset), 5, replace=False)

# Print image file paths
for i, idx in enumerate(random_indices):
    filename = validation_dataset.samples[idx][0]  # Get the filename
    print(f"Image {i + 1} Path: {filename}")

# Plot images (transformed) with truncated names
plt.figure(figsize=(15, 5))
for i, idx in enumerate(random_indices):
    image, label = validation_dataset[idx]  # Use validation_dataset directly
    filename = validation_dataset.samples[idx][0]  # Get the filename
    truncated_filename = filename.split('/')[-1][:15]  # Extract the last part and truncate to 15 characters
    plt.subplot(1, 5, i + 1)
    plt.title(f"Label: {label}")
    plt.imshow(image[0], cmap='gray')  # Single-channel (grayscale)
    plt.axis('off')
plt.show()
# Out:
# Image 1 Path: /local/data1/honzh073/data/hospital_43_data/val/NFF/patient_PCXBNDJVGW/patient_PCXBNDJVGW_hospital_43_NFF_image_3.png
# Image 2 Path: /local/data1/honzh073/data/hospital_43_data/val/AFF/patient_LNXBCFQICO/patient_LNXBCFQICO_hospital_43_AFF_image_1.png
# Image 3 Path: /local/data1/honzh073/data/hospital_43_data/val/AFF/patient_EYRSUJGIZG/patient_EYRSUJGIZG_hospital_43_AFF_image_1.png
# Image 4 Path: /local/data1/honzh073/data/hospital_43_data/val/NFF/patient_ZYKAOFFICT/patient_ZYKAOFFICT_hospital_43_NFF_image_5.png
# Image 5 Path: /local/data1/honzh073/data/hospital_43_data/val/NFF/patient_ZYKAOFFICT/patient_ZYKAOFFICT_hospital_43_NFF_image_4.png

# %% [markdown]
# # Class weights of Training Dataset

# %%
# ---------------------------------------------------------------------------------

# aff and nff numbers in training dataset
train_aff_count = sum(1 for _, label in train_dataset if label == 0)  # 0 AFF
train_nff_count = sum(1 for _, label in train_dataset if label == 1)  # 1 NFF

# ---------------------------------------------------------------------------------
# Calculate class weights
n_aff_train = train_aff_count
n_nff_train = train_nff_count

class_weight_aff = 1 / (2 * (n_aff_train / (n_aff_train + n_nff_train)))
class_weight_nff = 1 / (2 * (n_nff_train / (n_aff_train + n_nff_train)))

print(f"Class Weight for AFF (0): {class_weight_aff:.4f}")
print(f"Class Weight for NFF (1): {class_weight_nff:.4f}")
# Out:
# Class Weight for AFF (0): 1.7500
# Class Weight for NFF (1): 0.7000

# %% [markdown]
# # ResNet152
# # 80% Training, 10% Validation, and 10% Test
# # Test Performance
#
# ## When used lr = 0.0001, step_size = 10, and gamma = 0.1, get a 96% accuracy on test data.

# %%
from torchvision.models import resnet152, ResNet152_Weights

# Settings
lr = 0.00001
step_size = 10
gamma = 0.1

# Class weights
class_weights = [class_weight_aff, class_weight_nff]
class_weights = torch.Tensor(class_weights).to(device)

# ResNet152
model = models.resnet152(weights=ResNet152_Weights.DEFAULT)
model = model.to(device)

# Update the output layer
model.fc = nn.Linear(2048, 2)  # output layer classes number = dataset classes number
model = model.to(device)

# Loss function
criterion = nn.CrossEntropyLoss(weight=class_weights)
criterion = criterion.to(device)

optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)

# Training (loss and accuracy)
train_losses = []
validation_losses = []
train_accuracies = []
validation_accuracies = []

num_epochs = 50
for epoch in range(num_epochs):
    model.train()
    correct_train = 0
    total_train = 0
    
    for images, labels in train_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()
    
    train_accuracy = 100 * correct_train / total_train
    
    model.eval()
    correct_validation = 0
    total_validation = 0
    validation_loss = 0
    
    with torch.no_grad():
        for images, labels in validation_loader:
            images = images.to(device)
            labels = labels.to(device)
            
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            _, predicted = torch.max(outputs.data, 1)
            total_validation += labels.size(0)
            correct_validation += (predicted == labels).sum().item()
            validation_loss += loss.item()
    
    validation_accuracy = 100 * correct_validation / total_validation
    validation_loss /= len(validation_loader)
    
    train_losses.append(loss.item())
    validation_losses.append(validation_loss)
    train_accuracies.append(train_accuracy)
    validation_accuracies.append(validation_accuracy)
    
    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {loss.item():.4f}, Validation Loss: {validation_loss:.4f}, Train Acc: {train_accuracy:.2f}%, Validation Acc: {validation_accuracy:.2f}%")
    
    scheduler.step()  # Step the learning rate scheduler

# Plot loss and accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(validation_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(validation_accuracies, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.show()

# Test dataset performance
model.eval()
correct_test = 0
total_test = 0
test_loss = 0

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        loss = criterion(outputs, labels)

        _, predicted = torch.max(outputs.data, 1)
        total_test += labels.size(0)
        correct_test += (predicted == labels).sum().item()
        test_loss += loss.item()

test_accuracy = 100 * correct_test / total_test
test_loss /= len(test_loader)

print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_accuracy:.2f}%")
# Out:
# Epoch 1/50, Train Loss: 0.6108, Validation Loss: 0.6627, Train Acc: 68.91%, Validation Acc: 66.67%
# Epoch 2/50, Train Loss: 0.6013, Validation Loss: 0.6630, Train Acc: 73.95%, Validation Acc: 66.67%
# Epoch 3/50, Train Loss: 0.6768, Validation Loss: 0.6625, Train Acc: 81.51%, Validation Acc: 70.18%
# Epoch 4/50, Train Loss: 0.7715, Validation Loss: 0.6778, Train Acc: 91.60%, Validation Acc: 63.16%
# Epoch 5/50, Train Loss: 0.6090, Validation Loss: 0.6544, Train Acc: 94.96%, Validation Acc: 61.40%
# Epoch 6/50, Train Loss: 0.4354, Validation Loss: 0.6322, Train Acc: 96.64%, Validation Acc: 57.89%
# Epoch 7/50, Train Loss: 0.4511, Validation Loss: 0.6374, Train Acc: 97.48%, Validation Acc: 57.89%
# Epoch 8/50, Train Loss: 0.4090, Validation Loss: 0.6300, Train Acc: 100.00%, Validation Acc: 63.16%
# Epoch 9/50, Train Loss: 0.3418, Validation Loss: 0.6054, Train Acc: 98.32%, Validation Acc: 63.16%
# Epoch 10/50, Train Loss: 0.3328, Validation Loss: 0.6044, Train Acc: 98.32%, Validation Acc: 57.89%
# Epoch 11/50, Train Loss: 0.3615, Validation Loss: 0.6263, Train Acc: 100.00%, Validation Acc: 59.65%
# Epoch 12/50, Train Loss: 0.3305, Validation Loss: 0.6274, Train Acc: 99.16%, Validation Acc: 59.65%
# Epoch 13/50, Train Loss: 0.3432, Validation Loss: 0.6386, Train Acc: 98.32%, Validation Acc: 56.14%
# Epoch 14/50, Train Loss: 0.3449, Validation Loss: 0.6317, Train Acc: 99.16%, Validation Acc: 57.89%
# Epoch 15/50, Train Loss: 0.3562, Validation Loss: 0.6361, Train Acc: 99.16%, Validation Acc: 57.89%
# Epoch 16/50, Train Loss: 0.3318, Validation Loss: 0.6294, Train Acc: 100.00%, Validation Acc: 56.14%
# Epoch 17/50, Train Loss: 0.3212, Validation Loss: 0.6290, Train Acc: 99.16%, Validation Acc: 56.14%
# Epoch 18/50, Train Loss: 0.3329, Validation Loss: 0.6303, Train Acc: 99.16%, Validation Acc: 57.89%
# Epoch 19/50, Train Loss: 0.3444, Validation Loss: 0.6343, Train Acc: 100.00%, Validation Acc: 56.14%
# Epoch 20/50, Train Loss: 0.3215, Validation Loss: 0.6342, Train Acc: 100.00%, Validation Acc: 57.89%
# Epoch 21/50, Train Loss: 0.3566, Validation Loss: 0.6324, Train Acc: 100.00%, Validation Acc: 61.40%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /local/data1/honzh073/git/FL/localnn/3_single_hospital/3_1_single_hospital_resnet.ipynb Cell 10 line 4
#      <a href='vscode-notebook-cell://ssh-remote%2Bsuzuki_ssh/local/data1/honzh073/git/FL/localnn/3_single_hospital/3_1_single_hospital_resnet.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=39'>40</a> images = images.to(device)
#      <a href='vscode-notebook-cell://ssh-remote%2Bsuzuki_ssh/local/data1/honzh073/git/FL/localnn/3_single_hospital/3_1_single_hospital_resnet.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=40'>41</a> labels = labels.to(device)
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bsuzuki_ssh/local/data1/honzh073/git/FL/localnn/3_single_hospital/3_1_single_hospital_resnet.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=41'>42</a> outputs = model(images)
#      <a href='vscode-notebook-cell://ssh-remote%2Bsuzuki_ssh/local/data1/honzh073/git/FL/localnn/3_single_hospital/3_1_single_hospital_resnet.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=42'>43</a> loss = criterion(outputs, labels)
#      <a href='vscode-notebook-cell://ssh-remote%2Bsuzuki_ssh/local/data1/honzh073/git/FL/localnn/3_single_hospital/3_1_single_hospital_resnet.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=43'>44</a> optimizer.zero_grad()
#
# File /local/data1/honzh073/anaconda3/envs/myenv/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /local/data1/honzh073/anaconda3/envs/myenv/lib/python3.9/site-packages/torchvision/models/resnet.py:285, in ResNet.forward(self, x)
#     284 def forward(self, x: Tensor) -> Tensor:
# --> 285     return self._forward_impl(x)
#
# File /local/data1/honzh073/anaconda3/envs/myenv/lib/python3.9/site-packages/torchvision/models/resnet.py:275, in ResNet._forward_impl(self, x)
#     273 x = self.layer1(x)
#     274 x = self.layer2(x)
# --> 275 x = self.layer3(x)
#     276 x = self.layer4(x)
#     278 x = self.avgpool(x)
#
# File /local/data1/honzh073/anaconda3/envs/myenv/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /local/data1/honzh073/anaconda3/envs/myenv/lib/python3.9/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File /local/data1/honzh073/anaconda3/envs/myenv/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /local/data1/honzh073/anaconda3/envs/myenv/lib/python3.9/site-packages/torchvision/models/resnet.py:154, in Bottleneck.forward(self, x)
#     151 out = self.bn2(out)
#     152 out = self.relu(out)
# --> 154 out = self.conv3(out)
#     155 out = self.bn3(out)
#     157 if self.downsample is not None:
#
# File /local/data1/honzh073/anaconda3/envs/myenv/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /local/data1/honzh073/anaconda3/envs/myenv/lib/python3.9/site-packages/torch/nn/modules/conv.py:463, in Conv2d.forward(self, input)
#     462 def forward(self, input: Tensor) -> Tensor:
# --> 463     return self._conv_forward(input, self.weight, self.bias)
#
# File /local/data1/honzh073/anaconda3/envs/myenv/lib/python3.9/site-packages/torch/nn/modules/conv.py:459, in Conv2d._conv_forward(self, input, weight, bias)
#     455 if self.padding_mode != 'zeros':
#     456     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     457                     weight, bias, self.stride,
#     458                     _pair(0), self.dilation, self.groups)
# --> 459 return F.conv2d(input, weight, bias, self.stride,
#     460                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
def eva(test_loader):
        
    # Test dataset performance
    model.eval()
    correct_test = 0
    total_test = 0
    test_loss = 0

    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            _, predicted = torch.max(outputs.data, 1)
            total_test += labels.size(0)
            correct_test += (predicted == labels).sum().item()
            test_loss += loss.item()

    test_accuracy = 100 * correct_test / total_test
    test_loss /= len(test_loader)

    print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_accuracy:.2f}%")

    from sklearn.metrics import confusion_matrix, classification_report

    original_classes = train_loader.dataset.classes

    # confusion matrix
    with torch.no_grad():
        all_predictions = []
        all_labels = []

        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)

            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    conf_matrix = confusion_matrix(all_labels, all_predictions)

    # Precision、Recall、F1 Score
    classification_rep = classification_report(all_labels, all_predictions, target_names=original_classes)

    print("Confusion Matrix:")
    print(conf_matrix)
    print("Classification Report:")
    print(classification_rep)



# 在所有image上的表现
images = ImageFolder(root='/local/data1/honzh073/data/8bit_image', transform=transform)

image_loader = DataLoader(images, batch_size=batch_size, shuffle=False, pin_memory=True)

eva(test_loader)
# Out:
# Test Loss: 0.5885, Test Acc: 76.81%
# Confusion Matrix:
# [[11 11]
#  [ 7 40]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          AFF       0.61      0.50      0.55        22
#          NFF       0.78      0.85      0.82        47
#
#     accuracy                           0.74        69
#    macro avg       0.70      0.68      0.68        69
# weighted avg       0.73      0.74      0.73        69

# %% [markdown]
# # Save model

# %%
# Save the trained VGG model
# torch.save(model.state_dict(), 'patient_level_resnet152.pth')

# %% [markdown]
# # Clean GPU memory

# %%
torch.cuda.empty_cache()

# %% [markdown]
# # VGG19

# %%
from torchvision.models import vgg19, VGG19_Weights

# Settings
lr = 0.0001
step_size = 10
gamma = 0.1

# Move class weights to the selected device
class_weights = [class_weight_aff, class_weight_nff]
class_weights = torch.Tensor(class_weights).to(device)

# VGG19
model = models.vgg19(weights=VGG19_Weights.DEFAULT)  # Load the pre-trained VGG19 model
model.classifier[6] = nn.Linear(4096, 2)  # Modify the last fully connected layer
model = model.to(device)

# Loss function
criterion = nn.CrossEntropyLoss(weight=class_weights)
criterion = criterion.to(device)

optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)

# Training and validation
train_losses = []
validation_losses = []
train_accuracies = []
validation_accuracies = []

num_epochs = 50
for epoch in range(num_epochs):
    model.train()
    correct_train = 0
    total_train = 0

    for images, labels in train_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    train_accuracy = 100 * correct_train / total_train

    model.eval()
    correct_validation = 0
    total_validation = 0
    validation_loss = 0

    with torch.no_grad():
        for images, labels in validation_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            _, predicted = torch.max(outputs.data, 1)
            total_validation += labels.size(0)
            correct_validation += (predicted == labels).sum().item()
            validation_loss += loss.item()

    validation_accuracy = 100 * correct_validation / total_validation
    validation_loss /= len(validation_loader)

    train_losses.append(loss.item())
    validation_losses.append(validation_loss)
    train_accuracies.append(train_accuracy)
    validation_accuracies.append(validation_accuracy)

    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {loss.item():.4f}, Validation Loss: {validation_loss:.4f}, Train Acc: {train_accuracy:.2f}%, Validation Acc: {validation_accuracy:.2f}%")

    scheduler.step()  # Step the learning rate scheduler

# Plot loss and accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(validation_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(validation_accuracies, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.show()

# Test the model on the test dataset
model.eval()
correct_test = 0
total_test = 0
test_loss = 0

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        loss = criterion(outputs, labels)

        _, predicted = torch.max(outputs.data, 1)
        total_test += labels.size(0)
        correct_test += (predicted == labels).sum().item()
        test_loss += loss.item()

test_accuracy = 100 * correct_test / total_test
test_loss /= len(test_loader)

print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_accuracy:.2f}%")
# Out:
# Epoch 1/50, Train Loss: 0.3641, Validation Loss: 0.6193, Train Acc: 64.71%, Validation Acc: 66.67%
# Epoch 2/50, Train Loss: 0.6335, Validation Loss: 0.6660, Train Acc: 59.66%, Validation Acc: 66.67%
# Epoch 3/50, Train Loss: 0.7161, Validation Loss: 0.6911, Train Acc: 66.39%, Validation Acc: 49.12%
# Epoch 4/50, Train Loss: 0.4508, Validation Loss: 0.6713, Train Acc: 62.18%, Validation Acc: 61.40%
# Epoch 5/50, Train Loss: 1.0998, Validation Loss: 0.8895, Train Acc: 60.50%, Validation Acc: 33.33%
# Epoch 6/50, Train Loss: 0.5284, Validation Loss: 0.6462, Train Acc: 57.98%, Validation Acc: 66.67%
# Epoch 7/50, Train Loss: 0.7107, Validation Loss: 0.6842, Train Acc: 66.39%, Validation Acc: 56.14%
# Epoch 8/50, Train Loss: 0.7955, Validation Loss: 0.7255, Train Acc: 58.82%, Validation Acc: 40.35%
# Epoch 9/50, Train Loss: 0.1009, Validation Loss: 0.9140, Train Acc: 67.23%, Validation Acc: 61.40%
# Epoch 10/50, Train Loss: 0.3467, Validation Loss: 0.8293, Train Acc: 68.07%, Validation Acc: 66.67%
# Epoch 11/50, Train Loss: 0.5326, Validation Loss: 0.8166, Train Acc: 80.67%, Validation Acc: 68.42%
# Epoch 12/50, Train Loss: 0.4877, Validation Loss: 0.7859, Train Acc: 82.35%, Validation Acc: 71.93%
# Epoch 13/50, Train Loss: 0.2267, Validation Loss: 0.8762, Train Acc: 86.55%, Validation Acc: 68.42%
# Epoch 14/50, Train Loss: 0.2566, Validation Loss: 0.7777, Train Acc: 85.71%, Validation Acc: 70.18%
# Epoch 15/50, Train Loss: 0.1529, Validation Loss: 0.8600, Train Acc: 89.08%, Validation Acc: 70.18%
# Epoch 16/50, Train Loss: 0.0808, Validation Loss: 0.9581, Train Acc: 93.28%, Validation Acc: 64.91%
# Epoch 17/50, Train Loss: 0.0466, Validation Loss: 0.9918, Train Acc: 91.60%, Validation Acc: 71.93%
# Epoch 18/50, Train Loss: 0.0512, Validation Loss: 1.0383, Train Acc: 94.96%, Validation Acc: 70.18%
# Epoch 19/50, Train Loss: 0.0494, Validation Loss: 1.0130, Train Acc: 93.28%, Validation Acc: 77.19%
# Epoch 20/50, Train Loss: 0.0039, Validation Loss: 1.2323, Train Acc: 95.80%, Validation Acc: 71.93%
# Epoch 21/50, Train Loss: 0.0136, Validation Loss: 1.1620, Train Acc: 95.80%, Validation Acc: 73.68%
# Epoch 22/50, Train Loss: 0.0206, Validation Loss: 1.2147, Train Acc: 97.48%, Validation Acc: 75.44%
# Epoch 23/50, Train Loss: 0.0193, Validation Loss: 1.1508, Train Acc: 97.48%, Validation Acc: 73.68%
# Epoch 24/50, Train Loss: 0.0221, Validation Loss: 1.1560, Train Acc: 97.48%, Validation Acc: 80.70%
# Epoch 25/50, Train Loss: 0.0155, Validation Loss: 1.0510, Train Acc: 98.32%, Validation Acc: 77.19%
# Epoch 26/50, Train Loss: 0.0180, Validation Loss: 1.1451, Train Acc: 98.32%, Validation Acc: 68.42%
# Epoch 27/50, Train Loss: 0.0173, Validation Loss: 1.0183, Train Acc: 99.16%, Validation Acc: 71.93%
# Epoch 28/50, Train Loss: 0.0135, Validation Loss: 1.6081, Train Acc: 98.32%, Validation Acc: 66.67%
# Epoch 29/50, Train Loss: 0.0125, Validation Loss: 1.3225, Train Acc: 99.16%, Validation Acc: 73.68%
# Epoch 30/50, Train Loss: 0.0085, Validation Loss: 1.4701, Train Acc: 99.16%, Validation Acc: 70.18%
# Epoch 31/50, Train Loss: 0.0086, Validation Loss: 1.0578, Train Acc: 99.16%, Validation Acc: 78.95%
# Epoch 32/50, Train Loss: 0.0146, Validation Loss: 1.2828, Train Acc: 99.16%, Validation Acc: 77.19%
# Epoch 33/50, Train Loss: 0.0115, Validation Loss: 0.9519, Train Acc: 98.32%, Validation Acc: 77.19%
# Epoch 34/50, Train Loss: 0.0137, Validation Loss: 1.1255, Train Acc: 99.16%, Validation Acc: 71.93%
# Epoch 35/50, Train Loss: 0.0144, Validation Loss: 1.3551, Train Acc: 99.16%, Validation Acc: 73.68%
# Epoch 36/50, Train Loss: 0.0140, Validation Loss: 1.0183, Train Acc: 100.00%, Validation Acc: 73.68%
# Epoch 37/50, Train Loss: 0.0113, Validation Loss: 1.0526, Train Acc: 100.00%, Validation Acc: 73.68%
# Epoch 38/50, Train Loss: 0.0091, Validation Loss: 1.1398, Train Acc: 97.48%, Validation Acc: 80.70%
# Epoch 39/50, Train Loss: 0.0155, Validation Loss: 1.1308, Train Acc: 99.16%, Validation Acc: 77.19%
# Epoch 40/50, Train Loss: 0.0091, Validation Loss: 1.2937, Train Acc: 99.16%, Validation Acc: 73.68%
# Epoch 41/50, Train Loss: 0.0110, Validation Loss: 1.2813, Train Acc: 99.16%, Validation Acc: 73.68%
# Epoch 42/50, Train Loss: 0.0091, Validation Loss: 1.3335, Train Acc: 99.16%, Validation Acc: 66.67%
# Epoch 43/50, Train Loss: 0.0092, Validation Loss: 1.3497, Train Acc: 99.16%, Validation Acc: 73.68%
# Epoch 44/50, Train Loss: 0.0091, Validation Loss: 1.2187, Train Acc: 100.00%, Validation Acc: 68.42%
# Epoch 45/50, Train Loss: 0.0150, Validation Loss: 1.0409, Train Acc: 98.32%, Validation Acc: 70.18%
# Epoch 46/50, Train Loss: 0.0160, Validation Loss: 1.1352, Train Acc: 100.00%, Validation Acc: 75.44%
# Epoch 47/50, Train Loss: 0.0110, Validation Loss: 0.9201, Train Acc: 100.00%, Validation Acc: 78.95%
# Epoch 48/50, Train Loss: 0.0091, Validation Loss: 1.1429, Train Acc: 99.16%, Validation Acc: 77.19%
# Epoch 49/50, Train Loss: 0.0150, Validation Loss: 1.1796, Train Acc: 99.16%, Validation Acc: 78.95%
# Epoch 50/50, Train Loss: 0.0159, Validation Loss: 1.2209, Train Acc: 99.16%, Validation Acc: 70.18%
# Test Loss: 1.2936, Test Acc: 81.16%

# %%
# Save the trained VGG model
# torch.save(model.state_dict(), 'patient_level_vgg19.pth')
