# %% [markdown]
# # Functions

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_curve, roc_auc_score
   
def show_image(dataset, num_images=5):
    # Get random indices
    random_indices = np.random.choice(len(dataset), num_images, replace=False)

    # Plot images with truncated names
    plt.figure(figsize=(15, 5))
    for i, idx in enumerate(random_indices):
        image, label = dataset[idx]  # Use the dataset directly
        filename = dataset.data[idx][0]  # Get the filename from dataset's internal data attribute
        truncated_filename = filename.split('/')[-1][:15]  # Extract the last part and truncate to 15 characters
        
        # Print the original filename
        print(f"Image location: {filename}")

        plt.subplot(1, num_images, i + 1)
        plt.title(f"Label: {label}")
        plt.imshow(image[0])  # Assuming single-channel (grayscale) image
        # plt.imshow(image[0], cmap='gray')  # Assuming single-channel (grayscale) image

        plt.axis('off')
    plt.show()
    
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_classweight(train_dataset):
    train_nff_count = sum(1 for _, label in train_dataset if label == 0)  # 0 NFF
    train_aff_count = sum(1 for _, label in train_dataset if label == 1)  # 1 AFF
    class_weight_nff = 1 / (2 * (train_nff_count / (train_nff_count + train_aff_count)))
    class_weight_aff = 1 / (2 * (train_aff_count / (train_nff_count + train_aff_count)))
    
    return [class_weight_nff, class_weight_aff] # 0 nff , 1 aff

# %%
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import csv
from torchvision import transforms, models
from sklearn.model_selection import KFold
# Define your image transformations for training and testing
from torchvision import transforms
# Custom dataset class
import os
import csv
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn as nn
from torchvision import models
from torchvision import transforms
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_curve, roc_auc_score
import torch.nn.functional as F
import json

# custom dataset on csv files
class CustomDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]
        image_path = item['ImagePath']
        label = item['Label']

        # Load image
        image = Image.open(image_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        # Convert label to numerical representation
        if label == 'NFF':
            label = 0
        elif label == 'AFF':
            label = 1
        else:
            raise ValueError("Invalid label in JSON data.")

        return image, label

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])


# augmentation
train_transforms = transforms.Compose([
    transforms.RandomRotation(degrees=30),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.GaussianBlur(kernel_size=3),
    transforms.RandomAdjustSharpness(sharpness_factor=5),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
# Define data augmentation transforms for validation data
val_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load JSON data
with open('/local/data1/honzh073/local_repository/FL/code/4_centralized_learning/csv_files/combined_data1.json', 'r') as json_file:
    json_data = json.load(json_file)
    train_data = json_data['train']
    val_data = json_data['val']

train_dataset = CustomDataset(train_data, transform=train_transforms)
val_dataset = CustomDataset(val_data, transform=val_transforms)

# classweight
classweight = get_classweight(train_dataset)
print('training class weight', classweight)


# # print images
# show_image(train_dataset, 5)

# calculate numbers
print("train")
print('-----------------------------------')
train_NFF_count = sum(1 for _, label in train_dataset if label == 0)  # 0 NFF
train_AFF_count = sum(1 for _, label in train_dataset if label == 1)  # 1 AFF

print(f"train AFF: {train_AFF_count}, ratio: {train_AFF_count / (train_AFF_count + train_NFF_count):.2f}")
print(f"----- NFF: {train_NFF_count}, ratio: {train_NFF_count / (train_AFF_count + train_NFF_count):.2f}")

print("val")
print('-----------------------------------')
train_NFF_count = sum(1 for _, label in val_dataset if label == 0)  # 0 NFF
train_AFF_count = sum(1 for _, label in val_dataset if label == 1)  # 1 AFF

print(f"train AFF: {train_AFF_count}, ratio: {train_AFF_count / (train_AFF_count + train_NFF_count):.2f}")
print(f"----- NFF: {train_NFF_count}, ratio: {train_NFF_count / (train_AFF_count + train_NFF_count):.2f}")
# Out:
# training class weight [0.6863799283154122, 1.8413461538461537]
# train
# -----------------------------------
# train AFF: 104, ratio: 0.27
# ----- NFF: 279, ratio: 0.73
# val
# -----------------------------------
# train AFF: 42, ratio: 0.25
# ----- NFF: 126, ratio: 0.75

# %%
# custom dataset on csv files
class CustomCsvDataset(Dataset):
    def __init__(self, csv_file, transform=None):
        self.data = []
        self.labels = []  # Store labels separately
        self.patient_ids = []  # Store patient IDs separately
        self.hospital_ids = []  # Store hospital IDs separately
        self.transform = transform
        
        # read csv
        with open(csv_file, 'r') as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                image_path = row['ImagePath']
                label = row['Label']
                patient_id = row['PatientID']
                hospital_id = row['HospitalID']

                if label == 'NFF':
                    label = 0
                elif label == 'AFF':
                    label = 1
                else:
                    raise ValueError("Invalid label in CSV file.")
                self.data.append((image_path, label))
                self.labels.append(label)
                self.patient_ids.append(patient_id)
                self.hospital_ids.append(int(hospital_id))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image_path, label = self.data[idx]
        image = Image.open(image_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image, label

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import DataLoader
from sklearn.model_selection import StratifiedKFold
from torch.utils.data import DataLoader
from sklearn.metrics import roc_auc_score, confusion_matrix, classification_report

# ------------------------------------------------------------------------------------------------------
def train_custom_model(model, train_dataset, val_dataset, num_epochs, batch_size, optimizer=None):
    classweight = get_classweight(train_dataset) # get_classweight is a function defined above
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    
    model = model.to(device)
    criterion = nn.CrossEntropyLoss(weight=torch.Tensor(classweight).to(device))
    
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    for epoch in range(num_epochs):
        model.train()
        correct_train = 0
        total_train = 0

        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()

        train_accuracy = 100 * correct_train / total_train

        model.eval()
        correct_validation = 0
        total_validation = 0
        validation_loss = 0

        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                _, predicted = torch.max(outputs.data, 1)
                total_validation += labels.size(0)
                correct_validation += (predicted == labels).sum().item()
                validation_loss += loss.item()

        validation_accuracy = 100 * correct_validation / total_validation
        validation_loss /= len(val_loader)

        print(f"Epoch {epoch+1}/{num_epochs}, "
              f"Train ACC: {train_accuracy:.2f}%, "
              f"Validation ACC: {validation_accuracy:.2f}%")
    
    return model

# ------------------------------------------------------------------------------------------------------
def test_model(model, test_dataset, batch_size):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)
    model = model.to(device)

    model.eval()

    correct_test_nff = 0
    correct_test_aff = 0
    total_nff = 0
    total_aff = 0
    total_test = 0
    test_loss = 0

    criterion = nn.CrossEntropyLoss()

    with torch.no_grad():
        all_predictions = []
        all_labels = []
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            _, predicted = torch.max(outputs.data, 1)
            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            total_test += labels.size(0)
            total_nff += (labels == 0).sum().item()
            total_aff += (labels == 1).sum().item()
            correct_test_nff += ((predicted == labels) & (labels == 0)).sum().item()
            correct_test_aff += ((predicted == labels) & (labels == 1)).sum().item()
            test_loss += loss.item()

    # Check if total_aff is zero before performing the division
    test_accuracy_nff = 100 * (correct_test_nff / total_nff) if total_nff != 0 else 0
    test_accuracy_aff = 100 * (correct_test_aff / total_aff) if total_aff != 0 else 0
    test_accuracy_total = 100 * (correct_test_nff + correct_test_aff) / total_test
    test_loss /= len(test_loader)

    # Handle the case where there is only one class
    if len(set(all_labels)) > 1:
        auc_score = roc_auc_score(all_labels, all_predictions)
    else:
        auc_score = 0  # Default value if only one class is present

    conf_matrix = confusion_matrix(all_labels, all_predictions)

    # Directly use class labels as strings in target_names
    target_names = ['NFF', 'AFF']

    classification_rep = classification_report(all_labels, all_predictions, target_names=target_names, labels=[0, 1], zero_division=1)

    # Store metrics in a dictionary
    metrics = {
        "Test Loss": test_loss,
        "Total Test Accuracy": test_accuracy_total,
        "Test Accuracy (NFF)": test_accuracy_nff,
        "Test Accuracy (AFF)": test_accuracy_aff,
        "AUC": auc_score,
        "Confusion Matrix": conf_matrix,
        "Classification Report": classification_rep
    }
    return metrics

# %% [markdown]
# # VGG 19

# %%
from torchvision.models import vgg19, VGG19_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the VGG-19 model
model = models.vgg19(weights=VGG19_Weights.DEFAULT)

# Modify the classifier part of the model
num_features = model.classifier[6].in_features
model.classifier[6] = nn.Linear(num_features, 2)

# layer number
total_layers = len(list(model.features.children()))

# freeze 50% layer
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.features.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False
# ---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 20
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

v19 = train_custom_model(model, train_dataset, val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/20, Train ACC: 54.57%, Validation ACC: 51.79%
# Epoch 2/20, Train ACC: 62.14%, Validation ACC: 50.00%
# Epoch 3/20, Train ACC: 59.01%, Validation ACC: 61.31%
# Epoch 4/20, Train ACC: 74.15%, Validation ACC: 47.62%
# Epoch 5/20, Train ACC: 71.54%, Validation ACC: 35.71%
# Epoch 6/20, Train ACC: 72.58%, Validation ACC: 72.02%
# Epoch 7/20, Train ACC: 74.41%, Validation ACC: 72.62%
# Epoch 8/20, Train ACC: 81.98%, Validation ACC: 60.71%
# Epoch 9/20, Train ACC: 82.25%, Validation ACC: 66.07%
# Epoch 10/20, Train ACC: 83.03%, Validation ACC: 55.36%
# Epoch 11/20, Train ACC: 84.33%, Validation ACC: 69.64%
# Epoch 12/20, Train ACC: 89.03%, Validation ACC: 75.60%
# Epoch 13/20, Train ACC: 83.29%, Validation ACC: 85.71%
# Epoch 14/20, Train ACC: 84.07%, Validation ACC: 80.36%
# Epoch 15/20, Train ACC: 91.12%, Validation ACC: 72.62%
# Epoch 16/20, Train ACC: 91.38%, Validation ACC: 69.64%
# Epoch 17/20, Train ACC: 90.34%, Validation ACC: 79.76%
# Epoch 18/20, Train ACC: 90.08%, Validation ACC: 80.36%
# Epoch 19/20, Train ACC: 90.86%, Validation ACC: 73.81%
# Epoch 20/20, Train ACC: 92.43%, Validation ACC: 76.79%

# %%
model = v19
model.eval()
# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomCsvDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(10, 5))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
torch.cuda.empty_cache()
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.5008286237716675
# Total Test Accuracy: 73.91304347826087
# Test Accuracy (NFF): 73.91304347826086
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[17  6]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.74      0.85        23
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.74        23
#    macro avg       0.50      0.87      0.42        23
# weighted avg       1.00      0.74      0.85        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 0.0054484461434185505
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         0
#          AFF       1.00      1.00      1.00         3
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.44768384099006653
# Total Test Accuracy: 77.14285714285714
# Test Accuracy (NFF): 78.26086956521739
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[18  5]
#  [ 3  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.86      0.78      0.82        23
#          AFF       0.64      0.75      0.69        12
#
#     accuracy                           0.77        35
#    macro avg       0.75      0.77      0.76        35
# weighted avg       0.78      0.77      0.78        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.1589658111333847
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         2
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.2609013095498085
# Total Test Accuracy: 89.23076923076923
# Test Accuracy (NFF): 90.0
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[54  6]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.90      0.94        60
#          AFF       0.40      0.80      0.53         5
#
#     accuracy                           0.89        65
#    macro avg       0.69      0.85      0.74        65
# weighted avg       0.94      0.89      0.91        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.5574536323547363
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 63.888888888888886
# Test Accuracy (AFF): 95.0
# Confusion Matrix:
#  [[23 13]
#  [ 1 19]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.64      0.77        36
#          AFF       0.59      0.95      0.73        20
#
#     accuracy                           0.75        56
#    macro avg       0.78      0.79      0.75        56
# weighted avg       0.83      0.75      0.75        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.1401958167552948
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.5375533998012543
# Total Test Accuracy: 82.52427184466019
# Test Accuracy (NFF): 86.25
# Test Accuracy (AFF): 69.56521739130434
# Confusion Matrix:
#  [[69 11]
#  [ 7 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.86      0.88        80
#          AFF       0.59      0.70      0.64        23
#
#     accuracy                           0.83       103
#    macro avg       0.75      0.78      0.76       103
# weighted avg       0.84      0.83      0.83       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.25514182448387146
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 0.3443460613489151
# Total Test Accuracy: 86.95652173913044
# Test Accuracy (NFF): 88.67924528301887
# Test Accuracy (AFF): 81.25
# Confusion Matrix:
#  [[47  6]
#  [ 3 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.89      0.91        53
#          AFF       0.68      0.81      0.74        16
#
#     accuracy                           0.87        69
#    macro avg       0.81      0.85      0.83        69
# weighted avg       0.88      0.87      0.87        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.2924897437915206
# Total Test Accuracy: 80.51948051948052
# Test Accuracy (NFF): 82.8125
# Test Accuracy (AFF): 69.23076923076923
# Confusion Matrix:
#  [[53 11]
#  [ 4  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.83      0.88        64
#          AFF       0.45      0.69      0.55        13
#
#     accuracy                           0.81        77
#    macro avg       0.69      0.76      0.71        77
# weighted avg       0.85      0.81      0.82        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.44165651500225067
# Total Test Accuracy: 77.77777777777777
# Test Accuracy (NFF): 77.87610619469027
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[88 25]
#  [ 1  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.78      0.87       113
#          AFF       0.11      0.75      0.19         4
#
#     accuracy                           0.78       117
#    macro avg       0.55      0.76      0.53       117
# weighted avg       0.96      0.78      0.85       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.3258597254753113
# Total Test Accuracy: 84.44444444444444
# Test Accuracy (NFF): 86.04651162790698
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[37  6]
#  [ 1  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.86      0.91        43
#          AFF       0.14      0.50      0.22         2
#
#     accuracy                           0.84        45
#    macro avg       0.56      0.68      0.57        45
# weighted avg       0.94      0.84      0.88        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.3265361189842224
# Total Test Accuracy: 85.71428571428571
# Test Accuracy (NFF): 85.71428571428571
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[18  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.86      0.92        21
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.86        21
#    macro avg       0.50      0.93      0.46        21
# weighted avg       1.00      0.86      0.92        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 1.4014896154403687
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         3
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.22684292495250702
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 75.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.75      0.86         4
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.75         4
#    macro avg       0.50      0.88      0.43         4
# weighted avg       1.00      0.75      0.86         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 0.6040399968624115
# Total Test Accuracy: 70.4225352112676
# Test Accuracy (NFF): 75.51020408163265
# Test Accuracy (AFF): 59.09090909090909
# Confusion Matrix:
#  [[37 12]
#  [ 9 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.80      0.76      0.78        49
#          AFF       0.52      0.59      0.55        22
#
#     accuracy                           0.70        71
#    macro avg       0.66      0.67      0.67        71
# weighted avg       0.72      0.70      0.71        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.26175928115844727
# Total Test Accuracy: 90.47619047619048
# Test Accuracy (NFF): 90.36144578313254
# Test Accuracy (AFF): 90.69767441860465
# Confusion Matrix:
#  [[75  8]
#  [ 4 39]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.90      0.93        83
#          AFF       0.83      0.91      0.87        43
#
#     accuracy                           0.90       126
#    macro avg       0.89      0.91      0.90       126
# weighted avg       0.91      0.90      0.91       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.27207690477371216
# Total Test Accuracy: 91.11111111111111
# Test Accuracy (NFF): 92.5
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[37  3]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.93      0.95        40
#          AFF       0.57      0.80      0.67         5
#
#     accuracy                           0.91        45
#    macro avg       0.77      0.86      0.81        45
# weighted avg       0.93      0.91      0.92        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.388616144657135
# Total Test Accuracy: 77.77777777777777
# Test Accuracy (NFF): 75.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[6 2]
#  [0 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.75      0.86         8
#          AFF       0.33      1.00      0.50         1
#
#     accuracy                           0.78         9
#    macro avg       0.67      0.88      0.68         9
# weighted avg       0.93      0.78      0.82         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.5329830795526505
# Total Test Accuracy: 80.67226890756302
# Test Accuracy (NFF): 81.17647058823529
# Test Accuracy (AFF): 79.41176470588235
# Confusion Matrix:
#  [[69 16]
#  [ 7 27]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.81      0.86        85
#          AFF       0.63      0.79      0.70        34
#
#     accuracy                           0.81       119
#    macro avg       0.77      0.80      0.78       119
# weighted avg       0.83      0.81      0.81       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 0.4525349736213684
# Total Test Accuracy: 80.41237113402062
# Test Accuracy (NFF): 75.47169811320755
# Test Accuracy (AFF): 86.36363636363636
# Confusion Matrix:
#  [[40 13]
#  [ 6 38]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.75      0.81        53
#          AFF       0.75      0.86      0.80        44
#
#     accuracy                           0.80        97
#    macro avg       0.81      0.81      0.80        97
# weighted avg       0.81      0.80      0.80        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.10280991345643997
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.772065281867981
# Total Test Accuracy: 62.637362637362635
# Test Accuracy (NFF): 59.74025974025974
# Test Accuracy (AFF): 78.57142857142857
# Confusion Matrix:
#  [[46 31]
#  [ 3 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.60      0.73        77
#          AFF       0.26      0.79      0.39        14
#
#     accuracy                           0.63        91
#    macro avg       0.60      0.69      0.56        91
# weighted avg       0.83      0.63      0.68        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 0.47246789932250977
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 80.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[12  3]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.80      0.89        15
#          AFF       0.50      1.00      0.67         3
#
#     accuracy                           0.83        18
#    macro avg       0.75      0.90      0.78        18
# weighted avg       0.92      0.83      0.85        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.6015992164611816
# Total Test Accuracy: 80.76923076923077
# Test Accuracy (NFF): 83.33333333333334
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[15  3]
#  [ 2  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.83      0.86        18
#          AFF       0.67      0.75      0.71         8
#
#     accuracy                           0.81        26
#    macro avg       0.77      0.79      0.78        26
# weighted avg       0.82      0.81      0.81        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.08338675647974014
# Total Test Accuracy: 94.44444444444444
# Test Accuracy (NFF): 94.11764705882352
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[16  1]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.94      0.97        17
#          AFF       0.50      1.00      0.67         1
#
#     accuracy                           0.94        18
#    macro avg       0.75      0.97      0.82        18
# weighted avg       0.97      0.94      0.95        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.5108563601970673
# Total Test Accuracy: 77.41935483870968
# Test Accuracy (NFF): 73.41772151898735
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[58 21]
#  [ 0 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.73      0.85        79
#          AFF       0.40      1.00      0.57        14
#
#     accuracy                           0.77        93
#    macro avg       0.70      0.87      0.71        93
# weighted avg       0.91      0.77      0.81        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 0.790695071220398
# Total Test Accuracy: 81.25
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 57.14285714285714
# Confusion Matrix:
#  [[9 0]
#  [3 4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.75      1.00      0.86         9
#          AFF       1.00      0.57      0.73         7
#
#     accuracy                           0.81        16
#    macro avg       0.88      0.79      0.79        16
# weighted avg       0.86      0.81      0.80        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 0.9671416282653809
# Total Test Accuracy: 50.0
# Test Accuracy (NFF): 50.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3 3]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.50      0.67         6
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.50         6
#    macro avg       0.50      0.75      0.33         6
# weighted avg       1.00      0.50      0.67         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 0.46586596965789795
# Total Test Accuracy: 76.19047619047619
# Test Accuracy (NFF): 73.13432835820896
# Test Accuracy (AFF): 88.23529411764706
# Confusion Matrix:
#  [[49 18]
#  [ 2 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.73      0.83        67
#          AFF       0.45      0.88      0.60        17
#
#     accuracy                           0.76        84
#    macro avg       0.71      0.81      0.72        84
# weighted avg       0.86      0.76      0.78        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.228895366191864
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.5467646519343058
# Total Test Accuracy: 73.64864864864865
# Test Accuracy (NFF): 73.80952380952381
# Test Accuracy (AFF): 72.72727272727273
# Confusion Matrix:
#  [[93 33]
#  [ 6 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.74      0.83       126
#          AFF       0.33      0.73      0.45        22
#
#     accuracy                           0.74       148
#    macro avg       0.63      0.73      0.64       148
# weighted avg       0.85      0.74      0.77       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.16496016085147858
# Total Test Accuracy: 91.17647058823529
# Test Accuracy (NFF): 91.17647058823529
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[31  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.91      0.95        34
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.91        34
#    macro avg       0.50      0.96      0.48        34
# weighted avg       1.00      0.91      0.95        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.16018593311309814
# Total Test Accuracy: 94.11764705882354
# Test Accuracy (NFF): 92.85714285714286
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[13  1]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.93      0.96        14
#          AFF       0.75      1.00      0.86         3
#
#     accuracy                           0.94        17
#    macro avg       0.88      0.96      0.91        17
# weighted avg       0.96      0.94      0.94        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.33209431916475296
# Total Test Accuracy: 83.72093023255815
# Test Accuracy (NFF): 82.35294117647058
# Test Accuracy (AFF): 88.88888888888889
# Confusion Matrix:
#  [[56 12]
#  [ 2 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.82      0.89        68
#          AFF       0.57      0.89      0.70        18
#
#     accuracy                           0.84        86
#    macro avg       0.77      0.86      0.79        86
# weighted avg       0.88      0.84      0.85        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.9261809587478638
# Total Test Accuracy: 64.0
# Test Accuracy (NFF): 64.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[16  9]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.64      0.78        25
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.64        25
#    macro avg       0.50      0.82      0.39        25
# weighted avg       1.00      0.64      0.78        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.9281431436538696
# Total Test Accuracy: 65.51724137931035
# Test Accuracy (NFF): 60.86956521739131
# Test Accuracy (AFF): 83.33333333333334
# Confusion Matrix:
#  [[14  9]
#  [ 1  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.61      0.74        23
#          AFF       0.36      0.83      0.50         6
#
#     accuracy                           0.66        29
#    macro avg       0.65      0.72      0.62        29
# weighted avg       0.81      0.66      0.69        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.3983685187995434
# Total Test Accuracy: 76.0
# Test Accuracy (NFF): 78.57142857142857
# Test Accuracy (AFF): 40.0
# Confusion Matrix:
#  [[55 15]
#  [ 3  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.79      0.86        70
#          AFF       0.12      0.40      0.18         5
#
#     accuracy                           0.76        75
#    macro avg       0.53      0.59      0.52        75
# weighted avg       0.89      0.76      0.81        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 0.06167365983128548
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 0.9709151983261108
# Total Test Accuracy: 60.0
# Test Accuracy (NFF): 60.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9 6]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.60      0.75        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.60        15
#    macro avg       0.50      0.80      0.37        15
# weighted avg       1.00      0.60      0.75        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.42017005383968353
# Total Test Accuracy: 84.48979591836735
# Test Accuracy (NFF): 77.64705882352942
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[132  38]
#  [  0  75]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.78      0.87       170
#          AFF       0.66      1.00      0.80        75
#
#     accuracy                           0.84       245
#    macro avg       0.83      0.89      0.84       245
# weighted avg       0.90      0.84      0.85       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.6834757328033447
# Total Test Accuracy: 80.64516129032258
# Test Accuracy (NFF): 76.92307692307693
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[20  6]
#  [ 0  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.77      0.87        26
#          AFF       0.45      1.00      0.62         5
#
#     accuracy                           0.81        31
#    macro avg       0.73      0.88      0.75        31
# weighted avg       0.91      0.81      0.83        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.7740421295166016
# Total Test Accuracy: 71.90082644628099
# Test Accuracy (NFF): 65.9090909090909
# Test Accuracy (AFF): 87.87878787878788
# Confusion Matrix:
#  [[58 30]
#  [ 4 29]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.66      0.77        88
#          AFF       0.49      0.88      0.63        33
#
#     accuracy                           0.72       121
#    macro avg       0.71      0.77      0.70       121
# weighted avg       0.81      0.72      0.73       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.7179090976715088
# Total Test Accuracy: 59.09090909090909
# Test Accuracy (NFF): 59.09090909090909
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[13  9]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.59      0.74        22
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.59        22
#    macro avg       0.50      0.80      0.37        22
# weighted avg       1.00      0.59      0.74        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.3732377737760544
# Total Test Accuracy: 86.73469387755102
# Test Accuracy (NFF): 87.17948717948718
# Test Accuracy (AFF): 85.0
# Confusion Matrix:
#  [[68 10]
#  [ 3 17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.87      0.91        78
#          AFF       0.63      0.85      0.72        20
#
#     accuracy                           0.87        98
#    macro avg       0.79      0.86      0.82        98
# weighted avg       0.89      0.87      0.87        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.6526435315608978
# Total Test Accuracy: 64.78873239436619
# Test Accuracy (NFF): 64.0625
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[41 23]
#  [ 2  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.64      0.77        64
#          AFF       0.18      0.71      0.29         7
#
#     accuracy                           0.65        71
#    macro avg       0.57      0.68      0.53        71
# weighted avg       0.88      0.65      0.72        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.7173329591751099
# Total Test Accuracy: 63.1578947368421
# Test Accuracy (NFF): 63.1578947368421
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[36 21]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.63      0.77        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.63        57
#    macro avg       0.50      0.82      0.39        57
# weighted avg       1.00      0.63      0.77        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.39106088876724243
# Total Test Accuracy: 83.49514563106796
# Test Accuracy (NFF): 85.52631578947368
# Test Accuracy (AFF): 77.77777777777779
# Confusion Matrix:
#  [[65 11]
#  [ 6 21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.86      0.88        76
#          AFF       0.66      0.78      0.71        27
#
#     accuracy                           0.83       103
#    macro avg       0.79      0.82      0.80       103
# weighted avg       0.85      0.83      0.84       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.2472660094499588
# Total Test Accuracy: 89.87341772151899
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[64  8]
#  [ 0  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.89      0.94        72
#          AFF       0.47      1.00      0.64         7
#
#     accuracy                           0.90        79
#    macro avg       0.73      0.94      0.79        79
# weighted avg       0.95      0.90      0.91        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.016223685815930367
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[24  0]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        24
#          AFF       1.00      1.00      1.00         2
#
#     accuracy                           1.00        26
#    macro avg       1.00      1.00      1.00        26
# weighted avg       1.00      1.00      1.00        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 0.34175238013267517
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[3 0]
#  [3 6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.50      1.00      0.67         3
#          AFF       1.00      0.67      0.80         9
#
#     accuracy                           0.75        12
#    macro avg       0.75      0.83      0.73        12
# weighted avg       0.88      0.75      0.77        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.4368808368841807
# Total Test Accuracy: 87.31343283582089
# Test Accuracy (NFF): 88.67924528301887
# Test Accuracy (AFF): 82.14285714285714
# Confusion Matrix:
#  [[94 12]
#  [ 5 23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.89      0.92       106
#          AFF       0.66      0.82      0.73        28
#
#     accuracy                           0.87       134
#    macro avg       0.80      0.85      0.82       134
# weighted avg       0.89      0.87      0.88       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.28280848264694214
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 91.44736842105263
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[139  13]
#  [  7  21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.91      0.93       152
#          AFF       0.62      0.75      0.68        28
#
#     accuracy                           0.89       180
#    macro avg       0.78      0.83      0.81       180
# weighted avg       0.90      0.89      0.89       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.7137211561203003
# Total Test Accuracy: 67.5
# Test Accuracy (NFF): 62.96296296296296
# Test Accuracy (AFF): 76.92307692307693
# Confusion Matrix:
#  [[17 10]
#  [ 3 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.63      0.72        27
#          AFF       0.50      0.77      0.61        13
#
#     accuracy                           0.68        40
#    macro avg       0.68      0.70      0.66        40
# weighted avg       0.74      0.68      0.69        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 2.8535501956939697
# Total Test Accuracy: 0.0
# Test Accuracy (NFF): 0.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[0 3]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.00      0.00       3.0
#          AFF       0.00      1.00      0.00       0.0
#
#     accuracy                           1.00       3.0
#    macro avg       0.50      0.50      0.00       3.0
# weighted avg       1.00      0.00      0.00       3.0
#
#
# Performance for Hospital 58:
#
# Test Loss: 0.49662554264068604
# Total Test Accuracy: 89.47368421052632
# Test Accuracy (NFF): 82.75862068965517
# Test Accuracy (AFF): 96.42857142857143
# Confusion Matrix:
#  [[24  5]
#  [ 1 27]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.83      0.89        29
#          AFF       0.84      0.96      0.90        28
#
#     accuracy                           0.89        57
#    macro avg       0.90      0.90      0.89        57
# weighted avg       0.90      0.89      0.89        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.21076899766921997
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.89      0.94         9
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.89         9
#    macro avg       0.50      0.94      0.47         9
# weighted avg       1.00      0.89      0.94         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.7232104241847992
# Total Test Accuracy: 70.73170731707317
# Test Accuracy (NFF): 70.0
# Test Accuracy (AFF): 73.91304347826086
# Confusion Matrix:
#  [[70 30]
#  [ 6 17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.70      0.80       100
#          AFF       0.36      0.74      0.49        23
#
#     accuracy                           0.71       123
#    macro avg       0.64      0.72      0.64       123
# weighted avg       0.82      0.71      0.74       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.7049606442451477
# Total Test Accuracy: 74.60317460317461
# Test Accuracy (NFF): 73.91304347826086
# Test Accuracy (AFF): 76.47058823529412
# Confusion Matrix:
#  [[34 12]
#  [ 4 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.74      0.81        46
#          AFF       0.52      0.76      0.62        17
#
#     accuracy                           0.75        63
#    macro avg       0.71      0.75      0.71        63
# weighted avg       0.79      0.75      0.76        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 0.5430548191070557
# Total Test Accuracy: 81.13207547169812
# Test Accuracy (NFF): 82.92682926829268
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[34  7]
#  [ 3  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.83      0.87        41
#          AFF       0.56      0.75      0.64        12
#
#     accuracy                           0.81        53
#    macro avg       0.74      0.79      0.76        53
# weighted avg       0.84      0.81      0.82        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 0.5000444054603577
# Total Test Accuracy: 87.5
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[7 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.93         8
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.88         8
#    macro avg       0.50      0.94      0.47         8
# weighted avg       1.00      0.88      0.93         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.48324793577194214
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 75.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[24  8]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.75      0.86        32
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.75        32
#    macro avg       0.50      0.88      0.43        32
# weighted avg       1.00      0.75      0.86        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.7408425807952881
# Total Test Accuracy: 90.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[8 0]
#  [1 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      1.00      0.94         8
#          AFF       1.00      0.50      0.67         2
#
#     accuracy                           0.90        10
#    macro avg       0.94      0.75      0.80        10
# weighted avg       0.91      0.90      0.89        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.5751209855079651
# Total Test Accuracy: 63.63636363636363
# Test Accuracy (NFF): 64.70588235294117
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[11  6]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.65      0.73        17
#          AFF       0.33      0.60      0.43         5
#
#     accuracy                           0.64        22
#    macro avg       0.59      0.62      0.58        22
# weighted avg       0.73      0.64      0.66        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.291437029838562
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 89.65517241379311
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[26  3]
#  [ 1  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.90      0.93        29
#          AFF       0.67      0.86      0.75         7
#
#     accuracy                           0.89        36
#    macro avg       0.81      0.88      0.84        36
# weighted avg       0.91      0.89      0.89        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.5009217514441564
# Total Test Accuracy: 80.41871921182266
# Test Accuracy (NFF): 79.60426179604262
# Test Accuracy (AFF): 83.87096774193549
# Confusion Matrix:
#  [[523 134]
#  [ 25 130]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.80      0.87       657
#          AFF       0.49      0.84      0.62       155
#
#     accuracy                           0.80       812
#    macro avg       0.72      0.82      0.74       812
# weighted avg       0.87      0.80      0.82       812
#
#
# Average Total Test Accuracy: 79.89761066205624

# %% [markdown]
# # ResNet50

# %%
from torchvision.models import resnet50, ResNet50_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the ResNet-101 model
model = models.resnet50(weights=ResNet50_Weights.DEFAULT)

num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)

# layer number
total_layers = len(list(model.children()))

# freeze 50% layer
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False

# modify full connection layer
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)

# ---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 20
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

res50 = train_custom_model(model, train_dataset, val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/20, Train ACC: 49.87%, Validation ACC: 76.19%
# Epoch 2/20, Train ACC: 64.75%, Validation ACC: 73.21%
# Epoch 3/20, Train ACC: 70.76%, Validation ACC: 72.62%
# Epoch 4/20, Train ACC: 72.58%, Validation ACC: 73.21%
# Epoch 5/20, Train ACC: 72.85%, Validation ACC: 64.29%
# Epoch 6/20, Train ACC: 76.24%, Validation ACC: 69.64%
# Epoch 7/20, Train ACC: 79.11%, Validation ACC: 79.17%
# Epoch 8/20, Train ACC: 85.64%, Validation ACC: 77.38%
# Epoch 9/20, Train ACC: 85.64%, Validation ACC: 79.76%
# Epoch 10/20, Train ACC: 87.73%, Validation ACC: 77.38%
# Epoch 11/20, Train ACC: 89.56%, Validation ACC: 80.36%
# Epoch 12/20, Train ACC: 91.64%, Validation ACC: 80.36%
# Epoch 13/20, Train ACC: 92.69%, Validation ACC: 77.98%
# Epoch 14/20, Train ACC: 91.64%, Validation ACC: 81.55%
# Epoch 15/20, Train ACC: 93.21%, Validation ACC: 77.38%
# Epoch 16/20, Train ACC: 94.26%, Validation ACC: 81.55%
# Epoch 17/20, Train ACC: 96.87%, Validation ACC: 82.74%
# Epoch 18/20, Train ACC: 96.08%, Validation ACC: 83.33%
# Epoch 19/20, Train ACC: 95.56%, Validation ACC: 82.14%
# Epoch 20/20, Train ACC: 96.34%, Validation ACC: 85.71%

# %%
model = res50
model.eval()
# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomCsvDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(10, 5))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
torch.cuda.empty_cache()
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.0997239276766777
# Total Test Accuracy: 95.65217391304348
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[22  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        23
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.96        23
#    macro avg       0.50      0.98      0.49        23
# weighted avg       1.00      0.96      0.98        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 1.3982137441635132
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[0 0]
#  [1 2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.00      1.00      0.00         0
#          AFF       1.00      0.67      0.80         3
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.37445053458213806
# Total Test Accuracy: 82.85714285714286
# Test Accuracy (NFF): 91.30434782608695
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[21  2]
#  [ 4  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      0.91      0.87        23
#          AFF       0.80      0.67      0.73        12
#
#     accuracy                           0.83        35
#    macro avg       0.82      0.79      0.80        35
# weighted avg       0.83      0.83      0.82        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.44894132018089294
# Total Test Accuracy: 50.0
# Test Accuracy (NFF): 50.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[1 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.50      0.67         2
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.75      0.33         2
# weighted avg       1.00      0.50      0.67         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.1064520925283432
# Total Test Accuracy: 93.84615384615384
# Test Accuracy (NFF): 96.66666666666667
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[58  2]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.97      0.97        60
#          AFF       0.60      0.60      0.60         5
#
#     accuracy                           0.94        65
#    macro avg       0.78      0.78      0.78        65
# weighted avg       0.94      0.94      0.94        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.2949114739894867
# Total Test Accuracy: 89.28571428571429
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 90.0
# Confusion Matrix:
#  [[32  4]
#  [ 2 18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.89      0.91        36
#          AFF       0.82      0.90      0.86        20
#
#     accuracy                           0.89        56
#    macro avg       0.88      0.89      0.89        56
# weighted avg       0.90      0.89      0.89        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.057453226298093796
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.3898070752620697
# Total Test Accuracy: 86.40776699029126
# Test Accuracy (NFF): 93.75
# Test Accuracy (AFF): 60.86956521739131
# Confusion Matrix:
#  [[75  5]
#  [ 9 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.94      0.91        80
#          AFF       0.74      0.61      0.67        23
#
#     accuracy                           0.86       103
#    macro avg       0.81      0.77      0.79       103
# weighted avg       0.86      0.86      0.86       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.03314851224422455
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 0.17047591134905815
# Total Test Accuracy: 86.95652173913044
# Test Accuracy (NFF): 96.22641509433963
# Test Accuracy (AFF): 56.25
# Confusion Matrix:
#  [[51  2]
#  [ 7  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.96      0.92        53
#          AFF       0.82      0.56      0.67        16
#
#     accuracy                           0.87        69
#    macro avg       0.85      0.76      0.79        69
# weighted avg       0.87      0.87      0.86        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.13067387510091066
# Total Test Accuracy: 88.31168831168831
# Test Accuracy (NFF): 92.1875
# Test Accuracy (AFF): 69.23076923076923
# Confusion Matrix:
#  [[59  5]
#  [ 4  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.92      0.93        64
#          AFF       0.64      0.69      0.67        13
#
#     accuracy                           0.88        77
#    macro avg       0.79      0.81      0.80        77
# weighted avg       0.89      0.88      0.88        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.17029159516096115
# Total Test Accuracy: 93.16239316239316
# Test Accuracy (NFF): 93.80530973451327
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[106   7]
#  [  1   3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.94      0.96       113
#          AFF       0.30      0.75      0.43         4
#
#     accuracy                           0.93       117
#    macro avg       0.65      0.84      0.70       117
# weighted avg       0.97      0.93      0.95       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.15519171953201294
# Total Test Accuracy: 95.55555555555556
# Test Accuracy (NFF): 97.67441860465115
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[42  1]
#  [ 1  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.98      0.98        43
#          AFF       0.50      0.50      0.50         2
#
#     accuracy                           0.96        45
#    macro avg       0.74      0.74      0.74        45
# weighted avg       0.96      0.96      0.96        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.057647090405225754
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        21
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 0.14301897585391998
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.013878049328923225
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         4
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 0.5514736920595169
# Total Test Accuracy: 84.50704225352112
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[49  0]
#  [11 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.82      1.00      0.90        49
#          AFF       1.00      0.50      0.67        22
#
#     accuracy                           0.85        71
#    macro avg       0.91      0.75      0.78        71
# weighted avg       0.87      0.85      0.83        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.18203690275549889
# Total Test Accuracy: 92.85714285714286
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 79.06976744186046
# Confusion Matrix:
#  [[83  0]
#  [ 9 34]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      1.00      0.95        83
#          AFF       1.00      0.79      0.88        43
#
#     accuracy                           0.93       126
#    macro avg       0.95      0.90      0.92       126
# weighted avg       0.94      0.93      0.93       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.2268429845571518
# Total Test Accuracy: 93.33333333333333
# Test Accuracy (NFF): 97.5
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[39  1]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.97      0.96        40
#          AFF       0.75      0.60      0.67         5
#
#     accuracy                           0.93        45
#    macro avg       0.85      0.79      0.81        45
# weighted avg       0.93      0.93      0.93        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.08517292141914368
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[8 0]
#  [0 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         1
#
#     accuracy                           1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.5341088175773621
# Total Test Accuracy: 80.67226890756302
# Test Accuracy (NFF): 92.94117647058823
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[79  6]
#  [17 17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.82      0.93      0.87        85
#          AFF       0.74      0.50      0.60        34
#
#     accuracy                           0.81       119
#    macro avg       0.78      0.71      0.73       119
# weighted avg       0.80      0.81      0.79       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 0.7885884940624237
# Total Test Accuracy: 69.0721649484536
# Test Accuracy (NFF): 88.67924528301887
# Test Accuracy (AFF): 45.45454545454545
# Confusion Matrix:
#  [[47  6]
#  [24 20]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.66      0.89      0.76        53
#          AFF       0.77      0.45      0.57        44
#
#     accuracy                           0.69        97
#    macro avg       0.72      0.67      0.66        97
# weighted avg       0.71      0.69      0.67        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.005286423489451408
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.20343602448701859
# Total Test Accuracy: 94.50549450549451
# Test Accuracy (NFF): 98.7012987012987
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[76  1]
#  [ 4 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.99      0.97        77
#          AFF       0.91      0.71      0.80        14
#
#     accuracy                           0.95        91
#    macro avg       0.93      0.85      0.88        91
# weighted avg       0.94      0.95      0.94        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 0.3262224793434143
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 93.33333333333333
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[14  1]
#  [ 1  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.93      0.93        15
#          AFF       0.67      0.67      0.67         3
#
#     accuracy                           0.89        18
#    macro avg       0.80      0.80      0.80        18
# weighted avg       0.89      0.89      0.89        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.2660455107688904
# Total Test Accuracy: 88.46153846153847
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 62.5
# Confusion Matrix:
#  [[18  0]
#  [ 3  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.86      1.00      0.92        18
#          AFF       1.00      0.62      0.77         8
#
#     accuracy                           0.88        26
#    macro avg       0.93      0.81      0.85        26
# weighted avg       0.90      0.88      0.88        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.06755626946687698
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[17  0]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        17
#          AFF       1.00      1.00      1.00         1
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.18635742366313934
# Total Test Accuracy: 94.6236559139785
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 64.28571428571429
# Confusion Matrix:
#  [[79  0]
#  [ 5  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      1.00      0.97        79
#          AFF       1.00      0.64      0.78        14
#
#     accuracy                           0.95        93
#    macro avg       0.97      0.82      0.88        93
# weighted avg       0.95      0.95      0.94        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 0.6511433720588684
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 57.14285714285714
# Confusion Matrix:
#  [[8 1]
#  [3 4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.73      0.89      0.80         9
#          AFF       0.80      0.57      0.67         7
#
#     accuracy                           0.75        16
#    macro avg       0.76      0.73      0.73        16
# weighted avg       0.76      0.75      0.74        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 0.024718819186091423
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 0.16232063993811607
# Total Test Accuracy: 94.04761904761905
# Test Accuracy (NFF): 94.02985074626866
# Test Accuracy (AFF): 94.11764705882352
# Confusion Matrix:
#  [[63  4]
#  [ 1 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.94      0.96        67
#          AFF       0.80      0.94      0.86        17
#
#     accuracy                           0.94        84
#    macro avg       0.89      0.94      0.91        84
# weighted avg       0.95      0.94      0.94        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.018164556473493576
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.3585776786009471
# Total Test Accuracy: 86.48648648648648
# Test Accuracy (NFF): 92.85714285714286
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[117   9]
#  [ 11  11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.93      0.92       126
#          AFF       0.55      0.50      0.52        22
#
#     accuracy                           0.86       148
#    macro avg       0.73      0.71      0.72       148
# weighted avg       0.86      0.86      0.86       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.1354563683271408
# Total Test Accuracy: 97.05882352941177
# Test Accuracy (NFF): 97.05882352941177
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[33  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.97      0.99        34
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.97        34
#    macro avg       0.50      0.99      0.49        34
# weighted avg       1.00      0.97      0.99        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.06819726526737213
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[14  0]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        14
#          AFF       1.00      1.00      1.00         3
#
#     accuracy                           1.00        17
#    macro avg       1.00      1.00      1.00        17
# weighted avg       1.00      1.00      1.00        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.34908999502658844
# Total Test Accuracy: 83.72093023255815
# Test Accuracy (NFF): 86.76470588235294
# Test Accuracy (AFF): 72.22222222222221
# Confusion Matrix:
#  [[59  9]
#  [ 5 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.87      0.89        68
#          AFF       0.59      0.72      0.65        18
#
#     accuracy                           0.84        86
#    macro avg       0.76      0.79      0.77        86
# weighted avg       0.85      0.84      0.84        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.03107321821153164
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        25
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        25
#    macro avg       1.00      1.00      1.00        25
# weighted avg       1.00      1.00      1.00        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.26866769790649414
# Total Test Accuracy: 89.65517241379311
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[22  1]
#  [ 2  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.96      0.94        23
#          AFF       0.80      0.67      0.73         6
#
#     accuracy                           0.90        29
#    macro avg       0.86      0.81      0.83        29
# weighted avg       0.89      0.90      0.89        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.2686589490622282
# Total Test Accuracy: 86.66666666666667
# Test Accuracy (NFF): 92.85714285714286
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[65  5]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.93      0.93        70
#          AFF       0.00      0.00      1.00         5
#
#     accuracy                           0.87        75
#    macro avg       0.46      0.46      0.96        75
# weighted avg       0.87      0.87      0.93        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 0.0074019655585289
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 0.26534709334373474
# Total Test Accuracy: 93.33333333333333
# Test Accuracy (NFF): 93.33333333333333
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[14  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.93      0.97        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.93        15
#    macro avg       0.50      0.97      0.48        15
# weighted avg       1.00      0.93      0.97        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.1335185607895255
# Total Test Accuracy: 95.91836734693878
# Test Accuracy (NFF): 95.29411764705881
# Test Accuracy (AFF): 97.33333333333334
# Confusion Matrix:
#  [[162   8]
#  [  2  73]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.95      0.97       170
#          AFF       0.90      0.97      0.94        75
#
#     accuracy                           0.96       245
#    macro avg       0.94      0.96      0.95       245
# weighted avg       0.96      0.96      0.96       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.22840145230293274
# Total Test Accuracy: 90.3225806451613
# Test Accuracy (NFF): 92.3076923076923
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[24  2]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.92      0.94        26
#          AFF       0.67      0.80      0.73         5
#
#     accuracy                           0.90        31
#    macro avg       0.81      0.86      0.83        31
# weighted avg       0.91      0.90      0.91        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.33516454696655273
# Total Test Accuracy: 87.60330578512396
# Test Accuracy (NFF): 93.18181818181817
# Test Accuracy (AFF): 72.72727272727273
# Confusion Matrix:
#  [[82  6]
#  [ 9 24]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.93      0.92        88
#          AFF       0.80      0.73      0.76        33
#
#     accuracy                           0.88       121
#    macro avg       0.85      0.83      0.84       121
# weighted avg       0.87      0.88      0.87       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.1910984367132187
# Total Test Accuracy: 90.9090909090909
# Test Accuracy (NFF): 90.9090909090909
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[20  2]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.91      0.95        22
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.91        22
#    macro avg       0.50      0.95      0.48        22
# weighted avg       1.00      0.91      0.95        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.3847573548555374
# Total Test Accuracy: 82.65306122448979
# Test Accuracy (NFF): 87.17948717948718
# Test Accuracy (AFF): 65.0
# Confusion Matrix:
#  [[68 10]
#  [ 7 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.87      0.89        78
#          AFF       0.57      0.65      0.60        20
#
#     accuracy                           0.83        98
#    macro avg       0.74      0.76      0.75        98
# weighted avg       0.84      0.83      0.83        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.2558571547269821
# Total Test Accuracy: 90.14084507042253
# Test Accuracy (NFF): 90.625
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[58  6]
#  [ 1  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.91      0.94        64
#          AFF       0.50      0.86      0.63         7
#
#     accuracy                           0.90        71
#    macro avg       0.74      0.88      0.79        71
# weighted avg       0.94      0.90      0.91        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.2512023448944092
# Total Test Accuracy: 91.2280701754386
# Test Accuracy (NFF): 91.22807017543859
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[52  5]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.91      0.95        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.91        57
#    macro avg       0.50      0.96      0.48        57
# weighted avg       1.00      0.91      0.95        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.36954692006111145
# Total Test Accuracy: 85.4368932038835
# Test Accuracy (NFF): 96.05263157894737
# Test Accuracy (AFF): 55.55555555555556
# Confusion Matrix:
#  [[73  3]
#  [12 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.86      0.96      0.91        76
#          AFF       0.83      0.56      0.67        27
#
#     accuracy                           0.85       103
#    macro avg       0.85      0.76      0.79       103
# weighted avg       0.85      0.85      0.84       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.08813386131078005
# Total Test Accuracy: 92.40506329113924
# Test Accuracy (NFF): 97.22222222222221
# Test Accuracy (AFF): 42.857142857142854
# Confusion Matrix:
#  [[70  2]
#  [ 4  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.97      0.96        72
#          AFF       0.60      0.43      0.50         7
#
#     accuracy                           0.92        79
#    macro avg       0.77      0.70      0.73        79
# weighted avg       0.92      0.92      0.92        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.15987633168697357
# Total Test Accuracy: 92.3076923076923
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[24  0]
#  [ 2  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      1.00      0.96        24
#          AFF       1.00      0.00      0.00         2
#
#     accuracy                           0.92        26
#    macro avg       0.96      0.50      0.48        26
# weighted avg       0.93      0.92      0.89        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 0.4824241101741791
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 77.77777777777779
# Confusion Matrix:
#  [[3 0]
#  [2 7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.60      1.00      0.75         3
#          AFF       1.00      0.78      0.88         9
#
#     accuracy                           0.83        12
#    macro avg       0.80      0.89      0.81        12
# weighted avg       0.90      0.83      0.84        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.24050024151802063
# Total Test Accuracy: 84.32835820895522
# Test Accuracy (NFF): 92.45283018867924
# Test Accuracy (AFF): 53.57142857142857
# Confusion Matrix:
#  [[98  8]
#  [13 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.92      0.90       106
#          AFF       0.65      0.54      0.59        28
#
#     accuracy                           0.84       134
#    macro avg       0.77      0.73      0.75       134
# weighted avg       0.83      0.84      0.84       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.23689625412225723
# Total Test Accuracy: 92.22222222222223
# Test Accuracy (NFF): 98.02631578947368
# Test Accuracy (AFF): 60.71428571428571
# Confusion Matrix:
#  [[149   3]
#  [ 11  17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.98      0.96       152
#          AFF       0.85      0.61      0.71        28
#
#     accuracy                           0.92       180
#    macro avg       0.89      0.79      0.83       180
# weighted avg       0.92      0.92      0.92       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.7836118340492249
# Total Test Accuracy: 77.5
# Test Accuracy (NFF): 92.5925925925926
# Test Accuracy (AFF): 46.15384615384615
# Confusion Matrix:
#  [[25  2]
#  [ 7  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.78      0.93      0.85        27
#          AFF       0.75      0.46      0.57        13
#
#     accuracy                           0.78        40
#    macro avg       0.77      0.69      0.71        40
# weighted avg       0.77      0.78      0.76        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 0.01626952737569809
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 58:
#
# Test Loss: 0.31922265887260437
# Total Test Accuracy: 85.96491228070175
# Test Accuracy (NFF): 86.20689655172413
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[25  4]
#  [ 4 24]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.86      0.86      0.86        29
#          AFF       0.86      0.86      0.86        28
#
#     accuracy                           0.86        57
#    macro avg       0.86      0.86      0.86        57
# weighted avg       0.86      0.86      0.86        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.06373947113752365
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.4759567081928253
# Total Test Accuracy: 82.11382113821138
# Test Accuracy (NFF): 89.0
# Test Accuracy (AFF): 52.17391304347826
# Confusion Matrix:
#  [[89 11]
#  [11 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.89      0.89       100
#          AFF       0.52      0.52      0.52        23
#
#     accuracy                           0.82       123
#    macro avg       0.71      0.71      0.71       123
# weighted avg       0.82      0.82      0.82       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.5220884680747986
# Total Test Accuracy: 84.12698412698413
# Test Accuracy (NFF): 97.82608695652173
# Test Accuracy (AFF): 47.05882352941176
# Confusion Matrix:
#  [[45  1]
#  [ 9  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.83      0.98      0.90        46
#          AFF       0.89      0.47      0.62        17
#
#     accuracy                           0.84        63
#    macro avg       0.86      0.72      0.76        63
# weighted avg       0.85      0.84      0.82        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 0.2952648103237152
# Total Test Accuracy: 88.67924528301887
# Test Accuracy (NFF): 97.5609756097561
# Test Accuracy (AFF): 58.333333333333336
# Confusion Matrix:
#  [[40  1]
#  [ 5  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.98      0.93        41
#          AFF       0.88      0.58      0.70        12
#
#     accuracy                           0.89        53
#    macro avg       0.88      0.78      0.82        53
# weighted avg       0.89      0.89      0.88        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 0.06757809221744537
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.09949635714292526
# Total Test Accuracy: 93.75
# Test Accuracy (NFF): 93.75
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[30  2]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.94      0.97        32
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.94        32
#    macro avg       0.50      0.97      0.48        32
# weighted avg       1.00      0.94      0.97        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.6361507177352905
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[8 0]
#  [2 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.80      1.00      0.89         8
#          AFF       1.00      0.00      0.00         2
#
#     accuracy                           0.80        10
#    macro avg       0.90      0.50      0.44        10
# weighted avg       0.84      0.80      0.71        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.44145384430885315
# Total Test Accuracy: 81.81818181818181
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 20.0
# Confusion Matrix:
#  [[17  0]
#  [ 4  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      1.00      0.89        17
#          AFF       1.00      0.20      0.33         5
#
#     accuracy                           0.82        22
#    macro avg       0.90      0.60      0.61        22
# weighted avg       0.85      0.82      0.77        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.46064507961273193
# Total Test Accuracy: 86.11111111111111
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 28.57142857142857
# Confusion Matrix:
#  [[29  0]
#  [ 5  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      1.00      0.92        29
#          AFF       1.00      0.29      0.44         7
#
#     accuracy                           0.86        36
#    macro avg       0.93      0.64      0.68        36
# weighted avg       0.88      0.86      0.83        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.37881992757320404
# Total Test Accuracy: 86.45320197044335
# Test Accuracy (NFF): 92.69406392694064
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[609  48]
#  [ 62  93]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.93      0.92       657
#          AFF       0.66      0.60      0.63       155
#
#     accuracy                           0.86       812
#    macro avg       0.78      0.76      0.77       812
# weighted avg       0.86      0.86      0.86       812
#
#
# Average Total Test Accuracy: 89.95401015761354

# %% [markdown]
# # ResNet101

# %%
from torchvision.models import resnet101, ResNet101_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the ResNet-101 model
model = models.resnet101(weights=ResNet101_Weights.DEFAULT)

num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)


# layer number
total_layers = len(list(model.children()))

# freeze 50% layer
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False

# modify full connection layer
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)

# ---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 20
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

res101 = train_custom_model(model, train_dataset, val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/20, Train ACC: 51.17%, Validation ACC: 49.40%
# Epoch 2/20, Train ACC: 60.05%, Validation ACC: 54.17%
# Epoch 3/20, Train ACC: 69.97%, Validation ACC: 70.83%
# Epoch 4/20, Train ACC: 71.54%, Validation ACC: 65.48%
# Epoch 5/20, Train ACC: 74.41%, Validation ACC: 62.50%
# Epoch 6/20, Train ACC: 78.59%, Validation ACC: 67.86%
# Epoch 7/20, Train ACC: 81.98%, Validation ACC: 73.21%
# Epoch 8/20, Train ACC: 86.42%, Validation ACC: 76.79%
# Epoch 9/20, Train ACC: 87.47%, Validation ACC: 75.60%
# Epoch 10/20, Train ACC: 89.56%, Validation ACC: 80.36%
# Epoch 11/20, Train ACC: 90.34%, Validation ACC: 82.74%
# Epoch 12/20, Train ACC: 93.99%, Validation ACC: 82.14%
# Epoch 13/20, Train ACC: 93.47%, Validation ACC: 80.95%
# Epoch 14/20, Train ACC: 96.34%, Validation ACC: 81.55%
# Epoch 15/20, Train ACC: 94.52%, Validation ACC: 83.33%
# Epoch 16/20, Train ACC: 96.34%, Validation ACC: 83.93%
# Epoch 17/20, Train ACC: 96.61%, Validation ACC: 87.50%
# Epoch 18/20, Train ACC: 97.65%, Validation ACC: 85.71%
# Epoch 19/20, Train ACC: 97.39%, Validation ACC: 85.71%
# Epoch 20/20, Train ACC: 98.17%, Validation ACC: 85.71%

# %%
model = res101
model.eval()
# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomCsvDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(15, 5))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
torch.cuda.empty_cache()
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.08584263920783997
# Total Test Accuracy: 95.65217391304348
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[22  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        23
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.96        23
#    macro avg       0.50      0.98      0.49        23
# weighted avg       1.00      0.96      0.98        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 0.005881467368453741
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         0
#          AFF       1.00      1.00      1.00         3
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.41347530484199524
# Total Test Accuracy: 85.71428571428571
# Test Accuracy (NFF): 91.30434782608695
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[21  2]
#  [ 3  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.91      0.89        23
#          AFF       0.82      0.75      0.78        12
#
#     accuracy                           0.86        35
#    macro avg       0.85      0.83      0.84        35
# weighted avg       0.86      0.86      0.86        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.07744715362787247
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         2
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.08646080363541842
# Total Test Accuracy: 93.84615384615384
# Test Accuracy (NFF): 93.33333333333333
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[56  4]
#  [ 0  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.93      0.97        60
#          AFF       0.56      1.00      0.71         5
#
#     accuracy                           0.94        65
#    macro avg       0.78      0.97      0.84        65
# weighted avg       0.97      0.94      0.95        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.3163548409938812
# Total Test Accuracy: 89.28571428571429
# Test Accuracy (NFF): 94.44444444444444
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[34  2]
#  [ 4 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.94      0.92        36
#          AFF       0.89      0.80      0.84        20
#
#     accuracy                           0.89        56
#    macro avg       0.89      0.87      0.88        56
# weighted avg       0.89      0.89      0.89        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.0173350740224123
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.45284998416900635
# Total Test Accuracy: 85.4368932038835
# Test Accuracy (NFF): 92.5
# Test Accuracy (AFF): 60.86956521739131
# Confusion Matrix:
#  [[74  6]
#  [ 9 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.93      0.91        80
#          AFF       0.70      0.61      0.65        23
#
#     accuracy                           0.85       103
#    macro avg       0.80      0.77      0.78       103
# weighted avg       0.85      0.85      0.85       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.01570688746869564
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 0.5630997344851494
# Total Test Accuracy: 86.95652173913044
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 43.75
# Confusion Matrix:
#  [[53  0]
#  [ 9  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      1.00      0.92        53
#          AFF       1.00      0.44      0.61        16
#
#     accuracy                           0.87        69
#    macro avg       0.93      0.72      0.77        69
# weighted avg       0.89      0.87      0.85        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.21611300599761307
# Total Test Accuracy: 89.6103896103896
# Test Accuracy (NFF): 95.3125
# Test Accuracy (AFF): 61.53846153846154
# Confusion Matrix:
#  [[61  3]
#  [ 5  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.95      0.94        64
#          AFF       0.73      0.62      0.67        13
#
#     accuracy                           0.90        77
#    macro avg       0.83      0.78      0.80        77
# weighted avg       0.89      0.90      0.89        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.3898536264896393
# Total Test Accuracy: 84.61538461538461
# Test Accuracy (NFF): 84.95575221238938
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[96 17]
#  [ 1  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.85      0.91       113
#          AFF       0.15      0.75      0.25         4
#
#     accuracy                           0.85       117
#    macro avg       0.57      0.80      0.58       117
# weighted avg       0.96      0.85      0.89       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.41448312997817993
# Total Test Accuracy: 84.44444444444444
# Test Accuracy (NFF): 83.72093023255815
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[36  7]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.84      0.91        43
#          AFF       0.22      1.00      0.36         2
#
#     accuracy                           0.84        45
#    macro avg       0.61      0.92      0.64        45
# weighted avg       0.97      0.84      0.89        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.095374196767807
# Total Test Accuracy: 95.23809523809524
# Test Accuracy (NFF): 95.23809523809523
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[20  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.95      0.98        21
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.95        21
#    macro avg       0.50      0.98      0.49        21
# weighted avg       1.00      0.95      0.98        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 0.15167737007141113
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.03024682030081749
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         4
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 0.5948399901390076
# Total Test Accuracy: 76.05633802816901
# Test Accuracy (NFF): 81.63265306122449
# Test Accuracy (AFF): 63.63636363636363
# Confusion Matrix:
#  [[40  9]
#  [ 8 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.83      0.82      0.82        49
#          AFF       0.61      0.64      0.62        22
#
#     accuracy                           0.76        71
#    macro avg       0.72      0.73      0.72        71
# weighted avg       0.76      0.76      0.76        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.10881919786334038
# Total Test Accuracy: 96.03174603174604
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 88.37209302325581
# Confusion Matrix:
#  [[83  0]
#  [ 5 38]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      1.00      0.97        83
#          AFF       1.00      0.88      0.94        43
#
#     accuracy                           0.96       126
#    macro avg       0.97      0.94      0.95       126
# weighted avg       0.96      0.96      0.96       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.46777403354644775
# Total Test Accuracy: 84.44444444444444
# Test Accuracy (NFF): 85.0
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[34  6]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.85      0.91        40
#          AFF       0.40      0.80      0.53         5
#
#     accuracy                           0.84        45
#    macro avg       0.69      0.82      0.72        45
# weighted avg       0.91      0.84      0.87        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.10290922969579697
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[8 0]
#  [0 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         1
#
#     accuracy                           1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.4239712655544281
# Total Test Accuracy: 84.03361344537815
# Test Accuracy (NFF): 91.76470588235294
# Test Accuracy (AFF): 64.70588235294117
# Confusion Matrix:
#  [[78  7]
#  [12 22]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.92      0.89        85
#          AFF       0.76      0.65      0.70        34
#
#     accuracy                           0.84       119
#    macro avg       0.81      0.78      0.79       119
# weighted avg       0.84      0.84      0.84       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 0.565269872546196
# Total Test Accuracy: 77.31958762886597
# Test Accuracy (NFF): 90.56603773584906
# Test Accuracy (AFF): 61.36363636363637
# Confusion Matrix:
#  [[48  5]
#  [17 27]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.74      0.91      0.81        53
#          AFF       0.84      0.61      0.71        44
#
#     accuracy                           0.77        97
#    macro avg       0.79      0.76      0.76        97
# weighted avg       0.79      0.77      0.77        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.011059162206947803
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.3052077889442444
# Total Test Accuracy: 92.3076923076923
# Test Accuracy (NFF): 90.9090909090909
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[70  7]
#  [ 0 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.91      0.95        77
#          AFF       0.67      1.00      0.80        14
#
#     accuracy                           0.92        91
#    macro avg       0.83      0.95      0.88        91
# weighted avg       0.95      0.92      0.93        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 0.6600089073181152
# Total Test Accuracy: 77.77777777777777
# Test Accuracy (NFF): 80.0
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[12  3]
#  [ 1  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.80      0.86        15
#          AFF       0.40      0.67      0.50         3
#
#     accuracy                           0.78        18
#    macro avg       0.66      0.73      0.68        18
# weighted avg       0.84      0.78      0.80        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.17651282250881195
# Total Test Accuracy: 92.3076923076923
# Test Accuracy (NFF): 94.44444444444444
# Test Accuracy (AFF): 87.5
# Confusion Matrix:
#  [[17  1]
#  [ 1  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.94      0.94        18
#          AFF       0.88      0.88      0.88         8
#
#     accuracy                           0.92        26
#    macro avg       0.91      0.91      0.91        26
# weighted avg       0.92      0.92      0.92        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.340408056974411
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 88.23529411764706
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[15  2]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.94        17
#          AFF       0.33      1.00      0.50         1
#
#     accuracy                           0.89        18
#    macro avg       0.67      0.94      0.72        18
# weighted avg       0.96      0.89      0.91        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.1875230222940445
# Total Test Accuracy: 93.54838709677419
# Test Accuracy (NFF): 97.46835443037975
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[77  2]
#  [ 4 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.97      0.96        79
#          AFF       0.83      0.71      0.77        14
#
#     accuracy                           0.94        93
#    macro avg       0.89      0.84      0.87        93
# weighted avg       0.93      0.94      0.93        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 0.4877445697784424
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 77.77777777777779
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[7 2]
#  [2 5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.78      0.78      0.78         9
#          AFF       0.71      0.71      0.71         7
#
#     accuracy                           0.75        16
#    macro avg       0.75      0.75      0.75        16
# weighted avg       0.75      0.75      0.75        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 0.011447220109403133
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 0.5706411823630333
# Total Test Accuracy: 82.14285714285714
# Test Accuracy (NFF): 89.55223880597015
# Test Accuracy (AFF): 52.94117647058824
# Confusion Matrix:
#  [[60  7]
#  [ 8  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.90      0.89        67
#          AFF       0.56      0.53      0.55        17
#
#     accuracy                           0.82        84
#    macro avg       0.72      0.71      0.72        84
# weighted avg       0.82      0.82      0.82        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.04903988540172577
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.5303521454334259
# Total Test Accuracy: 79.72972972972973
# Test Accuracy (NFF): 80.95238095238095
# Test Accuracy (AFF): 72.72727272727273
# Confusion Matrix:
#  [[102  24]
#  [  6  16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.81      0.87       126
#          AFF       0.40      0.73      0.52        22
#
#     accuracy                           0.80       148
#    macro avg       0.67      0.77      0.69       148
# weighted avg       0.86      0.80      0.82       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.14425580203533173
# Total Test Accuracy: 91.17647058823529
# Test Accuracy (NFF): 91.17647058823529
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[31  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.91      0.95        34
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.91        34
#    macro avg       0.50      0.96      0.48        34
# weighted avg       1.00      0.91      0.95        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.14218057692050934
# Total Test Accuracy: 94.11764705882354
# Test Accuracy (NFF): 92.85714285714286
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[13  1]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.93      0.96        14
#          AFF       0.75      1.00      0.86         3
#
#     accuracy                           0.94        17
#    macro avg       0.88      0.96      0.91        17
# weighted avg       0.96      0.94      0.94        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.26622646301984787
# Total Test Accuracy: 88.37209302325581
# Test Accuracy (NFF): 91.17647058823529
# Test Accuracy (AFF): 77.77777777777779
# Confusion Matrix:
#  [[62  6]
#  [ 4 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.91      0.93        68
#          AFF       0.70      0.78      0.74        18
#
#     accuracy                           0.88        86
#    macro avg       0.82      0.84      0.83        86
# weighted avg       0.89      0.88      0.89        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.06891319155693054
# Total Test Accuracy: 96.0
# Test Accuracy (NFF): 96.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[24  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        25
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.96        25
#    macro avg       0.50      0.98      0.49        25
# weighted avg       1.00      0.96      0.98        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.3610955476760864
# Total Test Accuracy: 89.65517241379311
# Test Accuracy (NFF): 91.30434782608695
# Test Accuracy (AFF): 83.33333333333334
# Confusion Matrix:
#  [[21  2]
#  [ 1  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.91      0.93        23
#          AFF       0.71      0.83      0.77         6
#
#     accuracy                           0.90        29
#    macro avg       0.83      0.87      0.85        29
# weighted avg       0.90      0.90      0.90        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.3260536976158619
# Total Test Accuracy: 84.0
# Test Accuracy (NFF): 90.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[63  7]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.90      0.91        70
#          AFF       0.00      0.00      1.00         5
#
#     accuracy                           0.84        75
#    macro avg       0.46      0.45      0.96        75
# weighted avg       0.86      0.84      0.92        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 0.005237547215074301
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 0.6980763077735901
# Total Test Accuracy: 73.33333333333333
# Test Accuracy (NFF): 73.33333333333333
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[11  4]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.73      0.85        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.73        15
#    macro avg       0.50      0.87      0.42        15
# weighted avg       1.00      0.73      0.85        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.15177091117948294
# Total Test Accuracy: 95.51020408163265
# Test Accuracy (NFF): 95.29411764705881
# Test Accuracy (AFF): 96.0
# Confusion Matrix:
#  [[162   8]
#  [  3  72]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.95      0.97       170
#          AFF       0.90      0.96      0.93        75
#
#     accuracy                           0.96       245
#    macro avg       0.94      0.96      0.95       245
# weighted avg       0.96      0.96      0.96       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.1856147050857544
# Total Test Accuracy: 93.54838709677419
# Test Accuracy (NFF): 96.15384615384616
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[25  1]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.96      0.96        26
#          AFF       0.80      0.80      0.80         5
#
#     accuracy                           0.94        31
#    macro avg       0.88      0.88      0.88        31
# weighted avg       0.94      0.94      0.94        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.30396556109189987
# Total Test Accuracy: 89.25619834710744
# Test Accuracy (NFF): 93.18181818181817
# Test Accuracy (AFF): 78.78787878787878
# Confusion Matrix:
#  [[82  6]
#  [ 7 26]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.93      0.93        88
#          AFF       0.81      0.79      0.80        33
#
#     accuracy                           0.89       121
#    macro avg       0.87      0.86      0.86       121
# weighted avg       0.89      0.89      0.89       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.258548378944397
# Total Test Accuracy: 86.36363636363636
# Test Accuracy (NFF): 86.36363636363636
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[19  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.86      0.93        22
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.86        22
#    macro avg       0.50      0.93      0.46        22
# weighted avg       1.00      0.86      0.93        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.17497765645384789
# Total Test Accuracy: 92.85714285714286
# Test Accuracy (NFF): 97.43589743589743
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[76  2]
#  [ 5 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.97      0.96        78
#          AFF       0.88      0.75      0.81        20
#
#     accuracy                           0.93        98
#    macro avg       0.91      0.86      0.88        98
# weighted avg       0.93      0.93      0.93        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.2748991996049881
# Total Test Accuracy: 91.54929577464789
# Test Accuracy (NFF): 93.75
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[60  4]
#  [ 2  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.94      0.95        64
#          AFF       0.56      0.71      0.63         7
#
#     accuracy                           0.92        71
#    macro avg       0.76      0.83      0.79        71
# weighted avg       0.93      0.92      0.92        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.4902689456939697
# Total Test Accuracy: 87.71929824561404
# Test Accuracy (NFF): 87.71929824561403
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[50  7]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.93        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.88        57
#    macro avg       0.50      0.94      0.47        57
# weighted avg       1.00      0.88      0.93        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.3430680111050606
# Total Test Accuracy: 86.40776699029126
# Test Accuracy (NFF): 93.42105263157895
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[71  5]
#  [ 9 18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.93      0.91        76
#          AFF       0.78      0.67      0.72        27
#
#     accuracy                           0.86       103
#    macro avg       0.84      0.80      0.82       103
# weighted avg       0.86      0.86      0.86       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.17757364362478256
# Total Test Accuracy: 89.87341772151899
# Test Accuracy (NFF): 91.66666666666666
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[66  6]
#  [ 2  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.92      0.94        72
#          AFF       0.45      0.71      0.56         7
#
#     accuracy                           0.90        79
#    macro avg       0.71      0.82      0.75        79
# weighted avg       0.92      0.90      0.91        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.09774449467658997
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[24  0]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        24
#          AFF       1.00      1.00      1.00         2
#
#     accuracy                           1.00        26
#    macro avg       1.00      1.00      1.00        26
# weighted avg       1.00      1.00      1.00        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 0.4352599084377289
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[3 0]
#  [3 6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.50      1.00      0.67         3
#          AFF       1.00      0.67      0.80         9
#
#     accuracy                           0.75        12
#    macro avg       0.75      0.83      0.73        12
# weighted avg       0.88      0.75      0.77        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.3192476729551951
# Total Test Accuracy: 87.31343283582089
# Test Accuracy (NFF): 91.50943396226415
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[97  9]
#  [ 8 20]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.92      0.92       106
#          AFF       0.69      0.71      0.70        28
#
#     accuracy                           0.87       134
#    macro avg       0.81      0.81      0.81       134
# weighted avg       0.87      0.87      0.87       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.20070044696331024
# Total Test Accuracy: 93.88888888888889
# Test Accuracy (NFF): 98.68421052631578
# Test Accuracy (AFF): 67.85714285714286
# Confusion Matrix:
#  [[150   2]
#  [  9  19]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.99      0.96       152
#          AFF       0.90      0.68      0.78        28
#
#     accuracy                           0.94       180
#    macro avg       0.92      0.83      0.87       180
# weighted avg       0.94      0.94      0.94       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.6327320337295532
# Total Test Accuracy: 77.5
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 53.84615384615385
# Confusion Matrix:
#  [[24  3]
#  [ 6  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.80      0.89      0.84        27
#          AFF       0.70      0.54      0.61        13
#
#     accuracy                           0.78        40
#    macro avg       0.75      0.71      0.73        40
# weighted avg       0.77      0.78      0.77        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 0.014284372329711914
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 58:
#
# Test Loss: 0.4120686650276184
# Total Test Accuracy: 87.71929824561404
# Test Accuracy (NFF): 86.20689655172413
# Test Accuracy (AFF): 89.28571428571429
# Confusion Matrix:
#  [[25  4]
#  [ 3 25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.86      0.88        29
#          AFF       0.86      0.89      0.88        28
#
#     accuracy                           0.88        57
#    macro avg       0.88      0.88      0.88        57
# weighted avg       0.88      0.88      0.88        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.02033931203186512
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.5415671914815903
# Total Test Accuracy: 80.48780487804878
# Test Accuracy (NFF): 86.0
# Test Accuracy (AFF): 56.52173913043478
# Confusion Matrix:
#  [[86 14]
#  [10 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.86      0.88       100
#          AFF       0.48      0.57      0.52        23
#
#     accuracy                           0.80       123
#    macro avg       0.69      0.71      0.70       123
# weighted avg       0.82      0.80      0.81       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.5585609078407288
# Total Test Accuracy: 76.19047619047619
# Test Accuracy (NFF): 84.78260869565217
# Test Accuracy (AFF): 52.94117647058824
# Confusion Matrix:
#  [[39  7]
#  [ 8  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.83      0.85      0.84        46
#          AFF       0.56      0.53      0.55        17
#
#     accuracy                           0.76        63
#    macro avg       0.70      0.69      0.69        63
# weighted avg       0.76      0.76      0.76        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 0.3976356089115143
# Total Test Accuracy: 88.67924528301887
# Test Accuracy (NFF): 97.5609756097561
# Test Accuracy (AFF): 58.333333333333336
# Confusion Matrix:
#  [[40  1]
#  [ 5  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.98      0.93        41
#          AFF       0.88      0.58      0.70        12
#
#     accuracy                           0.89        53
#    macro avg       0.88      0.78      0.82        53
# weighted avg       0.89      0.89      0.88        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 0.2498941868543625
# Total Test Accuracy: 87.5
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[7 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.93         8
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.88         8
#    macro avg       0.50      0.94      0.47         8
# weighted avg       1.00      0.88      0.93         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.08890415728092194
# Total Test Accuracy: 96.875
# Test Accuracy (NFF): 96.875
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[31  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.97      0.98        32
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.97        32
#    macro avg       0.50      0.98      0.49        32
# weighted avg       1.00      0.97      0.98        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.29543858766555786
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[8 0]
#  [2 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.80      1.00      0.89         8
#          AFF       1.00      0.00      0.00         2
#
#     accuracy                           0.80        10
#    macro avg       0.90      0.50      0.44        10
# weighted avg       0.84      0.80      0.71        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.3525336980819702
# Total Test Accuracy: 90.9090909090909
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[17  0]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      1.00      0.94        17
#          AFF       1.00      0.60      0.75         5
#
#     accuracy                           0.91        22
#    macro avg       0.95      0.80      0.85        22
# weighted avg       0.92      0.91      0.90        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.42004820704460144
# Total Test Accuracy: 86.11111111111111
# Test Accuracy (NFF): 96.55172413793103
# Test Accuracy (AFF): 42.857142857142854
# Confusion Matrix:
#  [[28  1]
#  [ 4  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.97      0.92        29
#          AFF       0.75      0.43      0.55         7
#
#     accuracy                           0.86        36
#    macro avg       0.81      0.70      0.73        36
# weighted avg       0.85      0.86      0.85        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.3617373120326262
# Total Test Accuracy: 87.6847290640394
# Test Accuracy (NFF): 91.62861491628614
# Test Accuracy (AFF): 70.96774193548387
# Confusion Matrix:
#  [[602  55]
#  [ 45 110]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.92      0.92       657
#          AFF       0.67      0.71      0.69       155
#
#     accuracy                           0.88       812
#    macro avg       0.80      0.81      0.81       812
# weighted avg       0.88      0.88      0.88       812
#
#
# Average Total Test Accuracy: 89.79086496630532

# %% [markdown]
# # ResNet152

# %%
from torchvision.models import resnet152, ResNet152_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the ResNet
model = models.resnet152(weights=ResNet152_Weights.DEFAULT)

num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)


# layer number
total_layers = len(list(model.children()))

# freeze 50% layer
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False

# modify full connection layer
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)

# ---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 20
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

res152 = train_custom_model(model, train_dataset, val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/20, Train ACC: 65.54%, Validation ACC: 74.40%
# Epoch 2/20, Train ACC: 72.32%, Validation ACC: 70.83%
# Epoch 3/20, Train ACC: 65.01%, Validation ACC: 73.21%
# Epoch 4/20, Train ACC: 68.41%, Validation ACC: 75.60%
# Epoch 5/20, Train ACC: 77.28%, Validation ACC: 75.60%
# Epoch 6/20, Train ACC: 80.68%, Validation ACC: 77.38%
# Epoch 7/20, Train ACC: 86.16%, Validation ACC: 78.57%
# Epoch 8/20, Train ACC: 88.25%, Validation ACC: 79.76%
# Epoch 9/20, Train ACC: 91.12%, Validation ACC: 80.95%
# Epoch 10/20, Train ACC: 92.69%, Validation ACC: 80.36%
# Epoch 11/20, Train ACC: 92.95%, Validation ACC: 85.71%
# Epoch 12/20, Train ACC: 91.64%, Validation ACC: 86.90%
# Epoch 13/20, Train ACC: 94.52%, Validation ACC: 86.90%
# Epoch 14/20, Train ACC: 96.61%, Validation ACC: 86.31%
# Epoch 15/20, Train ACC: 96.34%, Validation ACC: 88.69%
# Epoch 16/20, Train ACC: 97.91%, Validation ACC: 88.10%
# Epoch 17/20, Train ACC: 98.43%, Validation ACC: 86.90%
# Epoch 18/20, Train ACC: 98.17%, Validation ACC: 88.10%
# Epoch 19/20, Train ACC: 97.39%, Validation ACC: 89.29%
# Epoch 20/20, Train ACC: 98.96%, Validation ACC: 91.07%

# %%
model = res152
model.eval()
# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomCsvDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(10, 5))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
torch.cuda.empty_cache()
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.08462969958782196
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        23
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        23
#    macro avg       1.00      1.00      1.00        23
# weighted avg       1.00      1.00      1.00        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 0.0029635487589985132
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         0
#          AFF       1.00      1.00      1.00         3
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.5335125923156738
# Total Test Accuracy: 82.85714285714286
# Test Accuracy (NFF): 91.30434782608695
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[21  2]
#  [ 4  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      0.91      0.87        23
#          AFF       0.80      0.67      0.73        12
#
#     accuracy                           0.83        35
#    macro avg       0.82      0.79      0.80        35
# weighted avg       0.83      0.83      0.82        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.14955389499664307
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         2
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.08811644045636058
# Total Test Accuracy: 96.92307692307692
# Test Accuracy (NFF): 96.66666666666667
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[58  2]
#  [ 0  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.97      0.98        60
#          AFF       0.71      1.00      0.83         5
#
#     accuracy                           0.97        65
#    macro avg       0.86      0.98      0.91        65
# weighted avg       0.98      0.97      0.97        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.24422024190425873
# Total Test Accuracy: 92.85714285714286
# Test Accuracy (NFF): 97.22222222222221
# Test Accuracy (AFF): 85.0
# Confusion Matrix:
#  [[35  1]
#  [ 3 17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.97      0.95        36
#          AFF       0.94      0.85      0.89        20
#
#     accuracy                           0.93        56
#    macro avg       0.93      0.91      0.92        56
# weighted avg       0.93      0.93      0.93        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.09496583789587021
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.4536064714193344
# Total Test Accuracy: 84.46601941747574
# Test Accuracy (NFF): 92.5
# Test Accuracy (AFF): 56.52173913043478
# Confusion Matrix:
#  [[74  6]
#  [10 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.93      0.90        80
#          AFF       0.68      0.57      0.62        23
#
#     accuracy                           0.84       103
#    macro avg       0.78      0.75      0.76       103
# weighted avg       0.84      0.84      0.84       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.024705341085791588
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 0.20565461367368698
# Total Test Accuracy: 92.7536231884058
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 68.75
# Confusion Matrix:
#  [[53  0]
#  [ 5 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      1.00      0.95        53
#          AFF       1.00      0.69      0.81        16
#
#     accuracy                           0.93        69
#    macro avg       0.96      0.84      0.88        69
# weighted avg       0.93      0.93      0.92        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.17856997065246105
# Total Test Accuracy: 89.6103896103896
# Test Accuracy (NFF): 93.75
# Test Accuracy (AFF): 69.23076923076923
# Confusion Matrix:
#  [[60  4]
#  [ 4  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.94      0.94        64
#          AFF       0.69      0.69      0.69        13
#
#     accuracy                           0.90        77
#    macro avg       0.81      0.81      0.81        77
# weighted avg       0.90      0.90      0.90        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.18683260679244995
# Total Test Accuracy: 94.87179487179488
# Test Accuracy (NFF): 94.69026548672566
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[107   6]
#  [  0   4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.95      0.97       113
#          AFF       0.40      1.00      0.57         4
#
#     accuracy                           0.95       117
#    macro avg       0.70      0.97      0.77       117
# weighted avg       0.98      0.95      0.96       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.15275008976459503
# Total Test Accuracy: 97.77777777777777
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[43  0]
#  [ 1  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      1.00      0.99        43
#          AFF       1.00      0.50      0.67         2
#
#     accuracy                           0.98        45
#    macro avg       0.99      0.75      0.83        45
# weighted avg       0.98      0.98      0.97        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.006298151798546314
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        21
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 0.2387569546699524
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.013989043422043324
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         4
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 0.36017801612615585
# Total Test Accuracy: 83.09859154929578
# Test Accuracy (NFF): 97.95918367346938
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[48  1]
#  [11 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      0.98      0.89        49
#          AFF       0.92      0.50      0.65        22
#
#     accuracy                           0.83        71
#    macro avg       0.87      0.74      0.77        71
# weighted avg       0.85      0.83      0.81        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.07233601622283459
# Total Test Accuracy: 98.41269841269842
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 95.34883720930233
# Confusion Matrix:
#  [[83  0]
#  [ 2 41]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      1.00      0.99        83
#          AFF       1.00      0.95      0.98        43
#
#     accuracy                           0.98       126
#    macro avg       0.99      0.98      0.98       126
# weighted avg       0.98      0.98      0.98       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.28562918305397034
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 92.5
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[37  3]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.93      0.94        40
#          AFF       0.50      0.60      0.55         5
#
#     accuracy                           0.89        45
#    macro avg       0.72      0.76      0.74        45
# weighted avg       0.90      0.89      0.89        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.060199931263923645
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[8 0]
#  [0 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         1
#
#     accuracy                           1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.5159060806035995
# Total Test Accuracy: 83.19327731092437
# Test Accuracy (NFF): 94.11764705882352
# Test Accuracy (AFF): 55.88235294117647
# Confusion Matrix:
#  [[80  5]
#  [15 19]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      0.94      0.89        85
#          AFF       0.79      0.56      0.66        34
#
#     accuracy                           0.83       119
#    macro avg       0.82      0.75      0.77       119
# weighted avg       0.83      0.83      0.82       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 0.647043764591217
# Total Test Accuracy: 78.35051546391753
# Test Accuracy (NFF): 94.33962264150944
# Test Accuracy (AFF): 59.09090909090909
# Confusion Matrix:
#  [[50  3]
#  [18 26]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.74      0.94      0.83        53
#          AFF       0.90      0.59      0.71        44
#
#     accuracy                           0.78        97
#    macro avg       0.82      0.77      0.77        97
# weighted avg       0.81      0.78      0.77        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.012269658036530018
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.33416855335235596
# Total Test Accuracy: 91.20879120879121
# Test Accuracy (NFF): 93.5064935064935
# Test Accuracy (AFF): 78.57142857142857
# Confusion Matrix:
#  [[72  5]
#  [ 3 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.94      0.95        77
#          AFF       0.69      0.79      0.73        14
#
#     accuracy                           0.91        91
#    macro avg       0.82      0.86      0.84        91
# weighted avg       0.92      0.91      0.91        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 0.7204460501670837
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 80.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[12  3]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.80      0.89        15
#          AFF       0.50      1.00      0.67         3
#
#     accuracy                           0.83        18
#    macro avg       0.75      0.90      0.78        18
# weighted avg       0.92      0.83      0.85        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.4705173075199127
# Total Test Accuracy: 80.76923076923077
# Test Accuracy (NFF): 94.44444444444444
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[17  1]
#  [ 4  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      0.94      0.87        18
#          AFF       0.80      0.50      0.62         8
#
#     accuracy                           0.81        26
#    macro avg       0.80      0.72      0.74        26
# weighted avg       0.81      0.81      0.79        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.013684784062206745
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[17  0]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        17
#          AFF       1.00      1.00      1.00         1
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.272846519947052
# Total Test Accuracy: 91.39784946236558
# Test Accuracy (NFF): 94.9367088607595
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[75  4]
#  [ 4 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.95      0.95        79
#          AFF       0.71      0.71      0.71        14
#
#     accuracy                           0.91        93
#    macro avg       0.83      0.83      0.83        93
# weighted avg       0.91      0.91      0.91        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 0.46486565470695496
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 57.14285714285714
# Confusion Matrix:
#  [[8 1]
#  [3 4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.73      0.89      0.80         9
#          AFF       0.80      0.57      0.67         7
#
#     accuracy                           0.75        16
#    macro avg       0.76      0.73      0.73        16
# weighted avg       0.76      0.75      0.74        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 1.220546841621399
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4 2]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         6
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         6
#    macro avg       0.50      0.83      0.40         6
# weighted avg       1.00      0.67      0.80         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 0.1984676979482174
# Total Test Accuracy: 90.47619047619048
# Test Accuracy (NFF): 89.55223880597015
# Test Accuracy (AFF): 94.11764705882352
# Confusion Matrix:
#  [[60  7]
#  [ 1 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.90      0.94        67
#          AFF       0.70      0.94      0.80        17
#
#     accuracy                           0.90        84
#    macro avg       0.84      0.92      0.87        84
# weighted avg       0.93      0.90      0.91        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.00813406240195036
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.26150576025247574
# Total Test Accuracy: 89.1891891891892
# Test Accuracy (NFF): 93.65079365079364
# Test Accuracy (AFF): 63.63636363636363
# Confusion Matrix:
#  [[118   8]
#  [  8  14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.94      0.94       126
#          AFF       0.64      0.64      0.64        22
#
#     accuracy                           0.89       148
#    macro avg       0.79      0.79      0.79       148
# weighted avg       0.89      0.89      0.89       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.09813433140516281
# Total Test Accuracy: 97.05882352941177
# Test Accuracy (NFF): 97.05882352941177
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[33  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.97      0.99        34
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.97        34
#    macro avg       0.50      0.99      0.49        34
# weighted avg       1.00      0.97      0.99        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.08553975820541382
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[14  0]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        14
#          AFF       1.00      1.00      1.00         3
#
#     accuracy                           1.00        17
#    macro avg       1.00      1.00      1.00        17
# weighted avg       1.00      1.00      1.00        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.26778440177440643
# Total Test Accuracy: 87.20930232558139
# Test Accuracy (NFF): 95.58823529411765
# Test Accuracy (AFF): 55.55555555555556
# Confusion Matrix:
#  [[65  3]
#  [ 8 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.96      0.92        68
#          AFF       0.77      0.56      0.65        18
#
#     accuracy                           0.87        86
#    macro avg       0.83      0.76      0.78        86
# weighted avg       0.87      0.87      0.86        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.06101827323436737
# Total Test Accuracy: 96.0
# Test Accuracy (NFF): 96.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[24  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        25
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.96        25
#    macro avg       0.50      0.98      0.49        25
# weighted avg       1.00      0.96      0.98        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.1881585568189621
# Total Test Accuracy: 93.10344827586206
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 83.33333333333334
# Confusion Matrix:
#  [[22  1]
#  [ 1  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.96      0.96        23
#          AFF       0.83      0.83      0.83         6
#
#     accuracy                           0.93        29
#    macro avg       0.89      0.89      0.89        29
# weighted avg       0.93      0.93      0.93        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.22142250835895538
# Total Test Accuracy: 88.0
# Test Accuracy (NFF): 94.28571428571428
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[66  4]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.94      0.94        70
#          AFF       0.00      0.00      1.00         5
#
#     accuracy                           0.88        75
#    macro avg       0.46      0.47      0.97        75
# weighted avg       0.87      0.88      0.94        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 0.0007496288162656128
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 0.42125633358955383
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 80.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[12  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.80      0.89        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.80        15
#    macro avg       0.50      0.90      0.44        15
# weighted avg       1.00      0.80      0.89        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.06279761414043605
# Total Test Accuracy: 98.36734693877551
# Test Accuracy (NFF): 98.23529411764706
# Test Accuracy (AFF): 98.66666666666667
# Confusion Matrix:
#  [[167   3]
#  [  1  74]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.98      0.99       170
#          AFF       0.96      0.99      0.97        75
#
#     accuracy                           0.98       245
#    macro avg       0.98      0.98      0.98       245
# weighted avg       0.98      0.98      0.98       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.27834850549697876
# Total Test Accuracy: 83.87096774193549
# Test Accuracy (NFF): 88.46153846153845
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[23  3]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.88      0.90        26
#          AFF       0.50      0.60      0.55         5
#
#     accuracy                           0.84        31
#    macro avg       0.71      0.74      0.72        31
# weighted avg       0.85      0.84      0.84        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.30854807794094086
# Total Test Accuracy: 88.4297520661157
# Test Accuracy (NFF): 88.63636363636364
# Test Accuracy (AFF): 87.87878787878788
# Confusion Matrix:
#  [[78 10]
#  [ 4 29]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.89      0.92        88
#          AFF       0.74      0.88      0.81        33
#
#     accuracy                           0.88       121
#    macro avg       0.85      0.88      0.86       121
# weighted avg       0.89      0.88      0.89       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.07981152087450027
# Total Test Accuracy: 95.45454545454545
# Test Accuracy (NFF): 95.45454545454545
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.95      0.98        22
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.95        22
#    macro avg       0.50      0.98      0.49        22
# weighted avg       1.00      0.95      0.98        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.20722999051213264
# Total Test Accuracy: 93.87755102040816
# Test Accuracy (NFF): 98.71794871794873
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[77  1]
#  [ 5 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.99      0.96        78
#          AFF       0.94      0.75      0.83        20
#
#     accuracy                           0.94        98
#    macro avg       0.94      0.87      0.90        98
# weighted avg       0.94      0.94      0.94        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.11946978606283665
# Total Test Accuracy: 92.95774647887323
# Test Accuracy (NFF): 93.75
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[60  4]
#  [ 1  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.94      0.96        64
#          AFF       0.60      0.86      0.71         7
#
#     accuracy                           0.93        71
#    macro avg       0.79      0.90      0.83        71
# weighted avg       0.95      0.93      0.93        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.5215650796890259
# Total Test Accuracy: 82.45614035087719
# Test Accuracy (NFF): 82.45614035087719
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[47 10]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.82      0.90        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.82        57
#    macro avg       0.50      0.91      0.45        57
# weighted avg       1.00      0.82      0.90        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.45102179795503616
# Total Test Accuracy: 86.40776699029126
# Test Accuracy (NFF): 96.05263157894737
# Test Accuracy (AFF): 59.25925925925925
# Confusion Matrix:
#  [[73  3]
#  [11 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.96      0.91        76
#          AFF       0.84      0.59      0.70        27
#
#     accuracy                           0.86       103
#    macro avg       0.86      0.78      0.80       103
# weighted avg       0.86      0.86      0.86       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.10381653532385826
# Total Test Accuracy: 94.9367088607595
# Test Accuracy (NFF): 97.22222222222221
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[70  2]
#  [ 2  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.97      0.97        72
#          AFF       0.71      0.71      0.71         7
#
#     accuracy                           0.95        79
#    macro avg       0.84      0.84      0.84        79
# weighted avg       0.95      0.95      0.95        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.03537004813551903
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[24  0]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        24
#          AFF       1.00      1.00      1.00         2
#
#     accuracy                           1.00        26
#    macro avg       1.00      1.00      1.00        26
# weighted avg       1.00      1.00      1.00        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 0.7689037919044495
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 55.55555555555556
# Confusion Matrix:
#  [[3 0]
#  [4 5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.43      1.00      0.60         3
#          AFF       1.00      0.56      0.71         9
#
#     accuracy                           0.67        12
#    macro avg       0.71      0.78      0.66        12
# weighted avg       0.86      0.67      0.69        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.18247459704677263
# Total Test Accuracy: 91.04477611940298
# Test Accuracy (NFF): 96.22641509433963
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[102   4]
#  [  8  20]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.96      0.94       106
#          AFF       0.83      0.71      0.77        28
#
#     accuracy                           0.91       134
#    macro avg       0.88      0.84      0.86       134
# weighted avg       0.91      0.91      0.91       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.17113854736089706
# Total Test Accuracy: 94.44444444444444
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 64.28571428571429
# Confusion Matrix:
#  [[152   0]
#  [ 10  18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      1.00      0.97       152
#          AFF       1.00      0.64      0.78        28
#
#     accuracy                           0.94       180
#    macro avg       0.97      0.82      0.88       180
# weighted avg       0.95      0.94      0.94       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.6090745329856873
# Total Test Accuracy: 82.5
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 46.15384615384615
# Confusion Matrix:
#  [[27  0]
#  [ 7  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.79      1.00      0.89        27
#          AFF       1.00      0.46      0.63        13
#
#     accuracy                           0.82        40
#    macro avg       0.90      0.73      0.76        40
# weighted avg       0.86      0.82      0.80        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 0.0157605092972517
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 58:
#
# Test Loss: 0.44052839279174805
# Total Test Accuracy: 91.2280701754386
# Test Accuracy (NFF): 89.65517241379311
# Test Accuracy (AFF): 92.85714285714286
# Confusion Matrix:
#  [[26  3]
#  [ 2 26]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.90      0.91        29
#          AFF       0.90      0.93      0.91        28
#
#     accuracy                           0.91        57
#    macro avg       0.91      0.91      0.91        57
# weighted avg       0.91      0.91      0.91        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.08506349474191666
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.26137565821409225
# Total Test Accuracy: 89.4308943089431
# Test Accuracy (NFF): 94.0
# Test Accuracy (AFF): 69.56521739130434
# Confusion Matrix:
#  [[94  6]
#  [ 7 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.94      0.94       100
#          AFF       0.73      0.70      0.71        23
#
#     accuracy                           0.89       123
#    macro avg       0.83      0.82      0.82       123
# weighted avg       0.89      0.89      0.89       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.3044542968273163
# Total Test Accuracy: 85.71428571428571
# Test Accuracy (NFF): 91.30434782608695
# Test Accuracy (AFF): 70.58823529411765
# Confusion Matrix:
#  [[42  4]
#  [ 5 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.91      0.90        46
#          AFF       0.75      0.71      0.73        17
#
#     accuracy                           0.86        63
#    macro avg       0.82      0.81      0.82        63
# weighted avg       0.85      0.86      0.86        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 0.4541592001914978
# Total Test Accuracy: 90.56603773584905
# Test Accuracy (NFF): 95.1219512195122
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[39  2]
#  [ 3  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.95      0.94        41
#          AFF       0.82      0.75      0.78        12
#
#     accuracy                           0.91        53
#    macro avg       0.87      0.85      0.86        53
# weighted avg       0.90      0.91      0.90        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 0.3041203022003174
# Total Test Accuracy: 87.5
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[7 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.93         8
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.88         8
#    macro avg       0.50      0.94      0.47         8
# weighted avg       1.00      0.88      0.93         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.039075423032045364
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[32]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        32
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        32
#    macro avg       1.00      1.00      1.00        32
# weighted avg       1.00      1.00      1.00        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.3438616991043091
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[7 1]
#  [1 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.88      0.88         8
#          AFF       0.50      0.50      0.50         2
#
#     accuracy                           0.80        10
#    macro avg       0.69      0.69      0.69        10
# weighted avg       0.80      0.80      0.80        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.39938828349113464
# Total Test Accuracy: 86.36363636363636
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 40.0
# Confusion Matrix:
#  [[17  0]
#  [ 3  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      1.00      0.92        17
#          AFF       1.00      0.40      0.57         5
#
#     accuracy                           0.86        22
#    macro avg       0.93      0.70      0.75        22
# weighted avg       0.88      0.86      0.84        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.4338569939136505
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 42.857142857142854
# Confusion Matrix:
#  [[29  0]
#  [ 4  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      1.00      0.94        29
#          AFF       1.00      0.43      0.60         7
#
#     accuracy                           0.89        36
#    macro avg       0.94      0.71      0.77        36
# weighted avg       0.90      0.89      0.87        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.31079624879818696
# Total Test Accuracy: 90.39408866995073
# Test Accuracy (NFF): 94.06392694063926
# Test Accuracy (AFF): 74.83870967741936
# Confusion Matrix:
#  [[618  39]
#  [ 39 116]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.94      0.94       657
#          AFF       0.75      0.75      0.75       155
#
#     accuracy                           0.90       812
#    macro avg       0.84      0.84      0.84       812
# weighted avg       0.90      0.90      0.90       812
#
#
# Average Total Test Accuracy: 91.26826984112896

# %% [markdown]
# # DenseNet 161

# %%
from torchvision.models import densenet161, DenseNet161_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# Define the DenseNet-161 model
model = models.densenet161(weights=DenseNet161_Weights.DEFAULT)

# Modify the classifier part of the model
num_features = model.classifier.in_features
model.classifier = nn.Linear(num_features, 2)

# total layers 
total_layers = len(list(model.features.children()))

# freeze 50% layers
freeze_layers = int(total_layers * 0.5)
for index, child in enumerate(model.features.children()):
    if index < freeze_layers:
        for param in child.parameters():
            param.requires_grad = False
            
# ---------------------------------------------------------------------------------------------------------
# Hyper parameters
num_epochs = 20
batch_size = 64
learning_rate = 0.0001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# ---------------------------------------------------------------------------------------------------------

dense161 = train_custom_model(model, train_dataset, val_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
# Out:
# Epoch 1/20, Train ACC: 65.27%, Validation ACC: 62.50%
# Epoch 2/20, Train ACC: 65.80%, Validation ACC: 59.52%
# Epoch 3/20, Train ACC: 74.93%, Validation ACC: 73.21%
# Epoch 4/20, Train ACC: 85.90%, Validation ACC: 76.19%
# Epoch 5/20, Train ACC: 87.99%, Validation ACC: 80.36%
# Epoch 6/20, Train ACC: 92.43%, Validation ACC: 83.33%
# Epoch 7/20, Train ACC: 92.17%, Validation ACC: 85.71%
# Epoch 8/20, Train ACC: 94.52%, Validation ACC: 77.98%
# Epoch 9/20, Train ACC: 93.47%, Validation ACC: 83.93%
# Epoch 10/20, Train ACC: 97.39%, Validation ACC: 85.12%
# Epoch 11/20, Train ACC: 96.61%, Validation ACC: 84.52%
# Epoch 12/20, Train ACC: 98.43%, Validation ACC: 82.14%
# Epoch 13/20, Train ACC: 98.43%, Validation ACC: 78.57%
# Epoch 14/20, Train ACC: 98.17%, Validation ACC: 84.52%
# Epoch 15/20, Train ACC: 98.43%, Validation ACC: 85.71%
# Epoch 16/20, Train ACC: 99.22%, Validation ACC: 86.90%
# Epoch 17/20, Train ACC: 99.22%, Validation ACC: 86.90%
# Epoch 18/20, Train ACC: 98.96%, Validation ACC: 87.50%
# Epoch 19/20, Train ACC: 99.48%, Validation ACC: 89.29%
# Epoch 20/20, Train ACC: 98.17%, Validation ACC: 88.69%

# %%
model = dense161
model.eval()
# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomCsvDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(15, 5))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
torch.cuda.empty_cache()
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.028998812660574913
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        23
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        23
#    macro avg       1.00      1.00      1.00        23
# weighted avg       1.00      1.00      1.00        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 0.024774810299277306
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         0
#          AFF       1.00      1.00      1.00         3
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.5698567032814026
# Total Test Accuracy: 91.42857142857143
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[23  0]
#  [ 3  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      1.00      0.94        23
#          AFF       1.00      0.75      0.86        12
#
#     accuracy                           0.91        35
#    macro avg       0.94      0.88      0.90        35
# weighted avg       0.92      0.91      0.91        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.008626616559922695
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         2
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.06283077842090279
# Total Test Accuracy: 93.84615384615384
# Test Accuracy (NFF): 96.66666666666667
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[58  2]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.97      0.97        60
#          AFF       0.60      0.60      0.60         5
#
#     accuracy                           0.94        65
#    macro avg       0.78      0.78      0.78        65
# weighted avg       0.94      0.94      0.94        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.26805737614631653
# Total Test Accuracy: 89.28571428571429
# Test Accuracy (NFF): 97.22222222222221
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[35  1]
#  [ 5 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.97      0.92        36
#          AFF       0.94      0.75      0.83        20
#
#     accuracy                           0.89        56
#    macro avg       0.91      0.86      0.88        56
# weighted avg       0.90      0.89      0.89        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.06967905163764954
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.4891607165336609
# Total Test Accuracy: 85.4368932038835
# Test Accuracy (NFF): 95.0
# Test Accuracy (AFF): 52.17391304347826
# Confusion Matrix:
#  [[76  4]
#  [11 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.95      0.91        80
#          AFF       0.75      0.52      0.62        23
#
#     accuracy                           0.85       103
#    macro avg       0.81      0.74      0.76       103
# weighted avg       0.85      0.85      0.84       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.03557442128658295
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 0.27719650603830814
# Total Test Accuracy: 85.5072463768116
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 37.5
# Confusion Matrix:
#  [[53  0]
#  [10  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      1.00      0.91        53
#          AFF       1.00      0.38      0.55        16
#
#     accuracy                           0.86        69
#    macro avg       0.92      0.69      0.73        69
# weighted avg       0.88      0.86      0.83        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.16855444852262735
# Total Test Accuracy: 89.6103896103896
# Test Accuracy (NFF): 95.3125
# Test Accuracy (AFF): 61.53846153846154
# Confusion Matrix:
#  [[61  3]
#  [ 5  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.95      0.94        64
#          AFF       0.73      0.62      0.67        13
#
#     accuracy                           0.90        77
#    macro avg       0.83      0.78      0.80        77
# weighted avg       0.89      0.90      0.89        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.07418741099536419
# Total Test Accuracy: 96.58119658119658
# Test Accuracy (NFF): 96.46017699115043
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[109   4]
#  [  0   4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98       113
#          AFF       0.50      1.00      0.67         4
#
#     accuracy                           0.97       117
#    macro avg       0.75      0.98      0.82       117
# weighted avg       0.98      0.97      0.97       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.10805006325244904
# Total Test Accuracy: 93.33333333333333
# Test Accuracy (NFF): 95.34883720930233
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[41  2]
#  [ 1  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.95      0.96        43
#          AFF       0.33      0.50      0.40         2
#
#     accuracy                           0.93        45
#    macro avg       0.65      0.73      0.68        45
# weighted avg       0.95      0.93      0.94        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.008823448792099953
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        21
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 0.040812525898218155
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.0058736251667141914
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         4
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 0.4998957961797714
# Total Test Accuracy: 81.69014084507042
# Test Accuracy (NFF): 95.91836734693877
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[47  2]
#  [11 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      0.96      0.88        49
#          AFF       0.85      0.50      0.63        22
#
#     accuracy                           0.82        71
#    macro avg       0.83      0.73      0.75        71
# weighted avg       0.82      0.82      0.80        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.1582749504595995
# Total Test Accuracy: 96.03174603174604
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 88.37209302325581
# Confusion Matrix:
#  [[83  0]
#  [ 5 38]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      1.00      0.97        83
#          AFF       1.00      0.88      0.94        43
#
#     accuracy                           0.96       126
#    macro avg       0.97      0.94      0.95       126
# weighted avg       0.96      0.96      0.96       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.2817936837673187
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 95.0
# Test Accuracy (AFF): 40.0
# Confusion Matrix:
#  [[38  2]
#  [ 3  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.95      0.94        40
#          AFF       0.50      0.40      0.44         5
#
#     accuracy                           0.89        45
#    macro avg       0.71      0.68      0.69        45
# weighted avg       0.88      0.89      0.88        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.0038666112814098597
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[8 0]
#  [0 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         1
#
#     accuracy                           1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.62421053647995
# Total Test Accuracy: 80.67226890756302
# Test Accuracy (NFF): 96.47058823529412
# Test Accuracy (AFF): 41.17647058823529
# Confusion Matrix:
#  [[82  3]
#  [20 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.80      0.96      0.88        85
#          AFF       0.82      0.41      0.55        34
#
#     accuracy                           0.81       119
#    macro avg       0.81      0.69      0.71       119
# weighted avg       0.81      0.81      0.78       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 0.6490478813648224
# Total Test Accuracy: 79.38144329896907
# Test Accuracy (NFF): 96.22641509433963
# Test Accuracy (AFF): 59.09090909090909
# Confusion Matrix:
#  [[51  2]
#  [18 26]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.74      0.96      0.84        53
#          AFF       0.93      0.59      0.72        44
#
#     accuracy                           0.79        97
#    macro avg       0.83      0.78      0.78        97
# weighted avg       0.83      0.79      0.78        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.003470354713499546
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.29308556765317917
# Total Test Accuracy: 92.3076923076923
# Test Accuracy (NFF): 96.1038961038961
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[74  3]
#  [ 4 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.96      0.95        77
#          AFF       0.77      0.71      0.74        14
#
#     accuracy                           0.92        91
#    macro avg       0.86      0.84      0.85        91
# weighted avg       0.92      0.92      0.92        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 0.08352672308683395
# Total Test Accuracy: 94.44444444444444
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[15  0]
#  [ 1  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      1.00      0.97        15
#          AFF       1.00      0.67      0.80         3
#
#     accuracy                           0.94        18
#    macro avg       0.97      0.83      0.88        18
# weighted avg       0.95      0.94      0.94        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.3306792974472046
# Total Test Accuracy: 92.3076923076923
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[18  0]
#  [ 2  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      1.00      0.95        18
#          AFF       1.00      0.75      0.86         8
#
#     accuracy                           0.92        26
#    macro avg       0.95      0.88      0.90        26
# weighted avg       0.93      0.92      0.92        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.0038518246728926897
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[17  0]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        17
#          AFF       1.00      1.00      1.00         1
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.20761127769947052
# Total Test Accuracy: 92.47311827956989
# Test Accuracy (NFF): 97.46835443037975
# Test Accuracy (AFF): 64.28571428571429
# Confusion Matrix:
#  [[77  2]
#  [ 5  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.97      0.96        79
#          AFF       0.82      0.64      0.72        14
#
#     accuracy                           0.92        93
#    macro avg       0.88      0.81      0.84        93
# weighted avg       0.92      0.92      0.92        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 0.6360447406768799
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 42.857142857142854
# Confusion Matrix:
#  [[9 0]
#  [4 3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.69      1.00      0.82         9
#          AFF       1.00      0.43      0.60         7
#
#     accuracy                           0.75        16
#    macro avg       0.85      0.71      0.71        16
# weighted avg       0.83      0.75      0.72        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 0.3886055648326874
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 83.33333333333334
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[5 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.83      0.91         6
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.83         6
#    macro avg       0.50      0.92      0.45         6
# weighted avg       1.00      0.83      0.91         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 0.17425129935145378
# Total Test Accuracy: 89.28571428571429
# Test Accuracy (NFF): 94.02985074626866
# Test Accuracy (AFF): 70.58823529411765
# Confusion Matrix:
#  [[63  4]
#  [ 5 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.94      0.93        67
#          AFF       0.75      0.71      0.73        17
#
#     accuracy                           0.89        84
#    macro avg       0.84      0.82      0.83        84
# weighted avg       0.89      0.89      0.89        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.005037784110754728
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.2809687579671542
# Total Test Accuracy: 88.51351351351352
# Test Accuracy (NFF): 94.44444444444444
# Test Accuracy (AFF): 54.54545454545454
# Confusion Matrix:
#  [[119   7]
#  [ 10  12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.94      0.93       126
#          AFF       0.63      0.55      0.59        22
#
#     accuracy                           0.89       148
#    macro avg       0.78      0.74      0.76       148
# weighted avg       0.88      0.89      0.88       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.04049704968929291
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[34]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        34
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        34
#    macro avg       1.00      1.00      1.00        34
# weighted avg       1.00      1.00      1.00        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.05933167785406113
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[14  0]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        14
#          AFF       1.00      1.00      1.00         3
#
#     accuracy                           1.00        17
#    macro avg       1.00      1.00      1.00        17
# weighted avg       1.00      1.00      1.00        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.20581058971583843
# Total Test Accuracy: 93.02325581395348
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[68  0]
#  [ 6 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      1.00      0.96        68
#          AFF       1.00      0.67      0.80        18
#
#     accuracy                           0.93        86
#    macro avg       0.96      0.83      0.88        86
# weighted avg       0.94      0.93      0.92        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.014279812574386597
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        25
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        25
#    macro avg       1.00      1.00      1.00        25
# weighted avg       1.00      1.00      1.00        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.31037741899490356
# Total Test Accuracy: 89.65517241379311
# Test Accuracy (NFF): 91.30434782608695
# Test Accuracy (AFF): 83.33333333333334
# Confusion Matrix:
#  [[21  2]
#  [ 1  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.91      0.93        23
#          AFF       0.71      0.83      0.77         6
#
#     accuracy                           0.90        29
#    macro avg       0.83      0.87      0.85        29
# weighted avg       0.90      0.90      0.90        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.19978538481518626
# Total Test Accuracy: 88.0
# Test Accuracy (NFF): 94.28571428571428
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[66  4]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.94      0.94        70
#          AFF       0.00      0.00      1.00         5
#
#     accuracy                           0.88        75
#    macro avg       0.46      0.47      0.97        75
# weighted avg       0.87      0.88      0.94        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 0.001200212282128632
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 0.4864856004714966
# Total Test Accuracy: 86.66666666666667
# Test Accuracy (NFF): 86.66666666666667
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[13  2]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.87      0.93        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.87        15
#    macro avg       0.50      0.93      0.46        15
# weighted avg       1.00      0.87      0.93        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.06520249787718058
# Total Test Accuracy: 97.14285714285714
# Test Accuracy (NFF): 97.05882352941177
# Test Accuracy (AFF): 97.33333333333334
# Confusion Matrix:
#  [[165   5]
#  [  2  73]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.97      0.98       170
#          AFF       0.94      0.97      0.95        75
#
#     accuracy                           0.97       245
#    macro avg       0.96      0.97      0.97       245
# weighted avg       0.97      0.97      0.97       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.10841360688209534
# Total Test Accuracy: 96.7741935483871
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[26  0]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      1.00      0.98        26
#          AFF       1.00      0.80      0.89         5
#
#     accuracy                           0.97        31
#    macro avg       0.98      0.90      0.94        31
# weighted avg       0.97      0.97      0.97        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.2423296645283699
# Total Test Accuracy: 93.38842975206612
# Test Accuracy (NFF): 98.86363636363636
# Test Accuracy (AFF): 78.78787878787878
# Confusion Matrix:
#  [[87  1]
#  [ 7 26]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.99      0.96        88
#          AFF       0.96      0.79      0.87        33
#
#     accuracy                           0.93       121
#    macro avg       0.94      0.89      0.91       121
# weighted avg       0.94      0.93      0.93       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.034180477261543274
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[22]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        22
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        22
#    macro avg       1.00      1.00      1.00        22
# weighted avg       1.00      1.00      1.00        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.19218852743506432
# Total Test Accuracy: 91.83673469387755
# Test Accuracy (NFF): 97.43589743589743
# Test Accuracy (AFF): 70.0
# Confusion Matrix:
#  [[76  2]
#  [ 6 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.97      0.95        78
#          AFF       0.88      0.70      0.78        20
#
#     accuracy                           0.92        98
#    macro avg       0.90      0.84      0.86        98
# weighted avg       0.92      0.92      0.91        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.15375376120209694
# Total Test Accuracy: 95.77464788732394
# Test Accuracy (NFF): 98.4375
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[63  1]
#  [ 2  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.98      0.98        64
#          AFF       0.83      0.71      0.77         7
#
#     accuracy                           0.96        71
#    macro avg       0.90      0.85      0.87        71
# weighted avg       0.96      0.96      0.96        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.12696623802185059
# Total Test Accuracy: 94.73684210526316
# Test Accuracy (NFF): 94.73684210526315
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[54  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.95      0.97        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.95        57
#    macro avg       0.50      0.97      0.49        57
# weighted avg       1.00      0.95      0.97        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.4078233689069748
# Total Test Accuracy: 84.46601941747574
# Test Accuracy (NFF): 98.68421052631578
# Test Accuracy (AFF): 44.44444444444444
# Confusion Matrix:
#  [[75  1]
#  [15 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.83      0.99      0.90        76
#          AFF       0.92      0.44      0.60        27
#
#     accuracy                           0.84       103
#    macro avg       0.88      0.72      0.75       103
# weighted avg       0.86      0.84      0.82       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.04437767155468464
# Total Test Accuracy: 97.46835443037975
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[72  0]
#  [ 2  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      1.00      0.99        72
#          AFF       1.00      0.71      0.83         7
#
#     accuracy                           0.97        79
#    macro avg       0.99      0.86      0.91        79
# weighted avg       0.98      0.97      0.97        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.07301247864961624
# Total Test Accuracy: 96.15384615384616
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[24  0]
#  [ 1  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      1.00      0.98        24
#          AFF       1.00      0.50      0.67         2
#
#     accuracy                           0.96        26
#    macro avg       0.98      0.75      0.82        26
# weighted avg       0.96      0.96      0.96        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 0.4643510580062866
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[3 0]
#  [3 6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.50      1.00      0.67         3
#          AFF       1.00      0.67      0.80         9
#
#     accuracy                           0.75        12
#    macro avg       0.75      0.83      0.73        12
# weighted avg       0.88      0.75      0.77        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.16038952628150582
# Total Test Accuracy: 91.04477611940298
# Test Accuracy (NFF): 97.16981132075472
# Test Accuracy (AFF): 67.85714285714286
# Confusion Matrix:
#  [[103   3]
#  [  9  19]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.97      0.94       106
#          AFF       0.86      0.68      0.76        28
#
#     accuracy                           0.91       134
#    macro avg       0.89      0.83      0.85       134
# weighted avg       0.91      0.91      0.91       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.2126905589054028
# Total Test Accuracy: 95.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 67.85714285714286
# Confusion Matrix:
#  [[152   0]
#  [  9  19]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      1.00      0.97       152
#          AFF       1.00      0.68      0.81        28
#
#     accuracy                           0.95       180
#    macro avg       0.97      0.84      0.89       180
# weighted avg       0.95      0.95      0.95       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.481038898229599
# Total Test Accuracy: 87.5
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 61.53846153846154
# Confusion Matrix:
#  [[27  0]
#  [ 5  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      1.00      0.92        27
#          AFF       1.00      0.62      0.76        13
#
#     accuracy                           0.88        40
#    macro avg       0.92      0.81      0.84        40
# weighted avg       0.89      0.88      0.87        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 0.19848094880580902
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 58:
#
# Test Loss: 0.5300102829933167
# Total Test Accuracy: 85.96491228070175
# Test Accuracy (NFF): 89.65517241379311
# Test Accuracy (AFF): 82.14285714285714
# Confusion Matrix:
#  [[26  3]
#  [ 5 23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      0.90      0.87        29
#          AFF       0.88      0.82      0.85        28
#
#     accuracy                           0.86        57
#    macro avg       0.86      0.86      0.86        57
# weighted avg       0.86      0.86      0.86        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.00626797741279006
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.25405772775411606
# Total Test Accuracy: 92.6829268292683
# Test Accuracy (NFF): 99.0
# Test Accuracy (AFF): 65.21739130434783
# Confusion Matrix:
#  [[99  1]
#  [ 8 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.99      0.96       100
#          AFF       0.94      0.65      0.77        23
#
#     accuracy                           0.93       123
#    macro avg       0.93      0.82      0.86       123
# weighted avg       0.93      0.93      0.92       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.38052499294281006
# Total Test Accuracy: 84.12698412698413
# Test Accuracy (NFF): 93.47826086956522
# Test Accuracy (AFF): 58.82352941176471
# Confusion Matrix:
#  [[43  3]
#  [ 7 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.86      0.93      0.90        46
#          AFF       0.77      0.59      0.67        17
#
#     accuracy                           0.84        63
#    macro avg       0.81      0.76      0.78        63
# weighted avg       0.84      0.84      0.83        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 0.35397255420684814
# Total Test Accuracy: 88.67924528301887
# Test Accuracy (NFF): 95.1219512195122
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[39  2]
#  [ 4  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.95      0.93        41
#          AFF       0.80      0.67      0.73        12
#
#     accuracy                           0.89        53
#    macro avg       0.85      0.81      0.83        53
# weighted avg       0.88      0.89      0.88        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 0.06444691121578217
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.048967741429805756
# Total Test Accuracy: 96.875
# Test Accuracy (NFF): 96.875
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[31  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.97      0.98        32
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.97        32
#    macro avg       0.50      0.98      0.49        32
# weighted avg       1.00      0.97      0.98        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.13629049062728882
# Total Test Accuracy: 90.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[8 0]
#  [1 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      1.00      0.94         8
#          AFF       1.00      0.50      0.67         2
#
#     accuracy                           0.90        10
#    macro avg       0.94      0.75      0.80        10
# weighted avg       0.91      0.90      0.89        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.5605993270874023
# Total Test Accuracy: 81.81818181818181
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 20.0
# Confusion Matrix:
#  [[17  0]
#  [ 4  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      1.00      0.89        17
#          AFF       1.00      0.20      0.33         5
#
#     accuracy                           0.82        22
#    macro avg       0.90      0.60      0.61        22
# weighted avg       0.85      0.82      0.77        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.28198322653770447
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 42.857142857142854
# Confusion Matrix:
#  [[29  0]
#  [ 4  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      1.00      0.94        29
#          AFF       1.00      0.43      0.60         7
#
#     accuracy                           0.89        36
#    macro avg       0.94      0.71      0.77        36
# weighted avg       0.90      0.89      0.87        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.2645209107834559
# Total Test Accuracy: 90.64039408866995
# Test Accuracy (NFF): 96.9558599695586
# Test Accuracy (AFF): 63.87096774193548
# Confusion Matrix:
#  [[637  20]
#  [ 56  99]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.97      0.94       657
#          AFF       0.83      0.64      0.72       155
#
#     accuracy                           0.91       812
#    macro avg       0.88      0.80      0.83       812
# weighted avg       0.90      0.91      0.90       812
#
#
# Average Total Test Accuracy: 92.72638544136205
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Efficient B2

# %%
# from torchvision.models import efficientnet_b2, EfficientNet_B2_Weights

# torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# # Define the EfficientNetV2-M model
# model = efficientnet_b2(weights=EfficientNet_B2_Weights.DEFAULT)

# # Access input features of the classifier
# num_features = model.classifier[1].in_features

# # Modify the classifier part of the model
# model.classifier[1] = nn.Linear(in_features=num_features, out_features=2)

# # Freeze certain layers
# total_layers = len(list(model.children()))
# freeze_layers = int(total_layers * 0.5)
# for index, child in enumerate(model.children()):
#     if index < freeze_layers:
#         for param in child.parameters():
#             param.requires_grad = False

# # Hyperparameters
# num_epochs = 20
# batch_size = 8
# learning_rate = 0.0001
# optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# # Move model to GPU if available
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# model = model.to(device)

# # Train the model
# effi_b2 = train_custom_model(model, train_dataset, num_epochs=num_epochs, batch_size=batch_size, optimizer=optimizer)
