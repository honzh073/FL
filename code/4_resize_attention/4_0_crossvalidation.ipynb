# %% [markdown]
# # Create all image path csv files

# %%
import os
import csv

def create_csv(image_folder, csv_file_path):
    # Define the CSV header fields
    fieldnames = ['HospitalID', 'PatientID', 'ImageID', 'ImagePath', 'Label']
    
    # Open the CSV file in write mode
    with open(csv_file_path, 'w', newline='') as csvfile:
        # Create a CSV writer object and write the header
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        # Iterate through files in the folder
        for filename in sorted(os.listdir(image_folder)):
            # Construct the complete image file path
            image_path = os.path.join(image_folder, filename)
            
            # Parse the filename to extract HospitalID, PatientID, image number, and image label
            parts = filename.split('_')
            
            # Check if the parts list contains enough elements
            if len(parts) >= 7:
                hospital_id = parts[3]
                patient_id = parts[1]
                image_number = parts[6]
                image_label = parts[4]

                # Write data into the CSV file
                writer.writerow({
                    'HospitalID': hospital_id,
                    'PatientID': patient_id,
                    'ImageID': image_number,
                    'ImagePath': image_path,
                    'Label': image_label
                })
            else:
                # Print the filename that caused the issue
                print(f"Skipping file: {filename} due to insufficient parts.")

    # Print a message indicating that the CSV file has been created and saved
    print("CSV file has been created and saved to:", csv_file_path)

# Call the function with your image_folder and csv_file_path values
image_folder = "/local/data1/honzh073/data/Hospital_processed"
csv_file_path = "/local/data1/honzh073/local_repo/FL/code/4_resize_attention/image_path.csv"
create_csv(image_folder, csv_file_path)
# Out:
# Skipping file: .DS_Store due to insufficient parts.
# CSV file has been created and saved to: /local/data1/honzh073/local_repo/FL/code/4_resize_attention/image_path.csv

# %% [markdown]
# # create train, val csv

# %%
import csv
from collections import defaultdict
import random

def split_and_save_data(input_csv_path, output_folder, target_hospital_ids, train_ratio, seed):
    patient_data = defaultdict(list)
    
    with open(input_csv_path, 'r') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            if row['HospitalID'] in target_hospital_ids:
                patient_id = row['PatientID']
                patient_data[patient_id].append(row)

    num_patients = len(patient_data)

    num_train = int(num_patients * train_ratio)

    # get random IDs
    all_patient_ids = list(patient_data.keys())

    random.seed(seed)
    random.shuffle(all_patient_ids)

    # split by ID
    train_patients = all_patient_ids[ : num_train]
    test_patients = all_patient_ids[num_train: ]

    # iter by patient IDs
    train_data = []
    test_data = []

    for patient_id, images in patient_data.items():
        if patient_id in train_patients:
            train_data.extend(images)
        elif patient_id in test_patients:
            test_data.extend(images)

    # write to csv
    def write_to_csv(file_path, data):
        with open(file_path, 'w', newline='') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=data[0].keys())
            writer.writeheader()
            writer.writerows(data)

    # Write to CSV files
    write_to_csv(os.path.join(output_folder, 'cross_train.csv'), train_data)
    write_to_csv(os.path.join(output_folder, 'cross_test.csv'), test_data)
    
    print("Saved train.csv, test.csv.")

# input and output path
input_csv_path = "/local/data1/honzh073/local_repo/FL/code/4_resize_attention/image_path.csv"
output_folder = '/local/data1/honzh073/local_repo/FL/code/4_resize_attention'

# single hospital id
target_hospital_ids = ['43']

# random seed
seed = 1

# train and val dataset ratio
train_ratio = 0.7
# test_ratio = 0.3 # unnecessary

split_and_save_data(input_csv_path, output_folder,
                    train_ratio=train_ratio,
                    target_hospital_ids = target_hospital_ids,
                    seed = seed)
# Out:
# Saved train.csv, test.csv.

# %% [markdown]
# # functions

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import models
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_curve, roc_auc_score
   
def plot_roc_curve(all_labels, all_predictions):
    fpr, tpr, thresholds = roc_curve(all_labels, all_predictions)
    roc_auc = roc_auc_score(all_labels, all_predictions)

    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc='lower right')
    plt.show()

def show_image(dataset, num_images=5):
    # Get random indices
    random_indices = np.random.choice(len(dataset), num_images, replace=False)

    # Plot images with truncated names
    plt.figure(figsize=(15, 5))
    for i, idx in enumerate(random_indices):
        image, label = dataset[idx]  # Use the dataset directly
        filename = dataset.data[idx][0]  # Get the filename from dataset's internal data attribute
        truncated_filename = filename.split('/')[-1][:15]  # Extract the last part and truncate to 15 characters
        
        # Print the original filename
        print(f"Image location: {filename}")

        plt.subplot(1, num_images, i + 1)
        plt.title(f"Label: {label}")
        plt.imshow(image[0])  # Assuming single-channel (grayscale) image
        # plt.imshow(image[0], cmap='gray')  # Assuming single-channel (grayscale) image

        plt.axis('off')
    plt.show()
    
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_classweight(train_dataset):
    train_nff_count = sum(1 for _, label in train_dataset if label == 0)  # 0 NFF
    train_aff_count = sum(1 for _, label in train_dataset if label == 1)  # 1 AFF
    class_weight_nff = 1 / (2 * (train_nff_count / (train_nff_count + train_aff_count)))
    class_weight_aff = 1 / (2 * (train_aff_count / (train_nff_count + train_aff_count)))
    
    return [class_weight_nff, class_weight_aff] # 0 nff , 1 aff


def test_model(model, test_dataset, batch_size):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)
    model.eval()
    
    correct_test = 0
    total_test = 0
    test_loss = 0
    
    criterion = nn.CrossEntropyLoss()
    
    with torch.no_grad():
        all_predictions = []
        all_labels = []
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            _, predicted = torch.max(outputs.data, 1)
            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            total_test += labels.size(0)
            correct_test += (predicted == labels).sum().item()
            test_loss += loss.item()

    test_accuracy = 100 * correct_test / total_test
    test_loss /= len(test_loader)

    print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_accuracy:.2f}%")
     
    auc_score = roc_auc_score(all_labels, all_predictions)
    conf_matrix = confusion_matrix(all_labels, all_predictions)
    
    # Precision、Recall、F1 Score
    class_labels = {0: 'NFF', 1: 'AFF'}

    classification_rep = classification_report(all_labels, all_predictions, target_names=[class_labels[i] for i in range(len(class_labels))])
    print("AUC:", auc_score)
    print("Confusion Matrix:")
    print(conf_matrix)
    print("Classification Report:")
    print(classification_rep)

    plot_roc_curve(all_labels, all_predictions)

# %% [markdown]
# # Custom dataset and transform

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import csv
import pandas as pd
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, models
from sklearn.model_selection import KFold

# Custom dataset class
class CustomDataset(Dataset):
    def __init__(self, csv_file, transform=None):
        self.data = []
        self.labels = []  # Store labels separately
        self.patient_ids = []  # Store patient IDs separately
        self.transform = transform
        
        # read csv
        with open(csv_file, 'r') as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                image_path = row['ImagePath']
                label = row['Label']
                patient_id = row['PatientID']  # Assuming 'PatientID' is the column name in your CSV file

                if label == 'NFF':
                    label = 0
                elif label == 'AFF':
                    label = 1
                else:
                    raise ValueError("Invalid label in CSV file.")
                self.data.append((image_path, label))
                self.labels.append(label)
                self.patient_ids.append(patient_id)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image_path, label = self.data[idx]
        image = Image.open(image_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image, label

# Define your image transformations for training and testing
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomRotation(degrees=20),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.GaussianBlur(kernel_size=3),
    transforms.RandomAdjustSharpness(sharpness_factor=5),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load the datasets using CustomDataset class
train_dataset = CustomDataset('/local/data1/honzh073/local_repo/FL/code/4_resize_attention/cross_train.csv', transform=train_transform)
test_dataset = CustomDataset('/local/data1/honzh073/local_repo/FL/code/4_resize_attention/cross_test.csv', transform=test_transform)

# classweight
classweight = get_classweight(train_dataset)
print('training class weight', classweight)

# device
# device = torch.device("cuda:0" if  torch.cuda.is_available() else "cpu")

# print images
show_image(train_dataset, 10)

# calculate numbers
print("Saved train.csv, val.csv, test.csv.")
print('-----------------------------------')
train_NFF_count = sum(1 for _, label in train_dataset if label == 0)  # 0 NFF
train_AFF_count = sum(1 for _, label in train_dataset if label == 1)  # 1 AFF
test_NFF_count = sum(1 for _, label in test_dataset if label == 0)  # 0 NFF
test_AFF_count = sum(1 for _, label in test_dataset if label == 1)  # 1 AFF

print(f"train AFF: {train_AFF_count}, ratio: {train_AFF_count / (train_AFF_count + train_NFF_count):.2f}")
print(f"----- NFF: {train_NFF_count}, ratio: {train_NFF_count / (train_AFF_count + train_NFF_count):.2f}")
print('-----------------------------------')
print(f"test AFF: {test_AFF_count}, ratio: {test_AFF_count / (test_AFF_count + test_NFF_count):.2f}")
print(f"---- NFF: {test_NFF_count}, ratio: {test_NFF_count / (test_AFF_count + test_NFF_count):.2f}")
# Out:
# training class weight [0.7336448598130841, 1.57]
# Image location: /local/data1/honzh073/data/Hospital_processed/patient_IHUZCYWODS_hospital_43_AFF_image_1.png
# Image location: /local/data1/honzh073/data/Hospital_processed/patient_MMOQGMWSNT_hospital_43_AFF_image_2.png
# Image location: /local/data1/honzh073/data/Hospital_processed/patient_RCQOXVJTTC_hospital_43_AFF_image_2.png
# Image location: /local/data1/honzh073/data/Hospital_processed/patient_HVTVEBPSCC_hospital_43_NFF_image_1.png
# Image location: /local/data1/honzh073/data/Hospital_processed/patient_UBHHXPNTCW_hospital_43_NFF_image_2.png
# Image location: /local/data1/honzh073/data/Hospital_processed/patient_JTCVKHWOJN_hospital_43_AFF_image_1.png
# Image location: /local/data1/honzh073/data/Hospital_processed/patient_UVSPTMWBZC_hospital_43_NFF_image_3.png
# Image location: /local/data1/honzh073/data/Hospital_processed/patient_TADAVBRLUJ_hospital_43_NFF_image_1.png
# Image location: /local/data1/honzh073/data/Hospital_processed/patient_HOZSVLMOGT_hospital_43_NFF_image_3.png
# Image location: /local/data1/honzh073/data/Hospital_processed/patient_NUJLYDBSYC_hospital_43_NFF_image_3.png
# Saved train.csv, val.csv, test.csv.
# -----------------------------------
# train AFF: 50, ratio: 0.32
# ----- NFF: 107, ratio: 0.68
# -----------------------------------
# test AFF: 22, ratio: 0.27
# ---- NFF: 60, ratio: 0.73

# %% [markdown]
# # ResNet 101

# %%
from sklearn.model_selection import StratifiedKFold
from torchvision.models import resnet101, ResNet101_Weights

classweight = get_classweight(train_dataset)

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Define the ResNet-101 model
model = models.resnet101(weights=ResNet101_Weights.DEFAULT)

num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)  # Assuming 2 classes, change it according to your problem
model = model.to(device)
# ------------------------------------------------------------------------------------------
# # 冻结除最后一层之外的所有层
# for param in model.parameters():
#     param.requires_grad = False

# # 解冻最后一层
# for param in model.fc.parameters():
#     param.requires_grad = True
    
# # Define your loss function and optimizer
criterion = nn.CrossEntropyLoss(weight=torch.Tensor(classweight).to(device))

optimizer = optim.RMSprop(model.parameters(), lr=0.0001)
scheduler = lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
# ------------------------------------------------------------------------------------------

# # 找到冻结起始的层（假设从layer3开始冻结）
# # 冻结conv4之前的所有层
# for name, param in model.named_parameters():
#     if 'layer3' in name:  # 这里假设conv4的层名是'layer4'，你可以根据实际模型结构进行调整
#         break
#     param.requires_grad = False

# # 定义损失函数和优化器
# criterion = nn.CrossEntropyLoss(weight=torch.Tensor(classweight).to(device))
# optimizer = optim.RMSprop(filter(lambda p: p.requires_grad, model.parameters()), lr=0.001)
# scheduler = lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
# ------------------------------------------------------------------------------------------


# Define the number of splits for cross-validation
n_splits = 5
# kf = KFold(n_splits=n_splits, shuffle=True, random_state=1)
kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=1)

# k-fold cross-validation
for fold, (train_idx, val_idx) in enumerate(kf.split(range(len(train_dataset)), train_dataset.patient_ids)):

# for fold, (train_idx, val_idx) in enumerate(kf.split(range(len(train_dataset)))):
    print(f'Fold {fold + 1}/{n_splits}')

    # Create data loaders for training and validation subsets
    train_sampler = torch.utils.data.SubsetRandomSampler(train_idx)
    val_sampler = torch.utils.data.SubsetRandomSampler(val_idx)

    train_loader = DataLoader(train_dataset, batch_size=16, sampler=train_sampler)
    val_loader = DataLoader(train_dataset, batch_size=16, sampler=val_sampler)

    # Training loop
    num_epochs = 30  # Choose the number of epochs
    
    # Loss, ACC
    train_losses = []
    validation_losses = []
    train_accuracies = []
    validation_accuracies = []
    
    for epoch in range(num_epochs):
        model.train()
        correct_train = 0
        total_train = 0
        
        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
        
        train_accuracy = 100 * correct_train / total_train
        
        model.eval()
        correct_validation_aff = 0
        total_validation_aff = 0
        correct_validation = 0
        total_validation = 0
        validation_loss = 0
        
        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                
                outputs = model(images)
                loss = criterion(outputs, labels)
                
                _, predicted = torch.max(outputs.data, 1)
                total_validation += labels.size(0)
                correct_validation += (predicted == labels).sum().item()
                validation_loss += loss.item()
                # Calculate accuracy for AFF class
                total_validation_aff += torch.sum(labels == 1).item()
                correct_validation_aff += torch.sum((predicted == 1) & (labels == 1)).item()

        # validation_accuracy_aff = 100 * correct_validation_aff / total_validation_aff

        # validation accuracy and loss
        validation_accuracy = 100 * correct_validation / total_validation
        validation_loss /= len(val_loader)
        
        train_losses.append(loss.item())
        validation_losses.append(validation_loss)
        train_accuracies.append(train_accuracy)
        validation_accuracies.append(validation_accuracy)
        
        print(f"Epoch {epoch+1}/{num_epochs}, "
            f"train Loss: {loss.item():.4f}, "
            f"val Loss: {validation_loss:.4f}, "
            f"train ACC: {train_accuracy:.2f}%, "
            f"Val ACC: {validation_accuracy:.2f}%")
    scheduler.step()
        
    # Plot train/val loss,  accuracy
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Train Loss')
    plt.plot(validation_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(train_accuracies, label='Train Accuracy')
    plt.plot(validation_accuracies, label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.legend() 

    plt.show()
# Out:
# /local/data1/honzh073/anaconda3/envs/myenv/lib/python3.9/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# Fold 1/5
# Epoch 1/30, train Loss: 0.5894, val Loss: 0.4991, train ACC: 58.40%, Val ACC: 75.00%
# Epoch 2/30, train Loss: 0.1784, val Loss: 0.3147, train ACC: 74.40%, Val ACC: 84.38%
# Epoch 3/30, train Loss: 0.3448, val Loss: 0.9493, train ACC: 85.60%, Val ACC: 71.88%
# Epoch 4/30, train Loss: 0.1246, val Loss: 0.1829, train ACC: 86.40%, Val ACC: 90.62%
# Epoch 5/30, train Loss: 0.3322, val Loss: 0.3598, train ACC: 81.60%, Val ACC: 84.38%
# Epoch 6/30, train Loss: 0.3296, val Loss: 0.2117, train ACC: 86.40%, Val ACC: 84.38%
# Epoch 7/30, train Loss: 0.1393, val Loss: 0.1622, train ACC: 88.80%, Val ACC: 93.75%
# Epoch 8/30, train Loss: 0.3007, val Loss: 0.2293, train ACC: 89.60%, Val ACC: 90.62%
# Epoch 9/30, train Loss: 0.1153, val Loss: 0.1561, train ACC: 88.00%, Val ACC: 90.62%
# Epoch 10/30, train Loss: 0.0785, val Loss: 0.1511, train ACC: 91.20%, Val ACC: 93.75%
# Epoch 11/30, train Loss: 0.0839, val Loss: 0.1880, train ACC: 92.00%, Val ACC: 93.75%
# Epoch 12/30, train Loss: 0.1269, val Loss: 0.2005, train ACC: 95.20%, Val ACC: 93.75%
# Epoch 13/30, train Loss: 0.0642, val Loss: 0.0988, train ACC: 98.40%, Val ACC: 96.88%
# Epoch 14/30, train Loss: 0.0444, val Loss: 0.1456, train ACC: 96.00%, Val ACC: 96.88%
# Epoch 15/30, train Loss: 0.0756, val Loss: 0.1963, train ACC: 98.40%, Val ACC: 90.62%
# Epoch 16/30, train Loss: 0.0560, val Loss: 0.0852, train ACC: 95.20%, Val ACC: 93.75%
# Epoch 17/30, train Loss: 0.1249, val Loss: 0.0773, train ACC: 96.80%, Val ACC: 90.62%
# Epoch 18/30, train Loss: 0.1961, val Loss: 0.1273, train ACC: 96.00%, Val ACC: 93.75%
# Epoch 19/30, train Loss: 0.0297, val Loss: 0.1090, train ACC: 94.40%, Val ACC: 93.75%
# Epoch 20/30, train Loss: 0.2362, val Loss: 0.1833, train ACC: 96.00%, Val ACC: 93.75%
# Epoch 21/30, train Loss: 0.0781, val Loss: 0.1649, train ACC: 99.20%, Val ACC: 96.88%
# Epoch 22/30, train Loss: 0.1955, val Loss: 0.1446, train ACC: 99.20%, Val ACC: 96.88%
# Epoch 23/30, train Loss: 0.0525, val Loss: 0.1184, train ACC: 98.40%, Val ACC: 96.88%
# Epoch 24/30, train Loss: 0.3561, val Loss: 0.2392, train ACC: 99.20%, Val ACC: 93.75%
# Epoch 25/30, train Loss: 0.2663, val Loss: 0.1516, train ACC: 96.80%, Val ACC: 96.88%
# Epoch 26/30, train Loss: 0.2472, val Loss: 0.1696, train ACC: 98.40%, Val ACC: 93.75%
# Epoch 27/30, train Loss: 0.3047, val Loss: 0.2062, train ACC: 97.60%, Val ACC: 93.75%
# Epoch 28/30, train Loss: 0.2993, val Loss: 0.1567, train ACC: 97.60%, Val ACC: 90.62%
# Epoch 29/30, train Loss: 0.0736, val Loss: 0.0549, train ACC: 96.80%, Val ACC: 96.88%
# Epoch 30/30, train Loss: 0.0086, val Loss: 0.0731, train ACC: 99.20%, Val ACC: 96.88%
# Fold 2/5
# Epoch 1/30, train Loss: 0.0093, val Loss: 0.0134, train ACC: 96.80%, Val ACC: 100.00%
# Epoch 2/30, train Loss: 0.0420, val Loss: 0.2140, train ACC: 97.60%, Val ACC: 93.75%
# Epoch 3/30, train Loss: 0.1171, val Loss: 0.0643, train ACC: 98.40%, Val ACC: 96.88%
# Epoch 4/30, train Loss: 0.0372, val Loss: 0.0328, train ACC: 97.60%, Val ACC: 100.00%
# Epoch 5/30, train Loss: 0.0101, val Loss: 0.0140, train ACC: 98.40%, Val ACC: 100.00%
# Epoch 6/30, train Loss: 0.0053, val Loss: 0.0205, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 7/30, train Loss: 0.0189, val Loss: 0.0202, train ACC: 96.80%, Val ACC: 100.00%
# Epoch 8/30, train Loss: 0.0080, val Loss: 0.0114, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 9/30, train Loss: 0.0149, val Loss: 0.0267, train ACC: 99.20%, Val ACC: 100.00%
# Epoch 10/30, train Loss: 0.0214, val Loss: 0.0209, train ACC: 98.40%, Val ACC: 100.00%
# Epoch 11/30, train Loss: 0.0893, val Loss: 0.0754, train ACC: 96.00%, Val ACC: 100.00%
# Epoch 12/30, train Loss: 0.0123, val Loss: 0.0554, train ACC: 96.80%, Val ACC: 100.00%
# Epoch 13/30, train Loss: 0.0756, val Loss: 0.0482, train ACC: 99.20%, Val ACC: 96.88%
# Epoch 14/30, train Loss: 0.2905, val Loss: 0.1664, train ACC: 98.40%, Val ACC: 96.88%
# Epoch 15/30, train Loss: 0.0131, val Loss: 0.0136, train ACC: 97.60%, Val ACC: 100.00%
# Epoch 16/30, train Loss: 0.0440, val Loss: 0.0292, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 17/30, train Loss: 0.0040, val Loss: 0.0555, train ACC: 96.80%, Val ACC: 96.88%
# Epoch 18/30, train Loss: 0.0462, val Loss: 0.0572, train ACC: 98.40%, Val ACC: 96.88%
# Epoch 19/30, train Loss: 0.0461, val Loss: 0.0305, train ACC: 98.40%, Val ACC: 100.00%
# Epoch 20/30, train Loss: 0.0510, val Loss: 0.0399, train ACC: 98.40%, Val ACC: 100.00%
# Epoch 21/30, train Loss: 0.0048, val Loss: 0.0816, train ACC: 100.00%, Val ACC: 96.88%
# Epoch 22/30, train Loss: 0.0136, val Loss: 0.0736, train ACC: 97.60%, Val ACC: 96.88%
# Epoch 23/30, train Loss: 0.0515, val Loss: 0.0676, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 24/30, train Loss: 0.0465, val Loss: 0.1818, train ACC: 99.20%, Val ACC: 96.88%
# Epoch 25/30, train Loss: 0.0535, val Loss: 0.1623, train ACC: 99.20%, Val ACC: 96.88%
# Epoch 26/30, train Loss: 0.0033, val Loss: 0.0249, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 27/30, train Loss: 0.0228, val Loss: 0.0304, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 28/30, train Loss: 0.0193, val Loss: 0.0334, train ACC: 99.20%, Val ACC: 100.00%
# Epoch 29/30, train Loss: 0.0226, val Loss: 0.0454, train ACC: 99.20%, Val ACC: 100.00%
# Epoch 30/30, train Loss: 0.0545, val Loss: 0.0536, train ACC: 100.00%, Val ACC: 100.00%
# Fold 3/5
# Epoch 1/30, train Loss: 0.0052, val Loss: 0.0041, train ACC: 98.41%, Val ACC: 100.00%
# Epoch 2/30, train Loss: 0.0861, val Loss: 0.0444, train ACC: 97.62%, Val ACC: 100.00%
# Epoch 3/30, train Loss: 0.0018, val Loss: 0.0011, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 4/30, train Loss: 0.0046, val Loss: 0.0043, train ACC: 97.62%, Val ACC: 100.00%
# Epoch 5/30, train Loss: 0.0036, val Loss: 0.0036, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 6/30, train Loss: 0.0008, val Loss: 0.0176, train ACC: 98.41%, Val ACC: 100.00%
# Epoch 7/30, train Loss: 0.0018, val Loss: 0.0066, train ACC: 97.62%, Val ACC: 100.00%
# Epoch 8/30, train Loss: 0.0008, val Loss: 0.0007, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 9/30, train Loss: 0.0037, val Loss: 0.0057, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 10/30, train Loss: 0.0031, val Loss: 0.0111, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 11/30, train Loss: 0.0812, val Loss: 0.0429, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 12/30, train Loss: 0.0185, val Loss: 0.0300, train ACC: 98.41%, Val ACC: 100.00%
# Epoch 13/30, train Loss: 0.3348, val Loss: 0.1859, train ACC: 99.21%, Val ACC: 96.77%
# Epoch 14/30, train Loss: 0.0249, val Loss: 0.0227, train ACC: 94.44%, Val ACC: 100.00%
# Epoch 15/30, train Loss: 0.0091, val Loss: 0.0069, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 16/30, train Loss: 0.0199, val Loss: 0.0140, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 17/30, train Loss: 0.0108, val Loss: 0.0094, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 18/30, train Loss: 0.0029, val Loss: 0.0051, train ACC: 98.41%, Val ACC: 100.00%
# Epoch 19/30, train Loss: 0.0017, val Loss: 0.0041, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 20/30, train Loss: 0.0093, val Loss: 0.0092, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 21/30, train Loss: 0.0335, val Loss: 0.0190, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 22/30, train Loss: 0.0111, val Loss: 0.0066, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 23/30, train Loss: 0.0014, val Loss: 0.0019, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 24/30, train Loss: 0.0014, val Loss: 0.0016, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 25/30, train Loss: 0.0028, val Loss: 0.0023, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 26/30, train Loss: 0.0020, val Loss: 0.0018, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 27/30, train Loss: 0.0008, val Loss: 0.0026, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 28/30, train Loss: 0.0031, val Loss: 0.0084, train ACC: 98.41%, Val ACC: 100.00%
# Epoch 29/30, train Loss: 0.0006, val Loss: 0.0197, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 30/30, train Loss: 0.0036, val Loss: 0.0064, train ACC: 99.21%, Val ACC: 100.00%
# Fold 4/5
# Epoch 1/30, train Loss: 0.0196, val Loss: 0.0108, train ACC: 98.41%, Val ACC: 100.00%
# Epoch 2/30, train Loss: 0.0041, val Loss: 0.0025, train ACC: 98.41%, Val ACC: 100.00%
# Epoch 3/30, train Loss: 0.0148, val Loss: 0.0166, train ACC: 96.03%, Val ACC: 100.00%
# Epoch 4/30, train Loss: 0.0088, val Loss: 0.0051, train ACC: 98.41%, Val ACC: 100.00%
# Epoch 5/30, train Loss: 0.0065, val Loss: 0.0056, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 6/30, train Loss: 0.0019, val Loss: 0.0023, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 7/30, train Loss: 0.0764, val Loss: 0.0407, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 8/30, train Loss: 0.0057, val Loss: 0.0065, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 9/30, train Loss: 0.0017, val Loss: 0.0014, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 10/30, train Loss: 0.0020, val Loss: 0.0779, train ACC: 100.00%, Val ACC: 96.77%
# Epoch 11/30, train Loss: 0.3140, val Loss: 0.1572, train ACC: 100.00%, Val ACC: 96.77%
# Epoch 12/30, train Loss: 0.0036, val Loss: 0.0028, train ACC: 97.62%, Val ACC: 100.00%
# Epoch 13/30, train Loss: 0.0026, val Loss: 0.1144, train ACC: 100.00%, Val ACC: 96.77%
# Epoch 14/30, train Loss: 0.4169, val Loss: 0.2098, train ACC: 100.00%, Val ACC: 96.77%
# Epoch 15/30, train Loss: 0.0371, val Loss: 0.0206, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 16/30, train Loss: 0.0896, val Loss: 0.0532, train ACC: 100.00%, Val ACC: 96.77%
# Epoch 17/30, train Loss: 0.0410, val Loss: 0.0220, train ACC: 97.62%, Val ACC: 100.00%
# Epoch 18/30, train Loss: 0.0032, val Loss: 0.0062, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 19/30, train Loss: 0.0070, val Loss: 0.0169, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 20/30, train Loss: 0.0300, val Loss: 0.0564, train ACC: 100.00%, Val ACC: 96.77%
# Epoch 21/30, train Loss: 0.0017, val Loss: 0.0136, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 22/30, train Loss: 0.0007, val Loss: 0.0012, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 23/30, train Loss: 0.0000, val Loss: 0.0033, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 24/30, train Loss: 0.0474, val Loss: 0.0248, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 25/30, train Loss: 0.0592, val Loss: 0.0337, train ACC: 100.00%, Val ACC: 96.77%
# Epoch 26/30, train Loss: 0.0808, val Loss: 0.0532, train ACC: 100.00%, Val ACC: 96.77%
# Epoch 27/30, train Loss: 0.0111, val Loss: 0.0056, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 28/30, train Loss: 0.0003, val Loss: 0.0022, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 29/30, train Loss: 0.0010, val Loss: 0.0752, train ACC: 100.00%, Val ACC: 96.77%
# Epoch 30/30, train Loss: 0.0000, val Loss: 0.0005, train ACC: 100.00%, Val ACC: 100.00%
# Fold 5/5
# Epoch 1/30, train Loss: 0.0001, val Loss: 0.0001, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 2/30, train Loss: 0.0002, val Loss: 0.0001, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 3/30, train Loss: 0.0004, val Loss: 0.0007, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 4/30, train Loss: 0.0019, val Loss: 0.0503, train ACC: 97.62%, Val ACC: 96.77%
# Epoch 5/30, train Loss: 0.0016, val Loss: 0.0023, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 6/30, train Loss: 0.0001, val Loss: 0.0008, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 7/30, train Loss: 0.0042, val Loss: 0.0026, train ACC: 96.03%, Val ACC: 100.00%
# Epoch 8/30, train Loss: 0.0018, val Loss: 0.0040, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 9/30, train Loss: 0.0055, val Loss: 0.0081, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 10/30, train Loss: 0.0084, val Loss: 0.0094, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 11/30, train Loss: 0.0207, val Loss: 0.0124, train ACC: 97.62%, Val ACC: 100.00%
# Epoch 12/30, train Loss: 0.0067, val Loss: 0.0041, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 13/30, train Loss: 0.0054, val Loss: 0.0029, train ACC: 98.41%, Val ACC: 100.00%
# Epoch 14/30, train Loss: 0.0048, val Loss: 0.0090, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 15/30, train Loss: 0.0033, val Loss: 0.0037, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 16/30, train Loss: 0.0003, val Loss: 0.0014, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 17/30, train Loss: 0.0069, val Loss: 0.0036, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 18/30, train Loss: 0.0002, val Loss: 0.0005, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 19/30, train Loss: 0.0287, val Loss: 0.0146, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 20/30, train Loss: 0.0004, val Loss: 0.0003, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 21/30, train Loss: 0.0001, val Loss: 0.0003, train ACC: 98.41%, Val ACC: 100.00%
# Epoch 22/30, train Loss: 0.0001, val Loss: 0.0003, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 23/30, train Loss: 0.0044, val Loss: 0.0042, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 24/30, train Loss: 0.0002, val Loss: 0.0008, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 25/30, train Loss: 0.0002, val Loss: 0.0002, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 26/30, train Loss: 0.0241, val Loss: 0.0122, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 27/30, train Loss: 0.0005, val Loss: 0.0011, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 28/30, train Loss: 0.0010, val Loss: 0.0012, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 29/30, train Loss: 0.0001, val Loss: 0.0124, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 30/30, train Loss: 0.0000, val Loss: 0.0000, train ACC: 100.00%, Val ACC: 100.00%

# %%
# Resnet 101
test_model(model=model, test_dataset=test_dataset, batch_size=16)
# Out:
# Test Loss: 0.1085, Test Acc: 96.34%
# AUC: 0.9318181818181819
# Confusion Matrix:
# [[60  0]
#  [ 3 19]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          NFF       0.95      1.00      0.98        60
#          AFF       1.00      0.86      0.93        22
#
#     accuracy                           0.96        82
#    macro avg       0.98      0.93      0.95        82
# weighted avg       0.97      0.96      0.96        82

# %% [markdown]
# # ResNet 152

# %%
from sklearn.model_selection import StratifiedKFold
from torchvision.models import resnet152, ResNet152_Weights

classweight = get_classweight(train_dataset)

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Define the ResNet-101 model
model = models.resnet152(weights=ResNet152_Weights.DEFAULT)
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)  # Assuming 2 classes, change it according to your problem
model = model.to(device)

# Define your loss function and optimizer
criterion = nn.CrossEntropyLoss()
criterion = nn.CrossEntropyLoss(weight=torch.Tensor(classweight).to(device))

optimizer = optim.RMSprop(model.parameters(), lr=0.0001)
# scheduler = lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# Define the number of splits for cross-validation
n_splits = 5
# kf = KFold(n_splits=n_splits, shuffle=True, random_state=1)
kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=1)
# Perform k-fold cross-validation
for fold, (train_idx, val_idx) in enumerate(kf.split(range(len(train_dataset)), train_dataset.patient_ids)):

# for fold, (train_idx, val_idx) in enumerate(kf.split(range(len(train_dataset)))):
    print(f'Fold {fold + 1}/{n_splits}')

    # Create data loaders for training and validation subsets
    train_sampler = torch.utils.data.SubsetRandomSampler(train_idx)
    val_sampler = torch.utils.data.SubsetRandomSampler(val_idx)

    train_loader = DataLoader(train_dataset, batch_size=16, sampler=train_sampler)
    val_loader = DataLoader(train_dataset, batch_size=16, sampler=val_sampler)

    # Training loop
    num_epochs = 30  # Choose the number of epochs
        # Loss, ACC
    train_losses = []
    validation_losses = []
    train_accuracies = []
    validation_accuracies = []
    
    for epoch in range(num_epochs):
        model.train()
        correct_train = 0
        total_train = 0
        
        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
        
        train_accuracy = 100 * correct_train / total_train
        
        model.eval()
        correct_validation_aff = 0
        total_validation_aff = 0
        correct_validation = 0
        total_validation = 0
        validation_loss = 0
        
        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                
                outputs = model(images)
                loss = criterion(outputs, labels)
                
                _, predicted = torch.max(outputs.data, 1)
                total_validation += labels.size(0)
                correct_validation += (predicted == labels).sum().item()
                validation_loss += loss.item()
                # Calculate accuracy for AFF class
                total_validation_aff += torch.sum(labels == 1).item()
                correct_validation_aff += torch.sum((predicted == 1) & (labels == 1)).item()

        validation_accuracy_aff = 100 * correct_validation_aff / total_validation_aff

        # validation accuracy and loss
        validation_accuracy = 100 * correct_validation / total_validation
        validation_loss /= len(val_loader)
        
        train_losses.append(loss.item())
        validation_losses.append(validation_loss)
        train_accuracies.append(train_accuracy)
        validation_accuracies.append(validation_accuracy)
        
        print(f"Epoch {epoch+1}/{num_epochs}, "
            f"train Loss: {loss.item():.4f}, "
            f"val Loss: {validation_loss:.4f}, "
            f"train ACC: {train_accuracy:.2f}%, "
            f"Val ACC: {validation_accuracy:.2f}%")
        # scheduler.step()
# Out:
# /local/data1/honzh073/anaconda3/envs/myenv/lib/python3.9/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# Fold 1/5
# Epoch 1/30, train Loss: 0.4667, val Loss: 0.4765, train ACC: 61.60%, Val ACC: 90.62%
# Epoch 2/30, train Loss: 0.5143, val Loss: 0.4195, train ACC: 75.20%, Val ACC: 87.50%
# Epoch 3/30, train Loss: 0.3325, val Loss: 0.4116, train ACC: 86.40%, Val ACC: 90.62%
# Epoch 4/30, train Loss: 0.1214, val Loss: 0.2283, train ACC: 88.80%, Val ACC: 90.62%
# Epoch 5/30, train Loss: 0.2843, val Loss: 0.2356, train ACC: 84.80%, Val ACC: 84.38%
# Epoch 6/30, train Loss: 0.2299, val Loss: 0.2775, train ACC: 89.60%, Val ACC: 90.62%
# Epoch 7/30, train Loss: 0.0737, val Loss: 0.1404, train ACC: 92.80%, Val ACC: 96.88%
# Epoch 8/30, train Loss: 0.5098, val Loss: 0.3564, train ACC: 92.00%, Val ACC: 87.50%
# Epoch 9/30, train Loss: 0.0920, val Loss: 0.1381, train ACC: 98.40%, Val ACC: 96.88%
# Epoch 10/30, train Loss: 0.4009, val Loss: 0.2310, train ACC: 94.40%, Val ACC: 90.62%
# Epoch 11/30, train Loss: 0.0709, val Loss: 0.1802, train ACC: 97.60%, Val ACC: 93.75%
# Epoch 12/30, train Loss: 0.0290, val Loss: 0.0930, train ACC: 95.20%, Val ACC: 100.00%
# Epoch 13/30, train Loss: 0.3252, val Loss: 0.1717, train ACC: 92.00%, Val ACC: 96.88%
# Epoch 14/30, train Loss: 0.2612, val Loss: 0.1640, train ACC: 99.20%, Val ACC: 96.88%
# Epoch 15/30, train Loss: 0.2771, val Loss: 0.1685, train ACC: 96.00%, Val ACC: 96.88%
# Epoch 16/30, train Loss: 0.2835, val Loss: 0.1547, train ACC: 97.60%, Val ACC: 96.88%
# Epoch 17/30, train Loss: 0.0354, val Loss: 0.2055, train ACC: 96.00%, Val ACC: 96.88%
# Epoch 18/30, train Loss: 0.0443, val Loss: 0.2111, train ACC: 98.40%, Val ACC: 96.88%
# Epoch 19/30, train Loss: 0.0362, val Loss: 0.1151, train ACC: 97.60%, Val ACC: 96.88%
# Epoch 20/30, train Loss: 0.4562, val Loss: 0.2300, train ACC: 100.00%, Val ACC: 96.88%
# Epoch 21/30, train Loss: 0.0108, val Loss: 0.1286, train ACC: 99.20%, Val ACC: 96.88%
# Epoch 22/30, train Loss: 0.4598, val Loss: 0.2723, train ACC: 99.20%, Val ACC: 93.75%
# Epoch 23/30, train Loss: 0.4878, val Loss: 0.2882, train ACC: 97.60%, Val ACC: 90.62%
# Epoch 24/30, train Loss: 0.1175, val Loss: 0.1722, train ACC: 96.80%, Val ACC: 96.88%
# Epoch 25/30, train Loss: 0.1534, val Loss: 0.1814, train ACC: 97.60%, Val ACC: 90.62%
# Epoch 26/30, train Loss: 0.0218, val Loss: 0.2092, train ACC: 99.20%, Val ACC: 96.88%
# Epoch 27/30, train Loss: 0.1953, val Loss: 0.1364, train ACC: 98.40%, Val ACC: 90.62%
# Epoch 28/30, train Loss: 0.0369, val Loss: 0.2208, train ACC: 99.20%, Val ACC: 96.88%
# Epoch 29/30, train Loss: 0.0088, val Loss: 0.2691, train ACC: 99.20%, Val ACC: 96.88%
# Epoch 30/30, train Loss: 0.0134, val Loss: 0.1081, train ACC: 100.00%, Val ACC: 96.88%
# Fold 2/5
# Epoch 1/30, train Loss: 0.0082, val Loss: 0.0083, train ACC: 96.00%, Val ACC: 100.00%
# Epoch 2/30, train Loss: 0.0281, val Loss: 0.1786, train ACC: 95.20%, Val ACC: 96.88%
# Epoch 3/30, train Loss: 0.0045, val Loss: 0.0135, train ACC: 97.60%, Val ACC: 100.00%
# Epoch 4/30, train Loss: 0.5234, val Loss: 0.2784, train ACC: 96.80%, Val ACC: 96.88%
# Epoch 5/30, train Loss: 0.0226, val Loss: 0.0360, train ACC: 98.40%, Val ACC: 100.00%
# Epoch 6/30, train Loss: 0.3467, val Loss: 0.3975, train ACC: 98.40%, Val ACC: 93.75%
# Epoch 7/30, train Loss: 0.0463, val Loss: 0.1090, train ACC: 99.20%, Val ACC: 96.88%
# Epoch 8/30, train Loss: 0.0079, val Loss: 0.1198, train ACC: 100.00%, Val ACC: 96.88%
# Epoch 9/30, train Loss: 0.0297, val Loss: 0.0235, train ACC: 98.40%, Val ACC: 100.00%
# Epoch 10/30, train Loss: 0.1267, val Loss: 0.0760, train ACC: 97.60%, Val ACC: 96.88%
# Epoch 11/30, train Loss: 0.0541, val Loss: 0.3164, train ACC: 97.60%, Val ACC: 96.88%
# Epoch 12/30, train Loss: 0.0986, val Loss: 0.1271, train ACC: 98.40%, Val ACC: 93.75%
# Epoch 13/30, train Loss: 0.0135, val Loss: 0.0628, train ACC: 100.00%, Val ACC: 96.88%
# Epoch 14/30, train Loss: 0.5312, val Loss: 0.2905, train ACC: 98.40%, Val ACC: 96.88%
# Epoch 15/30, train Loss: 0.0983, val Loss: 0.0532, train ACC: 100.00%, Val ACC: 96.88%
# Epoch 16/30, train Loss: 0.3090, val Loss: 0.1876, train ACC: 100.00%, Val ACC: 96.88%
# Epoch 17/30, train Loss: 0.0039, val Loss: 0.4029, train ACC: 100.00%, Val ACC: 96.88%
# Epoch 18/30, train Loss: 0.9405, val Loss: 0.4767, train ACC: 100.00%, Val ACC: 93.75%
# Epoch 19/30, train Loss: 0.1631, val Loss: 0.4932, train ACC: 99.20%, Val ACC: 90.62%
# Epoch 20/30, train Loss: 0.0072, val Loss: 0.0046, train ACC: 99.20%, Val ACC: 100.00%
# Epoch 21/30, train Loss: 0.1032, val Loss: 0.1772, train ACC: 99.20%, Val ACC: 93.75%
# Epoch 22/30, train Loss: 0.2817, val Loss: 0.1438, train ACC: 97.60%, Val ACC: 96.88%
# Epoch 23/30, train Loss: 0.0096, val Loss: 0.0497, train ACC: 97.60%, Val ACC: 96.88%
# Epoch 24/30, train Loss: 0.0127, val Loss: 0.0122, train ACC: 97.60%, Val ACC: 100.00%
# Epoch 25/30, train Loss: 0.0329, val Loss: 0.0288, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 26/30, train Loss: 0.0008, val Loss: 0.0227, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 27/30, train Loss: 0.0039, val Loss: 0.0064, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 28/30, train Loss: 0.0919, val Loss: 0.0466, train ACC: 100.00%, Val ACC: 96.88%
# Epoch 29/30, train Loss: 0.0033, val Loss: 0.0190, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 30/30, train Loss: 0.3353, val Loss: 0.1690, train ACC: 98.40%, Val ACC: 96.88%
# Fold 3/5
# Epoch 1/30, train Loss: 0.0681, val Loss: 0.0687, train ACC: 98.41%, Val ACC: 96.77%
# Epoch 2/30, train Loss: 0.0554, val Loss: 0.0745, train ACC: 96.83%, Val ACC: 96.77%
# Epoch 3/30, train Loss: 0.0045, val Loss: 0.0053, train ACC: 96.03%, Val ACC: 100.00%
# Epoch 4/30, train Loss: 0.0011, val Loss: 0.0326, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 5/30, train Loss: 0.0181, val Loss: 0.0129, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 6/30, train Loss: 0.0011, val Loss: 0.0081, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 7/30, train Loss: 0.0228, val Loss: 0.0118, train ACC: 98.41%, Val ACC: 100.00%
# Epoch 8/30, train Loss: 0.4338, val Loss: 0.2215, train ACC: 98.41%, Val ACC: 96.77%
# Epoch 9/30, train Loss: 0.0305, val Loss: 0.2219, train ACC: 100.00%, Val ACC: 96.77%
# Epoch 10/30, train Loss: 0.0149, val Loss: 0.4762, train ACC: 100.00%, Val ACC: 96.77%
# Epoch 11/30, train Loss: 0.0223, val Loss: 0.0117, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 12/30, train Loss: 0.0021, val Loss: 0.0062, train ACC: 97.62%, Val ACC: 100.00%
# Epoch 13/30, train Loss: 0.6782, val Loss: 0.3424, train ACC: 98.41%, Val ACC: 96.77%
# Epoch 14/30, train Loss: 0.0024, val Loss: 0.0471, train ACC: 100.00%, Val ACC: 96.77%
# Epoch 15/30, train Loss: 0.0144, val Loss: 0.0090, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 16/30, train Loss: 0.0140, val Loss: 0.0343, train ACC: 96.83%, Val ACC: 100.00%
# Epoch 17/30, train Loss: 0.0260, val Loss: 0.0215, train ACC: 98.41%, Val ACC: 100.00%
# Epoch 18/30, train Loss: 0.0279, val Loss: 0.0208, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 19/30, train Loss: 0.0022, val Loss: 0.1286, train ACC: 98.41%, Val ACC: 90.32%
# Epoch 20/30, train Loss: 0.0156, val Loss: 0.0587, train ACC: 98.41%, Val ACC: 96.77%
# Epoch 21/30, train Loss: 0.0194, val Loss: 0.0168, train ACC: 96.03%, Val ACC: 100.00%
# Epoch 22/30, train Loss: 0.0022, val Loss: 0.0136, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 23/30, train Loss: 0.0184, val Loss: 0.0421, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 24/30, train Loss: 0.0121, val Loss: 0.0931, train ACC: 100.00%, Val ACC: 96.77%
# Epoch 25/30, train Loss: 0.0035, val Loss: 0.0022, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 26/30, train Loss: 0.0029, val Loss: 0.0027, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 27/30, train Loss: 0.0036, val Loss: 0.0294, train ACC: 100.00%, Val ACC: 96.77%
# Epoch 28/30, train Loss: 0.0066, val Loss: 0.0095, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 29/30, train Loss: 0.5900, val Loss: 0.2953, train ACC: 100.00%, Val ACC: 96.77%
# Epoch 30/30, train Loss: 0.0054, val Loss: 0.0279, train ACC: 99.21%, Val ACC: 100.00%
# Fold 4/5
# Epoch 1/30, train Loss: 0.0008, val Loss: 0.0004, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 2/30, train Loss: 0.0001, val Loss: 0.0002, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 3/30, train Loss: 0.0004, val Loss: 0.0011, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 4/30, train Loss: 0.0001, val Loss: 0.0001, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 5/30, train Loss: 0.0006, val Loss: 0.0007, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 6/30, train Loss: 0.0006, val Loss: 0.0015, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 7/30, train Loss: 0.0012, val Loss: 0.0015, train ACC: 98.41%, Val ACC: 100.00%
# Epoch 8/30, train Loss: 0.0002, val Loss: 0.0200, train ACC: 99.21%, Val ACC: 96.77%
# Epoch 9/30, train Loss: 0.0010, val Loss: 0.0007, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 10/30, train Loss: 0.0003, val Loss: 0.0076, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 11/30, train Loss: 0.0013, val Loss: 0.0009, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 12/30, train Loss: 0.0125, val Loss: 0.0069, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 13/30, train Loss: 0.0004, val Loss: 0.0011, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 14/30, train Loss: 0.0019, val Loss: 0.0017, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 15/30, train Loss: 0.0038, val Loss: 0.0021, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 16/30, train Loss: 0.0031, val Loss: 0.0220, train ACC: 100.00%, Val ACC: 96.77%
# Epoch 17/30, train Loss: 0.0728, val Loss: 0.0373, train ACC: 99.21%, Val ACC: 96.77%
# Epoch 18/30, train Loss: 0.0023, val Loss: 0.0052, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 19/30, train Loss: 0.0068, val Loss: 0.0040, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 20/30, train Loss: 0.0010, val Loss: 0.0009, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 21/30, train Loss: 0.0010, val Loss: 0.0006, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 22/30, train Loss: 0.0062, val Loss: 0.0032, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 23/30, train Loss: 0.0005, val Loss: 0.0007, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 24/30, train Loss: 0.0035, val Loss: 0.0024, train ACC: 98.41%, Val ACC: 100.00%
# Epoch 25/30, train Loss: 0.0001, val Loss: 0.0010, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 26/30, train Loss: 0.0013, val Loss: 0.0007, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 27/30, train Loss: 0.0007, val Loss: 0.0015, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 28/30, train Loss: 0.0165, val Loss: 0.0098, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 29/30, train Loss: 0.0087, val Loss: 0.0304, train ACC: 99.21%, Val ACC: 96.77%
# Epoch 30/30, train Loss: 0.0066, val Loss: 0.3094, train ACC: 99.21%, Val ACC: 93.55%
# Fold 5/5
# Epoch 1/30, train Loss: 0.0010, val Loss: 0.0010, train ACC: 97.62%, Val ACC: 100.00%
# Epoch 2/30, train Loss: 0.0008, val Loss: 0.0039, train ACC: 98.41%, Val ACC: 100.00%
# Epoch 3/30, train Loss: 0.0045, val Loss: 0.0126, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 4/30, train Loss: 0.0002, val Loss: 0.0018, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 5/30, train Loss: 0.0475, val Loss: 0.0241, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 6/30, train Loss: 0.0048, val Loss: 0.0036, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 7/30, train Loss: 0.0045, val Loss: 0.0027, train ACC: 98.41%, Val ACC: 100.00%
# Epoch 8/30, train Loss: 0.0013, val Loss: 0.0011, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 9/30, train Loss: 0.0003, val Loss: 0.0010, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 10/30, train Loss: 0.0002, val Loss: 0.0031, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 11/30, train Loss: 0.0007, val Loss: 0.0071, train ACC: 98.41%, Val ACC: 100.00%
# Epoch 12/30, train Loss: 0.0008, val Loss: 0.0014, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 13/30, train Loss: 0.0377, val Loss: 0.0199, train ACC: 97.62%, Val ACC: 100.00%
# Epoch 14/30, train Loss: 0.0567, val Loss: 0.0327, train ACC: 98.41%, Val ACC: 96.77%
# Epoch 15/30, train Loss: 0.0162, val Loss: 0.0085, train ACC: 97.62%, Val ACC: 100.00%
# Epoch 16/30, train Loss: 0.0947, val Loss: 0.0479, train ACC: 100.00%, Val ACC: 96.77%
# Epoch 17/30, train Loss: 0.0081, val Loss: 0.0120, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 18/30, train Loss: 0.0123, val Loss: 0.0159, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 19/30, train Loss: 0.0061, val Loss: 0.0039, train ACC: 98.41%, Val ACC: 100.00%
# Epoch 20/30, train Loss: 0.0016, val Loss: 0.1183, train ACC: 98.41%, Val ACC: 96.77%
# Epoch 21/30, train Loss: 0.0065, val Loss: 0.0091, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 22/30, train Loss: 0.0028, val Loss: 0.0047, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 23/30, train Loss: 0.0020, val Loss: 0.0030, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 24/30, train Loss: 0.0046, val Loss: 0.0039, train ACC: 99.21%, Val ACC: 100.00%
# Epoch 25/30, train Loss: 0.0024, val Loss: 0.0024, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 26/30, train Loss: 0.0008, val Loss: 0.0027, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 27/30, train Loss: 0.0241, val Loss: 0.0134, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 28/30, train Loss: 0.0005, val Loss: 0.0003, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 29/30, train Loss: 0.0018, val Loss: 0.0015, train ACC: 100.00%, Val ACC: 100.00%
# Epoch 30/30, train Loss: 0.0014, val Loss: 0.0009, train ACC: 100.00%, Val ACC: 100.00%

# %%
# # resnet 152
test_model(model=model, test_dataset=test_dataset, batch_size=66)
# Out:
# Test Loss: 0.3256, Test Acc: 95.12%
# AUC: 0.9234848484848485
# Confusion Matrix:
# [[59  1]
#  [ 3 19]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          NFF       0.95      0.98      0.97        60
#          AFF       0.95      0.86      0.90        22
#
#     accuracy                           0.95        82
#    macro avg       0.95      0.92      0.94        82
# weighted avg       0.95      0.95      0.95        82
