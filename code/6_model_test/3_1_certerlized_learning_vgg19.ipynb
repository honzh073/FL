# %% [markdown]
# # Create all image csv files

# %%
# import os
# import csv

# def create_csv(image_folder, csv_file_path):
#     # Define the CSV header fields
#     fieldnames = ['HospitalID', 'PatientID', 'ImageID', 'ImagePath', 'Label']
    
#     # Open the CSV file in write mode
#     with open(csv_file_path, 'w', newline='') as csvfile:
#         # Create a CSV writer object and write the header
#         writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
#         writer.writeheader()

#         # Iterate through files in the folder
#         for filename in sorted(os.listdir(image_folder)):
#             # Construct the complete image file path
#             image_path = os.path.join(image_folder, filename)

#             # Parse the filename to extract HospitalID, PatientID, image number, and image label
#             parts = filename.split('_')
#             hospital_id = parts[3]
#             patient_id = parts[1]
#             image_number = parts[6]
#             image_label = parts[4]

#             # Write data into the CSV file
#             writer.writerow({
#                 'HospitalID': hospital_id,
#                 'PatientID': patient_id,
#                 'ImageID': image_number,
#                 'ImagePath': image_path,
#                 'Label': image_label
#             })

#     # Print a message indicating that the CSV file has been created and saved
#     print("CSV file has been created and saved to:", csv_file_path)


# image_folder = "/local/data1/honzh073/data/8bit_downsample_256"
# csv_file_path = "/local/data1/honzh073/local_repo/FL/code/3_single_hospital/csv_files/image_data.csv"
# create_csv(image_folder, csv_file_path)

# %%
# # Create csv files, hospital 43, 55&18, 54&22
# import pandas as pd

# # Read the original CSV file
# original_df = pd.read_csv('/local/data1/honzh073/local_repository/FL/code/6_model_test/all_image_data.csv')

# # List of hospitals to keep
# hospitals_to_keep = [43, 55, 54, 18, 33]

# # Filter rows based on HospitalID
# filtered_df = original_df[original_df['HospitalID'].isin(hospitals_to_keep)]

# # Save the filtered DataFrame to a new CSV file at the specified path
# output_path = '/local/data1/honzh073/local_repository/FL/code/6_model_test/centralized_learning.csv'
# filtered_df.to_csv(output_path, index=False)

# print(f"Filtered CSV file created successfully at: {output_path}")

# %% [markdown]
# # create train, val csv

# %%
# import csv
# from collections import defaultdict
# import random
# import os

# def split_and_save_data(input_csv_path, output_folder, target_hospital_ids, train_ratio, seed):
#     patient_data = defaultdict(list)
    
#     with open(input_csv_path, 'r') as csvfile:
#         reader = csv.DictReader(csvfile)
#         for row in reader:
#             if row['HospitalID'] in target_hospital_ids:
#                 patient_id = row['PatientID']
#                 patient_data[patient_id].append(row)

#     num_patients = len(patient_data)

#     num_train = int(num_patients * train_ratio)

#     # get random IDs
#     all_patient_ids = list(patient_data.keys())

#     random.seed(seed)
#     random.shuffle(all_patient_ids)

#     # split by ID
#     train_patients = all_patient_ids[ : num_train]
#     test_patients = all_patient_ids[num_train: ]

#     # iter by patient IDs
#     train_data = []
#     test_data = []

#     for patient_id, images in patient_data.items():
#         if patient_id in train_patients:
#             train_data.extend(images)
#         elif patient_id in test_patients:
#             test_data.extend(images)

#     # write to csv
#     def write_to_csv(file_path, data):
#         with open(file_path, 'w', newline='') as csvfile:
#             writer = csv.DictWriter(csvfile, fieldnames=data[0].keys())
#             writer.writeheader()
#             writer.writerows(data)

#     # Write to CSV files
#     write_to_csv(os.path.join(output_folder, 'cl_cross_train.csv'), train_data)
#     write_to_csv(os.path.join(output_folder, 'cl_cross_test.csv'), test_data)
    
#     print("Saved train.csv, test.csv.")

# # input and output path
# input_csv_path = "/local/data1/honzh073/local_repository/FL/code/6_model_test/all_image_data.csv"
# output_folder = '/local/data1/honzh073/local_repository/FL/code/6_model_test'

# # single hospital id
# target_hospital_ids = ['43', '55', '54', '18', '33']

# # random seed
# seed = 1

# # train and val dataset ratio
# train_ratio = 0.7
# # test_ratio = 0.3 # unnecessary

# split_and_save_data(input_csv_path, output_folder,
#                     train_ratio=train_ratio,
#                     target_hospital_ids = target_hospital_ids,
#                     seed = seed)

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import models
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_curve, roc_auc_score
   
def plot_roc_curve(all_labels, all_predictions):
    fpr, tpr, thresholds = roc_curve(all_labels, all_predictions)
    roc_auc = roc_auc_score(all_labels, all_predictions)

    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc='lower right')
    plt.show()

def show_image(dataset, num_images=5):
    # Get random indices
    random_indices = np.random.choice(len(dataset), num_images, replace=False)

    # Plot images with truncated names
    plt.figure(figsize=(15, 5))
    for i, idx in enumerate(random_indices):
        image, label = dataset[idx]  # Use the dataset directly
        filename = dataset.data[idx][0]  # Get the filename from dataset's internal data attribute
        truncated_filename = filename.split('/')[-1][:15]  # Extract the last part and truncate to 15 characters
        
        # Print the original filename
        print(f"Image location: {filename}")

        plt.subplot(1, num_images, i + 1)
        plt.title(f"Label: {label}")
        plt.imshow(image[0])  # Assuming single-channel (grayscale) image
        # plt.imshow(image[0], cmap='gray')  # Assuming single-channel (grayscale) image

        plt.axis('off')
    plt.show()
    
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_classweight(train_dataset):
    train_nff_count = sum(1 for _, label in train_dataset if label == 0)  # 0 NFF
    train_aff_count = sum(1 for _, label in train_dataset if label == 1)  # 1 AFF
    class_weight_nff = 1 / (2 * (train_nff_count / (train_nff_count + train_aff_count)))
    class_weight_aff = 1 / (2 * (train_aff_count / (train_nff_count + train_aff_count)))
    
    return [class_weight_nff, class_weight_aff] # 0 nff , 1 aff


def test_model(model, test_dataset, batch_size):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)
    model.eval()
    
    correct_test = 0
    total_test = 0
    test_loss = 0
    
    criterion = nn.CrossEntropyLoss()
    
    with torch.no_grad():
        all_predictions = []
        all_labels = []
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            _, predicted = torch.max(outputs.data, 1)
            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            total_test += labels.size(0)
            correct_test += (predicted == labels).sum().item()
            test_loss += loss.item()

    test_accuracy = 100 * correct_test / total_test
    test_loss /= len(test_loader)

    print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_accuracy:.2f}%")
     
    auc_score = roc_auc_score(all_labels, all_predictions)
    conf_matrix = confusion_matrix(all_labels, all_predictions)
    
    # Precision、Recall、F1 Score
    class_labels = {0: 'NFF', 1: 'AFF'}

    classification_rep = classification_report(all_labels, all_predictions, target_names=[class_labels[i] for i in range(len(class_labels))])
    print("AUC:", auc_score)
    print("Confusion Matrix:")
    print(conf_matrix)
    print("Classification Report:")
    print(classification_rep)

    plot_roc_curve(all_labels, all_predictions)

# %% [markdown]
# # Centralized learning and random pick test
#
# read csv file centralized_learning.csv and train model use 5 fold cross validation
#
# test on randompick_patient_data.csv

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import csv
import pandas as pd
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, models
from sklearn.model_selection import KFold

# Custom dataset class
class CustomDataset(Dataset):
    def __init__(self, csv_file, transform=None):
        self.data = []
        self.labels = []  # Store labels separately
        self.patient_ids = []  # Store patient IDs separately
        self.transform = transform
        
        # read csv
        with open(csv_file, 'r') as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                image_path = row['ImagePath']
                label = row['Label']
                patient_id = row['PatientID']  # Assuming 'PatientID' is the column name in your CSV file

                if label == 'NFF':
                    label = 0
                elif label == 'AFF':
                    label = 1
                else:
                    raise ValueError("Invalid label in CSV file.")
                self.data.append((image_path, label))
                self.labels.append(label)
                self.patient_ids.append(patient_id)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image_path, label = self.data[idx]
        image = Image.open(image_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image, label

# Define your image transformations for training and testing
train_transform = transforms.Compose([
    transforms.RandomRotation(degrees=20),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomResizedCrop(256, scale=(0.8, 1.0)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.GaussianBlur(kernel_size=3),
    transforms.RandomAdjustSharpness(sharpness_factor=5),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load the datasets using CustomDataset class
train_dataset = CustomDataset('/local/data1/honzh073/local_repository/FL/code/6_model_test/centralized_learning.csv', transform=train_transform)
test_dataset = CustomDataset('/local/data1/honzh073/local_repository/FL/code/6_model_test/randompick_patient_data.csv', transform=test_transform)

# classweight
classweight = get_classweight(train_dataset)
print('training class weight', classweight)

# device
# device = torch.device("cuda:0" if  torch.cuda.is_available() else "cpu")

# print images
show_image(train_dataset, 10)

# calculate numbers
# print("Saved train.csv, val.csv, test.csv.")
print('-----------------------------------')
train_NFF_count = sum(1 for _, label in train_dataset if label == 0)  # 0 NFF
train_AFF_count = sum(1 for _, label in train_dataset if label == 1)  # 1 AFF
test_NFF_count = sum(1 for _, label in test_dataset if label == 0)  # 0 NFF
test_AFF_count = sum(1 for _, label in test_dataset if label == 1)  # 1 AFF

print(f"train AFF: {train_AFF_count}, ratio: {train_AFF_count / (train_AFF_count + train_NFF_count):.2f}")
print(f"----- NFF: {train_NFF_count}, ratio: {train_NFF_count / (train_AFF_count + train_NFF_count):.2f}")
print('-----------------------------------')
print(f"test AFF: {test_AFF_count}, ratio: {test_AFF_count / (test_AFF_count + test_NFF_count):.2f}")
print(f"---- NFF: {test_NFF_count}, ratio: {test_NFF_count / (test_AFF_count + test_NFF_count):.2f}")
# Out:
# training class weight [0.6538461538461539, 2.125]
# Image location: /local/data1/honzh073/data/8bit_down224/patient_ICRBFMHKPB_hospital_43_NFF_image_6.png
# Image location: /local/data1/honzh073/data/8bit_down224/patient_ZSRIAOAGEL_hospital_18_NFF_image_1.png
# Image location: /local/data1/honzh073/data/8bit_down224/patient_HACUSUQVAK_hospital_54_NFF_image_1.png
# Image location: /local/data1/honzh073/data/8bit_down224/patient_TZSHYXLTOZ_hospital_55_NFF_image_1.png
# Image location: /local/data1/honzh073/data/8bit_down224/patient_QJPWSKOGSI_hospital_55_NFF_image_2.png
# Image location: /local/data1/honzh073/data/8bit_down224/patient_FFDXEONXXX_hospital_43_AFF_image_2.png
# Image location: /local/data1/honzh073/data/8bit_down224/patient_MMOQGMWSNT_hospital_43_AFF_image_3.png
# Image location: /local/data1/honzh073/data/8bit_down224/patient_HIOOQPEKJC_hospital_43_NFF_image_1.png
# Image location: /local/data1/honzh073/data/8bit_down224/patient_JDYQZFVMPB_hospital_18_NFF_image_3.png
# Image location: /local/data1/honzh073/data/8bit_down224/patient_PEFWDQLPTH_hospital_54_NFF_image_8.png
# -----------------------------------
# train AFF: 196, ratio: 0.24
# ----- NFF: 637, ratio: 0.76
# -----------------------------------
# test AFF: 94, ratio: 0.16
# ---- NFF: 494, ratio: 0.84

# %% [markdown]
# # 5 fold cross validation
#
# cgg 19, Adam, 0.0001, batch size 64

# %%
from sklearn.model_selection import StratifiedKFold
from torchvision.models import vgg19, VGG19_Weights

classweight = get_classweight(train_dataset)

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

vgg19_Adam = models.vgg19(weights=VGG19_Weights.DEFAULT)

# Modify the last layer for binary classification
num_features = vgg19_Adam.classifier[-1].in_features
vgg19_Adam.classifier[-1] = nn.Linear(num_features, 2)  # Assuming 2 classes, change it according to your problem

# Move the model to the desired device (CPU or GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
vgg19_Adam = vgg19_Adam.to(device)

# Define your loss function and optimizer
criterion = nn.CrossEntropyLoss()
criterion = nn.CrossEntropyLoss(weight=torch.Tensor(classweight).to(device))

optimizer = optim.Adam(vgg19_Adam.parameters(), lr=0.0001)
# scheduler = lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# Define the number of splits for cross-validation
n_splits = 5
# kf = KFold(n_splits=n_splits, shuffle=True, random_state=1)
kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=1)
# Perform k-fold cross-validation
for fold, (train_idx, val_idx) in enumerate(kf.split(range(len(train_dataset)), train_dataset.patient_ids)):

# for fold, (train_idx, val_idx) in enumerate(kf.split(range(len(train_dataset)))):
    print(f'Fold {fold + 1}/{n_splits}')

    # Create data loaders for training and validation subsets
    train_sampler = torch.utils.data.SubsetRandomSampler(train_idx)
    val_sampler = torch.utils.data.SubsetRandomSampler(val_idx)

    train_loader = DataLoader(train_dataset, batch_size=64, sampler=train_sampler)
    val_loader = DataLoader(train_dataset, batch_size=64, sampler=val_sampler)

    # Training loop
    num_epochs = 20  # Choose the number of epochs
        # Loss, ACC
    train_losses = []
    validation_losses = []
    train_accuracies = []
    validation_accuracies = []
    
    for epoch in range(num_epochs):
        vgg19_Adam.train()
        correct_train = 0
        total_train = 0
        
        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = vgg19_Adam(images)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
        
        train_accuracy = 100 * correct_train / total_train
        
        vgg19_Adam.eval()
        correct_validation_aff = 0
        total_validation_aff = 0
        correct_validation = 0
        total_validation = 0
        validation_loss = 0
        
        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                
                outputs = vgg19_Adam(images)
                loss = criterion(outputs, labels)
                
                _, predicted = torch.max(outputs.data, 1)
                total_validation += labels.size(0)
                correct_validation += (predicted == labels).sum().item()
                validation_loss += loss.item()
                # Calculate accuracy for AFF class
                total_validation_aff += torch.sum(labels == 1).item()
                correct_validation_aff += torch.sum((predicted == 1) & (labels == 1)).item()

        validation_accuracy_aff = 100 * correct_validation_aff / total_validation_aff

        # validation accuracy and loss
        validation_accuracy = 100 * correct_validation / total_validation
        validation_loss /= len(val_loader)
        
        train_losses.append(loss.item())
        validation_losses.append(validation_loss)
        train_accuracies.append(train_accuracy)
        validation_accuracies.append(validation_accuracy)
        
        print(f"Epoch {epoch+1}/{num_epochs}, "
            f"train Loss: {loss.item():.4f}, "
            f"val Loss: {validation_loss:.4f}, "
            f"train ACC: {train_accuracy:.2f}%, "
            f"Val ACC: {validation_accuracy:.2f}%")
        # scheduler.step()
# Out:
# /local/data1/honzh073/anaconda3/envs/myenv/lib/python3.9/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# Fold 1/5
# Epoch 1/20, train Loss: 0.6838, val Loss: 0.6721, train ACC: 54.05%, Val ACC: 68.86%
# Epoch 2/20, train Loss: 0.7049, val Loss: 0.6699, train ACC: 53.00%, Val ACC: 43.71%
# Epoch 3/20, train Loss: 0.6906, val Loss: 0.6116, train ACC: 54.20%, Val ACC: 73.05%
# Epoch 4/20, train Loss: 0.6505, val Loss: 0.6294, train ACC: 62.61%, Val ACC: 64.07%
# Epoch 5/20, train Loss: 0.6417, val Loss: 0.6298, train ACC: 53.00%, Val ACC: 79.64%
# Epoch 6/20, train Loss: 0.5698, val Loss: 0.6304, train ACC: 59.16%, Val ACC: 81.44%
# Epoch 7/20, train Loss: 0.8519, val Loss: 0.6577, train ACC: 64.41%, Val ACC: 50.30%
# Epoch 8/20, train Loss: 0.5789, val Loss: 0.5807, train ACC: 59.01%, Val ACC: 70.66%
# Epoch 9/20, train Loss: 0.4063, val Loss: 0.4170, train ACC: 75.83%, Val ACC: 83.23%
# Epoch 10/20, train Loss: 0.6228, val Loss: 0.6621, train ACC: 68.77%, Val ACC: 81.44%
# Epoch 11/20, train Loss: 0.4298, val Loss: 0.4838, train ACC: 76.13%, Val ACC: 86.83%
# Epoch 12/20, train Loss: 0.4206, val Loss: 0.3807, train ACC: 71.47%, Val ACC: 91.02%
# Epoch 13/20, train Loss: 0.2546, val Loss: 0.3107, train ACC: 81.53%, Val ACC: 88.62%
# Epoch 14/20, train Loss: 0.3954, val Loss: 0.3692, train ACC: 86.34%, Val ACC: 80.24%
# Epoch 15/20, train Loss: 0.3384, val Loss: 0.3882, train ACC: 87.24%, Val ACC: 70.66%
# Epoch 16/20, train Loss: 0.1869, val Loss: 0.2637, train ACC: 83.93%, Val ACC: 88.62%
# Epoch 17/20, train Loss: 0.2591, val Loss: 0.2489, train ACC: 89.19%, Val ACC: 92.81%
# Epoch 18/20, train Loss: 0.4196, val Loss: 0.4111, train ACC: 89.04%, Val ACC: 74.25%
# Epoch 19/20, train Loss: 0.4317, val Loss: 0.2729, train ACC: 87.09%, Val ACC: 87.43%
# Epoch 20/20, train Loss: 0.3055, val Loss: 0.2439, train ACC: 90.84%, Val ACC: 88.02%
# Fold 2/5
# Epoch 1/20, train Loss: 0.5630, val Loss: 0.4108, train ACC: 89.64%, Val ACC: 76.05%
# Epoch 2/20, train Loss: 0.3617, val Loss: 0.3310, train ACC: 85.59%, Val ACC: 85.03%
# Epoch 3/20, train Loss: 0.4081, val Loss: 0.2975, train ACC: 86.64%, Val ACC: 89.82%
# Epoch 4/20, train Loss: 0.1780, val Loss: 0.2750, train ACC: 92.04%, Val ACC: 87.43%
# Epoch 5/20, train Loss: 0.2441, val Loss: 0.3212, train ACC: 91.14%, Val ACC: 84.43%
# Epoch 6/20, train Loss: 0.1907, val Loss: 0.2494, train ACC: 90.99%, Val ACC: 91.02%
# Epoch 7/20, train Loss: 0.3258, val Loss: 0.3386, train ACC: 91.14%, Val ACC: 91.02%
# Epoch 8/20, train Loss: 0.5424, val Loss: 0.4783, train ACC: 91.59%, Val ACC: 89.82%
# Epoch 9/20, train Loss: 0.1318, val Loss: 0.2381, train ACC: 95.05%, Val ACC: 90.42%
# Epoch 10/20, train Loss: 0.5141, val Loss: 0.4347, train ACC: 94.14%, Val ACC: 92.22%
# Epoch 11/20, train Loss: 0.2633, val Loss: 0.2684, train ACC: 93.39%, Val ACC: 88.62%
# Epoch 12/20, train Loss: 0.2663, val Loss: 0.2408, train ACC: 93.09%, Val ACC: 90.42%
# Epoch 13/20, train Loss: 0.6132, val Loss: 0.4911, train ACC: 94.89%, Val ACC: 91.02%
# Epoch 14/20, train Loss: 0.1777, val Loss: 0.2012, train ACC: 95.20%, Val ACC: 91.62%
# Epoch 15/20, train Loss: 0.9309, val Loss: 0.8863, train ACC: 94.14%, Val ACC: 87.43%
# Epoch 16/20, train Loss: 0.2184, val Loss: 0.2595, train ACC: 90.24%, Val ACC: 82.04%
# Epoch 17/20, train Loss: 0.6832, val Loss: 0.6639, train ACC: 91.59%, Val ACC: 89.22%
# Epoch 18/20, train Loss: 0.5583, val Loss: 0.4056, train ACC: 92.94%, Val ACC: 90.42%
# Epoch 19/20, train Loss: 0.5216, val Loss: 0.3680, train ACC: 95.65%, Val ACC: 89.82%
# Epoch 20/20, train Loss: 0.2012, val Loss: 0.2287, train ACC: 96.55%, Val ACC: 89.22%
# Fold 3/5
# Epoch 1/20, train Loss: 0.2385, val Loss: 0.2367, train ACC: 93.69%, Val ACC: 84.43%
# Epoch 2/20, train Loss: 0.1268, val Loss: 0.1571, train ACC: 88.74%, Val ACC: 92.81%
# Epoch 3/20, train Loss: 0.2352, val Loss: 0.1398, train ACC: 94.59%, Val ACC: 91.62%
# Epoch 4/20, train Loss: 0.0509, val Loss: 0.0956, train ACC: 95.35%, Val ACC: 96.41%
# Epoch 5/20, train Loss: 0.0730, val Loss: 0.1239, train ACC: 94.89%, Val ACC: 95.81%
# Epoch 6/20, train Loss: 0.0926, val Loss: 0.1603, train ACC: 93.99%, Val ACC: 95.21%
# Epoch 7/20, train Loss: 0.2222, val Loss: 0.2143, train ACC: 95.80%, Val ACC: 94.61%
# Epoch 8/20, train Loss: 0.2018, val Loss: 0.1239, train ACC: 95.95%, Val ACC: 97.01%
# Epoch 9/20, train Loss: 0.0743, val Loss: 0.0764, train ACC: 96.55%, Val ACC: 94.01%
# Epoch 10/20, train Loss: 0.1380, val Loss: 0.1214, train ACC: 96.25%, Val ACC: 94.61%
# Epoch 11/20, train Loss: 0.2383, val Loss: 0.1224, train ACC: 95.80%, Val ACC: 95.21%
# Epoch 12/20, train Loss: 0.0341, val Loss: 0.0693, train ACC: 95.65%, Val ACC: 98.20%
# Epoch 13/20, train Loss: 0.1063, val Loss: 0.1925, train ACC: 98.20%, Val ACC: 88.62%
# Epoch 14/20, train Loss: 0.2188, val Loss: 0.2285, train ACC: 92.94%, Val ACC: 92.81%
# Epoch 15/20, train Loss: 0.0369, val Loss: 0.2877, train ACC: 95.05%, Val ACC: 93.41%
# Epoch 16/20, train Loss: 0.0970, val Loss: 0.1293, train ACC: 97.45%, Val ACC: 92.81%
# Epoch 17/20, train Loss: 0.1434, val Loss: 0.1720, train ACC: 95.20%, Val ACC: 91.02%
# Epoch 18/20, train Loss: 0.1355, val Loss: 0.1504, train ACC: 93.54%, Val ACC: 95.81%
# Epoch 19/20, train Loss: 0.0918, val Loss: 0.1895, train ACC: 95.80%, Val ACC: 92.22%
# Epoch 20/20, train Loss: 0.0784, val Loss: 0.1042, train ACC: 96.10%, Val ACC: 94.01%
# Fold 4/5
# Epoch 1/20, train Loss: 0.0181, val Loss: 0.0436, train ACC: 95.50%, Val ACC: 98.19%
# Epoch 2/20, train Loss: 0.1194, val Loss: 0.1203, train ACC: 96.40%, Val ACC: 93.37%
# Epoch 3/20, train Loss: 0.0972, val Loss: 0.1086, train ACC: 94.75%, Val ACC: 92.77%
# Epoch 4/20, train Loss: 0.0485, val Loss: 0.0637, train ACC: 95.80%, Val ACC: 96.99%
# Epoch 5/20, train Loss: 0.1573, val Loss: 0.1242, train ACC: 96.85%, Val ACC: 92.17%
# Epoch 6/20, train Loss: 0.0950, val Loss: 0.1114, train ACC: 95.95%, Val ACC: 93.98%
# Epoch 7/20, train Loss: 0.0285, val Loss: 0.0634, train ACC: 95.35%, Val ACC: 96.99%
# Epoch 8/20, train Loss: 0.0378, val Loss: 0.0732, train ACC: 94.45%, Val ACC: 98.19%
# Epoch 9/20, train Loss: 0.0626, val Loss: 0.0884, train ACC: 97.60%, Val ACC: 95.18%
# Epoch 10/20, train Loss: 0.0457, val Loss: 0.0544, train ACC: 97.00%, Val ACC: 99.40%
# Epoch 11/20, train Loss: 0.0327, val Loss: 0.0557, train ACC: 97.45%, Val ACC: 98.19%
# Epoch 12/20, train Loss: 0.0340, val Loss: 0.0284, train ACC: 97.60%, Val ACC: 100.00%
# Epoch 13/20, train Loss: 0.0205, val Loss: 0.0482, train ACC: 98.35%, Val ACC: 95.78%
# Epoch 14/20, train Loss: 0.1884, val Loss: 0.2297, train ACC: 92.50%, Val ACC: 90.96%
# Epoch 15/20, train Loss: 0.1139, val Loss: 0.1787, train ACC: 89.96%, Val ACC: 94.58%
# Epoch 16/20, train Loss: 0.3247, val Loss: 0.2074, train ACC: 94.75%, Val ACC: 96.39%
# Epoch 17/20, train Loss: 0.0221, val Loss: 0.1164, train ACC: 95.80%, Val ACC: 95.18%
# Epoch 18/20, train Loss: 0.3531, val Loss: 0.2341, train ACC: 94.75%, Val ACC: 95.18%
# Epoch 19/20, train Loss: 0.2897, val Loss: 0.1561, train ACC: 97.30%, Val ACC: 95.78%
# Epoch 20/20, train Loss: 0.1698, val Loss: 0.0974, train ACC: 97.45%, Val ACC: 96.99%
# Fold 5/5
# Epoch 1/20, train Loss: 0.1841, val Loss: 0.1185, train ACC: 96.70%, Val ACC: 92.17%
# Epoch 2/20, train Loss: 0.1928, val Loss: 0.1840, train ACC: 96.10%, Val ACC: 90.36%
# Epoch 3/20, train Loss: 0.0082, val Loss: 0.1129, train ACC: 95.80%, Val ACC: 96.99%
# Epoch 4/20, train Loss: 0.0186, val Loss: 0.0226, train ACC: 97.45%, Val ACC: 99.40%
# Epoch 5/20, train Loss: 0.0010, val Loss: 0.0250, train ACC: 97.60%, Val ACC: 99.40%
# Epoch 6/20, train Loss: 0.0269, val Loss: 0.0246, train ACC: 98.35%, Val ACC: 98.80%
# Epoch 7/20, train Loss: 0.0137, val Loss: 0.0548, train ACC: 98.05%, Val ACC: 96.99%
# Epoch 8/20, train Loss: 0.0161, val Loss: 0.0186, train ACC: 98.65%, Val ACC: 99.40%
# Epoch 9/20, train Loss: 0.0336, val Loss: 0.0347, train ACC: 98.65%, Val ACC: 98.80%
# Epoch 10/20, train Loss: 0.0066, val Loss: 0.0056, train ACC: 99.25%, Val ACC: 100.00%
# Epoch 11/20, train Loss: 0.0772, val Loss: 0.2596, train ACC: 96.85%, Val ACC: 95.78%
# Epoch 12/20, train Loss: 0.0262, val Loss: 0.0478, train ACC: 97.45%, Val ACC: 98.19%
# Epoch 13/20, train Loss: 0.0394, val Loss: 0.0807, train ACC: 98.35%, Val ACC: 96.99%
# Epoch 14/20, train Loss: 0.0283, val Loss: 0.0194, train ACC: 97.45%, Val ACC: 99.40%
# Epoch 15/20, train Loss: 0.0859, val Loss: 0.0632, train ACC: 97.60%, Val ACC: 95.78%
# Epoch 16/20, train Loss: 0.1437, val Loss: 0.1428, train ACC: 98.50%, Val ACC: 90.96%
# Epoch 17/20, train Loss: 0.2279, val Loss: 0.1264, train ACC: 97.00%, Val ACC: 95.18%
# Epoch 18/20, train Loss: 0.0589, val Loss: 0.0518, train ACC: 97.00%, Val ACC: 96.99%
# Epoch 19/20, train Loss: 0.0119, val Loss: 0.0392, train ACC: 97.45%, Val ACC: 98.19%
# Epoch 20/20, train Loss: 0.0455, val Loss: 0.0584, train ACC: 97.75%, Val ACC: 97.59%

# %%
test_dataset = CustomDataset('/local/data1/honzh073/local_repository/FL/code/6_model_test/randompick_patient_data.csv', transform=test_transform)

test_model(model=vgg19_Adam, test_dataset=test_dataset, batch_size=64)
# Out:
# Test Loss: 0.2251, Test Acc: 92.52%
# AUC: 0.8348694978034285
# Confusion Matrix:
# [[478  16]
#  [ 28  66]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          NFF       0.94      0.97      0.96       494
#          AFF       0.80      0.70      0.75        94
#
#     accuracy                           0.93       588
#    macro avg       0.87      0.83      0.85       588
# weighted avg       0.92      0.93      0.92       588

# %% [markdown]
# # 5 fold cross validation
#
# vgg 19, RMSprop, 0.0001, batch size 64

# %%
from sklearn.model_selection import StratifiedKFold
from torchvision.models import vgg19, VGG19_Weights

classweight = get_classweight(train_dataset)

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

vgg19_Adam = models.vgg19(weights=VGG19_Weights.DEFAULT)

# Modify the last layer for binary classification
num_features = vgg19_Adam.classifier[-1].in_features
vgg19_Adam.classifier[-1] = nn.Linear(num_features, 2)  # Assuming 2 classes, change it according to your problem

# Move the model to the desired device (CPU or GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
vgg19_Adam = vgg19_Adam.to(device)

# Define your loss function and optimizer
criterion = nn.CrossEntropyLoss()
criterion = nn.CrossEntropyLoss(weight=torch.Tensor(classweight).to(device))

optimizer = optim.RMSprop(vgg19_Adam.parameters(), lr=0.0001)
# scheduler = lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# Define the number of splits for cross-validation
n_splits = 5
# kf = KFold(n_splits=n_splits, shuffle=True, random_state=1)
kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=1)
# Perform k-fold cross-validation
for fold, (train_idx, val_idx) in enumerate(kf.split(range(len(train_dataset)), train_dataset.patient_ids)):

# for fold, (train_idx, val_idx) in enumerate(kf.split(range(len(train_dataset)))):
    print(f'Fold {fold + 1}/{n_splits}')

    # Create data loaders for training and validation subsets
    train_sampler = torch.utils.data.SubsetRandomSampler(train_idx)
    val_sampler = torch.utils.data.SubsetRandomSampler(val_idx)

    train_loader = DataLoader(train_dataset, batch_size=64, sampler=train_sampler)
    val_loader = DataLoader(train_dataset, batch_size=64, sampler=val_sampler)

    # Training loop
    num_epochs = 20  # Choose the number of epochs
        # Loss, ACC
    train_losses = []
    validation_losses = []
    train_accuracies = []
    validation_accuracies = []
    
    for epoch in range(num_epochs):
        vgg19_Adam.train()
        correct_train = 0
        total_train = 0
        
        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = vgg19_Adam(images)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
        
        train_accuracy = 100 * correct_train / total_train
        
        vgg19_Adam.eval()
        correct_validation_aff = 0
        total_validation_aff = 0
        correct_validation = 0
        total_validation = 0
        validation_loss = 0
        
        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                
                outputs = vgg19_Adam(images)
                loss = criterion(outputs, labels)
                
                _, predicted = torch.max(outputs.data, 1)
                total_validation += labels.size(0)
                correct_validation += (predicted == labels).sum().item()
                validation_loss += loss.item()
                # Calculate accuracy for AFF class
                total_validation_aff += torch.sum(labels == 1).item()
                correct_validation_aff += torch.sum((predicted == 1) & (labels == 1)).item()

        validation_accuracy_aff = 100 * correct_validation_aff / total_validation_aff

        # validation accuracy and loss
        validation_accuracy = 100 * correct_validation / total_validation
        validation_loss /= len(val_loader)
        
        train_losses.append(loss.item())
        validation_losses.append(validation_loss)
        train_accuracies.append(train_accuracy)
        validation_accuracies.append(validation_accuracy)
        
        print(f"Epoch {epoch+1}/{num_epochs}, "
            f"train Loss: {loss.item():.4f}, "
            f"val Loss: {validation_loss:.4f}, "
            f"train ACC: {train_accuracy:.2f}%, "
            f"Val ACC: {validation_accuracy:.2f}%")
        # scheduler.step()
# Out:
# /local/data1/honzh073/anaconda3/envs/myenv/lib/python3.9/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# Fold 1/5
# Epoch 1/20, train Loss: 0.6939, val Loss: 0.6919, train ACC: 53.75%, Val ACC: 29.34%
# Epoch 2/20, train Loss: 0.6705, val Loss: 0.6971, train ACC: 54.35%, Val ACC: 22.16%
# Epoch 3/20, train Loss: 0.7003, val Loss: 0.6939, train ACC: 37.39%, Val ACC: 22.16%
# Epoch 4/20, train Loss: 0.6943, val Loss: 0.7034, train ACC: 43.69%, Val ACC: 22.16%
# Epoch 5/20, train Loss: 0.6906, val Loss: 0.6929, train ACC: 47.75%, Val ACC: 34.13%
# Epoch 6/20, train Loss: 0.6968, val Loss: 0.6760, train ACC: 58.41%, Val ACC: 70.66%
# Epoch 7/20, train Loss: 0.6842, val Loss: 0.6872, train ACC: 40.99%, Val ACC: 76.05%
# Epoch 8/20, train Loss: 0.6535, val Loss: 0.6673, train ACC: 59.76%, Val ACC: 57.49%
# Epoch 9/20, train Loss: 0.6794, val Loss: 0.6858, train ACC: 43.54%, Val ACC: 37.13%
# Epoch 10/20, train Loss: 0.6873, val Loss: 0.6888, train ACC: 45.05%, Val ACC: 47.31%
# Epoch 11/20, train Loss: 0.6908, val Loss: 0.6908, train ACC: 54.35%, Val ACC: 70.06%
# Epoch 12/20, train Loss: 0.6893, val Loss: 0.6901, train ACC: 59.61%, Val ACC: 70.66%
# Epoch 13/20, train Loss: 0.6971, val Loss: 0.6977, train ACC: 68.92%, Val ACC: 26.95%
# Epoch 14/20, train Loss: 0.6678, val Loss: 0.6777, train ACC: 47.45%, Val ACC: 34.73%
# Epoch 15/20, train Loss: 0.7209, val Loss: 0.6978, train ACC: 46.55%, Val ACC: 25.15%
# Epoch 16/20, train Loss: 0.7027, val Loss: 0.6943, train ACC: 40.69%, Val ACC: 41.92%
# Epoch 17/20, train Loss: 0.6882, val Loss: 0.6886, train ACC: 41.14%, Val ACC: 23.35%
# Epoch 18/20, train Loss: 0.6919, val Loss: 0.6921, train ACC: 39.94%, Val ACC: 65.27%
# Epoch 19/20, train Loss: 0.7050, val Loss: 0.6935, train ACC: 55.11%, Val ACC: 29.34%
# Epoch 20/20, train Loss: 0.6910, val Loss: 0.6783, train ACC: 48.80%, Val ACC: 57.49%
# Fold 2/5
# Epoch 1/20, train Loss: 0.7040, val Loss: 0.6858, train ACC: 50.30%, Val ACC: 38.32%
# Epoch 2/20, train Loss: 0.7009, val Loss: 0.6921, train ACC: 57.51%, Val ACC: 74.25%
# Epoch 3/20, train Loss: 0.6803, val Loss: 0.6916, train ACC: 67.12%, Val ACC: 25.75%
# Epoch 4/20, train Loss: 0.7587, val Loss: 0.7137, train ACC: 48.50%, Val ACC: 31.74%
# Epoch 5/20, train Loss: 0.6895, val Loss: 0.6785, train ACC: 53.00%, Val ACC: 50.30%
# Epoch 6/20, train Loss: 0.7015, val Loss: 0.7582, train ACC: 55.71%, Val ACC: 27.54%
# Epoch 7/20, train Loss: 0.6623, val Loss: 0.6773, train ACC: 65.47%, Val ACC: 43.71%
# Epoch 8/20, train Loss: 0.6506, val Loss: 0.6730, train ACC: 54.50%, Val ACC: 40.72%
# Epoch 9/20, train Loss: 0.7143, val Loss: 0.6758, train ACC: 53.90%, Val ACC: 38.92%
# Epoch 10/20, train Loss: 0.6654, val Loss: 0.6905, train ACC: 62.31%, Val ACC: 71.86%
# Epoch 11/20, train Loss: 0.6957, val Loss: 0.6902, train ACC: 73.12%, Val ACC: 61.08%
# Epoch 12/20, train Loss: 0.5196, val Loss: 0.7943, train ACC: 62.76%, Val ACC: 70.06%
# Epoch 13/20, train Loss: 0.6075, val Loss: 1.1850, train ACC: 56.76%, Val ACC: 70.66%
# Epoch 14/20, train Loss: 0.6864, val Loss: 0.6781, train ACC: 56.91%, Val ACC: 43.11%
# Epoch 15/20, train Loss: 0.6782, val Loss: 0.6797, train ACC: 55.56%, Val ACC: 44.91%
# Epoch 16/20, train Loss: 0.6939, val Loss: 0.6742, train ACC: 53.45%, Val ACC: 41.32%
# Epoch 17/20, train Loss: 0.6449, val Loss: 0.6558, train ACC: 53.00%, Val ACC: 43.11%
# Epoch 18/20, train Loss: 0.6666, val Loss: 0.6738, train ACC: 54.50%, Val ACC: 45.51%
# Epoch 19/20, train Loss: 0.6843, val Loss: 0.6708, train ACC: 52.40%, Val ACC: 41.92%
# Epoch 20/20, train Loss: 0.7009, val Loss: 0.6755, train ACC: 55.86%, Val ACC: 32.34%
# Fold 3/5
# Epoch 1/20, train Loss: 1.0322, val Loss: 0.9781, train ACC: 58.41%, Val ACC: 73.65%
# Epoch 2/20, train Loss: 0.6440, val Loss: 0.6576, train ACC: 59.01%, Val ACC: 50.90%
# Epoch 3/20, train Loss: 0.6885, val Loss: 0.6459, train ACC: 60.81%, Val ACC: 55.09%
# Epoch 4/20, train Loss: 0.5911, val Loss: 0.6623, train ACC: 63.81%, Val ACC: 76.05%
# Epoch 5/20, train Loss: 0.6999, val Loss: 0.6527, train ACC: 64.86%, Val ACC: 77.25%
# Epoch 6/20, train Loss: 0.6065, val Loss: 0.6439, train ACC: 66.07%, Val ACC: 47.31%
# Epoch 7/20, train Loss: 0.6994, val Loss: 0.6905, train ACC: 66.52%, Val ACC: 71.26%
# Epoch 8/20, train Loss: 0.7372, val Loss: 0.6957, train ACC: 73.57%, Val ACC: 56.89%
# Epoch 9/20, train Loss: 0.6767, val Loss: 0.6804, train ACC: 69.37%, Val ACC: 41.32%
# Epoch 10/20, train Loss: 0.7144, val Loss: 0.6849, train ACC: 60.36%, Val ACC: 53.89%
# Epoch 11/20, train Loss: 0.7433, val Loss: 0.7125, train ACC: 61.56%, Val ACC: 77.25%
# Epoch 12/20, train Loss: 0.6819, val Loss: 0.6730, train ACC: 69.07%, Val ACC: 79.04%
# Epoch 13/20, train Loss: 0.6228, val Loss: 0.6243, train ACC: 70.72%, Val ACC: 54.49%
# Epoch 14/20, train Loss: 0.7073, val Loss: 0.6711, train ACC: 65.77%, Val ACC: 49.10%
# Epoch 15/20, train Loss: 0.6875, val Loss: 0.6609, train ACC: 64.56%, Val ACC: 55.09%
# Epoch 16/20, train Loss: 1.1889, val Loss: 1.0157, train ACC: 66.22%, Val ACC: 68.26%
# Epoch 17/20, train Loss: 0.6728, val Loss: 0.6792, train ACC: 66.07%, Val ACC: 28.74%
# Epoch 18/20, train Loss: 0.5236, val Loss: 0.6203, train ACC: 56.91%, Val ACC: 68.86%
# Epoch 19/20, train Loss: 0.5984, val Loss: 0.6442, train ACC: 66.97%, Val ACC: 70.06%
# Epoch 20/20, train Loss: 0.6975, val Loss: 0.6776, train ACC: 71.62%, Val ACC: 38.92%
# Fold 4/5
# Epoch 1/20, train Loss: 0.7075, val Loss: 0.6720, train ACC: 66.42%, Val ACC: 51.81%
# Epoch 2/20, train Loss: 0.6261, val Loss: 0.7059, train ACC: 64.92%, Val ACC: 68.07%
# Epoch 3/20, train Loss: 0.9423, val Loss: 0.9818, train ACC: 70.01%, Val ACC: 28.31%
# Epoch 4/20, train Loss: 0.6172, val Loss: 0.6350, train ACC: 64.92%, Val ACC: 49.40%
# Epoch 5/20, train Loss: 0.6009, val Loss: 0.6985, train ACC: 66.57%, Val ACC: 43.37%
# Epoch 6/20, train Loss: 0.6386, val Loss: 0.6480, train ACC: 70.16%, Val ACC: 58.43%
# Epoch 7/20, train Loss: 0.6504, val Loss: 0.6159, train ACC: 71.81%, Val ACC: 63.86%
# Epoch 8/20, train Loss: 0.8355, val Loss: 0.7623, train ACC: 75.71%, Val ACC: 37.95%
# Epoch 9/20, train Loss: 0.4970, val Loss: 0.5559, train ACC: 68.97%, Val ACC: 72.29%
# Epoch 10/20, train Loss: 0.5288, val Loss: 0.5544, train ACC: 71.51%, Val ACC: 66.27%
# Epoch 11/20, train Loss: 0.7505, val Loss: 0.6792, train ACC: 74.96%, Val ACC: 82.53%
# Epoch 12/20, train Loss: 0.5905, val Loss: 0.5901, train ACC: 75.56%, Val ACC: 57.83%
# Epoch 13/20, train Loss: 0.5428, val Loss: 0.5863, train ACC: 77.21%, Val ACC: 79.52%
# Epoch 14/20, train Loss: 0.5328, val Loss: 0.5038, train ACC: 81.41%, Val ACC: 72.29%
# Epoch 15/20, train Loss: 0.5929, val Loss: 0.5940, train ACC: 77.51%, Val ACC: 58.43%
# Epoch 16/20, train Loss: 0.8614, val Loss: 1.0127, train ACC: 80.06%, Val ACC: 83.13%
# Epoch 17/20, train Loss: 0.6637, val Loss: 0.7016, train ACC: 77.51%, Val ACC: 78.92%
# Epoch 18/20, train Loss: 0.4873, val Loss: 0.4772, train ACC: 79.46%, Val ACC: 82.53%
# Epoch 19/20, train Loss: 0.5835, val Loss: 0.6264, train ACC: 79.46%, Val ACC: 84.94%
# Epoch 20/20, train Loss: 0.4814, val Loss: 0.4869, train ACC: 86.21%, Val ACC: 85.54%
# Fold 5/5
# Epoch 1/20, train Loss: 0.4017, val Loss: 0.3999, train ACC: 77.81%, Val ACC: 75.90%
# Epoch 2/20, train Loss: 0.2568, val Loss: 0.3434, train ACC: 80.66%, Val ACC: 80.12%
# Epoch 3/20, train Loss: 1.9371, val Loss: 1.7035, train ACC: 83.21%, Val ACC: 81.33%
# Epoch 4/20, train Loss: 0.5584, val Loss: 0.4784, train ACC: 73.16%, Val ACC: 78.92%
# Epoch 5/20, train Loss: 0.5472, val Loss: 0.4750, train ACC: 80.81%, Val ACC: 84.34%
# Epoch 6/20, train Loss: 0.4418, val Loss: 0.4128, train ACC: 83.96%, Val ACC: 84.94%
# Epoch 7/20, train Loss: 0.3565, val Loss: 0.4348, train ACC: 81.71%, Val ACC: 72.29%
# Epoch 8/20, train Loss: 0.5125, val Loss: 0.4496, train ACC: 84.26%, Val ACC: 74.10%
# Epoch 9/20, train Loss: 0.3276, val Loss: 0.4012, train ACC: 82.61%, Val ACC: 82.53%
# Epoch 10/20, train Loss: 0.6756, val Loss: 0.6671, train ACC: 71.36%, Val ACC: 46.99%
# Epoch 11/20, train Loss: 0.3781, val Loss: 0.3778, train ACC: 71.36%, Val ACC: 87.35%
# Epoch 12/20, train Loss: 0.7761, val Loss: 0.7520, train ACC: 82.91%, Val ACC: 84.34%
# Epoch 13/20, train Loss: 0.2377, val Loss: 0.3245, train ACC: 83.66%, Val ACC: 82.53%
# Epoch 14/20, train Loss: 0.4074, val Loss: 0.3825, train ACC: 80.21%, Val ACC: 81.93%
# Epoch 15/20, train Loss: 0.1664, val Loss: 0.3860, train ACC: 88.76%, Val ACC: 87.95%
# Epoch 16/20, train Loss: 0.2839, val Loss: 0.3312, train ACC: 88.01%, Val ACC: 80.12%
# Epoch 17/20, train Loss: 0.5196, val Loss: 0.4201, train ACC: 87.26%, Val ACC: 78.92%
# Epoch 18/20, train Loss: 0.7731, val Loss: 0.6282, train ACC: 87.26%, Val ACC: 88.55%
# Epoch 19/20, train Loss: 0.2974, val Loss: 0.3318, train ACC: 86.96%, Val ACC: 91.57%
# Epoch 20/20, train Loss: 0.3720, val Loss: 0.5972, train ACC: 91.75%, Val ACC: 88.55%

# %%
# vgg19_rmsprop
test_dataset = CustomDataset('/local/data1/honzh073/local_repository/FL/code/6_model_test/randompick_patient_data.csv', transform=test_transform)

test_model(model=vgg19_Adam, test_dataset=test_dataset, batch_size=64)
# Out:
# Test Loss: 0.3374, Test Acc: 89.12%
# AUC: 0.7198725127056593
# Confusion Matrix:
# [[480  14]
#  [ 50  44]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          NFF       0.91      0.97      0.94       494
#          AFF       0.76      0.47      0.58        94
#
#     accuracy                           0.89       588
#    macro avg       0.83      0.72      0.76       588
# weighted avg       0.88      0.89      0.88       588
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
