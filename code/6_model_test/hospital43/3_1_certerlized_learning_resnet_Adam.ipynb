# %% [markdown]
# # Create all image csv files

# %%
# import os
# import csv

# def create_csv(image_folder, csv_file_path):
#     # Define the CSV header fields
#     fieldnames = ['HospitalID', 'PatientID', 'ImageID', 'ImagePath', 'Label']
    
#     # Open the CSV file in write mode
#     with open(csv_file_path, 'w', newline='') as csvfile:
#         # Create a CSV writer object and write the header
#         writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
#         writer.writeheader()

#         # Iterate through files in the folder
#         for filename in sorted(os.listdir(image_folder)):
#             # Construct the complete image file path
#             image_path = os.path.join(image_folder, filename)

#             # Parse the filename to extract HospitalID, PatientID, image number, and image label
#             parts = filename.split('_')
#             hospital_id = parts[3]
#             patient_id = parts[1]
#             image_number = parts[6]
#             image_label = parts[4]

#             # Write data into the CSV file
#             writer.writerow({
#                 'HospitalID': hospital_id,
#                 'PatientID': patient_id,
#                 'ImageID': image_number,
#                 'ImagePath': image_path,
#                 'Label': image_label
#             })

#     # Print a message indicating that the CSV file has been created and saved
#     print("CSV file has been created and saved to:", csv_file_path)


# image_folder = "/local/data1/honzh073/data/8bit_downsample_256"
# csv_file_path = "/local/data1/honzh073/local_repo/FL/code/3_single_hospital/csv_files/image_data.csv"
# create_csv(image_folder, csv_file_path)

# %%
# # Create csv files, hospital 43, 55&18, 54&22
# import pandas as pd

# # Read the original CSV file
# original_df = pd.read_csv('/local/data1/honzh073/local_repository/FL/code/6_model_test/all_image_data.csv')

# # List of hospitals to keep
# hospitals_to_keep = [43, 55, 54, 18, 33]

# # Filter rows based on HospitalID
# filtered_df = original_df[original_df['HospitalID'].isin(hospitals_to_keep)]

# # Save the filtered DataFrame to a new CSV file at the specified path
# output_path = '/local/data1/honzh073/local_repository/FL/code/6_model_test/centralized_learning.csv'
# filtered_df.to_csv(output_path, index=False)

# print(f"Filtered CSV file created successfully at: {output_path}")

# %% [markdown]
# # create train, val csv

# %%
# import csv
# from collections import defaultdict
# import random
# import os

# def split_and_save_data(input_csv_path, output_folder, target_hospital_ids, train_ratio, seed):
#     patient_data = defaultdict(list)
    
#     with open(input_csv_path, 'r') as csvfile:
#         reader = csv.DictReader(csvfile)
#         for row in reader:
#             if row['HospitalID'] in target_hospital_ids:
#                 patient_id = row['PatientID']
#                 patient_data[patient_id].append(row)

#     num_patients = len(patient_data)

#     num_train = int(num_patients * train_ratio)

#     # get random IDs
#     all_patient_ids = list(patient_data.keys())

#     random.seed(seed)
#     random.shuffle(all_patient_ids)

#     # split by ID
#     train_patients = all_patient_ids[ : num_train]
#     test_patients = all_patient_ids[num_train: ]

#     # iter by patient IDs
#     train_data = []
#     test_data = []

#     for patient_id, images in patient_data.items():
#         if patient_id in train_patients:
#             train_data.extend(images)
#         elif patient_id in test_patients:
#             test_data.extend(images)

#     # write to csv
#     def write_to_csv(file_path, data):
#         with open(file_path, 'w', newline='') as csvfile:
#             writer = csv.DictWriter(csvfile, fieldnames=data[0].keys())
#             writer.writeheader()
#             writer.writerows(data)

#     # Write to CSV files
#     write_to_csv(os.path.join(output_folder, 'cl_cross_train.csv'), train_data)
#     write_to_csv(os.path.join(output_folder, 'cl_cross_test.csv'), test_data)
    
#     print("Saved train.csv, test.csv.")

# # input and output path
# input_csv_path = "/local/data1/honzh073/local_repository/FL/code/6_model_test/all_image_data.csv"
# output_folder = '/local/data1/honzh073/local_repository/FL/code/6_model_test'

# # single hospital id
# target_hospital_ids = ['43', '55', '54', '18', '33']

# # random seed
# seed = 1

# # train and val dataset ratio
# train_ratio = 0.7
# # test_ratio = 0.3 # unnecessary

# split_and_save_data(input_csv_path, output_folder,
#                     train_ratio=train_ratio,
#                     target_hospital_ids = target_hospital_ids,
#                     seed = seed)

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import models
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_curve, roc_auc_score
   
def plot_roc_curve(all_labels, all_predictions):
    fpr, tpr, thresholds = roc_curve(all_labels, all_predictions)
    roc_auc = roc_auc_score(all_labels, all_predictions)

    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend(loc='lower right')
    plt.show()

def show_image(dataset, num_images=5):
    # Get random indices
    random_indices = np.random.choice(len(dataset), num_images, replace=False)

    # Plot images with truncated names
    plt.figure(figsize=(15, 5))
    for i, idx in enumerate(random_indices):
        image, label = dataset[idx]  # Use the dataset directly
        filename = dataset.data[idx][0]  # Get the filename from dataset's internal data attribute
        truncated_filename = filename.split('/')[-1][:15]  # Extract the last part and truncate to 15 characters
        
        # Print the original filename
        print(f"Image location: {filename}")

        plt.subplot(1, num_images, i + 1)
        plt.title(f"Label: {label}")
        plt.imshow(image[0])  # Assuming single-channel (grayscale) image
        # plt.imshow(image[0], cmap='gray')  # Assuming single-channel (grayscale) image

        plt.axis('off')
    plt.show()
    
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

def get_classweight(train_dataset):
    train_nff_count = sum(1 for _, label in train_dataset if label == 0)  # 0 NFF
    train_aff_count = sum(1 for _, label in train_dataset if label == 1)  # 1 AFF
    class_weight_nff = 1 / (2 * (train_nff_count / (train_nff_count + train_aff_count)))
    class_weight_aff = 1 / (2 * (train_aff_count / (train_nff_count + train_aff_count)))
    
    return [class_weight_nff, class_weight_aff] # 0 nff , 1 aff


def test_model(model, test_dataset, batch_size):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)
    model.eval()
    
    correct_test = 0
    total_test = 0
    test_loss = 0
    
    criterion = nn.CrossEntropyLoss()
    
    with torch.no_grad():
        all_predictions = []
        all_labels = []
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            _, predicted = torch.max(outputs.data, 1)
            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            total_test += labels.size(0)
            correct_test += (predicted == labels).sum().item()
            test_loss += loss.item()

    test_accuracy = 100 * correct_test / total_test
    test_loss /= len(test_loader)

    print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_accuracy:.2f}%")
     
    auc_score = roc_auc_score(all_labels, all_predictions)
    conf_matrix = confusion_matrix(all_labels, all_predictions)
    
    # Precision、Recall、F1 Score
    class_labels = {0: 'NFF', 1: 'AFF'}

    classification_rep = classification_report(all_labels, all_predictions, target_names=[class_labels[i] for i in range(len(class_labels))])
    print("AUC:", auc_score)
    print("Confusion Matrix:")
    print(conf_matrix)
    print("Classification Report:")
    print(classification_rep)

    plot_roc_curve(all_labels, all_predictions)

# %% [markdown]
# # Centralized learning and random pick test
#
# read csv file centralized_learning.csv and train model use 5 fold cross validation
#
# test on randompick_patient_data.csv

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import csv
import pandas as pd
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, models
from sklearn.model_selection import KFold

# Custom dataset class
class CustomDataset(Dataset):
    def __init__(self, csv_file, transform=None):
        self.data = []
        self.labels = []  # Store labels separately
        self.patient_ids = []  # Store patient IDs separately
        self.transform = transform
        
        # read csv
        with open(csv_file, 'r') as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                image_path = row['ImagePath']
                label = row['Label']
                patient_id = row['PatientID']  # Assuming 'PatientID' is the column name in your CSV file

                if label == 'NFF':
                    label = 0
                elif label == 'AFF':
                    label = 1
                else:
                    raise ValueError("Invalid label in CSV file.")
                self.data.append((image_path, label))
                self.labels.append(label)
                self.patient_ids.append(patient_id)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image_path, label = self.data[idx]
        image = Image.open(image_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image, label

# Define your image transformations for training and testing
train_transform = transforms.Compose([
    transforms.RandomRotation(degrees=20),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomResizedCrop(256, scale=(0.8, 1.0)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.GaussianBlur(kernel_size=3),
    transforms.RandomAdjustSharpness(sharpness_factor=5),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Load the datasets using CustomDataset class
train_dataset = CustomDataset('/local/data1/honzh073/local_repository/FL/code/6_model_test/hospital43.csv', transform=train_transform)
test_dataset = CustomDataset('/local/data1/honzh073/local_repository/FL/code/6_model_test/randompick_patient_data.csv', transform=test_transform)

# classweight
classweight = get_classweight(train_dataset)
print('training class weight', classweight)

# device
# device = torch.device("cuda:0" if  torch.cuda.is_available() else "cpu")

# print images
show_image(train_dataset, 10)

# calculate numbers
# print("Saved train.csv, val.csv, test.csv.")
print('-----------------------------------')
train_NFF_count = sum(1 for _, label in train_dataset if label == 0)  # 0 NFF
train_AFF_count = sum(1 for _, label in train_dataset if label == 1)  # 1 AFF
test_NFF_count = sum(1 for _, label in test_dataset if label == 0)  # 0 NFF
test_AFF_count = sum(1 for _, label in test_dataset if label == 1)  # 1 AFF

print(f"train AFF: {train_AFF_count}, ratio: {train_AFF_count / (train_AFF_count + train_NFF_count):.2f}")
print(f"----- NFF: {train_NFF_count}, ratio: {train_NFF_count / (train_AFF_count + train_NFF_count):.2f}")
print('-----------------------------------')
print(f"test AFF: {test_AFF_count}, ratio: {test_AFF_count / (test_AFF_count + test_NFF_count):.2f}")
print(f"---- NFF: {test_NFF_count}, ratio: {test_NFF_count / (test_AFF_count + test_NFF_count):.2f}")
# Out:
# training class weight [0.6538461538461539, 2.125]
# Image location: /local/data1/honzh073/data/8bit_down224/patient_QXFRIAVLCY_hospital_54_NFF_image_5.png
# Image location: /local/data1/honzh073/data/8bit_down224/patient_SDEGXCSEVI_hospital_18_AFF_image_2.png
# Image location: /local/data1/honzh073/data/8bit_down224/patient_QBRMHNSVII_hospital_43_NFF_image_5.png
# Image location: /local/data1/honzh073/data/8bit_down224/patient_GHXSWJQAXM_hospital_43_NFF_image_3.png
# Image location: /local/data1/honzh073/data/8bit_down224/patient_HSROSREDZE_hospital_43_NFF_image_4.png
# Image location: /local/data1/honzh073/data/8bit_down224/patient_HGGEYYVSEJ_hospital_43_NFF_image_2.png
# Image location: /local/data1/honzh073/data/8bit_down224/patient_SDEGXCSEVI_hospital_18_AFF_image_6.png
# Image location: /local/data1/honzh073/data/8bit_down224/patient_JQRZYJFXHO_hospital_18_NFF_image_2.png
# Image location: /local/data1/honzh073/data/8bit_down224/patient_PSJSXBDWKK_hospital_18_NFF_image_2.png
# Image location: /local/data1/honzh073/data/8bit_down224/patient_EIIXGIKSDW_hospital_43_NFF_image_3.png
# -----------------------------------
# train AFF: 196, ratio: 0.24
# ----- NFF: 637, ratio: 0.76
# -----------------------------------
# test AFF: 94, ratio: 0.16
# ---- NFF: 494, ratio: 0.84

# %% [markdown]
# # ResNet 50 Adam

# %%
from sklearn.model_selection import StratifiedKFold
from torchvision.models import resnet152, ResNet152_Weights
from torchvision.models import resnet50, ResNet50_Weights

classweight = get_classweight(train_dataset)

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Define the ResNet-101 model
model = models.resnet50(weights=ResNet50_Weights.DEFAULT)
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)  # Assuming 2 classes, change it according to your problem
model = model.to(device)

# Define your loss function and optimizer
criterion = nn.CrossEntropyLoss()
criterion = nn.CrossEntropyLoss(weight=torch.Tensor(classweight).to(device))

optimizer = optim.Adam(model.parameters(), lr=0.0001)
# scheduler = lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# Define the number of splits for cross-validation
n_splits = 5
# kf = KFold(n_splits=n_splits, shuffle=True, random_state=1)
kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=1)
# Perform k-fold cross-validation
for fold, (train_idx, val_idx) in enumerate(kf.split(range(len(train_dataset)), train_dataset.patient_ids)):

# for fold, (train_idx, val_idx) in enumerate(kf.split(range(len(train_dataset)))):
    print(f'Fold {fold + 1}/{n_splits}')

    # Create data loaders for training and validation subsets
    train_sampler = torch.utils.data.SubsetRandomSampler(train_idx)
    val_sampler = torch.utils.data.SubsetRandomSampler(val_idx)

    train_loader = DataLoader(train_dataset, batch_size=64, sampler=train_sampler)
    val_loader = DataLoader(train_dataset, batch_size=64, sampler=val_sampler)

    # Training loop
    num_epochs = 20  # Choose the number of epochs
        # Loss, ACC
    train_losses = []
    validation_losses = []
    train_accuracies = []
    validation_accuracies = []
    
    for epoch in range(num_epochs):
        model.train()
        correct_train = 0
        total_train = 0
        
        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
        
        train_accuracy = 100 * correct_train / total_train
        
        model.eval()
        correct_validation_aff = 0
        total_validation_aff = 0
        correct_validation = 0
        total_validation = 0
        validation_loss = 0
        
        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                
                outputs = model(images)
                loss = criterion(outputs, labels)
                
                _, predicted = torch.max(outputs.data, 1)
                total_validation += labels.size(0)
                correct_validation += (predicted == labels).sum().item()
                validation_loss += loss.item()
                # Calculate accuracy for AFF class
                total_validation_aff += torch.sum(labels == 1).item()
                correct_validation_aff += torch.sum((predicted == 1) & (labels == 1)).item()

        validation_accuracy_aff = 100 * correct_validation_aff / total_validation_aff

        # validation accuracy and loss
        validation_accuracy = 100 * correct_validation / total_validation
        validation_loss /= len(val_loader)
        
        train_losses.append(loss.item())
        validation_losses.append(validation_loss)
        train_accuracies.append(train_accuracy)
        validation_accuracies.append(validation_accuracy)
        
        print(f"Epoch {epoch+1}/{num_epochs}, "
            f"train Loss: {loss.item():.4f}, "
            f"val Loss: {validation_loss:.4f}, "
            f"train ACC: {train_accuracy:.2f}%, "
            f"Val ACC: {validation_accuracy:.2f}%")
        # scheduler.step()
# Out:
# /local/data1/honzh073/anaconda3/envs/myenv/lib/python3.9/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# Fold 1/5
# Epoch 1/20, train Loss: 0.6943, val Loss: 0.6968, train ACC: 63.06%, Val ACC: 60.48%
# Epoch 2/20, train Loss: 0.7156, val Loss: 0.6780, train ACC: 58.86%, Val ACC: 62.87%
# Epoch 3/20, train Loss: 0.6715, val Loss: 0.6564, train ACC: 56.16%, Val ACC: 56.29%
# Epoch 4/20, train Loss: 0.6992, val Loss: 0.6533, train ACC: 59.31%, Val ACC: 44.91%
# Epoch 5/20, train Loss: 0.6625, val Loss: 0.6494, train ACC: 69.37%, Val ACC: 49.70%
# Epoch 6/20, train Loss: 0.5931, val Loss: 0.5365, train ACC: 71.17%, Val ACC: 71.26%
# Epoch 7/20, train Loss: 0.4201, val Loss: 0.4814, train ACC: 76.73%, Val ACC: 86.83%
# Epoch 8/20, train Loss: 0.3615, val Loss: 0.4892, train ACC: 81.08%, Val ACC: 77.25%
# Epoch 9/20, train Loss: 0.2075, val Loss: 0.3432, train ACC: 82.88%, Val ACC: 86.83%
# Epoch 10/20, train Loss: 0.3561, val Loss: 0.3295, train ACC: 84.53%, Val ACC: 85.03%
# Epoch 11/20, train Loss: 0.3230, val Loss: 0.3167, train ACC: 87.09%, Val ACC: 88.02%
# Epoch 12/20, train Loss: 0.3021, val Loss: 0.3579, train ACC: 88.29%, Val ACC: 86.23%
# Epoch 13/20, train Loss: 0.3011, val Loss: 0.3867, train ACC: 90.24%, Val ACC: 86.83%
# Epoch 14/20, train Loss: 0.1836, val Loss: 0.2455, train ACC: 89.94%, Val ACC: 92.81%
# Epoch 15/20, train Loss: 0.3905, val Loss: 0.2964, train ACC: 92.79%, Val ACC: 86.83%
# Epoch 16/20, train Loss: 0.2331, val Loss: 0.2483, train ACC: 94.29%, Val ACC: 88.62%
# Epoch 17/20, train Loss: 0.1296, val Loss: 0.2176, train ACC: 94.59%, Val ACC: 90.42%
# Epoch 18/20, train Loss: 0.0895, val Loss: 0.1811, train ACC: 94.44%, Val ACC: 92.22%
# Epoch 19/20, train Loss: 0.2373, val Loss: 0.2154, train ACC: 93.84%, Val ACC: 89.82%
# Epoch 20/20, train Loss: 0.4489, val Loss: 0.3428, train ACC: 97.75%, Val ACC: 86.83%
# Fold 2/5
# Epoch 1/20, train Loss: 0.1576, val Loss: 0.1142, train ACC: 94.14%, Val ACC: 97.01%
# Epoch 2/20, train Loss: 0.3007, val Loss: 0.1565, train ACC: 95.65%, Val ACC: 97.60%
# Epoch 3/20, train Loss: 0.2996, val Loss: 0.1667, train ACC: 93.99%, Val ACC: 95.81%
# Epoch 4/20, train Loss: 0.0573, val Loss: 0.0992, train ACC: 96.25%, Val ACC: 96.41%
# Epoch 5/20, train Loss: 0.4615, val Loss: 0.2707, train ACC: 97.30%, Val ACC: 91.62%
# Epoch 6/20, train Loss: 0.0547, val Loss: 0.0990, train ACC: 98.05%, Val ACC: 97.01%
# Epoch 7/20, train Loss: 0.2652, val Loss: 0.2335, train ACC: 95.50%, Val ACC: 94.01%
# Epoch 8/20, train Loss: 0.1955, val Loss: 0.1460, train ACC: 98.20%, Val ACC: 94.61%
# Epoch 9/20, train Loss: 0.3314, val Loss: 0.1855, train ACC: 96.10%, Val ACC: 95.81%
# Epoch 10/20, train Loss: 0.0716, val Loss: 0.2471, train ACC: 97.90%, Val ACC: 94.01%
# Epoch 11/20, train Loss: 0.0353, val Loss: 0.1045, train ACC: 97.60%, Val ACC: 97.60%
# Epoch 12/20, train Loss: 0.1567, val Loss: 0.1803, train ACC: 98.65%, Val ACC: 93.41%
# Epoch 13/20, train Loss: 0.3143, val Loss: 0.2180, train ACC: 98.05%, Val ACC: 93.41%
# Epoch 14/20, train Loss: 0.0580, val Loss: 0.1409, train ACC: 98.65%, Val ACC: 94.61%
# Epoch 15/20, train Loss: 0.2065, val Loss: 0.1986, train ACC: 98.95%, Val ACC: 96.41%
# Epoch 16/20, train Loss: 0.0972, val Loss: 0.2001, train ACC: 98.35%, Val ACC: 92.81%
# Epoch 17/20, train Loss: 0.1171, val Loss: 0.1887, train ACC: 98.65%, Val ACC: 92.81%
# Epoch 18/20, train Loss: 0.3153, val Loss: 0.3163, train ACC: 98.05%, Val ACC: 92.22%
# Epoch 19/20, train Loss: 0.0892, val Loss: 0.1242, train ACC: 98.65%, Val ACC: 94.61%
# Epoch 20/20, train Loss: 0.4752, val Loss: 0.2590, train ACC: 98.35%, Val ACC: 95.21%
# Fold 3/5
# Epoch 1/20, train Loss: 0.0337, val Loss: 0.0923, train ACC: 96.85%, Val ACC: 96.41%
# Epoch 2/20, train Loss: 0.0683, val Loss: 0.1122, train ACC: 96.70%, Val ACC: 95.81%
# Epoch 3/20, train Loss: 0.0082, val Loss: 0.0636, train ACC: 98.35%, Val ACC: 98.20%
# Epoch 4/20, train Loss: 0.0309, val Loss: 0.0316, train ACC: 98.50%, Val ACC: 98.80%
# Epoch 5/20, train Loss: 0.1178, val Loss: 0.0550, train ACC: 98.35%, Val ACC: 98.20%
# Epoch 6/20, train Loss: 0.1035, val Loss: 0.0973, train ACC: 98.80%, Val ACC: 97.01%
# Epoch 7/20, train Loss: 0.2938, val Loss: 0.1425, train ACC: 99.10%, Val ACC: 96.41%
# Epoch 8/20, train Loss: 0.0328, val Loss: 0.0302, train ACC: 98.95%, Val ACC: 99.40%
# Epoch 9/20, train Loss: 0.0827, val Loss: 0.0657, train ACC: 99.25%, Val ACC: 95.81%
# Epoch 10/20, train Loss: 0.0231, val Loss: 0.0303, train ACC: 98.35%, Val ACC: 98.80%
# Epoch 11/20, train Loss: 0.0575, val Loss: 0.1122, train ACC: 99.25%, Val ACC: 96.41%
# Epoch 12/20, train Loss: 0.1665, val Loss: 0.1048, train ACC: 98.50%, Val ACC: 97.60%
# Epoch 13/20, train Loss: 0.0150, val Loss: 0.0803, train ACC: 99.25%, Val ACC: 98.20%
# Epoch 14/20, train Loss: 0.0229, val Loss: 0.0916, train ACC: 99.25%, Val ACC: 97.60%
# Epoch 15/20, train Loss: 0.0034, val Loss: 0.0481, train ACC: 97.90%, Val ACC: 97.60%
# Epoch 16/20, train Loss: 0.0095, val Loss: 0.0286, train ACC: 99.25%, Val ACC: 98.20%
# Epoch 17/20, train Loss: 0.0191, val Loss: 0.0739, train ACC: 99.10%, Val ACC: 97.60%
# Epoch 18/20, train Loss: 0.1159, val Loss: 0.0828, train ACC: 99.40%, Val ACC: 97.60%
# Epoch 19/20, train Loss: 0.0458, val Loss: 0.1152, train ACC: 98.95%, Val ACC: 96.41%
# Epoch 20/20, train Loss: 0.0405, val Loss: 0.0464, train ACC: 99.70%, Val ACC: 98.20%
# Fold 4/5
# Epoch 1/20, train Loss: 0.0512, val Loss: 0.0541, train ACC: 99.55%, Val ACC: 97.59%
# Epoch 2/20, train Loss: 0.0093, val Loss: 0.0226, train ACC: 99.55%, Val ACC: 98.80%
# Epoch 3/20, train Loss: 0.0074, val Loss: 0.0282, train ACC: 98.50%, Val ACC: 98.80%
# Epoch 4/20, train Loss: 0.0121, val Loss: 0.0093, train ACC: 98.95%, Val ACC: 100.00%
# Epoch 5/20, train Loss: 0.0397, val Loss: 0.0254, train ACC: 99.55%, Val ACC: 100.00%
# Epoch 6/20, train Loss: 0.0077, val Loss: 0.0054, train ACC: 99.55%, Val ACC: 100.00%
# Epoch 7/20, train Loss: 0.0043, val Loss: 0.0396, train ACC: 99.40%, Val ACC: 98.80%
# Epoch 8/20, train Loss: 0.0041, val Loss: 0.0245, train ACC: 98.05%, Val ACC: 99.40%
# Epoch 9/20, train Loss: 0.0351, val Loss: 0.0262, train ACC: 98.35%, Val ACC: 99.40%
# Epoch 10/20, train Loss: 0.0048, val Loss: 0.0119, train ACC: 98.50%, Val ACC: 98.80%
# Epoch 11/20, train Loss: 0.0724, val Loss: 0.0360, train ACC: 98.95%, Val ACC: 98.80%
# Epoch 12/20, train Loss: 0.0184, val Loss: 0.0242, train ACC: 98.50%, Val ACC: 99.40%
# Epoch 13/20, train Loss: 0.0193, val Loss: 0.0258, train ACC: 99.25%, Val ACC: 99.40%
# Epoch 14/20, train Loss: 0.0619, val Loss: 0.0540, train ACC: 99.85%, Val ACC: 99.40%
# Epoch 15/20, train Loss: 0.0625, val Loss: 0.0354, train ACC: 99.55%, Val ACC: 98.80%
# Epoch 16/20, train Loss: 0.0232, val Loss: 0.0217, train ACC: 99.10%, Val ACC: 100.00%
# Epoch 17/20, train Loss: 0.0933, val Loss: 0.0410, train ACC: 99.85%, Val ACC: 99.40%
# Epoch 18/20, train Loss: 0.0407, val Loss: 0.0710, train ACC: 99.40%, Val ACC: 98.19%
# Epoch 19/20, train Loss: 0.0023, val Loss: 0.0095, train ACC: 99.25%, Val ACC: 99.40%
# Epoch 20/20, train Loss: 0.0156, val Loss: 0.0121, train ACC: 99.55%, Val ACC: 100.00%
# Fold 5/5
# Epoch 1/20, train Loss: 0.0029, val Loss: 0.0148, train ACC: 98.95%, Val ACC: 98.80%
# Epoch 2/20, train Loss: 0.0819, val Loss: 0.0362, train ACC: 98.80%, Val ACC: 98.80%
# Epoch 3/20, train Loss: 0.1286, val Loss: 0.0582, train ACC: 99.10%, Val ACC: 98.80%
# Epoch 4/20, train Loss: 0.0633, val Loss: 0.0319, train ACC: 99.25%, Val ACC: 99.40%
# Epoch 5/20, train Loss: 0.0100, val Loss: 0.0161, train ACC: 98.80%, Val ACC: 99.40%
# Epoch 6/20, train Loss: 0.0398, val Loss: 0.0350, train ACC: 98.80%, Val ACC: 98.80%
# Epoch 7/20, train Loss: 0.0352, val Loss: 0.0211, train ACC: 99.40%, Val ACC: 100.00%
# Epoch 8/20, train Loss: 0.0644, val Loss: 0.0240, train ACC: 99.55%, Val ACC: 100.00%
# Epoch 9/20, train Loss: 0.0293, val Loss: 0.0229, train ACC: 99.55%, Val ACC: 98.19%
# Epoch 10/20, train Loss: 0.0447, val Loss: 0.0408, train ACC: 98.20%, Val ACC: 98.80%
# Epoch 11/20, train Loss: 0.0038, val Loss: 0.0101, train ACC: 99.55%, Val ACC: 99.40%
# Epoch 12/20, train Loss: 0.0153, val Loss: 0.0096, train ACC: 99.55%, Val ACC: 100.00%
# Epoch 13/20, train Loss: 0.0579, val Loss: 0.0283, train ACC: 99.55%, Val ACC: 98.80%
# Epoch 14/20, train Loss: 0.0082, val Loss: 0.0172, train ACC: 99.55%, Val ACC: 98.80%
# Epoch 15/20, train Loss: 0.0276, val Loss: 0.0232, train ACC: 99.70%, Val ACC: 99.40%
# Epoch 16/20, train Loss: 0.0008, val Loss: 0.0223, train ACC: 100.00%, Val ACC: 98.80%
# Epoch 17/20, train Loss: 0.0034, val Loss: 0.0144, train ACC: 99.55%, Val ACC: 98.80%
# Epoch 18/20, train Loss: 0.0644, val Loss: 0.0325, train ACC: 99.70%, Val ACC: 98.80%
# Epoch 19/20, train Loss: 0.0153, val Loss: 0.0432, train ACC: 100.00%, Val ACC: 98.19%
# Epoch 20/20, train Loss: 0.0134, val Loss: 0.0382, train ACC: 99.70%, Val ACC: 98.80%

# %%
# resnet 50
test_dataset = CustomDataset('/local/data1/honzh073/local_repository/FL/code/6_model_test/randompick_patient_data.csv', transform=test_transform)

test_model(model=model, test_dataset=test_dataset, batch_size=64)
# Out:
# Test Loss: 0.1946, Test Acc: 93.71%
# AUC: 0.9065595658540787
# Confusion Matrix:
# [[470  24]
#  [ 13  81]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          NFF       0.97      0.95      0.96       494
#          AFF       0.77      0.86      0.81        94
#
#     accuracy                           0.94       588
#    macro avg       0.87      0.91      0.89       588
# weighted avg       0.94      0.94      0.94       588

# %% [markdown]
# # ResNet 101 Adam

# %%
from sklearn.model_selection import StratifiedKFold
from torchvision.models import resnet101, ResNet101_Weights

classweight = get_classweight(train_dataset)

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Define the ResNet-101 model
model = models.resnet101(weights=ResNet101_Weights.DEFAULT)

num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 2)  # Assuming 2 classes, change it according to your problem
model = model.to(device)

# Define your loss function and optimizer
criterion = nn.CrossEntropyLoss(weight=torch.Tensor(classweight).to(device))

optimizer = optim.Adam(model.parameters(), lr=0.0001)
# scheduler = lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# Define the number of splits for cross-validation
n_splits = 5
# kf = KFold(n_splits=n_splits, shuffle=True, random_state=1)
kf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=1)

# k-fold cross-validation
for fold, (train_idx, val_idx) in enumerate(kf.split(range(len(train_dataset)), train_dataset.patient_ids)):

# for fold, (train_idx, val_idx) in enumerate(kf.split(range(len(train_dataset)))):
    print(f'Fold {fold + 1}/{n_splits}')

    # Create data loaders for training and validation subsets
    train_sampler = torch.utils.data.SubsetRandomSampler(train_idx)
    val_sampler = torch.utils.data.SubsetRandomSampler(val_idx)

    train_loader = DataLoader(train_dataset, batch_size=64, sampler=train_sampler)
    val_loader = DataLoader(train_dataset, batch_size=64, sampler=val_sampler)

    # Training loop
    num_epochs = 20  # Choose the number of epochs
    
    # Loss, ACC
    train_losses = []
    validation_losses = []
    train_accuracies = []
    validation_accuracies = []
    
    for epoch in range(num_epochs):
        model.train()
        correct_train = 0
        total_train = 0
        
        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
        
        train_accuracy = 100 * correct_train / total_train
        
        model.eval()
        correct_validation_aff = 0
        total_validation_aff = 0
        correct_validation = 0
        total_validation = 0
        validation_loss = 0
        
        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                
                outputs = model(images)
                loss = criterion(outputs, labels)
                
                _, predicted = torch.max(outputs.data, 1)
                total_validation += labels.size(0)
                correct_validation += (predicted == labels).sum().item()
                validation_loss += loss.item()
                # Calculate accuracy for AFF class
                total_validation_aff += torch.sum(labels == 1).item()
                correct_validation_aff += torch.sum((predicted == 1) & (labels == 1)).item()

        # validation_accuracy_aff = 100 * correct_validation_aff / total_validation_aff

        # validation accuracy and loss
        validation_accuracy = 100 * correct_validation / total_validation
        validation_loss /= len(val_loader)
        
        train_losses.append(loss.item())
        validation_losses.append(validation_loss)
        train_accuracies.append(train_accuracy)
        validation_accuracies.append(validation_accuracy)
        
        print(f"Epoch {epoch+1}/{num_epochs}, "
            f"train Loss: {loss.item():.4f}, "
            f"val Loss: {validation_loss:.4f}, "
            f"train ACC: {train_accuracy:.2f}%, "
            f"Val ACC: {validation_accuracy:.2f}%")
        # scheduler.step()
        
    # Plot train/val loss,  accuracy
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Train Loss')
    plt.plot(validation_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(train_accuracies, label='Train Accuracy')
    plt.plot(validation_accuracies, label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.legend() 

    plt.show()
# Out:
# /local/data1/honzh073/anaconda3/envs/myenv/lib/python3.9/site-packages/sklearn/model_selection/_split.py:725: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# Fold 1/5
# Epoch 1/20, train Loss: 0.6859, val Loss: 0.6775, train ACC: 60.36%, Val ACC: 53.29%
# Epoch 2/20, train Loss: 0.6271, val Loss: 0.6360, train ACC: 59.46%, Val ACC: 67.66%
# Epoch 3/20, train Loss: 0.5505, val Loss: 0.5687, train ACC: 69.82%, Val ACC: 66.47%
# Epoch 4/20, train Loss: 0.4818, val Loss: 0.4885, train ACC: 69.82%, Val ACC: 77.25%
# Epoch 5/20, train Loss: 0.5001, val Loss: 0.4862, train ACC: 78.83%, Val ACC: 82.63%
# Epoch 6/20, train Loss: 0.3607, val Loss: 0.3951, train ACC: 79.13%, Val ACC: 80.24%
# Epoch 7/20, train Loss: 0.2981, val Loss: 0.2957, train ACC: 81.98%, Val ACC: 85.03%
# Epoch 8/20, train Loss: 0.3515, val Loss: 0.2518, train ACC: 86.34%, Val ACC: 90.42%
# Epoch 9/20, train Loss: 0.2969, val Loss: 0.3140, train ACC: 92.04%, Val ACC: 91.62%
# Epoch 10/20, train Loss: 0.2237, val Loss: 0.2533, train ACC: 91.14%, Val ACC: 89.82%
# Epoch 11/20, train Loss: 0.1980, val Loss: 0.2794, train ACC: 92.79%, Val ACC: 86.83%
# Epoch 12/20, train Loss: 0.1064, val Loss: 0.2160, train ACC: 92.04%, Val ACC: 91.02%
# Epoch 13/20, train Loss: 0.2528, val Loss: 0.2143, train ACC: 93.84%, Val ACC: 89.22%
# Epoch 14/20, train Loss: 0.1657, val Loss: 0.2594, train ACC: 93.99%, Val ACC: 88.62%
# Epoch 15/20, train Loss: 0.0687, val Loss: 0.1261, train ACC: 94.44%, Val ACC: 95.21%
# Epoch 16/20, train Loss: 0.5458, val Loss: 0.3063, train ACC: 96.25%, Val ACC: 89.22%
# Epoch 17/20, train Loss: 0.3188, val Loss: 0.3044, train ACC: 95.65%, Val ACC: 86.83%
# Epoch 18/20, train Loss: 0.4230, val Loss: 0.2515, train ACC: 96.55%, Val ACC: 89.82%
# Epoch 19/20, train Loss: 0.2082, val Loss: 0.2216, train ACC: 96.25%, Val ACC: 93.41%
# Epoch 20/20, train Loss: 0.1007, val Loss: 0.1682, train ACC: 97.45%, Val ACC: 92.81%
# Fold 2/5
# Epoch 1/20, train Loss: 0.1936, val Loss: 0.1000, train ACC: 96.55%, Val ACC: 96.41%
# Epoch 2/20, train Loss: 0.0908, val Loss: 0.0809, train ACC: 96.40%, Val ACC: 97.60%
# Epoch 3/20, train Loss: 0.0903, val Loss: 0.1008, train ACC: 98.65%, Val ACC: 94.61%
# Epoch 4/20, train Loss: 0.4029, val Loss: 0.1672, train ACC: 97.30%, Val ACC: 95.21%
# Epoch 5/20, train Loss: 0.0431, val Loss: 0.0823, train ACC: 96.40%, Val ACC: 97.60%
# Epoch 6/20, train Loss: 0.0210, val Loss: 0.0300, train ACC: 98.20%, Val ACC: 98.80%
# Epoch 7/20, train Loss: 0.1502, val Loss: 0.1027, train ACC: 98.20%, Val ACC: 96.41%
# Epoch 8/20, train Loss: 0.0287, val Loss: 0.1329, train ACC: 98.95%, Val ACC: 97.01%
# Epoch 9/20, train Loss: 0.0390, val Loss: 0.0577, train ACC: 98.50%, Val ACC: 97.01%
# Epoch 10/20, train Loss: 0.0470, val Loss: 0.0569, train ACC: 99.25%, Val ACC: 97.60%
# Epoch 11/20, train Loss: 0.3180, val Loss: 0.1750, train ACC: 99.25%, Val ACC: 97.60%
# Epoch 12/20, train Loss: 0.2822, val Loss: 0.1421, train ACC: 99.10%, Val ACC: 97.01%
# Epoch 13/20, train Loss: 0.2231, val Loss: 0.1312, train ACC: 98.80%, Val ACC: 94.61%
# Epoch 14/20, train Loss: 0.2669, val Loss: 0.2209, train ACC: 98.20%, Val ACC: 94.01%
# Epoch 15/20, train Loss: 0.0417, val Loss: 0.1622, train ACC: 98.35%, Val ACC: 93.41%
# Epoch 16/20, train Loss: 0.1957, val Loss: 0.1462, train ACC: 97.30%, Val ACC: 95.21%
# Epoch 17/20, train Loss: 0.1527, val Loss: 0.1243, train ACC: 98.95%, Val ACC: 94.61%
# Epoch 18/20, train Loss: 0.1455, val Loss: 0.0761, train ACC: 98.80%, Val ACC: 96.41%
# Epoch 19/20, train Loss: 0.2208, val Loss: 0.1502, train ACC: 98.50%, Val ACC: 96.41%
# Epoch 20/20, train Loss: 0.0603, val Loss: 0.1374, train ACC: 99.10%, Val ACC: 98.20%
# Fold 3/5
# Epoch 1/20, train Loss: 0.2120, val Loss: 0.1029, train ACC: 97.15%, Val ACC: 97.60%
# Epoch 2/20, train Loss: 0.0349, val Loss: 0.0163, train ACC: 98.95%, Val ACC: 100.00%
# Epoch 3/20, train Loss: 0.0105, val Loss: 0.0112, train ACC: 98.80%, Val ACC: 100.00%
# Epoch 4/20, train Loss: 0.0052, val Loss: 0.0439, train ACC: 98.65%, Val ACC: 98.20%
# Epoch 5/20, train Loss: 0.0402, val Loss: 0.0515, train ACC: 97.90%, Val ACC: 98.80%
# Epoch 6/20, train Loss: 0.0066, val Loss: 0.0941, train ACC: 99.40%, Val ACC: 99.40%
# Epoch 7/20, train Loss: 0.0069, val Loss: 0.0250, train ACC: 98.95%, Val ACC: 98.80%
# Epoch 8/20, train Loss: 0.0366, val Loss: 0.0521, train ACC: 98.80%, Val ACC: 98.80%
# Epoch 9/20, train Loss: 0.0090, val Loss: 0.0088, train ACC: 98.95%, Val ACC: 100.00%
# Epoch 10/20, train Loss: 0.0454, val Loss: 0.0478, train ACC: 98.50%, Val ACC: 97.60%
# Epoch 11/20, train Loss: 0.0076, val Loss: 0.0122, train ACC: 98.80%, Val ACC: 100.00%
# Epoch 12/20, train Loss: 0.0089, val Loss: 0.0079, train ACC: 99.40%, Val ACC: 100.00%
# Epoch 13/20, train Loss: 0.0222, val Loss: 0.0152, train ACC: 99.10%, Val ACC: 99.40%
# Epoch 14/20, train Loss: 0.0055, val Loss: 0.0321, train ACC: 99.40%, Val ACC: 98.80%
# Epoch 15/20, train Loss: 0.0207, val Loss: 0.0241, train ACC: 98.05%, Val ACC: 99.40%
# Epoch 16/20, train Loss: 0.0080, val Loss: 0.0681, train ACC: 98.95%, Val ACC: 97.60%
# Epoch 17/20, train Loss: 0.0107, val Loss: 0.0414, train ACC: 99.70%, Val ACC: 98.80%
# Epoch 18/20, train Loss: 0.0759, val Loss: 0.0345, train ACC: 99.10%, Val ACC: 99.40%
# Epoch 19/20, train Loss: 0.0178, val Loss: 0.0225, train ACC: 99.70%, Val ACC: 100.00%
# Epoch 20/20, train Loss: 0.0130, val Loss: 0.0481, train ACC: 99.70%, Val ACC: 98.80%
# Fold 4/5
# Epoch 1/20, train Loss: 0.0562, val Loss: 0.0378, train ACC: 98.50%, Val ACC: 98.19%
# Epoch 2/20, train Loss: 0.0372, val Loss: 0.0236, train ACC: 98.50%, Val ACC: 98.80%
# Epoch 3/20, train Loss: 0.0324, val Loss: 0.0214, train ACC: 99.25%, Val ACC: 99.40%
# Epoch 4/20, train Loss: 0.0127, val Loss: 0.0303, train ACC: 99.55%, Val ACC: 99.40%
# Epoch 5/20, train Loss: 0.0060, val Loss: 0.0861, train ACC: 98.20%, Val ACC: 98.19%
# Epoch 6/20, train Loss: 0.0170, val Loss: 0.1311, train ACC: 99.25%, Val ACC: 97.59%
# Epoch 7/20, train Loss: 0.0221, val Loss: 0.0292, train ACC: 99.10%, Val ACC: 98.19%
# Epoch 8/20, train Loss: 0.0016, val Loss: 0.0090, train ACC: 98.65%, Val ACC: 99.40%
# Epoch 9/20, train Loss: 0.0111, val Loss: 0.0274, train ACC: 99.10%, Val ACC: 99.40%
# Epoch 10/20, train Loss: 0.0036, val Loss: 0.0236, train ACC: 98.50%, Val ACC: 98.80%
# Epoch 11/20, train Loss: 0.1393, val Loss: 0.0568, train ACC: 98.65%, Val ACC: 98.19%
# Epoch 12/20, train Loss: 0.1504, val Loss: 0.0549, train ACC: 98.35%, Val ACC: 99.40%
# Epoch 13/20, train Loss: 0.0011, val Loss: 0.0706, train ACC: 99.10%, Val ACC: 97.59%
# Epoch 14/20, train Loss: 0.0294, val Loss: 0.0274, train ACC: 99.85%, Val ACC: 98.19%
# Epoch 15/20, train Loss: 0.1471, val Loss: 0.0672, train ACC: 99.40%, Val ACC: 96.99%
# Epoch 16/20, train Loss: 0.0155, val Loss: 0.0682, train ACC: 98.65%, Val ACC: 97.59%
# Epoch 17/20, train Loss: 0.0130, val Loss: 0.0203, train ACC: 98.95%, Val ACC: 100.00%
# Epoch 18/20, train Loss: 0.0065, val Loss: 0.0521, train ACC: 99.10%, Val ACC: 98.19%
# Epoch 19/20, train Loss: 0.0019, val Loss: 0.0235, train ACC: 99.55%, Val ACC: 98.80%
# Epoch 20/20, train Loss: 0.0415, val Loss: 0.0893, train ACC: 99.40%, Val ACC: 99.40%
# Fold 5/5
# Epoch 1/20, train Loss: 0.0018, val Loss: 0.0016, train ACC: 99.70%, Val ACC: 100.00%
# Epoch 2/20, train Loss: 0.0006, val Loss: 0.0052, train ACC: 99.40%, Val ACC: 100.00%
# Epoch 3/20, train Loss: 0.0007, val Loss: 0.0086, train ACC: 99.10%, Val ACC: 99.40%
# Epoch 4/20, train Loss: 0.0010, val Loss: 0.0159, train ACC: 99.25%, Val ACC: 99.40%
# Epoch 5/20, train Loss: 0.0077, val Loss: 0.0195, train ACC: 99.25%, Val ACC: 99.40%
# Epoch 6/20, train Loss: 0.0148, val Loss: 0.0107, train ACC: 99.55%, Val ACC: 100.00%
# Epoch 7/20, train Loss: 0.0016, val Loss: 0.0102, train ACC: 99.40%, Val ACC: 98.80%
# Epoch 8/20, train Loss: 0.0383, val Loss: 0.0344, train ACC: 99.10%, Val ACC: 98.80%
# Epoch 9/20, train Loss: 0.0093, val Loss: 0.0301, train ACC: 98.80%, Val ACC: 98.80%
# Epoch 10/20, train Loss: 0.0183, val Loss: 0.0185, train ACC: 98.80%, Val ACC: 98.19%
# Epoch 11/20, train Loss: 0.0235, val Loss: 0.0275, train ACC: 99.25%, Val ACC: 98.19%
# Epoch 12/20, train Loss: 0.0006, val Loss: 0.0144, train ACC: 99.55%, Val ACC: 99.40%
# Epoch 13/20, train Loss: 0.0036, val Loss: 0.0151, train ACC: 98.80%, Val ACC: 99.40%
# Epoch 14/20, train Loss: 0.0255, val Loss: 0.0216, train ACC: 98.50%, Val ACC: 99.40%
# Epoch 15/20, train Loss: 0.0252, val Loss: 0.0438, train ACC: 98.95%, Val ACC: 98.80%
# Epoch 16/20, train Loss: 0.1336, val Loss: 0.0523, train ACC: 98.95%, Val ACC: 99.40%
# Epoch 17/20, train Loss: 0.0187, val Loss: 0.0173, train ACC: 98.95%, Val ACC: 100.00%
# Epoch 18/20, train Loss: 0.1548, val Loss: 0.0654, train ACC: 99.55%, Val ACC: 97.59%
# Epoch 19/20, train Loss: 0.0218, val Loss: 0.0259, train ACC: 99.25%, Val ACC: 98.19%
# Epoch 20/20, train Loss: 0.0498, val Loss: 0.0258, train ACC: 99.40%, Val ACC: 98.80%

# %%
# Resnet 101
test_dataset = CustomDataset('/local/data1/honzh073/local_repository/FL/code/6_model_test/randompick_patient_data.csv', transform=test_transform)

test_model(model=model, test_dataset=test_dataset, batch_size=64)
# Out:
# Test Loss: 0.3208, Test Acc: 92.69%
# AUC: 0.8832586786114222
# Confusion Matrix:
# [[468  26]
#  [ 17  77]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          NFF       0.96      0.95      0.96       494
#          AFF       0.75      0.82      0.78        94
#
#     accuracy                           0.93       588
#    macro avg       0.86      0.88      0.87       588
# weighted avg       0.93      0.93      0.93       588
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
