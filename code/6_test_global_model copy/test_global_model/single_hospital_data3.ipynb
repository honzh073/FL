# %% [markdown]
# # All image csv files

# %%
import os
import csv

def create_csv(image_folder, csv_file_path):
    # CSV header
    fieldnames = ['HospitalID', 'PatientID', 'ImageID', 'ImagePath', 'Label']
    
    # open the CSV file in write mode
    with open(csv_file_path, 'w', newline='') as csvfile:
        # Create a CSV writer object and write the header
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        for filename in sorted(os.listdir(image_folder)):
            # complete image file path
            image_path = os.path.join(image_folder, filename)

            # filename to extract HospitalID, PatientID, image number, and image label
            parts = filename.split('_')
            hospital_id = parts[3]
            patient_id = parts[1]
            image_number = parts[6]
            image_label = parts[4]

            # write data into the CSV file
            writer.writerow({
                'HospitalID': hospital_id,
                'PatientID': patient_id,
                'ImageID': image_number,
                'ImagePath': image_path,
                'Label': image_label
            })

    # created and saved
    print("CSV file has been created and saved to:", csv_file_path)


image_folder = "/local/data1/honzh073/data/8bit_down224"
csv_file_path = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"
create_csv(image_folder, csv_file_path)
# Out:
# CSV file has been created and saved to: /local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv

# %% [markdown]
# # Custom Dataset and test 100 times average

# %%
# Custom dataset class
import os
import csv
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn as nn
from torchvision import models
from torchvision import transforms
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_curve, roc_auc_score
import torch.nn.functional as F

# custom dataset on csv files
class CustomDataset(Dataset):
    def __init__(self, csv_file, transform=None):
        self.data = []
        self.labels = []  # Store labels separately
        self.patient_ids = []  # Store patient IDs separately
        self.hospital_ids = []  # Store hospital IDs separately
        self.transform = transform
        
        # read csv
        with open(csv_file, 'r') as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                image_path = row['ImagePath']
                label = row['Label']
                patient_id = row['PatientID']
                hospital_id = row['HospitalID']

                if label == 'NFF':
                    label = 0
                elif label == 'AFF':
                    label = 1
                else:
                    raise ValueError("Invalid label in CSV file.")
                self.data.append((image_path, label))
                self.labels.append(label)
                self.patient_ids.append(patient_id)
                self.hospital_ids.append(int(hospital_id))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image_path, label = self.data[idx]
        image = Image.open(image_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image, label

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from sklearn.metrics import roc_auc_score, confusion_matrix, classification_report

def test_model(model, test_dataset, batch_size):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)
    model = model.to(device)

    model.eval()

    correct_test_nff = 0
    correct_test_aff = 0
    total_nff = 0
    total_aff = 0
    total_test = 0
    test_loss = 0

    criterion = nn.CrossEntropyLoss()

    with torch.no_grad():
        all_predictions = []
        all_labels = []
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            _, predicted = torch.max(outputs.data, 1)
            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            total_test += labels.size(0)
            total_nff += (labels == 0).sum().item()
            total_aff += (labels == 1).sum().item()
            correct_test_nff += ((predicted == labels) & (labels == 0)).sum().item()
            correct_test_aff += ((predicted == labels) & (labels == 1)).sum().item()
            test_loss += loss.item()

    # Check if total_aff is zero before performing the division
    test_accuracy_nff = 100 * (correct_test_nff / total_nff) if total_nff != 0 else 0
    test_accuracy_aff = 100 * (correct_test_aff / total_aff) if total_aff != 0 else 0
    test_accuracy_total = 100 * (correct_test_nff + correct_test_aff) / total_test
    test_loss /= len(test_loader)

    # Handle the case where there is only one class
    if len(set(all_labels)) > 1:
        auc_score = roc_auc_score(all_labels, all_predictions)
    else:
        auc_score = 0  # Default value if only one class is present

    conf_matrix = confusion_matrix(all_labels, all_predictions)

    # Directly use class labels as strings in target_names
    target_names = ['NFF', 'AFF']

    classification_rep = classification_report(all_labels, all_predictions, target_names=target_names, labels=[0, 1], zero_division=1)

    # Store metrics in a dictionary
    metrics = {
        "Test Loss": test_loss,
        "Total Test Accuracy": test_accuracy_total,
        "Test Accuracy (NFF)": test_accuracy_nff,
        "Test Accuracy (AFF)": test_accuracy_aff,
        "AUC": auc_score,
        "Confusion Matrix": conf_matrix,
        "Classification Report": classification_rep
    }
    return metrics

# %% [markdown]
# # VGG 19

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision.models import vgg19, VGG19_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# models from job, 50% freezed
class CustomNet(nn.Module):
    def __init__(self, num_classes=2, freeze_percentage=0.5):
        super(CustomNet, self).__init__()

        # Load the pre-trained VGG19 model
        vgg19_model = models.vgg19(weights=VGG19_Weights.DEFAULT)

        # Extract features (all layers except the classifier)
        self.features = nn.Sequential(*list(vgg19_model.features.children()))

        # Calculate the index where to split the layers
        total_layers = len(list(self.features.children()))
        split_idx = int(total_layers * freeze_percentage)

        # Split the layers into groups for freezing and non-freezing
        children = list(self.features.children())
        self.frozen_features = nn.Sequential(*children[:split_idx])
        self.unfrozen_features = nn.Sequential(*children[split_idx:])

        # Freeze layers in self.frozen_features
        for param in self.frozen_features.parameters():
            param.requires_grad = False

        # Define the final fully connected layer
        in_features = vgg19_model.classifier[0].in_features
        self.classifier = nn.Linear(in_features, num_classes)  # VGG19's last feature map has 512 channels

    def forward(self, x):
        x = self.frozen_features(x)
        x = self.unfrozen_features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

# create net
model = CustomNet(num_classes=2)  # num_classes 2

# checkpoint
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# vgg19_freeze_Adam_100R_2E
global_path = '/local/data1/honzh073/data/suzuki.ad.liu.se/175e72fa-36fa-4222-8464-7ff4246f97e1/app_server/FL_global_model.pt'

checkpoint = torch.load(global_path, map_location=device)

# print(checkpoint.keys())

# modify checkpoint keys，match model
# load model weights
state_dict = checkpoint['model']
modified_state_dict = {}
for key, value in state_dict.items():
    # modify key names，match model layers
    new_key = key.replace("model.", "")
    modified_state_dict[new_key] = value

# load weights to model
model.load_state_dict(modified_state_dict)
model = model.to(device)
model.eval()


# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(30, 20))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
# Out:
# Performance for Hospital 1:
#
# Test Loss: 1.0204555988311768
# Total Test Accuracy: 82.6086956521739
# Test Accuracy (NFF): 82.6086956521739
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[19  4]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.83      0.90        23
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.83        23
#    macro avg       0.50      0.91      0.45        23
# weighted avg       1.00      0.83      0.90        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 0.04738033190369606
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         0
#          AFF       1.00      1.00      1.00         3
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.6349090337753296
# Total Test Accuracy: 88.57142857142857
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[23  0]
#  [ 4  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      1.00      0.92        23
#          AFF       1.00      0.67      0.80        12
#
#     accuracy                           0.89        35
#    macro avg       0.93      0.83      0.86        35
# weighted avg       0.90      0.89      0.88        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.06680944561958313
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         2
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 4.243210598826408
# Total Test Accuracy: 89.23076923076923
# Test Accuracy (NFF): 90.0
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[54  6]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.90      0.94        60
#          AFF       0.40      0.80      0.53         5
#
#     accuracy                           0.89        65
#    macro avg       0.69      0.85      0.74        65
# weighted avg       0.94      0.89      0.91        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.47852620482444763
# Total Test Accuracy: 82.14285714285714
# Test Accuracy (NFF): 83.33333333333334
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[30  6]
#  [ 4 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.83      0.86        36
#          AFF       0.73      0.80      0.76        20
#
#     accuracy                           0.82        56
#    macro avg       0.80      0.82      0.81        56
# weighted avg       0.83      0.82      0.82        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.1658574491739273
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 83.33333333333334
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[5 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.83      0.91         6
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.83         6
#    macro avg       0.50      0.92      0.45         6
# weighted avg       1.00      0.83      0.91         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.9666126370429993
# Total Test Accuracy: 77.66990291262135
# Test Accuracy (NFF): 82.5
# Test Accuracy (AFF): 60.86956521739131
# Confusion Matrix:
#  [[66 14]
#  [ 9 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.82      0.85        80
#          AFF       0.50      0.61      0.55        23
#
#     accuracy                           0.78       103
#    macro avg       0.69      0.72      0.70       103
# weighted avg       0.80      0.78      0.78       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.32629725337028503
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.89      0.94         9
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.89         9
#    macro avg       0.50      0.94      0.47         9
# weighted avg       1.00      0.89      0.94         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 1.2841044664382935
# Total Test Accuracy: 68.1159420289855
# Test Accuracy (NFF): 67.9245283018868
# Test Accuracy (AFF): 68.75
# Confusion Matrix:
#  [[36 17]
#  [ 5 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.68      0.77        53
#          AFF       0.39      0.69      0.50        16
#
#     accuracy                           0.68        69
#    macro avg       0.64      0.68      0.63        69
# weighted avg       0.77      0.68      0.70        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.2322858871120843
# Total Test Accuracy: 89.6103896103896
# Test Accuracy (NFF): 92.1875
# Test Accuracy (AFF): 76.92307692307693
# Confusion Matrix:
#  [[59  5]
#  [ 3 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.92      0.94        64
#          AFF       0.67      0.77      0.71        13
#
#     accuracy                           0.90        77
#    macro avg       0.81      0.85      0.83        77
# weighted avg       0.90      0.90      0.90        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 1.3902931213378906
# Total Test Accuracy: 74.35897435897436
# Test Accuracy (NFF): 73.45132743362832
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[83 30]
#  [ 0  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.73      0.85       113
#          AFF       0.12      1.00      0.21         4
#
#     accuracy                           0.74       117
#    macro avg       0.56      0.87      0.53       117
# weighted avg       0.97      0.74      0.83       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 1.1373553276062012
# Total Test Accuracy: 71.11111111111111
# Test Accuracy (NFF): 72.09302325581395
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[31 12]
#  [ 1  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.72      0.83        43
#          AFF       0.08      0.50      0.13         2
#
#     accuracy                           0.71        45
#    macro avg       0.52      0.61      0.48        45
# weighted avg       0.93      0.71      0.80        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.4049615263938904
# Total Test Accuracy: 90.47619047619048
# Test Accuracy (NFF): 90.47619047619048
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[19  2]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.90      0.95        21
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.90        21
#    macro avg       0.50      0.95      0.48        21
# weighted avg       1.00      0.90      0.95        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 0.04716528579592705
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.09539181739091873
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         4
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 0.6269021034240723
# Total Test Accuracy: 80.28169014084507
# Test Accuracy (NFF): 75.51020408163265
# Test Accuracy (AFF): 90.9090909090909
# Confusion Matrix:
#  [[37 12]
#  [ 2 20]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.76      0.84        49
#          AFF       0.62      0.91      0.74        22
#
#     accuracy                           0.80        71
#    macro avg       0.79      0.83      0.79        71
# weighted avg       0.85      0.80      0.81        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.41869605891406536
# Total Test Accuracy: 93.65079365079364
# Test Accuracy (NFF): 97.59036144578313
# Test Accuracy (AFF): 86.04651162790698
# Confusion Matrix:
#  [[81  2]
#  [ 6 37]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.98      0.95        83
#          AFF       0.95      0.86      0.90        43
#
#     accuracy                           0.94       126
#    macro avg       0.94      0.92      0.93       126
# weighted avg       0.94      0.94      0.94       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.9400768876075745
# Total Test Accuracy: 75.55555555555556
# Test Accuracy (NFF): 72.5
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[29 11]
#  [ 0  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.72      0.84        40
#          AFF       0.31      1.00      0.48         5
#
#     accuracy                           0.76        45
#    macro avg       0.66      0.86      0.66        45
# weighted avg       0.92      0.76      0.80        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 2.1798276901245117
# Total Test Accuracy: 55.55555555555556
# Test Accuracy (NFF): 50.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[4 4]
#  [0 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.50      0.67         8
#          AFF       0.20      1.00      0.33         1
#
#     accuracy                           0.56         9
#    macro avg       0.60      0.75      0.50         9
# weighted avg       0.91      0.56      0.63         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.9311332106590271
# Total Test Accuracy: 77.3109243697479
# Test Accuracy (NFF): 80.0
# Test Accuracy (AFF): 70.58823529411765
# Confusion Matrix:
#  [[68 17]
#  [10 24]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.80      0.83        85
#          AFF       0.59      0.71      0.64        34
#
#     accuracy                           0.77       119
#    macro avg       0.73      0.75      0.74       119
# weighted avg       0.79      0.77      0.78       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 1.9102995991706848
# Total Test Accuracy: 73.19587628865979
# Test Accuracy (NFF): 86.79245283018868
# Test Accuracy (AFF): 56.81818181818182
# Confusion Matrix:
#  [[46  7]
#  [19 25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.71      0.87      0.78        53
#          AFF       0.78      0.57      0.66        44
#
#     accuracy                           0.73        97
#    macro avg       0.74      0.72      0.72        97
# weighted avg       0.74      0.73      0.72        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.004010329023003578
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.8701420426368713
# Total Test Accuracy: 75.82417582417582
# Test Accuracy (NFF): 75.32467532467533
# Test Accuracy (AFF): 78.57142857142857
# Confusion Matrix:
#  [[58 19]
#  [ 3 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.75      0.84        77
#          AFF       0.37      0.79      0.50        14
#
#     accuracy                           0.76        91
#    macro avg       0.66      0.77      0.67        91
# weighted avg       0.86      0.76      0.79        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 1.8618261814117432
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[10  5]
#  [ 1  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.67      0.77        15
#          AFF       0.29      0.67      0.40         3
#
#     accuracy                           0.67        18
#    macro avg       0.60      0.67      0.58        18
# weighted avg       0.81      0.67      0.71        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 1.0051937103271484
# Total Test Accuracy: 76.92307692307692
# Test Accuracy (NFF): 77.77777777777779
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[14  4]
#  [ 2  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.78      0.82        18
#          AFF       0.60      0.75      0.67         8
#
#     accuracy                           0.77        26
#    macro avg       0.74      0.76      0.75        26
# weighted avg       0.79      0.77      0.78        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 1.1002250909805298
# Total Test Accuracy: 72.22222222222223
# Test Accuracy (NFF): 70.58823529411765
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[12  5]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.71      0.83        17
#          AFF       0.17      1.00      0.29         1
#
#     accuracy                           0.72        18
#    macro avg       0.58      0.85      0.56        18
# weighted avg       0.95      0.72      0.80        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.9505743980407715
# Total Test Accuracy: 78.49462365591398
# Test Accuracy (NFF): 75.9493670886076
# Test Accuracy (AFF): 92.85714285714286
# Confusion Matrix:
#  [[60 19]
#  [ 1 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.76      0.86        79
#          AFF       0.41      0.93      0.57        14
#
#     accuracy                           0.78        93
#    macro avg       0.69      0.84      0.71        93
# weighted avg       0.90      0.78      0.81        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 1.1502612829208374
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 77.77777777777779
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[7 2]
#  [2 5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.78      0.78      0.78         9
#          AFF       0.71      0.71      0.71         7
#
#     accuracy                           0.75        16
#    macro avg       0.75      0.75      0.75        16
# weighted avg       0.75      0.75      0.75        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 1.5913519859313965
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 83.33333333333334
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[5 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.83      0.91         6
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.83         6
#    macro avg       0.50      0.92      0.45         6
# weighted avg       1.00      0.83      0.91         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 0.8555631935596466
# Total Test Accuracy: 82.14285714285714
# Test Accuracy (NFF): 80.59701492537313
# Test Accuracy (AFF): 88.23529411764706
# Confusion Matrix:
#  [[54 13]
#  [ 2 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.81      0.88        67
#          AFF       0.54      0.88      0.67        17
#
#     accuracy                           0.82        84
#    macro avg       0.75      0.84      0.77        84
# weighted avg       0.88      0.82      0.84        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.004014318808913231
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 1.0822162628173828
# Total Test Accuracy: 77.70270270270271
# Test Accuracy (NFF): 76.19047619047619
# Test Accuracy (AFF): 86.36363636363636
# Confusion Matrix:
#  [[96 30]
#  [ 3 19]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.76      0.85       126
#          AFF       0.39      0.86      0.54        22
#
#     accuracy                           0.78       148
#    macro avg       0.68      0.81      0.69       148
# weighted avg       0.88      0.78      0.81       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.0960504561662674
# Total Test Accuracy: 94.11764705882354
# Test Accuracy (NFF): 94.11764705882352
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[32  2]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.94      0.97        34
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.94        34
#    macro avg       0.50      0.97      0.48        34
# weighted avg       1.00      0.94      0.97        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.16849711537361145
# Total Test Accuracy: 88.23529411764706
# Test Accuracy (NFF): 85.71428571428571
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[12  2]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.86      0.92        14
#          AFF       0.60      1.00      0.75         3
#
#     accuracy                           0.88        17
#    macro avg       0.80      0.93      0.84        17
# weighted avg       0.93      0.88      0.89        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 1.1804644763469696
# Total Test Accuracy: 73.25581395348837
# Test Accuracy (NFF): 76.47058823529412
# Test Accuracy (AFF): 61.111111111111114
# Confusion Matrix:
#  [[52 16]
#  [ 7 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.76      0.82        68
#          AFF       0.41      0.61      0.49        18
#
#     accuracy                           0.73        86
#    macro avg       0.64      0.69      0.65        86
# weighted avg       0.78      0.73      0.75        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 1.3836647272109985
# Total Test Accuracy: 68.0
# Test Accuracy (NFF): 68.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[17  8]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.68      0.81        25
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.68        25
#    macro avg       0.50      0.84      0.40        25
# weighted avg       1.00      0.68      0.81        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.7099490761756897
# Total Test Accuracy: 82.75862068965517
# Test Accuracy (NFF): 82.6086956521739
# Test Accuracy (AFF): 83.33333333333334
# Confusion Matrix:
#  [[19  4]
#  [ 1  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.83      0.88        23
#          AFF       0.56      0.83      0.67         6
#
#     accuracy                           0.83        29
#    macro avg       0.75      0.83      0.78        29
# weighted avg       0.87      0.83      0.84        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.6974316257983446
# Total Test Accuracy: 74.66666666666667
# Test Accuracy (NFF): 80.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[56 14]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.80      0.85        70
#          AFF       0.00      0.00      1.00         5
#
#     accuracy                           0.75        75
#    macro avg       0.46      0.40      0.93        75
# weighted avg       0.86      0.75      0.86        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 1.470244910706242e-06
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 0.5990174412727356
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 80.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[12  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.80      0.89        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.80        15
#    macro avg       0.50      0.90      0.44        15
# weighted avg       1.00      0.80      0.89        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.34200911200605333
# Total Test Accuracy: 93.87755102040816
# Test Accuracy (NFF): 93.52941176470588
# Test Accuracy (AFF): 94.66666666666667
# Confusion Matrix:
#  [[159  11]
#  [  4  71]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.94      0.95       170
#          AFF       0.87      0.95      0.90        75
#
#     accuracy                           0.94       245
#    macro avg       0.92      0.94      0.93       245
# weighted avg       0.94      0.94      0.94       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.7983888387680054
# Total Test Accuracy: 80.64516129032258
# Test Accuracy (NFF): 80.76923076923077
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[21  5]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.81      0.88        26
#          AFF       0.44      0.80      0.57         5
#
#     accuracy                           0.81        31
#    macro avg       0.70      0.80      0.72        31
# weighted avg       0.87      0.81      0.83        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 1.2864096760749817
# Total Test Accuracy: 77.68595041322314
# Test Accuracy (NFF): 76.13636363636364
# Test Accuracy (AFF): 81.81818181818183
# Confusion Matrix:
#  [[67 21]
#  [ 6 27]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.76      0.83        88
#          AFF       0.56      0.82      0.67        33
#
#     accuracy                           0.78       121
#    macro avg       0.74      0.79      0.75       121
# weighted avg       0.82      0.78      0.79       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.6565554141998291
# Total Test Accuracy: 77.27272727272727
# Test Accuracy (NFF): 77.27272727272727
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[17  5]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.77      0.87        22
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.77        22
#    macro avg       0.50      0.89      0.44        22
# weighted avg       1.00      0.77      0.87        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.5895604342222214
# Total Test Accuracy: 86.73469387755102
# Test Accuracy (NFF): 89.74358974358975
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[70  8]
#  [ 5 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.90      0.92        78
#          AFF       0.65      0.75      0.70        20
#
#     accuracy                           0.87        98
#    macro avg       0.79      0.82      0.81        98
# weighted avg       0.88      0.87      0.87        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 1.0750980973243713
# Total Test Accuracy: 87.32394366197182
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[56  8]
#  [ 1  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.88      0.93        64
#          AFF       0.43      0.86      0.57         7
#
#     accuracy                           0.87        71
#    macro avg       0.71      0.87      0.75        71
# weighted avg       0.93      0.87      0.89        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 1.070226788520813
# Total Test Accuracy: 78.94736842105263
# Test Accuracy (NFF): 78.94736842105263
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[45 12]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.79      0.88        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.79        57
#    macro avg       0.50      0.89      0.44        57
# weighted avg       1.00      0.79      0.88        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 1.3005945086479187
# Total Test Accuracy: 79.6116504854369
# Test Accuracy (NFF): 90.78947368421053
# Test Accuracy (AFF): 48.148148148148145
# Confusion Matrix:
#  [[69  7]
#  [14 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.83      0.91      0.87        76
#          AFF       0.65      0.48      0.55        27
#
#     accuracy                           0.80       103
#    macro avg       0.74      0.69      0.71       103
# weighted avg       0.78      0.80      0.79       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 1.1457136273384094
# Total Test Accuracy: 91.13924050632912
# Test Accuracy (NFF): 91.66666666666666
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[66  6]
#  [ 1  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.92      0.95        72
#          AFF       0.50      0.86      0.63         7
#
#     accuracy                           0.91        79
#    macro avg       0.74      0.89      0.79        79
# weighted avg       0.94      0.91      0.92        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.559679388999939
# Total Test Accuracy: 88.46153846153847
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[21  3]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.93        24
#          AFF       0.40      1.00      0.57         2
#
#     accuracy                           0.88        26
#    macro avg       0.70      0.94      0.75        26
# weighted avg       0.95      0.88      0.91        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 0.6542744636535645
# Total Test Accuracy: 91.66666666666667
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 88.88888888888889
# Confusion Matrix:
#  [[3 0]
#  [1 8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.75      1.00      0.86         3
#          AFF       1.00      0.89      0.94         9
#
#     accuracy                           0.92        12
#    macro avg       0.88      0.94      0.90        12
# weighted avg       0.94      0.92      0.92        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.6337840954462687
# Total Test Accuracy: 82.83582089552239
# Test Accuracy (NFF): 84.90566037735849
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[90 16]
#  [ 7 21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.85      0.89       106
#          AFF       0.57      0.75      0.65        28
#
#     accuracy                           0.83       134
#    macro avg       0.75      0.80      0.77       134
# weighted avg       0.85      0.83      0.84       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.4680281604329745
# Total Test Accuracy: 93.88888888888889
# Test Accuracy (NFF): 96.71052631578947
# Test Accuracy (AFF): 78.57142857142857
# Confusion Matrix:
#  [[147   5]
#  [  6  22]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.97      0.96       152
#          AFF       0.81      0.79      0.80        28
#
#     accuracy                           0.94       180
#    macro avg       0.89      0.88      0.88       180
# weighted avg       0.94      0.94      0.94       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 1.3502219915390015
# Total Test Accuracy: 72.5
# Test Accuracy (NFF): 81.48148148148148
# Test Accuracy (AFF): 53.84615384615385
# Confusion Matrix:
#  [[22  5]
#  [ 6  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.79      0.81      0.80        27
#          AFF       0.58      0.54      0.56        13
#
#     accuracy                           0.73        40
#    macro avg       0.68      0.68      0.68        40
# weighted avg       0.72      0.72      0.72        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 3.9864912033081055
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         3
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# Performance for Hospital 58:
#
# Test Loss: 0.8746270537376404
# Total Test Accuracy: 85.96491228070175
# Test Accuracy (NFF): 82.75862068965517
# Test Accuracy (AFF): 89.28571428571429
# Confusion Matrix:
#  [[24  5]
#  [ 3 25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.83      0.86        29
#          AFF       0.83      0.89      0.86        28
#
#     accuracy                           0.86        57
#    macro avg       0.86      0.86      0.86        57
# weighted avg       0.86      0.86      0.86        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.32741475105285645
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.89      0.94         9
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.89         9
#    macro avg       0.50      0.94      0.47         9
# weighted avg       1.00      0.89      0.94         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 1.6225346326828003
# Total Test Accuracy: 73.98373983739837
# Test Accuracy (NFF): 75.0
# Test Accuracy (AFF): 69.56521739130434
# Confusion Matrix:
#  [[75 25]
#  [ 7 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.75      0.82       100
#          AFF       0.39      0.70      0.50        23
#
#     accuracy                           0.74       123
#    macro avg       0.65      0.72      0.66       123
# weighted avg       0.82      0.74      0.76       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.7668001651763916
# Total Test Accuracy: 80.95238095238095
# Test Accuracy (NFF): 89.13043478260869
# Test Accuracy (AFF): 58.82352941176471
# Confusion Matrix:
#  [[41  5]
#  [ 7 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.89      0.87        46
#          AFF       0.67      0.59      0.62        17
#
#     accuracy                           0.81        63
#    macro avg       0.76      0.74      0.75        63
# weighted avg       0.80      0.81      0.81        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 1.1272685527801514
# Total Test Accuracy: 84.90566037735849
# Test Accuracy (NFF): 90.2439024390244
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[37  4]
#  [ 4  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.90      0.90        41
#          AFF       0.67      0.67      0.67        12
#
#     accuracy                           0.85        53
#    macro avg       0.78      0.78      0.78        53
# weighted avg       0.85      0.85      0.85        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 1.2125564813613892
# Total Test Accuracy: 87.5
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[7 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.93         8
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.88         8
#    macro avg       0.50      0.94      0.47         8
# weighted avg       1.00      0.88      0.93         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.17730440199375153
# Total Test Accuracy: 90.625
# Test Accuracy (NFF): 90.625
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[29  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.91      0.95        32
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.91        32
#    macro avg       0.50      0.95      0.48        32
# weighted avg       1.00      0.91      0.95        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 1.6262222528457642
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[7 1]
#  [1 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.88      0.88         8
#          AFF       0.50      0.50      0.50         2
#
#     accuracy                           0.80        10
#    macro avg       0.69      0.69      0.69        10
# weighted avg       0.80      0.80      0.80        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.47845345735549927
# Total Test Accuracy: 81.81818181818181
# Test Accuracy (NFF): 82.35294117647058
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[14  3]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.82      0.87        17
#          AFF       0.57      0.80      0.67         5
#
#     accuracy                           0.82        22
#    macro avg       0.75      0.81      0.77        22
# weighted avg       0.85      0.82      0.83        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 1.3444007635116577
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 75.86206896551724
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[22  7]
#  [ 2  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.76      0.83        29
#          AFF       0.42      0.71      0.53         7
#
#     accuracy                           0.75        36
#    macro avg       0.67      0.74      0.68        36
# weighted avg       0.82      0.75      0.77        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 1.0158302795428495
# Total Test Accuracy: 80.29556650246306
# Test Accuracy (NFF): 81.88736681887366
# Test Accuracy (AFF): 73.54838709677419
# Confusion Matrix:
#  [[538 119]
#  [ 41 114]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.82      0.87       657
#          AFF       0.49      0.74      0.59       155
#
#     accuracy                           0.80       812
#    macro avg       0.71      0.78      0.73       812
# weighted avg       0.85      0.80      0.82       812
#
#
# Average Total Test Accuracy: 82.83887729883267

# %% [markdown]
# # ResNet 50

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision.models import resnet101, ResNet101_Weights
from torchvision.models import resnet50, ResNet50_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

class CustomNet(nn.Module):
    def __init__(self, num_classes=2, freeze_percentage=0.5):
        super(CustomNet, self).__init__()

        self.features = models.resnet50(weights=ResNet50_Weights.DEFAULT)

        # Calculate the index where to split the layerszh
        total_layers = len(list(self.features.children()))
        split_idx = int(total_layers * freeze_percentage)

        # Split the layers into groups for freezing and non-freezing
        children = list(self.features.children())
        self.frozen_features = nn.Sequential(*children[:split_idx])
        self.unfrozen_features = nn.Sequential(*children[split_idx:-1])  # Exclude the last layer

        # Freeze layers in self.frozen_features
        for param in self.frozen_features.parameters():
            param.requires_grad = False

        # Define the final fully connected layer
        self.fc = nn.Linear(2048, num_classes)

    def forward(self, x):
        x = self.frozen_features(x)
        x = self.unfrozen_features(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x
    
# create net
model = CustomNet(num_classes=2)  # num_classes 2

# checkpoint
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

global_path = '/local/data1/honzh073/data/suzuki.ad.liu.se/dc5e6404-9d5c-42c3-abba-33fbc7acd6b6/app_server/FL_global_model.pt'

checkpoint = torch.load(global_path, map_location=device)

# print(checkpoint.keys())

# modify checkpoint keys，match model
# load model weights
state_dict = checkpoint['model']
modified_state_dict = {}
for key, value in state_dict.items():
    # modify key names，match model layers
    new_key = key.replace("model.", "")
    modified_state_dict[new_key] = value

# load weights to model
model.load_state_dict(modified_state_dict)
model = model.to(device)
model.eval()

# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(30, 20))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.008294160477817059
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        23
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        23
#    macro avg       1.00      1.00      1.00        23
# weighted avg       1.00      1.00      1.00        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 0.004530212376266718
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         0
#          AFF       1.00      1.00      1.00         3
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.38762417435646057
# Total Test Accuracy: 88.57142857142857
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[22  1]
#  [ 3  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.96      0.92        23
#          AFF       0.90      0.75      0.82        12
#
#     accuracy                           0.89        35
#    macro avg       0.89      0.85      0.87        35
# weighted avg       0.89      0.89      0.88        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.00456826901063323
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         2
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.27155379951000214
# Total Test Accuracy: 93.84615384615384
# Test Accuracy (NFF): 98.33333333333333
# Test Accuracy (AFF): 40.0
# Confusion Matrix:
#  [[59  1]
#  [ 3  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.98      0.97        60
#          AFF       0.67      0.40      0.50         5
#
#     accuracy                           0.94        65
#    macro avg       0.81      0.69      0.73        65
# weighted avg       0.93      0.94      0.93        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.6645120978355408
# Total Test Accuracy: 87.5
# Test Accuracy (NFF): 97.22222222222221
# Test Accuracy (AFF): 70.0
# Confusion Matrix:
#  [[35  1]
#  [ 6 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.97      0.91        36
#          AFF       0.93      0.70      0.80        20
#
#     accuracy                           0.88        56
#    macro avg       0.89      0.84      0.85        56
# weighted avg       0.88      0.88      0.87        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.0017102753045037389
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.37314826250076294
# Total Test Accuracy: 89.32038834951456
# Test Accuracy (NFF): 97.5
# Test Accuracy (AFF): 60.86956521739131
# Confusion Matrix:
#  [[78  2]
#  [ 9 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.97      0.93        80
#          AFF       0.88      0.61      0.72        23
#
#     accuracy                           0.89       103
#    macro avg       0.89      0.79      0.83       103
# weighted avg       0.89      0.89      0.89       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.0023479864466935396
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 1.1384695172309875
# Total Test Accuracy: 75.3623188405797
# Test Accuracy (NFF): 94.33962264150944
# Test Accuracy (AFF): 12.5
# Confusion Matrix:
#  [[50  3]
#  [14  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.78      0.94      0.85        53
#          AFF       0.40      0.12      0.19        16
#
#     accuracy                           0.75        69
#    macro avg       0.59      0.53      0.52        69
# weighted avg       0.69      0.75      0.70        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.3031228716718033
# Total Test Accuracy: 87.01298701298701
# Test Accuracy (NFF): 93.75
# Test Accuracy (AFF): 53.84615384615385
# Confusion Matrix:
#  [[60  4]
#  [ 6  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.94      0.92        64
#          AFF       0.64      0.54      0.58        13
#
#     accuracy                           0.87        77
#    macro avg       0.77      0.74      0.75        77
# weighted avg       0.86      0.87      0.87        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.17520378716289997
# Total Test Accuracy: 94.01709401709402
# Test Accuracy (NFF): 93.80530973451327
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[106   7]
#  [  0   4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.94      0.97       113
#          AFF       0.36      1.00      0.53         4
#
#     accuracy                           0.94       117
#    macro avg       0.68      0.97      0.75       117
# weighted avg       0.98      0.94      0.95       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.2776164412498474
# Total Test Accuracy: 93.33333333333333
# Test Accuracy (NFF): 95.34883720930233
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[41  2]
#  [ 1  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.95      0.96        43
#          AFF       0.33      0.50      0.40         2
#
#     accuracy                           0.93        45
#    macro avg       0.65      0.73      0.68        45
# weighted avg       0.95      0.93      0.94        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.004519051872193813
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        21
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 0.06701263040304184
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.00010894537263084203
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         4
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 1.1221457421779633
# Total Test Accuracy: 81.69014084507042
# Test Accuracy (NFF): 97.95918367346938
# Test Accuracy (AFF): 45.45454545454545
# Confusion Matrix:
#  [[48  1]
#  [12 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.80      0.98      0.88        49
#          AFF       0.91      0.45      0.61        22
#
#     accuracy                           0.82        71
#    macro avg       0.85      0.72      0.74        71
# weighted avg       0.83      0.82      0.80        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.16221004258841276
# Total Test Accuracy: 92.06349206349206
# Test Accuracy (NFF): 98.79518072289156
# Test Accuracy (AFF): 79.06976744186046
# Confusion Matrix:
#  [[82  1]
#  [ 9 34]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.99      0.94        83
#          AFF       0.97      0.79      0.87        43
#
#     accuracy                           0.92       126
#    macro avg       0.94      0.89      0.91       126
# weighted avg       0.93      0.92      0.92       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.4534878730773926
# Total Test Accuracy: 91.11111111111111
# Test Accuracy (NFF): 95.0
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[38  2]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.95      0.95        40
#          AFF       0.60      0.60      0.60         5
#
#     accuracy                           0.91        45
#    macro avg       0.77      0.77      0.78        45
# weighted avg       0.91      0.91      0.91        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.6699180006980896
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[8 0]
#  [1 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      1.00      0.94         8
#          AFF       1.00      0.00      0.00         1
#
#     accuracy                           0.89         9
#    macro avg       0.94      0.50      0.47         9
# weighted avg       0.90      0.89      0.84         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.49813300371170044
# Total Test Accuracy: 82.3529411764706
# Test Accuracy (NFF): 92.94117647058823
# Test Accuracy (AFF): 55.88235294117647
# Confusion Matrix:
#  [[79  6]
#  [15 19]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      0.93      0.88        85
#          AFF       0.76      0.56      0.64        34
#
#     accuracy                           0.82       119
#    macro avg       0.80      0.74      0.76       119
# weighted avg       0.82      0.82      0.81       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 1.4762389063835144
# Total Test Accuracy: 72.16494845360825
# Test Accuracy (NFF): 90.56603773584906
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[48  5]
#  [22 22]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.69      0.91      0.78        53
#          AFF       0.81      0.50      0.62        44
#
#     accuracy                           0.72        97
#    macro avg       0.75      0.70      0.70        97
# weighted avg       0.74      0.72      0.71        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.00045064487494528294
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.25723662227392197
# Total Test Accuracy: 94.50549450549451
# Test Accuracy (NFF): 98.7012987012987
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[76  1]
#  [ 4 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.99      0.97        77
#          AFF       0.91      0.71      0.80        14
#
#     accuracy                           0.95        91
#    macro avg       0.93      0.85      0.88        91
# weighted avg       0.94      0.95      0.94        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 0.20054557919502258
# Total Test Accuracy: 94.44444444444444
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[15  0]
#  [ 1  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      1.00      0.97        15
#          AFF       1.00      0.67      0.80         3
#
#     accuracy                           0.94        18
#    macro avg       0.97      0.83      0.88        18
# weighted avg       0.95      0.94      0.94        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.49604398012161255
# Total Test Accuracy: 84.61538461538461
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[16  2]
#  [ 2  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.89      0.89        18
#          AFF       0.75      0.75      0.75         8
#
#     accuracy                           0.85        26
#    macro avg       0.82      0.82      0.82        26
# weighted avg       0.85      0.85      0.85        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.13833974301815033
# Total Test Accuracy: 94.44444444444444
# Test Accuracy (NFF): 94.11764705882352
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[16  1]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.94      0.97        17
#          AFF       0.50      1.00      0.67         1
#
#     accuracy                           0.94        18
#    macro avg       0.75      0.97      0.82        18
# weighted avg       0.97      0.94      0.95        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.6716228425502777
# Total Test Accuracy: 89.24731182795699
# Test Accuracy (NFF): 97.46835443037975
# Test Accuracy (AFF): 42.857142857142854
# Confusion Matrix:
#  [[77  2]
#  [ 8  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.97      0.94        79
#          AFF       0.75      0.43      0.55        14
#
#     accuracy                           0.89        93
#    macro avg       0.83      0.70      0.74        93
# weighted avg       0.88      0.89      0.88        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 0.5469933748245239
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 42.857142857142854
# Confusion Matrix:
#  [[9 0]
#  [4 3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.69      1.00      0.82         9
#          AFF       1.00      0.43      0.60         7
#
#     accuracy                           0.75        16
#    macro avg       0.85      0.71      0.71        16
# weighted avg       0.83      0.75      0.72        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 0.004612576216459274
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 0.1858638972043991
# Total Test Accuracy: 94.04761904761905
# Test Accuracy (NFF): 98.50746268656717
# Test Accuracy (AFF): 76.47058823529412
# Confusion Matrix:
#  [[66  1]
#  [ 4 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.99      0.96        67
#          AFF       0.93      0.76      0.84        17
#
#     accuracy                           0.94        84
#    macro avg       0.94      0.87      0.90        84
# weighted avg       0.94      0.94      0.94        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.0006612038123421371
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.47120197614034015
# Total Test Accuracy: 85.8108108108108
# Test Accuracy (NFF): 91.26984126984127
# Test Accuracy (AFF): 54.54545454545454
# Confusion Matrix:
#  [[115  11]
#  [ 10  12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.91      0.92       126
#          AFF       0.52      0.55      0.53        22
#
#     accuracy                           0.86       148
#    macro avg       0.72      0.73      0.72       148
# weighted avg       0.86      0.86      0.86       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.011293912306427956
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[34]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        34
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        34
#    macro avg       1.00      1.00      1.00        34
# weighted avg       1.00      1.00      1.00        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.38349705934524536
# Total Test Accuracy: 82.3529411764706
# Test Accuracy (NFF): 85.71428571428571
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[12  2]
#  [ 1  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.86      0.89        14
#          AFF       0.50      0.67      0.57         3
#
#     accuracy                           0.82        17
#    macro avg       0.71      0.76      0.73        17
# weighted avg       0.85      0.82      0.83        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.39467646181583405
# Total Test Accuracy: 84.88372093023256
# Test Accuracy (NFF): 92.64705882352942
# Test Accuracy (AFF): 55.55555555555556
# Confusion Matrix:
#  [[63  5]
#  [ 8 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.93      0.91        68
#          AFF       0.67      0.56      0.61        18
#
#     accuracy                           0.85        86
#    macro avg       0.78      0.74      0.76        86
# weighted avg       0.84      0.85      0.84        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.08049989491701126
# Total Test Accuracy: 96.0
# Test Accuracy (NFF): 96.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[24  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        25
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.96        25
#    macro avg       0.50      0.98      0.49        25
# weighted avg       1.00      0.96      0.98        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.4592953324317932
# Total Test Accuracy: 96.55172413793103
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 83.33333333333334
# Confusion Matrix:
#  [[23  0]
#  [ 1  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      1.00      0.98        23
#          AFF       1.00      0.83      0.91         6
#
#     accuracy                           0.97        29
#    macro avg       0.98      0.92      0.94        29
# weighted avg       0.97      0.97      0.96        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.3807360401842743
# Total Test Accuracy: 89.33333333333333
# Test Accuracy (NFF): 95.71428571428572
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[67  3]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.96      0.94        70
#          AFF       0.00      0.00      1.00         5
#
#     accuracy                           0.89        75
#    macro avg       0.47      0.48      0.97        75
# weighted avg       0.87      0.89      0.95        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 1.6053307263064198e-05
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 0.22684970498085022
# Total Test Accuracy: 86.66666666666667
# Test Accuracy (NFF): 86.66666666666667
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[13  2]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.87      0.93        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.87        15
#    macro avg       0.50      0.93      0.46        15
# weighted avg       1.00      0.87      0.93        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.15711683314293623
# Total Test Accuracy: 95.51020408163265
# Test Accuracy (NFF): 96.47058823529412
# Test Accuracy (AFF): 93.33333333333333
# Confusion Matrix:
#  [[164   6]
#  [  5  70]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.96      0.97       170
#          AFF       0.92      0.93      0.93        75
#
#     accuracy                           0.96       245
#    macro avg       0.95      0.95      0.95       245
# weighted avg       0.96      0.96      0.96       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.7617432475090027
# Total Test Accuracy: 80.64516129032258
# Test Accuracy (NFF): 84.61538461538461
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[22  4]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.85      0.88        26
#          AFF       0.43      0.60      0.50         5
#
#     accuracy                           0.81        31
#    macro avg       0.67      0.72      0.69        31
# weighted avg       0.84      0.81      0.82        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.2759009227156639
# Total Test Accuracy: 90.9090909090909
# Test Accuracy (NFF): 95.45454545454545
# Test Accuracy (AFF): 78.78787878787878
# Confusion Matrix:
#  [[84  4]
#  [ 7 26]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.95      0.94        88
#          AFF       0.87      0.79      0.83        33
#
#     accuracy                           0.91       121
#    macro avg       0.89      0.87      0.88       121
# weighted avg       0.91      0.91      0.91       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.13141359388828278
# Total Test Accuracy: 95.45454545454545
# Test Accuracy (NFF): 95.45454545454545
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.95      0.98        22
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.95        22
#    macro avg       0.50      0.98      0.49        22
# weighted avg       1.00      0.95      0.98        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.3284010048955679
# Total Test Accuracy: 91.83673469387755
# Test Accuracy (NFF): 98.71794871794873
# Test Accuracy (AFF): 65.0
# Confusion Matrix:
#  [[77  1]
#  [ 7 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.99      0.95        78
#          AFF       0.93      0.65      0.76        20
#
#     accuracy                           0.92        98
#    macro avg       0.92      0.82      0.86        98
# weighted avg       0.92      0.92      0.91        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.28009553253650665
# Total Test Accuracy: 91.54929577464789
# Test Accuracy (NFF): 95.3125
# Test Accuracy (AFF): 57.14285714285714
# Confusion Matrix:
#  [[61  3]
#  [ 3  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.95      0.95        64
#          AFF       0.57      0.57      0.57         7
#
#     accuracy                           0.92        71
#    macro avg       0.76      0.76      0.76        71
# weighted avg       0.92      0.92      0.92        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.2781457304954529
# Total Test Accuracy: 87.71929824561404
# Test Accuracy (NFF): 87.71929824561403
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[50  7]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.93        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.88        57
#    macro avg       0.50      0.94      0.47        57
# weighted avg       1.00      0.88      0.93        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.8607120215892792
# Total Test Accuracy: 80.58252427184466
# Test Accuracy (NFF): 94.73684210526315
# Test Accuracy (AFF): 40.74074074074074
# Confusion Matrix:
#  [[72  4]
#  [16 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.82      0.95      0.88        76
#          AFF       0.73      0.41      0.52        27
#
#     accuracy                           0.81       103
#    macro avg       0.78      0.68      0.70       103
# weighted avg       0.80      0.81      0.79       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.5191913545131683
# Total Test Accuracy: 91.13924050632912
# Test Accuracy (NFF): 94.44444444444444
# Test Accuracy (AFF): 57.14285714285714
# Confusion Matrix:
#  [[68  4]
#  [ 3  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.94      0.95        72
#          AFF       0.50      0.57      0.53         7
#
#     accuracy                           0.91        79
#    macro avg       0.73      0.76      0.74        79
# weighted avg       0.92      0.91      0.91        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.042483314871788025
# Total Test Accuracy: 96.15384615384616
# Test Accuracy (NFF): 95.83333333333334
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[23  1]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        24
#          AFF       0.67      1.00      0.80         2
#
#     accuracy                           0.96        26
#    macro avg       0.83      0.98      0.89        26
# weighted avg       0.97      0.96      0.96        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 2.7343227863311768
# Total Test Accuracy: 58.333333333333336
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 44.44444444444444
# Confusion Matrix:
#  [[3 0]
#  [5 4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.38      1.00      0.55         3
#          AFF       1.00      0.44      0.62         9
#
#     accuracy                           0.58        12
#    macro avg       0.69      0.72      0.58        12
# weighted avg       0.84      0.58      0.60        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.339619657335182
# Total Test Accuracy: 88.80597014925372
# Test Accuracy (NFF): 96.22641509433963
# Test Accuracy (AFF): 60.71428571428571
# Confusion Matrix:
#  [[102   4]
#  [ 11  17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.96      0.93       106
#          AFF       0.81      0.61      0.69        28
#
#     accuracy                           0.89       134
#    macro avg       0.86      0.78      0.81       134
# weighted avg       0.88      0.89      0.88       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.2627491516371568
# Total Test Accuracy: 94.44444444444444
# Test Accuracy (NFF): 98.68421052631578
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[150   2]
#  [  8  20]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.99      0.97       152
#          AFF       0.91      0.71      0.80        28
#
#     accuracy                           0.94       180
#    macro avg       0.93      0.85      0.88       180
# weighted avg       0.94      0.94      0.94       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.819912314414978
# Total Test Accuracy: 77.5
# Test Accuracy (NFF): 96.29629629629629
# Test Accuracy (AFF): 38.46153846153847
# Confusion Matrix:
#  [[26  1]
#  [ 8  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.76      0.96      0.85        27
#          AFF       0.83      0.38      0.53        13
#
#     accuracy                           0.78        40
#    macro avg       0.80      0.67      0.69        40
# weighted avg       0.79      0.78      0.75        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 0.0006329988245852292
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 58:
#
# Test Loss: 0.6898183226585388
# Total Test Accuracy: 80.70175438596492
# Test Accuracy (NFF): 89.65517241379311
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[26  3]
#  [ 8 20]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.76      0.90      0.83        29
#          AFF       0.87      0.71      0.78        28
#
#     accuracy                           0.81        57
#    macro avg       0.82      0.81      0.80        57
# weighted avg       0.82      0.81      0.81        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.0360981747508049
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.8513983190059662
# Total Test Accuracy: 78.86178861788618
# Test Accuracy (NFF): 86.0
# Test Accuracy (AFF): 47.82608695652174
# Confusion Matrix:
#  [[86 14]
#  [12 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.86      0.87       100
#          AFF       0.44      0.48      0.46        23
#
#     accuracy                           0.79       123
#    macro avg       0.66      0.67      0.66       123
# weighted avg       0.80      0.79      0.79       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.5971896648406982
# Total Test Accuracy: 84.12698412698413
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 52.94117647058824
# Confusion Matrix:
#  [[44  2]
#  [ 8  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.96      0.90        46
#          AFF       0.82      0.53      0.64        17
#
#     accuracy                           0.84        63
#    macro avg       0.83      0.74      0.77        63
# weighted avg       0.84      0.84      0.83        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 0.6705541014671326
# Total Test Accuracy: 84.90566037735849
# Test Accuracy (NFF): 97.5609756097561
# Test Accuracy (AFF): 41.66666666666667
# Confusion Matrix:
#  [[40  1]
#  [ 7  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.98      0.91        41
#          AFF       0.83      0.42      0.56        12
#
#     accuracy                           0.85        53
#    macro avg       0.84      0.70      0.73        53
# weighted avg       0.85      0.85      0.83        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 0.012359358370304108
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.015241178683936596
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[32]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        32
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        32
#    macro avg       1.00      1.00      1.00        32
# weighted avg       1.00      1.00      1.00        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.5406292080879211
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[7 1]
#  [1 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.88      0.88         8
#          AFF       0.50      0.50      0.50         2
#
#     accuracy                           0.80        10
#    macro avg       0.69      0.69      0.69        10
# weighted avg       0.80      0.80      0.80        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.7777720093727112
# Total Test Accuracy: 77.27272727272727
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[17  0]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.77      1.00      0.87        17
#          AFF       1.00      0.00      0.00         5
#
#     accuracy                           0.77        22
#    macro avg       0.89      0.50      0.44        22
# weighted avg       0.82      0.77      0.67        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.7185266613960266
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 93.10344827586206
# Test Accuracy (AFF): 42.857142857142854
# Confusion Matrix:
#  [[27  2]
#  [ 4  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.93      0.90        29
#          AFF       0.60      0.43      0.50         7
#
#     accuracy                           0.83        36
#    macro avg       0.74      0.68      0.70        36
# weighted avg       0.82      0.83      0.82        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.6142150037563764
# Total Test Accuracy: 86.08374384236453
# Test Accuracy (NFF): 94.06392694063926
# Test Accuracy (AFF): 52.25806451612903
# Confusion Matrix:
#  [[618  39]
#  [ 74  81]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.94      0.92       657
#          AFF       0.68      0.52      0.59       155
#
#     accuracy                           0.86       812
#    macro avg       0.78      0.73      0.75       812
# weighted avg       0.85      0.86      0.85       812
#
#
# Average Total Test Accuracy: 90.16431050322272

# %% [markdown]
# # ResNet 101

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision.models import resnet101, ResNet101_Weights
from torchvision.models import resnet50, ResNet50_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

class CustomNet(nn.Module):
    def __init__(self, num_classes=2, freeze_percentage=0.5):
        super(CustomNet, self).__init__()

        self.features = models.resnet101(weights=ResNet101_Weights.DEFAULT)

        # Calculate the index where to split the layers
        total_layers = len(list(self.features.children()))
        split_idx = int(total_layers * freeze_percentage)

        # Split the layers into groups for freezing and non-freezing
        children = list(self.features.children())
        self.frozen_features = nn.Sequential(*children[:split_idx])
        self.unfrozen_features = nn.Sequential(*children[split_idx:-1])  # Exclude the last layer

        # Freeze layers in self.frozen_features
        for param in self.frozen_features.parameters():
            param.requires_grad = False

        # Define the final fully connected layer
        self.fc = nn.Linear(2048, num_classes)

    def forward(self, x):
        x = self.frozen_features(x)
        x = self.unfrozen_features(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x
    
# create net
model = CustomNet(num_classes=2)  # num_classes 2

# checkpoint
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

global_path = '/local/data1/honzh073/data/suzuki.ad.liu.se/95d130b2-0ce0-4684-9bff-52a89b07962e/app_server/FL_global_model.pt'

checkpoint = torch.load(global_path, map_location=device)

# print(checkpoint.keys())

# modify checkpoint keys，match model
# load model weights
state_dict = checkpoint['model']
modified_state_dict = {}
for key, value in state_dict.items():
    # modify key names，match model layers
    new_key = key.replace("model.", "")
    modified_state_dict[new_key] = value

# load weights to model
model.load_state_dict(modified_state_dict)
model = model.to(device)
model.eval()

# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(30, 20))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.012893286533653736
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        23
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        23
#    macro avg       1.00      1.00      1.00        23
# weighted avg       1.00      1.00      1.00        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 0.0007709696074016392
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         0
#          AFF       1.00      1.00      1.00         3
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.3716070055961609
# Total Test Accuracy: 85.71428571428571
# Test Accuracy (NFF): 91.30434782608695
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[21  2]
#  [ 3  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.91      0.89        23
#          AFF       0.82      0.75      0.78        12
#
#     accuracy                           0.86        35
#    macro avg       0.85      0.83      0.84        35
# weighted avg       0.86      0.86      0.86        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.003908795304596424
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         2
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.10383174009621143
# Total Test Accuracy: 92.3076923076923
# Test Accuracy (NFF): 95.0
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[57  3]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.95      0.96        60
#          AFF       0.50      0.60      0.55         5
#
#     accuracy                           0.92        65
#    macro avg       0.73      0.77      0.75        65
# weighted avg       0.93      0.92      0.93        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.7197992205619812
# Total Test Accuracy: 85.71428571428571
# Test Accuracy (NFF): 94.44444444444444
# Test Accuracy (AFF): 70.0
# Confusion Matrix:
#  [[34  2]
#  [ 6 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.94      0.89        36
#          AFF       0.88      0.70      0.78        20
#
#     accuracy                           0.86        56
#    macro avg       0.86      0.82      0.84        56
# weighted avg       0.86      0.86      0.85        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.002393097383901477
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.48421476781368256
# Total Test Accuracy: 86.40776699029126
# Test Accuracy (NFF): 95.0
# Test Accuracy (AFF): 56.52173913043478
# Confusion Matrix:
#  [[76  4]
#  [10 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.95      0.92        80
#          AFF       0.76      0.57      0.65        23
#
#     accuracy                           0.86       103
#    macro avg       0.82      0.76      0.78       103
# weighted avg       0.86      0.86      0.86       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.012141935527324677
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 1.554339362308383
# Total Test Accuracy: 78.26086956521739
# Test Accuracy (NFF): 98.11320754716981
# Test Accuracy (AFF): 12.5
# Confusion Matrix:
#  [[52  1]
#  [14  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.79      0.98      0.87        53
#          AFF       0.67      0.12      0.21        16
#
#     accuracy                           0.78        69
#    macro avg       0.73      0.55      0.54        69
# weighted avg       0.76      0.78      0.72        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.2353704323177226
# Total Test Accuracy: 88.31168831168831
# Test Accuracy (NFF): 93.75
# Test Accuracy (AFF): 61.53846153846154
# Confusion Matrix:
#  [[60  4]
#  [ 5  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.94      0.93        64
#          AFF       0.67      0.62      0.64        13
#
#     accuracy                           0.88        77
#    macro avg       0.79      0.78      0.79        77
# weighted avg       0.88      0.88      0.88        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.2551057040691376
# Total Test Accuracy: 92.3076923076923
# Test Accuracy (NFF): 92.03539823008849
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[104   9]
#  [  0   4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.92      0.96       113
#          AFF       0.31      1.00      0.47         4
#
#     accuracy                           0.92       117
#    macro avg       0.65      0.96      0.71       117
# weighted avg       0.98      0.92      0.94       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.1586565375328064
# Total Test Accuracy: 93.33333333333333
# Test Accuracy (NFF): 95.34883720930233
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[41  2]
#  [ 1  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.95      0.96        43
#          AFF       0.33      0.50      0.40         2
#
#     accuracy                           0.93        45
#    macro avg       0.65      0.73      0.68        45
# weighted avg       0.95      0.93      0.94        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.011893318966031075
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        21
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 2.410940170288086
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         3
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.08849065750837326
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         4
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 0.5837437361478806
# Total Test Accuracy: 85.91549295774648
# Test Accuracy (NFF): 89.79591836734694
# Test Accuracy (AFF): 77.27272727272727
# Confusion Matrix:
#  [[44  5]
#  [ 5 17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.90      0.90        49
#          AFF       0.77      0.77      0.77        22
#
#     accuracy                           0.86        71
#    macro avg       0.84      0.84      0.84        71
# weighted avg       0.86      0.86      0.86        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.06478306464850903
# Total Test Accuracy: 96.82539682539682
# Test Accuracy (NFF): 97.59036144578313
# Test Accuracy (AFF): 95.34883720930233
# Confusion Matrix:
#  [[81  2]
#  [ 2 41]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.98      0.98        83
#          AFF       0.95      0.95      0.95        43
#
#     accuracy                           0.97       126
#    macro avg       0.96      0.96      0.96       126
# weighted avg       0.97      0.97      0.97       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.4175407886505127
# Total Test Accuracy: 86.66666666666667
# Test Accuracy (NFF): 90.0
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[36  4]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.90      0.92        40
#          AFF       0.43      0.60      0.50         5
#
#     accuracy                           0.87        45
#    macro avg       0.69      0.75      0.71        45
# weighted avg       0.89      0.87      0.88        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.02758670598268509
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[8 0]
#  [0 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         1
#
#     accuracy                           1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.5271614193916321
# Total Test Accuracy: 78.99159663865547
# Test Accuracy (NFF): 85.88235294117646
# Test Accuracy (AFF): 61.76470588235294
# Confusion Matrix:
#  [[73 12]
#  [13 21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.86      0.85        85
#          AFF       0.64      0.62      0.63        34
#
#     accuracy                           0.79       119
#    macro avg       0.74      0.74      0.74       119
# weighted avg       0.79      0.79      0.79       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 0.8685724139213562
# Total Test Accuracy: 77.31958762886597
# Test Accuracy (NFF): 92.45283018867924
# Test Accuracy (AFF): 59.09090909090909
# Confusion Matrix:
#  [[49  4]
#  [18 26]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.73      0.92      0.82        53
#          AFF       0.87      0.59      0.70        44
#
#     accuracy                           0.77        97
#    macro avg       0.80      0.76      0.76        97
# weighted avg       0.79      0.77      0.76        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.0014722472988069057
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.4238218069076538
# Total Test Accuracy: 91.20879120879121
# Test Accuracy (NFF): 96.1038961038961
# Test Accuracy (AFF): 64.28571428571429
# Confusion Matrix:
#  [[74  3]
#  [ 5  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.96      0.95        77
#          AFF       0.75      0.64      0.69        14
#
#     accuracy                           0.91        91
#    macro avg       0.84      0.80      0.82        91
# weighted avg       0.91      0.91      0.91        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 0.12649965286254883
# Total Test Accuracy: 94.44444444444444
# Test Accuracy (NFF): 93.33333333333333
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[14  1]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.93      0.97        15
#          AFF       0.75      1.00      0.86         3
#
#     accuracy                           0.94        18
#    macro avg       0.88      0.97      0.91        18
# weighted avg       0.96      0.94      0.95        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.13967253267765045
# Total Test Accuracy: 96.15384615384616
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 87.5
# Confusion Matrix:
#  [[18  0]
#  [ 1  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      1.00      0.97        18
#          AFF       1.00      0.88      0.93         8
#
#     accuracy                           0.96        26
#    macro avg       0.97      0.94      0.95        26
# weighted avg       0.96      0.96      0.96        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.45875298976898193
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 88.23529411764706
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[15  2]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.94        17
#          AFF       0.33      1.00      0.50         1
#
#     accuracy                           0.89        18
#    macro avg       0.67      0.94      0.72        18
# weighted avg       0.96      0.89      0.91        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.46732307970523834
# Total Test Accuracy: 90.3225806451613
# Test Accuracy (NFF): 94.9367088607595
# Test Accuracy (AFF): 64.28571428571429
# Confusion Matrix:
#  [[75  4]
#  [ 5  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.95      0.94        79
#          AFF       0.69      0.64      0.67        14
#
#     accuracy                           0.90        93
#    macro avg       0.81      0.80      0.81        93
# weighted avg       0.90      0.90      0.90        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 0.7214391231536865
# Total Test Accuracy: 68.75
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 42.857142857142854
# Confusion Matrix:
#  [[8 1]
#  [4 3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.67      0.89      0.76         9
#          AFF       0.75      0.43      0.55         7
#
#     accuracy                           0.69        16
#    macro avg       0.71      0.66      0.65        16
# weighted avg       0.70      0.69      0.67        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 0.03871604800224304
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 1.527172103524208
# Total Test Accuracy: 88.0952380952381
# Test Accuracy (NFF): 92.53731343283582
# Test Accuracy (AFF): 70.58823529411765
# Confusion Matrix:
#  [[62  5]
#  [ 5 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.93      0.93        67
#          AFF       0.71      0.71      0.71        17
#
#     accuracy                           0.88        84
#    macro avg       0.82      0.82      0.82        84
# weighted avg       0.88      0.88      0.88        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.01121560763567686
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.3545686552921931
# Total Test Accuracy: 86.48648648648648
# Test Accuracy (NFF): 90.47619047619048
# Test Accuracy (AFF): 63.63636363636363
# Confusion Matrix:
#  [[114  12]
#  [  8  14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.90      0.92       126
#          AFF       0.54      0.64      0.58        22
#
#     accuracy                           0.86       148
#    macro avg       0.74      0.77      0.75       148
# weighted avg       0.88      0.86      0.87       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.23029126226902008
# Total Test Accuracy: 91.17647058823529
# Test Accuracy (NFF): 91.17647058823529
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[31  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.91      0.95        34
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.91        34
#    macro avg       0.50      0.96      0.48        34
# weighted avg       1.00      0.91      0.95        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.2555767595767975
# Total Test Accuracy: 94.11764705882354
# Test Accuracy (NFF): 92.85714285714286
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[13  1]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.93      0.96        14
#          AFF       0.75      1.00      0.86         3
#
#     accuracy                           0.94        17
#    macro avg       0.88      0.96      0.91        17
# weighted avg       0.96      0.94      0.94        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.2807636857032776
# Total Test Accuracy: 89.53488372093024
# Test Accuracy (NFF): 92.64705882352942
# Test Accuracy (AFF): 77.77777777777779
# Confusion Matrix:
#  [[63  5]
#  [ 4 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.93      0.93        68
#          AFF       0.74      0.78      0.76        18
#
#     accuracy                           0.90        86
#    macro avg       0.84      0.85      0.85        86
# weighted avg       0.90      0.90      0.90        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.26507604122161865
# Total Test Accuracy: 88.0
# Test Accuracy (NFF): 88.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[22  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.94        25
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.88        25
#    macro avg       0.50      0.94      0.47        25
# weighted avg       1.00      0.88      0.94        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.4206889271736145
# Total Test Accuracy: 89.65517241379311
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[22  1]
#  [ 2  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.96      0.94        23
#          AFF       0.80      0.67      0.73         6
#
#     accuracy                           0.90        29
#    macro avg       0.86      0.81      0.83        29
# weighted avg       0.89      0.90      0.89        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.5166794774122536
# Total Test Accuracy: 82.66666666666667
# Test Accuracy (NFF): 88.57142857142857
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[62  8]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.89      0.91        70
#          AFF       0.00      0.00      1.00         5
#
#     accuracy                           0.83        75
#    macro avg       0.46      0.44      0.95        75
# weighted avg       0.86      0.83      0.91        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 0.001998125808313489
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 0.3771459758281708
# Total Test Accuracy: 93.33333333333333
# Test Accuracy (NFF): 93.33333333333333
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[14  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.93      0.97        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.93        15
#    macro avg       0.50      0.97      0.48        15
# weighted avg       1.00      0.93      0.97        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.11421524849720299
# Total Test Accuracy: 97.14285714285714
# Test Accuracy (NFF): 98.23529411764706
# Test Accuracy (AFF): 94.66666666666667
# Confusion Matrix:
#  [[167   3]
#  [  4  71]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.98      0.98       170
#          AFF       0.96      0.95      0.95        75
#
#     accuracy                           0.97       245
#    macro avg       0.97      0.96      0.97       245
# weighted avg       0.97      0.97      0.97       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.2799476385116577
# Total Test Accuracy: 90.3225806451613
# Test Accuracy (NFF): 92.3076923076923
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[24  2]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.92      0.94        26
#          AFF       0.67      0.80      0.73         5
#
#     accuracy                           0.90        31
#    macro avg       0.81      0.86      0.83        31
# weighted avg       0.91      0.90      0.91        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.3545047342777252
# Total Test Accuracy: 86.77685950413223
# Test Accuracy (NFF): 86.36363636363636
# Test Accuracy (AFF): 87.87878787878788
# Confusion Matrix:
#  [[76 12]
#  [ 4 29]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.86      0.90        88
#          AFF       0.71      0.88      0.78        33
#
#     accuracy                           0.87       121
#    macro avg       0.83      0.87      0.84       121
# weighted avg       0.88      0.87      0.87       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.13395072519779205
# Total Test Accuracy: 95.45454545454545
# Test Accuracy (NFF): 95.45454545454545
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.95      0.98        22
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.95        22
#    macro avg       0.50      0.98      0.49        22
# weighted avg       1.00      0.95      0.98        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.2929811514914036
# Total Test Accuracy: 90.81632653061224
# Test Accuracy (NFF): 96.15384615384616
# Test Accuracy (AFF): 70.0
# Confusion Matrix:
#  [[75  3]
#  [ 6 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.96      0.94        78
#          AFF       0.82      0.70      0.76        20
#
#     accuracy                           0.91        98
#    macro avg       0.87      0.83      0.85        98
# weighted avg       0.91      0.91      0.91        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.35059599578380585
# Total Test Accuracy: 87.32394366197182
# Test Accuracy (NFF): 90.625
# Test Accuracy (AFF): 57.14285714285714
# Confusion Matrix:
#  [[58  6]
#  [ 3  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.91      0.93        64
#          AFF       0.40      0.57      0.47         7
#
#     accuracy                           0.87        71
#    macro avg       0.68      0.74      0.70        71
# weighted avg       0.90      0.87      0.88        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.6088714599609375
# Total Test Accuracy: 80.70175438596492
# Test Accuracy (NFF): 80.7017543859649
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[46 11]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.81      0.89        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.81        57
#    macro avg       0.50      0.90      0.45        57
# weighted avg       1.00      0.81      0.89        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.5516721457242966
# Total Test Accuracy: 86.40776699029126
# Test Accuracy (NFF): 94.73684210526315
# Test Accuracy (AFF): 62.96296296296296
# Confusion Matrix:
#  [[72  4]
#  [10 17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.95      0.91        76
#          AFF       0.81      0.63      0.71        27
#
#     accuracy                           0.86       103
#    macro avg       0.84      0.79      0.81       103
# weighted avg       0.86      0.86      0.86       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.3748171851038933
# Total Test Accuracy: 93.67088607594937
# Test Accuracy (NFF): 95.83333333333334
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[69  3]
#  [ 2  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.96      0.97        72
#          AFF       0.62      0.71      0.67         7
#
#     accuracy                           0.94        79
#    macro avg       0.80      0.84      0.82        79
# weighted avg       0.94      0.94      0.94        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.1520988643169403
# Total Test Accuracy: 96.15384615384616
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[24  0]
#  [ 1  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      1.00      0.98        24
#          AFF       1.00      0.50      0.67         2
#
#     accuracy                           0.96        26
#    macro avg       0.98      0.75      0.82        26
# weighted avg       0.96      0.96      0.96        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 1.3356752395629883
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[3 0]
#  [3 6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.50      1.00      0.67         3
#          AFF       1.00      0.67      0.80         9
#
#     accuracy                           0.75        12
#    macro avg       0.75      0.83      0.73        12
# weighted avg       0.88      0.75      0.77        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.22222213757534823
# Total Test Accuracy: 91.7910447761194
# Test Accuracy (NFF): 95.28301886792453
# Test Accuracy (AFF): 78.57142857142857
# Confusion Matrix:
#  [[101   5]
#  [  6  22]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.95      0.95       106
#          AFF       0.81      0.79      0.80        28
#
#     accuracy                           0.92       134
#    macro avg       0.88      0.87      0.87       134
# weighted avg       0.92      0.92      0.92       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.15166298610468706
# Total Test Accuracy: 95.55555555555556
# Test Accuracy (NFF): 98.68421052631578
# Test Accuracy (AFF): 78.57142857142857
# Confusion Matrix:
#  [[150   2]
#  [  6  22]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.99      0.97       152
#          AFF       0.92      0.79      0.85        28
#
#     accuracy                           0.96       180
#    macro avg       0.94      0.89      0.91       180
# weighted avg       0.95      0.96      0.95       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.9603678584098816
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 85.18518518518519
# Test Accuracy (AFF): 53.84615384615385
# Confusion Matrix:
#  [[23  4]
#  [ 6  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.79      0.85      0.82        27
#          AFF       0.64      0.54      0.58        13
#
#     accuracy                           0.75        40
#    macro avg       0.71      0.70      0.70        40
# weighted avg       0.74      0.75      0.74        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 0.00035755118005909026
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 58:
#
# Test Loss: 0.6388001441955566
# Total Test Accuracy: 85.96491228070175
# Test Accuracy (NFF): 86.20689655172413
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[25  4]
#  [ 4 24]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.86      0.86      0.86        29
#          AFF       0.86      0.86      0.86        28
#
#     accuracy                           0.86        57
#    macro avg       0.86      0.86      0.86        57
# weighted avg       0.86      0.86      0.86        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.09246768057346344
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.6312586814165115
# Total Test Accuracy: 82.92682926829268
# Test Accuracy (NFF): 89.0
# Test Accuracy (AFF): 56.52173913043478
# Confusion Matrix:
#  [[89 11]
#  [10 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.89      0.89       100
#          AFF       0.54      0.57      0.55        23
#
#     accuracy                           0.83       123
#    macro avg       0.72      0.73      0.72       123
# weighted avg       0.83      0.83      0.83       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.7058083415031433
# Total Test Accuracy: 80.95238095238095
# Test Accuracy (NFF): 89.13043478260869
# Test Accuracy (AFF): 58.82352941176471
# Confusion Matrix:
#  [[41  5]
#  [ 7 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.89      0.87        46
#          AFF       0.67      0.59      0.62        17
#
#     accuracy                           0.81        63
#    macro avg       0.76      0.74      0.75        63
# weighted avg       0.80      0.81      0.81        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 0.5111352205276489
# Total Test Accuracy: 86.79245283018868
# Test Accuracy (NFF): 90.2439024390244
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[37  4]
#  [ 3  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.90      0.91        41
#          AFF       0.69      0.75      0.72        12
#
#     accuracy                           0.87        53
#    macro avg       0.81      0.83      0.82        53
# weighted avg       0.87      0.87      0.87        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 1.003830075263977
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 75.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6 2]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.75      0.86         8
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.75         8
#    macro avg       0.50      0.88      0.43         8
# weighted avg       1.00      0.75      0.86         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.027238111943006516
# Total Test Accuracy: 96.875
# Test Accuracy (NFF): 96.875
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[31  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.97      0.98        32
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.97        32
#    macro avg       0.50      0.98      0.49        32
# weighted avg       1.00      0.97      0.98        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.5190948247909546
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[7 1]
#  [1 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.88      0.88         8
#          AFF       0.50      0.50      0.50         2
#
#     accuracy                           0.80        10
#    macro avg       0.69      0.69      0.69        10
# weighted avg       0.80      0.80      0.80        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.2908935248851776
# Total Test Accuracy: 86.36363636363636
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 40.0
# Confusion Matrix:
#  [[17  0]
#  [ 3  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      1.00      0.92        17
#          AFF       1.00      0.40      0.57         5
#
#     accuracy                           0.86        22
#    macro avg       0.93      0.70      0.75        22
# weighted avg       0.88      0.86      0.84        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.5719100832939148
# Total Test Accuracy: 80.55555555555556
# Test Accuracy (NFF): 89.65517241379311
# Test Accuracy (AFF): 42.857142857142854
# Confusion Matrix:
#  [[26  3]
#  [ 4  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.90      0.88        29
#          AFF       0.50      0.43      0.46         7
#
#     accuracy                           0.81        36
#    macro avg       0.68      0.66      0.67        36
# weighted avg       0.80      0.81      0.80        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.48696715155473125
# Total Test Accuracy: 87.4384236453202
# Test Accuracy (NFF): 92.3896499238965
# Test Accuracy (AFF): 66.45161290322581
# Confusion Matrix:
#  [[607  50]
#  [ 52 103]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.92      0.92       657
#          AFF       0.67      0.66      0.67       155
#
#     accuracy                           0.87       812
#    macro avg       0.80      0.79      0.80       812
# weighted avg       0.87      0.87      0.87       812
#
#
# Average Total Test Accuracy: 89.73977058367468

# %% [markdown]
# # ResNet152

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision.models import resnet152, ResNet152_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

class CustomNet(nn.Module):
    def __init__(self, num_classes=2, freeze_percentage=0.5):
        super(CustomNet, self).__init__()

        self.features = models.resnet152(weights=ResNet152_Weights.DEFAULT)

        # Calculate the index where to split the layers
        total_layers = len(list(self.features.children()))
        split_idx = int(total_layers * freeze_percentage)

        # Split the layers into groups for freezing and non-freezing
        children = list(self.features.children())
        self.frozen_features = nn.Sequential(*children[:split_idx])
        self.unfrozen_features = nn.Sequential(*children[split_idx:-1])  # Exclude the last layer

        # Freeze layers in self.frozen_features
        for param in self.frozen_features.parameters():
            param.requires_grad = False

        # Define the final fully connected layer
        self.fc = nn.Linear(2048, num_classes)

    def forward(self, x):
        x = self.frozen_features(x)
        x = self.unfrozen_features(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x
    
# create net
model = CustomNet(num_classes=2)  # num_classes 2

# checkpoint
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# resnet152_freeze_Adam_200R_1E
global_path = '/local/data1/honzh073/data/suzuki.ad.liu.se/4130d3d0-e84b-4973-b303-ba3972822f6b/app_server/FL_global_model.pt'

checkpoint = torch.load(global_path, map_location=device)

# print(checkpoint.keys())

# modify checkpoint keys，match model
# load model weights
state_dict = checkpoint['model']
modified_state_dict = {}
for key, value in state_dict.items():
    # modify key names，match model layers
    new_key = key.replace("model.", "")
    modified_state_dict[new_key] = value

# load weights to model
model.load_state_dict(modified_state_dict)
model = model.to(device)
model.eval()

# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(30, 20))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.0726480558514595
# Total Test Accuracy: 95.65217391304348
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[22  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        23
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.96        23
#    macro avg       0.50      0.98      0.49        23
# weighted avg       1.00      0.96      0.98        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 0.00025947572430595756
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         0
#          AFF       1.00      1.00      1.00         3
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 1.0319644212722778
# Total Test Accuracy: 88.57142857142857
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[23  0]
#  [ 4  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      1.00      0.92        23
#          AFF       1.00      0.67      0.80        12
#
#     accuracy                           0.89        35
#    macro avg       0.93      0.83      0.86        35
# weighted avg       0.90      0.89      0.88        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.0013988103019073606
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         2
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.09151754507638543
# Total Test Accuracy: 95.38461538461539
# Test Accuracy (NFF): 96.66666666666667
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[58  2]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.97      0.97        60
#          AFF       0.67      0.80      0.73         5
#
#     accuracy                           0.95        65
#    macro avg       0.82      0.88      0.85        65
# weighted avg       0.96      0.95      0.96        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.3642140328884125
# Total Test Accuracy: 91.07142857142857
# Test Accuracy (NFF): 94.44444444444444
# Test Accuracy (AFF): 85.0
# Confusion Matrix:
#  [[34  2]
#  [ 3 17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.94      0.93        36
#          AFF       0.89      0.85      0.87        20
#
#     accuracy                           0.91        56
#    macro avg       0.91      0.90      0.90        56
# weighted avg       0.91      0.91      0.91        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.00021466637554112822
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.7585639357566833
# Total Test Accuracy: 89.32038834951456
# Test Accuracy (NFF): 96.25
# Test Accuracy (AFF): 65.21739130434783
# Confusion Matrix:
#  [[77  3]
#  [ 8 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.96      0.93        80
#          AFF       0.83      0.65      0.73        23
#
#     accuracy                           0.89       103
#    macro avg       0.87      0.81      0.83       103
# weighted avg       0.89      0.89      0.89       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.002929333131760359
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 0.34936205585836433
# Total Test Accuracy: 86.95652173913044
# Test Accuracy (NFF): 98.11320754716981
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[52  1]
#  [ 8  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.98      0.92        53
#          AFF       0.89      0.50      0.64        16
#
#     accuracy                           0.87        69
#    macro avg       0.88      0.74      0.78        69
# weighted avg       0.87      0.87      0.86        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.23233994405018166
# Total Test Accuracy: 88.31168831168831
# Test Accuracy (NFF): 93.75
# Test Accuracy (AFF): 61.53846153846154
# Confusion Matrix:
#  [[60  4]
#  [ 5  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.94      0.93        64
#          AFF       0.67      0.62      0.64        13
#
#     accuracy                           0.88        77
#    macro avg       0.79      0.78      0.79        77
# weighted avg       0.88      0.88      0.88        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.3284463733434677
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 88.49557522123894
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[100  13]
#  [  0   4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.94       113
#          AFF       0.24      1.00      0.38         4
#
#     accuracy                           0.89       117
#    macro avg       0.62      0.94      0.66       117
# weighted avg       0.97      0.89      0.92       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.4417179822921753
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 90.69767441860465
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[39  4]
#  [ 1  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.91      0.94        43
#          AFF       0.20      0.50      0.29         2
#
#     accuracy                           0.89        45
#    macro avg       0.59      0.70      0.61        45
# weighted avg       0.94      0.89      0.91        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.0023957944940775633
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        21
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 0.04022219777107239
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.006119930651038885
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         4
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 0.7028206586837769
# Total Test Accuracy: 87.32394366197182
# Test Accuracy (NFF): 95.91836734693877
# Test Accuracy (AFF): 68.18181818181817
# Confusion Matrix:
#  [[47  2]
#  [ 7 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.96      0.91        49
#          AFF       0.88      0.68      0.77        22
#
#     accuracy                           0.87        71
#    macro avg       0.88      0.82      0.84        71
# weighted avg       0.87      0.87      0.87        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.12626338005065918
# Total Test Accuracy: 96.03174603174604
# Test Accuracy (NFF): 97.59036144578313
# Test Accuracy (AFF): 93.02325581395348
# Confusion Matrix:
#  [[81  2]
#  [ 3 40]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.98      0.97        83
#          AFF       0.95      0.93      0.94        43
#
#     accuracy                           0.96       126
#    macro avg       0.96      0.95      0.96       126
# weighted avg       0.96      0.96      0.96       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.3077653646469116
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 90.0
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[36  4]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.90      0.94        40
#          AFF       0.50      0.80      0.62         5
#
#     accuracy                           0.89        45
#    macro avg       0.74      0.85      0.78        45
# weighted avg       0.92      0.89      0.90        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 1.3348973989486694
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[8 0]
#  [1 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      1.00      0.94         8
#          AFF       1.00      0.00      0.00         1
#
#     accuracy                           0.89         9
#    macro avg       0.94      0.50      0.47         9
# weighted avg       0.90      0.89      0.84         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.5911368429660797
# Total Test Accuracy: 81.5126050420168
# Test Accuracy (NFF): 88.23529411764706
# Test Accuracy (AFF): 64.70588235294117
# Confusion Matrix:
#  [[75 10]
#  [12 22]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.86      0.88      0.87        85
#          AFF       0.69      0.65      0.67        34
#
#     accuracy                           0.82       119
#    macro avg       0.77      0.76      0.77       119
# weighted avg       0.81      0.82      0.81       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 1.390744388103485
# Total Test Accuracy: 73.19587628865979
# Test Accuracy (NFF): 90.56603773584906
# Test Accuracy (AFF): 52.27272727272727
# Confusion Matrix:
#  [[48  5]
#  [21 23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.70      0.91      0.79        53
#          AFF       0.82      0.52      0.64        44
#
#     accuracy                           0.73        97
#    macro avg       0.76      0.71      0.71        97
# weighted avg       0.75      0.73      0.72        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 8.14917148090899e-05
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.23457935452461243
# Total Test Accuracy: 91.20879120879121
# Test Accuracy (NFF): 93.5064935064935
# Test Accuracy (AFF): 78.57142857142857
# Confusion Matrix:
#  [[72  5]
#  [ 3 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.94      0.95        77
#          AFF       0.69      0.79      0.73        14
#
#     accuracy                           0.91        91
#    macro avg       0.82      0.86      0.84        91
# weighted avg       0.92      0.91      0.91        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 0.0996684730052948
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[15  0]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        15
#          AFF       1.00      1.00      1.00         3
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.5231634974479675
# Total Test Accuracy: 92.3076923076923
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[18  0]
#  [ 2  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      1.00      0.95        18
#          AFF       1.00      0.75      0.86         8
#
#     accuracy                           0.92        26
#    macro avg       0.95      0.88      0.90        26
# weighted avg       0.93      0.92      0.92        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.01618161052465439
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[17  0]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        17
#          AFF       1.00      1.00      1.00         1
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.5208649039268494
# Total Test Accuracy: 88.17204301075269
# Test Accuracy (NFF): 93.67088607594937
# Test Accuracy (AFF): 57.14285714285714
# Confusion Matrix:
#  [[74  5]
#  [ 6  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.94      0.93        79
#          AFF       0.62      0.57      0.59        14
#
#     accuracy                           0.88        93
#    macro avg       0.77      0.75      0.76        93
# weighted avg       0.88      0.88      0.88        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 0.2356623411178589
# Total Test Accuracy: 87.5
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[9 0]
#  [2 5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.82      1.00      0.90         9
#          AFF       1.00      0.71      0.83         7
#
#     accuracy                           0.88        16
#    macro avg       0.91      0.86      0.87        16
# weighted avg       0.90      0.88      0.87        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 0.03332816809415817
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 0.4295998364686966
# Total Test Accuracy: 88.0952380952381
# Test Accuracy (NFF): 94.02985074626866
# Test Accuracy (AFF): 64.70588235294117
# Confusion Matrix:
#  [[63  4]
#  [ 6 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.94      0.93        67
#          AFF       0.73      0.65      0.69        17
#
#     accuracy                           0.88        84
#    macro avg       0.82      0.79      0.81        84
# weighted avg       0.88      0.88      0.88        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.008204436860978603
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.5779032905896505
# Total Test Accuracy: 81.08108108108108
# Test Accuracy (NFF): 83.33333333333334
# Test Accuracy (AFF): 68.18181818181817
# Confusion Matrix:
#  [[105  21]
#  [  7  15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.83      0.88       126
#          AFF       0.42      0.68      0.52        22
#
#     accuracy                           0.81       148
#    macro avg       0.68      0.76      0.70       148
# weighted avg       0.86      0.81      0.83       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.006473527755588293
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[34]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        34
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        34
#    macro avg       1.00      1.00      1.00        34
# weighted avg       1.00      1.00      1.00        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.10231956094503403
# Total Test Accuracy: 94.11764705882354
# Test Accuracy (NFF): 92.85714285714286
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[13  1]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.93      0.96        14
#          AFF       0.75      1.00      0.86         3
#
#     accuracy                           0.94        17
#    macro avg       0.88      0.96      0.91        17
# weighted avg       0.96      0.94      0.94        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.5903148055076599
# Total Test Accuracy: 82.55813953488372
# Test Accuracy (NFF): 88.23529411764706
# Test Accuracy (AFF): 61.111111111111114
# Confusion Matrix:
#  [[60  8]
#  [ 7 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.88      0.89        68
#          AFF       0.58      0.61      0.59        18
#
#     accuracy                           0.83        86
#    macro avg       0.74      0.75      0.74        86
# weighted avg       0.83      0.83      0.83        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.01859430782496929
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        25
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        25
#    macro avg       1.00      1.00      1.00        25
# weighted avg       1.00      1.00      1.00        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.5878052115440369
# Total Test Accuracy: 86.20689655172414
# Test Accuracy (NFF): 91.30434782608695
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[21  2]
#  [ 2  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.91      0.91        23
#          AFF       0.67      0.67      0.67         6
#
#     accuracy                           0.86        29
#    macro avg       0.79      0.79      0.79        29
# weighted avg       0.86      0.86      0.86        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.49551669508218765
# Total Test Accuracy: 86.66666666666667
# Test Accuracy (NFF): 92.85714285714286
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[65  5]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.93      0.93        70
#          AFF       0.00      0.00      1.00         5
#
#     accuracy                           0.87        75
#    macro avg       0.46      0.46      0.96        75
# weighted avg       0.87      0.87      0.93        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 9.93409457805683e-07
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 0.2144908756017685
# Total Test Accuracy: 93.33333333333333
# Test Accuracy (NFF): 93.33333333333333
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[14  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.93      0.97        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.93        15
#    macro avg       0.50      0.97      0.48        15
# weighted avg       1.00      0.93      0.97        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.14306571800261736
# Total Test Accuracy: 95.91836734693878
# Test Accuracy (NFF): 98.23529411764706
# Test Accuracy (AFF): 90.66666666666666
# Confusion Matrix:
#  [[167   3]
#  [  7  68]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.98      0.97       170
#          AFF       0.96      0.91      0.93        75
#
#     accuracy                           0.96       245
#    macro avg       0.96      0.94      0.95       245
# weighted avg       0.96      0.96      0.96       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.338569700717926
# Total Test Accuracy: 90.3225806451613
# Test Accuracy (NFF): 92.3076923076923
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[24  2]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.92      0.94        26
#          AFF       0.67      0.80      0.73         5
#
#     accuracy                           0.90        31
#    macro avg       0.81      0.86      0.83        31
# weighted avg       0.91      0.90      0.91        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.2423015460371971
# Total Test Accuracy: 87.60330578512396
# Test Accuracy (NFF): 92.04545454545455
# Test Accuracy (AFF): 75.75757575757575
# Confusion Matrix:
#  [[81  7]
#  [ 8 25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.92      0.92        88
#          AFF       0.78      0.76      0.77        33
#
#     accuracy                           0.88       121
#    macro avg       0.85      0.84      0.84       121
# weighted avg       0.87      0.88      0.88       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.15290679037570953
# Total Test Accuracy: 90.9090909090909
# Test Accuracy (NFF): 90.9090909090909
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[20  2]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.91      0.95        22
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.91        22
#    macro avg       0.50      0.95      0.48        22
# weighted avg       1.00      0.91      0.95        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.36373597010970116
# Total Test Accuracy: 89.79591836734694
# Test Accuracy (NFF): 94.87179487179486
# Test Accuracy (AFF): 70.0
# Confusion Matrix:
#  [[74  4]
#  [ 6 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.95      0.94        78
#          AFF       0.78      0.70      0.74        20
#
#     accuracy                           0.90        98
#    macro avg       0.85      0.82      0.84        98
# weighted avg       0.89      0.90      0.90        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.21711210161447525
# Total Test Accuracy: 91.54929577464789
# Test Accuracy (NFF): 92.1875
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[59  5]
#  [ 1  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.92      0.95        64
#          AFF       0.55      0.86      0.67         7
#
#     accuracy                           0.92        71
#    macro avg       0.76      0.89      0.81        71
# weighted avg       0.94      0.92      0.92        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.3238258957862854
# Total Test Accuracy: 89.47368421052632
# Test Accuracy (NFF): 89.47368421052632
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[51  6]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.89      0.94        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.89        57
#    macro avg       0.50      0.95      0.47        57
# weighted avg       1.00      0.89      0.94        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.7544764876365662
# Total Test Accuracy: 87.37864077669903
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 51.85185185185185
# Confusion Matrix:
#  [[76  0]
#  [13 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      1.00      0.92        76
#          AFF       1.00      0.52      0.68        27
#
#     accuracy                           0.87       103
#    macro avg       0.93      0.76      0.80       103
# weighted avg       0.89      0.87      0.86       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.3987557739019394
# Total Test Accuracy: 92.40506329113924
# Test Accuracy (NFF): 94.44444444444444
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[68  4]
#  [ 2  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.94      0.96        72
#          AFF       0.56      0.71      0.63         7
#
#     accuracy                           0.92        79
#    macro avg       0.76      0.83      0.79        79
# weighted avg       0.93      0.92      0.93        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.10050225257873535
# Total Test Accuracy: 96.15384615384616
# Test Accuracy (NFF): 95.83333333333334
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[23  1]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        24
#          AFF       0.67      1.00      0.80         2
#
#     accuracy                           0.96        26
#    macro avg       0.83      0.98      0.89        26
# weighted avg       0.97      0.96      0.96        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 1.274240493774414
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 55.55555555555556
# Confusion Matrix:
#  [[3 0]
#  [4 5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.43      1.00      0.60         3
#          AFF       1.00      0.56      0.71         9
#
#     accuracy                           0.67        12
#    macro avg       0.71      0.78      0.66        12
# weighted avg       0.86      0.67      0.69        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.29979460686445236
# Total Test Accuracy: 91.7910447761194
# Test Accuracy (NFF): 96.22641509433963
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[102   4]
#  [  7  21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.96      0.95       106
#          AFF       0.84      0.75      0.79        28
#
#     accuracy                           0.92       134
#    macro avg       0.89      0.86      0.87       134
# weighted avg       0.92      0.92      0.92       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.13859195820987225
# Total Test Accuracy: 97.22222222222223
# Test Accuracy (NFF): 99.3421052631579
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[151   1]
#  [  4  24]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.99      0.98       152
#          AFF       0.96      0.86      0.91        28
#
#     accuracy                           0.97       180
#    macro avg       0.97      0.93      0.94       180
# weighted avg       0.97      0.97      0.97       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.7617958784103394
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 92.5925925925926
# Test Accuracy (AFF): 53.84615384615385
# Confusion Matrix:
#  [[25  2]
#  [ 6  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      0.93      0.86        27
#          AFF       0.78      0.54      0.64        13
#
#     accuracy                           0.80        40
#    macro avg       0.79      0.73      0.75        40
# weighted avg       0.80      0.80      0.79        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 0.16562288999557495
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 58:
#
# Test Loss: 1.1457103490829468
# Total Test Accuracy: 80.70175438596492
# Test Accuracy (NFF): 79.3103448275862
# Test Accuracy (AFF): 82.14285714285714
# Confusion Matrix:
#  [[23  6]
#  [ 5 23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.82      0.79      0.81        29
#          AFF       0.79      0.82      0.81        28
#
#     accuracy                           0.81        57
#    macro avg       0.81      0.81      0.81        57
# weighted avg       0.81      0.81      0.81        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.000894917466212064
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.6767162978649139
# Total Test Accuracy: 78.04878048780488
# Test Accuracy (NFF): 81.0
# Test Accuracy (AFF): 65.21739130434783
# Confusion Matrix:
#  [[81 19]
#  [ 8 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.81      0.86       100
#          AFF       0.44      0.65      0.53        23
#
#     accuracy                           0.78       123
#    macro avg       0.68      0.73      0.69       123
# weighted avg       0.82      0.78      0.80       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.246302530169487
# Total Test Accuracy: 90.47619047619048
# Test Accuracy (NFF): 93.47826086956522
# Test Accuracy (AFF): 82.35294117647058
# Confusion Matrix:
#  [[43  3]
#  [ 3 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.93      0.93        46
#          AFF       0.82      0.82      0.82        17
#
#     accuracy                           0.90        63
#    macro avg       0.88      0.88      0.88        63
# weighted avg       0.90      0.90      0.90        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 0.6817166805267334
# Total Test Accuracy: 88.67924528301887
# Test Accuracy (NFF): 95.1219512195122
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[39  2]
#  [ 4  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.95      0.93        41
#          AFF       0.80      0.67      0.73        12
#
#     accuracy                           0.89        53
#    macro avg       0.85      0.81      0.83        53
# weighted avg       0.88      0.89      0.88        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 0.6890522837638855
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 75.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6 2]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.75      0.86         8
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.75         8
#    macro avg       0.50      0.88      0.43         8
# weighted avg       1.00      0.75      0.86         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.006817436311393976
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[32]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        32
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        32
#    macro avg       1.00      1.00      1.00        32
# weighted avg       1.00      1.00      1.00        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.578192949295044
# Total Test Accuracy: 90.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[8 0]
#  [1 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      1.00      0.94         8
#          AFF       1.00      0.50      0.67         2
#
#     accuracy                           0.90        10
#    macro avg       0.94      0.75      0.80        10
# weighted avg       0.91      0.90      0.89        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.8093416690826416
# Total Test Accuracy: 77.27272727272727
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[17  0]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.77      1.00      0.87        17
#          AFF       1.00      0.00      0.00         5
#
#     accuracy                           0.77        22
#    macro avg       0.89      0.50      0.44        22
# weighted avg       0.82      0.77      0.67        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.6385211944580078
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 96.55172413793103
# Test Accuracy (AFF): 28.57142857142857
# Confusion Matrix:
#  [[28  1]
#  [ 5  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.97      0.90        29
#          AFF       0.67      0.29      0.40         7
#
#     accuracy                           0.83        36
#    macro avg       0.76      0.63      0.65        36
# weighted avg       0.81      0.83      0.81        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.4702990169708545
# Total Test Accuracy: 86.94581280788178
# Test Accuracy (NFF): 91.32420091324201
# Test Accuracy (AFF): 68.38709677419355
# Confusion Matrix:
#  [[600  57]
#  [ 49 106]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.91      0.92       657
#          AFF       0.65      0.68      0.67       155
#
#     accuracy                           0.87       812
#    macro avg       0.79      0.80      0.79       812
# weighted avg       0.87      0.87      0.87       812
#
#
# Average Total Test Accuracy: 91.01168763048115

# %% [markdown]
# # DenseNet 161

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision.models import densenet161, DenseNet161_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

class CustomNet(nn.Module):
    def __init__(self, num_classes=2, freeze_percentage=0.5):
        super(CustomNet, self).__init__()

        self.features = models.densenet161(weights=DenseNet161_Weights.DEFAULT)

        # Calculate the index where to split the layers
        total_layers = len(list(self.features.children()))
        split_idx = int(total_layers * freeze_percentage)

        # Split the layers into groups for freezing and non-freezing
        children = list(self.features.children())
        self.frozen_features = nn.Sequential(*children[:split_idx])
        self.unfrozen_features = nn.Sequential(*children[split_idx:-1])  # Exclude the last layer

        # Freeze layers in self.frozen_features
        for param in self.frozen_features.parameters():
            param.requires_grad = False

        # Define the final fully connected layer
        self.fc = nn.Linear(2208, num_classes)  # DenseNet-161 has 2208 output features

    def forward(self, x):
        x = self.frozen_features(x)
        x = self.unfrozen_features(x)
        x = nn.functional.adaptive_avg_pool2d(x, (1, 1))  # Global average pooling
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x


# create net
model = CustomNet(num_classes=2)  # num_classes 2

# checkpoint
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# dense 161
global_path = '/local/data1/honzh073/data/suzuki.ad.liu.se/9f29e22d-0290-4f02-aaf3-aa83ae05d9e5/app_server/FL_global_model.pt'

checkpoint = torch.load(global_path, map_location=device)

# print(checkpoint.keys())

# modify checkpoint keys，match model
# load model weights
state_dict = checkpoint['model']
modified_state_dict = {}
for key, value in state_dict.items():
    # modify key names，match model layers
    new_key = key.replace("model.", "")
    modified_state_dict[new_key] = value

# load weights to model
model.load_state_dict(modified_state_dict)
model = model.to(device)
model.eval()


# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(30, 20))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.23866309225559235
# Total Test Accuracy: 95.65217391304348
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[22  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        23
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.96        23
#    macro avg       0.50      0.98      0.49        23
# weighted avg       1.00      0.96      0.98        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 0.6947567462921143
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[0 0]
#  [1 2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.00      1.00      0.00         0
#          AFF       1.00      0.67      0.80         3
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.6704726815223694
# Total Test Accuracy: 71.42857142857143
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 16.666666666666664
# Confusion Matrix:
#  [[23  0]
#  [10  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.70      1.00      0.82        23
#          AFF       1.00      0.17      0.29        12
#
#     accuracy                           0.71        35
#    macro avg       0.85      0.58      0.55        35
# weighted avg       0.80      0.71      0.64        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.10034815967082977
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         2
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.22252577543258667
# Total Test Accuracy: 92.3076923076923
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[60  0]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      1.00      0.96        60
#          AFF       1.00      0.00      0.00         5
#
#     accuracy                           0.92        65
#    macro avg       0.96      0.50      0.48        65
# weighted avg       0.93      0.92      0.89        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.556900680065155
# Total Test Accuracy: 73.21428571428571
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 25.0
# Confusion Matrix:
#  [[36  0]
#  [15  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.71      1.00      0.83        36
#          AFF       1.00      0.25      0.40        20
#
#     accuracy                           0.73        56
#    macro avg       0.85      0.62      0.61        56
# weighted avg       0.81      0.73      0.67        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.2615046799182892
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.48685571551322937
# Total Test Accuracy: 77.66990291262135
# Test Accuracy (NFF): 98.75
# Test Accuracy (AFF): 4.3478260869565215
# Confusion Matrix:
#  [[79  1]
#  [22  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.78      0.99      0.87        80
#          AFF       0.50      0.04      0.08        23
#
#     accuracy                           0.78       103
#    macro avg       0.64      0.52      0.48       103
# weighted avg       0.72      0.78      0.70       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.3329986035823822
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.89      0.94         9
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.89         9
#    macro avg       0.50      0.94      0.47         9
# weighted avg       1.00      0.89      0.94         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 0.3928156644105911
# Total Test Accuracy: 78.26086956521739
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 6.25
# Confusion Matrix:
#  [[53  0]
#  [15  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.78      1.00      0.88        53
#          AFF       1.00      0.06      0.12        16
#
#     accuracy                           0.78        69
#    macro avg       0.89      0.53      0.50        69
# weighted avg       0.83      0.78      0.70        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.3271878957748413
# Total Test Accuracy: 84.41558441558442
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 7.6923076923076925
# Confusion Matrix:
#  [[64  0]
#  [12  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      1.00      0.91        64
#          AFF       1.00      0.08      0.14        13
#
#     accuracy                           0.84        77
#    macro avg       0.92      0.54      0.53        77
# weighted avg       0.87      0.84      0.78        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.2587215304374695
# Total Test Accuracy: 95.72649572649573
# Test Accuracy (NFF): 97.34513274336283
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[110   3]
#  [  2   2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.97      0.98       113
#          AFF       0.40      0.50      0.44         4
#
#     accuracy                           0.96       117
#    macro avg       0.69      0.74      0.71       117
# weighted avg       0.96      0.96      0.96       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.2771431505680084
# Total Test Accuracy: 95.55555555555556
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[43  0]
#  [ 2  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      1.00      0.98        43
#          AFF       1.00      0.00      0.00         2
#
#     accuracy                           0.96        45
#    macro avg       0.98      0.50      0.49        45
# weighted avg       0.96      0.96      0.93        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.1465282440185547
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        21
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 0.6208636164665222
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         3
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.31048154830932617
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         4
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 0.5057119280099869
# Total Test Accuracy: 71.83098591549296
# Test Accuracy (NFF): 95.91836734693877
# Test Accuracy (AFF): 18.181818181818183
# Confusion Matrix:
#  [[47  2]
#  [18  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.72      0.96      0.82        49
#          AFF       0.67      0.18      0.29        22
#
#     accuracy                           0.72        71
#    macro avg       0.69      0.57      0.56        71
# weighted avg       0.71      0.72      0.66        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.56497822701931
# Total Test Accuracy: 69.84126984126983
# Test Accuracy (NFF): 98.79518072289156
# Test Accuracy (AFF): 13.953488372093023
# Confusion Matrix:
#  [[82  1]
#  [37  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.69      0.99      0.81        83
#          AFF       0.86      0.14      0.24        43
#
#     accuracy                           0.70       126
#    macro avg       0.77      0.56      0.53       126
# weighted avg       0.75      0.70      0.62       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.3660849630832672
# Total Test Accuracy: 86.66666666666667
# Test Accuracy (NFF): 95.0
# Test Accuracy (AFF): 20.0
# Confusion Matrix:
#  [[38  2]
#  [ 4  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.95      0.93        40
#          AFF       0.33      0.20      0.25         5
#
#     accuracy                           0.87        45
#    macro avg       0.62      0.57      0.59        45
# weighted avg       0.84      0.87      0.85        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.2813030779361725
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[8 0]
#  [1 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      1.00      0.94         8
#          AFF       1.00      0.00      0.00         1
#
#     accuracy                           0.89         9
#    macro avg       0.94      0.50      0.47         9
# weighted avg       0.90      0.89      0.84         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.5243964344263077
# Total Test Accuracy: 78.15126050420169
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 23.52941176470588
# Confusion Matrix:
#  [[85  0]
#  [26  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.77      1.00      0.87        85
#          AFF       1.00      0.24      0.38        34
#
#     accuracy                           0.78       119
#    macro avg       0.88      0.62      0.62       119
# weighted avg       0.83      0.78      0.73       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 0.76718869805336
# Total Test Accuracy: 58.76288659793814
# Test Accuracy (NFF): 96.22641509433963
# Test Accuracy (AFF): 13.636363636363635
# Confusion Matrix:
#  [[51  2]
#  [38  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.57      0.96      0.72        53
#          AFF       0.75      0.14      0.23        44
#
#     accuracy                           0.59        97
#    macro avg       0.66      0.55      0.47        97
# weighted avg       0.65      0.59      0.50        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.2628971040248871
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.35465434193611145
# Total Test Accuracy: 87.91208791208791
# Test Accuracy (NFF): 98.7012987012987
# Test Accuracy (AFF): 28.57142857142857
# Confusion Matrix:
#  [[76  1]
#  [10  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.99      0.93        77
#          AFF       0.80      0.29      0.42        14
#
#     accuracy                           0.88        91
#    macro avg       0.84      0.64      0.68        91
# weighted avg       0.87      0.88      0.85        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 0.6670329570770264
# Total Test Accuracy: 72.22222222222223
# Test Accuracy (NFF): 86.66666666666667
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[13  2]
#  [ 3  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      0.87      0.84        15
#          AFF       0.00      0.00      1.00         3
#
#     accuracy                           0.72        18
#    macro avg       0.41      0.43      0.92        18
# weighted avg       0.68      0.72      0.87        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.45282256603240967
# Total Test Accuracy: 80.76923076923077
# Test Accuracy (NFF): 94.44444444444444
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[17  1]
#  [ 4  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      0.94      0.87        18
#          AFF       0.80      0.50      0.62         8
#
#     accuracy                           0.81        26
#    macro avg       0.80      0.72      0.74        26
# weighted avg       0.81      0.81      0.79        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.22887206077575684
# Total Test Accuracy: 94.44444444444444
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[17  0]
#  [ 1  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      1.00      0.97        17
#          AFF       1.00      0.00      0.00         1
#
#     accuracy                           0.94        18
#    macro avg       0.97      0.50      0.49        18
# weighted avg       0.95      0.94      0.92        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.4101528972387314
# Total Test Accuracy: 86.02150537634408
# Test Accuracy (NFF): 97.46835443037975
# Test Accuracy (AFF): 21.428571428571427
# Confusion Matrix:
#  [[77  2]
#  [11  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.97      0.92        79
#          AFF       0.60      0.21      0.32        14
#
#     accuracy                           0.86        93
#    macro avg       0.74      0.59      0.62        93
# weighted avg       0.83      0.86      0.83        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 0.5464743971824646
# Total Test Accuracy: 56.25
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[9 0]
#  [7 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.56      1.00      0.72         9
#          AFF       1.00      0.00      0.00         7
#
#     accuracy                           0.56        16
#    macro avg       0.78      0.50      0.36        16
# weighted avg       0.75      0.56      0.40        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 0.2674592435359955
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 0.46329838037490845
# Total Test Accuracy: 80.95238095238095
# Test Accuracy (NFF): 98.50746268656717
# Test Accuracy (AFF): 11.76470588235294
# Confusion Matrix:
#  [[66  1]
#  [15  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      0.99      0.89        67
#          AFF       0.67      0.12      0.20        17
#
#     accuracy                           0.81        84
#    macro avg       0.74      0.55      0.55        84
# weighted avg       0.78      0.81      0.75        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.17157089710235596
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.42138752341270447
# Total Test Accuracy: 85.13513513513513
# Test Accuracy (NFF): 96.82539682539682
# Test Accuracy (AFF): 18.181818181818183
# Confusion Matrix:
#  [[122   4]
#  [ 18   4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.97      0.92       126
#          AFF       0.50      0.18      0.27        22
#
#     accuracy                           0.85       148
#    macro avg       0.69      0.58      0.59       148
# weighted avg       0.82      0.85      0.82       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.2752223312854767
# Total Test Accuracy: 97.05882352941177
# Test Accuracy (NFF): 97.05882352941177
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[33  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.97      0.99        34
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.97        34
#    macro avg       0.50      0.99      0.49        34
# weighted avg       1.00      0.97      0.99        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.4533165693283081
# Total Test Accuracy: 82.3529411764706
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[14  0]
#  [ 3  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.82      1.00      0.90        14
#          AFF       1.00      0.00      0.00         3
#
#     accuracy                           0.82        17
#    macro avg       0.91      0.50      0.45        17
# weighted avg       0.85      0.82      0.74        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.38610196113586426
# Total Test Accuracy: 82.55813953488372
# Test Accuracy (NFF): 98.52941176470588
# Test Accuracy (AFF): 22.22222222222222
# Confusion Matrix:
#  [[67  1]
#  [14  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.83      0.99      0.90        68
#          AFF       0.80      0.22      0.35        18
#
#     accuracy                           0.83        86
#    macro avg       0.81      0.60      0.62        86
# weighted avg       0.82      0.83      0.78        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.3049885630607605
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        25
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        25
#    macro avg       1.00      1.00      1.00        25
# weighted avg       1.00      1.00      1.00        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.4141349494457245
# Total Test Accuracy: 86.20689655172414
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 33.33333333333333
# Confusion Matrix:
#  [[23  0]
#  [ 4  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      1.00      0.92        23
#          AFF       1.00      0.33      0.50         6
#
#     accuracy                           0.86        29
#    macro avg       0.93      0.67      0.71        29
# weighted avg       0.88      0.86      0.83        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.27155420929193497
# Total Test Accuracy: 90.66666666666667
# Test Accuracy (NFF): 97.14285714285714
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[68  2]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.97      0.95        70
#          AFF       0.00      0.00      1.00         5
#
#     accuracy                           0.91        75
#    macro avg       0.47      0.49      0.98        75
# weighted avg       0.87      0.91      0.95        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 0.10920163244009018
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 0.38071733713150024
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 80.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[12  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.80      0.89        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.80        15
#    macro avg       0.50      0.90      0.44        15
# weighted avg       1.00      0.80      0.89        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.44641435146331787
# Total Test Accuracy: 77.14285714285714
# Test Accuracy (NFF): 98.82352941176471
# Test Accuracy (AFF): 28.000000000000004
# Confusion Matrix:
#  [[168   2]
#  [ 54  21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.76      0.99      0.86       170
#          AFF       0.91      0.28      0.43        75
#
#     accuracy                           0.77       245
#    macro avg       0.83      0.63      0.64       245
# weighted avg       0.80      0.77      0.73       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.3570602834224701
# Total Test Accuracy: 83.87096774193549
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[26  0]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      1.00      0.91        26
#          AFF       1.00      0.00      0.00         5
#
#     accuracy                           0.84        31
#    macro avg       0.92      0.50      0.46        31
# weighted avg       0.86      0.84      0.77        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.4678412079811096
# Total Test Accuracy: 79.33884297520662
# Test Accuracy (NFF): 97.72727272727273
# Test Accuracy (AFF): 30.303030303030305
# Confusion Matrix:
#  [[86  2]
#  [23 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.79      0.98      0.87        88
#          AFF       0.83      0.30      0.44        33
#
#     accuracy                           0.79       121
#    macro avg       0.81      0.64      0.66       121
# weighted avg       0.80      0.79      0.76       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.23801322281360626
# Total Test Accuracy: 95.45454545454545
# Test Accuracy (NFF): 95.45454545454545
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.95      0.98        22
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.95        22
#    macro avg       0.50      0.98      0.49        22
# weighted avg       1.00      0.95      0.98        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.35346347093582153
# Total Test Accuracy: 83.6734693877551
# Test Accuracy (NFF): 98.71794871794873
# Test Accuracy (AFF): 25.0
# Confusion Matrix:
#  [[77  1]
#  [15  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      0.99      0.91        78
#          AFF       0.83      0.25      0.38        20
#
#     accuracy                           0.84        98
#    macro avg       0.84      0.62      0.65        98
# weighted avg       0.84      0.84      0.80        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.3176240772008896
# Total Test Accuracy: 91.54929577464789
# Test Accuracy (NFF): 96.875
# Test Accuracy (AFF): 42.857142857142854
# Confusion Matrix:
#  [[62  2]
#  [ 4  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.97      0.95        64
#          AFF       0.60      0.43      0.50         7
#
#     accuracy                           0.92        71
#    macro avg       0.77      0.70      0.73        71
# weighted avg       0.91      0.92      0.91        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.26203882694244385
# Total Test Accuracy: 98.24561403508773
# Test Accuracy (NFF): 98.24561403508771
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[56  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.98      0.99        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.98        57
#    macro avg       0.50      0.99      0.50        57
# weighted avg       1.00      0.98      0.99        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.5439440906047821
# Total Test Accuracy: 77.66990291262135
# Test Accuracy (NFF): 98.68421052631578
# Test Accuracy (AFF): 18.51851851851852
# Confusion Matrix:
#  [[75  1]
#  [22  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.77      0.99      0.87        76
#          AFF       0.83      0.19      0.30        27
#
#     accuracy                           0.78       103
#    macro avg       0.80      0.59      0.59       103
# weighted avg       0.79      0.78      0.72       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.32021553814411163
# Total Test Accuracy: 91.13924050632912
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[72  0]
#  [ 7  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      1.00      0.95        72
#          AFF       1.00      0.00      0.00         7
#
#     accuracy                           0.91        79
#    macro avg       0.96      0.50      0.48        79
# weighted avg       0.92      0.91      0.87        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.25705423951148987
# Total Test Accuracy: 92.3076923076923
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[24  0]
#  [ 2  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      1.00      0.96        24
#          AFF       1.00      0.00      0.00         2
#
#     accuracy                           0.92        26
#    macro avg       0.96      0.50      0.48        26
# weighted avg       0.93      0.92      0.89        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 1.0404261350631714
# Total Test Accuracy: 33.333333333333336
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 11.11111111111111
# Confusion Matrix:
#  [[3 0]
#  [8 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.27      1.00      0.43         3
#          AFF       1.00      0.11      0.20         9
#
#     accuracy                           0.33        12
#    macro avg       0.64      0.56      0.31        12
# weighted avg       0.82      0.33      0.26        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.3616400013367335
# Total Test Accuracy: 79.1044776119403
# Test Accuracy (NFF): 98.11320754716981
# Test Accuracy (AFF): 7.142857142857142
# Confusion Matrix:
#  [[104   2]
#  [ 26   2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.80      0.98      0.88       106
#          AFF       0.50      0.07      0.12        28
#
#     accuracy                           0.79       134
#    macro avg       0.65      0.53      0.50       134
# weighted avg       0.74      0.79      0.72       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.42893868684768677
# Total Test Accuracy: 81.66666666666667
# Test Accuracy (NFF): 94.73684210526315
# Test Accuracy (AFF): 10.714285714285714
# Confusion Matrix:
#  [[144   8]
#  [ 25   3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.95      0.90       152
#          AFF       0.27      0.11      0.15        28
#
#     accuracy                           0.82       180
#    macro avg       0.56      0.53      0.53       180
# weighted avg       0.76      0.82      0.78       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.5950337648391724
# Total Test Accuracy: 70.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 7.6923076923076925
# Confusion Matrix:
#  [[27  0]
#  [12  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.69      1.00      0.82        27
#          AFF       1.00      0.08      0.14        13
#
#     accuracy                           0.70        40
#    macro avg       0.85      0.54      0.48        40
# weighted avg       0.79      0.70      0.60        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 0.24669234454631805
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 58:
#
# Test Loss: 0.7103570103645325
# Total Test Accuracy: 56.14035087719298
# Test Accuracy (NFF): 89.65517241379311
# Test Accuracy (AFF): 21.428571428571427
# Confusion Matrix:
#  [[26  3]
#  [22  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.54      0.90      0.68        29
#          AFF       0.67      0.21      0.32        28
#
#     accuracy                           0.56        57
#    macro avg       0.60      0.56      0.50        57
# weighted avg       0.60      0.56      0.50        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.21541264653205872
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.4985206574201584
# Total Test Accuracy: 78.04878048780488
# Test Accuracy (NFF): 94.0
# Test Accuracy (AFF): 8.695652173913043
# Confusion Matrix:
#  [[94  6]
#  [21  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.82      0.94      0.87       100
#          AFF       0.25      0.09      0.13        23
#
#     accuracy                           0.78       123
#    macro avg       0.53      0.51      0.50       123
# weighted avg       0.71      0.78      0.74       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.523307740688324
# Total Test Accuracy: 76.19047619047619
# Test Accuracy (NFF): 97.82608695652173
# Test Accuracy (AFF): 17.647058823529413
# Confusion Matrix:
#  [[45  1]
#  [14  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.76      0.98      0.86        46
#          AFF       0.75      0.18      0.29        17
#
#     accuracy                           0.76        63
#    macro avg       0.76      0.58      0.57        63
# weighted avg       0.76      0.76      0.70        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 0.5145179629325867
# Total Test Accuracy: 81.13207547169812
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 16.666666666666664
# Confusion Matrix:
#  [[41  0]
#  [10  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.80      1.00      0.89        41
#          AFF       1.00      0.17      0.29        12
#
#     accuracy                           0.81        53
#    macro avg       0.90      0.58      0.59        53
# weighted avg       0.85      0.81      0.75        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 0.3207205533981323
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.240628182888031
# Total Test Accuracy: 96.875
# Test Accuracy (NFF): 96.875
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[31  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.97      0.98        32
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.97        32
#    macro avg       0.50      0.98      0.49        32
# weighted avg       1.00      0.97      0.98        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.45808902382850647
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[8 0]
#  [2 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.80      1.00      0.89         8
#          AFF       1.00      0.00      0.00         2
#
#     accuracy                           0.80        10
#    macro avg       0.90      0.50      0.44        10
# weighted avg       0.84      0.80      0.71        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.5405666828155518
# Total Test Accuracy: 77.27272727272727
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[17  0]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.77      1.00      0.87        17
#          AFF       1.00      0.00      0.00         5
#
#     accuracy                           0.77        22
#    macro avg       0.89      0.50      0.44        22
# weighted avg       0.82      0.77      0.67        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.46174049377441406
# Total Test Accuracy: 80.55555555555556
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[29  0]
#  [ 7  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      1.00      0.89        29
#          AFF       1.00      0.00      0.00         7
#
#     accuracy                           0.81        36
#    macro avg       0.90      0.50      0.45        36
# weighted avg       0.84      0.81      0.72        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.43724503883948695
# Total Test Accuracy: 82.38916256157636
# Test Accuracy (NFF): 98.17351598173516
# Test Accuracy (AFF): 15.483870967741936
# Confusion Matrix:
#  [[645  12]
#  [131  24]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.83      0.98      0.90       657
#          AFF       0.67      0.15      0.25       155
#
#     accuracy                           0.82       812
#    macro avg       0.75      0.57      0.58       812
# weighted avg       0.80      0.82      0.78       812
#
#
# Average Total Test Accuracy: 84.2723406076776
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
