# %% [markdown]
# # All image csv files

# %%
import os
import csv

def create_csv(image_folder, csv_file_path):
    # CSV header
    fieldnames = ['HospitalID', 'PatientID', 'ImageID', 'ImagePath', 'Label']
    
    # open the CSV file in write mode
    with open(csv_file_path, 'w', newline='') as csvfile:
        # Create a CSV writer object and write the header
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        for filename in sorted(os.listdir(image_folder)):
            # complete image file path
            image_path = os.path.join(image_folder, filename)

            # filename to extract HospitalID, PatientID, image number, and image label
            parts = filename.split('_')
            hospital_id = parts[3]
            patient_id = parts[1]
            image_number = parts[6]
            image_label = parts[4]

            # write data into the CSV file
            writer.writerow({
                'HospitalID': hospital_id,
                'PatientID': patient_id,
                'ImageID': image_number,
                'ImagePath': image_path,
                'Label': image_label
            })

    # created and saved
    print("CSV file has been created and saved to:", csv_file_path)


image_folder = "/local/data1/honzh073/data/8bit_down224"
csv_file_path = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"
create_csv(image_folder, csv_file_path)
# Out:
# CSV file has been created and saved to: /local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv

# %% [markdown]
# # Custom Dataset and test 100 times average

# %%
# Custom dataset class
import os
import csv
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn as nn
from torchvision import models
from torchvision import transforms
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_curve, roc_auc_score
import torch.nn.functional as F

# custom dataset on csv files
class CustomDataset(Dataset):
    def __init__(self, csv_file, transform=None):
        self.data = []
        self.labels = []  # Store labels separately
        self.patient_ids = []  # Store patient IDs separately
        self.hospital_ids = []  # Store hospital IDs separately
        self.transform = transform
        
        # read csv
        with open(csv_file, 'r') as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                image_path = row['ImagePath']
                label = row['Label']
                patient_id = row['PatientID']
                hospital_id = row['HospitalID']

                if label == 'NFF':
                    label = 0
                elif label == 'AFF':
                    label = 1
                else:
                    raise ValueError("Invalid label in CSV file.")
                self.data.append((image_path, label))
                self.labels.append(label)
                self.patient_ids.append(patient_id)
                self.hospital_ids.append(int(hospital_id))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image_path, label = self.data[idx]
        image = Image.open(image_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image, label

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from sklearn.metrics import roc_auc_score, confusion_matrix, classification_report

def test_model(model, test_dataset, batch_size):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)
    model = model.to(device)

    model.eval()

    correct_test_nff = 0
    correct_test_aff = 0
    total_nff = 0
    total_aff = 0
    total_test = 0
    test_loss = 0

    criterion = nn.CrossEntropyLoss()

    with torch.no_grad():
        all_predictions = []
        all_labels = []
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            _, predicted = torch.max(outputs.data, 1)
            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            total_test += labels.size(0)
            total_nff += (labels == 0).sum().item()
            total_aff += (labels == 1).sum().item()
            correct_test_nff += ((predicted == labels) & (labels == 0)).sum().item()
            correct_test_aff += ((predicted == labels) & (labels == 1)).sum().item()
            test_loss += loss.item()

    # Check if total_aff is zero before performing the division
    test_accuracy_nff = 100 * (correct_test_nff / total_nff) if total_nff != 0 else 0
    test_accuracy_aff = 100 * (correct_test_aff / total_aff) if total_aff != 0 else 0
    test_accuracy_total = 100 * (correct_test_nff + correct_test_aff) / total_test
    test_loss /= len(test_loader)

    # Handle the case where there is only one class
    if len(set(all_labels)) > 1:
        auc_score = roc_auc_score(all_labels, all_predictions)
    else:
        auc_score = 0  # Default value if only one class is present

    conf_matrix = confusion_matrix(all_labels, all_predictions)

    # Directly use class labels as strings in target_names
    target_names = ['NFF', 'AFF']

    classification_rep = classification_report(all_labels, all_predictions, target_names=target_names, labels=[0, 1], zero_division=1)

    # Store metrics in a dictionary
    metrics = {
        "Test Loss": test_loss,
        "Total Test Accuracy": test_accuracy_total,
        "Test Accuracy (NFF)": test_accuracy_nff,
        "Test Accuracy (AFF)": test_accuracy_aff,
        "AUC": auc_score,
        "Confusion Matrix": conf_matrix,
        "Classification Report": classification_rep
    }
    return metrics

# %% [markdown]
# # VGG 19

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision.models import vgg19, VGG19_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# models from job, 50% freezed
class CustomNet(nn.Module):
    def __init__(self, num_classes=2, freeze_percentage=0.5):
        super(CustomNet, self).__init__()

        # Load the pre-trained VGG19 model
        vgg19_model = models.vgg19(weights=VGG19_Weights.DEFAULT)

        # Extract features (all layers except the classifier)
        self.features = nn.Sequential(*list(vgg19_model.features.children()))

        # Calculate the index where to split the layers
        total_layers = len(list(self.features.children()))
        split_idx = int(total_layers * freeze_percentage)

        # Split the layers into groups for freezing and non-freezing
        children = list(self.features.children())
        self.frozen_features = nn.Sequential(*children[:split_idx])
        self.unfrozen_features = nn.Sequential(*children[split_idx:])

        # Freeze layers in self.frozen_features
        for param in self.frozen_features.parameters():
            param.requires_grad = False

        # Define the final fully connected layer
        in_features = vgg19_model.classifier[0].in_features
        self.classifier = nn.Linear(in_features, num_classes)  # VGG19's last feature map has 512 channels

    def forward(self, x):
        x = self.frozen_features(x)
        x = self.unfrozen_features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

# create net
model = CustomNet(num_classes=2)  # num_classes 2

# checkpoint
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# vgg19_freeze_Adam_100R_2E
global_path = '/local/data1/honzh073/data/suzuki.ad.liu.se/8851362f-e38d-4f9b-91b6-2cb42da00d67/app_server/FL_global_model.pt'
checkpoint = torch.load(global_path, map_location=device)

# print(checkpoint.keys())

# modify checkpoint keys，match model
# load model weights
state_dict = checkpoint['model']
modified_state_dict = {}
for key, value in state_dict.items():
    # modify key names，match model layers
    new_key = key.replace("model.", "")
    modified_state_dict[new_key] = value

# load weights to model
model.load_state_dict(modified_state_dict)
model = model.to(device)
model.eval()


# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(30, 20))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.1904100924730301
# Total Test Accuracy: 95.65217391304348
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[22  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        23
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.96        23
#    macro avg       0.50      0.98      0.49        23
# weighted avg       1.00      0.96      0.98        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 0.06496712565422058
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         0
#          AFF       1.00      1.00      1.00         3
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.8708636164665222
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 91.30434782608695
# Test Accuracy (AFF): 58.333333333333336
# Confusion Matrix:
#  [[21  2]
#  [ 5  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      0.91      0.86        23
#          AFF       0.78      0.58      0.67        12
#
#     accuracy                           0.80        35
#    macro avg       0.79      0.75      0.76        35
# weighted avg       0.80      0.80      0.79        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.0013182200491428375
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         2
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.3011103866792837
# Total Test Accuracy: 90.76923076923077
# Test Accuracy (NFF): 91.66666666666666
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[55  5]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.92      0.95        60
#          AFF       0.44      0.80      0.57         5
#
#     accuracy                           0.91        65
#    macro avg       0.71      0.86      0.76        65
# weighted avg       0.94      0.91      0.92        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.6012236475944519
# Total Test Accuracy: 85.71428571428571
# Test Accuracy (NFF): 83.33333333333334
# Test Accuracy (AFF): 90.0
# Confusion Matrix:
#  [[30  6]
#  [ 2 18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.83      0.88        36
#          AFF       0.75      0.90      0.82        20
#
#     accuracy                           0.86        56
#    macro avg       0.84      0.87      0.85        56
# weighted avg       0.87      0.86      0.86        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.028722213581204414
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.8491070866584778
# Total Test Accuracy: 86.40776699029126
# Test Accuracy (NFF): 90.0
# Test Accuracy (AFF): 73.91304347826086
# Confusion Matrix:
#  [[72  8]
#  [ 6 17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.90      0.91        80
#          AFF       0.68      0.74      0.71        23
#
#     accuracy                           0.86       103
#    macro avg       0.80      0.82      0.81       103
# weighted avg       0.87      0.86      0.87       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.0050506629049777985
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 0.3646917024962022
# Total Test Accuracy: 88.40579710144928
# Test Accuracy (NFF): 90.56603773584906
# Test Accuracy (AFF): 81.25
# Confusion Matrix:
#  [[48  5]
#  [ 3 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.91      0.92        53
#          AFF       0.72      0.81      0.76        16
#
#     accuracy                           0.88        69
#    macro avg       0.83      0.86      0.84        69
# weighted avg       0.89      0.88      0.89        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.19320196715125348
# Total Test Accuracy: 92.20779220779221
# Test Accuracy (NFF): 96.875
# Test Accuracy (AFF): 69.23076923076923
# Confusion Matrix:
#  [[62  2]
#  [ 4  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.97      0.95        64
#          AFF       0.82      0.69      0.75        13
#
#     accuracy                           0.92        77
#    macro avg       0.88      0.83      0.85        77
# weighted avg       0.92      0.92      0.92        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.3582751713693142
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 88.49557522123894
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[100  13]
#  [  0   4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.94       113
#          AFF       0.24      1.00      0.38         4
#
#     accuracy                           0.89       117
#    macro avg       0.62      0.94      0.66       117
# weighted avg       0.97      0.89      0.92       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.5229824781417847
# Total Test Accuracy: 91.11111111111111
# Test Accuracy (NFF): 90.69767441860465
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[39  4]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.91      0.95        43
#          AFF       0.33      1.00      0.50         2
#
#     accuracy                           0.91        45
#    macro avg       0.67      0.95      0.73        45
# weighted avg       0.97      0.91      0.93        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.03822730854153633
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        21
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 1.3470734357833862
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         3
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.002322992542758584
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         4
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 0.572362944483757
# Total Test Accuracy: 81.69014084507042
# Test Accuracy (NFF): 91.83673469387756
# Test Accuracy (AFF): 59.09090909090909
# Confusion Matrix:
#  [[45  4]
#  [ 9 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.83      0.92      0.87        49
#          AFF       0.76      0.59      0.67        22
#
#     accuracy                           0.82        71
#    macro avg       0.80      0.75      0.77        71
# weighted avg       0.81      0.82      0.81        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.24194660782814026
# Total Test Accuracy: 96.03174603174604
# Test Accuracy (NFF): 98.79518072289156
# Test Accuracy (AFF): 90.69767441860465
# Confusion Matrix:
#  [[82  1]
#  [ 4 39]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.99      0.97        83
#          AFF       0.97      0.91      0.94        43
#
#     accuracy                           0.96       126
#    macro avg       0.96      0.95      0.96       126
# weighted avg       0.96      0.96      0.96       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.5474575757980347
# Total Test Accuracy: 82.22222222222223
# Test Accuracy (NFF): 80.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[32  8]
#  [ 0  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.80      0.89        40
#          AFF       0.38      1.00      0.56         5
#
#     accuracy                           0.82        45
#    macro avg       0.69      0.90      0.72        45
# weighted avg       0.93      0.82      0.85        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.3597738444805145
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[7 1]
#  [0 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.93         8
#          AFF       0.50      1.00      0.67         1
#
#     accuracy                           0.89         9
#    macro avg       0.75      0.94      0.80         9
# weighted avg       0.94      0.89      0.90         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.6800632029771805
# Total Test Accuracy: 84.03361344537815
# Test Accuracy (NFF): 91.76470588235294
# Test Accuracy (AFF): 64.70588235294117
# Confusion Matrix:
#  [[78  7]
#  [12 22]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.92      0.89        85
#          AFF       0.76      0.65      0.70        34
#
#     accuracy                           0.84       119
#    macro avg       0.81      0.78      0.79       119
# weighted avg       0.84      0.84      0.84       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 0.6843025535345078
# Total Test Accuracy: 79.38144329896907
# Test Accuracy (NFF): 90.56603773584906
# Test Accuracy (AFF): 65.9090909090909
# Confusion Matrix:
#  [[48  5]
#  [15 29]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.76      0.91      0.83        53
#          AFF       0.85      0.66      0.74        44
#
#     accuracy                           0.79        97
#    macro avg       0.81      0.78      0.79        97
# weighted avg       0.80      0.79      0.79        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.0001237162941833958
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.4362388551235199
# Total Test Accuracy: 86.81318681318682
# Test Accuracy (NFF): 89.6103896103896
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[69  8]
#  [ 4 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.90      0.92        77
#          AFF       0.56      0.71      0.63        14
#
#     accuracy                           0.87        91
#    macro avg       0.75      0.81      0.77        91
# weighted avg       0.89      0.87      0.87        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 1.191685676574707
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 73.33333333333333
# Test Accuracy (AFF): 33.33333333333333
# Confusion Matrix:
#  [[11  4]
#  [ 2  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.73      0.79        15
#          AFF       0.20      0.33      0.25         3
#
#     accuracy                           0.67        18
#    macro avg       0.52      0.53      0.52        18
# weighted avg       0.74      0.67      0.70        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 1.0036168098449707
# Total Test Accuracy: 92.3076923076923
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[18  0]
#  [ 2  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      1.00      0.95        18
#          AFF       1.00      0.75      0.86         8
#
#     accuracy                           0.92        26
#    macro avg       0.95      0.88      0.90        26
# weighted avg       0.93      0.92      0.92        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.17467577755451202
# Total Test Accuracy: 94.44444444444444
# Test Accuracy (NFF): 94.11764705882352
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[16  1]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.94      0.97        17
#          AFF       0.50      1.00      0.67         1
#
#     accuracy                           0.94        18
#    macro avg       0.75      0.97      0.82        18
# weighted avg       0.97      0.94      0.95        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.2084207683801651
# Total Test Accuracy: 92.47311827956989
# Test Accuracy (NFF): 93.67088607594937
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[74  5]
#  [ 2 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.94      0.95        79
#          AFF       0.71      0.86      0.77        14
#
#     accuracy                           0.92        93
#    macro avg       0.84      0.90      0.86        93
# weighted avg       0.93      0.92      0.93        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 1.0289007425308228
# Total Test Accuracy: 81.25
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 57.14285714285714
# Confusion Matrix:
#  [[9 0]
#  [3 4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.75      1.00      0.86         9
#          AFF       1.00      0.57      0.73         7
#
#     accuracy                           0.81        16
#    macro avg       0.88      0.79      0.79        16
# weighted avg       0.86      0.81      0.80        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 2.5956718921661377
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4 2]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         6
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         6
#    macro avg       0.50      0.83      0.40         6
# weighted avg       1.00      0.67      0.80         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 0.1853039711713791
# Total Test Accuracy: 94.04761904761905
# Test Accuracy (NFF): 95.52238805970148
# Test Accuracy (AFF): 88.23529411764706
# Confusion Matrix:
#  [[64  3]
#  [ 2 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.96      0.96        67
#          AFF       0.83      0.88      0.86        17
#
#     accuracy                           0.94        84
#    macro avg       0.90      0.92      0.91        84
# weighted avg       0.94      0.94      0.94        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.0022668654564768076
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.4616604745388031
# Total Test Accuracy: 89.1891891891892
# Test Accuracy (NFF): 92.85714285714286
# Test Accuracy (AFF): 68.18181818181817
# Confusion Matrix:
#  [[117   9]
#  [  7  15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.93      0.94       126
#          AFF       0.62      0.68      0.65        22
#
#     accuracy                           0.89       148
#    macro avg       0.78      0.81      0.79       148
# weighted avg       0.90      0.89      0.89       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.06397996842861176
# Total Test Accuracy: 97.05882352941177
# Test Accuracy (NFF): 97.05882352941177
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[33  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.97      0.99        34
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.97        34
#    macro avg       0.50      0.99      0.49        34
# weighted avg       1.00      0.97      0.99        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.00032788998214527965
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[14  0]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        14
#          AFF       1.00      1.00      1.00         3
#
#     accuracy                           1.00        17
#    macro avg       1.00      1.00      1.00        17
# weighted avg       1.00      1.00      1.00        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.5235534533858299
# Total Test Accuracy: 87.20930232558139
# Test Accuracy (NFF): 92.64705882352942
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[63  5]
#  [ 6 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.93      0.92        68
#          AFF       0.71      0.67      0.69        18
#
#     accuracy                           0.87        86
#    macro avg       0.81      0.80      0.80        86
# weighted avg       0.87      0.87      0.87        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.2555733919143677
# Total Test Accuracy: 92.0
# Test Accuracy (NFF): 92.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[23  2]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.92      0.96        25
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.92        25
#    macro avg       0.50      0.96      0.48        25
# weighted avg       1.00      0.92      0.96        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.6882762312889099
# Total Test Accuracy: 79.3103448275862
# Test Accuracy (NFF): 78.26086956521739
# Test Accuracy (AFF): 83.33333333333334
# Confusion Matrix:
#  [[18  5]
#  [ 1  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.78      0.86        23
#          AFF       0.50      0.83      0.62         6
#
#     accuracy                           0.79        29
#    macro avg       0.72      0.81      0.74        29
# weighted avg       0.85      0.79      0.81        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.31947807408869267
# Total Test Accuracy: 84.0
# Test Accuracy (NFF): 85.71428571428571
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[60 10]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.86      0.91        70
#          AFF       0.23      0.60      0.33         5
#
#     accuracy                           0.84        75
#    macro avg       0.60      0.73      0.62        75
# weighted avg       0.92      0.84      0.87        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 0.0
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 1.814145565032959
# Total Test Accuracy: 60.0
# Test Accuracy (NFF): 60.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9 6]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.60      0.75        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.60        15
#    macro avg       0.50      0.80      0.37        15
# weighted avg       1.00      0.60      0.75        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.20421652682125568
# Total Test Accuracy: 96.3265306122449
# Test Accuracy (NFF): 95.88235294117648
# Test Accuracy (AFF): 97.33333333333334
# Confusion Matrix:
#  [[163   7]
#  [  2  73]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.96      0.97       170
#          AFF       0.91      0.97      0.94        75
#
#     accuracy                           0.96       245
#    macro avg       0.95      0.97      0.96       245
# weighted avg       0.96      0.96      0.96       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.3089548945426941
# Total Test Accuracy: 83.87096774193549
# Test Accuracy (NFF): 80.76923076923077
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[21  5]
#  [ 0  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.81      0.89        26
#          AFF       0.50      1.00      0.67         5
#
#     accuracy                           0.84        31
#    macro avg       0.75      0.90      0.78        31
# weighted avg       0.92      0.84      0.86        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.5197310447692871
# Total Test Accuracy: 89.25619834710744
# Test Accuracy (NFF): 89.77272727272727
# Test Accuracy (AFF): 87.87878787878788
# Confusion Matrix:
#  [[79  9]
#  [ 4 29]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.90      0.92        88
#          AFF       0.76      0.88      0.82        33
#
#     accuracy                           0.89       121
#    macro avg       0.86      0.89      0.87       121
# weighted avg       0.90      0.89      0.89       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.47347724437713623
# Total Test Accuracy: 77.27272727272727
# Test Accuracy (NFF): 77.27272727272727
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[17  5]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.77      0.87        22
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.77        22
#    macro avg       0.50      0.89      0.44        22
# weighted avg       1.00      0.77      0.87        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.45554108917713165
# Total Test Accuracy: 88.77551020408163
# Test Accuracy (NFF): 93.58974358974359
# Test Accuracy (AFF): 70.0
# Confusion Matrix:
#  [[73  5]
#  [ 6 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.94      0.93        78
#          AFF       0.74      0.70      0.72        20
#
#     accuracy                           0.89        98
#    macro avg       0.83      0.82      0.82        98
# weighted avg       0.89      0.89      0.89        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.594931572675705
# Total Test Accuracy: 90.14084507042253
# Test Accuracy (NFF): 92.1875
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[59  5]
#  [ 2  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.92      0.94        64
#          AFF       0.50      0.71      0.59         7
#
#     accuracy                           0.90        71
#    macro avg       0.73      0.82      0.77        71
# weighted avg       0.92      0.90      0.91        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.6717053651809692
# Total Test Accuracy: 85.96491228070175
# Test Accuracy (NFF): 85.96491228070175
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[49  8]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.86      0.92        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.86        57
#    macro avg       0.50      0.93      0.46        57
# weighted avg       1.00      0.86      0.92        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.6193973422050476
# Total Test Accuracy: 86.40776699029126
# Test Accuracy (NFF): 94.73684210526315
# Test Accuracy (AFF): 62.96296296296296
# Confusion Matrix:
#  [[72  4]
#  [10 17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.95      0.91        76
#          AFF       0.81      0.63      0.71        27
#
#     accuracy                           0.86       103
#    macro avg       0.84      0.79      0.81       103
# weighted avg       0.86      0.86      0.86       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.29010701924562454
# Total Test Accuracy: 93.67088607594937
# Test Accuracy (NFF): 93.05555555555556
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[67  5]
#  [ 0  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.93      0.96        72
#          AFF       0.58      1.00      0.74         7
#
#     accuracy                           0.94        79
#    macro avg       0.79      0.97      0.85        79
# weighted avg       0.96      0.94      0.94        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.008248514495790005
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[24  0]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        24
#          AFF       1.00      1.00      1.00         2
#
#     accuracy                           1.00        26
#    macro avg       1.00      1.00      1.00        26
# weighted avg       1.00      1.00      1.00        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 0.09055153280496597
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[3 0]
#  [0 9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         9
#
#     accuracy                           1.00        12
#    macro avg       1.00      1.00      1.00        12
# weighted avg       1.00      1.00      1.00        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.3587457984685898
# Total Test Accuracy: 93.28358208955224
# Test Accuracy (NFF): 96.22641509433963
# Test Accuracy (AFF): 82.14285714285714
# Confusion Matrix:
#  [[102   4]
#  [  5  23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.96      0.96       106
#          AFF       0.85      0.82      0.84        28
#
#     accuracy                           0.93       134
#    macro avg       0.90      0.89      0.90       134
# weighted avg       0.93      0.93      0.93       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.32608676453431445
# Total Test Accuracy: 94.44444444444444
# Test Accuracy (NFF): 98.68421052631578
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[150   2]
#  [  8  20]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.99      0.97       152
#          AFF       0.91      0.71      0.80        28
#
#     accuracy                           0.94       180
#    macro avg       0.93      0.85      0.88       180
# weighted avg       0.94      0.94      0.94       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.516962468624115
# Total Test Accuracy: 90.0
# Test Accuracy (NFF): 96.29629629629629
# Test Accuracy (AFF): 76.92307692307693
# Confusion Matrix:
#  [[26  1]
#  [ 3 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.96      0.93        27
#          AFF       0.91      0.77      0.83        13
#
#     accuracy                           0.90        40
#    macro avg       0.90      0.87      0.88        40
# weighted avg       0.90      0.90      0.90        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 0.29050949215888977
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         3
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# Performance for Hospital 58:
#
# Test Loss: 1.2799370288848877
# Total Test Accuracy: 84.21052631578948
# Test Accuracy (NFF): 79.3103448275862
# Test Accuracy (AFF): 89.28571428571429
# Confusion Matrix:
#  [[23  6]
#  [ 3 25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.79      0.84        29
#          AFF       0.81      0.89      0.85        28
#
#     accuracy                           0.84        57
#    macro avg       0.85      0.84      0.84        57
# weighted avg       0.85      0.84      0.84        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.1841145157814026
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.89      0.94         9
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.89         9
#    macro avg       0.50      0.94      0.47         9
# weighted avg       1.00      0.89      0.94         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.5818807929754257
# Total Test Accuracy: 83.73983739837398
# Test Accuracy (NFF): 86.0
# Test Accuracy (AFF): 73.91304347826086
# Confusion Matrix:
#  [[86 14]
#  [ 6 17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.86      0.90       100
#          AFF       0.55      0.74      0.63        23
#
#     accuracy                           0.84       123
#    macro avg       0.74      0.80      0.76       123
# weighted avg       0.86      0.84      0.85       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.43540307879447937
# Total Test Accuracy: 90.47619047619048
# Test Accuracy (NFF): 93.47826086956522
# Test Accuracy (AFF): 82.35294117647058
# Confusion Matrix:
#  [[43  3]
#  [ 3 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.93      0.93        46
#          AFF       0.82      0.82      0.82        17
#
#     accuracy                           0.90        63
#    macro avg       0.88      0.88      0.88        63
# weighted avg       0.90      0.90      0.90        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 1.0128815174102783
# Total Test Accuracy: 81.13207547169812
# Test Accuracy (NFF): 85.36585365853658
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[35  6]
#  [ 4  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.85      0.88        41
#          AFF       0.57      0.67      0.62        12
#
#     accuracy                           0.81        53
#    macro avg       0.73      0.76      0.75        53
# weighted avg       0.82      0.81      0.82        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 8.529080514563248e-05
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.18440236151218414
# Total Test Accuracy: 90.625
# Test Accuracy (NFF): 90.625
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[29  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.91      0.95        32
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.91        32
#    macro avg       0.50      0.95      0.48        32
# weighted avg       1.00      0.91      0.95        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 1.6636089086532593
# Total Test Accuracy: 70.0
# Test Accuracy (NFF): 75.0
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[6 2]
#  [1 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.86      0.75      0.80         8
#          AFF       0.33      0.50      0.40         2
#
#     accuracy                           0.70        10
#    macro avg       0.60      0.62      0.60        10
# weighted avg       0.75      0.70      0.72        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.637349545955658
# Total Test Accuracy: 86.36363636363636
# Test Accuracy (NFF): 88.23529411764706
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[15  2]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.88      0.91        17
#          AFF       0.67      0.80      0.73         5
#
#     accuracy                           0.86        22
#    macro avg       0.80      0.84      0.82        22
# weighted avg       0.88      0.86      0.87        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 1.2098685503005981
# Total Test Accuracy: 80.55555555555556
# Test Accuracy (NFF): 89.65517241379311
# Test Accuracy (AFF): 42.857142857142854
# Confusion Matrix:
#  [[26  3]
#  [ 4  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.90      0.88        29
#          AFF       0.50      0.43      0.46         7
#
#     accuracy                           0.81        36
#    macro avg       0.68      0.66      0.67        36
# weighted avg       0.80      0.81      0.80        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.6625420932586377
# Total Test Accuracy: 86.45320197044335
# Test Accuracy (NFF): 87.8234398782344
# Test Accuracy (AFF): 80.64516129032258
# Confusion Matrix:
#  [[577  80]
#  [ 30 125]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.88      0.91       657
#          AFF       0.61      0.81      0.69       155
#
#     accuracy                           0.86       812
#    macro avg       0.78      0.84      0.80       812
# weighted avg       0.89      0.86      0.87       812
#
#
# Average Total Test Accuracy: 88.3587279467067

# %% [markdown]
# # ResNet 50

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision.models import resnet101, ResNet101_Weights
from torchvision.models import resnet50, ResNet50_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

class CustomNet(nn.Module):
    def __init__(self, num_classes=2, freeze_percentage=0.5):
        super(CustomNet, self).__init__()

        self.features = models.resnet50(weights=ResNet50_Weights.DEFAULT)

        # Calculate the index where to split the layerszh
        total_layers = len(list(self.features.children()))
        split_idx = int(total_layers * freeze_percentage)

        # Split the layers into groups for freezing and non-freezing
        children = list(self.features.children())
        self.frozen_features = nn.Sequential(*children[:split_idx])
        self.unfrozen_features = nn.Sequential(*children[split_idx:-1])  # Exclude the last layer

        # Freeze layers in self.frozen_features
        for param in self.frozen_features.parameters():
            param.requires_grad = False

        # Define the final fully connected layer
        self.fc = nn.Linear(2048, num_classes)

    def forward(self, x):
        x = self.frozen_features(x)
        x = self.unfrozen_features(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x
    
# create net
model = CustomNet(num_classes=2)  # num_classes 2

# checkpoint
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

global_path = '/local/data1/honzh073/data/suzuki.ad.liu.se/6827e91a-2d44-4d5b-b239-8e87c0fc136f/app_server/FL_global_model.pt'

checkpoint = torch.load(global_path, map_location=device)

# print(checkpoint.keys())

# modify checkpoint keys，match model
# load model weights
state_dict = checkpoint['model']
modified_state_dict = {}
for key, value in state_dict.items():
    # modify key names，match model layers
    new_key = key.replace("model.", "")
    modified_state_dict[new_key] = value

# load weights to model
model.load_state_dict(modified_state_dict)
model = model.to(device)
model.eval()

# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(30, 20))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.03901340812444687
# Total Test Accuracy: 95.65217391304348
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[22  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        23
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.96        23
#    macro avg       0.50      0.98      0.49        23
# weighted avg       1.00      0.96      0.98        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 0.18653489649295807
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         0
#          AFF       1.00      1.00      1.00         3
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.3633090853691101
# Total Test Accuracy: 88.57142857142857
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[23  0]
#  [ 4  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      1.00      0.92        23
#          AFF       1.00      0.67      0.80        12
#
#     accuracy                           0.89        35
#    macro avg       0.93      0.83      0.86        35
# weighted avg       0.90      0.89      0.88        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.003597889095544815
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         2
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.11349115706980228
# Total Test Accuracy: 90.76923076923077
# Test Accuracy (NFF): 93.33333333333333
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[56  4]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.93      0.95        60
#          AFF       0.43      0.60      0.50         5
#
#     accuracy                           0.91        65
#    macro avg       0.70      0.77      0.72        65
# weighted avg       0.92      0.91      0.91        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.37335819005966187
# Total Test Accuracy: 87.5
# Test Accuracy (NFF): 94.44444444444444
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[34  2]
#  [ 5 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.94      0.91        36
#          AFF       0.88      0.75      0.81        20
#
#     accuracy                           0.88        56
#    macro avg       0.88      0.85      0.86        56
# weighted avg       0.88      0.88      0.87        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.016713356599211693
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.7419229745864868
# Total Test Accuracy: 83.49514563106796
# Test Accuracy (NFF): 91.25
# Test Accuracy (AFF): 56.52173913043478
# Confusion Matrix:
#  [[73  7]
#  [10 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.91      0.90        80
#          AFF       0.65      0.57      0.60        23
#
#     accuracy                           0.83       103
#    macro avg       0.76      0.74      0.75       103
# weighted avg       0.83      0.83      0.83       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.031023643910884857
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 0.2501798439770937
# Total Test Accuracy: 82.6086956521739
# Test Accuracy (NFF): 98.11320754716981
# Test Accuracy (AFF): 31.25
# Confusion Matrix:
#  [[52  1]
#  [11  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.83      0.98      0.90        53
#          AFF       0.83      0.31      0.45        16
#
#     accuracy                           0.83        69
#    macro avg       0.83      0.65      0.68        69
# weighted avg       0.83      0.83      0.79        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.22232206934131682
# Total Test Accuracy: 89.6103896103896
# Test Accuracy (NFF): 95.3125
# Test Accuracy (AFF): 61.53846153846154
# Confusion Matrix:
#  [[61  3]
#  [ 5  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.95      0.94        64
#          AFF       0.73      0.62      0.67        13
#
#     accuracy                           0.90        77
#    macro avg       0.83      0.78      0.80        77
# weighted avg       0.89      0.90      0.89        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.4082907922565937
# Total Test Accuracy: 93.16239316239316
# Test Accuracy (NFF): 92.92035398230088
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[105   8]
#  [  0   4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.93      0.96       113
#          AFF       0.33      1.00      0.50         4
#
#     accuracy                           0.93       117
#    macro avg       0.67      0.96      0.73       117
# weighted avg       0.98      0.93      0.95       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.22839133441448212
# Total Test Accuracy: 93.33333333333333
# Test Accuracy (NFF): 95.34883720930233
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[41  2]
#  [ 1  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.95      0.96        43
#          AFF       0.33      0.50      0.40         2
#
#     accuracy                           0.93        45
#    macro avg       0.65      0.73      0.68        45
# weighted avg       0.95      0.93      0.94        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.007994300685822964
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        21
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 0.016286788508296013
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.055623892694711685
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         4
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 0.5909326076507568
# Total Test Accuracy: 78.87323943661971
# Test Accuracy (NFF): 93.87755102040816
# Test Accuracy (AFF): 45.45454545454545
# Confusion Matrix:
#  [[46  3]
#  [12 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.79      0.94      0.86        49
#          AFF       0.77      0.45      0.57        22
#
#     accuracy                           0.79        71
#    macro avg       0.78      0.70      0.72        71
# weighted avg       0.79      0.79      0.77        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.10279234871268272
# Total Test Accuracy: 96.82539682539682
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 90.69767441860465
# Confusion Matrix:
#  [[83  0]
#  [ 4 39]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      1.00      0.98        83
#          AFF       1.00      0.91      0.95        43
#
#     accuracy                           0.97       126
#    macro avg       0.98      0.95      0.96       126
# weighted avg       0.97      0.97      0.97       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.3729710876941681
# Total Test Accuracy: 86.66666666666667
# Test Accuracy (NFF): 95.0
# Test Accuracy (AFF): 20.0
# Confusion Matrix:
#  [[38  2]
#  [ 4  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.95      0.93        40
#          AFF       0.33      0.20      0.25         5
#
#     accuracy                           0.87        45
#    macro avg       0.62      0.57      0.59        45
# weighted avg       0.84      0.87      0.85        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.15767189860343933
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[8 0]
#  [1 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      1.00      0.94         8
#          AFF       1.00      0.00      0.00         1
#
#     accuracy                           0.89         9
#    macro avg       0.94      0.50      0.47         9
# weighted avg       0.90      0.89      0.84         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.7400621771812439
# Total Test Accuracy: 79.83193277310924
# Test Accuracy (NFF): 91.76470588235294
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[78  7]
#  [17 17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.82      0.92      0.87        85
#          AFF       0.71      0.50      0.59        34
#
#     accuracy                           0.80       119
#    macro avg       0.76      0.71      0.73       119
# weighted avg       0.79      0.80      0.79       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 1.1285103559494019
# Total Test Accuracy: 72.16494845360825
# Test Accuracy (NFF): 92.45283018867924
# Test Accuracy (AFF): 47.72727272727273
# Confusion Matrix:
#  [[49  4]
#  [23 21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.68      0.92      0.78        53
#          AFF       0.84      0.48      0.61        44
#
#     accuracy                           0.72        97
#    macro avg       0.76      0.70      0.70        97
# weighted avg       0.75      0.72      0.70        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.0025096747558563948
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.3222445249557495
# Total Test Accuracy: 89.01098901098901
# Test Accuracy (NFF): 90.9090909090909
# Test Accuracy (AFF): 78.57142857142857
# Confusion Matrix:
#  [[70  7]
#  [ 3 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.91      0.93        77
#          AFF       0.61      0.79      0.69        14
#
#     accuracy                           0.89        91
#    macro avg       0.79      0.85      0.81        91
# weighted avg       0.91      0.89      0.90        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 0.3649309575557709
# Total Test Accuracy: 94.44444444444444
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[15  0]
#  [ 1  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      1.00      0.97        15
#          AFF       1.00      0.67      0.80         3
#
#     accuracy                           0.94        18
#    macro avg       0.97      0.83      0.88        18
# weighted avg       0.95      0.94      0.94        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.5227927565574646
# Total Test Accuracy: 88.46153846153847
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 62.5
# Confusion Matrix:
#  [[18  0]
#  [ 3  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.86      1.00      0.92        18
#          AFF       1.00      0.62      0.77         8
#
#     accuracy                           0.88        26
#    macro avg       0.93      0.81      0.85        26
# weighted avg       0.90      0.88      0.88        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.18085764348506927
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 88.23529411764706
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[15  2]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.94        17
#          AFF       0.33      1.00      0.50         1
#
#     accuracy                           0.89        18
#    macro avg       0.67      0.94      0.72        18
# weighted avg       0.96      0.89      0.91        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.2006698176264763
# Total Test Accuracy: 94.6236559139785
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 64.28571428571429
# Confusion Matrix:
#  [[79  0]
#  [ 5  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      1.00      0.97        79
#          AFF       1.00      0.64      0.78        14
#
#     accuracy                           0.95        93
#    macro avg       0.97      0.82      0.88        93
# weighted avg       0.95      0.95      0.94        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 1.7714438438415527
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 42.857142857142854
# Confusion Matrix:
#  [[9 0]
#  [4 3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.69      1.00      0.82         9
#          AFF       1.00      0.43      0.60         7
#
#     accuracy                           0.75        16
#    macro avg       0.85      0.71      0.71        16
# weighted avg       0.83      0.75      0.72        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 0.014332053251564503
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 0.2161281518638134
# Total Test Accuracy: 89.28571428571429
# Test Accuracy (NFF): 94.02985074626866
# Test Accuracy (AFF): 70.58823529411765
# Confusion Matrix:
#  [[63  4]
#  [ 5 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.94      0.93        67
#          AFF       0.75      0.71      0.73        17
#
#     accuracy                           0.89        84
#    macro avg       0.84      0.82      0.83        84
# weighted avg       0.89      0.89      0.89        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.00018840904522221535
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.4804484744866689
# Total Test Accuracy: 83.78378378378379
# Test Accuracy (NFF): 88.09523809523809
# Test Accuracy (AFF): 59.09090909090909
# Confusion Matrix:
#  [[111  15]
#  [  9  13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.88      0.90       126
#          AFF       0.46      0.59      0.52        22
#
#     accuracy                           0.84       148
#    macro avg       0.69      0.74      0.71       148
# weighted avg       0.86      0.84      0.85       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.040210552513599396
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[34]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        34
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        34
#    macro avg       1.00      1.00      1.00        34
# weighted avg       1.00      1.00      1.00        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.28207287192344666
# Total Test Accuracy: 94.11764705882354
# Test Accuracy (NFF): 92.85714285714286
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[13  1]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.93      0.96        14
#          AFF       0.75      1.00      0.86         3
#
#     accuracy                           0.94        17
#    macro avg       0.88      0.96      0.91        17
# weighted avg       0.96      0.94      0.94        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.28449415415525436
# Total Test Accuracy: 89.53488372093024
# Test Accuracy (NFF): 98.52941176470588
# Test Accuracy (AFF): 55.55555555555556
# Confusion Matrix:
#  [[67  1]
#  [ 8 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.99      0.94        68
#          AFF       0.91      0.56      0.69        18
#
#     accuracy                           0.90        86
#    macro avg       0.90      0.77      0.81        86
# weighted avg       0.90      0.90      0.89        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.30181145668029785
# Total Test Accuracy: 92.0
# Test Accuracy (NFF): 92.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[23  2]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.92      0.96        25
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.92        25
#    macro avg       0.50      0.96      0.48        25
# weighted avg       1.00      0.92      0.96        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.608731210231781
# Total Test Accuracy: 89.65517241379311
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[22  1]
#  [ 2  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.96      0.94        23
#          AFF       0.80      0.67      0.73         6
#
#     accuracy                           0.90        29
#    macro avg       0.86      0.81      0.83        29
# weighted avg       0.89      0.90      0.89        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.3698624465614557
# Total Test Accuracy: 85.33333333333333
# Test Accuracy (NFF): 91.42857142857143
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[64  6]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.91      0.92        70
#          AFF       0.00      0.00      1.00         5
#
#     accuracy                           0.85        75
#    macro avg       0.46      0.46      0.96        75
# weighted avg       0.87      0.85      0.93        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 7.390941846097121e-06
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 0.6754424571990967
# Total Test Accuracy: 86.66666666666667
# Test Accuracy (NFF): 86.66666666666667
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[13  2]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.87      0.93        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.87        15
#    macro avg       0.50      0.93      0.46        15
# weighted avg       1.00      0.87      0.93        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.1704178936779499
# Total Test Accuracy: 95.51020408163265
# Test Accuracy (NFF): 95.29411764705881
# Test Accuracy (AFF): 96.0
# Confusion Matrix:
#  [[162   8]
#  [  3  72]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.95      0.97       170
#          AFF       0.90      0.96      0.93        75
#
#     accuracy                           0.96       245
#    macro avg       0.94      0.96      0.95       245
# weighted avg       0.96      0.96      0.96       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.43189674615859985
# Total Test Accuracy: 90.3225806451613
# Test Accuracy (NFF): 92.3076923076923
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[24  2]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.92      0.94        26
#          AFF       0.67      0.80      0.73         5
#
#     accuracy                           0.90        31
#    macro avg       0.81      0.86      0.83        31
# weighted avg       0.91      0.90      0.91        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.2566763162612915
# Total Test Accuracy: 90.9090909090909
# Test Accuracy (NFF): 94.31818181818183
# Test Accuracy (AFF): 81.81818181818183
# Confusion Matrix:
#  [[83  5]
#  [ 6 27]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.94      0.94        88
#          AFF       0.84      0.82      0.83        33
#
#     accuracy                           0.91       121
#    macro avg       0.89      0.88      0.88       121
# weighted avg       0.91      0.91      0.91       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.4258575141429901
# Total Test Accuracy: 77.27272727272727
# Test Accuracy (NFF): 77.27272727272727
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[17  5]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.77      0.87        22
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.77        22
#    macro avg       0.50      0.89      0.44        22
# weighted avg       1.00      0.77      0.87        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.3052496179006994
# Total Test Accuracy: 92.85714285714286
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 65.0
# Confusion Matrix:
#  [[78  0]
#  [ 7 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      1.00      0.96        78
#          AFF       1.00      0.65      0.79        20
#
#     accuracy                           0.93        98
#    macro avg       0.96      0.82      0.87        98
# weighted avg       0.93      0.93      0.92        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.20025875885039568
# Total Test Accuracy: 91.54929577464789
# Test Accuracy (NFF): 93.75
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[60  4]
#  [ 2  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.94      0.95        64
#          AFF       0.56      0.71      0.63         7
#
#     accuracy                           0.92        71
#    macro avg       0.76      0.83      0.79        71
# weighted avg       0.93      0.92      0.92        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.5654006600379944
# Total Test Accuracy: 87.71929824561404
# Test Accuracy (NFF): 87.71929824561403
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[50  7]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.93        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.88        57
#    macro avg       0.50      0.94      0.47        57
# weighted avg       1.00      0.88      0.93        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.6741693019866943
# Total Test Accuracy: 86.40776699029126
# Test Accuracy (NFF): 98.68421052631578
# Test Accuracy (AFF): 51.85185185185185
# Confusion Matrix:
#  [[75  1]
#  [13 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.99      0.91        76
#          AFF       0.93      0.52      0.67        27
#
#     accuracy                           0.86       103
#    macro avg       0.89      0.75      0.79       103
# weighted avg       0.87      0.86      0.85       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.06782367487903684
# Total Test Accuracy: 94.9367088607595
# Test Accuracy (NFF): 95.83333333333334
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[69  3]
#  [ 1  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.96      0.97        72
#          AFF       0.67      0.86      0.75         7
#
#     accuracy                           0.95        79
#    macro avg       0.83      0.91      0.86        79
# weighted avg       0.96      0.95      0.95        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.039619941264390945
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[24  0]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        24
#          AFF       1.00      1.00      1.00         2
#
#     accuracy                           1.00        26
#    macro avg       1.00      1.00      1.00        26
# weighted avg       1.00      1.00      1.00        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 1.2035475969314575
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[3 0]
#  [3 6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.50      1.00      0.67         3
#          AFF       1.00      0.67      0.80         9
#
#     accuracy                           0.75        12
#    macro avg       0.75      0.83      0.73        12
# weighted avg       0.88      0.75      0.77        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.3031801513085763
# Total Test Accuracy: 88.80597014925372
# Test Accuracy (NFF): 95.28301886792453
# Test Accuracy (AFF): 64.28571428571429
# Confusion Matrix:
#  [[101   5]
#  [ 10  18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.95      0.93       106
#          AFF       0.78      0.64      0.71        28
#
#     accuracy                           0.89       134
#    macro avg       0.85      0.80      0.82       134
# weighted avg       0.88      0.89      0.88       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.22875546229382357
# Total Test Accuracy: 95.55555555555556
# Test Accuracy (NFF): 99.3421052631579
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[151   1]
#  [  7  21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.99      0.97       152
#          AFF       0.95      0.75      0.84        28
#
#     accuracy                           0.96       180
#    macro avg       0.96      0.87      0.91       180
# weighted avg       0.96      0.96      0.95       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.9834482073783875
# Total Test Accuracy: 72.5
# Test Accuracy (NFF): 85.18518518518519
# Test Accuracy (AFF): 46.15384615384615
# Confusion Matrix:
#  [[23  4]
#  [ 7  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.77      0.85      0.81        27
#          AFF       0.60      0.46      0.52        13
#
#     accuracy                           0.73        40
#    macro avg       0.68      0.66      0.66        40
# weighted avg       0.71      0.72      0.71        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 0.0030203477945178747
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 58:
#
# Test Loss: 0.7909970879554749
# Total Test Accuracy: 84.21052631578948
# Test Accuracy (NFF): 89.65517241379311
# Test Accuracy (AFF): 78.57142857142857
# Confusion Matrix:
#  [[26  3]
#  [ 6 22]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      0.90      0.85        29
#          AFF       0.88      0.79      0.83        28
#
#     accuracy                           0.84        57
#    macro avg       0.85      0.84      0.84        57
# weighted avg       0.85      0.84      0.84        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.15646114945411682
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.89      0.94         9
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.89         9
#    macro avg       0.50      0.94      0.47         9
# weighted avg       1.00      0.89      0.94         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.6639943420886993
# Total Test Accuracy: 83.73983739837398
# Test Accuracy (NFF): 89.0
# Test Accuracy (AFF): 60.86956521739131
# Confusion Matrix:
#  [[89 11]
#  [ 9 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.89      0.90       100
#          AFF       0.56      0.61      0.58        23
#
#     accuracy                           0.84       123
#    macro avg       0.73      0.75      0.74       123
# weighted avg       0.84      0.84      0.84       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.4725785255432129
# Total Test Accuracy: 85.71428571428571
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 58.82352941176471
# Confusion Matrix:
#  [[44  2]
#  [ 7 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.86      0.96      0.91        46
#          AFF       0.83      0.59      0.69        17
#
#     accuracy                           0.86        63
#    macro avg       0.85      0.77      0.80        63
# weighted avg       0.85      0.86      0.85        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 0.6891009211540222
# Total Test Accuracy: 86.79245283018868
# Test Accuracy (NFF): 97.5609756097561
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[40  1]
#  [ 6  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.98      0.92        41
#          AFF       0.86      0.50      0.63        12
#
#     accuracy                           0.87        53
#    macro avg       0.86      0.74      0.78        53
# weighted avg       0.87      0.87      0.85        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 0.0021672467701137066
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.07880622893571854
# Total Test Accuracy: 96.875
# Test Accuracy (NFF): 96.875
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[31  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.97      0.98        32
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.97        32
#    macro avg       0.50      0.98      0.49        32
# weighted avg       1.00      0.97      0.98        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.3247343897819519
# Total Test Accuracy: 90.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[8 0]
#  [1 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      1.00      0.94         8
#          AFF       1.00      0.50      0.67         2
#
#     accuracy                           0.90        10
#    macro avg       0.94      0.75      0.80        10
# weighted avg       0.91      0.90      0.89        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.7058225274085999
# Total Test Accuracy: 81.81818181818181
# Test Accuracy (NFF): 94.11764705882352
# Test Accuracy (AFF): 40.0
# Confusion Matrix:
#  [[16  1]
#  [ 3  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      0.94      0.89        17
#          AFF       0.67      0.40      0.50         5
#
#     accuracy                           0.82        22
#    macro avg       0.75      0.67      0.69        22
# weighted avg       0.80      0.82      0.80        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.8237146139144897
# Total Test Accuracy: 86.11111111111111
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 28.57142857142857
# Confusion Matrix:
#  [[29  0]
#  [ 5  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      1.00      0.92        29
#          AFF       1.00      0.29      0.44         7
#
#     accuracy                           0.86        36
#    macro avg       0.93      0.64      0.68        36
# weighted avg       0.88      0.86      0.83        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.5763294330010047
# Total Test Accuracy: 86.69950738916256
# Test Accuracy (NFF): 93.30289193302892
# Test Accuracy (AFF): 58.70967741935483
# Confusion Matrix:
#  [[613  44]
#  [ 64  91]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.93      0.92       657
#          AFF       0.67      0.59      0.63       155
#
#     accuracy                           0.87       812
#    macro avg       0.79      0.76      0.77       812
# weighted avg       0.86      0.87      0.86       812
#
#
# Average Total Test Accuracy: 90.43218976832975

# %% [markdown]
# # ResNet 101

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision.models import resnet101, ResNet101_Weights
from torchvision.models import resnet50, ResNet50_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

class CustomNet(nn.Module):
    def __init__(self, num_classes=2, freeze_percentage=0.5):
        super(CustomNet, self).__init__()

        self.features = models.resnet101(weights=ResNet101_Weights.DEFAULT)

        # Calculate the index where to split the layers
        total_layers = len(list(self.features.children()))
        split_idx = int(total_layers * freeze_percentage)

        # Split the layers into groups for freezing and non-freezing
        children = list(self.features.children())
        self.frozen_features = nn.Sequential(*children[:split_idx])
        self.unfrozen_features = nn.Sequential(*children[split_idx:-1])  # Exclude the last layer

        # Freeze layers in self.frozen_features
        for param in self.frozen_features.parameters():
            param.requires_grad = False

        # Define the final fully connected layer
        self.fc = nn.Linear(2048, num_classes)

    def forward(self, x):
        x = self.frozen_features(x)
        x = self.unfrozen_features(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x
    
# create net
model = CustomNet(num_classes=2)  # num_classes 2

# checkpoint
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

global_path = '/local/data1/honzh073/data/suzuki.ad.liu.se/fb2580aa-55f7-4a6d-b7d3-47343e1177d1/app_server/FL_global_model.pt'
checkpoint = torch.load(global_path, map_location=device)

# print(checkpoint.keys())

# modify checkpoint keys，match model
# load model weights
state_dict = checkpoint['model']
modified_state_dict = {}
for key, value in state_dict.items():
    # modify key names，match model layers
    new_key = key.replace("model.", "")
    modified_state_dict[new_key] = value

# load weights to model
model.load_state_dict(modified_state_dict)
model = model.to(device)
model.eval()

# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(30, 20))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.002237645909190178
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        23
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        23
#    macro avg       1.00      1.00      1.00        23
# weighted avg       1.00      1.00      1.00        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 0.0794205293059349
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         0
#          AFF       1.00      1.00      1.00         3
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.4420013427734375
# Total Test Accuracy: 82.85714285714286
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 58.333333333333336
# Confusion Matrix:
#  [[22  1]
#  [ 5  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      0.96      0.88        23
#          AFF       0.88      0.58      0.70        12
#
#     accuracy                           0.83        35
#    macro avg       0.84      0.77      0.79        35
# weighted avg       0.84      0.83      0.82        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.0013232368510216475
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         2
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.07247265457408503
# Total Test Accuracy: 96.92307692307692
# Test Accuracy (NFF): 96.66666666666667
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[58  2]
#  [ 0  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.97      0.98        60
#          AFF       0.71      1.00      0.83         5
#
#     accuracy                           0.97        65
#    macro avg       0.86      0.98      0.91        65
# weighted avg       0.98      0.97      0.97        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.35944417119026184
# Total Test Accuracy: 91.07142857142857
# Test Accuracy (NFF): 94.44444444444444
# Test Accuracy (AFF): 85.0
# Confusion Matrix:
#  [[34  2]
#  [ 3 17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.94      0.93        36
#          AFF       0.89      0.85      0.87        20
#
#     accuracy                           0.91        56
#    macro avg       0.91      0.90      0.90        56
# weighted avg       0.91      0.91      0.91        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.0025515807792544365
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.694072812795639
# Total Test Accuracy: 87.37864077669903
# Test Accuracy (NFF): 96.25
# Test Accuracy (AFF): 56.52173913043478
# Confusion Matrix:
#  [[77  3]
#  [10 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.96      0.92        80
#          AFF       0.81      0.57      0.67        23
#
#     accuracy                           0.87       103
#    macro avg       0.85      0.76      0.79       103
# weighted avg       0.87      0.87      0.87       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.0038975353818386793
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 1.308930870523909
# Total Test Accuracy: 84.05797101449275
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 31.25
# Confusion Matrix:
#  [[53  0]
#  [11  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.83      1.00      0.91        53
#          AFF       1.00      0.31      0.48        16
#
#     accuracy                           0.84        69
#    macro avg       0.91      0.66      0.69        69
# weighted avg       0.87      0.84      0.81        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.2473586851847358
# Total Test Accuracy: 90.9090909090909
# Test Accuracy (NFF): 95.3125
# Test Accuracy (AFF): 69.23076923076923
# Confusion Matrix:
#  [[61  3]
#  [ 4  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.95      0.95        64
#          AFF       0.75      0.69      0.72        13
#
#     accuracy                           0.91        77
#    macro avg       0.84      0.82      0.83        77
# weighted avg       0.91      0.91      0.91        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.33750995993614197
# Total Test Accuracy: 88.03418803418803
# Test Accuracy (NFF): 88.49557522123894
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[100  13]
#  [  1   3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.88      0.93       113
#          AFF       0.19      0.75      0.30         4
#
#     accuracy                           0.88       117
#    macro avg       0.59      0.82      0.62       117
# weighted avg       0.96      0.88      0.91       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.1858108937740326
# Total Test Accuracy: 91.11111111111111
# Test Accuracy (NFF): 93.02325581395348
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[40  3]
#  [ 1  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.93      0.95        43
#          AFF       0.25      0.50      0.33         2
#
#     accuracy                           0.91        45
#    macro avg       0.61      0.72      0.64        45
# weighted avg       0.94      0.91      0.92        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.07552722841501236
# Total Test Accuracy: 95.23809523809524
# Test Accuracy (NFF): 95.23809523809523
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[20  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.95      0.98        21
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.95        21
#    macro avg       0.50      0.98      0.49        21
# weighted avg       1.00      0.95      0.98        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 0.08739987760782242
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.039394110441207886
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         4
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 1.0113386511802673
# Total Test Accuracy: 85.91549295774648
# Test Accuracy (NFF): 95.91836734693877
# Test Accuracy (AFF): 63.63636363636363
# Confusion Matrix:
#  [[47  2]
#  [ 8 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.96      0.90        49
#          AFF       0.88      0.64      0.74        22
#
#     accuracy                           0.86        71
#    macro avg       0.86      0.80      0.82        71
# weighted avg       0.86      0.86      0.85        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.18159475922584534
# Total Test Accuracy: 95.23809523809524
# Test Accuracy (NFF): 98.79518072289156
# Test Accuracy (AFF): 88.37209302325581
# Confusion Matrix:
#  [[82  1]
#  [ 5 38]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.99      0.96        83
#          AFF       0.97      0.88      0.93        43
#
#     accuracy                           0.95       126
#    macro avg       0.96      0.94      0.95       126
# weighted avg       0.95      0.95      0.95       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.4140860140323639
# Total Test Accuracy: 93.33333333333333
# Test Accuracy (NFF): 95.0
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[38  2]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.95      0.96        40
#          AFF       0.67      0.80      0.73         5
#
#     accuracy                           0.93        45
#    macro avg       0.82      0.88      0.84        45
# weighted avg       0.94      0.93      0.94        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.08270689845085144
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[8 0]
#  [0 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         1
#
#     accuracy                           1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.7534873187541962
# Total Test Accuracy: 83.19327731092437
# Test Accuracy (NFF): 97.6470588235294
# Test Accuracy (AFF): 47.05882352941176
# Confusion Matrix:
#  [[83  2]
#  [18 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.82      0.98      0.89        85
#          AFF       0.89      0.47      0.62        34
#
#     accuracy                           0.83       119
#    macro avg       0.86      0.72      0.75       119
# weighted avg       0.84      0.83      0.81       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 0.9127324223518372
# Total Test Accuracy: 77.31958762886597
# Test Accuracy (NFF): 96.22641509433963
# Test Accuracy (AFF): 54.54545454545454
# Confusion Matrix:
#  [[51  2]
#  [20 24]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.72      0.96      0.82        53
#          AFF       0.92      0.55      0.69        44
#
#     accuracy                           0.77        97
#    macro avg       0.82      0.75      0.75        97
# weighted avg       0.81      0.77      0.76        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 6.230374128790572e-05
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.2502167671918869
# Total Test Accuracy: 91.20879120879121
# Test Accuracy (NFF): 94.8051948051948
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[73  4]
#  [ 4 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.95      0.95        77
#          AFF       0.71      0.71      0.71        14
#
#     accuracy                           0.91        91
#    macro avg       0.83      0.83      0.83        91
# weighted avg       0.91      0.91      0.91        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 0.42407673597335815
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 86.66666666666667
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[13  2]
#  [ 1  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.87      0.90        15
#          AFF       0.50      0.67      0.57         3
#
#     accuracy                           0.83        18
#    macro avg       0.71      0.77      0.73        18
# weighted avg       0.86      0.83      0.84        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.0699552670121193
# Total Test Accuracy: 96.15384615384616
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 87.5
# Confusion Matrix:
#  [[18  0]
#  [ 1  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      1.00      0.97        18
#          AFF       1.00      0.88      0.93         8
#
#     accuracy                           0.96        26
#    macro avg       0.97      0.94      0.95        26
# weighted avg       0.96      0.96      0.96        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.00913272425532341
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[17  0]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        17
#          AFF       1.00      1.00      1.00         1
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.3756222352385521
# Total Test Accuracy: 92.47311827956989
# Test Accuracy (NFF): 98.73417721518987
# Test Accuracy (AFF): 57.14285714285714
# Confusion Matrix:
#  [[78  1]
#  [ 6  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.99      0.96        79
#          AFF       0.89      0.57      0.70        14
#
#     accuracy                           0.92        93
#    macro avg       0.91      0.78      0.83        93
# weighted avg       0.92      0.92      0.92        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 0.7829203605651855
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 57.14285714285714
# Confusion Matrix:
#  [[8 1]
#  [3 4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.73      0.89      0.80         9
#          AFF       0.80      0.57      0.67         7
#
#     accuracy                           0.75        16
#    macro avg       0.76      0.73      0.73        16
# weighted avg       0.76      0.75      0.74        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 0.003263724036514759
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 1.2422083914279938
# Total Test Accuracy: 90.47619047619048
# Test Accuracy (NFF): 98.50746268656717
# Test Accuracy (AFF): 58.82352941176471
# Confusion Matrix:
#  [[66  1]
#  [ 7 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.99      0.94        67
#          AFF       0.91      0.59      0.71        17
#
#     accuracy                           0.90        84
#    macro avg       0.91      0.79      0.83        84
# weighted avg       0.91      0.90      0.90        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.001384785515256226
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.43153871099154156
# Total Test Accuracy: 90.54054054054055
# Test Accuracy (NFF): 94.44444444444444
# Test Accuracy (AFF): 68.18181818181817
# Confusion Matrix:
#  [[119   7]
#  [  7  15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.94      0.94       126
#          AFF       0.68      0.68      0.68        22
#
#     accuracy                           0.91       148
#    macro avg       0.81      0.81      0.81       148
# weighted avg       0.91      0.91      0.91       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.0342438668012619
# Total Test Accuracy: 97.05882352941177
# Test Accuracy (NFF): 97.05882352941177
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[33  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.97      0.99        34
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.97        34
#    macro avg       0.50      0.99      0.49        34
# weighted avg       1.00      0.97      0.99        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.24187326431274414
# Total Test Accuracy: 88.23529411764706
# Test Accuracy (NFF): 92.85714285714286
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[13  1]
#  [ 1  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.93      0.93        14
#          AFF       0.67      0.67      0.67         3
#
#     accuracy                           0.88        17
#    macro avg       0.80      0.80      0.80        17
# weighted avg       0.88      0.88      0.88        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.21621337719261646
# Total Test Accuracy: 91.86046511627907
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 61.111111111111114
# Confusion Matrix:
#  [[68  0]
#  [ 7 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      1.00      0.95        68
#          AFF       1.00      0.61      0.76        18
#
#     accuracy                           0.92        86
#    macro avg       0.95      0.81      0.85        86
# weighted avg       0.93      0.92      0.91        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.031191468238830566
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        25
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        25
#    macro avg       1.00      1.00      1.00        25
# weighted avg       1.00      1.00      1.00        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.45769202709198
# Total Test Accuracy: 93.10344827586206
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[23  0]
#  [ 2  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      1.00      0.96        23
#          AFF       1.00      0.67      0.80         6
#
#     accuracy                           0.93        29
#    macro avg       0.96      0.83      0.88        29
# weighted avg       0.94      0.93      0.93        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.30391674116253853
# Total Test Accuracy: 90.66666666666667
# Test Accuracy (NFF): 97.14285714285714
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[68  2]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.97      0.95        70
#          AFF       0.00      0.00      1.00         5
#
#     accuracy                           0.91        75
#    macro avg       0.47      0.49      0.98        75
# weighted avg       0.87      0.91      0.95        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 3.4092547139152884e-05
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 0.10111416131258011
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        15
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        15
#    macro avg       1.00      1.00      1.00        15
# weighted avg       1.00      1.00      1.00        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.10627780813956633
# Total Test Accuracy: 97.14285714285714
# Test Accuracy (NFF): 97.6470588235294
# Test Accuracy (AFF): 96.0
# Confusion Matrix:
#  [[166   4]
#  [  3  72]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.98      0.98       170
#          AFF       0.95      0.96      0.95        75
#
#     accuracy                           0.97       245
#    macro avg       0.96      0.97      0.97       245
# weighted avg       0.97      0.97      0.97       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.27389419078826904
# Total Test Accuracy: 87.09677419354838
# Test Accuracy (NFF): 88.46153846153845
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[23  3]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.88      0.92        26
#          AFF       0.57      0.80      0.67         5
#
#     accuracy                           0.87        31
#    macro avg       0.76      0.84      0.79        31
# weighted avg       0.90      0.87      0.88        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.287355899810791
# Total Test Accuracy: 91.73553719008264
# Test Accuracy (NFF): 94.31818181818183
# Test Accuracy (AFF): 84.84848484848484
# Confusion Matrix:
#  [[83  5]
#  [ 5 28]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.94      0.94        88
#          AFF       0.85      0.85      0.85        33
#
#     accuracy                           0.92       121
#    macro avg       0.90      0.90      0.90       121
# weighted avg       0.92      0.92      0.92       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.043961625546216965
# Total Test Accuracy: 95.45454545454545
# Test Accuracy (NFF): 95.45454545454545
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.95      0.98        22
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.95        22
#    macro avg       0.50      0.98      0.49        22
# weighted avg       1.00      0.95      0.98        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.32804450392723083
# Total Test Accuracy: 91.83673469387755
# Test Accuracy (NFF): 96.15384615384616
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[75  3]
#  [ 5 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.96      0.95        78
#          AFF       0.83      0.75      0.79        20
#
#     accuracy                           0.92        98
#    macro avg       0.89      0.86      0.87        98
# weighted avg       0.92      0.92      0.92        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.17764165997505188
# Total Test Accuracy: 95.77464788732394
# Test Accuracy (NFF): 96.875
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[62  2]
#  [ 1  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.97      0.98        64
#          AFF       0.75      0.86      0.80         7
#
#     accuracy                           0.96        71
#    macro avg       0.87      0.91      0.89        71
# weighted avg       0.96      0.96      0.96        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.39041638374328613
# Total Test Accuracy: 91.2280701754386
# Test Accuracy (NFF): 91.22807017543859
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[52  5]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.91      0.95        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.91        57
#    macro avg       0.50      0.96      0.48        57
# weighted avg       1.00      0.91      0.95        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.6251855567097664
# Total Test Accuracy: 85.4368932038835
# Test Accuracy (NFF): 97.36842105263158
# Test Accuracy (AFF): 51.85185185185185
# Confusion Matrix:
#  [[74  2]
#  [13 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.97      0.91        76
#          AFF       0.88      0.52      0.65        27
#
#     accuracy                           0.85       103
#    macro avg       0.86      0.75      0.78       103
# weighted avg       0.86      0.85      0.84       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.041084119118750095
# Total Test Accuracy: 97.46835443037975
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[72  0]
#  [ 2  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      1.00      0.99        72
#          AFF       1.00      0.71      0.83         7
#
#     accuracy                           0.97        79
#    macro avg       0.99      0.86      0.91        79
# weighted avg       0.98      0.97      0.97        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.028010394424200058
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[24  0]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        24
#          AFF       1.00      1.00      1.00         2
#
#     accuracy                           1.00        26
#    macro avg       1.00      1.00      1.00        26
# weighted avg       1.00      1.00      1.00        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 1.8118942975997925
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 55.55555555555556
# Confusion Matrix:
#  [[3 0]
#  [4 5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.43      1.00      0.60         3
#          AFF       1.00      0.56      0.71         9
#
#     accuracy                           0.67        12
#    macro avg       0.71      0.78      0.66        12
# weighted avg       0.86      0.67      0.69        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.5883805155754089
# Total Test Accuracy: 86.56716417910448
# Test Accuracy (NFF): 91.50943396226415
# Test Accuracy (AFF): 67.85714285714286
# Confusion Matrix:
#  [[97  9]
#  [ 9 19]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.92      0.92       106
#          AFF       0.68      0.68      0.68        28
#
#     accuracy                           0.87       134
#    macro avg       0.80      0.80      0.80       134
# weighted avg       0.87      0.87      0.87       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.2600219150384267
# Total Test Accuracy: 93.88888888888889
# Test Accuracy (NFF): 98.02631578947368
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[149   3]
#  [  8  20]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.98      0.96       152
#          AFF       0.87      0.71      0.78        28
#
#     accuracy                           0.94       180
#    macro avg       0.91      0.85      0.87       180
# weighted avg       0.94      0.94      0.94       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 1.0082547664642334
# Total Test Accuracy: 82.5
# Test Accuracy (NFF): 96.29629629629629
# Test Accuracy (AFF): 53.84615384615385
# Confusion Matrix:
#  [[26  1]
#  [ 6  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      0.96      0.88        27
#          AFF       0.88      0.54      0.67        13
#
#     accuracy                           0.82        40
#    macro avg       0.84      0.75      0.77        40
# weighted avg       0.83      0.82      0.81        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 0.0013824250781908631
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 58:
#
# Test Loss: 0.592215895652771
# Total Test Accuracy: 87.71929824561404
# Test Accuracy (NFF): 89.65517241379311
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[26  3]
#  [ 4 24]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.90      0.88        29
#          AFF       0.89      0.86      0.87        28
#
#     accuracy                           0.88        57
#    macro avg       0.88      0.88      0.88        57
# weighted avg       0.88      0.88      0.88        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.013070176355540752
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.5875554978847504
# Total Test Accuracy: 84.55284552845528
# Test Accuracy (NFF): 90.0
# Test Accuracy (AFF): 60.86956521739131
# Confusion Matrix:
#  [[90 10]
#  [ 9 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.90      0.90       100
#          AFF       0.58      0.61      0.60        23
#
#     accuracy                           0.85       123
#    macro avg       0.75      0.75      0.75       123
# weighted avg       0.85      0.85      0.85       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.7802492380142212
# Total Test Accuracy: 80.95238095238095
# Test Accuracy (NFF): 93.47826086956522
# Test Accuracy (AFF): 47.05882352941176
# Confusion Matrix:
#  [[43  3]
#  [ 9  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.83      0.93      0.88        46
#          AFF       0.73      0.47      0.57        17
#
#     accuracy                           0.81        63
#    macro avg       0.78      0.70      0.72        63
# weighted avg       0.80      0.81      0.79        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 0.523784339427948
# Total Test Accuracy: 90.56603773584905
# Test Accuracy (NFF): 97.5609756097561
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[40  1]
#  [ 4  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.98      0.94        41
#          AFF       0.89      0.67      0.76        12
#
#     accuracy                           0.91        53
#    macro avg       0.90      0.82      0.85        53
# weighted avg       0.90      0.91      0.90        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 0.02168172597885132
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.03804567828774452
# Total Test Accuracy: 96.875
# Test Accuracy (NFF): 96.875
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[31  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.97      0.98        32
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.97        32
#    macro avg       0.50      0.98      0.49        32
# weighted avg       1.00      0.97      0.98        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.4033671021461487
# Total Test Accuracy: 90.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[8 0]
#  [1 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      1.00      0.94         8
#          AFF       1.00      0.50      0.67         2
#
#     accuracy                           0.90        10
#    macro avg       0.94      0.75      0.80        10
# weighted avg       0.91      0.90      0.89        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.6778848171234131
# Total Test Accuracy: 81.81818181818181
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 20.0
# Confusion Matrix:
#  [[17  0]
#  [ 4  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      1.00      0.89        17
#          AFF       1.00      0.20      0.33         5
#
#     accuracy                           0.82        22
#    macro avg       0.90      0.60      0.61        22
# weighted avg       0.85      0.82      0.77        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.48705577850341797
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 42.857142857142854
# Confusion Matrix:
#  [[29  0]
#  [ 4  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      1.00      0.94        29
#          AFF       1.00      0.43      0.60         7
#
#     accuracy                           0.89        36
#    macro avg       0.94      0.71      0.77        36
# weighted avg       0.90      0.89      0.87        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.44586435648111195
# Total Test Accuracy: 89.65517241379311
# Test Accuracy (NFF): 95.28158295281582
# Test Accuracy (AFF): 65.80645161290323
# Confusion Matrix:
#  [[626  31]
#  [ 53 102]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.95      0.94       657
#          AFF       0.77      0.66      0.71       155
#
#     accuracy                           0.90       812
#    macro avg       0.84      0.81      0.82       812
# weighted avg       0.89      0.90      0.89       812
#
#
# Average Total Test Accuracy: 92.18680581033118

# %% [markdown]
# # ResNet152

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision.models import resnet152, ResNet152_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

class CustomNet(nn.Module):
    def __init__(self, num_classes=2, freeze_percentage=0.5):
        super(CustomNet, self).__init__()

        self.features = models.resnet152(weights=ResNet152_Weights.DEFAULT)

        # Calculate the index where to split the layers
        total_layers = len(list(self.features.children()))
        split_idx = int(total_layers * freeze_percentage)

        # Split the layers into groups for freezing and non-freezing
        children = list(self.features.children())
        self.frozen_features = nn.Sequential(*children[:split_idx])
        self.unfrozen_features = nn.Sequential(*children[split_idx:-1])  # Exclude the last layer

        # Freeze layers in self.frozen_features
        for param in self.frozen_features.parameters():
            param.requires_grad = False

        # Define the final fully connected layer
        self.fc = nn.Linear(2048, num_classes)

    def forward(self, x):
        x = self.frozen_features(x)
        x = self.unfrozen_features(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x
    
# create net
model = CustomNet(num_classes=2)  # num_classes 2

# checkpoint
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# resnet152_freeze_Adam_200R_1E
global_path = '/local/data1/honzh073/data/suzuki.ad.liu.se/020020f4-41a7-4693-9b42-b6414b1010f8/app_server/FL_global_model.pt'
checkpoint = torch.load(global_path, map_location=device)

# print(checkpoint.keys())

# modify checkpoint keys，match model
# load model weights
state_dict = checkpoint['model']
modified_state_dict = {}
for key, value in state_dict.items():
    # modify key names，match model layers
    new_key = key.replace("model.", "")
    modified_state_dict[new_key] = value

# load weights to model
model.load_state_dict(modified_state_dict)
model = model.to(device)
model.eval()

# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(30, 20))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.04645983502268791
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        23
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        23
#    macro avg       1.00      1.00      1.00        23
# weighted avg       1.00      1.00      1.00        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 0.004364034626632929
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         0
#          AFF       1.00      1.00      1.00         3
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.46692946553230286
# Total Test Accuracy: 82.85714285714286
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 58.333333333333336
# Confusion Matrix:
#  [[22  1]
#  [ 5  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      0.96      0.88        23
#          AFF       0.88      0.58      0.70        12
#
#     accuracy                           0.83        35
#    macro avg       0.84      0.77      0.79        35
# weighted avg       0.84      0.83      0.82        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.018952390179038048
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         2
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.12132283905521035
# Total Test Accuracy: 95.38461538461539
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 40.0
# Confusion Matrix:
#  [[60  0]
#  [ 3  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      1.00      0.98        60
#          AFF       1.00      0.40      0.57         5
#
#     accuracy                           0.95        65
#    macro avg       0.98      0.70      0.77        65
# weighted avg       0.96      0.95      0.94        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.32619237899780273
# Total Test Accuracy: 94.64285714285714
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 85.0
# Confusion Matrix:
#  [[36  0]
#  [ 3 17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      1.00      0.96        36
#          AFF       1.00      0.85      0.92        20
#
#     accuracy                           0.95        56
#    macro avg       0.96      0.93      0.94        56
# weighted avg       0.95      0.95      0.95        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.12811391055583954
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.6311599612236023
# Total Test Accuracy: 87.37864077669903
# Test Accuracy (NFF): 95.0
# Test Accuracy (AFF): 60.86956521739131
# Confusion Matrix:
#  [[76  4]
#  [ 9 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.95      0.92        80
#          AFF       0.78      0.61      0.68        23
#
#     accuracy                           0.87       103
#    macro avg       0.84      0.78      0.80       103
# weighted avg       0.87      0.87      0.87       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.02878883108496666
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 1.19157674908638
# Total Test Accuracy: 79.71014492753623
# Test Accuracy (NFF): 92.45283018867924
# Test Accuracy (AFF): 37.5
# Confusion Matrix:
#  [[49  4]
#  [10  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.83      0.92      0.88        53
#          AFF       0.60      0.38      0.46        16
#
#     accuracy                           0.80        69
#    macro avg       0.72      0.65      0.67        69
# weighted avg       0.78      0.80      0.78        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.2309783821401652
# Total Test Accuracy: 92.20779220779221
# Test Accuracy (NFF): 96.875
# Test Accuracy (AFF): 69.23076923076923
# Confusion Matrix:
#  [[62  2]
#  [ 4  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.97      0.95        64
#          AFF       0.82      0.69      0.75        13
#
#     accuracy                           0.92        77
#    macro avg       0.88      0.83      0.85        77
# weighted avg       0.92      0.92      0.92        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.19124294817447662
# Total Test Accuracy: 92.3076923076923
# Test Accuracy (NFF): 92.03539823008849
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[104   9]
#  [  0   4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.92      0.96       113
#          AFF       0.31      1.00      0.47         4
#
#     accuracy                           0.92       117
#    macro avg       0.65      0.96      0.71       117
# weighted avg       0.98      0.92      0.94       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.20515145361423492
# Total Test Accuracy: 95.55555555555556
# Test Accuracy (NFF): 97.67441860465115
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[42  1]
#  [ 1  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.98      0.98        43
#          AFF       0.50      0.50      0.50         2
#
#     accuracy                           0.96        45
#    macro avg       0.74      0.74      0.74        45
# weighted avg       0.96      0.96      0.96        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.0015976415015757084
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        21
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 0.40673765540122986
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         3
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.059137243777513504
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         4
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 0.4955783262848854
# Total Test Accuracy: 81.69014084507042
# Test Accuracy (NFF): 93.87755102040816
# Test Accuracy (AFF): 54.54545454545454
# Confusion Matrix:
#  [[46  3]
#  [10 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.82      0.94      0.88        49
#          AFF       0.80      0.55      0.65        22
#
#     accuracy                           0.82        71
#    macro avg       0.81      0.74      0.76        71
# weighted avg       0.81      0.82      0.81        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.1205417588353157
# Total Test Accuracy: 96.03174603174604
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 88.37209302325581
# Confusion Matrix:
#  [[83  0]
#  [ 5 38]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      1.00      0.97        83
#          AFF       1.00      0.88      0.94        43
#
#     accuracy                           0.96       126
#    macro avg       0.97      0.94      0.95       126
# weighted avg       0.96      0.96      0.96       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.3918124735355377
# Total Test Accuracy: 91.11111111111111
# Test Accuracy (NFF): 95.0
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[38  2]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.95      0.95        40
#          AFF       0.60      0.60      0.60         5
#
#     accuracy                           0.91        45
#    macro avg       0.77      0.77      0.78        45
# weighted avg       0.91      0.91      0.91        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.9409005045890808
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[8 0]
#  [1 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      1.00      0.94         8
#          AFF       1.00      0.00      0.00         1
#
#     accuracy                           0.89         9
#    macro avg       0.94      0.50      0.47         9
# weighted avg       0.90      0.89      0.84         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.666447639465332
# Total Test Accuracy: 83.19327731092437
# Test Accuracy (NFF): 92.94117647058823
# Test Accuracy (AFF): 58.82352941176471
# Confusion Matrix:
#  [[79  6]
#  [14 20]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.93      0.89        85
#          AFF       0.77      0.59      0.67        34
#
#     accuracy                           0.83       119
#    macro avg       0.81      0.76      0.78       119
# weighted avg       0.83      0.83      0.82       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 0.936995267868042
# Total Test Accuracy: 77.31958762886597
# Test Accuracy (NFF): 92.45283018867924
# Test Accuracy (AFF): 59.09090909090909
# Confusion Matrix:
#  [[49  4]
#  [18 26]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.73      0.92      0.82        53
#          AFF       0.87      0.59      0.70        44
#
#     accuracy                           0.77        97
#    macro avg       0.80      0.76      0.76        97
# weighted avg       0.79      0.77      0.76        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.0003530808899085969
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.09377827495336533
# Total Test Accuracy: 94.50549450549451
# Test Accuracy (NFF): 96.1038961038961
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[74  3]
#  [ 2 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.96      0.97        77
#          AFF       0.80      0.86      0.83        14
#
#     accuracy                           0.95        91
#    macro avg       0.89      0.91      0.90        91
# weighted avg       0.95      0.95      0.95        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 0.6327505707740784
# Total Test Accuracy: 72.22222222222223
# Test Accuracy (NFF): 73.33333333333333
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[11  4]
#  [ 1  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.73      0.81        15
#          AFF       0.33      0.67      0.44         3
#
#     accuracy                           0.72        18
#    macro avg       0.62      0.70      0.63        18
# weighted avg       0.82      0.72      0.75        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.24420897662639618
# Total Test Accuracy: 92.3076923076923
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[18  0]
#  [ 2  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      1.00      0.95        18
#          AFF       1.00      0.75      0.86         8
#
#     accuracy                           0.92        26
#    macro avg       0.95      0.88      0.90        26
# weighted avg       0.93      0.92      0.92        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.00038939094520173967
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[17  0]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        17
#          AFF       1.00      1.00      1.00         1
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.4158046916127205
# Total Test Accuracy: 92.47311827956989
# Test Accuracy (NFF): 96.20253164556962
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[76  3]
#  [ 4 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.96      0.96        79
#          AFF       0.77      0.71      0.74        14
#
#     accuracy                           0.92        93
#    macro avg       0.86      0.84      0.85        93
# weighted avg       0.92      0.92      0.92        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 0.6237926483154297
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 42.857142857142854
# Confusion Matrix:
#  [[9 0]
#  [4 3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.69      1.00      0.82         9
#          AFF       1.00      0.43      0.60         7
#
#     accuracy                           0.75        16
#    macro avg       0.85      0.71      0.71        16
# weighted avg       0.83      0.75      0.72        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 0.005023380275815725
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 0.27904586866497993
# Total Test Accuracy: 91.66666666666667
# Test Accuracy (NFF): 92.53731343283582
# Test Accuracy (AFF): 88.23529411764706
# Confusion Matrix:
#  [[62  5]
#  [ 2 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.93      0.95        67
#          AFF       0.75      0.88      0.81        17
#
#     accuracy                           0.92        84
#    macro avg       0.86      0.90      0.88        84
# weighted avg       0.92      0.92      0.92        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.00688276207074523
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.26587240273753804
# Total Test Accuracy: 89.1891891891892
# Test Accuracy (NFF): 93.65079365079364
# Test Accuracy (AFF): 63.63636363636363
# Confusion Matrix:
#  [[118   8]
#  [  8  14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.94      0.94       126
#          AFF       0.64      0.64      0.64        22
#
#     accuracy                           0.89       148
#    macro avg       0.79      0.79      0.79       148
# weighted avg       0.89      0.89      0.89       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.005581907462328672
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[34]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        34
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        34
#    macro avg       1.00      1.00      1.00        34
# weighted avg       1.00      1.00      1.00        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.18470241129398346
# Total Test Accuracy: 94.11764705882354
# Test Accuracy (NFF): 92.85714285714286
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[13  1]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.93      0.96        14
#          AFF       0.75      1.00      0.86         3
#
#     accuracy                           0.94        17
#    macro avg       0.88      0.96      0.91        17
# weighted avg       0.96      0.94      0.94        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.29617974907159805
# Total Test Accuracy: 88.37209302325581
# Test Accuracy (NFF): 94.11764705882352
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[64  4]
#  [ 6 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.94      0.93        68
#          AFF       0.75      0.67      0.71        18
#
#     accuracy                           0.88        86
#    macro avg       0.83      0.80      0.82        86
# weighted avg       0.88      0.88      0.88        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.37980470061302185
# Total Test Accuracy: 88.0
# Test Accuracy (NFF): 88.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[22  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.94        25
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.88        25
#    macro avg       0.50      0.94      0.47        25
# weighted avg       1.00      0.88      0.94        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.20222006738185883
# Total Test Accuracy: 86.20689655172414
# Test Accuracy (NFF): 86.95652173913044
# Test Accuracy (AFF): 83.33333333333334
# Confusion Matrix:
#  [[20  3]
#  [ 1  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.87      0.91        23
#          AFF       0.62      0.83      0.71         6
#
#     accuracy                           0.86        29
#    macro avg       0.79      0.85      0.81        29
# weighted avg       0.88      0.86      0.87        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.21445030625909567
# Total Test Accuracy: 93.33333333333333
# Test Accuracy (NFF): 98.57142857142858
# Test Accuracy (AFF): 20.0
# Confusion Matrix:
#  [[69  1]
#  [ 4  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.99      0.97        70
#          AFF       0.50      0.20      0.29         5
#
#     accuracy                           0.93        75
#    macro avg       0.72      0.59      0.63        75
# weighted avg       0.92      0.93      0.92        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 1.780149068508763e-05
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 0.7330523729324341
# Total Test Accuracy: 86.66666666666667
# Test Accuracy (NFF): 86.66666666666667
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[13  2]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.87      0.93        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.87        15
#    macro avg       0.50      0.93      0.46        15
# weighted avg       1.00      0.87      0.93        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.06357722636312246
# Total Test Accuracy: 97.14285714285714
# Test Accuracy (NFF): 97.05882352941177
# Test Accuracy (AFF): 97.33333333333334
# Confusion Matrix:
#  [[165   5]
#  [  2  73]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.97      0.98       170
#          AFF       0.94      0.97      0.95        75
#
#     accuracy                           0.97       245
#    macro avg       0.96      0.97      0.97       245
# weighted avg       0.97      0.97      0.97       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.15130844712257385
# Total Test Accuracy: 96.7741935483871
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[26  0]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      1.00      0.98        26
#          AFF       1.00      0.80      0.89         5
#
#     accuracy                           0.97        31
#    macro avg       0.98      0.90      0.94        31
# weighted avg       0.97      0.97      0.97        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.20493654161691666
# Total Test Accuracy: 90.9090909090909
# Test Accuracy (NFF): 93.18181818181817
# Test Accuracy (AFF): 84.84848484848484
# Confusion Matrix:
#  [[82  6]
#  [ 5 28]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.93      0.94        88
#          AFF       0.82      0.85      0.84        33
#
#     accuracy                           0.91       121
#    macro avg       0.88      0.89      0.89       121
# weighted avg       0.91      0.91      0.91       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.02253284864127636
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[22]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        22
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        22
#    macro avg       1.00      1.00      1.00        22
# weighted avg       1.00      1.00      1.00        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.3963307738304138
# Total Test Accuracy: 89.79591836734694
# Test Accuracy (NFF): 97.43589743589743
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[76  2]
#  [ 8 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.97      0.94        78
#          AFF       0.86      0.60      0.71        20
#
#     accuracy                           0.90        98
#    macro avg       0.88      0.79      0.82        98
# weighted avg       0.90      0.90      0.89        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.24940183758735657
# Total Test Accuracy: 92.95774647887323
# Test Accuracy (NFF): 93.75
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[60  4]
#  [ 1  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.94      0.96        64
#          AFF       0.60      0.86      0.71         7
#
#     accuracy                           0.93        71
#    macro avg       0.79      0.90      0.83        71
# weighted avg       0.95      0.93      0.93        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.17862533032894135
# Total Test Accuracy: 91.2280701754386
# Test Accuracy (NFF): 91.22807017543859
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[52  5]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.91      0.95        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.91        57
#    macro avg       0.50      0.96      0.48        57
# weighted avg       1.00      0.91      0.95        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.5793255567550659
# Total Test Accuracy: 86.40776699029126
# Test Accuracy (NFF): 98.68421052631578
# Test Accuracy (AFF): 51.85185185185185
# Confusion Matrix:
#  [[75  1]
#  [13 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.99      0.91        76
#          AFF       0.93      0.52      0.67        27
#
#     accuracy                           0.86       103
#    macro avg       0.89      0.75      0.79       103
# weighted avg       0.87      0.86      0.85       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.11931295320391655
# Total Test Accuracy: 97.46835443037975
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[72  0]
#  [ 2  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      1.00      0.99        72
#          AFF       1.00      0.71      0.83         7
#
#     accuracy                           0.97        79
#    macro avg       0.99      0.86      0.91        79
# weighted avg       0.98      0.97      0.97        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.003921080380678177
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[24  0]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        24
#          AFF       1.00      1.00      1.00         2
#
#     accuracy                           1.00        26
#    macro avg       1.00      1.00      1.00        26
# weighted avg       1.00      1.00      1.00        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 1.303817868232727
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[3 0]
#  [3 6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.50      1.00      0.67         3
#          AFF       1.00      0.67      0.80         9
#
#     accuracy                           0.75        12
#    macro avg       0.75      0.83      0.73        12
# weighted avg       0.88      0.75      0.77        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.20320869899296667
# Total Test Accuracy: 91.04477611940298
# Test Accuracy (NFF): 94.33962264150944
# Test Accuracy (AFF): 78.57142857142857
# Confusion Matrix:
#  [[100   6]
#  [  6  22]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.94      0.94       106
#          AFF       0.79      0.79      0.79        28
#
#     accuracy                           0.91       134
#    macro avg       0.86      0.86      0.86       134
# weighted avg       0.91      0.91      0.91       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.27120834961533546
# Total Test Accuracy: 94.44444444444444
# Test Accuracy (NFF): 99.3421052631579
# Test Accuracy (AFF): 67.85714285714286
# Confusion Matrix:
#  [[151   1]
#  [  9  19]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.99      0.97       152
#          AFF       0.95      0.68      0.79        28
#
#     accuracy                           0.94       180
#    macro avg       0.95      0.84      0.88       180
# weighted avg       0.94      0.94      0.94       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.6759090423583984
# Total Test Accuracy: 85.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 53.84615384615385
# Confusion Matrix:
#  [[27  0]
#  [ 6  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.82      1.00      0.90        27
#          AFF       1.00      0.54      0.70        13
#
#     accuracy                           0.85        40
#    macro avg       0.91      0.77      0.80        40
# weighted avg       0.88      0.85      0.84        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 0.0004755935806315392
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 58:
#
# Test Loss: 0.4633503556251526
# Total Test Accuracy: 91.2280701754386
# Test Accuracy (NFF): 93.10344827586206
# Test Accuracy (AFF): 89.28571428571429
# Confusion Matrix:
#  [[27  2]
#  [ 3 25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.93      0.92        29
#          AFF       0.93      0.89      0.91        28
#
#     accuracy                           0.91        57
#    macro avg       0.91      0.91      0.91        57
# weighted avg       0.91      0.91      0.91        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.2226894199848175
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.89      0.94         9
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.89         9
#    macro avg       0.50      0.94      0.47         9
# weighted avg       1.00      0.89      0.94         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.6176979094743729
# Total Test Accuracy: 86.17886178861788
# Test Accuracy (NFF): 94.0
# Test Accuracy (AFF): 52.17391304347826
# Confusion Matrix:
#  [[94  6]
#  [11 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.94      0.92       100
#          AFF       0.67      0.52      0.59        23
#
#     accuracy                           0.86       123
#    macro avg       0.78      0.73      0.75       123
# weighted avg       0.85      0.86      0.86       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.35364699363708496
# Total Test Accuracy: 87.3015873015873
# Test Accuracy (NFF): 93.47826086956522
# Test Accuracy (AFF): 70.58823529411765
# Confusion Matrix:
#  [[43  3]
#  [ 5 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.93      0.91        46
#          AFF       0.80      0.71      0.75        17
#
#     accuracy                           0.87        63
#    macro avg       0.85      0.82      0.83        63
# weighted avg       0.87      0.87      0.87        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 0.7988547086715698
# Total Test Accuracy: 84.90566037735849
# Test Accuracy (NFF): 90.2439024390244
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[37  4]
#  [ 4  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.90      0.90        41
#          AFF       0.67      0.67      0.67        12
#
#     accuracy                           0.85        53
#    macro avg       0.78      0.78      0.78        53
# weighted avg       0.85      0.85      0.85        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 0.1832195669412613
# Total Test Accuracy: 87.5
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[7 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.93         8
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.88         8
#    macro avg       0.50      0.94      0.47         8
# weighted avg       1.00      0.88      0.93         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.019367337226867676
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[32]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        32
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        32
#    macro avg       1.00      1.00      1.00        32
# weighted avg       1.00      1.00      1.00        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.08677436411380768
# Total Test Accuracy: 90.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[8 0]
#  [1 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      1.00      0.94         8
#          AFF       1.00      0.50      0.67         2
#
#     accuracy                           0.90        10
#    macro avg       0.94      0.75      0.80        10
# weighted avg       0.91      0.90      0.89        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.703241765499115
# Total Test Accuracy: 81.81818181818181
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 20.0
# Confusion Matrix:
#  [[17  0]
#  [ 4  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      1.00      0.89        17
#          AFF       1.00      0.20      0.33         5
#
#     accuracy                           0.82        22
#    macro avg       0.90      0.60      0.61        22
# weighted avg       0.85      0.82      0.77        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.5931569337844849
# Total Test Accuracy: 86.11111111111111
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 28.57142857142857
# Confusion Matrix:
#  [[29  0]
#  [ 5  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      1.00      0.92        29
#          AFF       1.00      0.29      0.44         7
#
#     accuracy                           0.86        36
#    macro avg       0.93      0.64      0.68        36
# weighted avg       0.88      0.86      0.83        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.38252251853163427
# Total Test Accuracy: 89.77832512315271
# Test Accuracy (NFF): 94.52054794520548
# Test Accuracy (AFF): 69.6774193548387
# Confusion Matrix:
#  [[621  36]
#  [ 47 108]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.95      0.94       657
#          AFF       0.75      0.70      0.72       155
#
#     accuracy                           0.90       812
#    macro avg       0.84      0.82      0.83       812
# weighted avg       0.90      0.90      0.90       812
#
#
# Average Total Test Accuracy: 91.20732514386049

# %% [markdown]
# # DenseNet 161

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision.models import densenet161, DenseNet161_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

class CustomNet(nn.Module):
    def __init__(self, num_classes=2, freeze_percentage=0.5):
        super(CustomNet, self).__init__()

        self.features = models.densenet161(weights=DenseNet161_Weights.DEFAULT)

        # Calculate the index where to split the layers
        total_layers = len(list(self.features.children()))
        split_idx = int(total_layers * freeze_percentage)

        # Split the layers into groups for freezing and non-freezing
        children = list(self.features.children())
        self.frozen_features = nn.Sequential(*children[:split_idx])
        self.unfrozen_features = nn.Sequential(*children[split_idx:-1])  # Exclude the last layer

        # Freeze layers in self.frozen_features
        for param in self.frozen_features.parameters():
            param.requires_grad = False

        # Define the final fully connected layer
        self.fc = nn.Linear(2208, num_classes)  # DenseNet-161 has 2208 output features

    def forward(self, x):
        x = self.frozen_features(x)
        x = self.unfrozen_features(x)
        x = nn.functional.adaptive_avg_pool2d(x, (1, 1))  # Global average pooling
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x


# create net
model = CustomNet(num_classes=2)  # num_classes 2

# checkpoint
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# resnet101_freeze_Adam_200R_1E
global_path = '/local/data1/honzh073/data/suzuki.ad.liu.se/ae454dfc-4e4e-4197-bbfd-484aa1a83b87/app_server/FL_global_model.pt'

checkpoint = torch.load(global_path, map_location=device)

# print(checkpoint.keys())

# modify checkpoint keys，match model
# load model weights
state_dict = checkpoint['model']
modified_state_dict = {}
for key, value in state_dict.items():
    # modify key names，match model layers
    new_key = key.replace("model.", "")
    modified_state_dict[new_key] = value

# load weights to model
model.load_state_dict(modified_state_dict)
model = model.to(device)
model.eval()


# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(30, 20))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.20350635051727295
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        23
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        23
#    macro avg       1.00      1.00      1.00        23
# weighted avg       1.00      1.00      1.00        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 0.7849733829498291
# Total Test Accuracy: 33.333333333333336
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 33.33333333333333
# Confusion Matrix:
#  [[0 0]
#  [2 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.00      1.00      0.00         0
#          AFF       1.00      0.33      0.50         3
#
#     accuracy                           0.33         3
#    macro avg       0.50      0.67      0.25         3
# weighted avg       1.00      0.33      0.50         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.7374448776245117
# Total Test Accuracy: 68.57142857142857
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 8.333333333333332
# Confusion Matrix:
#  [[23  0]
#  [11  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.68      1.00      0.81        23
#          AFF       1.00      0.08      0.15        12
#
#     accuracy                           0.69        35
#    macro avg       0.84      0.54      0.48        35
# weighted avg       0.79      0.69      0.58        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.08018720149993896
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         2
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.19801659882068634
# Total Test Accuracy: 92.3076923076923
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[60  0]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      1.00      0.96        60
#          AFF       1.00      0.00      0.00         5
#
#     accuracy                           0.92        65
#    macro avg       0.96      0.50      0.48        65
# weighted avg       0.93      0.92      0.89        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.5477122664451599
# Total Test Accuracy: 73.21428571428571
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 25.0
# Confusion Matrix:
#  [[36  0]
#  [15  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.71      1.00      0.83        36
#          AFF       1.00      0.25      0.40        20
#
#     accuracy                           0.73        56
#    macro avg       0.85      0.62      0.61        56
# weighted avg       0.81      0.73      0.67        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.26334813237190247
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.5027186423540115
# Total Test Accuracy: 81.55339805825243
# Test Accuracy (NFF): 98.75
# Test Accuracy (AFF): 21.73913043478261
# Confusion Matrix:
#  [[79  1]
#  [18  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      0.99      0.89        80
#          AFF       0.83      0.22      0.34        23
#
#     accuracy                           0.82       103
#    macro avg       0.82      0.60      0.62       103
# weighted avg       0.82      0.82      0.77       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.36010217666625977
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6 3]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         9
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         9
#    macro avg       0.50      0.83      0.40         9
# weighted avg       1.00      0.67      0.80         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 0.41767939925193787
# Total Test Accuracy: 78.26086956521739
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 6.25
# Confusion Matrix:
#  [[53  0]
#  [15  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.78      1.00      0.88        53
#          AFF       1.00      0.06      0.12        16
#
#     accuracy                           0.78        69
#    macro avg       0.89      0.53      0.50        69
# weighted avg       0.83      0.78      0.70        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.26135773956775665
# Total Test Accuracy: 84.41558441558442
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 7.6923076923076925
# Confusion Matrix:
#  [[64  0]
#  [12  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      1.00      0.91        64
#          AFF       1.00      0.08      0.14        13
#
#     accuracy                           0.84        77
#    macro avg       0.92      0.54      0.53        77
# weighted avg       0.87      0.84      0.78        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.283537819981575
# Total Test Accuracy: 94.87179487179488
# Test Accuracy (NFF): 97.34513274336283
# Test Accuracy (AFF): 25.0
# Confusion Matrix:
#  [[110   3]
#  [  3   1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.97      0.97       113
#          AFF       0.25      0.25      0.25         4
#
#     accuracy                           0.95       117
#    macro avg       0.61      0.61      0.61       117
# weighted avg       0.95      0.95      0.95       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.25944167375564575
# Total Test Accuracy: 93.33333333333333
# Test Accuracy (NFF): 97.67441860465115
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[42  1]
#  [ 2  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.98      0.97        43
#          AFF       0.00      0.00      1.00         2
#
#     accuracy                           0.93        45
#    macro avg       0.48      0.49      0.98        45
# weighted avg       0.91      0.93      0.97        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.15649913251399994
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        21
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 0.5387488007545471
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         3
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.2854486107826233
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         4
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 0.4384927600622177
# Total Test Accuracy: 73.2394366197183
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 13.636363636363635
# Confusion Matrix:
#  [[49  0]
#  [19  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.72      1.00      0.84        49
#          AFF       1.00      0.14      0.24        22
#
#     accuracy                           0.73        71
#    macro avg       0.86      0.57      0.54        71
# weighted avg       0.81      0.73      0.65        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.6124575138092041
# Total Test Accuracy: 68.25396825396825
# Test Accuracy (NFF): 96.3855421686747
# Test Accuracy (AFF): 13.953488372093023
# Confusion Matrix:
#  [[80  3]
#  [37  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.68      0.96      0.80        83
#          AFF       0.67      0.14      0.23        43
#
#     accuracy                           0.68       126
#    macro avg       0.68      0.55      0.52       126
# weighted avg       0.68      0.68      0.61       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.38777250051498413
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[40  0]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      1.00      0.94        40
#          AFF       1.00      0.00      0.00         5
#
#     accuracy                           0.89        45
#    macro avg       0.94      0.50      0.47        45
# weighted avg       0.90      0.89      0.84        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.2917846143245697
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[8 0]
#  [1 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      1.00      0.94         8
#          AFF       1.00      0.00      0.00         1
#
#     accuracy                           0.89         9
#    macro avg       0.94      0.50      0.47         9
# weighted avg       0.90      0.89      0.84         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.5406344830989838
# Total Test Accuracy: 74.78991596638656
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 11.76470588235294
# Confusion Matrix:
#  [[85  0]
#  [30  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.74      1.00      0.85        85
#          AFF       1.00      0.12      0.21        34
#
#     accuracy                           0.75       119
#    macro avg       0.87      0.56      0.53       119
# weighted avg       0.81      0.75      0.67       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 0.771591991186142
# Total Test Accuracy: 57.7319587628866
# Test Accuracy (NFF): 98.11320754716981
# Test Accuracy (AFF): 9.090909090909092
# Confusion Matrix:
#  [[52  1]
#  [40  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.57      0.98      0.72        53
#          AFF       0.80      0.09      0.16        44
#
#     accuracy                           0.58        97
#    macro avg       0.68      0.54      0.44        97
# weighted avg       0.67      0.58      0.47        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.17920152842998505
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.35301515460014343
# Total Test Accuracy: 84.61538461538461
# Test Accuracy (NFF): 96.1038961038961
# Test Accuracy (AFF): 21.428571428571427
# Confusion Matrix:
#  [[74  3]
#  [11  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.96      0.91        77
#          AFF       0.50      0.21      0.30        14
#
#     accuracy                           0.85        91
#    macro avg       0.69      0.59      0.61        91
# weighted avg       0.81      0.85      0.82        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 0.7071008682250977
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 80.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[12  3]
#  [ 3  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.80      0.80      0.80        15
#          AFF       0.00      0.00      1.00         3
#
#     accuracy                           0.67        18
#    macro avg       0.40      0.40      0.90        18
# weighted avg       0.67      0.67      0.83        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.4417215585708618
# Total Test Accuracy: 80.76923076923077
# Test Accuracy (NFF): 94.44444444444444
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[17  1]
#  [ 4  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      0.94      0.87        18
#          AFF       0.80      0.50      0.62         8
#
#     accuracy                           0.81        26
#    macro avg       0.80      0.72      0.74        26
# weighted avg       0.81      0.81      0.79        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.24778622388839722
# Total Test Accuracy: 94.44444444444444
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[17  0]
#  [ 1  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      1.00      0.97        17
#          AFF       1.00      0.00      0.00         1
#
#     accuracy                           0.94        18
#    macro avg       0.97      0.50      0.49        18
# weighted avg       0.95      0.94      0.92        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.3967680186033249
# Total Test Accuracy: 88.17204301075269
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 21.428571428571427
# Confusion Matrix:
#  [[79  0]
#  [11  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      1.00      0.93        79
#          AFF       1.00      0.21      0.35        14
#
#     accuracy                           0.88        93
#    macro avg       0.94      0.61      0.64        93
# weighted avg       0.90      0.88      0.85        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 0.4932616353034973
# Total Test Accuracy: 68.75
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 28.57142857142857
# Confusion Matrix:
#  [[9 0]
#  [5 2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.64      1.00      0.78         9
#          AFF       1.00      0.29      0.44         7
#
#     accuracy                           0.69        16
#    macro avg       0.82      0.64      0.61        16
# weighted avg       0.80      0.69      0.63        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 0.21034306287765503
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 0.4674837440252304
# Total Test Accuracy: 78.57142857142857
# Test Accuracy (NFF): 97.01492537313433
# Test Accuracy (AFF): 5.88235294117647
# Confusion Matrix:
#  [[65  2]
#  [16  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.80      0.97      0.88        67
#          AFF       0.33      0.06      0.10        17
#
#     accuracy                           0.79        84
#    macro avg       0.57      0.51      0.49        84
# weighted avg       0.71      0.79      0.72        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.2110179215669632
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.38490108648935956
# Total Test Accuracy: 85.8108108108108
# Test Accuracy (NFF): 97.61904761904762
# Test Accuracy (AFF): 18.181818181818183
# Confusion Matrix:
#  [[123   3]
#  [ 18   4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.98      0.92       126
#          AFF       0.57      0.18      0.28        22
#
#     accuracy                           0.86       148
#    macro avg       0.72      0.58      0.60       148
# weighted avg       0.83      0.86      0.83       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.23420517146587372
# Total Test Accuracy: 94.11764705882354
# Test Accuracy (NFF): 94.11764705882352
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[32  2]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.94      0.97        34
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.94        34
#    macro avg       0.50      0.97      0.48        34
# weighted avg       1.00      0.94      0.97        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.5313677787780762
# Total Test Accuracy: 82.3529411764706
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[14  0]
#  [ 3  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.82      1.00      0.90        14
#          AFF       1.00      0.00      0.00         3
#
#     accuracy                           0.82        17
#    macro avg       0.91      0.50      0.45        17
# weighted avg       0.85      0.82      0.74        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.36228248476982117
# Total Test Accuracy: 80.23255813953489
# Test Accuracy (NFF): 98.52941176470588
# Test Accuracy (AFF): 11.11111111111111
# Confusion Matrix:
#  [[67  1]
#  [16  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      0.99      0.89        68
#          AFF       0.67      0.11      0.19        18
#
#     accuracy                           0.80        86
#    macro avg       0.74      0.55      0.54        86
# weighted avg       0.78      0.80      0.74        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.2723703682422638
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        25
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        25
#    macro avg       1.00      1.00      1.00        25
# weighted avg       1.00      1.00      1.00        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.40217912197113037
# Total Test Accuracy: 82.75862068965517
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 16.666666666666664
# Confusion Matrix:
#  [[23  0]
#  [ 5  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.82      1.00      0.90        23
#          AFF       1.00      0.17      0.29         6
#
#     accuracy                           0.83        29
#    macro avg       0.91      0.58      0.59        29
# weighted avg       0.86      0.83      0.77        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.27119045704603195
# Total Test Accuracy: 92.0
# Test Accuracy (NFF): 98.57142857142858
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[69  1]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.99      0.96        70
#          AFF       0.00      0.00      1.00         5
#
#     accuracy                           0.92        75
#    macro avg       0.47      0.49      0.98        75
# weighted avg       0.87      0.92      0.96        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 0.11903206259012222
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 0.40890997648239136
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 80.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[12  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.80      0.89        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.80        15
#    macro avg       0.50      0.90      0.44        15
# weighted avg       1.00      0.80      0.89        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.4415067434310913
# Total Test Accuracy: 76.73469387755102
# Test Accuracy (NFF): 96.47058823529412
# Test Accuracy (AFF): 32.0
# Confusion Matrix:
#  [[164   6]
#  [ 51  24]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.76      0.96      0.85       170
#          AFF       0.80      0.32      0.46        75
#
#     accuracy                           0.77       245
#    macro avg       0.78      0.64      0.65       245
# weighted avg       0.77      0.77      0.73       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.31729018688201904
# Total Test Accuracy: 87.09677419354838
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 20.0
# Confusion Matrix:
#  [[26  0]
#  [ 4  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      1.00      0.93        26
#          AFF       1.00      0.20      0.33         5
#
#     accuracy                           0.87        31
#    macro avg       0.93      0.60      0.63        31
# weighted avg       0.89      0.87      0.83        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.5094309747219086
# Total Test Accuracy: 75.20661157024793
# Test Accuracy (NFF): 96.5909090909091
# Test Accuracy (AFF): 18.181818181818183
# Confusion Matrix:
#  [[85  3]
#  [27  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.76      0.97      0.85        88
#          AFF       0.67      0.18      0.29        33
#
#     accuracy                           0.75       121
#    macro avg       0.71      0.57      0.57       121
# weighted avg       0.73      0.75      0.70       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.25939151644706726
# Total Test Accuracy: 95.45454545454545
# Test Accuracy (NFF): 95.45454545454545
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.95      0.98        22
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.95        22
#    macro avg       0.50      0.98      0.49        22
# weighted avg       1.00      0.95      0.98        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.3655809387564659
# Total Test Accuracy: 82.65306122448979
# Test Accuracy (NFF): 97.43589743589743
# Test Accuracy (AFF): 25.0
# Confusion Matrix:
#  [[76  2]
#  [15  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      0.97      0.90        78
#          AFF       0.71      0.25      0.37        20
#
#     accuracy                           0.83        98
#    macro avg       0.77      0.61      0.63        98
# weighted avg       0.81      0.83      0.79        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.3304474800825119
# Total Test Accuracy: 92.95774647887323
# Test Accuracy (NFF): 98.4375
# Test Accuracy (AFF): 42.857142857142854
# Confusion Matrix:
#  [[63  1]
#  [ 4  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.98      0.96        64
#          AFF       0.75      0.43      0.55         7
#
#     accuracy                           0.93        71
#    macro avg       0.85      0.71      0.75        71
# weighted avg       0.92      0.93      0.92        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.24730873107910156
# Total Test Accuracy: 96.49122807017544
# Test Accuracy (NFF): 96.49122807017544
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[55  2]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.96        57
#    macro avg       0.50      0.98      0.49        57
# weighted avg       1.00      0.96      0.98        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.5283411741256714
# Total Test Accuracy: 77.66990291262135
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 14.814814814814813
# Confusion Matrix:
#  [[76  0]
#  [23  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.77      1.00      0.87        76
#          AFF       1.00      0.15      0.26        27
#
#     accuracy                           0.78       103
#    macro avg       0.88      0.57      0.56       103
# weighted avg       0.83      0.78      0.71       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.28011883795261383
# Total Test Accuracy: 91.13924050632912
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[72  0]
#  [ 7  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      1.00      0.95        72
#          AFF       1.00      0.00      0.00         7
#
#     accuracy                           0.91        79
#    macro avg       0.96      0.50      0.48        79
# weighted avg       0.92      0.91      0.87        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.22206911444664001
# Total Test Accuracy: 92.3076923076923
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[24  0]
#  [ 2  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      1.00      0.96        24
#          AFF       1.00      0.00      0.00         2
#
#     accuracy                           0.92        26
#    macro avg       0.96      0.50      0.48        26
# weighted avg       0.93      0.92      0.89        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 1.007138729095459
# Total Test Accuracy: 41.666666666666664
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 22.22222222222222
# Confusion Matrix:
#  [[3 0]
#  [7 2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.30      1.00      0.46         3
#          AFF       1.00      0.22      0.36         9
#
#     accuracy                           0.42        12
#    macro avg       0.65      0.61      0.41        12
# weighted avg       0.83      0.42      0.39        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.35333440204461414
# Total Test Accuracy: 80.59701492537313
# Test Accuracy (NFF): 99.05660377358491
# Test Accuracy (AFF): 10.714285714285714
# Confusion Matrix:
#  [[105   1]
#  [ 25   3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      0.99      0.89       106
#          AFF       0.75      0.11      0.19        28
#
#     accuracy                           0.81       134
#    macro avg       0.78      0.55      0.54       134
# weighted avg       0.80      0.81      0.74       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.4233277440071106
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 98.02631578947368
# Test Accuracy (AFF): 3.571428571428571
# Confusion Matrix:
#  [[149   3]
#  [ 27   1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.98      0.91       152
#          AFF       0.25      0.04      0.06        28
#
#     accuracy                           0.83       180
#    macro avg       0.55      0.51      0.49       180
# weighted avg       0.75      0.83      0.78       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.5624874830245972
# Total Test Accuracy: 70.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 7.6923076923076925
# Confusion Matrix:
#  [[27  0]
#  [12  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.69      1.00      0.82        27
#          AFF       1.00      0.08      0.14        13
#
#     accuracy                           0.70        40
#    macro avg       0.85      0.54      0.48        40
# weighted avg       0.79      0.70      0.60        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 0.1517602801322937
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 58:
#
# Test Loss: 0.722344696521759
# Total Test Accuracy: 56.14035087719298
# Test Accuracy (NFF): 96.55172413793103
# Test Accuracy (AFF): 14.285714285714285
# Confusion Matrix:
#  [[28  1]
#  [24  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.54      0.97      0.69        29
#          AFF       0.80      0.14      0.24        28
#
#     accuracy                           0.56        57
#    macro avg       0.67      0.55      0.47        57
# weighted avg       0.67      0.56      0.47        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.15311436355113983
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.4610631912946701
# Total Test Accuracy: 79.67479674796748
# Test Accuracy (NFF): 97.0
# Test Accuracy (AFF): 4.3478260869565215
# Confusion Matrix:
#  [[97  3]
#  [22  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.82      0.97      0.89       100
#          AFF       0.25      0.04      0.07        23
#
#     accuracy                           0.80       123
#    macro avg       0.53      0.51      0.48       123
# weighted avg       0.71      0.80      0.73       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.48645517230033875
# Total Test Accuracy: 77.77777777777777
# Test Accuracy (NFF): 93.47826086956522
# Test Accuracy (AFF): 35.294117647058826
# Confusion Matrix:
#  [[43  3]
#  [11  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.80      0.93      0.86        46
#          AFF       0.67      0.35      0.46        17
#
#     accuracy                           0.78        63
#    macro avg       0.73      0.64      0.66        63
# weighted avg       0.76      0.78      0.75        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 0.49706169962882996
# Total Test Accuracy: 79.24528301886792
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 8.333333333333332
# Confusion Matrix:
#  [[41  0]
#  [11  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.79      1.00      0.88        41
#          AFF       1.00      0.08      0.15        12
#
#     accuracy                           0.79        53
#    macro avg       0.89      0.54      0.52        53
# weighted avg       0.84      0.79      0.72        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 0.2604219913482666
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.190105140209198
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[32]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        32
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        32
#    macro avg       1.00      1.00      1.00        32
# weighted avg       1.00      1.00      1.00        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.4388354420661926
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[8 0]
#  [2 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.80      1.00      0.89         8
#          AFF       1.00      0.00      0.00         2
#
#     accuracy                           0.80        10
#    macro avg       0.90      0.50      0.44        10
# weighted avg       0.84      0.80      0.71        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.5330240726470947
# Total Test Accuracy: 77.27272727272727
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[17  0]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.77      1.00      0.87        17
#          AFF       1.00      0.00      0.00         5
#
#     accuracy                           0.77        22
#    macro avg       0.89      0.50      0.44        22
# weighted avg       0.82      0.77      0.67        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.46703991293907166
# Total Test Accuracy: 80.55555555555556
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[29  0]
#  [ 7  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      1.00      0.89        29
#          AFF       1.00      0.00      0.00         7
#
#     accuracy                           0.81        36
#    macro avg       0.90      0.50      0.45        36
# weighted avg       0.84      0.81      0.72        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.43764655406658465
# Total Test Accuracy: 81.4039408866995
# Test Accuracy (NFF): 98.02130898021308
# Test Accuracy (AFF): 10.967741935483872
# Confusion Matrix:
#  [[644  13]
#  [138  17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.82      0.98      0.90       657
#          AFF       0.57      0.11      0.18       155
#
#     accuracy                           0.81       812
#    macro avg       0.70      0.54      0.54       812
# weighted avg       0.77      0.81      0.76       812
#
#
# Average Total Test Accuracy: 83.57654970890194
