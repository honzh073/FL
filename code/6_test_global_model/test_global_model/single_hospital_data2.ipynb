# %% [markdown]
# # All image csv files

# %%
import os
import csv

def create_csv(image_folder, csv_file_path):
    # CSV header
    fieldnames = ['HospitalID', 'PatientID', 'ImageID', 'ImagePath', 'Label']
    
    # open the CSV file in write mode
    with open(csv_file_path, 'w', newline='') as csvfile:
        # Create a CSV writer object and write the header
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        for filename in sorted(os.listdir(image_folder)):
            # complete image file path
            image_path = os.path.join(image_folder, filename)

            # filename to extract HospitalID, PatientID, image number, and image label
            parts = filename.split('_')
            hospital_id = parts[3]
            patient_id = parts[1]
            image_number = parts[6]
            image_label = parts[4]

            # write data into the CSV file
            writer.writerow({
                'HospitalID': hospital_id,
                'PatientID': patient_id,
                'ImageID': image_number,
                'ImagePath': image_path,
                'Label': image_label
            })

    # created and saved
    print("CSV file has been created and saved to:", csv_file_path)


image_folder = "/local/data1/honzh073/data/8bit_down224"
csv_file_path = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"
create_csv(image_folder, csv_file_path)
# Out:
# CSV file has been created and saved to: /local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv

# %% [markdown]
# # Custom Dataset and test 100 times average

# %%
# Custom dataset class
import os
import csv
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn as nn
from torchvision import models
from torchvision import transforms
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_curve, roc_auc_score
import torch.nn.functional as F

# custom dataset on csv files
class CustomDataset(Dataset):
    def __init__(self, csv_file, transform=None):
        self.data = []
        self.labels = []  # Store labels separately
        self.patient_ids = []  # Store patient IDs separately
        self.hospital_ids = []  # Store hospital IDs separately
        self.transform = transform
        
        # read csv
        with open(csv_file, 'r') as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                image_path = row['ImagePath']
                label = row['Label']
                patient_id = row['PatientID']
                hospital_id = row['HospitalID']

                if label == 'NFF':
                    label = 0
                elif label == 'AFF':
                    label = 1
                else:
                    raise ValueError("Invalid label in CSV file.")
                self.data.append((image_path, label))
                self.labels.append(label)
                self.patient_ids.append(patient_id)
                self.hospital_ids.append(int(hospital_id))

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image_path, label = self.data[idx]
        image = Image.open(image_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        return image, label

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from sklearn.metrics import roc_auc_score, confusion_matrix, classification_report

def test_model(model, test_dataset, batch_size):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)
    model = model.to(device)

    model.eval()

    correct_test_nff = 0
    correct_test_aff = 0
    total_nff = 0
    total_aff = 0
    total_test = 0
    test_loss = 0

    criterion = nn.CrossEntropyLoss()

    with torch.no_grad():
        all_predictions = []
        all_labels = []
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            _, predicted = torch.max(outputs.data, 1)
            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            total_test += labels.size(0)
            total_nff += (labels == 0).sum().item()
            total_aff += (labels == 1).sum().item()
            correct_test_nff += ((predicted == labels) & (labels == 0)).sum().item()
            correct_test_aff += ((predicted == labels) & (labels == 1)).sum().item()
            test_loss += loss.item()

    # Check if total_aff is zero before performing the division
    test_accuracy_nff = 100 * (correct_test_nff / total_nff) if total_nff != 0 else 0
    test_accuracy_aff = 100 * (correct_test_aff / total_aff) if total_aff != 0 else 0
    test_accuracy_total = 100 * (correct_test_nff + correct_test_aff) / total_test
    test_loss /= len(test_loader)

    # Handle the case where there is only one class
    if len(set(all_labels)) > 1:
        auc_score = roc_auc_score(all_labels, all_predictions)
    else:
        auc_score = 0  # Default value if only one class is present

    conf_matrix = confusion_matrix(all_labels, all_predictions)

    # Directly use class labels as strings in target_names
    target_names = ['NFF', 'AFF']

    classification_rep = classification_report(all_labels, all_predictions, target_names=target_names, labels=[0, 1], zero_division=1)

    # Store metrics in a dictionary
    metrics = {
        "Test Loss": test_loss,
        "Total Test Accuracy": test_accuracy_total,
        "Test Accuracy (NFF)": test_accuracy_nff,
        "Test Accuracy (AFF)": test_accuracy_aff,
        "AUC": auc_score,
        "Confusion Matrix": conf_matrix,
        "Classification Report": classification_rep
    }
    return metrics

# %% [markdown]
# # VGG 19

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision.models import vgg19, VGG19_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

# models from job, 50% freezed
class CustomNet(nn.Module):
    def __init__(self, num_classes=2, freeze_percentage=0.5):
        super(CustomNet, self).__init__()

        # Load the pre-trained VGG19 model
        vgg19_model = models.vgg19(weights=VGG19_Weights.DEFAULT)

        # Extract features (all layers except the classifier)
        self.features = nn.Sequential(*list(vgg19_model.features.children()))

        # Calculate the index where to split the layers
        total_layers = len(list(self.features.children()))
        split_idx = int(total_layers * freeze_percentage)

        # Split the layers into groups for freezing and non-freezing
        children = list(self.features.children())
        self.frozen_features = nn.Sequential(*children[:split_idx])
        self.unfrozen_features = nn.Sequential(*children[split_idx:])

        # Freeze layers in self.frozen_features
        for param in self.frozen_features.parameters():
            param.requires_grad = False

        # Define the final fully connected layer
        in_features = vgg19_model.classifier[0].in_features
        self.classifier = nn.Linear(in_features, num_classes)  # VGG19's last feature map has 512 channels

    def forward(self, x):
        x = self.frozen_features(x)
        x = self.unfrozen_features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

# create net
model = CustomNet(num_classes=2)  # num_classes 2

# checkpoint
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# vgg19_freeze_Adam_100R_2E
global_path = '/local/data1/honzh073/data/suzuki.ad.liu.se/66b1dc57-e31e-4451-a09d-0cdc3b11f16f/app_server/FL_global_model.pt'
checkpoint = torch.load(global_path, map_location=device)

# print(checkpoint.keys())

# modify checkpoint keys，match model
# load model weights
state_dict = checkpoint['model']
modified_state_dict = {}
for key, value in state_dict.items():
    # modify key names，match model layers
    new_key = key.replace("model.", "")
    modified_state_dict[new_key] = value

# load weights to model
model.load_state_dict(modified_state_dict)
model = model.to(device)
model.eval()


# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(30, 20))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
# Out:
# Performance for Hospital 1:
#
# Test Loss: 1.476976752281189
# Total Test Accuracy: 73.91304347826087
# Test Accuracy (NFF): 73.91304347826086
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[17  6]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.74      0.85        23
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.74        23
#    macro avg       0.50      0.87      0.42        23
# weighted avg       1.00      0.74      0.85        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 6.755124559276737e-06
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         0
#          AFF       1.00      1.00      1.00         3
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 1.0037847757339478
# Total Test Accuracy: 71.42857142857143
# Test Accuracy (NFF): 73.91304347826086
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[17  6]
#  [ 4  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      0.74      0.77        23
#          AFF       0.57      0.67      0.62        12
#
#     accuracy                           0.71        35
#    macro avg       0.69      0.70      0.69        35
# weighted avg       0.73      0.71      0.72        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.0710785910487175
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         2
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 1.0107285678386688
# Total Test Accuracy: 73.84615384615384
# Test Accuracy (NFF): 73.33333333333333
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[44 16]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.73      0.84        60
#          AFF       0.20      0.80      0.32         5
#
#     accuracy                           0.74        65
#    macro avg       0.59      0.77      0.58        65
# weighted avg       0.92      0.74      0.80        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.7155327796936035
# Total Test Accuracy: 83.92857142857143
# Test Accuracy (NFF): 80.55555555555556
# Test Accuracy (AFF): 90.0
# Confusion Matrix:
#  [[29  7]
#  [ 2 18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.81      0.87        36
#          AFF       0.72      0.90      0.80        20
#
#     accuracy                           0.84        56
#    macro avg       0.83      0.85      0.83        56
# weighted avg       0.86      0.84      0.84        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.12436491996049881
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 83.33333333333334
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[5 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.83      0.91         6
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.83         6
#    macro avg       0.50      0.92      0.45         6
# weighted avg       1.00      0.83      0.91         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 1.4854519963264465
# Total Test Accuracy: 77.66990291262135
# Test Accuracy (NFF): 77.5
# Test Accuracy (AFF): 78.26086956521739
# Confusion Matrix:
#  [[62 18]
#  [ 5 18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.78      0.84        80
#          AFF       0.50      0.78      0.61        23
#
#     accuracy                           0.78       103
#    macro avg       0.71      0.78      0.73       103
# weighted avg       0.83      0.78      0.79       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.5179626941680908
# Total Test Accuracy: 77.77777777777777
# Test Accuracy (NFF): 77.77777777777779
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[7 2]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.78      0.88         9
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.78         9
#    macro avg       0.50      0.89      0.44         9
# weighted avg       1.00      0.78      0.88         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 0.9002980887889862
# Total Test Accuracy: 81.15942028985508
# Test Accuracy (NFF): 77.35849056603774
# Test Accuracy (AFF): 93.75
# Confusion Matrix:
#  [[41 12]
#  [ 1 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.77      0.86        53
#          AFF       0.56      0.94      0.70        16
#
#     accuracy                           0.81        69
#    macro avg       0.77      0.86      0.78        69
# weighted avg       0.88      0.81      0.82        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.21170171035919338
# Total Test Accuracy: 89.6103896103896
# Test Accuracy (NFF): 90.625
# Test Accuracy (AFF): 84.61538461538461
# Confusion Matrix:
#  [[58  6]
#  [ 2 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.91      0.94        64
#          AFF       0.65      0.85      0.73        13
#
#     accuracy                           0.90        77
#    macro avg       0.81      0.88      0.83        77
# weighted avg       0.91      0.90      0.90        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 1.332220435142517
# Total Test Accuracy: 78.63247863247864
# Test Accuracy (NFF): 77.87610619469027
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[88 25]
#  [ 0  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.78      0.88       113
#          AFF       0.14      1.00      0.24         4
#
#     accuracy                           0.79       117
#    macro avg       0.57      0.89      0.56       117
# weighted avg       0.97      0.79      0.85       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.874516487121582
# Total Test Accuracy: 82.22222222222223
# Test Accuracy (NFF): 81.3953488372093
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[35  8]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.81      0.90        43
#          AFF       0.20      1.00      0.33         2
#
#     accuracy                           0.82        45
#    macro avg       0.60      0.91      0.62        45
# weighted avg       0.96      0.82      0.87        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.279567152261734
# Total Test Accuracy: 85.71428571428571
# Test Accuracy (NFF): 85.71428571428571
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[18  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.86      0.92        21
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.86        21
#    macro avg       0.50      0.93      0.46        21
# weighted avg       1.00      0.86      0.92        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 0.36842402815818787
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         3
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.019365297630429268
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         4
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 1.060797393321991
# Total Test Accuracy: 81.69014084507042
# Test Accuracy (NFF): 79.59183673469387
# Test Accuracy (AFF): 86.36363636363636
# Confusion Matrix:
#  [[39 10]
#  [ 3 19]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.80      0.86        49
#          AFF       0.66      0.86      0.75        22
#
#     accuracy                           0.82        71
#    macro avg       0.79      0.83      0.80        71
# weighted avg       0.84      0.82      0.82        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.26957761961966753
# Total Test Accuracy: 97.61904761904762
# Test Accuracy (NFF): 96.3855421686747
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[80  3]
#  [ 0 43]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        83
#          AFF       0.93      1.00      0.97        43
#
#     accuracy                           0.98       126
#    macro avg       0.97      0.98      0.97       126
# weighted avg       0.98      0.98      0.98       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.3348029851913452
# Total Test Accuracy: 84.44444444444444
# Test Accuracy (NFF): 82.5
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[33  7]
#  [ 0  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.82      0.90        40
#          AFF       0.42      1.00      0.59         5
#
#     accuracy                           0.84        45
#    macro avg       0.71      0.91      0.75        45
# weighted avg       0.94      0.84      0.87        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.47717633843421936
# Total Test Accuracy: 77.77777777777777
# Test Accuracy (NFF): 75.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[6 2]
#  [0 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.75      0.86         8
#          AFF       0.33      1.00      0.50         1
#
#     accuracy                           0.78         9
#    macro avg       0.67      0.88      0.68         9
# weighted avg       0.93      0.78      0.82         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 1.551223635673523
# Total Test Accuracy: 76.47058823529412
# Test Accuracy (NFF): 71.76470588235294
# Test Accuracy (AFF): 88.23529411764706
# Confusion Matrix:
#  [[61 24]
#  [ 4 30]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.72      0.81        85
#          AFF       0.56      0.88      0.68        34
#
#     accuracy                           0.76       119
#    macro avg       0.75      0.80      0.75       119
# weighted avg       0.83      0.76      0.78       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 1.0676976144313812
# Total Test Accuracy: 80.41237113402062
# Test Accuracy (NFF): 77.35849056603774
# Test Accuracy (AFF): 84.0909090909091
# Confusion Matrix:
#  [[41 12]
#  [ 7 37]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.77      0.81        53
#          AFF       0.76      0.84      0.80        44
#
#     accuracy                           0.80        97
#    macro avg       0.80      0.81      0.80        97
# weighted avg       0.81      0.80      0.80        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.00044960982631891966
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 1.2396776974201202
# Total Test Accuracy: 82.41758241758242
# Test Accuracy (NFF): 79.22077922077922
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[61 16]
#  [ 0 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.79      0.88        77
#          AFF       0.47      1.00      0.64        14
#
#     accuracy                           0.82        91
#    macro avg       0.73      0.90      0.76        91
# weighted avg       0.92      0.82      0.85        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 2.020810842514038
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 80.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[12  3]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.80      0.89        15
#          AFF       0.50      1.00      0.67         3
#
#     accuracy                           0.83        18
#    macro avg       0.75      0.90      0.78        18
# weighted avg       0.92      0.83      0.85        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.7391229271888733
# Total Test Accuracy: 76.92307692307692
# Test Accuracy (NFF): 77.77777777777779
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[14  4]
#  [ 2  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.78      0.82        18
#          AFF       0.60      0.75      0.67         8
#
#     accuracy                           0.77        26
#    macro avg       0.74      0.76      0.75        26
# weighted avg       0.79      0.77      0.78        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.5349461436271667
# Total Test Accuracy: 94.44444444444444
# Test Accuracy (NFF): 94.11764705882352
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[16  1]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.94      0.97        17
#          AFF       0.50      1.00      0.67         1
#
#     accuracy                           0.94        18
#    macro avg       0.75      0.97      0.82        18
# weighted avg       0.97      0.94      0.95        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.8022812008857727
# Total Test Accuracy: 78.49462365591398
# Test Accuracy (NFF): 74.68354430379746
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[59 20]
#  [ 0 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.75      0.86        79
#          AFF       0.41      1.00      0.58        14
#
#     accuracy                           0.78        93
#    macro avg       0.71      0.87      0.72        93
# weighted avg       0.91      0.78      0.81        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 0.5189515948295593
# Total Test Accuracy: 68.75
# Test Accuracy (NFF): 77.77777777777779
# Test Accuracy (AFF): 57.14285714285714
# Confusion Matrix:
#  [[7 2]
#  [3 4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.70      0.78      0.74         9
#          AFF       0.67      0.57      0.62         7
#
#     accuracy                           0.69        16
#    macro avg       0.68      0.67      0.68        16
# weighted avg       0.69      0.69      0.68        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 1.6428351402282715
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4 2]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         6
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         6
#    macro avg       0.50      0.83      0.40         6
# weighted avg       1.00      0.67      0.80         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 0.37879322841763496
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 79.1044776119403
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[53 14]
#  [ 0 17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.79      0.88        67
#          AFF       0.55      1.00      0.71        17
#
#     accuracy                           0.83        84
#    macro avg       0.77      0.90      0.80        84
# weighted avg       0.91      0.83      0.85        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.0021518266294151545
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.9342062075932821
# Total Test Accuracy: 79.72972972972973
# Test Accuracy (NFF): 80.15873015873017
# Test Accuracy (AFF): 77.27272727272727
# Confusion Matrix:
#  [[101  25]
#  [  5  17]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.80      0.87       126
#          AFF       0.40      0.77      0.53        22
#
#     accuracy                           0.80       148
#    macro avg       0.68      0.79      0.70       148
# weighted avg       0.87      0.80      0.82       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.2298109382390976
# Total Test Accuracy: 85.29411764705883
# Test Accuracy (NFF): 85.29411764705883
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[29  5]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.85      0.92        34
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.85        34
#    macro avg       0.50      0.93      0.46        34
# weighted avg       1.00      0.85      0.92        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.12576481699943542
# Total Test Accuracy: 94.11764705882354
# Test Accuracy (NFF): 92.85714285714286
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[13  1]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.93      0.96        14
#          AFF       0.75      1.00      0.86         3
#
#     accuracy                           0.94        17
#    macro avg       0.88      0.96      0.91        17
# weighted avg       0.96      0.94      0.94        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 1.2360200583934784
# Total Test Accuracy: 76.74418604651163
# Test Accuracy (NFF): 75.0
# Test Accuracy (AFF): 83.33333333333334
# Confusion Matrix:
#  [[51 17]
#  [ 3 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.75      0.84        68
#          AFF       0.47      0.83      0.60        18
#
#     accuracy                           0.77        86
#    macro avg       0.71      0.79      0.72        86
# weighted avg       0.84      0.77      0.79        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 1.2138817310333252
# Total Test Accuracy: 76.0
# Test Accuracy (NFF): 76.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[19  6]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.76      0.86        25
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.76        25
#    macro avg       0.50      0.88      0.43        25
# weighted avg       1.00      0.76      0.86        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 3.0577986240386963
# Total Test Accuracy: 62.06896551724138
# Test Accuracy (NFF): 52.17391304347826
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[12 11]
#  [ 0  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.52      0.69        23
#          AFF       0.35      1.00      0.52         6
#
#     accuracy                           0.62        29
#    macro avg       0.68      0.76      0.60        29
# weighted avg       0.87      0.62      0.65        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 1.1507490277290344
# Total Test Accuracy: 76.0
# Test Accuracy (NFF): 75.71428571428571
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[53 17]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.76      0.85        70
#          AFF       0.19      0.80      0.31         5
#
#     accuracy                           0.76        75
#    macro avg       0.59      0.78      0.58        75
# weighted avg       0.93      0.76      0.82        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 3.973640616550256e-07
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 1.5932673215866089
# Total Test Accuracy: 60.0
# Test Accuracy (NFF): 60.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9 6]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.60      0.75        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.60        15
#    macro avg       0.50      0.80      0.37        15
# weighted avg       1.00      0.60      0.75        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.3012280753464438
# Total Test Accuracy: 95.51020408163265
# Test Accuracy (NFF): 94.70588235294117
# Test Accuracy (AFF): 97.33333333333334
# Confusion Matrix:
#  [[161   9]
#  [  2  73]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.95      0.97       170
#          AFF       0.89      0.97      0.93        75
#
#     accuracy                           0.96       245
#    macro avg       0.94      0.96      0.95       245
# weighted avg       0.96      0.96      0.96       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.45840945839881897
# Total Test Accuracy: 83.87096774193549
# Test Accuracy (NFF): 80.76923076923077
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[21  5]
#  [ 0  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.81      0.89        26
#          AFF       0.50      1.00      0.67         5
#
#     accuracy                           0.84        31
#    macro avg       0.75      0.90      0.78        31
# weighted avg       0.92      0.84      0.86        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.8776053339242935
# Total Test Accuracy: 77.68595041322314
# Test Accuracy (NFF): 75.0
# Test Accuracy (AFF): 84.84848484848484
# Confusion Matrix:
#  [[66 22]
#  [ 5 28]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.75      0.83        88
#          AFF       0.56      0.85      0.67        33
#
#     accuracy                           0.78       121
#    macro avg       0.74      0.80      0.75       121
# weighted avg       0.83      0.78      0.79       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.5620927214622498
# Total Test Accuracy: 81.81818181818181
# Test Accuracy (NFF): 81.81818181818183
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[18  4]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.82      0.90        22
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.82        22
#    macro avg       0.50      0.91      0.45        22
# weighted avg       1.00      0.82      0.90        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.5804000496864319
# Total Test Accuracy: 81.63265306122449
# Test Accuracy (NFF): 79.48717948717949
# Test Accuracy (AFF): 90.0
# Confusion Matrix:
#  [[62 16]
#  [ 2 18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.79      0.87        78
#          AFF       0.53      0.90      0.67        20
#
#     accuracy                           0.82        98
#    macro avg       0.75      0.85      0.77        98
# weighted avg       0.88      0.82      0.83        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.8695092797279358
# Total Test Accuracy: 80.28169014084507
# Test Accuracy (NFF): 79.6875
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[51 13]
#  [ 1  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.80      0.88        64
#          AFF       0.32      0.86      0.46         7
#
#     accuracy                           0.80        71
#    macro avg       0.65      0.83      0.67        71
# weighted avg       0.92      0.80      0.84        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 1.4358325004577637
# Total Test Accuracy: 77.19298245614036
# Test Accuracy (NFF): 77.19298245614034
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[44 13]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.77      0.87        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.77        57
#    macro avg       0.50      0.89      0.44        57
# weighted avg       1.00      0.77      0.87        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 1.2378156185150146
# Total Test Accuracy: 73.7864077669903
# Test Accuracy (NFF): 75.0
# Test Accuracy (AFF): 70.37037037037037
# Confusion Matrix:
#  [[57 19]
#  [ 8 19]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.75      0.81        76
#          AFF       0.50      0.70      0.58        27
#
#     accuracy                           0.74       103
#    macro avg       0.69      0.73      0.70       103
# weighted avg       0.78      0.74      0.75       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.5608136057853699
# Total Test Accuracy: 87.34177215189874
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[63  9]
#  [ 1  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.88      0.93        72
#          AFF       0.40      0.86      0.55         7
#
#     accuracy                           0.87        79
#    macro avg       0.69      0.87      0.74        79
# weighted avg       0.93      0.87      0.89        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.027836166322231293
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[24  0]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        24
#          AFF       1.00      1.00      1.00         2
#
#     accuracy                           1.00        26
#    macro avg       1.00      1.00      1.00        26
# weighted avg       1.00      1.00      1.00        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 0.7347643971443176
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 77.77777777777779
# Confusion Matrix:
#  [[3 0]
#  [2 7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.60      1.00      0.75         3
#          AFF       1.00      0.78      0.88         9
#
#     accuracy                           0.83        12
#    macro avg       0.80      0.89      0.81        12
# weighted avg       0.90      0.83      0.84        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.37108435419698554
# Total Test Accuracy: 88.05970149253731
# Test Accuracy (NFF): 86.79245283018868
# Test Accuracy (AFF): 92.85714285714286
# Confusion Matrix:
#  [[92 14]
#  [ 2 26]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.87      0.92       106
#          AFF       0.65      0.93      0.76        28
#
#     accuracy                           0.88       134
#    macro avg       0.81      0.90      0.84       134
# weighted avg       0.91      0.88      0.89       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.36772168676058453
# Total Test Accuracy: 92.77777777777777
# Test Accuracy (NFF): 94.73684210526315
# Test Accuracy (AFF): 82.14285714285714
# Confusion Matrix:
#  [[144   8]
#  [  5  23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.95      0.96       152
#          AFF       0.74      0.82      0.78        28
#
#     accuracy                           0.93       180
#    macro avg       0.85      0.88      0.87       180
# weighted avg       0.93      0.93      0.93       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.39798682928085327
# Total Test Accuracy: 92.5
# Test Accuracy (NFF): 92.5925925925926
# Test Accuracy (AFF): 92.3076923076923
# Confusion Matrix:
#  [[25  2]
#  [ 1 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.93      0.94        27
#          AFF       0.86      0.92      0.89        13
#
#     accuracy                           0.93        40
#    macro avg       0.91      0.92      0.92        40
# weighted avg       0.93      0.93      0.93        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 9.254535675048828
# Total Test Accuracy: 0.0
# Test Accuracy (NFF): 0.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[0 3]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.00      0.00       3.0
#          AFF       0.00      1.00      0.00       0.0
#
#     accuracy                           1.00       3.0
#    macro avg       0.50      0.50      0.00       3.0
# weighted avg       1.00      0.00      0.00       3.0
#
#
# Performance for Hospital 58:
#
# Test Loss: 1.1208062171936035
# Total Test Accuracy: 89.47368421052632
# Test Accuracy (NFF): 82.75862068965517
# Test Accuracy (AFF): 96.42857142857143
# Confusion Matrix:
#  [[24  5]
#  [ 1 27]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.83      0.89        29
#          AFF       0.84      0.96      0.90        28
#
#     accuracy                           0.89        57
#    macro avg       0.90      0.90      0.89        57
# weighted avg       0.90      0.89      0.89        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.0851539596915245
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 1.7824140191078186
# Total Test Accuracy: 78.86178861788618
# Test Accuracy (NFF): 76.0
# Test Accuracy (AFF): 91.30434782608695
# Confusion Matrix:
#  [[76 24]
#  [ 2 21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.76      0.85       100
#          AFF       0.47      0.91      0.62        23
#
#     accuracy                           0.79       123
#    macro avg       0.72      0.84      0.74       123
# weighted avg       0.88      0.79      0.81       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.928284764289856
# Total Test Accuracy: 79.36507936507937
# Test Accuracy (NFF): 76.08695652173914
# Test Accuracy (AFF): 88.23529411764706
# Confusion Matrix:
#  [[35 11]
#  [ 2 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.76      0.84        46
#          AFF       0.58      0.88      0.70        17
#
#     accuracy                           0.79        63
#    macro avg       0.76      0.82      0.77        63
# weighted avg       0.85      0.79      0.80        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 1.4729843139648438
# Total Test Accuracy: 81.13207547169812
# Test Accuracy (NFF): 80.48780487804879
# Test Accuracy (AFF): 83.33333333333334
# Confusion Matrix:
#  [[33  8]
#  [ 2 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.80      0.87        41
#          AFF       0.56      0.83      0.67        12
#
#     accuracy                           0.81        53
#    macro avg       0.75      0.82      0.77        53
# weighted avg       0.86      0.81      0.82        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 0.9071841239929199
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 75.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6 2]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.75      0.86         8
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.75         8
#    macro avg       0.50      0.88      0.43         8
# weighted avg       1.00      0.75      0.86         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.887552797794342
# Total Test Accuracy: 84.375
# Test Accuracy (NFF): 84.375
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[27  5]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.84      0.92        32
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.84        32
#    macro avg       0.50      0.92      0.46        32
# weighted avg       1.00      0.84      0.92        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.8625594973564148
# Total Test Accuracy: 70.0
# Test Accuracy (NFF): 75.0
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[6 2]
#  [1 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.86      0.75      0.80         8
#          AFF       0.33      0.50      0.40         2
#
#     accuracy                           0.70        10
#    macro avg       0.60      0.62      0.60        10
# weighted avg       0.75      0.70      0.72        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.8387128710746765
# Total Test Accuracy: 81.81818181818181
# Test Accuracy (NFF): 76.47058823529412
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[13  4]
#  [ 0  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.76      0.87        17
#          AFF       0.56      1.00      0.71         5
#
#     accuracy                           0.82        22
#    macro avg       0.78      0.88      0.79        22
# weighted avg       0.90      0.82      0.83        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.626495897769928
# Total Test Accuracy: 77.77777777777777
# Test Accuracy (NFF): 75.86206896551724
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[22  7]
#  [ 1  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.76      0.85        29
#          AFF       0.46      0.86      0.60         7
#
#     accuracy                           0.78        36
#    macro avg       0.71      0.81      0.72        36
# weighted avg       0.86      0.78      0.80        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 1.2045651296010385
# Total Test Accuracy: 80.54187192118226
# Test Accuracy (NFF): 78.53881278538812
# Test Accuracy (AFF): 89.03225806451613
# Confusion Matrix:
#  [[516 141]
#  [ 17 138]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.79      0.87       657
#          AFF       0.49      0.89      0.64       155
#
#     accuracy                           0.81       812
#    macro avg       0.73      0.84      0.75       812
# weighted avg       0.88      0.81      0.82       812
#
#
# Average Total Test Accuracy: 81.53391008341211

# %% [markdown]
# # ResNet 50

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision.models import resnet101, ResNet101_Weights
from torchvision.models import resnet50, ResNet50_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

class CustomNet(nn.Module):
    def __init__(self, num_classes=2, freeze_percentage=0.5):
        super(CustomNet, self).__init__()

        self.features = models.resnet50(weights=ResNet50_Weights.DEFAULT)

        # Calculate the index where to split the layerszh
        total_layers = len(list(self.features.children()))
        split_idx = int(total_layers * freeze_percentage)

        # Split the layers into groups for freezing and non-freezing
        children = list(self.features.children())
        self.frozen_features = nn.Sequential(*children[:split_idx])
        self.unfrozen_features = nn.Sequential(*children[split_idx:-1])  # Exclude the last layer

        # Freeze layers in self.frozen_features
        for param in self.frozen_features.parameters():
            param.requires_grad = False

        # Define the final fully connected layer
        self.fc = nn.Linear(2048, num_classes)

    def forward(self, x):
        x = self.frozen_features(x)
        x = self.unfrozen_features(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x
    
# create net
model = CustomNet(num_classes=2)  # num_classes 2

# checkpoint
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

global_path = '/local/data1/honzh073/data/suzuki.ad.liu.se/ca59fc06-2b34-4ae0-989d-3b4784d170dd/app_server/FL_global_model.pt'

checkpoint = torch.load(global_path, map_location=device)

# print(checkpoint.keys())

# modify checkpoint keys，match model
# load model weights
state_dict = checkpoint['model']
modified_state_dict = {}
for key, value in state_dict.items():
    # modify key names，match model layers
    new_key = key.replace("model.", "")
    modified_state_dict[new_key] = value

# load weights to model
model.load_state_dict(modified_state_dict)
model = model.to(device)
model.eval()

# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(30, 20))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.10642509162425995
# Total Test Accuracy: 95.65217391304348
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[22  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        23
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.96        23
#    macro avg       0.50      0.98      0.49        23
# weighted avg       1.00      0.96      0.98        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 9.615706949261948e-05
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         0
#          AFF       1.00      1.00      1.00         3
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.3885912597179413
# Total Test Accuracy: 82.85714285714286
# Test Accuracy (NFF): 91.30434782608695
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[21  2]
#  [ 4  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      0.91      0.87        23
#          AFF       0.80      0.67      0.73        12
#
#     accuracy                           0.83        35
#    macro avg       0.82      0.79      0.80        35
# weighted avg       0.83      0.83      0.82        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.005375490058213472
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         2
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.2156447626184672
# Total Test Accuracy: 86.15384615384616
# Test Accuracy (NFF): 90.0
# Test Accuracy (AFF): 40.0
# Confusion Matrix:
#  [[54  6]
#  [ 3  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.90      0.92        60
#          AFF       0.25      0.40      0.31         5
#
#     accuracy                           0.86        65
#    macro avg       0.60      0.65      0.62        65
# weighted avg       0.89      0.86      0.88        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.4975099563598633
# Total Test Accuracy: 92.85714285714286
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[36  0]
#  [ 4 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      1.00      0.95        36
#          AFF       1.00      0.80      0.89        20
#
#     accuracy                           0.93        56
#    macro avg       0.95      0.90      0.92        56
# weighted avg       0.94      0.93      0.93        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.03905816376209259
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.6273569762706757
# Total Test Accuracy: 90.29126213592232
# Test Accuracy (NFF): 93.75
# Test Accuracy (AFF): 78.26086956521739
# Confusion Matrix:
#  [[75  5]
#  [ 5 18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.94      0.94        80
#          AFF       0.78      0.78      0.78        23
#
#     accuracy                           0.90       103
#    macro avg       0.86      0.86      0.86       103
# weighted avg       0.90      0.90      0.90       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.0026337269227951765
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 0.6067679226398468
# Total Test Accuracy: 86.95652173913044
# Test Accuracy (NFF): 90.56603773584906
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[48  5]
#  [ 4 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.91      0.91        53
#          AFF       0.71      0.75      0.73        16
#
#     accuracy                           0.87        69
#    macro avg       0.81      0.83      0.82        69
# weighted avg       0.87      0.87      0.87        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.3090437261853367
# Total Test Accuracy: 89.6103896103896
# Test Accuracy (NFF): 93.75
# Test Accuracy (AFF): 69.23076923076923
# Confusion Matrix:
#  [[60  4]
#  [ 4  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.94      0.94        64
#          AFF       0.69      0.69      0.69        13
#
#     accuracy                           0.90        77
#    macro avg       0.81      0.81      0.81        77
# weighted avg       0.90      0.90      0.90        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.32356614619493484
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 88.49557522123894
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[100  13]
#  [  0   4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.94       113
#          AFF       0.24      1.00      0.38         4
#
#     accuracy                           0.89       117
#    macro avg       0.62      0.94      0.66       117
# weighted avg       0.97      0.89      0.92       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.08836090564727783
# Total Test Accuracy: 97.77777777777777
# Test Accuracy (NFF): 97.67441860465115
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[42  1]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.98      0.99        43
#          AFF       0.67      1.00      0.80         2
#
#     accuracy                           0.98        45
#    macro avg       0.83      0.99      0.89        45
# weighted avg       0.99      0.98      0.98        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.22472941875457764
# Total Test Accuracy: 95.23809523809524
# Test Accuracy (NFF): 95.23809523809523
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[20  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.95      0.98        21
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.95        21
#    macro avg       0.50      0.98      0.49        21
# weighted avg       1.00      0.95      0.98        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 0.0130046047270298
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.010387059301137924
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         4
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 0.43853944540023804
# Total Test Accuracy: 87.32394366197182
# Test Accuracy (NFF): 95.91836734693877
# Test Accuracy (AFF): 68.18181818181817
# Confusion Matrix:
#  [[47  2]
#  [ 7 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.96      0.91        49
#          AFF       0.88      0.68      0.77        22
#
#     accuracy                           0.87        71
#    macro avg       0.88      0.82      0.84        71
# weighted avg       0.87      0.87      0.87        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.13202617736533284
# Total Test Accuracy: 96.03174603174604
# Test Accuracy (NFF): 96.3855421686747
# Test Accuracy (AFF): 95.34883720930233
# Confusion Matrix:
#  [[80  3]
#  [ 2 41]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.96      0.97        83
#          AFF       0.93      0.95      0.94        43
#
#     accuracy                           0.96       126
#    macro avg       0.95      0.96      0.96       126
# weighted avg       0.96      0.96      0.96       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.2921246886253357
# Total Test Accuracy: 91.11111111111111
# Test Accuracy (NFF): 97.5
# Test Accuracy (AFF): 40.0
# Confusion Matrix:
#  [[39  1]
#  [ 3  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.97      0.95        40
#          AFF       0.67      0.40      0.50         5
#
#     accuracy                           0.91        45
#    macro avg       0.80      0.69      0.73        45
# weighted avg       0.90      0.91      0.90        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.2979191541671753
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[8 0]
#  [1 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      1.00      0.94         8
#          AFF       1.00      0.00      0.00         1
#
#     accuracy                           0.89         9
#    macro avg       0.94      0.50      0.47         9
# weighted avg       0.90      0.89      0.84         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.5966365337371826
# Total Test Accuracy: 82.3529411764706
# Test Accuracy (NFF): 85.88235294117646
# Test Accuracy (AFF): 73.52941176470588
# Confusion Matrix:
#  [[73 12]
#  [ 9 25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.86      0.87        85
#          AFF       0.68      0.74      0.70        34
#
#     accuracy                           0.82       119
#    macro avg       0.78      0.80      0.79       119
# weighted avg       0.83      0.82      0.83       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 1.0903236269950867
# Total Test Accuracy: 72.16494845360825
# Test Accuracy (NFF): 90.56603773584906
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[48  5]
#  [22 22]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.69      0.91      0.78        53
#          AFF       0.81      0.50      0.62        44
#
#     accuracy                           0.72        97
#    macro avg       0.75      0.70      0.70        97
# weighted avg       0.74      0.72      0.71        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.0006286197458393872
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.3861989974975586
# Total Test Accuracy: 93.4065934065934
# Test Accuracy (NFF): 96.1038961038961
# Test Accuracy (AFF): 78.57142857142857
# Confusion Matrix:
#  [[74  3]
#  [ 3 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.96      0.96        77
#          AFF       0.79      0.79      0.79        14
#
#     accuracy                           0.93        91
#    macro avg       0.87      0.87      0.87        91
# weighted avg       0.93      0.93      0.93        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 0.1614566147327423
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 93.33333333333333
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[14  1]
#  [ 1  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.93      0.93        15
#          AFF       0.67      0.67      0.67         3
#
#     accuracy                           0.89        18
#    macro avg       0.80      0.80      0.80        18
# weighted avg       0.89      0.89      0.89        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.15774202346801758
# Total Test Accuracy: 96.15384615384616
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 87.5
# Confusion Matrix:
#  [[18  0]
#  [ 1  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      1.00      0.97        18
#          AFF       1.00      0.88      0.93         8
#
#     accuracy                           0.96        26
#    macro avg       0.97      0.94      0.95        26
# weighted avg       0.96      0.96      0.96        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.12129542231559753
# Total Test Accuracy: 94.44444444444444
# Test Accuracy (NFF): 94.11764705882352
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[16  1]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.94      0.97        17
#          AFF       0.50      1.00      0.67         1
#
#     accuracy                           0.94        18
#    macro avg       0.75      0.97      0.82        18
# weighted avg       0.97      0.94      0.95        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.3771872818470001
# Total Test Accuracy: 90.3225806451613
# Test Accuracy (NFF): 97.46835443037975
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[77  2]
#  [ 7  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.97      0.94        79
#          AFF       0.78      0.50      0.61        14
#
#     accuracy                           0.90        93
#    macro avg       0.85      0.74      0.78        93
# weighted avg       0.90      0.90      0.89        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 0.6028003692626953
# Total Test Accuracy: 81.25
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 57.14285714285714
# Confusion Matrix:
#  [[9 0]
#  [3 4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.75      1.00      0.86         9
#          AFF       1.00      0.57      0.73         7
#
#     accuracy                           0.81        16
#    macro avg       0.88      0.79      0.79        16
# weighted avg       0.86      0.81      0.80        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 0.00045682769268751144
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 0.10043932311236858
# Total Test Accuracy: 92.85714285714286
# Test Accuracy (NFF): 94.02985074626866
# Test Accuracy (AFF): 88.23529411764706
# Confusion Matrix:
#  [[63  4]
#  [ 2 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.94      0.95        67
#          AFF       0.79      0.88      0.83        17
#
#     accuracy                           0.93        84
#    macro avg       0.88      0.91      0.89        84
# weighted avg       0.93      0.93      0.93        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 2.120131731033325
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         3
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.600764145453771
# Total Test Accuracy: 84.45945945945945
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 59.09090909090909
# Confusion Matrix:
#  [[112  14]
#  [  9  13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.89      0.91       126
#          AFF       0.48      0.59      0.53        22
#
#     accuracy                           0.84       148
#    macro avg       0.70      0.74      0.72       148
# weighted avg       0.86      0.84      0.85       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.07977157831192017
# Total Test Accuracy: 97.05882352941177
# Test Accuracy (NFF): 97.05882352941177
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[33  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.97      0.99        34
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.97        34
#    macro avg       0.50      0.99      0.49        34
# weighted avg       1.00      0.97      0.99        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.3232135474681854
# Total Test Accuracy: 94.11764705882354
# Test Accuracy (NFF): 92.85714285714286
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[13  1]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.93      0.96        14
#          AFF       0.75      1.00      0.86         3
#
#     accuracy                           0.94        17
#    macro avg       0.88      0.96      0.91        17
# weighted avg       0.96      0.94      0.94        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.42635419964790344
# Total Test Accuracy: 86.04651162790698
# Test Accuracy (NFF): 92.64705882352942
# Test Accuracy (AFF): 61.111111111111114
# Confusion Matrix:
#  [[63  5]
#  [ 7 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.93      0.91        68
#          AFF       0.69      0.61      0.65        18
#
#     accuracy                           0.86        86
#    macro avg       0.79      0.77      0.78        86
# weighted avg       0.86      0.86      0.86        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.051600381731987
# Total Test Accuracy: 96.0
# Test Accuracy (NFF): 96.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[24  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        25
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.96        25
#    macro avg       0.50      0.98      0.49        25
# weighted avg       1.00      0.96      0.98        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.36640095710754395
# Total Test Accuracy: 96.55172413793103
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 83.33333333333334
# Confusion Matrix:
#  [[23  0]
#  [ 1  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      1.00      0.98        23
#          AFF       1.00      0.83      0.91         6
#
#     accuracy                           0.97        29
#    macro avg       0.98      0.92      0.94        29
# weighted avg       0.97      0.97      0.96        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.3638181798160076
# Total Test Accuracy: 84.0
# Test Accuracy (NFF): 90.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[63  7]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.90      0.91        70
#          AFF       0.00      0.00      1.00         5
#
#     accuracy                           0.84        75
#    macro avg       0.46      0.45      0.96        75
# weighted avg       0.86      0.84      0.92        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 7.545325206592679e-05
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 0.638215184211731
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 80.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[12  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.80      0.89        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.80        15
#    macro avg       0.50      0.90      0.44        15
# weighted avg       1.00      0.80      0.89        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.1613600691780448
# Total Test Accuracy: 95.91836734693878
# Test Accuracy (NFF): 97.6470588235294
# Test Accuracy (AFF): 92.0
# Confusion Matrix:
#  [[166   4]
#  [  6  69]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.98      0.97       170
#          AFF       0.95      0.92      0.93        75
#
#     accuracy                           0.96       245
#    macro avg       0.96      0.95      0.95       245
# weighted avg       0.96      0.96      0.96       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.8300628066062927
# Total Test Accuracy: 80.64516129032258
# Test Accuracy (NFF): 84.61538461538461
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[22  4]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.85      0.88        26
#          AFF       0.43      0.60      0.50         5
#
#     accuracy                           0.81        31
#    macro avg       0.67      0.72      0.69        31
# weighted avg       0.84      0.81      0.82        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.21911828219890594
# Total Test Accuracy: 93.38842975206612
# Test Accuracy (NFF): 93.18181818181817
# Test Accuracy (AFF): 93.93939393939394
# Confusion Matrix:
#  [[82  6]
#  [ 2 31]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.93      0.95        88
#          AFF       0.84      0.94      0.89        33
#
#     accuracy                           0.93       121
#    macro avg       0.91      0.94      0.92       121
# weighted avg       0.94      0.93      0.94       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.14816562831401825
# Total Test Accuracy: 95.45454545454545
# Test Accuracy (NFF): 95.45454545454545
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.95      0.98        22
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.95        22
#    macro avg       0.50      0.98      0.49        22
# weighted avg       1.00      0.95      0.98        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.3114805668592453
# Total Test Accuracy: 91.83673469387755
# Test Accuracy (NFF): 97.43589743589743
# Test Accuracy (AFF): 70.0
# Confusion Matrix:
#  [[76  2]
#  [ 6 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.97      0.95        78
#          AFF       0.88      0.70      0.78        20
#
#     accuracy                           0.92        98
#    macro avg       0.90      0.84      0.86        98
# weighted avg       0.92      0.92      0.91        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.13939419016242027
# Total Test Accuracy: 92.95774647887323
# Test Accuracy (NFF): 93.75
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[60  4]
#  [ 1  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.94      0.96        64
#          AFF       0.60      0.86      0.71         7
#
#     accuracy                           0.93        71
#    macro avg       0.79      0.90      0.83        71
# weighted avg       0.95      0.93      0.93        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.4352601170539856
# Total Test Accuracy: 87.71929824561404
# Test Accuracy (NFF): 87.71929824561403
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[50  7]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.93        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.88        57
#    macro avg       0.50      0.94      0.47        57
# weighted avg       1.00      0.88      0.93        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.6756263971328735
# Total Test Accuracy: 85.4368932038835
# Test Accuracy (NFF): 94.73684210526315
# Test Accuracy (AFF): 59.25925925925925
# Confusion Matrix:
#  [[72  4]
#  [11 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.95      0.91        76
#          AFF       0.80      0.59      0.68        27
#
#     accuracy                           0.85       103
#    macro avg       0.83      0.77      0.79       103
# weighted avg       0.85      0.85      0.85       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.10984552092850208
# Total Test Accuracy: 96.20253164556962
# Test Accuracy (NFF): 97.22222222222221
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[70  2]
#  [ 1  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.97      0.98        72
#          AFF       0.75      0.86      0.80         7
#
#     accuracy                           0.96        79
#    macro avg       0.87      0.91      0.89        79
# weighted avg       0.97      0.96      0.96        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.028378505259752274
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[24  0]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        24
#          AFF       1.00      1.00      1.00         2
#
#     accuracy                           1.00        26
#    macro avg       1.00      1.00      1.00        26
# weighted avg       1.00      1.00      1.00        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 2.2400033473968506
# Total Test Accuracy: 58.333333333333336
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 44.44444444444444
# Confusion Matrix:
#  [[3 0]
#  [5 4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.38      1.00      0.55         3
#          AFF       1.00      0.44      0.62         9
#
#     accuracy                           0.58        12
#    macro avg       0.69      0.72      0.58        12
# weighted avg       0.84      0.58      0.60        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.29202096071094275
# Total Test Accuracy: 88.05970149253731
# Test Accuracy (NFF): 97.16981132075472
# Test Accuracy (AFF): 53.57142857142857
# Confusion Matrix:
#  [[103   3]
#  [ 13  15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.97      0.93       106
#          AFF       0.83      0.54      0.65        28
#
#     accuracy                           0.88       134
#    macro avg       0.86      0.75      0.79       134
# weighted avg       0.88      0.88      0.87       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.17867824559410414
# Total Test Accuracy: 96.11111111111111
# Test Accuracy (NFF): 99.3421052631579
# Test Accuracy (AFF): 78.57142857142857
# Confusion Matrix:
#  [[151   1]
#  [  6  22]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.99      0.98       152
#          AFF       0.96      0.79      0.86        28
#
#     accuracy                           0.96       180
#    macro avg       0.96      0.89      0.92       180
# weighted avg       0.96      0.96      0.96       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.5442813634872437
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 92.5925925925926
# Test Accuracy (AFF): 53.84615384615385
# Confusion Matrix:
#  [[25  2]
#  [ 6  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      0.93      0.86        27
#          AFF       0.78      0.54      0.64        13
#
#     accuracy                           0.80        40
#    macro avg       0.79      0.73      0.75        40
# weighted avg       0.80      0.80      0.79        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 0.0007695012609474361
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 58:
#
# Test Loss: 0.6944375038146973
# Total Test Accuracy: 85.96491228070175
# Test Accuracy (NFF): 89.65517241379311
# Test Accuracy (AFF): 82.14285714285714
# Confusion Matrix:
#  [[26  3]
#  [ 5 23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      0.90      0.87        29
#          AFF       0.88      0.82      0.85        28
#
#     accuracy                           0.86        57
#    macro avg       0.86      0.86      0.86        57
# weighted avg       0.86      0.86      0.86        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.02780827507376671
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.5619626939296722
# Total Test Accuracy: 89.4308943089431
# Test Accuracy (NFF): 96.0
# Test Accuracy (AFF): 60.86956521739131
# Confusion Matrix:
#  [[96  4]
#  [ 9 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.96      0.94       100
#          AFF       0.78      0.61      0.68        23
#
#     accuracy                           0.89       123
#    macro avg       0.85      0.78      0.81       123
# weighted avg       0.89      0.89      0.89       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.7274727821350098
# Total Test Accuracy: 82.53968253968254
# Test Accuracy (NFF): 86.95652173913044
# Test Accuracy (AFF): 70.58823529411765
# Confusion Matrix:
#  [[40  6]
#  [ 5 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.87      0.88        46
#          AFF       0.67      0.71      0.69        17
#
#     accuracy                           0.83        63
#    macro avg       0.78      0.79      0.78        63
# weighted avg       0.83      0.83      0.83        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 0.8687189817428589
# Total Test Accuracy: 77.35849056603773
# Test Accuracy (NFF): 80.48780487804879
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[33  8]
#  [ 4  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.80      0.85        41
#          AFF       0.50      0.67      0.57        12
#
#     accuracy                           0.77        53
#    macro avg       0.70      0.74      0.71        53
# weighted avg       0.80      0.77      0.78        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 0.023737384006381035
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.06462270021438599
# Total Test Accuracy: 96.875
# Test Accuracy (NFF): 96.875
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[31  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.97      0.98        32
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.97        32
#    macro avg       0.50      0.98      0.49        32
# weighted avg       1.00      0.97      0.98        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.2888031601905823
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[7 1]
#  [1 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.88      0.88         8
#          AFF       0.50      0.50      0.50         2
#
#     accuracy                           0.80        10
#    macro avg       0.69      0.69      0.69        10
# weighted avg       0.80      0.80      0.80        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.49548396468162537
# Total Test Accuracy: 86.36363636363636
# Test Accuracy (NFF): 94.11764705882352
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[16  1]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.94      0.91        17
#          AFF       0.75      0.60      0.67         5
#
#     accuracy                           0.86        22
#    macro avg       0.82      0.77      0.79        22
# weighted avg       0.86      0.86      0.86        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.5821099281311035
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 42.857142857142854
# Confusion Matrix:
#  [[29  0]
#  [ 4  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      1.00      0.94        29
#          AFF       1.00      0.43      0.60         7
#
#     accuracy                           0.89        36
#    macro avg       0.94      0.71      0.77        36
# weighted avg       0.90      0.89      0.87        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.5177486653511341
# Total Test Accuracy: 87.06896551724138
# Test Accuracy (NFF): 91.78082191780823
# Test Accuracy (AFF): 67.0967741935484
# Confusion Matrix:
#  [[603  54]
#  [ 51 104]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.92      0.92       657
#          AFF       0.66      0.67      0.66       155
#
#     accuracy                           0.87       812
#    macro avg       0.79      0.79      0.79       812
# weighted avg       0.87      0.87      0.87       812
#
#
# Average Total Test Accuracy: 90.49157423709335

# %% [markdown]
# # ResNet 101

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision.models import resnet101, ResNet101_Weights
from torchvision.models import resnet50, ResNet50_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

class CustomNet(nn.Module):
    def __init__(self, num_classes=2, freeze_percentage=0.5):
        super(CustomNet, self).__init__()

        self.features = models.resnet101(weights=ResNet101_Weights.DEFAULT)

        # Calculate the index where to split the layers
        total_layers = len(list(self.features.children()))
        split_idx = int(total_layers * freeze_percentage)

        # Split the layers into groups for freezing and non-freezing
        children = list(self.features.children())
        self.frozen_features = nn.Sequential(*children[:split_idx])
        self.unfrozen_features = nn.Sequential(*children[split_idx:-1])  # Exclude the last layer

        # Freeze layers in self.frozen_features
        for param in self.frozen_features.parameters():
            param.requires_grad = False

        # Define the final fully connected layer
        self.fc = nn.Linear(2048, num_classes)

    def forward(self, x):
        x = self.frozen_features(x)
        x = self.unfrozen_features(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x
    
# create net
model = CustomNet(num_classes=2)  # num_classes 2

# checkpoint
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

global_path = '/local/data1/honzh073/data/suzuki.ad.liu.se/89eb79c8-f720-4f86-92e5-83646ee163fb/app_server/FL_global_model.pt'

checkpoint = torch.load(global_path, map_location=device)

# print(checkpoint.keys())

# modify checkpoint keys，match model
# load model weights
state_dict = checkpoint['model']
modified_state_dict = {}
for key, value in state_dict.items():
    # modify key names，match model layers
    new_key = key.replace("model.", "")
    modified_state_dict[new_key] = value

# load weights to model
model.load_state_dict(modified_state_dict)
model = model.to(device)
model.eval()

# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(30, 20))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.011298997327685356
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        23
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        23
#    macro avg       1.00      1.00      1.00        23
# weighted avg       1.00      1.00      1.00        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 0.00036886901943944395
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         0
#          AFF       1.00      1.00      1.00         3
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.5040792226791382
# Total Test Accuracy: 85.71428571428571
# Test Accuracy (NFF): 86.95652173913044
# Test Accuracy (AFF): 83.33333333333334
# Confusion Matrix:
#  [[20  3]
#  [ 2 10]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.87      0.89        23
#          AFF       0.77      0.83      0.80        12
#
#     accuracy                           0.86        35
#    macro avg       0.84      0.85      0.84        35
# weighted avg       0.86      0.86      0.86        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.0012745480053126812
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         2
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.33699953369796276
# Total Test Accuracy: 86.15384615384616
# Test Accuracy (NFF): 88.33333333333333
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[53  7]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.88      0.92        60
#          AFF       0.30      0.60      0.40         5
#
#     accuracy                           0.86        65
#    macro avg       0.63      0.74      0.66        65
# weighted avg       0.91      0.86      0.88        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.5098146200180054
# Total Test Accuracy: 87.5
# Test Accuracy (NFF): 91.66666666666666
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[33  3]
#  [ 4 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.92      0.90        36
#          AFF       0.84      0.80      0.82        20
#
#     accuracy                           0.88        56
#    macro avg       0.87      0.86      0.86        56
# weighted avg       0.87      0.88      0.87        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.006428571417927742
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.820333868265152
# Total Test Accuracy: 83.49514563106796
# Test Accuracy (NFF): 88.75
# Test Accuracy (AFF): 65.21739130434783
# Confusion Matrix:
#  [[71  9]
#  [ 8 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.89      0.89        80
#          AFF       0.62      0.65      0.64        23
#
#     accuracy                           0.83       103
#    macro avg       0.76      0.77      0.77       103
# weighted avg       0.84      0.83      0.84       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.047478750348091125
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 0.9975363686680794
# Total Test Accuracy: 85.5072463768116
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 37.5
# Confusion Matrix:
#  [[53  0]
#  [10  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      1.00      0.91        53
#          AFF       1.00      0.38      0.55        16
#
#     accuracy                           0.86        69
#    macro avg       0.92      0.69      0.73        69
# weighted avg       0.88      0.86      0.83        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.3334109502611682
# Total Test Accuracy: 85.71428571428571
# Test Accuracy (NFF): 89.0625
# Test Accuracy (AFF): 69.23076923076923
# Confusion Matrix:
#  [[57  7]
#  [ 4  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.89      0.91        64
#          AFF       0.56      0.69      0.62        13
#
#     accuracy                           0.86        77
#    macro avg       0.75      0.79      0.77        77
# weighted avg       0.87      0.86      0.86        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.37118346989154816
# Total Test Accuracy: 91.45299145299145
# Test Accuracy (NFF): 91.1504424778761
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[103  10]
#  [  0   4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.91      0.95       113
#          AFF       0.29      1.00      0.44         4
#
#     accuracy                           0.91       117
#    macro avg       0.64      0.96      0.70       117
# weighted avg       0.98      0.91      0.94       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.054464537650346756
# Total Test Accuracy: 97.77777777777777
# Test Accuracy (NFF): 97.67441860465115
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[42  1]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.98      0.99        43
#          AFF       0.67      1.00      0.80         2
#
#     accuracy                           0.98        45
#    macro avg       0.83      0.99      0.89        45
# weighted avg       0.99      0.98      0.98        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.026291988790035248
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        21
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 0.0003453392127994448
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.4095302224159241
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 75.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.75      0.86         4
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.75         4
#    macro avg       0.50      0.88      0.43         4
# weighted avg       1.00      0.75      0.86         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 0.5092584937810898
# Total Test Accuracy: 87.32394366197182
# Test Accuracy (NFF): 93.87755102040816
# Test Accuracy (AFF): 72.72727272727273
# Confusion Matrix:
#  [[46  3]
#  [ 6 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.94      0.91        49
#          AFF       0.84      0.73      0.78        22
#
#     accuracy                           0.87        71
#    macro avg       0.86      0.83      0.85        71
# weighted avg       0.87      0.87      0.87        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.09195494744926691
# Total Test Accuracy: 97.61904761904762
# Test Accuracy (NFF): 98.79518072289156
# Test Accuracy (AFF): 95.34883720930233
# Confusion Matrix:
#  [[82  1]
#  [ 2 41]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.99      0.98        83
#          AFF       0.98      0.95      0.96        43
#
#     accuracy                           0.98       126
#    macro avg       0.98      0.97      0.97       126
# weighted avg       0.98      0.98      0.98       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.49392858147621155
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 92.5
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[37  3]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.93      0.94        40
#          AFF       0.50      0.60      0.55         5
#
#     accuracy                           0.89        45
#    macro avg       0.72      0.76      0.74        45
# weighted avg       0.90      0.89      0.89        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.042765893042087555
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[8 0]
#  [0 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         1
#
#     accuracy                           1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.5935214459896088
# Total Test Accuracy: 85.71428571428571
# Test Accuracy (NFF): 88.23529411764706
# Test Accuracy (AFF): 79.41176470588235
# Confusion Matrix:
#  [[75 10]
#  [ 7 27]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.88      0.90        85
#          AFF       0.73      0.79      0.76        34
#
#     accuracy                           0.86       119
#    macro avg       0.82      0.84      0.83       119
# weighted avg       0.86      0.86      0.86       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 0.8481220006942749
# Total Test Accuracy: 80.41237113402062
# Test Accuracy (NFF): 90.56603773584906
# Test Accuracy (AFF): 68.18181818181817
# Confusion Matrix:
#  [[48  5]
#  [14 30]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.77      0.91      0.83        53
#          AFF       0.86      0.68      0.76        44
#
#     accuracy                           0.80        97
#    macro avg       0.82      0.79      0.80        97
# weighted avg       0.81      0.80      0.80        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.00034287586458958685
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.3264854848384857
# Total Test Accuracy: 91.20879120879121
# Test Accuracy (NFF): 92.20779220779221
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[71  6]
#  [ 2 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.92      0.95        77
#          AFF       0.67      0.86      0.75        14
#
#     accuracy                           0.91        91
#    macro avg       0.82      0.89      0.85        91
# weighted avg       0.93      0.91      0.92        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 0.9604531526565552
# Total Test Accuracy: 72.22222222222223
# Test Accuracy (NFF): 80.0
# Test Accuracy (AFF): 33.33333333333333
# Confusion Matrix:
#  [[12  3]
#  [ 2  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.86      0.80      0.83        15
#          AFF       0.25      0.33      0.29         3
#
#     accuracy                           0.72        18
#    macro avg       0.55      0.57      0.56        18
# weighted avg       0.76      0.72      0.74        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.013615629635751247
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[18  0]
#  [ 0  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        18
#          AFF       1.00      1.00      1.00         8
#
#     accuracy                           1.00        26
#    macro avg       1.00      1.00      1.00        26
# weighted avg       1.00      1.00      1.00        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.3394606113433838
# Total Test Accuracy: 94.44444444444444
# Test Accuracy (NFF): 94.11764705882352
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[16  1]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.94      0.97        17
#          AFF       0.50      1.00      0.67         1
#
#     accuracy                           0.94        18
#    macro avg       0.75      0.97      0.82        18
# weighted avg       0.97      0.94      0.95        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.5459555611014366
# Total Test Accuracy: 90.3225806451613
# Test Accuracy (NFF): 96.20253164556962
# Test Accuracy (AFF): 57.14285714285714
# Confusion Matrix:
#  [[76  3]
#  [ 6  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.96      0.94        79
#          AFF       0.73      0.57      0.64        14
#
#     accuracy                           0.90        93
#    macro avg       0.83      0.77      0.79        93
# weighted avg       0.90      0.90      0.90        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 0.8219925761222839
# Total Test Accuracy: 81.25
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[8 1]
#  [2 5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.80      0.89      0.84         9
#          AFF       0.83      0.71      0.77         7
#
#     accuracy                           0.81        16
#    macro avg       0.82      0.80      0.81        16
# weighted avg       0.81      0.81      0.81        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 0.001425888971425593
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 1.0640493258833885
# Total Test Accuracy: 84.52380952380952
# Test Accuracy (NFF): 88.05970149253731
# Test Accuracy (AFF): 70.58823529411765
# Confusion Matrix:
#  [[59  8]
#  [ 5 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.88      0.90        67
#          AFF       0.60      0.71      0.65        17
#
#     accuracy                           0.85        84
#    macro avg       0.76      0.79      0.77        84
# weighted avg       0.86      0.85      0.85        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.02160940319299698
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.515248715877533
# Total Test Accuracy: 87.16216216216216
# Test Accuracy (NFF): 90.47619047619048
# Test Accuracy (AFF): 68.18181818181817
# Confusion Matrix:
#  [[114  12]
#  [  7  15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.90      0.92       126
#          AFF       0.56      0.68      0.61        22
#
#     accuracy                           0.87       148
#    macro avg       0.75      0.79      0.77       148
# weighted avg       0.88      0.87      0.88       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.22936952114105225
# Total Test Accuracy: 94.11764705882354
# Test Accuracy (NFF): 94.11764705882352
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[32  2]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.94      0.97        34
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.94        34
#    macro avg       0.50      0.97      0.48        34
# weighted avg       1.00      0.94      0.97        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.2962815761566162
# Total Test Accuracy: 88.23529411764706
# Test Accuracy (NFF): 85.71428571428571
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[12  2]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.86      0.92        14
#          AFF       0.60      1.00      0.75         3
#
#     accuracy                           0.88        17
#    macro avg       0.80      0.93      0.84        17
# weighted avg       0.93      0.88      0.89        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.25205865502357483
# Total Test Accuracy: 86.04651162790698
# Test Accuracy (NFF): 88.23529411764706
# Test Accuracy (AFF): 77.77777777777779
# Confusion Matrix:
#  [[60  8]
#  [ 4 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.88      0.91        68
#          AFF       0.64      0.78      0.70        18
#
#     accuracy                           0.86        86
#    macro avg       0.79      0.83      0.80        86
# weighted avg       0.87      0.86      0.87        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.1045900285243988
# Total Test Accuracy: 96.0
# Test Accuracy (NFF): 96.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[24  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        25
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.96        25
#    macro avg       0.50      0.98      0.49        25
# weighted avg       1.00      0.96      0.98        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.4720423221588135
# Total Test Accuracy: 93.10344827586206
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 83.33333333333334
# Confusion Matrix:
#  [[22  1]
#  [ 1  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      0.96      0.96        23
#          AFF       0.83      0.83      0.83         6
#
#     accuracy                           0.93        29
#    macro avg       0.89      0.89      0.89        29
# weighted avg       0.93      0.93      0.93        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.44908716157078743
# Total Test Accuracy: 81.33333333333333
# Test Accuracy (NFF): 87.14285714285714
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[61  9]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.87      0.90        70
#          AFF       0.00      0.00      1.00         5
#
#     accuracy                           0.81        75
#    macro avg       0.46      0.44      0.95        75
# weighted avg       0.86      0.81      0.90        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 0.00011367485421942547
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 0.5432103872299194
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 80.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[12  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.80      0.89        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.80        15
#    macro avg       0.50      0.90      0.44        15
# weighted avg       1.00      0.80      0.89        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.1585780770983547
# Total Test Accuracy: 97.14285714285714
# Test Accuracy (NFF): 98.23529411764706
# Test Accuracy (AFF): 94.66666666666667
# Confusion Matrix:
#  [[167   3]
#  [  4  71]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.98      0.98       170
#          AFF       0.96      0.95      0.95        75
#
#     accuracy                           0.97       245
#    macro avg       0.97      0.96      0.97       245
# weighted avg       0.97      0.97      0.97       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.5502736568450928
# Total Test Accuracy: 90.3225806451613
# Test Accuracy (NFF): 96.15384615384616
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[25  1]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.96      0.94        26
#          AFF       0.75      0.60      0.67         5
#
#     accuracy                           0.90        31
#    macro avg       0.84      0.78      0.81        31
# weighted avg       0.90      0.90      0.90        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.17309332266449928
# Total Test Accuracy: 93.38842975206612
# Test Accuracy (NFF): 93.18181818181817
# Test Accuracy (AFF): 93.93939393939394
# Confusion Matrix:
#  [[82  6]
#  [ 2 31]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.93      0.95        88
#          AFF       0.84      0.94      0.89        33
#
#     accuracy                           0.93       121
#    macro avg       0.91      0.94      0.92       121
# weighted avg       0.94      0.93      0.94       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.06924561411142349
# Total Test Accuracy: 95.45454545454545
# Test Accuracy (NFF): 95.45454545454545
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.95      0.98        22
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.95        22
#    macro avg       0.50      0.98      0.49        22
# weighted avg       1.00      0.95      0.98        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.43823832273483276
# Total Test Accuracy: 92.85714285714286
# Test Accuracy (NFF): 93.58974358974359
# Test Accuracy (AFF): 90.0
# Confusion Matrix:
#  [[73  5]
#  [ 2 18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.94      0.95        78
#          AFF       0.78      0.90      0.84        20
#
#     accuracy                           0.93        98
#    macro avg       0.88      0.92      0.90        98
# weighted avg       0.93      0.93      0.93        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.08160942752147093
# Total Test Accuracy: 95.77464788732394
# Test Accuracy (NFF): 95.3125
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[61  3]
#  [ 0  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.95      0.98        64
#          AFF       0.70      1.00      0.82         7
#
#     accuracy                           0.96        71
#    macro avg       0.85      0.98      0.90        71
# weighted avg       0.97      0.96      0.96        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.5824328064918518
# Total Test Accuracy: 89.47368421052632
# Test Accuracy (NFF): 89.47368421052632
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[51  6]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.89      0.94        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.89        57
#    macro avg       0.50      0.95      0.47        57
# weighted avg       1.00      0.89      0.94        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.7563987225294113
# Total Test Accuracy: 82.52427184466019
# Test Accuracy (NFF): 92.10526315789474
# Test Accuracy (AFF): 55.55555555555556
# Confusion Matrix:
#  [[70  6]
#  [12 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.92      0.89        76
#          AFF       0.71      0.56      0.63        27
#
#     accuracy                           0.83       103
#    macro avg       0.78      0.74      0.76       103
# weighted avg       0.82      0.83      0.82       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.2564280703663826
# Total Test Accuracy: 94.9367088607595
# Test Accuracy (NFF): 97.22222222222221
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[70  2]
#  [ 2  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.97      0.97        72
#          AFF       0.71      0.71      0.71         7
#
#     accuracy                           0.95        79
#    macro avg       0.84      0.84      0.84        79
# weighted avg       0.95      0.95      0.95        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.16194063425064087
# Total Test Accuracy: 92.3076923076923
# Test Accuracy (NFF): 91.66666666666666
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[22  2]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.92      0.96        24
#          AFF       0.50      1.00      0.67         2
#
#     accuracy                           0.92        26
#    macro avg       0.75      0.96      0.81        26
# weighted avg       0.96      0.92      0.93        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 1.6975854635238647
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 55.55555555555556
# Confusion Matrix:
#  [[3 0]
#  [4 5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.43      1.00      0.60         3
#          AFF       1.00      0.56      0.71         9
#
#     accuracy                           0.67        12
#    macro avg       0.71      0.78      0.66        12
# weighted avg       0.86      0.67      0.69        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.45616458853085834
# Total Test Accuracy: 91.04477611940298
# Test Accuracy (NFF): 90.56603773584906
# Test Accuracy (AFF): 92.85714285714286
# Confusion Matrix:
#  [[96 10]
#  [ 2 26]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.91      0.94       106
#          AFF       0.72      0.93      0.81        28
#
#     accuracy                           0.91       134
#    macro avg       0.85      0.92      0.88       134
# weighted avg       0.93      0.91      0.91       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.1507534747943282
# Total Test Accuracy: 96.66666666666667
# Test Accuracy (NFF): 99.3421052631579
# Test Accuracy (AFF): 82.14285714285714
# Confusion Matrix:
#  [[151   1]
#  [  5  23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.99      0.98       152
#          AFF       0.96      0.82      0.88        28
#
#     accuracy                           0.97       180
#    macro avg       0.96      0.91      0.93       180
# weighted avg       0.97      0.97      0.97       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.5676159858703613
# Total Test Accuracy: 85.0
# Test Accuracy (NFF): 96.29629629629629
# Test Accuracy (AFF): 61.53846153846154
# Confusion Matrix:
#  [[26  1]
#  [ 5  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      0.96      0.90        27
#          AFF       0.89      0.62      0.73        13
#
#     accuracy                           0.85        40
#    macro avg       0.86      0.79      0.81        40
# weighted avg       0.86      0.85      0.84        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 0.00011439460649853572
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 58:
#
# Test Loss: 0.609210193157196
# Total Test Accuracy: 87.71929824561404
# Test Accuracy (NFF): 89.65517241379311
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[26  3]
#  [ 4 24]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.90      0.88        29
#          AFF       0.89      0.86      0.87        28
#
#     accuracy                           0.88        57
#    macro avg       0.88      0.88      0.88        57
# weighted avg       0.88      0.88      0.88        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.17835089564323425
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.89      0.94         9
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.89         9
#    macro avg       0.50      0.94      0.47         9
# weighted avg       1.00      0.89      0.94         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.6755832582712173
# Total Test Accuracy: 82.92682926829268
# Test Accuracy (NFF): 88.0
# Test Accuracy (AFF): 60.86956521739131
# Confusion Matrix:
#  [[88 12]
#  [ 9 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.88      0.89       100
#          AFF       0.54      0.61      0.57        23
#
#     accuracy                           0.83       123
#    macro avg       0.72      0.74      0.73       123
# weighted avg       0.84      0.83      0.83       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.6168242692947388
# Total Test Accuracy: 80.95238095238095
# Test Accuracy (NFF): 84.78260869565217
# Test Accuracy (AFF): 70.58823529411765
# Confusion Matrix:
#  [[39  7]
#  [ 5 12]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.85      0.87        46
#          AFF       0.63      0.71      0.67        17
#
#     accuracy                           0.81        63
#    macro avg       0.76      0.78      0.77        63
# weighted avg       0.82      0.81      0.81        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 0.6303234696388245
# Total Test Accuracy: 83.01886792452831
# Test Accuracy (NFF): 85.36585365853658
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[35  6]
#  [ 3  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.85      0.89        41
#          AFF       0.60      0.75      0.67        12
#
#     accuracy                           0.83        53
#    macro avg       0.76      0.80      0.78        53
# weighted avg       0.85      0.83      0.84        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 0.7800241708755493
# Total Test Accuracy: 87.5
# Test Accuracy (NFF): 87.5
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[7 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.88      0.93         8
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.88         8
#    macro avg       0.50      0.94      0.47         8
# weighted avg       1.00      0.88      0.93         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.14000096917152405
# Total Test Accuracy: 93.75
# Test Accuracy (NFF): 93.75
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[30  2]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.94      0.97        32
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.94        32
#    macro avg       0.50      0.97      0.48        32
# weighted avg       1.00      0.94      0.97        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.011048883199691772
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[8 0]
#  [0 2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         2
#
#     accuracy                           1.00        10
#    macro avg       1.00      1.00      1.00        10
# weighted avg       1.00      1.00      1.00        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.5037156343460083
# Total Test Accuracy: 86.36363636363636
# Test Accuracy (NFF): 94.11764705882352
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[16  1]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.94      0.91        17
#          AFF       0.75      0.60      0.67         5
#
#     accuracy                           0.86        22
#    macro avg       0.82      0.77      0.79        22
# weighted avg       0.86      0.86      0.86        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.36955657601356506
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 93.10344827586206
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[27  2]
#  [ 2  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.93      0.93        29
#          AFF       0.71      0.71      0.71         7
#
#     accuracy                           0.89        36
#    macro avg       0.82      0.82      0.82        36
# weighted avg       0.89      0.89      0.89        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.4649296643642279
# Total Test Accuracy: 88.54679802955665
# Test Accuracy (NFF): 91.47640791476408
# Test Accuracy (AFF): 76.12903225806451
# Confusion Matrix:
#  [[601  56]
#  [ 37 118]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.91      0.93       657
#          AFF       0.68      0.76      0.72       155
#
#     accuracy                           0.89       812
#    macro avg       0.81      0.84      0.82       812
# weighted avg       0.89      0.89      0.89       812
#
#
# Average Total Test Accuracy: 90.60239730502543

# %% [markdown]
# # ResNet152

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision.models import resnet152, ResNet152_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

class CustomNet(nn.Module):
    def __init__(self, num_classes=2, freeze_percentage=0.5):
        super(CustomNet, self).__init__()

        self.features = models.resnet152(weights=ResNet152_Weights.DEFAULT)

        # Calculate the index where to split the layers
        total_layers = len(list(self.features.children()))
        split_idx = int(total_layers * freeze_percentage)

        # Split the layers into groups for freezing and non-freezing
        children = list(self.features.children())
        self.frozen_features = nn.Sequential(*children[:split_idx])
        self.unfrozen_features = nn.Sequential(*children[split_idx:-1])  # Exclude the last layer

        # Freeze layers in self.frozen_features
        for param in self.frozen_features.parameters():
            param.requires_grad = False

        # Define the final fully connected layer
        self.fc = nn.Linear(2048, num_classes)

    def forward(self, x):
        x = self.frozen_features(x)
        x = self.unfrozen_features(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x
    
# create net
model = CustomNet(num_classes=2)  # num_classes 2

# checkpoint
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# resnet152_freeze_Adam_200R_1E
global_path = '/local/data1/honzh073/data/suzuki.ad.liu.se/393be8ef-157c-40d6-906b-249caa5cbc9d/app_server/FL_global_model.pt'

checkpoint = torch.load(global_path, map_location=device)

# print(checkpoint.keys())

# modify checkpoint keys，match model
# load model weights
state_dict = checkpoint['model']
modified_state_dict = {}
for key, value in state_dict.items():
    # modify key names，match model layers
    new_key = key.replace("model.", "")
    modified_state_dict[new_key] = value

# load weights to model
model.load_state_dict(modified_state_dict)
model = model.to(device)
model.eval()

# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(30, 20))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.17494677007198334
# Total Test Accuracy: 95.65217391304348
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[22  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        23
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.96        23
#    macro avg       0.50      0.98      0.49        23
# weighted avg       1.00      0.96      0.98        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 0.001924483454786241
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         0
#          AFF       1.00      1.00      1.00         3
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.9441831111907959
# Total Test Accuracy: 77.14285714285714
# Test Accuracy (NFF): 91.30434782608695
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[21  2]
#  [ 6  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.78      0.91      0.84        23
#          AFF       0.75      0.50      0.60        12
#
#     accuracy                           0.77        35
#    macro avg       0.76      0.71      0.72        35
# weighted avg       0.77      0.77      0.76        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.027178414165973663
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         2
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.1782858669757843
# Total Test Accuracy: 93.84615384615384
# Test Accuracy (NFF): 96.66666666666667
# Test Accuracy (AFF): 60.0
# Confusion Matrix:
#  [[58  2]
#  [ 2  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.97      0.97        60
#          AFF       0.60      0.60      0.60         5
#
#     accuracy                           0.94        65
#    macro avg       0.78      0.78      0.78        65
# weighted avg       0.94      0.94      0.94        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.5266050696372986
# Total Test Accuracy: 92.85714285714286
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[36  0]
#  [ 4 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      1.00      0.95        36
#          AFF       1.00      0.80      0.89        20
#
#     accuracy                           0.93        56
#    macro avg       0.95      0.90      0.92        56
# weighted avg       0.94      0.93      0.93        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.029716311022639275
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.46962060034275055
# Total Test Accuracy: 90.29126213592232
# Test Accuracy (NFF): 96.25
# Test Accuracy (AFF): 69.56521739130434
# Confusion Matrix:
#  [[77  3]
#  [ 7 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.96      0.94        80
#          AFF       0.84      0.70      0.76        23
#
#     accuracy                           0.90       103
#    macro avg       0.88      0.83      0.85       103
# weighted avg       0.90      0.90      0.90       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.008131507784128189
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 0.2925148718059063
# Total Test Accuracy: 82.6086956521739
# Test Accuracy (NFF): 94.33962264150944
# Test Accuracy (AFF): 43.75
# Confusion Matrix:
#  [[50  3]
#  [ 9  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.94      0.89        53
#          AFF       0.70      0.44      0.54        16
#
#     accuracy                           0.83        69
#    macro avg       0.77      0.69      0.72        69
# weighted avg       0.81      0.83      0.81        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.2881636481615715
# Total Test Accuracy: 92.20779220779221
# Test Accuracy (NFF): 96.875
# Test Accuracy (AFF): 69.23076923076923
# Confusion Matrix:
#  [[62  2]
#  [ 4  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.97      0.95        64
#          AFF       0.82      0.69      0.75        13
#
#     accuracy                           0.92        77
#    macro avg       0.88      0.83      0.85        77
# weighted avg       0.92      0.92      0.92        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.23291516304016113
# Total Test Accuracy: 94.87179487179488
# Test Accuracy (NFF): 94.69026548672566
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[107   6]
#  [  0   4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.95      0.97       113
#          AFF       0.40      1.00      0.57         4
#
#     accuracy                           0.95       117
#    macro avg       0.70      0.97      0.77       117
# weighted avg       0.98      0.95      0.96       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.1595199555158615
# Total Test Accuracy: 93.33333333333333
# Test Accuracy (NFF): 95.34883720930233
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[41  2]
#  [ 1  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.95      0.96        43
#          AFF       0.33      0.50      0.40         2
#
#     accuracy                           0.93        45
#    macro avg       0.65      0.73      0.68        45
# weighted avg       0.95      0.93      0.94        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.0012988133821636438
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        21
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 6.778514216421172e-05
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.24628880620002747
# Total Test Accuracy: 75.0
# Test Accuracy (NFF): 75.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.75      0.86         4
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.75         4
#    macro avg       0.50      0.88      0.43         4
# weighted avg       1.00      0.75      0.86         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 0.4737403988838196
# Total Test Accuracy: 85.91549295774648
# Test Accuracy (NFF): 93.87755102040816
# Test Accuracy (AFF): 68.18181818181817
# Confusion Matrix:
#  [[46  3]
#  [ 7 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.94      0.90        49
#          AFF       0.83      0.68      0.75        22
#
#     accuracy                           0.86        71
#    macro avg       0.85      0.81      0.83        71
# weighted avg       0.86      0.86      0.85        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.11772220954298973
# Total Test Accuracy: 98.41269841269842
# Test Accuracy (NFF): 98.79518072289156
# Test Accuracy (AFF): 97.67441860465115
# Confusion Matrix:
#  [[82  1]
#  [ 1 42]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.99      0.99        83
#          AFF       0.98      0.98      0.98        43
#
#     accuracy                           0.98       126
#    macro avg       0.98      0.98      0.98       126
# weighted avg       0.98      0.98      0.98       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.17435051500797272
# Total Test Accuracy: 93.33333333333333
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 40.0
# Confusion Matrix:
#  [[40  0]
#  [ 3  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      1.00      0.96        40
#          AFF       1.00      0.40      0.57         5
#
#     accuracy                           0.93        45
#    macro avg       0.97      0.70      0.77        45
# weighted avg       0.94      0.93      0.92        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.8579649329185486
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[8 0]
#  [1 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      1.00      0.94         8
#          AFF       1.00      0.00      0.00         1
#
#     accuracy                           0.89         9
#    macro avg       0.94      0.50      0.47         9
# weighted avg       0.90      0.89      0.84         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.6326947510242462
# Total Test Accuracy: 84.87394957983193
# Test Accuracy (NFF): 89.41176470588236
# Test Accuracy (AFF): 73.52941176470588
# Confusion Matrix:
#  [[76  9]
#  [ 9 25]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      0.89      0.89        85
#          AFF       0.74      0.74      0.74        34
#
#     accuracy                           0.85       119
#    macro avg       0.81      0.81      0.81       119
# weighted avg       0.85      0.85      0.85       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 1.0365344285964966
# Total Test Accuracy: 79.38144329896907
# Test Accuracy (NFF): 94.33962264150944
# Test Accuracy (AFF): 61.36363636363637
# Confusion Matrix:
#  [[50  3]
#  [17 27]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.75      0.94      0.83        53
#          AFF       0.90      0.61      0.73        44
#
#     accuracy                           0.79        97
#    macro avg       0.82      0.78      0.78        97
# weighted avg       0.82      0.79      0.79        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.0001054872409440577
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.3341105580329895
# Total Test Accuracy: 87.91208791208791
# Test Accuracy (NFF): 92.20779220779221
# Test Accuracy (AFF): 64.28571428571429
# Confusion Matrix:
#  [[71  6]
#  [ 5  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.92      0.93        77
#          AFF       0.60      0.64      0.62        14
#
#     accuracy                           0.88        91
#    macro avg       0.77      0.78      0.77        91
# weighted avg       0.88      0.88      0.88        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 0.4977741837501526
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 86.66666666666667
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[13  2]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.87      0.93        15
#          AFF       0.60      1.00      0.75         3
#
#     accuracy                           0.89        18
#    macro avg       0.80      0.93      0.84        18
# weighted avg       0.93      0.89      0.90        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.17137391865253448
# Total Test Accuracy: 96.15384615384616
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 87.5
# Confusion Matrix:
#  [[18  0]
#  [ 1  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      1.00      0.97        18
#          AFF       1.00      0.88      0.93         8
#
#     accuracy                           0.96        26
#    macro avg       0.97      0.94      0.95        26
# weighted avg       0.96      0.96      0.96        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.06142289936542511
# Total Test Accuracy: 94.44444444444444
# Test Accuracy (NFF): 94.11764705882352
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[16  1]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.94      0.97        17
#          AFF       0.50      1.00      0.67         1
#
#     accuracy                           0.94        18
#    macro avg       0.75      0.97      0.82        18
# weighted avg       0.97      0.94      0.95        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.41127660870552063
# Total Test Accuracy: 90.3225806451613
# Test Accuracy (NFF): 96.20253164556962
# Test Accuracy (AFF): 57.14285714285714
# Confusion Matrix:
#  [[76  3]
#  [ 6  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.96      0.94        79
#          AFF       0.73      0.57      0.64        14
#
#     accuracy                           0.90        93
#    macro avg       0.83      0.77      0.79        93
# weighted avg       0.90      0.90      0.90        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 0.19490714371204376
# Total Test Accuracy: 93.75
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[8 1]
#  [0 7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.89      0.94         9
#          AFF       0.88      1.00      0.93         7
#
#     accuracy                           0.94        16
#    macro avg       0.94      0.94      0.94        16
# weighted avg       0.95      0.94      0.94        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 0.0004103636892978102
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 0.2664007544517517
# Total Test Accuracy: 91.66666666666667
# Test Accuracy (NFF): 92.53731343283582
# Test Accuracy (AFF): 88.23529411764706
# Confusion Matrix:
#  [[62  5]
#  [ 2 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.93      0.95        67
#          AFF       0.75      0.88      0.81        17
#
#     accuracy                           0.92        84
#    macro avg       0.86      0.90      0.88        84
# weighted avg       0.92      0.92      0.92        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.0019219978712499142
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.5527082482973734
# Total Test Accuracy: 84.45945945945945
# Test Accuracy (NFF): 86.5079365079365
# Test Accuracy (AFF): 72.72727272727273
# Confusion Matrix:
#  [[109  17]
#  [  6  16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.87      0.90       126
#          AFF       0.48      0.73      0.58        22
#
#     accuracy                           0.84       148
#    macro avg       0.72      0.80      0.74       148
# weighted avg       0.88      0.84      0.86       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.045554690062999725
# Total Test Accuracy: 97.05882352941177
# Test Accuracy (NFF): 97.05882352941177
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[33  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.97      0.99        34
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.97        34
#    macro avg       0.50      0.99      0.49        34
# weighted avg       1.00      0.97      0.99        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.3150657117366791
# Total Test Accuracy: 82.3529411764706
# Test Accuracy (NFF): 78.57142857142857
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[11  3]
#  [ 0  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.79      0.88        14
#          AFF       0.50      1.00      0.67         3
#
#     accuracy                           0.82        17
#    macro avg       0.75      0.89      0.77        17
# weighted avg       0.91      0.82      0.84        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.2902851477265358
# Total Test Accuracy: 90.69767441860465
# Test Accuracy (NFF): 92.64705882352942
# Test Accuracy (AFF): 83.33333333333334
# Confusion Matrix:
#  [[63  5]
#  [ 3 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.93      0.94        68
#          AFF       0.75      0.83      0.79        18
#
#     accuracy                           0.91        86
#    macro avg       0.85      0.88      0.86        86
# weighted avg       0.91      0.91      0.91        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.050603579729795456
# Total Test Accuracy: 96.0
# Test Accuracy (NFF): 96.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[24  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        25
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.96        25
#    macro avg       0.50      0.98      0.49        25
# weighted avg       1.00      0.96      0.98        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.5465512871742249
# Total Test Accuracy: 89.65517241379311
# Test Accuracy (NFF): 95.65217391304348
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[22  1]
#  [ 2  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.96      0.94        23
#          AFF       0.80      0.67      0.73         6
#
#     accuracy                           0.90        29
#    macro avg       0.86      0.81      0.83        29
# weighted avg       0.89      0.90      0.89        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.4093897268176079
# Total Test Accuracy: 84.0
# Test Accuracy (NFF): 90.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[63  7]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.90      0.91        70
#          AFF       0.00      0.00      1.00         5
#
#     accuracy                           0.84        75
#    macro avg       0.46      0.45      0.96        75
# weighted avg       0.86      0.84      0.92        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 1.3113003660691902e-06
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 0.6272367835044861
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 80.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[12  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.80      0.89        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.80        15
#    macro avg       0.50      0.90      0.44        15
# weighted avg       1.00      0.80      0.89        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.07325269258581102
# Total Test Accuracy: 97.95918367346938
# Test Accuracy (NFF): 98.23529411764706
# Test Accuracy (AFF): 97.33333333333334
# Confusion Matrix:
#  [[167   3]
#  [  2  73]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.99      0.98      0.99       170
#          AFF       0.96      0.97      0.97        75
#
#     accuracy                           0.98       245
#    macro avg       0.97      0.98      0.98       245
# weighted avg       0.98      0.98      0.98       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.6005340218544006
# Total Test Accuracy: 80.64516129032258
# Test Accuracy (NFF): 80.76923076923077
# Test Accuracy (AFF): 80.0
# Confusion Matrix:
#  [[21  5]
#  [ 1  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.81      0.88        26
#          AFF       0.44      0.80      0.57         5
#
#     accuracy                           0.81        31
#    macro avg       0.70      0.80      0.72        31
# weighted avg       0.87      0.81      0.83        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.11067849397659302
# Total Test Accuracy: 95.86776859504133
# Test Accuracy (NFF): 97.72727272727273
# Test Accuracy (AFF): 90.9090909090909
# Confusion Matrix:
#  [[86  2]
#  [ 3 30]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.98      0.97        88
#          AFF       0.94      0.91      0.92        33
#
#     accuracy                           0.96       121
#    macro avg       0.95      0.94      0.95       121
# weighted avg       0.96      0.96      0.96       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.284406453371048
# Total Test Accuracy: 90.9090909090909
# Test Accuracy (NFF): 90.9090909090909
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[20  2]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.91      0.95        22
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.91        22
#    macro avg       0.50      0.95      0.48        22
# weighted avg       1.00      0.91      0.95        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.2591124325990677
# Total Test Accuracy: 89.79591836734694
# Test Accuracy (NFF): 94.87179487179486
# Test Accuracy (AFF): 70.0
# Confusion Matrix:
#  [[74  4]
#  [ 6 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.95      0.94        78
#          AFF       0.78      0.70      0.74        20
#
#     accuracy                           0.90        98
#    macro avg       0.85      0.82      0.84        98
# weighted avg       0.89      0.90      0.90        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.43501532077789307
# Total Test Accuracy: 91.54929577464789
# Test Accuracy (NFF): 92.1875
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[59  5]
#  [ 1  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.98      0.92      0.95        64
#          AFF       0.55      0.86      0.67         7
#
#     accuracy                           0.92        71
#    macro avg       0.76      0.89      0.81        71
# weighted avg       0.94      0.92      0.92        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.3505757451057434
# Total Test Accuracy: 85.96491228070175
# Test Accuracy (NFF): 85.96491228070175
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[49  8]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.86      0.92        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.86        57
#    macro avg       0.50      0.93      0.46        57
# weighted avg       1.00      0.86      0.92        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.5991960167884827
# Total Test Accuracy: 84.46601941747574
# Test Accuracy (NFF): 93.42105263157895
# Test Accuracy (AFF): 59.25925925925925
# Confusion Matrix:
#  [[71  5]
#  [11 16]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.93      0.90        76
#          AFF       0.76      0.59      0.67        27
#
#     accuracy                           0.84       103
#    macro avg       0.81      0.76      0.78       103
# weighted avg       0.84      0.84      0.84       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.3426574841141701
# Total Test Accuracy: 92.40506329113924
# Test Accuracy (NFF): 94.44444444444444
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[68  4]
#  [ 2  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.94      0.96        72
#          AFF       0.56      0.71      0.63         7
#
#     accuracy                           0.92        79
#    macro avg       0.76      0.83      0.79        79
# weighted avg       0.93      0.92      0.93        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.06404213607311249
# Total Test Accuracy: 96.15384615384616
# Test Accuracy (NFF): 95.83333333333334
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[23  1]
#  [ 0  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        24
#          AFF       0.67      1.00      0.80         2
#
#     accuracy                           0.96        26
#    macro avg       0.83      0.98      0.89        26
# weighted avg       0.97      0.96      0.96        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 2.259711980819702
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 55.55555555555556
# Confusion Matrix:
#  [[3 0]
#  [4 5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.43      1.00      0.60         3
#          AFF       1.00      0.56      0.71         9
#
#     accuracy                           0.67        12
#    macro avg       0.71      0.78      0.66        12
# weighted avg       0.86      0.67      0.69        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.21940039455269775
# Total Test Accuracy: 93.28358208955224
# Test Accuracy (NFF): 96.22641509433963
# Test Accuracy (AFF): 82.14285714285714
# Confusion Matrix:
#  [[102   4]
#  [  5  23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.96      0.96       106
#          AFF       0.85      0.82      0.84        28
#
#     accuracy                           0.93       134
#    macro avg       0.90      0.89      0.90       134
# weighted avg       0.93      0.93      0.93       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.20730919778967896
# Total Test Accuracy: 96.11111111111111
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 75.0
# Confusion Matrix:
#  [[152   0]
#  [  7  21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.96      1.00      0.98       152
#          AFF       1.00      0.75      0.86        28
#
#     accuracy                           0.96       180
#    macro avg       0.98      0.88      0.92       180
# weighted avg       0.96      0.96      0.96       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.6801231503486633
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 38.46153846153847
# Confusion Matrix:
#  [[27  0]
#  [ 8  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.77      1.00      0.87        27
#          AFF       1.00      0.38      0.56        13
#
#     accuracy                           0.80        40
#    macro avg       0.89      0.69      0.71        40
# weighted avg       0.85      0.80      0.77        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 0.18342025578022003
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 58:
#
# Test Loss: 0.6857030987739563
# Total Test Accuracy: 85.96491228070175
# Test Accuracy (NFF): 86.20689655172413
# Test Accuracy (AFF): 85.71428571428571
# Confusion Matrix:
#  [[25  4]
#  [ 4 24]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.86      0.86      0.86        29
#          AFF       0.86      0.86      0.86        28
#
#     accuracy                           0.86        57
#    macro avg       0.86      0.86      0.86        57
# weighted avg       0.86      0.86      0.86        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.15879784524440765
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 88.88888888888889
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.89      0.94         9
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.89         9
#    macro avg       0.50      0.94      0.47         9
# weighted avg       1.00      0.89      0.94         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.4304703027009964
# Total Test Accuracy: 86.99186991869918
# Test Accuracy (NFF): 93.0
# Test Accuracy (AFF): 60.86956521739131
# Confusion Matrix:
#  [[93  7]
#  [ 9 14]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.93      0.92       100
#          AFF       0.67      0.61      0.64        23
#
#     accuracy                           0.87       123
#    macro avg       0.79      0.77      0.78       123
# weighted avg       0.87      0.87      0.87       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.6410295367240906
# Total Test Accuracy: 82.53968253968254
# Test Accuracy (NFF): 89.13043478260869
# Test Accuracy (AFF): 64.70588235294117
# Confusion Matrix:
#  [[41  5]
#  [ 6 11]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.87      0.89      0.88        46
#          AFF       0.69      0.65      0.67        17
#
#     accuracy                           0.83        63
#    macro avg       0.78      0.77      0.77        63
# weighted avg       0.82      0.83      0.82        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 0.8275499939918518
# Total Test Accuracy: 84.90566037735849
# Test Accuracy (NFF): 90.2439024390244
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[37  4]
#  [ 4  8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.90      0.90      0.90        41
#          AFF       0.67      0.67      0.67        12
#
#     accuracy                           0.85        53
#    macro avg       0.78      0.78      0.78        53
# weighted avg       0.85      0.85      0.85        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 0.0020533581264317036
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.08428045362234116
# Total Test Accuracy: 96.875
# Test Accuracy (NFF): 96.875
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[31  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.97      0.98        32
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.97        32
#    macro avg       0.50      0.98      0.49        32
# weighted avg       1.00      0.97      0.98        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.09043832868337631
# Total Test Accuracy: 90.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 50.0
# Confusion Matrix:
#  [[8 0]
#  [1 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      1.00      0.94         8
#          AFF       1.00      0.50      0.67         2
#
#     accuracy                           0.90        10
#    macro avg       0.94      0.75      0.80        10
# weighted avg       0.91      0.90      0.89        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.2419017255306244
# Total Test Accuracy: 86.36363636363636
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 40.0
# Confusion Matrix:
#  [[17  0]
#  [ 3  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      1.00      0.92        17
#          AFF       1.00      0.40      0.57         5
#
#     accuracy                           0.86        22
#    macro avg       0.93      0.70      0.75        22
# weighted avg       0.88      0.86      0.84        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.1575084626674652
# Total Test Accuracy: 94.44444444444444
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 71.42857142857143
# Confusion Matrix:
#  [[29  0]
#  [ 2  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      1.00      0.97        29
#          AFF       1.00      0.71      0.83         7
#
#     accuracy                           0.94        36
#    macro avg       0.97      0.86      0.90        36
# weighted avg       0.95      0.94      0.94        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.5927893164066168
# Total Test Accuracy: 84.97536945812809
# Test Accuracy (NFF): 89.3455098934551
# Test Accuracy (AFF): 66.45161290322581
# Confusion Matrix:
#  [[587  70]
#  [ 52 103]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.89      0.91       657
#          AFF       0.60      0.66      0.63       155
#
#     accuracy                           0.85       812
#    macro avg       0.76      0.78      0.77       812
# weighted avg       0.86      0.85      0.85       812
#
#
# Average Total Test Accuracy: 90.89114450794729

# %% [markdown]
# # DenseNet 161

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision.models import densenet161, DenseNet161_Weights

torch.hub.set_dir('/local/data1/honzh073/download/TORCH_PRETRAINED')

class CustomNet(nn.Module):
    def __init__(self, num_classes=2, freeze_percentage=0.5):
        super(CustomNet, self).__init__()

        self.features = models.densenet161(weights=DenseNet161_Weights.DEFAULT)

        # Calculate the index where to split the layers
        total_layers = len(list(self.features.children()))
        split_idx = int(total_layers * freeze_percentage)

        # Split the layers into groups for freezing and non-freezing
        children = list(self.features.children())
        self.frozen_features = nn.Sequential(*children[:split_idx])
        self.unfrozen_features = nn.Sequential(*children[split_idx:-1])  # Exclude the last layer

        # Freeze layers in self.frozen_features
        for param in self.frozen_features.parameters():
            param.requires_grad = False

        # Define the final fully connected layer
        self.fc = nn.Linear(2208, num_classes)  # DenseNet-161 has 2208 output features

    def forward(self, x):
        x = self.frozen_features(x)
        x = self.unfrozen_features(x)
        x = nn.functional.adaptive_avg_pool2d(x, (1, 1))  # Global average pooling
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x


# create net
model = CustomNet(num_classes=2)  # num_classes 2

# checkpoint
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# resnet101_freeze_Adam_200R_1E
global_path = '/local/data1/honzh073/data/suzuki.ad.liu.se/4d5030d5-7968-49a4-898a-1625df4af25e/app_server/FL_global_model.pt'

checkpoint = torch.load(global_path, map_location=device)

# print(checkpoint.keys())

# modify checkpoint keys，match model
# load model weights
state_dict = checkpoint['model']
modified_state_dict = {}
for key, value in state_dict.items():
    # modify key names，match model layers
    new_key = key.replace("model.", "")
    modified_state_dict[new_key] = value

# load weights to model
model.load_state_dict(modified_state_dict)
model = model.to(device)
model.eval()


# 加载测试数据集
test_csv_file = "/local/data1/honzh073/local_repository/FL/code/6_test_global_model/csv_files/all_image.csv"  # 替换成你的测试数据集的CSV文件路径

test_dataset = CustomDataset(csv_file=test_csv_file, transform=test_transform)

# Get unique hospital IDs
unique_hospital_ids = set(test_dataset.hospital_ids)

hospital_accuracies = {}

# Loop over all hospital IDs and print performance metrics
for selected_hospital in unique_hospital_ids:
    # Select data for the current hospital
    filtered_test_data_indices = [idx for idx, hospital_id in enumerate(test_dataset.hospital_ids) if hospital_id == selected_hospital]
    filtered_test_dataset = torch.utils.data.Subset(test_dataset, indices=filtered_test_data_indices)

    # Test the model
    batch_size = 64  # Adjust according to your needs
    metrics = test_model(model, filtered_test_dataset, batch_size)

    # Store Total Test Accuracy for the current hospital
    hospital_accuracies[selected_hospital] = metrics["Total Test Accuracy"]

    # Print or record the model's performance for the current hospital
    print(f"\nPerformance for Hospital {selected_hospital}:\n")
    print("Test Loss:", metrics["Test Loss"])
    print("Total Test Accuracy:", metrics["Total Test Accuracy"])
    print("Test Accuracy (NFF):", metrics["Test Accuracy (NFF)"])
    print("Test Accuracy (AFF):", metrics["Test Accuracy (AFF)"])
    print("Confusion Matrix:\n", metrics["Confusion Matrix"])
    print("Classification Report:\n", metrics["Classification Report"])

# Calculate average performance
average_performance = sum(hospital_accuracies.values()) / len(hospital_accuracies)
print(f"\nAverage Total Test Accuracy: {average_performance}")

# List of hospitals to exclude
exclude_hospitals = {18, 43, 55, 100}

# Filter out excluded hospitals
filtered_accuracies = {hospital: accuracy for hospital, accuracy in hospital_accuracies.items() if hospital not in exclude_hospitals}

# Plotting the bar chart with wider bars and text labels
bar_width = 0.8  # Adjust the width of the bars as needed

# Set the figure size
fig, ax = plt.subplots(figsize=(30, 20))  # Adjust the figsize as needed

# Plot the bar chart
bars = ax.bar(filtered_accuracies.keys(), filtered_accuracies.values(), width=bar_width)

# Add text labels for each bar
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

# Set labels and title
plt.xlabel('Hospital ID')
plt.ylabel('Total Test Accuracy')
plt.title('Total Test Accuracy for Each Hospital (Excluding hospitals 18, 43, 55, 100)')

# Show the bar chart
plt.show()
# Out:
# Performance for Hospital 1:
#
# Test Loss: 0.22938008606433868
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        23
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        23
#    macro avg       1.00      1.00      1.00        23
# weighted avg       1.00      1.00      1.00        23
#
#
# Performance for Hospital 2:
#
# Test Loss: 0.5721169710159302
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 0
# Test Accuracy (AFF): 66.66666666666666
# Confusion Matrix:
#  [[0 0]
#  [1 2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.00      1.00      0.00         0
#          AFF       1.00      0.67      0.80         3
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# Performance for Hospital 3:
#
# Test Loss: 0.7259248495101929
# Total Test Accuracy: 62.857142857142854
# Test Accuracy (NFF): 91.30434782608695
# Test Accuracy (AFF): 8.333333333333332
# Confusion Matrix:
#  [[21  2]
#  [11  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.66      0.91      0.76        23
#          AFF       0.33      0.08      0.13        12
#
#     accuracy                           0.63        35
#    macro avg       0.49      0.50      0.45        35
# weighted avg       0.55      0.63      0.55        35
#
#
# Performance for Hospital 4:
#
# Test Loss: 0.18365250527858734
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         2
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
#
#
# Performance for Hospital 5:
#
# Test Loss: 0.21844565123319626
# Total Test Accuracy: 90.76923076923077
# Test Accuracy (NFF): 96.66666666666667
# Test Accuracy (AFF): 20.0
# Confusion Matrix:
#  [[58  2]
#  [ 4  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.94      0.97      0.95        60
#          AFF       0.33      0.20      0.25         5
#
#     accuracy                           0.91        65
#    macro avg       0.63      0.58      0.60        65
# weighted avg       0.89      0.91      0.90        65
#
#
# Performance for Hospital 6:
#
# Test Loss: 0.569998562335968
# Total Test Accuracy: 73.21428571428571
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 25.0
# Confusion Matrix:
#  [[36  0]
#  [15  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.71      1.00      0.83        36
#          AFF       1.00      0.25      0.40        20
#
#     accuracy                           0.73        56
#    macro avg       0.85      0.62      0.61        56
# weighted avg       0.81      0.73      0.67        56
#
#
# Performance for Hospital 7:
#
# Test Loss: 0.3137325346469879
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 8:
#
# Test Loss: 0.4731582999229431
# Total Test Accuracy: 81.55339805825243
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 17.391304347826086
# Confusion Matrix:
#  [[80  0]
#  [19  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      1.00      0.89        80
#          AFF       1.00      0.17      0.30        23
#
#     accuracy                           0.82       103
#    macro avg       0.90      0.59      0.60       103
# weighted avg       0.85      0.82      0.76       103
#
#
# Performance for Hospital 9:
#
# Test Loss: 0.3346976935863495
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6 3]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         9
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         9
#    macro avg       0.50      0.83      0.40         9
# weighted avg       1.00      0.67      0.80         9
#
#
# Performance for Hospital 10:
#
# Test Loss: 0.4220014065504074
# Total Test Accuracy: 78.26086956521739
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 6.25
# Confusion Matrix:
#  [[53  0]
#  [15  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.78      1.00      0.88        53
#          AFF       1.00      0.06      0.12        16
#
#     accuracy                           0.78        69
#    macro avg       0.89      0.53      0.50        69
# weighted avg       0.83      0.78      0.70        69
#
#
# Performance for Hospital 11:
#
# Test Loss: 0.2746165618300438
# Total Test Accuracy: 84.41558441558442
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 7.6923076923076925
# Confusion Matrix:
#  [[64  0]
#  [12  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      1.00      0.91        64
#          AFF       1.00      0.08      0.14        13
#
#     accuracy                           0.84        77
#    macro avg       0.92      0.54      0.53        77
# weighted avg       0.87      0.84      0.78        77
#
#
# Performance for Hospital 12:
#
# Test Loss: 0.2819454073905945
# Total Test Accuracy: 94.87179487179488
# Test Accuracy (NFF): 97.34513274336283
# Test Accuracy (AFF): 25.0
# Confusion Matrix:
#  [[110   3]
#  [  3   1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.97      0.97      0.97       113
#          AFF       0.25      0.25      0.25         4
#
#     accuracy                           0.95       117
#    macro avg       0.61      0.61      0.61       117
# weighted avg       0.95      0.95      0.95       117
#
#
# Performance for Hospital 13:
#
# Test Loss: 0.27954602241516113
# Total Test Accuracy: 93.33333333333333
# Test Accuracy (NFF): 97.67441860465115
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[42  1]
#  [ 2  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.95      0.98      0.97        43
#          AFF       0.00      0.00      1.00         2
#
#     accuracy                           0.93        45
#    macro avg       0.48      0.49      0.98        45
# weighted avg       0.91      0.93      0.97        45
#
#
# Performance for Hospital 14:
#
# Test Loss: 0.15576483309268951
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        21
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        21
#    macro avg       1.00      1.00      1.00        21
# weighted avg       1.00      1.00      1.00        21
#
#
# Performance for Hospital 15:
#
# Test Loss: 0.6050422787666321
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 66.66666666666666
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[2 1]
#  [0 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.67      0.80         3
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.83      0.40         3
# weighted avg       1.00      0.67      0.80         3
#
#
# Performance for Hospital 16:
#
# Test Loss: 0.2559283673763275
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         4
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
#
#
# Performance for Hospital 17:
#
# Test Loss: 0.48720043897628784
# Total Test Accuracy: 76.05633802816901
# Test Accuracy (NFF): 97.95918367346938
# Test Accuracy (AFF): 27.27272727272727
# Confusion Matrix:
#  [[48  1]
#  [16  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.75      0.98      0.85        49
#          AFF       0.86      0.27      0.41        22
#
#     accuracy                           0.76        71
#    macro avg       0.80      0.63      0.63        71
# weighted avg       0.78      0.76      0.71        71
#
#
# Performance for Hospital 18:
#
# Test Loss: 0.5440643578767776
# Total Test Accuracy: 69.04761904761905
# Test Accuracy (NFF): 98.79518072289156
# Test Accuracy (AFF): 11.627906976744185
# Confusion Matrix:
#  [[82  1]
#  [38  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.68      0.99      0.81        83
#          AFF       0.83      0.12      0.20        43
#
#     accuracy                           0.69       126
#    macro avg       0.76      0.55      0.51       126
# weighted avg       0.73      0.69      0.60       126
#
#
# Performance for Hospital 19:
#
# Test Loss: 0.36296218633651733
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 97.5
# Test Accuracy (AFF): 20.0
# Confusion Matrix:
#  [[39  1]
#  [ 4  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.91      0.97      0.94        40
#          AFF       0.50      0.20      0.29         5
#
#     accuracy                           0.89        45
#    macro avg       0.70      0.59      0.61        45
# weighted avg       0.86      0.89      0.87        45
#
#
# Performance for Hospital 20:
#
# Test Loss: 0.24928659200668335
# Total Test Accuracy: 88.88888888888889
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[8 0]
#  [1 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.89      1.00      0.94         8
#          AFF       1.00      0.00      0.00         1
#
#     accuracy                           0.89         9
#    macro avg       0.94      0.50      0.47         9
# weighted avg       0.90      0.89      0.84         9
#
#
# Performance for Hospital 21:
#
# Test Loss: 0.5350864082574844
# Total Test Accuracy: 77.3109243697479
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 20.588235294117645
# Confusion Matrix:
#  [[85  0]
#  [27  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.76      1.00      0.86        85
#          AFF       1.00      0.21      0.34        34
#
#     accuracy                           0.77       119
#    macro avg       0.88      0.60      0.60       119
# weighted avg       0.83      0.77      0.71       119
#
#
# Performance for Hospital 22:
#
# Test Loss: 0.7436881959438324
# Total Test Accuracy: 59.79381443298969
# Test Accuracy (NFF): 98.11320754716981
# Test Accuracy (AFF): 13.636363636363635
# Confusion Matrix:
#  [[52  1]
#  [38  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.58      0.98      0.73        53
#          AFF       0.86      0.14      0.24        44
#
#     accuracy                           0.60        97
#    macro avg       0.72      0.56      0.48        97
# weighted avg       0.70      0.60      0.50        97
#
#
# Performance for Hospital 23:
#
# Test Loss: 0.22123773396015167
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 24:
#
# Test Loss: 0.3931370675563812
# Total Test Accuracy: 85.71428571428571
# Test Accuracy (NFF): 96.1038961038961
# Test Accuracy (AFF): 28.57142857142857
# Confusion Matrix:
#  [[74  3]
#  [10  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.96      0.92        77
#          AFF       0.57      0.29      0.38        14
#
#     accuracy                           0.86        91
#    macro avg       0.73      0.62      0.65        91
# weighted avg       0.83      0.86      0.84        91
#
#
# Performance for Hospital 25:
#
# Test Loss: 0.7256855368614197
# Total Test Accuracy: 66.66666666666667
# Test Accuracy (NFF): 80.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[12  3]
#  [ 3  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.80      0.80      0.80        15
#          AFF       0.00      0.00      1.00         3
#
#     accuracy                           0.67        18
#    macro avg       0.40      0.40      0.90        18
# weighted avg       0.67      0.67      0.83        18
#
#
# Performance for Hospital 26:
#
# Test Loss: 0.36777007579803467
# Total Test Accuracy: 84.61538461538461
# Test Accuracy (NFF): 94.44444444444444
# Test Accuracy (AFF): 62.5
# Confusion Matrix:
#  [[17  1]
#  [ 3  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      0.94      0.89        18
#          AFF       0.83      0.62      0.71         8
#
#     accuracy                           0.85        26
#    macro avg       0.84      0.78      0.80        26
# weighted avg       0.84      0.85      0.84        26
#
#
# Performance for Hospital 27:
#
# Test Loss: 0.23962658643722534
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 100.0
# Confusion Matrix:
#  [[17  0]
#  [ 0  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        17
#          AFF       1.00      1.00      1.00         1
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
#
# Performance for Hospital 28:
#
# Test Loss: 0.4336436986923218
# Total Test Accuracy: 86.02150537634408
# Test Accuracy (NFF): 97.46835443037975
# Test Accuracy (AFF): 21.428571428571427
# Confusion Matrix:
#  [[77  2]
#  [11  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.88      0.97      0.92        79
#          AFF       0.60      0.21      0.32        14
#
#     accuracy                           0.86        93
#    macro avg       0.74      0.59      0.62        93
# weighted avg       0.83      0.86      0.83        93
#
#
# Performance for Hospital 29:
#
# Test Loss: 0.45999935269355774
# Total Test Accuracy: 68.75
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 28.57142857142857
# Confusion Matrix:
#  [[9 0]
#  [5 2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.64      1.00      0.78         9
#          AFF       1.00      0.29      0.44         7
#
#     accuracy                           0.69        16
#    macro avg       0.82      0.64      0.61        16
# weighted avg       0.80      0.69      0.63        16
#
#
# Performance for Hospital 30:
#
# Test Loss: 0.25859394669532776
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         6
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
#
#
# Performance for Hospital 31:
#
# Test Loss: 0.46010535955429077
# Total Test Accuracy: 82.14285714285714
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 11.76470588235294
# Confusion Matrix:
#  [[67  0]
#  [15  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.82      1.00      0.90        67
#          AFF       1.00      0.12      0.21        17
#
#     accuracy                           0.82        84
#    macro avg       0.91      0.56      0.55        84
# weighted avg       0.85      0.82      0.76        84
#
#
# Performance for Hospital 32:
#
# Test Loss: 0.21627803146839142
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 33:
#
# Test Loss: 0.42422573765118915
# Total Test Accuracy: 85.13513513513513
# Test Accuracy (NFF): 98.4126984126984
# Test Accuracy (AFF): 9.090909090909092
# Confusion Matrix:
#  [[124   2]
#  [ 20   2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.86      0.98      0.92       126
#          AFF       0.50      0.09      0.15        22
#
#     accuracy                           0.85       148
#    macro avg       0.68      0.54      0.54       148
# weighted avg       0.81      0.85      0.80       148
#
#
# Performance for Hospital 34:
#
# Test Loss: 0.23585908114910126
# Total Test Accuracy: 97.05882352941177
# Test Accuracy (NFF): 97.05882352941177
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[33  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.97      0.99        34
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.97        34
#    macro avg       0.50      0.99      0.49        34
# weighted avg       1.00      0.97      0.99        34
#
#
# Performance for Hospital 35:
#
# Test Loss: 0.540648341178894
# Total Test Accuracy: 76.47058823529412
# Test Accuracy (NFF): 92.85714285714286
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[13  1]
#  [ 3  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.81      0.93      0.87        14
#          AFF       0.00      0.00      1.00         3
#
#     accuracy                           0.76        17
#    macro avg       0.41      0.46      0.93        17
# weighted avg       0.67      0.76      0.89        17
#
#
# Performance for Hospital 36:
#
# Test Loss: 0.3699478358030319
# Total Test Accuracy: 80.23255813953489
# Test Accuracy (NFF): 95.58823529411765
# Test Accuracy (AFF): 22.22222222222222
# Confusion Matrix:
#  [[65  3]
#  [14  4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.82      0.96      0.88        68
#          AFF       0.57      0.22      0.32        18
#
#     accuracy                           0.80        86
#    macro avg       0.70      0.59      0.60        86
# weighted avg       0.77      0.80      0.77        86
#
#
# Performance for Hospital 37:
#
# Test Loss: 0.285878986120224
# Total Test Accuracy: 96.0
# Test Accuracy (NFF): 96.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[24  1]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.96      0.98        25
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.96        25
#    macro avg       0.50      0.98      0.49        25
# weighted avg       1.00      0.96      0.98        25
#
#
# Performance for Hospital 38:
#
# Test Loss: 0.40478482842445374
# Total Test Accuracy: 86.20689655172414
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 33.33333333333333
# Confusion Matrix:
#  [[23  0]
#  [ 4  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.85      1.00      0.92        23
#          AFF       1.00      0.33      0.50         6
#
#     accuracy                           0.86        29
#    macro avg       0.93      0.67      0.71        29
# weighted avg       0.88      0.86      0.83        29
#
#
# Performance for Hospital 39:
#
# Test Loss: 0.2870645672082901
# Total Test Accuracy: 89.33333333333333
# Test Accuracy (NFF): 95.71428571428572
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[67  3]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.96      0.94        70
#          AFF       0.00      0.00      1.00         5
#
#     accuracy                           0.89        75
#    macro avg       0.47      0.48      0.97        75
# weighted avg       0.87      0.89      0.95        75
#
#
# Performance for Hospital 41:
#
# Test Loss: 0.1301591545343399
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 42:
#
# Test Loss: 0.4655582010746002
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 80.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[12  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.80      0.89        15
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.80        15
#    macro avg       0.50      0.90      0.44        15
# weighted avg       1.00      0.80      0.89        15
#
#
# Performance for Hospital 43:
#
# Test Loss: 0.44995805621147156
# Total Test Accuracy: 78.36734693877551
# Test Accuracy (NFF): 98.82352941176471
# Test Accuracy (AFF): 32.0
# Confusion Matrix:
#  [[168   2]
#  [ 51  24]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.77      0.99      0.86       170
#          AFF       0.92      0.32      0.48        75
#
#     accuracy                           0.78       245
#    macro avg       0.85      0.65      0.67       245
# weighted avg       0.81      0.78      0.74       245
#
#
# Performance for Hospital 44:
#
# Test Loss: 0.3610956072807312
# Total Test Accuracy: 83.87096774193549
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[26  0]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      1.00      0.91        26
#          AFF       1.00      0.00      0.00         5
#
#     accuracy                           0.84        31
#    macro avg       0.92      0.50      0.46        31
# weighted avg       0.86      0.84      0.77        31
#
#
# Performance for Hospital 45:
#
# Test Loss: 0.49695171415805817
# Total Test Accuracy: 76.03305785123968
# Test Accuracy (NFF): 94.31818181818183
# Test Accuracy (AFF): 27.27272727272727
# Confusion Matrix:
#  [[83  5]
#  [24  9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.78      0.94      0.85        88
#          AFF       0.64      0.27      0.38        33
#
#     accuracy                           0.76       121
#    macro avg       0.71      0.61      0.62       121
# weighted avg       0.74      0.76      0.72       121
#
#
# Performance for Hospital 46:
#
# Test Loss: 0.22787898778915405
# Total Test Accuracy: 90.9090909090909
# Test Accuracy (NFF): 90.9090909090909
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[20  2]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.91      0.95        22
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.91        22
#    macro avg       0.50      0.95      0.48        22
# weighted avg       1.00      0.91      0.95        22
#
#
# Performance for Hospital 47:
#
# Test Loss: 0.38164757192134857
# Total Test Accuracy: 83.6734693877551
# Test Accuracy (NFF): 97.43589743589743
# Test Accuracy (AFF): 30.0
# Confusion Matrix:
#  [[76  2]
#  [14  6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.84      0.97      0.90        78
#          AFF       0.75      0.30      0.43        20
#
#     accuracy                           0.84        98
#    macro avg       0.80      0.64      0.67        98
# weighted avg       0.83      0.84      0.81        98
#
#
# Performance for Hospital 48:
#
# Test Loss: 0.3354306071996689
# Total Test Accuracy: 90.14084507042253
# Test Accuracy (NFF): 96.875
# Test Accuracy (AFF): 28.57142857142857
# Confusion Matrix:
#  [[62  2]
#  [ 5  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.93      0.97      0.95        64
#          AFF       0.50      0.29      0.36         7
#
#     accuracy                           0.90        71
#    macro avg       0.71      0.63      0.66        71
# weighted avg       0.88      0.90      0.89        71
#
#
# Performance for Hospital 49:
#
# Test Loss: 0.296191930770874
# Total Test Accuracy: 94.73684210526316
# Test Accuracy (NFF): 94.73684210526315
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[54  3]
#  [ 0  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      0.95      0.97        57
#          AFF       0.00      1.00      0.00         0
#
#     accuracy                           0.95        57
#    macro avg       0.50      0.97      0.49        57
# weighted avg       1.00      0.95      0.97        57
#
#
# Performance for Hospital 50:
#
# Test Loss: 0.543951690196991
# Total Test Accuracy: 80.58252427184466
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 25.925925925925924
# Confusion Matrix:
#  [[76  0]
#  [20  7]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.79      1.00      0.88        76
#          AFF       1.00      0.26      0.41        27
#
#     accuracy                           0.81       103
#    macro avg       0.90      0.63      0.65       103
# weighted avg       0.85      0.81      0.76       103
#
#
# Performance for Hospital 51:
#
# Test Loss: 0.32518135011196136
# Total Test Accuracy: 91.13924050632912
# Test Accuracy (NFF): 98.61111111111111
# Test Accuracy (AFF): 14.285714285714285
# Confusion Matrix:
#  [[71  1]
#  [ 6  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      0.99      0.95        72
#          AFF       0.50      0.14      0.22         7
#
#     accuracy                           0.91        79
#    macro avg       0.71      0.56      0.59        79
# weighted avg       0.88      0.91      0.89        79
#
#
# Performance for Hospital 52:
#
# Test Loss: 0.26240259408950806
# Total Test Accuracy: 92.3076923076923
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[24  0]
#  [ 2  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.92      1.00      0.96        24
#          AFF       1.00      0.00      0.00         2
#
#     accuracy                           0.92        26
#    macro avg       0.96      0.50      0.48        26
# weighted avg       0.93      0.92      0.89        26
#
#
# Performance for Hospital 53:
#
# Test Loss: 1.2525147199630737
# Total Test Accuracy: 33.333333333333336
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 11.11111111111111
# Confusion Matrix:
#  [[3 0]
#  [8 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.27      1.00      0.43         3
#          AFF       1.00      0.11      0.20         9
#
#     accuracy                           0.33        12
#    macro avg       0.64      0.56      0.31        12
# weighted avg       0.82      0.33      0.26        12
#
#
# Performance for Hospital 54:
#
# Test Loss: 0.3810059577226639
# Total Test Accuracy: 81.34328358208955
# Test Accuracy (NFF): 97.16981132075472
# Test Accuracy (AFF): 21.428571428571427
# Confusion Matrix:
#  [[103   3]
#  [ 22   6]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.82      0.97      0.89       106
#          AFF       0.67      0.21      0.32        28
#
#     accuracy                           0.81       134
#    macro avg       0.75      0.59      0.61       134
# weighted avg       0.79      0.81      0.77       134
#
#
# Performance for Hospital 55:
#
# Test Loss: 0.398001104593277
# Total Test Accuracy: 86.11111111111111
# Test Accuracy (NFF): 99.3421052631579
# Test Accuracy (AFF): 14.285714285714285
# Confusion Matrix:
#  [[151   1]
#  [ 24   4]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.86      0.99      0.92       152
#          AFF       0.80      0.14      0.24        28
#
#     accuracy                           0.86       180
#    macro avg       0.83      0.57      0.58       180
# weighted avg       0.85      0.86      0.82       180
#
#
# Performance for Hospital 56:
#
# Test Loss: 0.5491760969161987
# Total Test Accuracy: 70.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 7.6923076923076925
# Confusion Matrix:
#  [[27  0]
#  [12  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.69      1.00      0.82        27
#          AFF       1.00      0.08      0.14        13
#
#     accuracy                           0.70        40
#    macro avg       0.85      0.54      0.48        40
# weighted avg       0.79      0.70      0.60        40
#
#
# Performance for Hospital 57:
#
# Test Loss: 0.14774638414382935
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         3
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3
#
#
# Performance for Hospital 58:
#
# Test Loss: 0.6953787803649902
# Total Test Accuracy: 57.89473684210526
# Test Accuracy (NFF): 96.55172413793103
# Test Accuracy (AFF): 17.857142857142858
# Confusion Matrix:
#  [[28  1]
#  [23  5]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.55      0.97      0.70        29
#          AFF       0.83      0.18      0.29        28
#
#     accuracy                           0.58        57
#    macro avg       0.69      0.57      0.50        57
# weighted avg       0.69      0.58      0.50        57
#
#
# Performance for Hospital 59:
#
# Test Loss: 0.17557284235954285
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[9]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         9
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Performance for Hospital 60:
#
# Test Loss: 0.48849494755268097
# Total Test Accuracy: 80.48780487804878
# Test Accuracy (NFF): 96.0
# Test Accuracy (AFF): 13.043478260869565
# Confusion Matrix:
#  [[96  4]
#  [20  3]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.83      0.96      0.89       100
#          AFF       0.43      0.13      0.20        23
#
#     accuracy                           0.80       123
#    macro avg       0.63      0.55      0.54       123
# weighted avg       0.75      0.80      0.76       123
#
#
# Performance for Hospital 61:
#
# Test Loss: 0.547054648399353
# Total Test Accuracy: 71.42857142857143
# Test Accuracy (NFF): 93.47826086956522
# Test Accuracy (AFF): 11.76470588235294
# Confusion Matrix:
#  [[43  3]
#  [15  2]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.74      0.93      0.83        46
#          AFF       0.40      0.12      0.18        17
#
#     accuracy                           0.71        63
#    macro avg       0.57      0.53      0.50        63
# weighted avg       0.65      0.71      0.65        63
#
#
# Performance for Hospital 62:
#
# Test Loss: 0.5537251234054565
# Total Test Accuracy: 77.35849056603773
# Test Accuracy (NFF): 97.5609756097561
# Test Accuracy (AFF): 8.333333333333332
# Confusion Matrix:
#  [[40  1]
#  [11  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.78      0.98      0.87        41
#          AFF       0.50      0.08      0.14        12
#
#     accuracy                           0.77        53
#    macro avg       0.64      0.53      0.51        53
# weighted avg       0.72      0.77      0.71        53
#
#
# Performance for Hospital 63:
#
# Test Loss: 0.3211362361907959
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[8]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00         8
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00         8
#    macro avg       1.00      1.00      1.00         8
# weighted avg       1.00      1.00      1.00         8
#
#
# Performance for Hospital 64:
#
# Test Loss: 0.24383953213691711
# Total Test Accuracy: 100.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0
# Confusion Matrix:
#  [[32]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       1.00      1.00      1.00        32
#          AFF       1.00      1.00      1.00         0
#
#    micro avg       1.00      1.00      1.00        32
#    macro avg       1.00      1.00      1.00        32
# weighted avg       1.00      1.00      1.00        32
#
#
# Performance for Hospital 65:
#
# Test Loss: 0.4516482353210449
# Total Test Accuracy: 80.0
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[8 0]
#  [2 0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.80      1.00      0.89         8
#          AFF       1.00      0.00      0.00         2
#
#     accuracy                           0.80        10
#    macro avg       0.90      0.50      0.44        10
# weighted avg       0.84      0.80      0.71        10
#
#
# Performance for Hospital 66:
#
# Test Loss: 0.5268556475639343
# Total Test Accuracy: 72.72727272727273
# Test Accuracy (NFF): 94.11764705882352
# Test Accuracy (AFF): 0.0
# Confusion Matrix:
#  [[16  1]
#  [ 5  0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.76      0.94      0.84        17
#          AFF       0.00      0.00      1.00         5
#
#     accuracy                           0.73        22
#    macro avg       0.38      0.47      0.92        22
# weighted avg       0.59      0.73      0.88        22
#
#
# Performance for Hospital 67:
#
# Test Loss: 0.47513067722320557
# Total Test Accuracy: 83.33333333333333
# Test Accuracy (NFF): 100.0
# Test Accuracy (AFF): 14.285714285714285
# Confusion Matrix:
#  [[29  0]
#  [ 6  1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.83      1.00      0.91        29
#          AFF       1.00      0.14      0.25         7
#
#     accuracy                           0.83        36
#    macro avg       0.91      0.57      0.58        36
# weighted avg       0.86      0.83      0.78        36
#
#
# Performance for Hospital 100:
#
# Test Loss: 0.44328273030427784
# Total Test Accuracy: 81.89655172413794
# Test Accuracy (NFF): 97.56468797564688
# Test Accuracy (AFF): 15.483870967741936
# Confusion Matrix:
#  [[641  16]
#  [131  24]]
# Classification Report:
#                precision    recall  f1-score   support
#
#          NFF       0.83      0.98      0.90       657
#          AFF       0.60      0.15      0.25       155
#
#     accuracy                           0.82       812
#    macro avg       0.72      0.57      0.57       812
# weighted avg       0.79      0.82      0.77       812
#
#
# Average Total Test Accuracy: 83.89978678055978
