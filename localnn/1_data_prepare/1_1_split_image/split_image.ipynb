# %% [markdown]
# # 1 split image by hospital

# %% [markdown]
# Folder stracture:
#
# dataset
# ├── AFF
# │   ├── hospital_1
# │   │   ├── patient_BCEXMHRRAZ
# │   │   │   └── image1.png
# │   │   ├── ...
# │   ├── hospital_2
# │   │   ├── ...
# ├── NFF
# │   ├── hospital_1
# │   │   ├── ...
# │   ├── hospital_2
# │   │   ├── ...
#
# NB: some hospitals only have one type images, either appear in AFF or NFF folder.
#
# split by parts of image names.
# for example:
#
# patient_ABEFSLVKVT_hospital_55_NFF_image_1
#
# [1]: patient id
#
# [3]: hospital number id
#
# [4]: image type

# %%
import os
import shutil

# down-sampled images
image_folder = '/Users/hong/thesis/code/data/images'

# new dataset folder
dataset_folder = '/Users/hong/thesis/code/data/hospital'

# create it if not exist
if not os.path.exists(dataset_folder):
    os.makedirs(dataset_folder)

# AFF and NFF folders
fracture_types = ['AFF', 'NFF']

# read images 
for filename in os.listdir(image_folder):
        parts = filename.split('_')
        image_type = parts[4]
        hospital_number = parts[3]
        patient_id = parts[1]

        # fracture types
        if image_type == 'AFF':
            fracture_types = 'AFF'
        elif image_type == 'NFF':
            fracture_types = 'NFF'
        else:
            continue
    
        # fracture type folders
        fracture_types_folder = os.path.join(dataset_folder, fracture_types)
        os.makedirs(fracture_types_folder, exist_ok=True)

        # hospital-specific folders
        hospital_folder = os.path.join(fracture_types_folder, f'hospital_{hospital_number}')
        os.makedirs(hospital_folder, exist_ok=True)

        # patient-specific folders
        patient_folder = os.path.join(hospital_folder, f'patient_{patient_id}')
        os.makedirs(patient_folder, exist_ok=True)

        # Move the image to the patient-specific folders
        src_path = os.path.join(image_folder, filename)
        dest_path = os.path.join(patient_folder, filename)
        # shutil.move(src_path, dest_path)
        shutil.copy(src_path, dest_path)

# %% [markdown]
# # # 2 split image by hospital

# %%
import os
import shutil

# down-sampled images
image_folder = '/Users/hong/thesis/code/data/images'

# new dataset folder
dataset_folder = '/Users/hong/thesis/code/data/patient'

# create it if not exist
if not os.path.exists(dataset_folder):
    os.makedirs(dataset_folder)

# AFF and NFF folders
fracture_types = ['AFF', 'NFF']

# read images patient_ABEFSLVKVT_hospital_55_NFF_image_1
for filename in os.listdir(image_folder):
        parts = filename.split('_') # 0 1 2 3 4 5 6
        image_type = parts[4]
    #    hospital_number = parts[3]
        patient_id = parts[1]

        # fracture types
        if image_type == 'AFF':
            fracture_types = 'AFF'
        elif image_type == 'NFF':
            fracture_types = 'NFF'
        else:
            continue
    
        # 1 fracture type folders
        fracture_types_folder = os.path.join(dataset_folder, fracture_types)
        os.makedirs(fracture_types_folder, exist_ok=True)

        # # 2 hospital-specific folders
        # hospital_folder = os.path.join(fracture_types_folder, f'hospital_{hospital_number}')
        # os.makedirs(hospital_folder, exist_ok=True)

        # 3 patient-specific folders
        patient_folder = os.path.join(fracture_types_folder, f'patient_{patient_id}')
        os.makedirs(patient_folder, exist_ok=True)

        # Move the image to the patient-specific folders
        src_path = os.path.join(image_folder, filename)
        dest_path = os.path.join(patient_folder, filename)
        # shutil.move(src_path, dest_path)
        shutil.copy(src_path, dest_path)

# %% [markdown]
# # 3 create train, validation and test folder by patient

# %%
import os
import random
import shutil

# 原始数据集根文件夹
dataset_root = '/Users/hong/thesis/code/data/patient'

# 目标数据集文件夹
target_dataset_folder = '/Users/hong/thesis/code/data/Data'

# 创建目标数据集文件夹
os.makedirs(target_dataset_folder, exist_ok=True)

# AFF和NFF文件夹
fracture_types = ['AFF', 'NFF']

# 分割数据集的比例
train_ratio = 0.8
val_ratio = 0.1
test_ratio = 0.1

# 遍历AFF和NFF文件夹
for fracture_type in fracture_types:
    source_folder = os.path.join(dataset_root, fracture_type)
    patients = os.listdir(source_folder)
    
    # 随机打乱患者顺序
    random.shuffle(patients)
    print(patients)
    
    # 划分数据集
    total_patients = len(patients)
    train_end = int(total_patients * train_ratio)
    val_end = train_end + int(total_patients * val_ratio)
    
    train_patients = patients[:train_end]
    val_patients = patients[train_end:val_end]
    test_patients = patients[val_end:]
    
    # 复制图片到相应的数据集文件夹
    for patient_id in train_patients:
        source_path = os.path.join(source_folder, patient_id)
        target_path = os.path.join(target_dataset_folder, 'train', fracture_type, patient_id)
        shutil.copytree(source_path, target_path)
    
    for patient_id in val_patients:
        source_path = os.path.join(source_folder, patient_id)
        target_path = os.path.join(target_dataset_folder, 'val', fracture_type, patient_id)
        shutil.copytree(source_path, target_path)
    
    for patient_id in test_patients:
        source_path = os.path.join(source_folder, patient_id)
        target_path = os.path.join(target_dataset_folder, 'test', fracture_type, patient_id)
        shutil.copytree(source_path, target_path)

print("Dataset split completed.")
# Out:
# ['patient_XQIOCJYVFV', 'patient_MOWHAOQJMV', 'patient_FOUONYLTKU', 'patient_HEQQAPRBWS', 'patient_QCFIKCSVST', 'patient_NOSIZIEUBU', 'patient_FFDXEONXXX', 'patient_XMGEWXFYNV', 'patient_YPRSRZHCPG', 'patient_HOPFPVLORH', 'patient_WZDWXHOMYA', 'patient_ILTVEQPXUA', 'patient_RDKDNXSNQD', 'patient_QDKTGGUNYM', 'patient_YANFWWOIKT', 'patient_UKLORUKSHD', 'patient_PPRWBFLFRK', 'patient_KEWEWVMUVK', 'patient_IEUAFGLDKF', 'patient_LVATVCYKNM', 'patient_IZPGJMHUGE', 'patient_PXNDALWWBU', 'patient_VJIXMXRDLI', 'patient_MHXRSFVRST', 'patient_IOZGIBUOFZ', 'patient_JKHJHWQTVV', 'patient_TLNHVEAPQM', 'patient_XYHTKUACGH', 'patient_FJUGUHNGQK', 'patient_TCOYOMJLTX', 'patient_GWTGJUWRHF', 'patient_ZHFQURFRCS', 'patient_JZLVBLAJKO', 'patient_BZAMJROXOS', 'patient_BGPFUVHNCO', 'patient_CMCPVBKNQC', 'patient_JDGKZIOUOH', 'patient_VCVVGCOVRG', 'patient_YAPWPSSJEE', 'patient_ELUCKPXATQ', 'patient_OOQEIAYRHH', 'patient_GMGSLMHKAV', 'patient_KSCCWJHMTJ', 'patient_UGJDNUXDFH', 'patient_EYRSUJGIZG', 'patient_LFWWIJGYEQ', 'patient_IHUZCYWODS', 'patient_MIVYQZNXOV', 'patient_DFFGXTNMAL', 'patient_FANSAJFYJW', 'patient_XUZYOGNMEX', 'patient_MKBOWYNUAD', 'patient_XXHINYNRCP', 'patient_YKGTKOEZOD', 'patient_PHGFIYJAHW', 'patient_BCEXMHRRAZ', 'patient_OGEYDUICJW', 'patient_CDDNMOLKUK', 'patient_ONJAHVIYRA', 'patient_TGRBLUOPTR', 'patient_XQISFIEFWE', 'patient_KRIDLZVHHN', 'patient_MUDQOWZAKJ', 'patient_YOASRWEXBB', 'patient_UXASSCGOJN', 'patient_YCIAMZAMKV', 'patient_LXHISOUOWM', 'patient_OCZTBZLACI', 'patient_VQEPVDURKM', 'patient_PESFPWFMWG', 'patient_FKPKPANOYY', 'patient_DZNZWZRLFF', 'patient_OVPNOLHVMQ', 'patient_JPPZTHGZAL', 'patient_ZQZUXAYGEY', 'patient_UNNOIKXWXO', 'patient_NHNXUTUUOI', 'patient_FXSVCOWVBO', 'patient_BBYPZEYQKD', 'patient_HISIXPFYOD', 'patient_CUAXWEKBCN', 'patient_JFNNXYYMOZ', 'patient_CXPINYYQCY', 'patient_NPFRIRZSPE', 'patient_SKPPWHJWFD', 'patient_NLISXLUOCK', 'patient_UVBWKOAUMI', 'patient_YDXOGKBBTR', 'patient_GWDTWSDIRD', 'patient_LWKGQBDALW', 'patient_YKGFQJDFPL', 'patient_FDMXDZTYAM', 'patient_HIKKWINDYT', 'patient_JNTKTMWHSD', 'patient_CTMHLKMPOI', 'patient_GVLWDYDBKH', 'patient_RQBEOUBITS', 'patient_VQTDZRXGQL', 'patient_PLOOQXOZKI', 'patient_KNPRIMYDUP', 'patient_MMOQGMWSNT', 'patient_SGYERTEXGO', 'patient_QJCFZQHGNO', 'patient_RDQRTFFAPT', 'patient_BOLEDDYOCV', 'patient_FSRARWYTGZ', 'patient_KMMULPQNKR', 'patient_BTNIKLXGIQ', 'patient_LNXBCFQICO', 'patient_ZWBJETAUYV', 'patient_PFZZTGOPIF', 'patient_ZUEQIPTWBP', 'patient_IQMABKMYHR', 'patient_HLNUGQSFMX', 'patient_QUCMBLOWKV', 'patient_UYVXOYBSQF', 'patient_CIPRLOMAGI', 'patient_YCXXAANTSO', 'patient_FWFAVDTSLJ', 'patient_FQRLCZBTPY', 'patient_RLRDIDRWOV', 'patient_ULUSXYKPHX', 'patient_GBHNKADXHT', 'patient_HMVVBDGXGJ', 'patient_ETXKVNHWFX', 'patient_DBPMMXEURX', 'patient_VTKFJIYBVL', 'patient_FZFHJJOOCM', 'patient_LMMPSNHKIG', 'patient_BJDJFHTUZW', 'patient_QVBUVJDACH', 'patient_HZUMGPZPKQ', 'patient_FHVCBFRPNT', 'patient_XLNZUNIVBF', 'patient_PAJBEAVZKR', 'patient_XDXANMWIWE', 'patient_NVBGGUFWZO', 'patient_AHZJZGQSST', 'patient_NQKDPLTAZH', 'patient_RCQOXVJTTC', 'patient_WIUJIVNJQF', 'patient_YFJKEMLNNI', 'patient_YICWUPETQU', 'patient_ORFRZBNBRJ', 'patient_YFULNYERJC', 'patient_KHSTMJVEJQ', 'patient_HTBNEVTDWH', 'patient_IGYIWYIHNP', 'patient_JZJBNVSFZV', 'patient_QUTANJXEDK', 'patient_ODOMHZFGYT', 'patient_IOTDXTXPQJ', 'patient_LBYMCBQHTO', 'patient_SXITFKEWLV', 'patient_VKNBZMYRLC', 'patient_JRZKWGZQFF', 'patient_DSTZZATEIP', 'patient_HTDWURKWEF', 'patient_AYKDVWTXSQ', 'patient_PQGDGGGFUM', 'patient_RGAQRKXMMX', 'patient_JFNBSGQMJO', 'patient_BYEDSYTODQ', 'patient_CNADCDIUZJ', 'patient_KZUZABMUFH', 'patient_LSQQDJXBHZ', 'patient_VHAOBPQUOM', 'patient_BTNEAZBRXT', 'patient_XTWUQBZCTI', 'patient_GKSHWBQPUP', 'patient_HICWADUKYN', 'patient_ZSQBPMEXDL', 'patient_VZVWOXCCSD', 'patient_KEXZWBFVIX', 'patient_TSRMTUFPUM', 'patient_DTGBJKMSXR', 'patient_ZHAIJPEBDR', 'patient_SFNRYWQVLH', 'patient_KDZBUUIKOL', 'patient_VCYAFOQEQN', 'patient_TVUJDEJMML', 'patient_REWKUEZW ...
# ['patient_GHNOKXHQHG', 'patient_RMIGZGUMIQ', 'patient_XOABULJUJN', 'patient_ZLXXVBJHQD', 'patient_URWPQCFALI', 'patient_PENMJCGIJD', 'patient_UYDGJZIXGF', 'patient_ABYNJJDDJI', 'patient_YRFXJAFXWP', 'patient_HRDNSYTTKG', 'patient_HPHUUYLLPV', 'patient_FGRMQGEVTY', 'patient_CIGPLKBGGS', 'patient_OKNXDLBJSC', 'patient_JQRZYJFXHO', 'patient_ZSRIAOAGEL', 'patient_KXMXMYSSAO', 'patient_ZFZPGNSGCO', 'patient_IFVJEAYRWY', 'patient_ZUYTGSSUTI', 'patient_WPGJXXLGOE', 'patient_BGLHRYUQTT', 'patient_RSLXZYLXKP', 'patient_ABEFSLVKVT', 'patient_XMUBGQDQKT', 'patient_DESRJCAJUL', 'patient_EDPXYFMJNG', 'patient_PVZXFALAMY', 'patient_JPRXCOLQOF', 'patient_OPWJTEBIVJ', 'patient_NMWJLZBZER', 'patient_DIXPAIFHAV', 'patient_GBTEHGOOUW', 'patient_MMYKDGRVZF', 'patient_WQCXABZRJN', 'patient_QDSQBUZLIB', 'patient_INWBNLXQZP', 'patient_FFIWMKEZKV', 'patient_JEKUKTHQXF', 'patient_NJUWTKPQDM', 'patient_TNPENBBIQX', 'patient_LNMVZZTFAE', 'patient_NMILTZGUDA', 'patient_MBEIWBJQVB', 'patient_XLLANZHTDU', 'patient_CBTIBYBBOL', 'patient_DEYHGRACIF', 'patient_MPSDPFBBYN', 'patient_LFXTWHRRDK', 'patient_XZDNVQYYZB', 'patient_ZSEWXZOOEN', 'patient_MBNIWAFWFI', 'patient_VQGXTOXJIQ', 'patient_ATNMXPQWUO', 'patient_UETTWLEHIL', 'patient_DKISXMUIOK', 'patient_OMGPWBLCOO', 'patient_QZQPXOIYLP', 'patient_AEYYLVYRJK', 'patient_HACUSUQVAK', 'patient_LBCURAOSCF', 'patient_OWBXDVUXDN', 'patient_YULIBTNFLE', 'patient_GHXSWJQAXM', 'patient_UNOKSBPWLQ', 'patient_UTKBPESNGX', 'patient_SZYCYEZPGB', 'patient_KGWYJBEOEH', 'patient_QIHLJWASIH', 'patient_ECIPJYBZRQ', 'patient_DGCLGHLDMS', 'patient_QFVZWNHTGY', 'patient_FREZNXSMPJ', 'patient_AFLOKQPTEN', 'patient_GDNBMZRWMH', 'patient_ZBYARUNXXQ', 'patient_ERIUOFRBOZ', 'patient_SOKBUIPTCD', 'patient_BRBBNCVVSD', 'patient_JQJKJMNXFI', 'patient_EZGUVMXCDW', 'patient_HULOZRZCXB', 'patient_TAKGFRXATU', 'patient_HGLFUZANCU', 'patient_ZTTADGXZZJ', 'patient_PODODGNVSN', 'patient_EAISQOLHNT', 'patient_ISYCHPVUOA', 'patient_UMRKJFJAMI', 'patient_RPJJEUMJUG', 'patient_CFPSXPWRUN', 'patient_MDUCHGNCKC', 'patient_PJWUMVXLIP', 'patient_HMXNHNOKAS', 'patient_ZXWUOKDRWH', 'patient_VGVGYJFGQM', 'patient_NWPEFKTVUI', 'patient_IWGPYBBARP', 'patient_CIUGTSVVHI', 'patient_DIASYSTEJO', 'patient_KYXDPJSNGM', 'patient_SMSYNHUGGM', 'patient_BBNUYDOMAI', 'patient_NXQDBAFNDB', 'patient_IHAOCDQWZO', 'patient_UCEJWPPYOA', 'patient_IIKTERQVJC', 'patient_ZYQNJTUABI', 'patient_WYEBOAVXSG', 'patient_WNJWGERGEH', 'patient_IVTDBNTVSX', 'patient_IWEENPEQVU', 'patient_HAFRZGQZMH', 'patient_MSZIVTYAJR', 'patient_DPIGOERBAH', 'patient_IZMTRUHHSE', 'patient_BVNSFOSYLC', 'patient_TKADHWPIHL', 'patient_NVLAAEJSEH', 'patient_ENVHEBYGQF', 'patient_GYYHFGGGLV', 'patient_TKSOPISEAO', 'patient_YZEAGJGTFL', 'patient_VKPVXYEGXP', 'patient_XNZJFSIDXS', 'patient_SKCFGFSTOO', 'patient_UMMDXRVRZZ', 'patient_CXNPICWDJQ', 'patient_NFVRVUMIRZ', 'patient_MWKBHILMSJ', 'patient_YQVETFKUKB', 'patient_MPAPURNVZI', 'patient_ZCNNCXWLUD', 'patient_JESEZABUWO', 'patient_VDWYAJEOCB', 'patient_EPYCXOLDGL', 'patient_XTRTLKFWYY', 'patient_WBRZHDRXPX', 'patient_QVCPPNLZEO', 'patient_REGLAGZIOP', 'patient_EZYMUDKXUY', 'patient_QOVYBXOFFS', 'patient_TECFORYBEL', 'patient_UXMVDTYVGF', 'patient_IIYTHPTVXP', 'patient_NGHQXWFKXG', 'patient_KBXYMMIXJC', 'patient_YYZSSJBLOO', 'patient_OJOHERRUJG', 'patient_HVTVEBPSCC', 'patient_UHACIHAELT', 'patient_IPXXPIWLXA', 'patient_LWWJQWABJD', 'patient_ZFNFOZDYDE', 'patient_DRRYVEYFFA', 'patient_KUECXWZWAO', 'patient_UNTTLWMYUD', 'patient_KZUSTTVUZC', 'patient_NBIXVAQUGB', 'patient_CMFXIWGWET', 'patient_ZOYSMQXFKZ', 'patient_IWEFNCGQCP', 'patient_LUAOLBLVQT', 'patient_VRRNEMOVFN', 'patient_OFKIJJCNVI', 'patient_BOHMRFPIWD', 'patient_EIBQGTHKBA', 'patient_DTQKVACYKN', 'patient_HETSELBRUW', 'patient_CYDDECLRVU', 'patient_NFPFKWLYJS', 'patient_SFRLLEFQGO', 'patient_QUHMVPNIKU', 'patient_HWYUZNCQEW', 'patient_WAIKCCBXZK', 'patient_LCULHJMLSR', 'patient_GOJANVGBGR', 'patient_SQRYNKRLDL', 'patient_NRKVSZNICP', 'patient_XGWSWYDKZQ', 'patient_FKGHAYNMNI', 'patient_WLAMVWHG ...
# Dataset split completed.

# %%
import os

def count_number(path_folder):
    # AFF和NFF文件夹路径
    aff_folder = os.path.join(path_folder, 'AFF')
    nff_folder = os.path.join(path_folder, 'NFF')

    # 统计AFF和NFF文件夹中的图片数量
    aff_image_count = sum(len(files) for _, _, files in os.walk(aff_folder))
    nff_image_count = sum(len(files) for _, _, files in os.walk(nff_folder))
    
    return aff_image_count, nff_image_count

print('total:')
path_folder = '/Users/hong/thesis/code/data/hospital'
total_aff_num, total_nff_num = count_number(path_folder)
print('aff number:', total_aff_num, '; nff number:', total_nff_num)

print('train:')
path_folder = '/Users/hong/thesis/code/data/Data/train'
aff_num, nff_num = count_number(path_folder)
print('aff number:', aff_num, '; nff number:', nff_num)
print('%:', aff_num / total_aff_num , '; %:', nff_num / total_nff_num)

print('val:')
path_folder = '/Users/hong/thesis/code/data/Data/val'
aff_num, nff_num = count_number(path_folder)
print('aff number:', aff_num, '; nff number:', nff_num)
print('%:', aff_num / total_aff_num , '; %:', nff_num / total_nff_num)


print('test:')
path_folder = '/Users/hong/thesis/code/data/Data/test'
aff_num, nff_num = count_number(path_folder)
print('aff number:', aff_num, '; nff number:', nff_num)
print('%:', aff_num / total_aff_num , '; %:', nff_num / total_nff_num)
# Out:
# total:
# aff number: 868 ; nff number: 3474
# train:
# aff number: 751 ; nff number: 2873
# %: 0.8652073732718893 ; %: 0.8270005757052389
# val:
# aff number: 51 ; nff number: 224
# %: 0.0587557603686636 ; %: 0.0644789867587795
# test:
# aff number: 68 ; nff number: 379
# %: 0.07834101382488479 ; %: 0.10909614277489925
